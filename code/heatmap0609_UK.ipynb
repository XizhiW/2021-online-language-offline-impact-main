# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 3.4 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=2825025b2a4a9824960bcc5be523aa1726711a01ed8ff7b329bfef8fefa6e8aa
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK         dataframe0610_UK.csv
#  a0529-a0611_US         dataframe0611_UK.csv
#  a0529.csv	        dataframe_csv
#  a0530.csv	        dataframe_csv_EU
#  a0531.csv	        dataframe_csv_UK
#  a0601.csv	        dataframe_result_csv
#  a0602.csv	        dataframe_result_csv_EU
#  a0603.csv	        dataframe_result_csv_UK
#  a0604.csv	        Github
#  a0605.csv	        heatmap529_UK.ipynb
#  a0606.csv	        heatmap530.ipynb
#  a0607.csv	        Heat_Map_Online_language.ipynb
#  a0608.csv	        __MACOSX
#  a0610.csv	        non_violant1.csv
#  a0611.csv	        non_violant2.csv
#  csv		        UK
#  csv.zip	        violant.csv
#  dataframe0608_UK.csv  '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_531 = 'UK/06_09.csv'

# %%
ct = pd.read_csv(ct_path_531)

# %%
ct.shape[1]
# Out:
# 47

# %%
#columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                               platformId  ...                    post_id
# 0          18343191100_10158286958501101  ...    40736|10158286958501101
# 1        111188856119651_700712523833945  ...    7934143|700712523833945
# 2      2185993931653388_2550218238564287  ...   8557227|2550218238564287
# 3         131459315949_10158124442440950  ...    14655|10158124442440950
# 4          51642564435_10157738513099436  ...    20335|10157738513099436
# ...                                  ...  ...                        ...
# 25788   116031465116295_3273138612738882  ...      5169|3273138612738882
# 25789   118106634893622_3157166614320927  ...   4687770|3157166614320927
# 25790  1563911857243719_2358973767737520  ...   1249797|2358973767737520
# 25791     195046979230_10158288430374231  ...  7644434|10158288430374231
# 25792    199583243888887_891400818040456  ...    3764718|891400818040456
#
# [25793 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#           NER-msg        NER-desc
# 0              {}              {}
# 1              {}              {}
# 2              {}              {}
# 3              {}              {}
# 4  {'Houston': 1}  {'Houston': 1}

# %%
ct.to_csv('a0609.csv')

# %%
ct=pd.read_csv('a0609.csv',lineterminator="\n")

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                               NER-msg                NER-desc       NER-title
# 4                      {'Houston': 1}          {'Houston': 1}              {}
# 5                                  {}          {'Houston': 1}              {}
# 7     {'Long Island': 2, 'Albany': 2}  {'Albany': 1, 'mo': 1}              {}
# 10  {'America': 1, 'Philadelphia': 1}                      {}              {}
# 12                                 {}                      {}  {'Houston': 1}

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ct_ner['NER-msg']
# Out:
# 4                      [Houston]
# 5                             []
# 7          [Albany, Long Island]
# 10       [America, Philadelphia]
# 12                            []
#                   ...
# 25787                         []
# 25788                         []
# 25790                         []
# 25791                         []
# 25792                         []
# Name: NER-msg, Length: 18310, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ct_ner['NER']
# Out:
# 4                                       [Houston, Houston]
# 5                                                [Houston]
# 7                        [Albany, Long Island, Albany, mo]
# 10                                 [America, Philadelphia]
# 12                                               [Houston]
#                                ...
# 25787    [Houston, Texas, Minneapolis, Minnesota, North...
# 25788    [the United States, #Poverty, North Carolina, ...
# 25790                           [NYC, Brooklyn, Manhattan]
# 25791                           [NYC, Brooklyn, Manhattan]
# 25792                               [Milwaukee, MILWAUKEE]
# Name: NER, Length: 18310, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ner_lst = ct_ner['NER'].values

# %%
ner_lst
# Out:
# array([list(['houston']), list(['houston']),
#        list(['albany', 'long island', 'mo']), ...,
#        list(['manhattan', 'nyc', 'brooklyn']),
#        list(['manhattan', 'nyc', 'brooklyn']),
#        list(['milwaukee', 'milwaukee'])], dtype=object)

# %%
m=0
list=[]
for n in ner_lst:
  for i in range(len(n)):
    list.append(ner_lst[m][i])
  m+=1

# %%
list
# Out:
# ['houston',
#  'houston',
#  'albany',
#  'long island',
#  'mo',
#  'america',
#  'philadelphia',
#  'houston',
#  'houston',
#  'dyersburg',
#  'the united states',
#  'the city of dyersburg police department',
#  'new york',
#  'new york',
#  'new york',
#  'los angeles',
#  'new york',
#  'new york',
#  'new york',
#  'minnesota',
#  'san francisco',
#  'south jersey',
#  'franklin township',
#  'n.j.',
#  'n.j.',
#  'minneapolis',
#  'uk',
#  'minneapolis',
#  'martinsburg',
#  'west virginia',
#  'west virginia',
#  'houston',
#  'texas',
#  'new york city',
#  'u.s.',
#  'minneapolis',
#  'america',
#  'washington dc',
#  'chicago',
#  'new jersey',
#  'new jersey',
#  'erie county',
#  'buffalo',
#  'martinsville',
#  'new jersey',
#  'franklinville',
#  'new jersey',
#  'franklinville',
#  'new jersey',
#  'spokane',
#  'spokane city',
#  'new orleans',
#  'the city of new orleans',
#  'houston',
#  'adelaide',
#  'minneapolis',
#  'houston',
#  'new york',
#  'new york',
#  'new york',
#  'compton',
#  'joliet',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'south jersey',
#  'n.j.',
#  'houston',
#  'n.j.',
#  'milwaukee',
#  'minneapolis',
#  'minneapolis',
#  'alberta',
#  'minnesota',
#  'huntsville',
#  'minneapolis',
#  'alberta',
#  'minnesota',
#  'st. charles',
#  'new jersey',
#  'nj',
#  'south jersey',
#  'franklin township',
#  'minneapolis',
#  'alberta',
#  'minnesota',
#  'albany',
#  'n.y.',
#  'the united states of america',
#  'minneapolis',
#  'alberta',
#  'minnesota',
#  'houston',
#  'texas',
#  'houston',
#  'mexico',
#  'houston',
#  'mexico',
#  'minneapolis',
#  'alberta',
#  'minnesota',
#  'america',
#  'minneapolis',
#  'alberta',
#  'minnesota',
#  'minneapolis',
#  'u.s.',
#  'evanston',
#  'minneapolis',
#  'providence',
#  'us',
#  'minnesotta',
#  'minneapolis',
#  'ohio',
#  'the united states',
#  'ohio',
#  'the united states',
#  'minneapolis',
#  'israel',
#  'buffalo',
#  'italia',
#  'davenport',
#  'iowa',
#  'clark nj',
#  'clark',
#  'minneapolis',
#  'tulsa',
#  'america',
#  'us',
#  'minneapolis',
#  'washington',
#  'new york',
#  'uk',
#  'lake county',
#  'minneapolis',
#  'alberta',
#  'minnesota',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'u.s.',
#  'america',
#  'philadelphia',
#  'black minneapolis',
#  'minneapolis',
#  'kentucky',
#  'minneapolis',
#  'u.s.',
#  'america',
#  'oklahoma',
#  'oklahoma city pd',
#  'minneapolis',
#  'minneapolis',
#  'oxford',
#  'bristol',
#  'australia',
#  'the united states',
#  'america',
#  'houston',
#  'indiana',
#  'minneapolis',
#  'carmel',
#  'indiana',
#  'minneapolis',
#  'carmel',
#  'minneapolis',
#  'minneapolis',
#  'houston',
#  'us',
#  'minneapolis',
#  'washington',
#  'new york',
#  'uk',
#  'america',
#  'connecticut',
#  'us',
#  'america',
#  'saint lucia',
#  'saint lucia’s',
#  'us',
#  'columbus',
#  'u.s.',
#  'america',
#  'minneapolis',
#  'new york',
#  'saint lucia',
#  'ohio',
#  'saint lucia’s',
#  'new york',
#  'minneapolis',
#  'brooklyn',
#  'new york city',
#  'franklinville',
#  'houston',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'ohio',
#  'minneapolis',
#  'toledo',
#  'city',
#  'america',
#  'the united states of america',
#  'america',
#  'houston',
#  'america',
#  'texas',
#  'pearland',
#  'houston',
#  'america',
#  'texas',
#  'pearland',
#  'us',
#  'minneapolis',
#  'washington',
#  'new york',
#  'uk',
#  'texas',
#  'fort worth',
#  'texas',
#  'the united states',
#  'fort worth',
#  'chicago',
#  'lafayette park',
#  'america',
#  'washington',
#  'new york',
#  'potomac',
#  'd.c.',
#  'st. john’s',
#  'lafayette park',
#  'america',
#  'washington',
#  'new york',
#  'potomac',
#  'd.c.',
#  'st. john’s',
#  'america',
#  'minneapolis',
#  'alabama',
#  'jersey',
#  'mexico',
#  'brazil',
#  'mexico city',
#  'madrid',
#  'ireland',
#  'new zealand',
#  'syria',
#  'barcelona',
#  'minneapolis',
#  'lauderdale',
#  'boston',
#  'spain',
#  'binnish',
#  'poland',
#  'amsterdam',
#  'greece',
#  'france',
#  'us',
#  'auckland',
#  'america',
#  'athens',
#  'canada',
#  'copenhagen',
#  'germany',
#  'maryland',
#  'dublin',
#  'paris',
#  'berlin',
#  'virginia',
#  'australia',
#  'brussels',
#  'd.c.',
#  'buffalo',
#  'denmark',
#  'haiti',
#  'minnesota',
#  'lafayette park',
#  'america',
#  'washington',
#  'new york',
#  'potomac',
#  'd.c.',
#  'st. john’s',
#  'america',
#  'london',
#  'the united states of america',
#  'alabama',
#  'minneapolis',
#  'america',
#  'the united states',
#  'south minneapolis',
#  'minneapolis',
#  'america',
#  'lafayette park',
#  'america',
#  'washington',
#  'new york',
#  'potomac',
#  'd.c.',
#  'st. john’s',
#  'lafayette park',
#  'america',
#  'washington',
#  'new york',
#  'potomac',
#  'd.c.',
#  'st. john’s',
#  'houston',
#  'houston',
#  'houston',
#  'minneapolis',
#  'houston',
#  'houston',
#  'houston',
#  'houston',
#  'united states',
#  'south carolina',
#  'the united states',
#  'philando castile',
#  'muestra de unidad y solidaridad',
#  'asi que',
#  'los hermanos',
#  'los invitamos',
#  'ansianos',
#  'france',
#  'minneapolis',
#  'the united states',
#  'houston',
#  'houston',
#  'st. louis county',
#  'st. louis',
#  'detroit',
#  'new york',
#  'ny',
#  'tarrant',
#  'denton',
#  'tarrant',
#  'denton',
#  'milwaukee',
#  'milwaukee',
#  'u.s.',
#  'houston',
#  'houston',
#  'us',
#  'america',
#  'minneapolis',
#  'houston',
#  'tampa',
#  'the city of tampa',
#  'maryland',
#  'u.s.',
#  'us',
#  'the u. s.',
#  'washington',
#  'us',
#  'tunis',
#  'minneapolis',
#  'the u. s.',
#  'washington',
#  'houston',
#  'miami',
#  'miami beach',
#  'america',
#  'newyork',
#  'newyork',
#  'philadelphia',
#  'new york',
#  'minneapolis',
#  'buffalo',
#  'us',
#  'texas',
#  'georgia',
#  'minneapolis',
#  'houston',
#  'us',
#  'washington',
#  'u.s.',
#  'oregon',
#  'us',
#  'washington',
#  'u.s.',
#  'houston',
#  'us',
#  'washington',
#  'u.s.',
#  'america',
#  'minneapolis',
#  'the united states',
#  'houston',
#  'indianapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  "new zealand's",
#  'christchurch',
#  'new jersey',
#  'franklinville',
#  'los angeles',
#  'washington',
#  'u. s.',
#  'washington',
#  'u. s.',
#  'washington',
#  'u. s.',
#  'minneapolis',
#  'houston',
#  'minneapolis',
#  'us',
#  'the u. s.',
#  'washington',
#  'u.s.',
#  'montgomery county',
#  'new jersey',
#  'nj',
#  'nyc',
#  'new york city',
#  'new york',
#  'buffalo',
#  'the united states',
#  'the united states',
#  'oregon',
#  'the united states',
#  'u.s.',
#  'northampton',
#  'northampton',
#  'u.s.',
#  'matuzungidi',
#  'chicago',
#  'osaka',
#  'u.s.',
#  'america',
#  'minneapolis',
#  'new jersey',
#  'washington',
#  'new york city',
#  'los angeles',
#  'osaka',
#  'pennsylvania',
#  'pittsburgh',
#  'u.s.',
#  'houston',
#  'houston',
#  'houston',
#  'pearland',
#  'houston',
#  'east spencer',
#  'alabama',
#  'jersey',
#  'mexico',
#  'brazil',
#  'mexico city',
#  'madrid',
#  'ireland',
#  'new zealand',
#  'syria',
#  'barcelona',
#  'lauderdale',
#  'boston',
#  'spain',
#  'binnish',
#  'poland',
#  'amsterdam',
#  'greece',
#  'france',
#  'us',
#  'auckland',
#  'america',
#  'athens',
#  'canada',
#  'copenhagen',
#  'germany',
#  'maryland',
#  'dublin',
#  'paris',
#  'east spencer',
#  'berlin',
#  'virginia',
#  'australia',
#  'brussels',
#  'd.c.',
#  'buffalo',
#  'denmark',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'brooklyn',
#  'america',
#  'the united states',
#  'minnesota',
#  'roc',
#  'minnesota',
#  'roc',
#  'houston',
#  'houston',
#  'pearland',
#  'alabama',
#  'jersey',
#  'mexico',
#  'brazil',
#  'mexico city',
#  'madrid',
#  'ireland',
#  'new zealand',
#  'syria',
#  'barcelona',
#  'minneapolis',
#  'lauderdale',
#  'boston',
#  'spain',
#  'binnish',
#  'poland',
#  'amsterdam',
#  'greece',
#  'france',
#  'us',
#  'houston',
#  'auckland',
#  'america',
#  'athens',
#  'canada',
#  'houston',
#  'copenhagen',
#  'germany',
#  'maryland',
#  'dublin',
#  'paris',
#  'berlin',
#  'virginia',
#  'australia',
#  'brussels',
#  'd.c.',
#  'buffalo',
#  'denmark',
#  'los angeles',
#  'l.a.',
#  "los angeles'",
#  'houston',
#  'houston',
#  'tx',
#  'minneapolis',
#  'minn',
#  'denville',
#  'texas',
#  'denville',
#  'texas',
#  'denville',
#  'claremont',
#  'houston',
#  'claremont',
#  'houston',
#  'united states',
#  'the united states',
#  'houston',
#  'houston',
#  'houston',
#  'port houston',
#  'the peaceful protest',
#  'texas',
#  'stoneham',
#  'hollywood',
#  'minneapolis',
#  'elmhurst',
#  'america',
#  'philadelphia',
#  'san francisco',
#  'houston',
#  'houston',
#  'rockford',
#  'winnebago county',
#  'houston',
#  'houston',
#  'https://www.sidewalk-talk.org/blog/anti-racism-is-a-consciousness-practice',
#  'houston',
#  'alabama',
#  'jersey',
#  'mexico',
#  'brazil',
#  'mexico city',
#  'madrid',
#  'ireland',
#  'new zealand',
#  'syria',
#  'barcelona',
#  'minneapolis',
#  'lauderdale',
#  'boston',
#  'spain',
#  'binnish',
#  'poland',
#  'amsterdam',
#  'greece',
#  'france',
#  'us',
#  'auckland',
#  'america',
#  'athens',
#  'canada',
#  'copenhagen',
#  'germany',
#  'maryland',
#  'dublin',
#  'paris',
#  'berlin',
#  'virginia',
#  'australia',
#  'brussels',
#  'd.c.',
#  'buffalo',
#  'denmark',
#  'monterey county',
#  'salinas',
#  'houston',
#  'houston',
#  'houston',
#  'indiana',
#  'lollapalooza',
#  'chicago',
#  'illinois',
#  'buffalo',
#  'houston',
#  'minneapolis',
#  'u.s.',
#  'pearland',
#  'minneapolis',
#  'us',
#  'syracuse',
#  'minneapolis',
#  'new york',
#  'syracuse',
#  'minneapolis',
#  'new york',
#  'houston',
#  'texas',
#  'minneapolis',
#  'us',
#  'texas',
#  'houston',
#  'the united states',
#  'america',
#  'minneapolis',
#  'houston',
#  'houston',
#  'houston',
#  'houston',
#  'texas',
#  'houston',
#  'texas',
#  'houston',
#  'texas',
#  'pearland',
#  'america',
#  'wisconsin',
#  'south carolina',
#  'america',
#  '🥰',
#  'uk',
#  'usa',
#  'us',
#  'syracuse',
#  'minneapolis',
#  'new york',
#  'houston',
#  'texas',
#  'u.s.',
#  'america',
#  'minneapolis',
#  'houston',
#  'minneapolis',
#  'malaysia',
#  'minneapolis',
#  'malaysia',
#  'houston',
#  'texas',
#  'malaysia',
#  'malaysia',
#  'america',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'montana',
#  'america',
#  'the united states',
#  'houston',
#  'texas',
#  'alaska',
#  'houston',
#  'houston',
#  'texas',
#  'minneapolis',
#  'canada',
#  'london',
#  'new zealand',
#  'germany',
#  'houston',
#  'los angeles',
#  'america',
#  'minneapolis',
#  'new york',
#  'buffalo',
#  'houston',
#  'tx',
#  'buffalo',
#  'houston',
#  'tx',
#  'the united states',
#  'buffalo',
#  'minn',
#  'the united states',
#  'u.s.',
#  'houston',
#  'us',
#  'the united states',
#  'sudan',
#  'berlin',
#  'ethiopia',
#  'london',
#  'us',
#  'london',
#  'the united states',
#  'berlin',
#  'houston',
#  'us',
#  'the united states',
#  'sudan',
#  'berlin',
#  'ethiopia',
#  'london',
#  'new york',
#  'us',
#  'buffalo',
#  'houston',
#  'buffalo',
#  'sf city',
#  'syria',
#  'damascus',
#  'u.s.',
#  'america',
#  'minneapolis',
#  'tehran',
#  'israel',
#  'south africa',
#  'usa',
#  'iran',
#  'texas',
#  'florida',
#  'fort worth',
#  'ponte vedra beach',
#  'houston',
#  'us',
#  'minneapolis',
#  'china',
#  'togo',
#  'nw',
#  'jefferson park',
#  'edison park',
#  'norwood park',
#  'chicago',
#  'america',
#  'houston',
#  'u.s.',
#  'houston',
#  'texas',
#  'tx',
#  'broward county',
#  'houston',
#  'houston',
#  'houston',
#  'minneapolis',
#  'houston',
#  'houston',
#  'texas',
#  'houston',
#  'texas',
#  'boston',
#  'america',
#  'america',
#  'united states of america',
#  'alabama',
#  'jersey',
#  'mexico',
#  'brazil',
#  'mexico city',
#  'madrid',
#  'ireland',
#  'new zealand',
#  'syria',
#  'barcelona',
#  'minneapolis',
#  'lauderdale',
#  'boston',
#  'spain',
#  'binnish',
#  'poland',
#  'amsterdam',
#  'greece',
#  'france',
#  'us',
#  'auckland',
#  'america',
#  'athens',
#  'canada',
#  'copenhagen',
#  'germany',
#  'maryland',
#  'dublin',
#  'paris',
#  'berlin',
#  'virginia',
#  'australia',
#  'brussels',
#  'd.c.',
#  'buffalo',
#  'denmark',
#  'the city of greensboro',
#  'minneapolis',
#  'greensboro',
#  'greater greensboro',
#  'mn',
#  'washington',
#  'houston',
#  'us',
#  'houston',
#  'america',
#  'third ward',
#  'pearland',
#  'us',
#  'america',
#  'lincoln park',
#  'chicago',
#  'chicago',
#  'lincoln park',
#  'chicago',
#  'chicago',
#  'new york',
#  'nyc',
#  'new york city',
#  'houston',
#  'texas',
#  'minneapolis',
#  'new york',
#  'america',
#  'new york',
#  'ghana',
#  'the united states embassy',
#  'zimbabwe',
#  'harare',
#  'bluff hill',
#  'zimbabwe',
#  'minneapolis',
#  'fayetteville',
#  'county',
#  'rockingham county',
#  'houston',
#  'houston',
#  'houston',
#  'houston',
#  'minneapolis',
#  'south jersey',
#  'franklinville',
#  'gloucester county',
#  'united states of america',
#  'south jersey',
#  'franklinville',
#  'gloucester county',
#  'the united states',
#  'south jersey',
#  'gloucester county',
#  'minneapolis',
#  'new york',
#  'franklinville',
#  'buffalo',
#  'houston',
#  'tx',
#  'pearland',
#  'united states of america',
#  'alabama',
#  'birmingham',
#  'alabama',
#  'chattanooga',
#  'us',
#  'los angeles',
#  'los angeles',
#  'houston',
#  'texas',
#  'los angeles',
#  'us',
#  'los angeles',
#  'houston',
#  'los angeles',
#  'minnesota',
#  'the extreme liberal',
#  'our united states of america - democratic party',
#  'houston',
#  'texas',
#  'minneapolis',
#  'the union states',
#  'america',
#  'minneapolis',
#  'new york',
#  'america',
#  'california',
#  'brooklyn',
#  'america',
#  'wisconsin',
#  'south carolina',
#  'houston',
#  'america',
#  'houston',
#  'minneapolis',
#  'new jersey',
#  'newark',
#  'brooklyn',
#  'new york city',
#  'minneapolis',
#  'brooklyn',
#  'houston',
#  'houston',
#  'houston',
#  'tallahassee',
#  'fl 32302',
#  'florida',
#  'escambia county',
#  'santa rosa county',
#  'alabama',
#  'jersey',
#  'mexico',
#  'brazil',
#  'mexico city',
#  'madrid',
#  'ireland',
#  'new zealand',
#  'syria',
#  'barcelona',
#  'minneapolis',
#  'lauderdale',
#  'boston',
#  'spain',
#  'binnish',
#  'poland',
#  'amsterdam',
#  'greece',
#  'france',
#  'us',
#  'houston',
#  'auckland',
#  'america',
#  'athens',
#  'canada',
#  'copenhagen',
#  'germany',
#  'maryland',
#  'dublin',
#  'paris',
#  'berlin',
#  'virginia',
#  'australia',
#  'italy',
#  'brussels',
#  'd.c.',
#  'buffalo',
#  'denmark',
#  'u.s.',
#  'baltimore safe haven',
#  'baltimore',
#  'u.s.',
#  'philadelphia',
#  'philadelphia',
#  'kensington',
#  'america',
#  'philadelphia',
#  'philadelphia',
#  'usa',
#  'buffalo',
#  'ligonier',
#  'montana',
#  'maryland',
#  'san antonio',
#  'tx',
#  'san antonio tx',
#  'bs',
#  'minneapolis',
#  'san antonio',
#  'houston',
#  'minneapolis',
#  'minneapolis',
#  'houston',
#  'houston',
#  'houston',
#  'lancaster',
#  'vietnam',
#  'rehoboth beach',
#  'de',
#  'u.s.',
#  'houston',
#  'texas',
#  'houston',
#  'guadalupe',
#  'houston',
#  ...]

# %%
c = collections.Counter()

# %%
dict_a=collections.Counter(list).most_common()

# %%
dict_a
# Out:
# [('houston', 5314),
#  ('minneapolis', 4869),
#  ('america', 2279),
#  ('texas', 2112),
#  ('us', 1819),
#  ('u.s.', 1317),
#  ('the united states', 1049),
#  ('minnesota', 868),
#  ('buffalo', 561),
#  ('new york', 490),
#  ('canada', 479),
#  ('d.c.', 446),
#  ('washington', 430),
#  ('france', 417),
#  ('virginia', 401),
#  ('australia', 400),
#  ('alabama', 391),
#  ('germany', 390),
#  ('maryland', 383),
#  ('boston', 365),
#  ('paris', 364),
#  ('chicago', 362),
#  ('philadelphia', 355),
#  ('mexico', 346),
#  ('brazil', 345),
#  ('new zealand', 344),
#  ('spain', 327),
#  ('berlin', 327),
#  ('los angeles', 326),
#  ('ireland', 325),
#  ('athens', 317),
#  ('uk', 315),
#  ('jersey', 309),
#  ('lauderdale', 309),
#  ('denmark', 309),
#  ('brussels', 307),
#  ('new york city', 306),
#  ('syria', 306),
#  ('amsterdam', 305),
#  ('dublin', 305),
#  ('greece', 304),
#  ('madrid', 302),
#  ('barcelona', 302),
#  ('copenhagen', 300),
#  ('poland', 287),
#  ('auckland', 282),
#  ('mexico city', 279),
#  ('binnish', 256),
#  ('pearland', 254),
#  ('portland', 247),
#  ('nyc', 222),
#  ('london', 212),
#  ('california', 205),
#  ('usa', 202),
#  ('brooklyn', 197),
#  ('ghana', 180),
#  ('tx', 163),
#  ('georgia', 154),
#  ('north carolina', 152),
#  ('the united states of america', 150),
#  ('florida', 150),
#  ('louisville', 134),
#  ('ohio', 124),
#  ('seattle', 124),
#  ('atlanta', 123),
#  ('new jersey', 110),
#  ('britain', 102),
#  ('israel', 99),
#  ('china', 98),
#  ('united states', 96),
#  ('birmingham', 93),
#  ('england', 92),
#  ('nj', 90),
#  ('pittsburgh', 90),
#  ('oregon', 88),
#  ('bristol', 86),
#  ('oakland', 84),
#  ('nigeria', 84),
#  ('hollywood', 83),
#  ('long island', 78),
#  ('milwaukee', 77),
#  ('south minneapolis', 77),
#  ('detroit', 77),
#  ('massachusetts', 73),
#  ('n.y.', 72),
#  ('baltimore', 72),
#  ('kentucky', 71),
#  ('denver', 69),
#  ('st. louis', 67),
#  ('wisconsin', 66),
#  ('italy', 65),
#  ('south africa', 64),
#  ('la', 63),
#  ('|', 63),
#  ('san francisco', 61),
#  ('colorado', 61),
#  ('richmond', 60),
#  ('phoenix', 60),
#  ('india', 60),
#  ('belgium', 59),
#  ('howard county', 58),
#  ('mn', 57),
#  ('dc', 57),
#  ('philando castile', 56),
#  ('ny', 55),
#  ('harris county', 55),
#  ('michigan', 54),
#  ('columbus', 53),
#  ('montana', 53),
#  ('minn.', 53),
#  ('iran', 52),
#  ('dallas', 50),
#  ('s.c.', 49),
#  ('illinois', 48),
#  ('🇸', 48),
#  ('st. paul', 48),
#  ('south carolina', 47),
#  ('third ward', 45),
#  ('toronto', 45),
#  ('salem', 44),
#  ('san antonio', 43),
#  ('hennepin county', 43),
#  ('sacramento', 43),
#  ('ore.', 42),
#  ('franklinville', 41),
#  ('u.k.', 40),
#  ('vietnam', 39),
#  ('russia', 38),
#  ('palestine', 38),
#  ('d-n.y.', 38),
#  ('washington dc', 37),
#  ('indiana', 37),
#  ('tulsa', 36),
#  ('l.a.', 36),
#  ('washington, dc', 36),
#  ('abuja', 36),
#  ('south korea', 36),
#  ('the republic of ghana', 36),
#  ('utah', 35),
#  ('albany', 34),
#  ('fort worth', 34),
#  ('n.j.', 33),
#  ('pennsylvania', 33),
#  ('manchester', 33),
#  ('clarksburg', 33),
#  ('ky.', 33),
#  ('calif.', 32),
#  ('austin', 32),
#  ('hillsborough county', 32),
#  ('lagos', 32),
#  ('arkansas', 31),
#  ('cleveland', 31),
#  ('sri lanka', 31),
#  ('ky', 31),
#  ('stoke', 31),
#  ('manhattan', 30),
#  ('missouri', 30),
#  ('hartford', 30),
#  ('sydney', 30),
#  ('jamaica', 30),
#  ('rochester', 30),
#  ('miami', 29),
#  ('cincinnati', 29),
#  ('bloomington', 29),
#  ('hillsborough state', 29),
#  ('chattanooga', 28),
#  ('nashville', 28),
#  ('new york state', 28),
#  ('libya', 28),
#  ("the united states'", 27),
#  ('edo', 27),
#  ('new orleans', 26),
#  ('arizona', 26),
#  ('san jose', 26),
#  ('scotland', 26),
#  ('ga.', 26),
#  ('camden', 26),
#  ('montreal', 26),
#  ('nigeria fida', 26),
#  ('charlotte', 25),
#  ('troy', 25),
#  ('indianapolis', 24),
#  ('zimbabwe', 24),
#  ('accra', 24),
#  ('san diego', 24),
#  ('ferguson', 24),
#  ('washington d.c.', 24),
#  ('seoul', 24),
#  ('south jersey', 23),
#  ('franklin township', 23),
#  ('lafayette park', 23),
#  ('charlottesville', 23),
#  ('japan', 23),
#  ('jacksonville', 23),
#  ('charleston', 23),
#  ('hamilton county', 23),
#  ('alberta', 22),
#  ('iowa', 22),
#  ('alaska', 22),
#  ('county', 22),
#  ('memphis', 22),
#  ('fl', 22),
#  ('springfield', 22),
#  ('oklahoma', 21),
#  ('minn', 21),
#  ('el paso', 21),
#  ('tennessee', 21),
#  ('orlando', 21),
#  ('tex', 21),
#  ('nevada', 21),
#  ('kobe', 21),
#  ('las vegas', 21),
#  ('baton rouge', 21),
#  ('cary', 21),
#  ('oak park heights', 21),
#  ('lower manhattan', 21),
#  ('connecticut', 20),
#  ('tampa', 20),
#  ('kenya', 20),
#  ('sweden', 20),
#  ('hong kong', 20),
#  ('manchester city', 20),
#  ('madison', 20),
#  ('pa.', 20),
#  ('akufo-addo', 20),
#  ('brunswick', 19),
#  ('ala.', 19),
#  ('north wales', 19),
#  ('st. john’s', 18),
#  ('va', 18),
#  ('fulton county', 18),
#  ('st louis', 18),
#  ('columbia', 18),
#  ('tucson', 18),
#  ('ct', 18),
#  ('u.s', 18),
#  ('harrisburg', 18),
#  ('iraq', 18),
#  ('derbyshire', 18),
#  ('long beach', 17),
#  ('mississippi', 17),
#  ('ga', 17),
#  ('botswana', 17),
#  ('ukraine', 17),
#  ('🏾louisville', 17),
#  ('vancouver', 17),
#  ('turkey', 17),
#  ('mo.', 17),
#  ('bayelsa', 17),
#  ('ondo', 17),
#  ('benin', 17),
#  ('switzerland', 17),
#  ('montgomery county', 16),
#  ('antwerp', 16),
#  ('md', 16),
#  ('williamson county', 16),
#  ('geneva', 16),
#  ('syracuse', 15),
#  ('senegal', 15),
#  ('los angeles county', 15),
#  ('vallejo', 15),
#  ('cuba', 15),
#  ('salt lake city', 15),
#  ('anaheim', 15),
#  ('ontario', 15),
#  ('glasgow', 15),
#  ('haiti', 14),
#  ('apo abuja', 14),
#  ('fairfax', 14),
#  ('beijing', 14),
#  ('district', 14),
#  ('bass river', 14),
#  ('delaware', 14),
#  ('philippines', 14),
#  ('fort benning', 14),
#  ('rome', 14),
#  ('omaha', 14),
#  ('greater brandywine', 14),
#  ('compton', 13),
#  ('the u. s.', 13),
#  ('fayetteville', 13),
#  ('newark', 13),
#  ('tallahassee', 13),
#  ('sc', 13),
#  ('united kingdom', 13),
#  ('congo', 13),
#  ('seattle pd', 13),
#  ('wales', 13),
#  ('pretoria', 13),
#  ('nc', 13),
#  ('va.', 13),
#  ('usa minneapolis', 13),
#  ('maine', 13),
#  ('british columbia', 13),
#  ('portugal', 13),
#  ('glendale', 13),
#  ('milford', 13),
#  ('wv', 13),
#  ('penna', 13),
#  ('west virginia', 12),
#  ('lincoln park', 12),
#  ('gaza', 12),
#  ('jerusalem', 12),
#  ('palm beach county', 12),
#  ('•', 12),
#  ('santa cruz', 12),
#  ('angry united', 12),
#  ('delhi', 12),
#  ('north korea', 12),
#  ('augusta', 12),
#  ('zaragoza', 12),
#  ('hampton bays', 12),
#  ('malaysia', 11),
#  ('gloucester county', 11),
#  ('n.c.', 11),
#  ('miami-dade', 11),
#  ('hawaii', 11),
#  ('venezuela', 11),
#  ('pensacola', 11),
#  ('minnea', 11),
#  ('montgomery', 11),
#  ('mobile', 11),
#  ('fort lauderdale', 11),
#  ('plymouth', 11),
#  ('trenton', 11),
#  ("new york's", 11),
#  ('walmart', 11),
#  ('jordan', 11),
#  ('youngstown', 11),
#  ('des moines', 11),
#  ("prince george's county", 11),
#  ('mi', 11),
#  ('abuja, nigeria', 11),
#  ('duluth', 11),
#  ('terrence hills', 11),
#  ('napa', 11),
#  ('https://bit.ly/2m8nywt', 11),
#  ('aledo', 11),
#  ('potomac', 10),
#  ('bloomfield', 10),
#  ('wi', 10),
#  ('alexandire', 10),
#  ('lightfoot', 10),
#  ('rochester hills', 10),
#  ('mich.', 10),
#  ('anoka county', 10),
#  ('vermont', 10),
#  ('chauvin', 10),
#  ("harris county's", 10),
#  ('bragg', 10),
#  ('asheville', 10),
#  ('york', 10),
#  ('afghanistan', 10),
#  ('new hampshire', 10),
#  ('tenn.', 10),
#  ('south florida', 10),
#  ('hungary', 10),
#  ('shreveport', 10),
#  ('nashville city', 10),
#  ('howie', 10),
#  ('kan.', 10),
#  ('ethiopia', 9),
#  ('fort bend county', 9),
#  ('alexandria', 9),
#  ('northam', 9),
#  ('the city of chicago', 9),
#  ('twitteremail', 9),
#  ('lawrence', 9),
#  ('pflag', 9),
#  ('pasadena', 9),
#  ('oklahoma city', 9),
#  ('cambridge', 9),
#  ('new mexico', 9),
#  ('raeford', 9),
#  ('rhode island', 9),
#  ('tyler', 9),
#  ('santa ana', 9),
#  ('nairobi', 9),
#  ('fort bragg', 9),
#  ('opelika', 9),
#  ('boca raton', 9),
#  ('melbourne', 9),
#  ('aotearoa', 9),
#  ('odessa', 9),
#  ('truckee', 9),
#  ('downtown oakland https://streamable.com/y9s4x9 bar', 9),
#  ('okla', 9),
#  ('placerville california', 9),
#  ('placerville', 9),
#  ('toledo', 8),
#  ('los invitamos', 8),
#  ('orange county', 8),
#  ('fla.', 8),
#  ('lebanon', 8),
#  ('raleigh', 8),
#  ('silver spring', 8),
#  ('matteson', 8),
#  ('the deep state', 8),
#  ('jackson', 8),
#  ('philly', 8),
#  ('lansing', 8),
#  ('saint paul', 8),
#  ('longview', 8),
#  ('watts', 8),
#  ('brownsville', 8),
#  ('simcoe county\n', 8),
#  ('belmont', 8),
#  ('oregon city', 8),
#  ('allegheny county', 8),
#  ('bronx', 8),
#  ('nebraska', 8),
#  ('huntington', 8),
#  ('worcester', 8),
#  ('ill.', 8),
#  ('new york&#821', 8),
#  ('washington,', 8),
#  ('west chester', 8),
#  ('prince georges county', 8),
#  ('downtown west palm beach', 8),
#  ('louisiana', 8),
#  ('puerto rico', 8),
#  ('woburn', 8),
#  ('somalia', 8),
#  ('us city', 8),
#  ('santa monica', 8),
#  ('these united states', 8),
#  ('new jersey’s', 8),
#  ('ramallah', 8),
#  ('wis.', 8),
#  ('peduto', 8),
#  ('providence', 7),
#  ('denton', 7),
#  ('claremont', 7),
#  ('tehran', 7),
#  ('little rock', 7),
#  ('wilmington', 7),
#  ('gauteng', 7),
#  ('la.', 7),
#  ('hialeah', 7),
#  ('the united kingdom', 7),
#  ('sheffield', 7),
#  ('westminster', 7),
#  ('florence', 7),
#  ('st.', 7),
#  ('new jersey state police', 7),
#  ('washington park', 7),
#  ('halton hills solidarity', 7),
#  ('durham', 7),
#  ('chatham', 7),
#  ('kansas', 7),
#  ('binghamton', 7),
#  ('fairfax county', 7),
#  ('annandale', 7),
#  ('yonkers', 7),
#  ('korea', 7),
#  ('ymca', 7),
#  ('laguna niguel', 7),
#  ('new jersey city', 7),
#  ('the city of san antonio', 7),
#  ('ottawa', 7),
#  ('tacoma', 7),
#  ('warsaw', 7),
#  ('san bernardino', 7),
#  ('christi', 7),
#  ('greenville', 7),
#  ('kansas city', 7),
#  ('tatenda', 7),
#  ('vienna', 7),
#  ('nottingham', 7),
#  ('bexar county', 7),
#  ('yarmouth', 7),
#  ('il', 7),
#  ('austria', 7),
#  ('haifa', 7),
#  ('mass.', 7),
#  ('windermere', 7),
#  ('turlock', 7),
#  ('spokane', 6),
#  ('lake county', 6),
#  ('city', 6),
#  ('st. louis county', 6),
#  ('sudan', 6),
#  ('united states of america', 6),
#  ('greensboro', 6),
#  ('lancaster', 6),
#  ('argentina', 6),
#  ('nh', 6),
#  ('east palo alto', 6),
#  ('new york’s', 6),
#  ('netherlands', 6),
#  ('calvary', 6),
#  ('kalamazoo county', 6),
#  ('harlow', 6),
#  ('finland', 6),
#  ('az', 6),
#  ('frankfurt', 6),
#  ('flint', 6),
#  ('humboldt park', 6),
#  ('stafford', 6),
#  ('new jersey state', 6),
#  ('burlington county', 6),
#  ('bollywood', 6),
#  ('washington ave', 6),
#  ('ark.', 6),
#  ('queens', 6),
#  ('riverside county', 6),
#  ('the blue states', 6),
#  ('pakistan', 6),
#  ('orillia', 6),
#  ('brevard county', 6),
#  ('the anne arundel county police department', 6),
#  ('casper', 6),
#  ('democ', 6),
#  ('king county', 6),
#  ('derry', 6),
#  ('ne', 6),
#  ('jeunes', 6),
#  ('dorn', 6),
#  ('hopkinton', 6),
#  ('the city of peekskill', 6),
#  ('preplanned', 6),
#  ('liberia', 6),
#  ('egypt', 6),
#  ('brisbane', 6),
#  ('lisbon', 6),
#  ('bremen', 6),
#  ('nexit', 6),
#  ('guam', 6),
#  ('tarrant county', 6),
#  ('decatur', 6),
#  ('virginia city', 6),
#  ('cal state', 6),
#  ('bangladesh', 6),
#  ('the essex county superior courthouse', 6),
#  ('new brunswick', 6),
#  ('clifton park', 6),
#  ('anti-israel', 6),
#  ('brevard', 6),
#  ('❤', 6),
#  ('lake elsinore', 6),
#  ('leadville', 6),
#  ('bayville', 6),
#  ('alamance county', 6),
#  ('mankato', 6),
#  ('mo', 5),
#  ('dyersburg', 5),
#  ('the city of new orleans', 5),
#  ('oxford', 5),
#  ('the city of tampa', 5),
#  ('miami beach', 5),
#  ('roc', 5),
#  ('togo', 5),
#  ('the united states embassy', 5),
#  ('virgin islands', 5),
#  ('savannah', 5),
#  ('drc', 5),
#  ('may.', 5),
#  ('goldsboro', 5),
#  ('belfast', 5),
#  ('asbury park', 5),
#  ('#georgefloyd', 5),
#  ('antifa', 5),
#  ('lafayette place', 5),
#  ('booth', 5),
#  ('booth brockton', 5),
#  ('salt lake county', 5),
#  ('hazleton', 5),
#  ('phx', 5),
#  ('selma', 5),
#  ('@revolttv', 5),
#  ('liverpool', 5),
#  ('evansville', 5),
#  ('south milwaukee', 5),
#  ('genoa city park', 5),
#  ('locust', 5),
#  ('oak creek', 5),
#  ('pulaski', 5),
#  ('waukesha', 5),
#  ('genoa city', 5),
#  ('monona', 5),
#  ('greendale', 5),
#  ('wauwatosa', 5),
#  ('halton hills', 5),
#  ('halton region', 5),
#  ('honduras', 5),
#  ('the city of whittier', 5),
#  ('whittier city budget', 5),
#  ('the city of whittier defund', 5),
#  ('whittier city', 5),
#  ('akron', 5),
#  ('reno', 5),
#  ('md.', 5),
#  ('kingdom', 5),
#  ('the city of jacksonville', 5),
#  ('palm springs', 5),
#  ('munich', 5),
#  ('miss.', 5),
#  ('colombia', 5),
#  ('calgary', 5),
#  ('mencuatkan', 5),
#  ('south west', 5),
#  ('simcoe county', 5),
#  ('nimal dunu', 5),
#  ('biaknak kong', 5),
#  ('indonesia', 5),
#  ('wy oil city news', 5),
#  ('dayton', 5),
#  ('olney', 5),
#  ('montpelier', 5),
#  ('oxnard', 5),
#  ('santa barbara', 5),
#  ('west papua', 5),
#  ('winona lake - news', 5),
#  ('kaduna', 5),
#  ('\u2063', 5),
#  ('staten island', 5),
#  ('ho', 5),
#  ('port huron', 5),
#  ('waco', 5),
#  ('dorchester', 5),
#  ('springboro', 5),
#  ('fait révolutionnaire - partie', 5),
#  ('wolverhampton', 5),
#  ('iowa city', 5),
#  ('anchorage', 5),
#  ('baltimore city', 5),
#  ('annapolis', 5),
#  ('st. matthews', 5),
#  ('clearwater', 5),
#  ('poughkeepsie', 5),
#  ('blackburn', 5),
#  ('lancashire', 5),
#  ('kingston', 5),
#  ('halifax', 5),
#  ('quebec', 5),
#  ('osimhen', 5),
#  ('yakima county', 5),
#  ('corvallis', 5),
#  ('woodbury', 5),
#  ('thurso', 5),
#  ('knoxville', 5),
#  ('topeka', 5),
#  ('angoon', 5),
#  ('new zealand police', 5),
#  ('tuscaloosa', 5),
#  ('los angeles county federation of labor', 5),
#  ('drag queens', 5),
#  ('kings', 5),
#  ('halsted', 5),
#  ('lakeview chicago', 5),
#  ('boystown', 5),
#  ('santee', 5),
#  ('peoria', 5),
#  ('salt lake', 5),
#  ('north minneapolis', 5),
#  ('twin lakes', 5),
#  ('newbury', 5),
#  ('martinsville', 4),
#  ('evanston', 4),
#  ('saint lucia', 4),
#  ('saint lucia’s', 4),
#  ('tunis', 4),
#  ('osaka', 4),
#  ('denville', 4),
#  ('stoneham', 4),
#  ('kensington', 4),
#  ('luton', 4),
#  ('poway', 4),
#  ('the virgin islands', 4),
#  ('#poverty', 4),
#  ('garki', 4),
#  ('middletown', 4),
#  ('grand rapids', 4),
#  ('colombo', 4),
#  ('idaho', 4),
#  ('leicester', 4),
#  ('sonoma', 4),
#  ('waterloo', 4),
#  ('johannesburg', 4),
#  ('the soviet union', 4),
#  ('budapest', 4),
#  ('city of chicago', 4),
#  ('cranbury', 4),
#  ('laramie', 4),
#  ('new york city flushing', 4),
#  ('warren county', 4),
#  ('states', 4),
#  ('north carolina house', 4),
#  ('humboldt park - 3000', 4),
#  ('ks', 4),
#  ('newcastle', 4),
#  ('hillcrest', 4),
#  ('san luis obispo', 4),
#  ('pa', 4),
#  ('politiegeweld', 4),
#  ('canterbury', 4),
#  ('ny state', 4),
#  ('maple grove', 4),
#  ('arlington', 4),
#  ('farmington', 4),
#  ('riverside', 4),
#  ('bluffton', 4),
#  ('bc', 4),
#  ('ghent', 4),
#  ('kavinda', 4),
#  ('judah', 4),
#  ('kerala', 4),
#  ('the city of charleston', 4),
#  ('the village of saranac lake', 4),
#  ('the village of saranac\nlake', 4),
#  ('lexington', 4),
#  ('juneau', 4),
#  ('the laguna niguel ymca', 4),
#  ('santa barbara independent', 4),
#  ('santa barbara’s', 4),
#  ('shelby county', 4),
#  ('the city of scranton', 4),
#  ('santa rosa', 4),
#  ('york county', 4),
#  ('scranton', 4),
#  ('edinburgh', 4),
#  ('melville', 4),
#  ('west toledo', 4),
#  ('delray', 4),
#  ('uganda', 4),
#  ('kolkata', 4),
#  ('north carolina’s', 4),
#  ('cumberland', 4),
#  ('ar', 4),
#  ('milan', 4),
#  ('sussex', 4),
#  ('north st louis', 4),
#  ('#usa', 4),
#  ('medford', 4),
#  ('norway', 4),
#  ('cardiff', 4),
#  ('wausau', 4),
#  ('nicaragua', 4),
#  ('nz', 4),
#  ('bangor', 4),
#  ('lee county', 4),
#  ('bethesda', 4),
#  ('bowie', 4),
#  ('cecil county', 4),
#  ('bartram park', 4),
#  ('little rock’s', 4),
#  ('americus', 4),
#  ('monrovia', 4),
#  ('myanmar', 4),
#  ('vets park', 4),
#  ('nsw', 4),
#  ('delray beach', 4),
#  ('bethany riellymonday', 4),
#  ('ogun', 4),
#  ('kogi', 4),
#  ('surrey', 4),
#  ('greenock', 4),
#  ('sekündige', 4),
#  ('der band hatten', 4),
#  ('wurde', 4),
#  ('rolle', 4),
#  ('miramar', 4),
#  ('cyprus', 4),
#  ('new jersey mock george floyd killing', 4),
#  ('melville monument', 4),
#  ('ankara', 4),
#  ('founta', 4),
#  ('sioux', 4),
#  ('moscow', 4),
#  ("worcester city '", 4),
#  ('cbd', 4),
#  ('buratai', 4),
#  ('orlando city', 4),
#  ('the republic of the united states of america', 4),
#  ('the republic of the united states', 4),
#  ('chico', 4),
#  ('trent', 4),
#  ('monroe', 4),
#  ('harrison', 4),
#  ('new york city\n', 4),
#  ('modesto', 4),
#  ('manchester city’s', 4),
#  ('watertown', 4),
#  ('grand junction', 4),
#  ('vall', 4),
#  ('1 minneapolis', 4),
#  ('traverse city', 4),
#  ('the redlands police', 4),
#  ('redlands', 4),
#  ('east florence', 4),
#  ('cote', 4),
#  ('new york city planned parenthood', 4),
#  ('bolivia', 4),
#  ('west alabama', 4),
#  ('erie', 4),
#  ('a united methodist', 4),
#  ('pinedale', 4),
#  ('north dakota', 4),
#  ('erie county', 3),
#  ('black minneapolis', 3),
#  ('carmel', 3),
#  ('muestra de unidad y solidaridad', 3),
#  ('asi que', 3),
#  ('los hermanos', 3),
#  ('ansianos', 3),
#  ('newyork', 3),
#  ('christchurch', 3),
#  ('u. s.', 3),
#  ('northampton', 3),
#  ('monterey county', 3),
#  ('salinas', 3),
#  ('damascus', 3),
#  ('broward county', 3),
#  ('harare', 3),
#  ('guadalupe', 3),
#  ('halle', 3),
#  ('oxfordshire', 3),
#  ('wellington', 3),
#  ('venezia', 3),
#  ('hyannis', 3),
#  ('greater pittsburgh', 3),
#  ('dundee', 3),
#  ('hamden', 3),
#  ('frisco', 3),
#  ('ashland', 3),
#  ('elmont', 3),
#  ('the state of texas', 3),
#  ('hattiesburg', 3),
#  ('west palm beach', 3),
#  ('brooklyn park', 3),
#  ('request city', 3),
#  ('dearborn', 3),
#  ('cape town', 3),
#  ('trumpian', 3),
#  ('windsor', 3),
#  ('mt. pleasant', 3),
#  ('sr.', 3),
#  ('vo', 3),
#  ('cal', 3),
#  ('😓', 3),
#  ('barbados', 3),
#  ('joelacevedo', 3),
#  ('whittier', 3),
#  ('chesapeake', 3),
#  ('berkeley', 3),
#  ('http://paypal', 3),
#  ('beaumont', 3),
#  ('paro', 3),
#  ('wamrong', 3),
#  ('issuna', 3),
#  ('hampton', 3),
#  ('nj - the borough', 3),
#  ('hyattsville', 3),
#  ('onslow', 3),
#  ('onslow county', 3),
#  ('tn', 3),
#  ('dep.', 3),
#  ('🏾 county', 3),
#  ('🏾 univ', 3),
#  ('narragansett', 3),
#  ("st. john's", 3),
#  ('hamburg', 3),
#  ('alexanderplatz', 3),
#  ('alameda', 3),
#  ('washington county', 3),
#  ('dover', 3),
#  ('portsmouth', 3),
#  ('scioto', 3),
#  ('marysville', 3),
#  ('metropolitan st. louis', 3),
#  ('coronado', 3),
#  ('monmouth', 3),
#  ('arundel county', 3),
#  ('the united st', 3),
#  ('st. john’s church', 3),
#  ('new delhi', 3),
#  ('reggaeville', 3),
#  ('kingsville', 3),
#  ('costa mesa', 3),
#  ('gadsden', 3),
#  ('man city', 3),
#  ('watford', 3),
#  ('nova scotia', 3),
#  ('bethlehem', 3),
#  ('west bank', 3),
#  ('the city of minneapolis', 3),
#  ('yorkshire', 3),
#  ('eugene', 3),
#  ('brazoria county', 3),
#  ('u.s.a', 3),
#  ('addis ababa', 3),
#  ('the state of california', 3),
#  ('kfbx', 3),
#  ('kunm', 3),
#  ('east harlem churches', 3),
#  ('new ideas', 3),
#  ('africa, nigeria', 3),
#  ('corpus', 3),
#  ('yellowknife', 3),
#  ('south dakota', 3),
#  ('sonoma county', 3),
#  ('woonsocket', 3),
#  ("manchester city's", 3),
#  ('ghana kente', 3),
#  ('utopia', 3),
#  ('santa claus', 3),
#  ('regina', 3),
#  ('s.d.', 3),
#  ('marietta', 3),
#  ('muskingum park', 3),
#  ('deep state', 3),
#  ('grand park', 3),
#  ('y’', 3),
#  ('🍃💨', 3),
#  ('durban', 3),
#  ('stillwater', 3),
#  ('curtis park', 3),
#  ('mobile county', 3),
#  ('d-nj', 3),
#  ('fayette', 3),
#  ('inner city', 3),
#  ('the united states conference of catholic bishops', 3),
#  ('perth', 3),
#  ('fla', 3),
#  ('helena', 3),
#  ('bryan', 3),
#  ('clarksville', 3),
#  ('district of columbia', 3),
#  ('drogheda', 3),
#  ('atlantic city', 3),
#  ('edgewater', 3),
#  ('easton', 3),
#  ('chester', 3),
#  ('the city of pearland', 3),
#  ('east ala.', 3),
#  ('east alabama', 3),
#  ('bowling green', 3),
#  ('tokyo', 3),
#  ('sanford', 3),
#  ('»', 3),
#  ('united', 3),
#  ('wetzel', 3),
#  ("new jersey's", 3),
#  ('meek mill', 3),
#  ('los angels', 3),
#  ('the british empire', 3),
#  ('the west indies', 3),
#  ('montclair', 3),
#  ('new britain', 3),
#  ('⠀', 3),
#  ('white plains', 3),
#  ('rio de janeiro', 3),
#  ('tunisia', 3),
#  ('bordeaux', 3),
#  ('den usa', 3),
#  ('deutschland', 3),
#  ('mudd', 3),
#  ('kueng', 3),
#  ('mansfield', 3),
#  ('griffith', 3),
#  ('singapore', 3),
#  ('dubai', 3),
#  ('colpetty', 3),
#  ('the district of columbia', 3),
#  ('iron county', 3),
#  ('fortune lake lutheran camp', 3),
#  ('st louis - four', 3),
#  ('forts bragg', 3),
#  ('buaicaan', 3),
#  ('asi lo', 3),
#  ('culver city', 3),
#  ('north st. louis city', 3),
#  ('vt.', 3),
#  ('marion', 3),
#  ('warren', 3),
#  ('the city of', 3),
#  ('bakersfield', 3),
#  ('tanzania', 3),
#  ('fredericksburg', 3),
#  ('milwaukee county', 3),
#  ('la crosse', 3),
#  ('desert vineyard', 3),
#  ('franklin park', 3),
#  ('east flatbush', 3),
#  ('lakeland', 3),
#  ('tennesse', 3),
#  ('united brass', 3),
#  ('west contra costa unified', 3),
#  ('the gaza strip', 3),
#  ('whitefish', 3),
#  ('bds', 3),
#  ('keung', 3),
#  ('@highrollerlobsterco', 3),
#  ('vacationland', 3),
#  ('muskegon', 3),
#  ('univ', 3),
#  ('multnomah county da', 3),
#  ('bbq', 3),
#  ('the west bank', 3),
#  ('muncie', 3),
#  ...]

# %%
dataframe531=pd.DataFrame(dict_a)

# %%
len(dict_a)
# Out:
# 3314

# %%
dataframe531.to_csv('dataframe0609_UK.csv')
