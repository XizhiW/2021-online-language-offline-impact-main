# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 4.3 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=a88a0863db1bbec2587c8f5efed883468e5ae3daecfe19a307798cb5bca14afc
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.8 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_UK
#  a0529-a0611_US     dataframe_result_529_UK.csv
#  a0529.csv	    dataframe_result_530_UK.csv
#  a0530.csv	    dataframe_result_531_UK.csv
#  a0601.csv	    dataframe_result_csv
#  a0602.csv	    dataframe_result_csv_EU
#  a0603.csv	    dataframe_result_csv_UK
#  a0604.csv	    Github
#  a0605.csv	    heatmap529_UK.ipynb
#  a0606.csv	    heatmap530.ipynb
#  a0607.csv	    Heat_Map_Online_language.ipynb
#  a0608.csv	    __MACOSX
#  a0610.csv	    mapping_UK
#  a0611.csv	    mapping_US
#  ccc_compiled.csv   non_violant1.csv
#  csv		    non_violant2.csv
#  csv.zip	    UK
#  dataframe_csv	    violant.csv
#  dataframe_csv_EU  '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_611 = 'csv/US06_12.csv'

# %%
ct = pd.read_csv(ct_path_611)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                              platformId  ...                    post_id
# 0     1791654857736614_2699985123570245  ...   8096587|2699985123570245
# 1     1481073582140028_2787886488125391  ...     68123|2787886488125391
# 2     2457084541029255_3911218202282541  ...   5775977|3911218202282541
# 3      104914626218275_3165074630202244  ...   1821675|3165074630202244
# 4      481275305234454_3775044389190846  ...   5799320|3775044389190846
# ...                                 ...  ...                        ...
# 6238   341833139168802_3359091014109651  ...     69527|3359091014109651
# 6239   674764996035495_1534516946726958  ...   1534289|1534516946726958
# 6240      28807649968_10151403362734969  ...  9868876|10151403362734969
# 6241   889555808073667_1168735133489065  ...  11386916|1168735133489065
# 6242    391196808388510_679376802903841  ...   13099713|679376802903841
#
# [6243 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#             NER-msg            NER-desc
# 0                {}                  {}
# 1                {}  {'Minneapolis': 1}
# 2  {'Minnesota': 1}  {'Minneapolis': 1}
# 3                {}  {'Minneapolis': 1}
# 4                {}  {'Minneapolis': 1}

# %%
ct
# Out:
#                              platformId  ...                     NER-title
# 0     1791654857736614_2699985123570245  ...                            {}
# 1     1481073582140028_2787886488125391  ...                            {}
# 2     2457084541029255_3911218202282541  ...                            {}
# 3      104914626218275_3165074630202244  ...                            {}
# 4      481275305234454_3775044389190846  ...                            {}
# ...                                 ...  ...                           ...
# 6238   341833139168802_3359091014109651  ...                            {}
# 6239   674764996035495_1534516946726958  ...                            {}
# 6240      28807649968_10151403362734969  ...                    {'NYC': 1}
# 6241   889555808073667_1168735133489065  ...                    {'NYC': 1}
# 6242    391196808388510_679376802903841  ...  {'D.C.': 1, 'Washington': 1}
#
# [6243 rows x 50 columns]

# %%
ct.to_csv('a0612.csv')

# %%
ct=pd.read_csv('a0612.csv',lineterminator='\n')

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#             NER-msg                  NER-desc       NER-title
# 1                {}        {'Minneapolis': 1}              {}
# 2  {'Minnesota': 1}        {'Minneapolis': 1}              {}
# 3                {}        {'Minneapolis': 1}              {}
# 4                {}        {'Minneapolis': 1}              {}
# 5                {}  {'HAMPTON': 1, 'Ga.': 1}  {'Atlanta': 1}

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ct_ner['NER-msg']
# Out:
# 1                                          []
# 2                                 [Minnesota]
# 3                                          []
# 4                                          []
# 5                                          []
#                         ...
# 6233                                 [Mequon]
# 6235                                       []
# 6240                                       []
# 6241    [Bayonne, Zelle, Socorro, St. Joseph]
# 6242                                       []
# Name: NER-msg, Length: 4190, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ct_ner['NER']
# Out:
# 1                                    [Minneapolis]
# 2                         [Minnesota, Minneapolis]
# 3                                    [Minneapolis]
# 4                                    [Minneapolis]
# 5                          [Ga., HAMPTON, Atlanta]
#                            ...
# 6233                              [Mequon, Mequon]
# 6235                        [Minneapolis, America]
# 6240                                         [NYC]
# 6241    [Bayonne, Zelle, Socorro, St. Joseph, NYC]
# 6242                            [Washington, D.C.]
# Name: NER, Length: 4190, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ner_lst = ct_ner['NER'].values

# %%
ner_lst
# Out:
# array([list(['minneapolis']), list(['minnesota', 'minneapolis']),
#        list(['minneapolis']), ..., list(['nyc']),
#        list(['zelle', 'nyc', 'socorro', 'st. joseph', 'bayonne']),
#        list(['washington', 'd.c.'])], dtype=object)

# %%
m=0
list=[]
for n in ner_lst:
  for i in range(len(n)):
    list.append(ner_lst[m][i])
  m+=1

# %%
list
# Out:
# ['minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'ga.',
#  'atlanta',
#  'hampton',
#  'ga.',
#  'atlanta',
#  'coronado',
#  'hampton',
#  'minneapolis',
#  'minneapolis',
#  'atlanta',
#  'jackson',
#  'conyers',
#  'covington',
#  'minneapolis',
#  'albuquerque',
#  'minneapolis',
#  'minneapolis',
#  'lake county',
#  'winter park',
#  'minneapolis',
#  'richland',
#  'dc',
#  'u.s.',
#  'dmv',
#  'minneapolis',
#  'richland',
#  'trenton',
#  'minneapolis',
#  'trenton',
#  'minneapolis',
#  'trenton',
#  'minneapolis',
#  'trenton',
#  'minneapolis',
#  'trenton',
#  'minneapolis',
#  'trenton',
#  'minneapolis',
#  'trenton',
#  'minneapolis',
#  'u.s.',
#  'belgium',
#  'cecil rhode',
#  'minneapolis',
#  'turkey',
#  'u.s.',
#  'istanbul',
#  'minneapolis',
#  'turkey',
#  'usa',
#  '@radiokingstonny',
#  'minneapolis',
#  'oakland',
#  'us',
#  '@oaklandartmurmur',
#  'turkey',
#  'minneapolis',
#  'oakland',
#  'us',
#  '@oaklandartmurmur',
#  'turkey',
#  'minneapolis',
#  'tx',
#  'houston',
#  'the united states',
#  'az',
#  'arizona',
#  'america',
#  'beavercreek',
#  'ohio',
#  'beavercreek',
#  'alexandria',
#  'ohio',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'jacksonville',
#  'westminster',
#  'louisville',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'belgium',
#  'u.s.',
#  'belgium',
#  'u.s.',
#  'belgium',
#  'pakistan',
#  'u.s.',
#  'belgium',
#  'riverdale',
#  'minneapolis',
#  'colorado',
#  'colorado',
#  'u.s.',
#  'rhode island',
#  'u.s.',
#  'u.s.',
#  'kentucky',
#  'texas',
#  'minneapolis',
#  'arlington',
#  'arlington',
#  'washington',
#  'denver',
#  'colorado',
#  'denver',
#  'oakland',
#  'portland',
#  'hollywood',
#  'orange county',
#  'minneapolis',
#  'california',
#  'new york city',
#  'r.i.',
#  'the state of rhode island',
#  'minneapolis',
#  "rhode island's",
#  'providence',
#  'rhode island',
#  'providence',
#  'minneapolis',
#  'yellow springs',
#  'ohio',
#  'wauwatosa',
#  'the united states',
#  'moscow',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'grand junction',
#  'minneapolis',
#  'grand junction',
#  'minneapolis',
#  'iowa',
#  'des moines',
#  'newport',
#  'minneapolis',
#  'iowa',
#  'des moines',
#  'black minneapolis',
#  'u.s.',
#  'los angeles sentinel',
#  'black minneapolis',
#  'u.s.',
#  'los angeles sentinel',
#  'minneapolis',
#  'minneapolis',
#  'vienna',
#  'minneapolis',
#  'pennsylvania',
#  'va.',
#  'minneapolis',
#  'u.s.',
#  'port chester',
#  'minneapolis',
#  'new york city',
#  'st. louis',
#  'miami',
#  'belgium',
#  'u.s.',
#  'pearland',
#  'houston',
#  'u.s.',
#  'dc',
#  'somalia',
#  'the united states',
#  'u.s.',
#  'kenya',
#  'minneapolis',
#  'america',
#  'st. paul',
#  'minneapolis',
#  'america',
#  'sydney',
#  'assemblymember sydney',
#  'alabama',
#  'birmingham',
#  'birmingham',
#  'ala.',
#  'bronx teen',
#  'bronx',
#  'new york',
#  'bronx teen',
#  'bronx',
#  'new york',
#  'bronx teen',
#  'new mexico',
#  'bronx',
#  'new york',
#  'tulsa',
#  'okla.',
#  'u.s.',
#  'new york',
#  'us',
#  'iran',
#  'america',
#  'new york',
#  'us',
#  'new york',
#  'us',
#  'new york',
#  'us',
#  'new york',
#  'seattle',
#  'tacoma',
#  'america',
#  'black lives',
#  'america',
#  'black lives',
#  'houston',
#  'minnesota',
#  'minnesota',
#  'utah',
#  'us',
#  'san antonio',
#  'minneapolis',
#  'yellow springs',
#  'georgia',
#  'memphis',
#  'the city of hartford',
#  'hartford',
#  'seattle',
#  'tacoma',
#  'st. paul',
#  'new movie',
#  'chicago',
#  'washington',
#  'iowa',
#  'new movie',
#  'new york city',
#  'detroit',
#  'new york city',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'usa',
#  'palau',
#  'yellow springs',
#  'the united states',
#  'america',
#  'new york',
#  'georgia',
#  'louisville',
#  'minneapolis',
#  'the united states',
#  'tampa',
#  'america',
#  'indianapolis',
#  'pittsburgh',
#  'pittsburgh',
#  'minneapolis',
#  'chicago',
#  'milwaukee',
#  'madison',
#  'pittsburgh',
#  'america',
#  'america',
#  'us',
#  'omaha',
#  'uk',
#  'tulsa',
#  'oklahoma',
#  'virginia beach',
#  'minneapolis',
#  'va.',
#  'denver',
#  'denver',
#  'belgium',
#  'the u. s.',
#  'u.s.',
#  'manhattan',
#  'minneapolis',
#  'los angeles',
#  'minnesota',
#  'minneapolis',
#  'america',
#  's.c.',
#  'u.s.',
#  'chicago',
#  'minneapolis',
#  'iowa',
#  'houston',
#  'us',
#  'chicago',
#  'baltimore',
#  'germantown',
#  'tacoma',
#  'san jose',
#  'new york',
#  'minneapolis',
#  'iowa',
#  'southwest louisiana',
#  'the united states',
#  'america',
#  'america',
#  'ireland',
#  '🏾louisville',
#  'brazil',
#  'us',
#  'buffalo',
#  'america',
#  'paris',
#  'berlin',
#  'greece',
#  'barcelona',
#  'athens',
#  'd.c.',
#  'new zealand',
#  'maryland',
#  'brussels',
#  'amsterdam',
#  'denmark',
#  'minneapolis',
#  'germany',
#  'france',
#  'boston',
#  'madrid',
#  'lauderdale',
#  'mexico',
#  'australia',
#  'jersey',
#  'spain',
#  'copenhagen',
#  'dublin',
#  'canada',
#  'ky',
#  'alabama',
#  'virginia',
#  'iran',
#  'new jersey',
#  'san francisco',
#  'hartford',
#  'doxxed',
#  'u.s.',
#  'new york city',
#  'new york city',
#  'rockdale',
#  'rockdale',
#  'alabama',
#  'rockdale',
#  'reno',
#  'america',
#  'minneapolis',
#  'ne',
#  'chicago',
#  'chicago',
#  'minneapolis',
#  'st. paul',
#  'ne',
#  'oklahoma',
#  'oklahoma',
#  'oklahoma',
#  'chicago',
#  'the u. s.',
#  'belgium',
#  'washington',
#  'united states',
#  'austin',
#  'minneapolis',
#  'texas',
#  'u.s.',
#  'california',
#  'oakland',
#  'u.s.',
#  'minn.',
#  'minneapolis',
#  'hennepin county',
#  'minneapolis',
#  'washington',
#  'new haven',
#  'america',
#  'washington',
#  'minneapolis',
#  'connecticut',
#  'ct',
#  'minnesota',
#  'minneapolis',
#  'connecticut',
#  'ct',
#  'minneapolis',
#  'connecticut',
#  'ct',
#  'walmart',
#  'minneapolis',
#  'minnesota',
#  'dania beach',
#  'miami',
#  'miami-dade',
#  'sacramento',
#  'california',
#  'los angeles',
#  'texas',
#  'minneapolis',
#  'america',
#  'america',
#  'des moines',
#  'iowa',
#  'america',
#  'america',
#  'new york city',
#  'oklahoma',
#  'u.s.',
#  'tulsa',
#  'greenwood',
#  'texas',
#  'black tulsa',
#  'burkina faso',
#  'new zealand',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'boston',
#  'boston',
#  'boston',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'little rock',
#  'darien',
#  'bristol county',
#  'darien',
#  'the city of everett',
#  'darien',
#  'pennsylvania',
#  'minneapolis',
#  'louisville',
#  'minneapolis',
#  'america',
#  'nc',
#  'charlotte',
#  'new york state',
#  'belle harbor',
#  'dracut',
#  'billerica',
#  'denver',
#  'denver',
#  'louisville',
#  'minneapolis',
#  'ky.',
#  'minneapolis',
#  'massachusetts',
#  '11:30am',
#  'america',
#  'colorado',
#  'beavercreek',
#  'ohio',
#  'toledo',
#  'toledo',
#  'tennessee',
#  'nashville',
#  'minnesota',
#  'u.s.',
#  'oklahoma',
#  'oklahoma',
#  'manhattan',
#  'new jersey',
#  'camden',
#  'los angeles',
#  'minneapolis',
#  'minneapolis',
#  'greenville',
#  'jersey city’s',
#  'shakoor',
#  'las vegas',
#  'dallas',
#  'america',
#  'minneapolis',
#  'seattle',
#  'brooklyn',
#  'baltimore',
#  'the united states',
#  'oklahoma',
#  'tulsa',
#  'minneapolis',
#  'america',
#  'baltimore',
#  'dallas',
#  'minnesota',
#  'st. louis',
#  'calif.',
#  'houston',
#  'minneapolis',
#  'new york city',
#  'america',
#  'houston',
#  'richmond',
#  'virginia',
#  'u.s.',
#  'atlanta',
#  'new york city',
#  'nj',
#  'the united states',
#  'minneapolis',
#  'camden',
#  'u.s.',
#  'belgium',
#  'denver',
#  'texas',
#  'arlington',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'the united states',
#  'los lunas',
#  'hampton',
#  'valencia county',
#  'new mexico',
#  'minneapolis',
#  'u.s.',
#  'minnesota',
#  'minneapolis',
#  '| riverbender.com',
#  'minneapolis',
#  'london',
#  'london',
#  'london',
#  'london',
#  'minneapolis',
#  'ohio',
#  'new york',
#  'south jersey',
#  'voorhees township',
#  'new jersey',
#  'minneapolis',
#  'minneapolis',
#  'st. luke’s',
#  'st. luke’s health system',
#  'arkansas',
#  'christena cleveland',
#  'new york',
#  'virginia beach',
#  'north carolina',
#  'minneapolis',
#  'the united states',
#  'stone park',
#  'chicagoland',
#  'tampa',
#  'minneapo',
#  'colorado springs',
#  'minneapolis',
#  'colorado',
#  'new york',
#  'minneapo',
#  'colorado springs',
#  'minneapolis',
#  'colorado',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'new jersey',
#  'minnesota',
#  'new jersey',
#  'new jersey',
#  'brooklyn park community meeting',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'united states of america',
#  'portland',
#  'oregon',
#  'the united states',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'the city of pittsburgh',
#  'pittsburgh',
#  'denver',
#  'oakland',
#  'america',
#  'tempe',
#  'america',
#  'chambersburg borough',
#  'tempe',
#  'chambersburg',
#  'minneapolis',
#  'minneapolis',
#  'ohio',
#  'beavercreek',
#  'minneapolis',
#  'minneapolis',
#  'us',
#  'hong kong',
#  "hong kong's",
#  'us',
#  'hong kong',
#  'houston',
#  'minneapolis',
#  'minneapolis',
#  'the united states',
#  'america',
#  'bandier',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'the city of orange',
#  'minneapolis',
#  'minneapolis',
#  'dallas',
#  'iu',
#  'michigan',
#  'grand rapids',
#  'casper',
#  'minneapolis',
#  'casper',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'la',
#  'minneapolis',
#  'n.y.',
#  'n.y.',
#  'vyla',
#  'dallas',
#  'n.y.',
#  'https://www.localmemphis.com/article/news/nation-world/historical-figures-reassessed-around-globe/507-bf3ab353-f60e-46ec-b875-f076533c0ce0',
#  'belgium',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'minneapolis',
#  'charlotte',
#  'n.c.',
#  'charlotte',
#  'us',
#  'oklahoma',
#  'j.u.s.t.i.c.e.',
#  'oklahoma',
#  'minneapolis',
#  'washington',
#  'america"—just',
#  'america',
#  'minn.',
#  'perris city',
#  'america',
#  'washington',
#  'seattle',
#  'u.s.',
#  'belgium',
#  'u.s.',
#  'belgium',
#  'u.s.',
#  'belgium',
#  'minneapolis',
#  'texas',
#  'texas',
#  'texas',
#  'minneapolis',
#  'chicago',
#  'ny',
#  'new york',
#  'inglewood',
#  'the united states',
#  'america',
#  'minnesota',
#  'america',
#  'new orleans',
#  'minneapolis',
#  'philadelphia',
#  'houston',
#  'minneapolis',
#  'north/south dakota',
#  'usa',
#  'minneapolis',
#  'chicago ave',
#  'minneapolis',
#  'washington',
#  'seattle',
#  'tacoma',
#  'minneapolis',
#  'oakland',
#  'san jose',
#  'seattle',
#  'des moines',
#  'iowa',
#  'oakland',
#  'new york city',
#  'america',
#  'minneapolis',
#  "bastrop county's",
#  'u.s.',
#  'bastrop',
#  'minneapolis',
#  'texas',
#  'south carolina',
#  'bastrop county',
#  'america',
#  'minnesota',
#  'minneapolis',
#  'hennepin county',
#  'georgia',
#  'minneapolis',
#  'king county',
#  'minneapolis',
#  '| city',
#  'minneapolis',
#  'minneapolis',
#  'belgium',
#  'chicago',
#  'minneapolis',
#  'usc',
#  'california',
#  'richmond',
#  'ark.',
#  'phoenix',
#  'minneapolis',
#  'britain',
#  'bristol',
#  'the united states',
#  'standing rock',
#  'u.s.',
#  'belleville',
#  'kendall',
#  'minneapolis',
#  'ky',
#  'mn',
#  'louisville',
#  'wisconsin',
#  'mississippi',
#  'wi',
#  'san francisco',
#  'seattle',
#  'u.s.',
#  'utah',
#  'utah',
#  'utah',
#  'the united states',
#  'the united states',
#  'minneapolis',
#  'minnesota',
#  'columbus',
#  'vegas',
#  'eugene',
#  'ore.',
#  'monroe',
#  'jefferson park',
#  'charlotte',
#  'fairbanks',
#  'the united states',
#  'pflag',
#  'mt. horeb',
#  'brix',
#  'america',
#  'wisconsin',
#  'new york',
#  '#newyork',
#  'maryland',
#  'elgin city',
#  'minneapolis',
#  'elgin city',
#  'elgin city',
#  'massachusetts',
#  'minneapolis',
#  'pensacola',
#  'pensacola',
#  'fla.',
#  'us',
#  'pensacola',
#  'pensacola',
#  'fla.',
#  'pensacola',
#  'pensacola',
#  'fla.',
#  'minnesota',
#  'minneapolis',
#  'u.s.',
#  'west palm beach',
#  'us',
#  'the city of west palm beach',
#  'palm beach county',
#  'west palm beach',
#  'milwaukee',
#  'u.s.',
#  'milwaukee',
#  'u.s.',
#  'milwaukee',
#  'milwaukee',
#  'windsor',
#  'black',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'nevada',
#  'virginia beach',
#  'va.',
#  'virginia beach',
#  'va.',
#  'virginia beach',
#  'rome',
#  'vietnam',
#  'va.',
#  'cook county',
#  'evanston',
#  'illinois',
#  'minneapolis',
#  'rochester',
#  'minneapolis',
#  'rochester',
#  'u.s.',
#  'minneapolis',
#  'georgia',
#  'atlanta',
#  'america',
#  'georgia',
#  'hollywood',
#  'birocratic',
#  'minneapolis',
#  'u.s.',
#  'tooele county',
#  'minneapolis',
#  'u.s.',
#  'ogden',
#  'u.s.',
#  'tallahassee',
#  'minneapolis',
#  'kentucky',
#  'louisville',
#  'florida',
#  'minnesota',
#  'oklahoma city',
#  'minn.',
#  'minneapolis',
#  'fort lauderdale',
#  'minneapolis',
#  'alexandria',
#  'virginia',
#  'us',
#  'us',
#  'waterbury',
#  'us',
#  'us',
#  'us',
#  'ohio',
#  'us',
#  'minneapolis',
#  'u.s.',
#  'new york',
#  'america',
#  'minneapolis',
#  'tampa bay',
#  'texas',
#  'minneapolis',
#  'houston',
#  'acluohio',
#  'ohio montgomery county',
#  'dayton',
#  'oakwood',
#  'ohio',
#  'kettering',
#  '💪 oakwood',
#  'boston',
#  'boston',
#  'stamford',
#  'boston',
#  'minneapolis',
#  'u.s.',
#  'rhode island',
#  'u.s.',
#  'rhode island',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'minneapolis',
#  'washington',
#  'columbus',
#  'miami',
#  'columbus',
#  'miami',
#  'columbus',
#  'miami',
#  'minnesota',
#  'without.2 media',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'the united states',
#  'america',
#  'america',
#  'wilmington',
#  'the united states',
#  'denver',
#  'denver',
#  'the united states',
#  'shawnee park',
#  'new york',
#  'minnesota',
#  '🇸',
#  'new city',
#  'u.s.',
#  'new zealand',
#  'minnesota',
#  'mcghie',
#  'duluth',
#  'new zealand',
#  'new zealand',
#  'minneapolis',
#  'baltimore county',
#  'minneapolis',
#  'baltimore county',
#  'baltimore county',
#  'minneapolis',
#  'the great saharan',
#  'texas',
#  'minneapolis',
#  'baltimore county',
#  'brownwood',
#  'minneapolis',
#  'texas',
#  'bakersfield',
#  'el paso',
#  'california',
#  'calif.',
#  'california',
#  'roanoke',
#  'california',
#  'chicago',
#  'the united states',
#  'u.s.cities',
#  'missouri',
#  'ferguson',
#  'henderson county',
#  'minneapolis',
#  'minnesota',
#  'minnesota',
#  'u.s.',
#  'mississippi',
#  'ohio',
#  'hollywood',
#  'shelby county',
#  'the united states',
#  'california',
#  'america',
#  'chino',
#  'our united states of america',
#  'america',
#  'chino',
#  'california',
#  'm.d.',
#  'charlotte',
#  'n.c.',
#  'minneapolis',
#  'philando castile',
#  'minneapolis',
#  'atlanta',
#  'minneapolis',
#  'louisville',
#  'kentucky',
#  'louisville',
#  'atlanta',
#  'minneapolis',
#  'los angeles',
#  'the city of los angeles',
#  'atlanta',
#  'texas',
#  'dallas',
#  'seattle',
#  'tacoma',
#  'mn',
#  'minneapolis',
#  'putnam county',
#  'putnam county',
#  'the united states',
#  'minneapolis',
#  'putnam county',
#  'america',
#  'ames',
#  'iowa',
#  'huntington',
#  'vermont',
#  'putnam county',
#  '#putnamcounty',
#  'putnam county',
#  'putnam county',
#  'georgia',
#  'putnam county',
#  'atlanta',
#  ...]

# %%
c = collections.Counter()

# %%
dict_a=collections.Counter(list).most_common()

# %%
dict_a
# Out:
# [('minneapolis', 1428),
#  ('america', 424),
#  ('minnesota', 379),
#  ('u.s.', 370),
#  ('the united states', 220),
#  ('us', 183),
#  ('new york', 157),
#  ('washington', 149),
#  ('seattle', 139),
#  ('texas', 122),
#  ('houston', 97),
#  ('ohio', 94),
#  ('california', 92),
#  ('chicago', 83),
#  ('philadelphia', 73),
#  ('denver', 67),
#  ('louisville', 62),
#  ('belgium', 58),
#  ('new york city', 58),
#  ('los angeles', 56),
#  ('dallas', 55),
#  ('georgia', 44),
#  ('pittsburgh', 44),
#  ('florida', 44),
#  ('boston', 42),
#  ('antifa', 42),
#  ('atlanta', 37),
#  ('illinois', 37),
#  ('new jersey', 36),
#  ('d.c.', 35),
#  ('virginia', 35),
#  ('iowa', 32),
#  ('tulsa', 32),
#  ('san francisco', 32),
#  ('oakland', 31),
#  ('wisconsin', 31),
#  ('portland', 30),
#  ('milwaukee', 30),
#  ('north carolina', 29),
#  ('minneapo', 29),
#  ('columbus', 27),
#  ('oklahoma', 26),
#  ('richmond', 26),
#  ('uk', 25),
#  ('minn.', 25),
#  ('calif.', 25),
#  ('dc', 24),
#  ('alabama', 24),
#  ('charlotte', 23),
#  ('nyc', 23),
#  ('new zealand', 22),
#  ('las vegas', 22),
#  ('albany', 22),
#  ('miami', 21),
#  ('st. paul', 21),
#  ('manhattan', 21),
#  ('france', 20),
#  ('south carolina', 20),
#  ('colorado', 19),
#  ('pennsylvania', 19),
#  ('baltimore', 19),
#  ('buffalo', 19),
#  ('kentucky', 18),
#  ('tacoma', 18),
#  ('nc', 18),
#  ('san diego', 18),
#  ('orlando', 18),
#  ('yellow springs', 17),
#  ('detroit', 17),
#  ('maryland', 17),
#  ('england', 17),
#  ('va.', 16),
#  ('utah', 16),
#  ('tennessee', 16),
#  ('michigan', 16),
#  ('cleveland', 16),
#  ('washington, dc', 16),
#  ('fort worth', 16),
#  ('arizona', 15),
#  ('beavercreek', 15),
#  ('hollywood', 15),
#  ('brooklyn', 15),
#  ('philando castile', 15),
#  ('arlington', 14),
#  ('birmingham', 14),
#  ('paris', 14),
#  ('mn', 14),
#  ('|', 14),
#  ('memphis', 13),
#  ('sacramento', 13),
#  ('ill.', 13),
#  ('des moines', 12),
#  ('berlin', 12),
#  ('brussels', 12),
#  ('new york state', 12),
#  ('ky.', 12),
#  ('massachusetts', 12),
#  ('nj', 12),
#  ('london', 12),
#  ('n.y.', 12),
#  ('mississippi', 12),
#  ('delaware', 12),
#  ('capitol hill autonomous zone', 12),
#  ('long beach', 12),
#  ('galesburg', 12),
#  ('usa', 11),
#  ('germany', 11),
#  ('nashville', 11),
#  ('china', 11),
#  ('jackson', 10),
#  ('rhode island', 10),
#  ('st. louis', 10),
#  ('bronx', 10),
#  ('oregon', 10),
#  ('new orleans', 10),
#  ('phoenix', 10),
#  ('tallahassee', 10),
#  ('el paso', 10),
#  ('brazil', 9),
#  ('mexico', 9),
#  ('hennepin county', 9),
#  ('ct', 9),
#  ('palm beach county', 9),
#  ('baltimore county', 9),
#  ('missouri', 9),
#  ('dallas county', 9),
#  ('north dallas', 9),
#  ('kansas city', 9),
#  ('south africa', 9),
#  ('jordan', 9),
#  ('fla', 9),
#  ('verona', 9),
#  ('new mexico', 8),
#  ('united states', 8),
#  ('austin', 8),
#  ('connecticut', 8),
#  ('arkansas', 8),
#  ('la', 8),
#  ('nevada', 8),
#  ('putnam county', 8),
#  ('vermont', 8),
#  ('russia', 8),
#  ('bloomington', 8),
#  ('washington park', 8),
#  ('the united kingdom', 8),
#  ('montgomery', 8),
#  ('cincinnati', 8),
#  ('baton rouge', 8),
#  ('wash.', 8),
#  ('hampton', 7),
#  ('albuquerque', 7),
#  ('trenton', 7),
#  ('alexandria', 7),
#  ('madison', 7),
#  ('virginia beach', 7),
#  ('the u. s.', 7),
#  ('athens', 7),
#  ('australia', 7),
#  ('canada', 7),
#  ('camden', 7),
#  ('ny', 7),
#  ('pensacola', 7),
#  ('fort lauderdale', 7),
#  ('wilmington', 7),
#  ('oxford', 7),
#  ('tenn.', 7),
#  ('springfield', 7),
#  ('japan', 7),
#  ('charleston', 7),
#  ('fayetteville', 7),
#  ('milwaukee city', 7),
#  ('new milwaukee city', 7),
#  ('south florida', 7),
#  ('cedar rapids', 7),
#  ('auckland', 7),
#  ('erie', 7),
#  ('burien', 7),
#  ('orange county', 6),
#  ('providence', 6),
#  ('tampa', 6),
#  ('ireland', 6),
#  ('greece', 6),
#  ('amsterdam', 6),
#  ('denmark', 6),
#  ('lauderdale', 6),
#  ('jersey', 6),
#  ('spain', 6),
#  ('ky', 6),
#  ('walmart', 6),
#  ('king county', 6),
#  ('ark.', 6),
#  ('south dakota', 6),
#  ('los angeles county', 6),
#  ('israel', 6),
#  ('https://www.hollywoodreporter.com/news/spike-lee-cautions-defund-police-message-warning-trump-tries-twist-narrative-1297908',
#   6),
#  ('englewood', 6),
#  ('u.s', 6),
#  ('charlottesville', 6),
#  ('tucson', 6),
#  ('wauwatosa', 5),
#  ('los angeles sentinel', 5),
#  ('okla.', 5),
#  ('hartford', 5),
#  ('barcelona', 5),
#  ('madrid', 5),
#  ('copenhagen', 5),
#  ('dublin', 5),
#  ('colorado springs', 5),
#  ('rochester', 5),
#  ('waterbury', 5),
#  ('duluth', 5),
#  ('va', 5),
#  ('manchester', 5),
#  ('lowell', 5),
#  ('accra', 5),
#  ('ghana', 5),
#  ('afghanistan', 5),
#  ('iraq', 5),
#  ('south minneapolis', 5),
#  ('dakota', 5),
#  ('columbus city', 5),
#  ('jr.', 5),
#  ('alaska', 5),
#  ('puerto rico', 5),
#  ('palestine', 5),
#  ('wausau', 5),
#  ('north philly', 5),
#  ('east hartford', 5),
#  ('binnish', 5),
#  ('poland', 5),
#  ('the united states of america', 5),
#  ('coachella valley', 5),
#  ('canton', 5),
#  ('ga.', 4),
#  ('turkey', 4),
#  ('jacksonville', 4),
#  ('r.i.', 4),
#  ('ala.', 4),
#  ('indianapolis', 4),
#  ('omaha', 4),
#  ('s.c.', 4),
#  ('rockdale', 4),
#  ('greenwood', 4),
#  ('greenville', 4),
#  ('st. luke’s', 4),
#  ('st. luke’s health system', 4),
#  ('hong kong', 4),
#  ('casper', 4),
#  ('n.c.', 4),
#  ('bristol', 4),
#  ('monroe', 4),
#  ('fla.', 4),
#  ('dayton', 4),
#  ('bakersfield', 4),
#  ('shelby county', 4),
#  ('la.', 4),
#  ('north county', 4),
#  ('jwu', 4),
#  ('dakota bright', 4),
#  ('su madre', 4),
#  ('manipulación de testigos', 4),
#  ('el lugar de su asesinato para escuchar', 4),
#  ('washington park y', 4),
#  ('la alianza de chicago', 4),
#  ('las demandas de los organizadores estudiantiles para que la universidad elimine',
#   4),
#  ('black southside', 4),
#  ('flint farmer', 4),
#  ('por el departamento de policía de la universidad de chicago', 4),
#  ('| camden', 4),
#  ('paniagua', 4),
#  ('washington dc', 4),
#  ('santa rosa', 4),
#  ('maine', 4),
#  ('new bern', 4),
#  ('daytona beach', 4),
#  ('galveston', 4),
#  ('minn', 4),
#  ('āluli', 4),
#  ('kūpuna', 4),
#  ('abq', 4),
#  ('third ward', 4),
#  ('whitefish', 4),
#  ('•', 4),
#  ('district', 4),
#  ('juneteenth', 4),
#  ('the city of cedar rapids', 4),
#  ("los angeles's", 4),
#  ('louisiana', 4),
#  ('mexico city', 4),
#  ('syria', 4),
#  ('osage ave', 4),
#  ('maricopa county', 4),
#  ('india', 4),
#  ('santa monica', 4),
#  ('martinsburg', 4),
#  ('reston', 4),
#  ('lakewood', 4),
#  ('the city of waterbury', 4),
#  ('tx', 3),
#  ('grand junction', 3),
#  ('newport', 3),
#  ('pearland', 3),
#  ('kenya', 3),
#  ('sydney', 3),
#  ('bronx teen', 3),
#  ('reno', 3),
#  ('darien', 3),
#  ('tempe', 3),
#  ('grand rapids', 3),
#  ('north/south dakota', 3),
#  ('britain', 3),
#  ('standing rock', 3),
#  ('wi', 3),
#  ('vegas', 3),
#  ('ore.', 3),
#  ('elgin city', 3),
#  ('rome', 3),
#  ('vietnam', 3),
#  ('oklahoma city', 3),
#  ('m.d.', 3),
#  ('ames', 3),
#  ('city', 3),
#  ('centre county', 3),
#  ('boise', 3),
#  ('idaho', 3),
#  ('the north miami campus', 3),
#  ('elkhart', 3),
#  ('san francisco’s', 3),
#  ('black wake county', 3),
#  ('the city of walker', 3),
#  ('midland', 3),
#  ('woodstock', 3),
#  ('columbia', 3),
#  ('salem', 3),
#  ("st. luke's", 3),
#  ('helena', 3),
#  ('lafayette park', 3),
#  ('richfield', 3),
#  ('shreveport', 3),
#  ('west virginia', 3),
#  ('portsmouth', 3),
#  ('l.a.', 3),
#  ('jersey city', 3),
#  ('waukesha', 3),
#  ('st. john’s', 3),
#  ('napa', 3),
#  ('tn', 3),
#  ('spokane', 3),
#  ('fort snelling', 3),
#  ('riverside county', 3),
#  ('st. clair shores', 3),
#  ('springtown', 3),
#  ('n.j.', 3),
#  ('powderhorn', 3),
#  ('new york’s', 3),
#  ('wales', 3),
#  ('newton', 3),
#  ('wv', 3),
#  ('walnut', 3),
#  ('vt', 3),
#  ('calvert county', 3),
#  ('oakland county', 3),
#  ('harris county', 3),
#  ('chattanooga', 3),
#  ('the arizona republic', 3),
#  ('norwalk', 3),
#  ('west springfield', 3),
#  ('mass.', 3),
#  ('fort myers', 3),
#  ('saugus', 3),
#  ('venezuela', 3),
#  ('egypt', 3),
#  ('county', 3),
#  ('marion county', 3),
#  ('alexanderplatz', 3),
#  ("south carolina's", 3),
#  ('thailand', 3),
#  ('desert ride', 3),
#  ('palm springs', 3),
#  ('y’', 3),
#  ('liberty township', 3),
#  ('cape town', 3),
#  ('north philadelphia', 3),
#  ('judicial district', 3),
#  ('deutschland', 3),
#  ('richland', 2),
#  ('@oaklandartmurmur', 2),
#  ('az', 2),
#  ('westminster', 2),
#  ('pakistan', 2),
#  ('black minneapolis', 2),
#  ('iran', 2),
#  ('black lives', 2),
#  ('san antonio', 2),
#  ('new movie', 2),
#  ('san jose', 2),
#  ('southwest louisiana', 2),
#  ('ne', 2),
#  ('new haven', 2),
#  ('miami-dade', 2),
#  ('burkina faso', 2),
#  ('little rock', 2),
#  ('toledo', 2),
#  ('los lunas', 2),
#  ('valencia county', 2),
#  ('south jersey', 2),
#  ('chambersburg borough', 2),
#  ('chambersburg', 2),
#  ('chicago ave', 2),
#  ('bastrop', 2),
#  ('| city', 2),
#  ('belleville', 2),
#  ('kendall', 2),
#  ('eugene', 2),
#  ('jefferson park', 2),
#  ('west palm beach', 2),
#  ('oakwood', 2),
#  ('shawnee park', 2),
#  ('🇸', 2),
#  ('mcghie', 2),
#  ('chino', 2),
#  ('huntington', 2),
#  ('#putnamcounty', 2),
#  ('bradenton', 2),
#  ('jerusalem', 2),
#  ('holy city', 2),
#  ('south bend', 2),
#  ('brunswick', 2),
#  ('cobb county', 2),
#  ('the queen city', 2),
#  ('philipsburg', 2),
#  ('camden county', 2),
#  ('worcester', 2),
#  ('ashland', 2),
#  ('minnea', 2),
#  ('lutheran', 2),
#  ('mcallen', 2),
#  ('hidalgo county', 2),
#  ('victorville', 2),
#  ('missoula', 2),
#  ('seniormost', 2),
#  ('sd', 2),
#  ('gettysburg', 2),
#  ('rapid city', 2),
#  ('new york city’s', 2),
#  ('cuyahoga county', 2),
#  ('philippines', 2),
#  ('\u2063', 2),
#  ('the city of seattle', 2),
#  ('lansing', 2),
#  ('douglas county', 2),
#  ('beaver county', 2),
#  ('mastic beach', 2),
#  ('edinburg', 2),
#  ('varnum ne', 2),
#  ('brookland', 2),
#  ("st. mark's", 2),
#  ('nw', 2),
#  ("st. mary's", 2),
#  ('st. joseph’s', 2),
#  ('cleveland park congregational', 2),
#  ('edlavitch', 2),
#  ('washington dc\n', 2),
#  ('st. petersburg', 2),
#  ('east brunswick', 2),
#  ('franklin township', 2),
#  ('kingdom', 2),
#  ('murfreesboro', 2),
#  ('uptown charlotte', 2),
#  ('vt.', 2),
#  ('burlington', 2),
#  ('metro detroit', 2),
#  ('donkeeboy', 2),
#  ('carrollton', 2),
#  ('the west bank', 2),
#  ('md', 2),
#  ('park ridge', 2),
#  ('aurora', 2),
#  ('rhine', 2),
#  ('brookfield', 2),
#  ('salisbury', 2),
#  ('bixby knolls', 2),
#  ('white minneapolis', 2),
#  ('metrowest', 2),
#  ('union county', 2),
#  ('fn rock', 2),
#  ('barbados', 2),
#  ('the united states’', 2),
#  ('mequon', 2),
#  ('halsted', 2),
#  ('belmont', 2),
#  ('drag queens', 2),
#  ('lakeview chicago', 2),
#  ('boystown', 2),
#  ('kings', 2),
#  ('toa baja', 2),
#  ('the city of alexandria', 2),
#  ('iine', 2),
#  ('north charleston', 2),
#  ('glenview', 2),
#  ('juneteen', 2),
#  ('sioux', 2),
#  ('their"more pe', 2),
#  ('netherlands', 2),
#  ('the confederate states of america', 2),
#  ('d-n.y.', 2),
#  ('everett', 2),
#  ('wuhan', 2),
#  ('god touch milwaukee', 2),
#  ('salt lake city', 2),
#  ('bethlehem', 2),
#  ('italy', 2),
#  ('oxnard', 2),
#  ('morgantown', 2),
#  ('w.va.', 2),
#  ('stillwater mn', 2),
#  ('staten island', 2),
#  ('newark', 2),
#  ('de pere', 2),
#  ('wis.', 2),
#  ('medina', 2),
#  ('malden', 2),
#  ('fort bragg', 2),
#  ('roc', 2),
#  ('colchester', 2),
#  ('southfield', 2),
#  ('the scenic city', 2),
#  ('fargo', 2),
#  ('lancaster', 2),
#  ('east bakersfield', 2),
#  ('south hills', 2),
#  ('delray beach', 2),
#  ('the city of lowell', 2),
#  ('media', 2),
#  ('andrews park', 2),
#  ('north minneapolis', 2),
#  ('berkeley', 2),
#  ('https://www.lionbrand.com/collections/paid-patterns', 2),
#  ('downtown memphis', 2),
#  ('buffalo n.y.', 2),
#  ('antwerp', 2),
#  ('cuba', 2),
#  ('richland county', 2),
#  ('the city of wilmington', 2),
#  ('libya', 2),
#  ('the west indies', 2),
#  ('may.', 2),
#  ('pa.', 2),
#  ('west los angeles', 2),
#  ('socalgas', 2),
#  ('san fernando valley', 2),
#  ('pláticas', 2),
#  ('el link de zoom', 2),
#  ('porter ranch', 2),
#  ('cuándo', 2),
#  ('respirar', 2),
#  ('los ángeles', 2),
#  ('aprender', 2),
#  ('mass', 2),
#  ('topeka', 2),
#  ('san angelo', 2),
#  ('pulse orlando', 2),
#  ('the massachusetts jobs', 2),
#  ('massachusetts jobs', 2),
#  ('district 3', 2),
#  ('palm beach county commission', 2),
#  ('mesa county', 2),
#  ('new', 2),
#  ('jamaica', 2),
#  ('westminster village', 2),
#  ('winston-salem', 2),
#  ('mobile', 2),
#  ('indio city', 2),
#  ('desert hot springs city council', 2),
#  ('larimer', 2),
#  ('park', 2),
#  ('colfax', 2),
#  ('u.k.', 2),
#  ('scotland', 2),
#  ('walker', 2),
#  ('harrisburg', 2),
#  ('tel aviv', 2),
#  ('hampton roads', 2),
#  ('wwhl', 2),
#  ('northern virginia', 2),
#  ('playworks dc\n', 2),
#  ('northshore', 2),
#  ('racine', 2),
#  ('warren', 2),
#  ('riverside park', 2),
#  ('providence village', 2),
#  ('providence united for peace\nprovidence united', 2),
#  ('https://umass-amherst.zoom.us/webinar/register/wn_7b3dcjggqvo75wtcl0kb5q',
#   2),
#  ('jesuit', 2),
#  ('mecca', 2),
#  ('liberia', 2),
#  ('santa clara county', 2),
#  ('del.', 2),
#  ('fort wayne', 2),
#  ('selma', 2),
#  ('butler county', 2),
#  ('west philly', 2),
#  ('racisme', 2),
#  ('armoede', 2),
#  ('mensen', 2),
#  ('zwolle', 2),
#  ('emmeloord', 2),
#  ('baudet', 2),
#  ('krullende', 2),
#  ('opgehitst.', 2),
#  ('geretweet', 2),
#  ('thuis', 2),
#  ('twitterden anderen', 2),
#  ('nederland', 2),
#  ('politiegeweld', 2),
#  ('riverside', 2),
#  ("bronx teen's", 2),
#  ('brevard county', 2),
#  ('livermore', 2),
#  ('norway', 2),
#  ('n. carolina', 2),
#  ('the north carolina coronavirus task force', 2),
#  ('olympia', 2),
#  ('margari hill', 2),
#  ('fresno', 2),
#  ('coronado', 1),
#  ('conyers', 1),
#  ('covington', 1),
#  ('lake county', 1),
#  ('winter park', 1),
#  ('dmv', 1),
#  ('cecil rhode', 1),
#  ('istanbul', 1),
#  ('@radiokingstonny', 1),
#  ('riverdale', 1),
#  ('the state of rhode island', 1),
#  ("rhode island's", 1),
#  ('moscow', 1),
#  ('vienna', 1),
#  ('port chester', 1),
#  ('somalia', 1),
#  ('assemblymember sydney', 1),
#  ('the city of hartford', 1),
#  ('palau', 1),
#  ('germantown', 1),
#  ('🏾louisville', 1),
#  ('doxxed', 1),
#  ('dania beach', 1),
#  ('black tulsa', 1),
#  ('bristol county', 1),
#  ('the city of everett', 1),
#  ('belle harbor', 1),
#  ('dracut', 1),
#  ('billerica', 1),
#  ('11:30am', 1),
#  ('jersey city’s', 1),
#  ('shakoor', 1),
#  ('| riverbender.com', 1),
#  ('voorhees township', 1),
#  ('christena cleveland', 1),
#  ('stone park', 1),
#  ('chicagoland', 1),
#  ('brooklyn park community meeting', 1),
#  ('united states of america', 1),
#  ('the city of pittsburgh', 1),
#  ("hong kong's", 1),
#  ('bandier', 1),
#  ('the city of orange', 1),
#  ('iu', 1),
#  ('vyla', 1),
#  ('https://www.localmemphis.com/article/news/nation-world/historical-figures-reassessed-around-globe/507-bf3ab353-f60e-46ec-b875-f076533c0ce0',
#   1),
#  ('j.u.s.t.i.c.e.', 1),
#  ('america"—just', 1),
#  ('perris city', 1),
#  ('inglewood', 1),
#  ("bastrop county's", 1),
#  ('bastrop county', 1),
#  ('usc', 1),
#  ('fairbanks', 1),
#  ('pflag', 1),
#  ('mt. horeb', 1),
#  ('brix', 1),
#  ('#newyork', 1),
#  ('the city of west palm beach', 1),
#  ('windsor', 1),
#  ('black', 1),
#  ('cook county', 1),
#  ('evanston', 1),
#  ('birocratic', 1),
#  ('tooele county', 1),
#  ('ogden', 1),
#  ('tampa bay', 1),
#  ('acluohio', 1),
#  ('ohio montgomery county', 1),
#  ('kettering', 1),
#  ('💪 oakwood', 1),
#  ('stamford', 1),
#  ('without.2 media', 1),
#  ('new city', 1),
#  ('the great saharan', 1),
#  ('brownwood', 1),
#  ('roanoke', 1),
#  ('u.s.cities', 1),
#  ('ferguson', 1),
#  ('henderson county', 1),
#  ('our united states of america', 1),
#  ('the city of los angeles', 1),
#  ('u.s.a.', 1),
#  ('kogo', 1),
#  ('taiwan', 1),
#  ('st. charles', 1),
#  ('little rock afb', 1),
#  ('utica', 1),
#  ('central new york', 1),
#  ('alachua county', 1),
#  ('esq.', 1),
#  ('colorado ave', 1),
#  ('bridgeport', 1),
#  ('the north county beat', 1),
#  ('north county san diego', 1),
#  ('the north county beat podcast', 1),
#  ("north county's", 1),
#  ('peace', 1),
#  ('miami beach', 1),
#  ('a cook county', 1),
#  ('http://www.americanuckradio.com/blog/2020/6/12/school-launches-investigation-into-teacher-who-said-the-term-white-privilege-is-as-racist-as-the-n-word',
#   1),
#  ('la jolla - peaceful', 1),
#  ('mid-city', 1),
#  ('st. ignatius', 1),
#  ('skokie', 1),
#  ('allegheny', 1),
#  ('butler', 1),
#  ('akufo-addo', 1),
#  ('chandler park', 1),
#  ('gahanna', 1),
#  ('the city of cleveland', 1),
#  ('mt. pleasant', 1),
#  ('union', 1),
#  ('jax', 1),
#  ('rv', 1),
#  ('ne portland', 1),
#  ('boston city', 1),
#  ('chimacum', 1),
#  ('finnriver', 1),
#  ('jefferson county', 1),
#  ('washington state', 1),
#  ('covid', 1),
#  ('jefferson county anti-racist fund', 1),
#  ('minneapolisand', 1),
#  ('compton', 1),
#  ('palm beach', 1),
#  ('springfield city', 1),
#  ('bay village’s', 1),
#  ('middleburg heights', 1),
#  ('newburg heights', 1),
#  ('fairview park’s', 1),
#  ('westlake', 1),
#  ('\u2063 vallejo', 1),
#  ('vallejo police', 1),
#  ('vallejo pd', 1),
#  ('christ', 1),
#  ('myrtle beach', 1),
#  ('macon', 1),
#  ('gainesville', 1),
#  ('burnham', 1),
#  ('lynwood', 1),
#  ('tf north', 1),
#  ('calumet city', 1),
#  ('maple ave', 1),
#  ('warren park', 1),
#  ('the island city', 1),
#  ('guatemala y', 1),
#  ('guatemala - nómada', 1),
#  ('guatemala', 1),
#  ('waterloo', 1),
#  ('acps', 1),
#  ('washington d.c.', 1),
#  ('rewind', 1),
#  ('a.k.a', 1),
#  ('cameron)--milam county', 1),
#  ('angleton', 1),
#  ('new rochelle', 1),
#  ('the capital hill autonomous zone', 1),
#  ('west philadelphia', 1),
#  ('sarver', 1),
#  ('latino usa', 1),
#  ('zurich', 1),
#  ('greenville county', 1),
#  ('guide', 1),
#  ('greenville south carolina', 1),
#  ('upstate', 1),
#  ('new york&#821', 1),
#  ('savannah', 1),
#  ('st. rose', 1),
#  ('lima', 1),
#  ('arverne', 1),
#  ('wikimedia', 1),
#  ('new york city - brandon sullivan', 1),
#  ('linn county', 1),
#  ('buffalo ny', 1),
#  ('hidatsa', 1),
#  ('navajo', 1),
#  ('lummi', 1),
#  ('mandan', 1),
#  ('assiniboine', 1),
#  ('hunkpapa', 1),
#  ('keweenaw', 1),
#  ('lakota', 1),
#  ('arikara', 1),
#  ('fond du lac', 1),
#  ('hampshire', 1),
#  ('granby', 1),
#  ('greenwood district', 1),
#  ('oakdale', 1),
#  ('walker field', 1),
#  ('marathon county', 1),
#  ('st. paul city', 1),
#  ('conway', 1),
#  ('portage park', 1),
#  ('45th ward', 1),
#  ("the district attorney's office", 1),
#  ('captial hill autonomous zone', 1),
#  ('stratford', 1),
#  ('south jersey’s', 1),
#  ('district superintendent', 1),
#  ('guam', 1),
#  ('the kingdom of god', 1),
#  ('bahamas', 1),
#  ('cal berkeley', 1),
#  ('bloomfield', 1),
#  ('the madhesi people of nepal', 1),
#  ('bhutan', 1),
#  ('nepal', 1),
#  ('llc', 1),
#  ('civil eats', 1),
#  ('new hampshire', 1),
#  ('peduto', 1),
#  ('thu', 1),
#  ('westchester', 1),
#  ('https://www.ghostcultmag.com/rage-against-the-machines-debut-album-returns-to-the-billboard-200-charts-on-the-strength-of-global-protests/',
#   1),
#  ('towson', 1),
#  ('blue', 1),
#  ('prc', 1),
#  ('philly socfem', 1),
#  ('middle tennessee’s', 1),
#  ('chittenden county', 1),
#  ('the city of chicago', 1),
#  ('krishnakumar', 1),
#  ('hamtramck', 1),
#  ('the town of mamaroneck, ny', 1),
#  ('the village of mamaroneck , village of larchmont ny', 1),
#  ('bartie', 1),
#  ('port arthur', 1),
#  ('hermann park', 1),
#  ('grapevine', 1),
#  ('irving', 1),
#  ('kitsap', 1),
#  ('kitsap county', 1),
#  ('minto', 1),
#  ('jacobi', 1),
#  ('prince george’s county', 1),
#  ('il', 1),
#  ('rockdale city', 1),
#  ('cottage grove', 1),
#  ('rund abdellfatah', 1),
#  ('genoa city', 1),
#  ('ride https://www.facebook.com/events/592267961403681/', 1),
#  ('ride, elkhorn', 1),
#  ('south milwaukee', 1),
#  ('humboldt park', 1),
#  ('morgan park', 1),
#  ('wisconsin ave', 1),
#  ('kenosha', 1),
#  ('kewaunee', 1),
#  ('layton blvd', 1),
#  ('waupaca', 1),
#  ('janesville', 1),
#  ('delafield', 1),
#  ('lake mills', 1),
#  ('greendale', 1),
#  ('pulaski', 1),
#  ('ywca', 1),
#  ('stow', 1),
#  ('brooklyn park', 1),
#  ('the village of mamaroneck', 1),
#  ('minne', 1),
#  ('fl', 1),
#  ('https://madisonreliefcomp.bandcamp.com/releases', 1),
#  ('rowan county', 1),
#  ('marin', 1),
#  ('alameda county', 1),
#  ('san francisco katrina kehl', 1),
#  ('napa valley', 1),
#  ('tony suburbs', 1),
#  ('monterey', 1),
#  ('sonoma', 1),
#  ('mill valley', 1),
#  ('carmel valley', 1),
#  ('marin county', 1),
#  ('fairfax', 1),
#  ('fear.', 1),
#  ('empire', 1),
#  ('ywca el paso', 1),
#  ('caribbean', 1),
#  ('kern county', 1),
#  ('asbury park', 1),
#  ('the kingdom of heaven on earth', 1),
#  ('chatham county', 1),
#  ('puerto rican', 1),
#  ('o’hara', 1),
#  ('ormond beach', 1),
#  ('the city of eastvale', 1),
#  ('eastvale', 1),
#  ('south jamaica', 1),
#  ('district attorney', 1),
#  ('santa cruz county sheriff', 1),
#  ('wa', 1),
#  ('mali', 1),
#  ('yemen', 1),
#  ('baptist', 1),
#  ('mount holly', 1),
#  ('buffalo new york', 1),
#  ("pretty city'", 1),
#  ('hattiesburg', 1),
#  ('downtown kissimmee', 1),
#  ('centre county’s', 1),
#  ('moline acres', 1),
#  ('alexandria city', 1),
#  ('| athens', 1),
#  ('athens county', 1),
#  ('nuremberg', 1),
#  ('greene county', 1),
#  ('greene county schools', 1),
#  ('league city', 1),
#  ('whitesburg', 1),
#  ('mount pleasant', 1),
#  ('buraanbur', 1),
#  ('t.i.', 1),
#  ('the city of santa rosa', 1),
#  ('lama', 1),
#  ('⠀', 1),
#  ('gardena', 1),
#  ('therfore', 1),
#  ("los angeles'", 1),
#  ('raleigh', 1),
#  ('bozeman', 1),
#  ('billings', 1),
#  ('montana', 1),
#  ('seville', 1),
#  ('mont.', 1),
#  ('n.m.', 1),
#  ('n.h.', 1),
#  ('centennial park', 1),
#  ('black deaf', 1),
#  ('several city', 1),
#  ('the city of del rey oaks', 1),
#  ('monterey county', 1),
#  ('northeast portland', 1),
#  ('the salt lake city council', 1),
#  ('https://www.click2houston.com/news/local/2020/06/05/ogg-case-involving-george-floyd-was-among-goines-cases-being-reviewed-by-prosecutors/',
#   1),
#  ('black iowa', 1),
#  ('greenbrier county', 1),
#  ('lewisburg', 1),
#  ('west virginia’s', 1),
#  ('okla', 1),
#  ('lyndhurst', 1),
#  ('https://www.ideastream.org/news/northeast-ohio-musicians-say-black-lives-matter-in-song',
#   1),
#  ('chowgirls', 1),
#  ('boca raton', 1),
#  ('homestead', 1),
#  ('abilene', 1),
#  ('holocaust', 1),
#  ('nelson county', 1),
#  ('the white community', 1),
#  ('rivertowns', 1),
#  ('saint paul', 1),
#  ('swanton', 1),
#  ('st. amour', 1),
#  ('greeley', 1),
#  ('greenport', 1),
#  ('the city of newark', 1),
#  ('essex county', 1),
#  ('santa rosa youth protest', 1),
#  ('santa rosa youth', 1),
#  ('sonoma county', 1),
#  ('lakeland', 1),
#  ('munn park', 1),
#  ('west baltimore', 1),
#  ('howard county', 1),
#  ('leelanau county', 1),
#  ('the city of sun prairie', 1),
#  ('longview', 1),
#  ('laurel', 1),
#  ('steele county', 1),
#  ('dodge county', 1),
#  ('owatonna', 1),
#  ('calhoun', 1),
#  ('falun gong', 1),
#  ('crain', 1),
#  ('yasharahla', 1),
#  ...]

# %%
dataframe611=pd.DataFrame(dict_a)

# %%
len(dict_a)
# Out:
# 1376

# %%
# %cd dataframe_csv
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/dataframe_csv

# %%
# !ls
# Out:
# dataframe0529.csv  dataframe0602.csv  dataframe0606.csv  dataframe0610.csv
# dataframe0530.csv  dataframe0603.csv  dataframe0607.csv  dataframe0611.csv
# dataframe0531.csv  dataframe0604.csv  dataframe0608.csv  heatmap.csv
# dataframe0601.csv  dataframe0605.csv  dataframe0609.csv

# %%
dataframe611.to_csv('dataframe0612.csv')
