# %%
# !pip install -q geopy
# !pip install -q pyproj

# basic utilities
import json
import requests
import pandas as pd
import pprint
import time

# reverse geocoding utilities
from geopy.geocoders import Nominatim

# geography projection utilities
import pyproj
from shapely.ops import transform
from shapely.geometry import Point
from functools import partial
# Out:
#      |████████████████████████████████| 6.3 MB 4.3 MB/s

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK		       dataframe_result_csv_UK
#  a0529-a0611_US		       Github
#  ccc_compiled.csv	       heatmap529_UK.ipynb
#  csv			       heatmap530.ipynb
#  csv.zip		       Heat_Map_Online_language.ipynb
#  dataframe_csv		       __MACOSX
#  dataframe_csv_EU	       mapping_UK
#  dataframe_csv_UK	       mapping_US
#  dataframe_result_529_UK.csv   non_violant1.csv
#  dataframe_result_530_UK.csv   non_violant2.csv
#  dataframe_result_531_UK.csv   UK
#  dataframe_result_csv	       violant.csv
#  dataframe_result_csv_EU      '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
dataframe_path_530 = 'dataframe_csv/dataframe0601.csv'

# %%
dataframe_530 = pd.read_csv(dataframe_path_530)

# %%
dataframe_530=pd.DataFrame(dataframe_530,columns=['0','1'])

# %%
dataframe_530
# Out:
#                       0     1
# 0           minneapolis  8856
# 1             minnesota  2579
# 2               america  2183
# 3                  u.s.  1792
# 4     the united states  1658
# ...                 ...   ...
# 3058              truah     1
# 3059             keshet     1
# 3060          gambrills     1
# 3061                paz     1
# 3062             journy     1
#
# [3063 rows x 2 columns]

# %%
dataframe_530.shape[1]
# Out:
# 2

# %%
columns2=['City','Number']

# %%
#len(columns1)
len(columns2)
# Out:
# 2

# %%
dataframe_530.columns=columns2

# %%
dataframe_530
# Out:
#                    City  Number
# 0           minneapolis    8856
# 1             minnesota    2579
# 2               america    2183
# 3                  u.s.    1792
# 4     the united states    1658
# ...                 ...     ...
# 3058              truah       1
# 3059             keshet       1
# 3060          gambrills       1
# 3061                paz       1
# 3062             journy       1
#
# [3063 rows x 2 columns]

# %%
dataframe_530['Mapping']=None
dataframe_530['Latitude']=None
dataframe_530['Longtitude']=None

# %%
#for i in dataframe_530['Mapping']:
#  if(i==None):
#    print('Y')

# %%
dataframe_530
# Out:
#                    City  Number Mapping Latitude Longtitude
# 0           minneapolis    8856    None     None       None
# 1             minnesota    2579    None     None       None
# 2               america    2183    None     None       None
# 3                  u.s.    1792    None     None       None
# 4     the united states    1658    None     None       None
# ...                 ...     ...     ...      ...        ...
# 3058              truah       1    None     None       None
# 3059             keshet       1    None     None       None
# 3060          gambrills       1    None     None       None
# 3061                paz       1    None     None       None
# 3062             journy       1    None     None       None
#
# [3063 rows x 5 columns]

# %%
counter=2
print(dataframe_530['City'][counter])
# Out:
# america

# %%
from geopy.exc import GeocoderTimedOut
counter=0
for i in dataframe_530['City']:
  #search_string=dataframe_529['City'][i]
  geolocator = Nominatim(user_agent="address_development")
  try:
    location = geolocator.geocode(i,timeout=30)
    if(location==None):
      counter+=1
      time.sleep(1)
      continue
    else:
      dataframe_530['Latitude'][counter]=location.latitude
      dataframe_530['Longtitude'][counter]=location.longitude
      dataframe_530['Mapping'][counter]=location.address
      time.sleep(1)
    counter+=1
  except GeocoderTimedOut as e:
    print("Error: geocode failed on input %s with message %s"%(Location, e.msg))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
dataframe_530
# Out:
#                    City  Number  ... Latitude Longtitude
# 0           minneapolis    8856  ...  44.9773   -93.2655
# 1             minnesota    2579  ...  45.9897   -94.6113
# 2               america    2183  ...  51.4371     5.9799
# 3                  u.s.    1792  ...  48.6841    9.00958
# 4     the united states    1658  ...   29.633   -97.9886
# ...                 ...     ...  ...      ...        ...
# 3058              truah       1  ...  6.77522   -8.52526
# 3059             keshet       1  ...  32.9807    35.8086
# 3060          gambrills       1  ...  39.0963   -76.6549
# 3061                paz       1  ...  45.2908    14.0945
# 3062             journy       1  ...  50.7544    1.99908
#
# [3063 rows x 5 columns]

# %%
# %cd mapping_US
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/mapping_US

# %%
# !ls
# Out:
#  Country.txt			 dataframe0607_post_remove.csv
#  dataframe0529_post.csv		 dataframe0608_post.csv
#  dataframe0529_post_remove.csv	 dataframe0608_post_remove.csv
#  dataframe0530_post.csv		 dataframe0609_post.csv
#  dataframe0530_post_remove.csv	 dataframe0609_post_remove.csv
#  dataframe0531_post.csv		 dataframe0610_post.csv
#  dataframe0531_post_remove.csv	 dataframe0610_post_remove.csv
#  dataframe0601_post.csv		 dataframe0611_post.csv
#  dataframe0601_post_remove.csv	 dataframe0611_post_remove.csv
#  dataframe0602_post.csv		 dataframe_mapping
#  dataframe0602_post_remove.csv	 dataframe_mapping_0529.csv
#  dataframe0603_post.csv		 dataframe_mapping_0530.csv
#  dataframe0603_post_remove.csv	 dataframe_mapping_0531.csv
#  dataframe0604_post.csv		 dataframe_mapping_0602.csv
#  dataframe0604_post_remove.csv	 datarframe_post
#  dataframe0605_post.csv		'mapping_US_Cities_Only (1).zip'
#  dataframe0605_post_remove.csv	 mapping_US_Cities_Only.zip
#  dataframe0606_post.csv		 post_specific_mapping_US.zip
#  dataframe0606_post_remove.csv	 states.csv
#  dataframe0607_post.csv

# %%
dataframe_530.to_csv('dataframe_mapping_0601.csv')
