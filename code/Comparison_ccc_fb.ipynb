# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
path_all = 'Mapping_US_New/US_fb_ccc.xlsx'

# %%
Comparison_xlsx = pd.read_excel(path_all)

# %%
pd.set_option('display.max_rows', None)

# %%
columns=['5-29','protest_num','fb_num','5-30','protest_num','fb_num','5-31','protest_num','fb_num','6-01','protest_num','fb_num','6-02','protest_num','fb_num','6-03','protest_num','fb_num','6-04','protest_num','fb_num','6-05','protest_num','fb_num','6-06','protest_num','fb_num','6-07','protest_num','fb_num','6-08','protest_num','fb_num','6-09','protest_num','fb_num','6-10','protest_num','fb_num','6-11','protest_num','fb_num','6-12','protest_num','fb_num','6-13','protest_num','fb_num','6-14','protest_num','fb_num']

# %%
Comparison_xlsx
# Out:
#                     5-29  protest_num   fb_num                  5-30  \
# 0               New York          6.0    626.0              New York
# 1               Portland          5.0      0.0               Chicago
# 2            Minneapolis          4.0  18105.0           Minneapolis
# 3            Los Angeles          3.0    299.0        Salt Lake City
# 4               San Jose          3.0     77.0          Fayetteville
# 5             Des Moines          3.0     19.0           Los Angeles
# 6           Indianapolis          3.0     26.0            Washington
# 7            Kansas City          3.0     35.0                Dallas
# 8                 Canton          3.0     13.0           San Antonio
# 9                 Dallas          3.0     57.0             Anchorage
# 10               Houston          3.0    391.0              San Jose
# 11             Milwaukee          3.0    114.0            Wilmington
# 12               Phoenix          2.0    182.0           Gainesville
# ...

# %%
Comparison_xlsx.to_csv('Comparison529-614.csv')

# %%
Comparison_xlsx.columns=columns

# %%
mapping_609_path='Mapping_US_New/US_fb_ccc_609.csv'
mapping_609 = pd.read_csv(mapping_609_path)
mapping_609
# Out:
#      Unnamed: 0             Places  Number        lat         lon  fb_Number  \
# 0             0           New York      12  40.712775  -74.005973        890
# 1             1       Philadelphia       3  39.952584  -75.165222        344
# 2             2           Berkeley       2  37.871523 -122.273042        136
# 3             3           Monterey       2  36.600238 -121.894676          9
# 4             4            Oakland       2  37.804351 -122.271164        136
# 5             5              Miami       2  25.761680  -80.191790         44
# 6             6         Des Moines       2  41.586835  -93.624959         12
# 7             7            Detroit       2  42.331427  -83.045754         63
# 8             8            Raleigh       2  35.779590  -78.638179         29
# 9             9            Buffalo       2  42.886447  -78.878369        211
# 10           10          Smithtown       2  40.855931  -73.200669         23
# ...

# %%
mapping_609['address'][0]
# Out:
# '[\'New York, United States\', \'Brooklyn, Kings County, New York, United States\', \'Newark, Essex County, New Jersey, 07102, United States\', \'Y, Terminal 5 Departures, Queens, Queens County, New York, 11430, United States\', \'Manhattan, New York County, New York, United States\', \'Lower Manhattan, Civic Center, Manhattan, New York County, New York, 10000, United States\', \'Staten Island, Richmond County, New York, United States\', \'N&J, 185, Norman Avenue, Greenpoint, Brooklyn, Kings County, New York, 11222, United States\', \'Elmont, Town of Hempstead, Nassau County, New York, 11003, United States\', \'Yonkers, Westchester County, New York, United States\', \'The Bronx, Bronx County, New York, United States\', \'Harlem, Manhattan, New York County, New York, United States\', \'Bayville, Town of Oyster Bay, Nassau County, New York, 11709, United States\', \'Queens, Queens County, New York, United States\', \'Denville, Morris County, New Jersey, United States\', \'Senate Place,
# ...
