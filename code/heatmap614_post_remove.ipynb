# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 4.2 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=4bd4617ec2359873b15373333929c50f14d9849bb7ec5ee2aad07bb76c4a5d23
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.9 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_EU
#  a0529-a0611_US     dataframe_csv_UK
#  a0529.csv	    dataframe_result_529_UK.csv
#  a0530.csv	    dataframe_result_530_UK.csv
#  a0601.csv	    dataframe_result_531_UK.csv
#  a0602.csv	    dataframe_result_csv
#  a0603.csv	    dataframe_result_csv_EU
#  a0604.csv	    dataframe_result_csv_UK
#  a0605.csv	    Github
#  a0606.csv	    heatmap529_UK.ipynb
#  a0607.csv	    heatmap530.ipynb
#  a0608.csv	    Heat_Map_Online_language.ipynb
#  a0610.csv	    __MACOSX
#  a0611.csv	    mapping_UK
#  a0612.csv	    mapping_US
#  a0613.csv	    non_violant1.csv
#  a0614.csv	    non_violant2.csv
#  ccc_compiled.csv   UK
#  csv		    violant.csv
#  csv.zip	   '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_csv

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_601 = 'csv/US06_14.csv'

# %%
ct = pd.read_csv(ct_path_601)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                             platformId  ...                    post_id
# 0        18982436812_10157083355091813  ...     8015|10157083355091813
# 1     115049898514565_3320488604637329  ...     10268|3320488604637329
# 2      212643102652626_651586795424919  ...    3892292|651586795424919
# 3     389462407756241_3044759782226477  ...    465971|3044759782226477
# 4     191314347566158_3285176251513270  ...   8605125|3285176251513270
# ...                                ...  ...                        ...
# 3281  837955106354138_1617784385037869  ...   2146395|1617784385037869
# 3282  519305544814653_3366661223412390  ...     48733|3366661223412390
# 3283    158094820767_10158441052675768  ...    13653|10158441052675768
# 3284    275678631915_10156988934511916  ...   349912|10156988934511916
# 3285  310182299373875_1236259733432789  ...  12924282|1236259733432789
#
# [3286 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#                          NER-msg                          NER-desc
# 0             {'Minneapolis': 1}  {'Minneapolis': 1, 'America': 1}
# 1                             {}                                {}
# 2                  {'Dallas': 1}                     {'Dallas': 1}
# 3  {'Abita Springs': 1, 'LA': 1}                     {'Dallas': 1}
# 4                             {}                                {}

# %%
ct.to_csv('a0614.csv')

# %%
ct=pd.read_csv('a0614.csv')

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_EU
#  a0529-a0611_US     dataframe_csv_UK
#  a0529.csv	    dataframe_result_529_UK.csv
#  a0530.csv	    dataframe_result_530_UK.csv
#  a0601.csv	    dataframe_result_531_UK.csv
#  a0602.csv	    dataframe_result_csv
#  a0603.csv	    dataframe_result_csv_EU
#  a0604.csv	    dataframe_result_csv_UK
#  a0605.csv	    Github
#  a0606.csv	    heatmap529_UK.ipynb
#  a0607.csv	    heatmap530.ipynb
#  a0608.csv	    Heat_Map_Online_language.ipynb
#  a0610.csv	    __MACOSX
#  a0611.csv	    mapping_UK
#  a0612.csv	    mapping_US
#  a0613.csv	    non_violant1.csv
#  a0614.csv	    non_violant2.csv
#  ccc_compiled.csv   UK
#  csv		    violant.csv
#  csv.zip	   '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_csv

# %%
###
#ct=pd.read_csv('a0601.csv')

# %%
ct
# Out:
#       Unnamed: 0  ...      NER-title
# 0              0  ...             {}
# 1              1  ...             {}
# 2              2  ...  {'Dallas': 1}
# 3              3  ...  {'Dallas': 1}
# 4              4  ...             {}
# ...          ...  ...            ...
# 3281        3281  ...             {}
# 3282        3282  ...             {}
# 3283        3283  ...             {}
# 3284        3284  ...             {}
# 3285        3285  ...    {'U.S.': 1}
#
# [3286 rows x 51 columns]

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
#ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
###
ct_ner = ct

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                          NER-msg  ...      NER-title
# 0             {'Minneapolis': 1}  ...             {}
# 1                             {}  ...             {}
# 2                  {'Dallas': 1}  ...  {'Dallas': 1}
# 3  {'Abita Springs': 1, 'LA': 1}  ...  {'Dallas': 1}
# 4                             {}  ...             {}
#
# [5 rows x 3 columns]

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))

# %%
ct_ner['NER-msg']
# Out:
# 0             [Minneapolis]
# 1                        []
# 2                  [Dallas]
# 3       [Abita Springs, LA]
# 4                        []
#                ...
# 3281                     []
# 3282                     []
# 3283                     []
# 3284                     []
# 3285       [U.S., New York]
# Name: NER-msg, Length: 3286, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']

# %%
ct_ner['NER']
# Out:
# 0       [Minneapolis, Minneapolis, America]
# 1                                        []
# 2                  [Dallas, Dallas, Dallas]
# 3       [Abita Springs, LA, Dallas, Dallas]
# 4                                        []
#                        ...
# 3281                          [Minneapolis]
# 3282                                     []
# 3283                                     []
# 3284                                     []
# 3285                 [U.S., New York, U.S.]
# Name: NER, Length: 3286, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])

# %%
ct_ner
# Out:
#       Unnamed: 0  ...                          NER
# 0              0  ...       [minneapolis, america]
# 1              1  ...                           []
# 2              2  ...                     [dallas]
# 3              3  ...  [dallas, abita springs, la]
# 4              4  ...                           []
# ...          ...  ...                          ...
# 3281        3281  ...                [minneapolis]
# 3282        3282  ...                           []
# 3283        3283  ...                           []
# 3284        3284  ...                           []
# 3285        3285  ...             [u.s., new york]
#
# [3286 rows x 52 columns]

# %%
ct_ner['NER-1']=ct_ner['NER']

# %%
ct_ner['NER-1'][0]
# Out:
# ['minneapolis', 'america']

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_ner[:100]
# Out:
#     Unnamed: 0  ...                                              NER-1
# 0            0  ...                             [minneapolis, america]
# 1            1  ...                                                 []
# 2            2  ...                                           [dallas]
# 3            3  ...                        [dallas, abita springs, la]
# 4            4  ...                                                 []
# ..         ...  ...                                                ...
# 95          95  ...                                               [us]
# 96          96  ...                                                 []
# 97          97  ...  [israel, britain, america, israel, the state o...
# 98          98  ...                                                 []
# 99          99  ...                                    [massachusetts]
#
# [100 rows x 53 columns]

# %%
# %cd mapping_US
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/mapping_US

# %%
# !ls
# Out:
#  Country.txt			 dataframe0610_post_remove.csv
#  dataframe0529_post.csv		 dataframe0611_post.csv
#  dataframe0529_post_remove.csv	 dataframe0611_post_remove.csv
#  dataframe0530_post.csv		 dataframe_mapping
#  dataframe0530_post_remove.csv	 dataframe_mapping_0529.csv
#  dataframe0531_post.csv		 dataframe_mapping_0530.csv
#  dataframe0531_post_remove.csv	 dataframe_mapping_0531.csv
#  dataframe0601_post.csv		 dataframe_mapping_0601.csv
#  dataframe0601_post_remove.csv	 dataframe_mapping_0602.csv
#  dataframe0602_post.csv		 dataframe_mapping_0603.csv
#  dataframe0602_post_remove.csv	 dataframe_mapping_0604.csv
#  dataframe0603_post.csv		 dataframe_mapping_0605.csv
#  dataframe0603_post_remove.csv	 dataframe_mapping_0606.csv
#  dataframe0604_post.csv		 dataframe_mapping_0607.csv
#  dataframe0604_post_remove.csv	 dataframe_mapping_0608.csv
#  dataframe0605_post.csv		 dataframe_mapping_0609.csv
#  dataframe0605_post_remove.csv	 dataframe_mapping_0610.csv
#  dataframe0606_post.csv		 dataframe_mapping_0611.csv
#  dataframe0606_post_remove.csv	 dataframe_mapping_0612.csv
#  dataframe0607_post.csv		 dataframe_mapping_0613.csv
#  dataframe0607_post_remove.csv	 dataframe_mapping_0614.csv
#  dataframe0608_post.csv		 datarframe_post
#  dataframe0608_post_remove.csv	'mapping_US_Cities_Only(1).zip'
#  dataframe0609_post.csv		 mapping_US_Cities_Only.zip
#  dataframe0609_post_remove.csv	 post_specific_mapping_US.zip
#  dataframe0610_post.csv		 states.csv

# %%
ct_mapping=pd.read_csv('dataframe_mapping_0614.csv',encoding='ISO-8859-1')

# %%
ct_mapping
# Out:
#      Unnamed: 0                City  ...   Latitude Longtitude
# 0             0         minneapolis  ...  44.977300 -93.265469
# 1             1             america  ...  51.437148   5.979900
# 2             2                u.s.  ...  48.684067   9.009582
# 3             3             atlanta  ...  33.748992 -84.390264
# 4             4   the united states  ...  29.633008 -97.988594
# ..          ...                 ...  ...        ...        ...
# 808         808              queens  ...  40.713508 -73.828313
# 809         809  new kensingtonâs  ...  40.569789 -79.764770
# 810         810      new kensington  ...  40.569789 -79.764770
# 811         811             indiana  ...  40.327013 -86.174693
# 812         812               state  ...  38.897554 -77.038682
#
# [813 rows x 6 columns]

# %%
country_list=pd.read_csv('Country.txt')
country_list['Name']=country_list['Name'].str.lower()

# %%
country_list['Name']
# Out:
# 0            afghanistan
# 1          �land islands
# 2                albania
# 3                algeria
# 4         american samoa
#              ...
# 250                   us
# 251    the united states
# 252              america
# 253                  u.s
# 254        united states
# Name: Name, Length: 255, dtype: object

# %%
states_list=pd.read_csv('states.csv')
states_list['State']
# Out:
# 0                             Alabama, United States
# 1                              Alaska, United States
# 2                             Arizona, United States
# 3                            Arkansas, United States
# 4                          California, United States
#                            ...
# 165         Armagh, Northern Ireland, United Kingdom
# 166           Down, Northern Ireland, United Kingdom
# 167      Fermanagh, Northern Ireland, United Kingdom
# 168    Londonderry, Northern Ireland, United Kingdom
# 169         Tyrone, Northern Ireland, United Kingdom
# Name: State, Length: 170, dtype: object

# %%
from numpy.core.numeric import NaN
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['City'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(states_list['State'])):
    if ct_mapping['Mapping'][i]==states_list['State'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['Mapping'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN

# %%
pd.set_option('display.max_rows', None)

# %%
ct_mapping
# Out:
#      Unnamed: 0  ...  Longtitude
# 0             0  ...  -93.265469
# 1             1  ...    5.979900
# 2             2  ...    9.009582
# 3             3  ...  -84.390264
# 4             4  ...  -97.988594
# 5             5  ...  -94.611329
# 6             6  ... -100.445882
# 7             7  ... -122.330062
# 8             8  ...  -99.683001
# 9             9  ...  -74.006015
# 10           10  ...  -95.367697
# 11           11  ... -118.755997
# 12           12  ...  -77.036543
# 13           13  ... -118.242766
# 14           14  ...  139.759455
# 15           15  ...  172.834408
# 16           16  ...  -76.938207
# 17           17  ...  139.239418
# 18           18  ...  -87.624421
# 19           19  ...    2.320041
# 20           20  ...    1.888333
# 21           21  ...  -78.492772
# 22           22  ...  -93.093103
# 23           23  ...  -77.036543
# 24           24  ... -115.148516
# 25           25  ...   -0.127647
# 26           26  ...  -73.949721
# 27           27  ...  -95.992911
# 28           28  ... -118.329523
# 29           29  ...  -75.163526
# 30           30  ...  -83.113737
# 31           31  ...  -96.796856
# 32           32  ...  -81.463983
# 33           33  ...  -77.434280
# 34           34  ... -122.271356
# 35           35  ...  -79.039292
# 36           36  ... -122.419906
# 37           37  ...  -84.682435
# 38           38  ...  -74.006015
# 39           39  ... -118.117111
# 40           40  ...  -71.058291
# 41           41  ...  134.755000
# 42           42  ...  -95.374125
# 43           43  ...  -79.990086
# 44           44  ... -112.074142
# 45           45  ...  -72.734216
# 46           46  ... -122.427866
# 47           47  ...         NaN
# 48           48  ...  -87.922497
# 49           49  ...   10.423447
# 50           50  ...  -85.759407
# 51           51  ... -118.755997
# 52           52  ...  -72.734216
# 53           53  ... -100.445882
# 54           54  ...  -81.693445
# 55           55  ...   -2.922520
# 56           56  ...  -98.495141
# 57           57  ...  -82.688140
# 58           58  ...  -90.051629
# 59           59  ...   13.388860
# 60           60  ... -100.445882
# 61           61  ...  -92.561787
# 62           62  ...  -94.611329
# 63           63  ...  -83.221873
# 64           64  ...  -74.006015
# 65           65  ...  -83.046640
# 66           66  ...  -94.157433
# 67           67  ... -111.763275
# 68           68  ...  -72.032366
# 69           69  ...  -76.938207
# 70           70  ...  -78.639099
# 71           71  ... -104.984862
# 72           72  ... -122.674195
# 73           73  ...         NaN
# 74           74  ...   -1.918023
# 75           75  ... -107.991707
# 76           76  ...  -77.036543
# 77           77  ...  -79.039292
# 78           78  ...  -82.458444
# 79           79  ...  -89.688464
# 80           80  ...   -3.276575
# 81           81  ...  -97.268406
# 82           82  ... -117.291156
# 83           83  ...  -89.734850
# 84           84  ...  -78.878392
# 85           85  ... -102.267516
# 86           86  ...  -86.829534
# 87           87  ... -121.493895
# 88           88  ...  102.288096
# 89           89  ...  -86.282008
# 90           90  ...  -74.404162
# 91           91  ...  -86.282008
# 92           92  ...  -79.940273
# 93           93  ... -109.638757
# 94           94  ...         NaN
# 95           95  ...  -90.199585
# 96           96  ...  -74.404162
# 97           97  ...  -73.204835
# 98           98  ...  -76.610759
# 99           99  ...  -97.988594
# 100         100  ...  -92.561787
# 101         101  ...    4.666714
# 102         102  ...  -83.000706
# 103         103  ...  -53.200000
# 104         104  ...   66.238514
# 105         105  ...   -4.837979
# 106         106  ...  -77.850765
# 107         107  ...  121.025875
# 108         108  ...   11.689970
# 109         109  ...  -97.517054
# 110         110  ...  -81.130843
# 111         111  ...         NaN
# 112         112  ...  -85.155141
# 113         113  ...  -80.843083
# 114         114  ...  -78.492772
# 115         115  ... -122.439875
# 116         116  ...   -3.703582
# 117         117  ...   39.049411
# 118         118  ...   10.333328
# 119         119  ...   19.134422
# 120         120  ...   -7.979460
# 121         121  ... -106.779808
# 122         122  ...  -83.323777
# 123         123  ... -119.019464
# 124         124  ...   34.866765
# 125         125  ...  -77.036543
# 126         126  ...   29.894378
# 127         127  ...  -79.039292
# 128         128  ...  -87.789743
# 129         129  ...  -75.765242
# 130         130  ...  -92.007126
# 131         131  ... -112.036277
# 132         132  ...  -89.433729
# 133         133  ...  -16.254088
# 134         134  ...  -84.512460
# 135         135  ...  -89.260060
# 136         136  ...  -77.727883
# 137         137  ...   23.728305
# 138         138  ...   21.987713
# 139         139  ...   -6.260273
# 140         140  ...   36.714575
# 141         141  ...  -99.133178
# 142         142  ...    4.893604
# 143         143  ...    4.351697
# 144         144  ...   12.570072
# 145         145  ...    2.177432
# 146         146  ...  174.763180
# 147         147  ...  -87.674740
# 148         148  ...   -4.555331
# 149         149  ...  -81.463983
# 150         150  ...  -80.436374
# 151         151  ...  -75.119891
# 152         152  ... -118.485635
# 153         153  ... -122.256637
# 154         154  ...  -85.608316
# 155         155  ...  -91.670405
# 156         156  ...  -81.818919
# 157         157  ...  -97.268406
# 158         158  ...  -88.929841
# 159         159  ...   -1.080027
# 160         160  ...  -93.486505
# 161         161  ...  -81.987349
# 162         162  ...  -97.332746
# 163         163  ... -121.990591
# 164         164  ...  -72.500261
# 165         165  ...  -87.580755
# 166         166  ...  -89.688464
# 167         167  ...  -93.589124
# 168         168  ...   11.689970
# 169         169  ...   -1.902691
# 170         170  ...   24.991639
# 171         171  ...  -99.683001
# 172         172  ... -105.993007
# 173         173  ... -111.714358
# 174         174  ...  -80.436374
# 175         175  ... -115.172797
# 176         176  ...  -77.036543
# 177         177  ...  -72.500261
# 178         178  ...  -72.575114
# 179         179  ...  -86.158350
# 180         180  ...   -2.135839
# 181         181  ... -155.428370
# 182         182  ... -117.162773
# 183         183  ...         NaN
# 184         184  ...   12.674297
# 185         185  ...   78.667743
# 186         186  ...  -75.844995
# 187         187  ...  -94.611329
# 188         188  ... -100.540737
# 189         189  ... -112.113055
# 190         190  ...   12.674297
# 191         191  ...  -79.791975
# 192         192  ...  -73.959894
# 193         193  ...   11.045785
# 194         194  ... -109.912162
# 195         195  ...   54.564352
# 196         196  ...   51.262730
# 197         197  ...   71.247499
# 198         198  ... -118.242766
# 199         199  ...  104.999927
# 200         200  ...  -97.997589
# 201         201  ...         NaN
# 202         202  ...  -74.404162
# 203         203  ...         NaN
# 204         204  ...  -92.172427
# 205         205  ...   -0.201238
# 206         206  ... -122.239634
# 207         207  ...  -91.187380
# 208         208  ... -122.391675
# 209         209  ...  -92.332964
# 210         210  ... -119.708861
# 211         211  ...  108.426511
# 212         212  ...  -72.032366
# 213         213  ...  -66.261522
# 214         214  ...  -85.155141
# 215         215  ...  -85.293691
# 216         216  ...         NaN
# 217         217  ... -105.607716
# 218         218  ...  -76.345206
# 219         219  ... -116.853723
# 220         220  ...  -87.676387
# 221         221  ...  -85.378280
# 222         222  ...  -82.161424
# 223         223  ...  -73.099426
# 224         224  ...  -77.615214
# 225         225  ...  -79.976040
# 226         226  ... -117.423511
# 227         227  ...  -93.278334
# 228         228  ...  -72.357097
# 229         229  ...  -92.447911
# 230         230  ...  -80.436374
# 231         231  ...  -97.268406
# 232         232  ...  -92.125122
# 233         233  ...  -74.975711
# 234         234  ...  -86.774298
# 235         235  ...  -94.344488
# 236         236  ...  -84.280933
# 237         237  ...   -4.114052
# 238         238  ...  -93.312270
# 239         239  ... -118.191604
# 240         240  ...  -95.094930
# 241         241  ... -100.217897
# 242         242  ...   -3.276575
# 243         243  ...  -73.878594
# 244         244  ...  -96.703412
# 245         245  ...  120.612966
# 246         246  ...  149.984444
# 247         247  ... -117.870493
# 248         248  ...   67.020706
# 249         249  ... -118.117111
# 250         250  ...  -80.284283
# 251         251  ...  -92.500000
# 252         252  ...  -97.743700
# 253         253  ...  -82.076402
# 254         254  ...         NaN
# 255         255  ...  -71.801888
# 256         256  ...  -90.037576
# 257         257  ...  114.162813
# 258         258  ...  -74.404162
# 259         259  ...  -74.159866
# 260         260  ...  -97.105624
# 261         261  ...  -77.009043
# 262         262  ...    1.046683
# 263         263  ...   34.573134
# 264         264  ...   35.225763
# 265         265  ... -119.613161
# 266         266  ...   38.431397
# 267         267  ...   31.271832
# 268         268  ...  -77.024037
# 269         269  ... -104.987964
# 270         270  ...   11.255576
# 271         271  ... -111.965413
# 272         272  ... -122.777656
# 273         273  ... -121.290780
# 274         274  ... -117.147366
# 275         275  ...  -78.476678
# 276         276  ...  -52.715149
# 277         277  ... -123.302049
# 278         278  ...  -87.216915
# 279         279  ...  -71.537476
# 280         280  ...    9.300651
# 281         281  ...  -72.908813
# 282         282  ... -124.263944
# 283         283  ...  -81.379030
# 284         284  ... -118.499820
# 285         285  ...  -88.914068
# 286         286  ... -118.491227
# 287         287  ...         NaN
# 288         288  ...   -2.754066
# 289         289  ...   -7.336248
# 290         290  ...  121.100360
# 291         291  ...   34.924965
# 292         292  ... -114.015407
# 293         293  ...  -70.975043
# 294         294  ...   15.575748
# 295         295  ...  -71.655399
# 296         296  ...  -80.449417
# 297         297  ...  -78.971078
# 298         298  ...         NaN
# 299         299  ...  151.210047
# 300         300  ...  -83.921026
# 301         301  ...  -88.952415
# 302         302  ...  -88.960238
# 303         303  ...    7.249473
# 304         304  ...  -87.649278
# 305         305  ...  100.532730
# 306         306  ... -119.795634
# 307         307  ...  -87.833269
# 308         308  ...   11.223458
# 309         309  ...  -87.020747
# 310         310  ...   19.999962
# 311         311  ... -118.209681
# 312         312  ...  -78.656398
# 313         313  ...   49.834791
# 314         314  ...   -2.597298
# 315         315  ...    4.399708
# 316         316  ...  -72.650906
# 317         317  ... -118.475953
# 318         318  ...   -7.889626
# 319         319  ...   -1.264906
# 320         320  ...  -75.546589
# 321         321  ...   46.717408
# 322         322  ... -120.737257
# 323         323  ...  -80.135301
# 324         324  ...  -80.193620
# 325         325  ...  -74.415984
# 326         326  ...  -78.998728
# 327         327  ... -110.974848
# 328         328  ...  -74.047455
# 329         329  ... -120.905723
# 330         330  ...  116.391276
# 331         331  ...  -82.398488
# 332         332  ...  -96.247134
# 333         333  ...  -87.358870
# 334         334  ...  -90.595365
# 335         335  ...         NaN
# 336         336  ...  -95.369691
# 337         337  ...  -96.995592
# 338         338  ...  -93.723406
# 339         339  ... -117.435048
# 340         340  ...  -99.813038
# 341         341  ... -116.770628
# 342         342  ...  -75.523423
# 343         343  ...  140.459214
# 344         344  ...  -87.821226
# 345         345  ...  -95.938376
# 346         346  ...  -90.122655
# 347         347  ...  -82.559429
# 348         348  ...  -89.589101
# 349         349  ...  -91.214790
# 350         350  ...  -72.925052
# 351         351  ...  -86.033877
# 352         352  ...  -84.191607
# 353         353  ... -117.911732
# 354         354  ...  -89.643957
# 355         355  ...         NaN
# 356         356  ...  -80.880559
# 357         357  ...  -77.036543
# 358         358  ... -118.242766
# 359         359  ... -111.714358
# 360         360  ...  -83.244371
# 361         361  ... -116.200886
# 362         362  ...  -75.977418
# 363         363  ...  -87.665474
# 364         364  ...  -80.352254
# 365         365  ...  -86.829534
# 366         366  ...  -96.753867
# 367         367  ...   10.523607
# 368         368  ...  -60.955858
# 369         369  ...  -72.758486
# 370         370  ...  -87.756525
# 371         371  ... -120.907089
# 372         372  ...  -81.655651
# 373         373  ...  -90.171799
# 374         374  ...         NaN
# 375         375  ...  -77.036540
# 376         376  ...   -2.002253
# 377         377  ...  -74.517722
# 378         378  ... -121.919747
# 379         379  ...   18.770272
# 380         380  ...    4.284453
# 381         381  ...   34.262717
# 382         382  ... -125.002441
# 383         383  ... -122.333057
# 384         384  ...  -96.731393
# 385         385  ... -100.348761
# 386         386  ...  -70.737736
# 387         387  ...         NaN
# 388         388  ...   29.267547
# 389         389  ... -122.141075
# 390         390  ...   18.871289
# 391         391  ...  -73.945415
# 392         392  ...  -71.064182
# 393         393  ... -122.855373
# 394         394  ...  -77.280393
# 395         395  ... -122.544354
# 396         396  ...  -70.973053
# 397         397  ...  121.090583
# 398         398  ... -117.188454
# 399         399  ...  -77.612135
# 400         400  ... -118.111975
# 401         401  ... -116.153277
# 402         402  ...  -87.940342
# 403         403  ...   29.746841
# 404         404  ...  -80.237270
# 405         405  ...  -74.055255
# 406         406  ...  -70.817310
# 407         407  ...  -78.602238
# 408         408  ...  -53.481842
# 409         409  ...   -1.080027
# 410         410  ...   -2.245115
# 411         411  ...  -73.817429
# 412         412  ...  -73.769721
# 413         413  ...  -93.765194
# 414         414  ...  -80.990371
# 415         415  ...         NaN
# 416         416  ...  -90.303897
# 417         417  ...  -85.654573
# 418         418  ... -106.325138
# 419         419  ...  -73.991228
# 420         420  ...  -47.897921
# 421         421  ... -112.730038
# 422         422  ...         NaN
# 423         423  ...  -84.073910
# 424         424  ...  -72.908813
# 425         425  ...  -81.130843
# 426         426  ...  -76.662665
# 427         427  ...   -1.396725
# 428         428  ...  -92.365186
# 429         429  ...  -86.305444
# 430         430  ...         NaN
# 431         431  ...  -90.184556
# 432         432  ...  -94.611329
# 433         433  ...  -72.536917
# 434         434  ... -122.376771
# 435         435  ...  -78.492772
# 436         436  ...  151.216454
# 437         437  ...  -81.315091
# 438         438  ...   44.174978
# 439         439  ...  -88.281099
# 440         440  ...   17.078078
# 441         441  ...  -74.095290
# 442         442  ...  -89.299846
# 443         443  ...  -72.500261
# 444         444  ... -117.395324
# 445         445  ...  -93.252012
# 446         446  ...  -79.383474
# 447         447  ...  -83.209524
# 448         448  ... -118.325855
# 449         449  ...  -84.379559
# 450         450  ...  -89.267641
# 451         451  ...  -98.908727
# 452         452  ... -104.228475
# 453         453  ...   12.871077
# 454         454  ...  -93.344358
# 455         455  ...  -93.094950
# 456         456  ...  -93.126110
# 457         457  ...    5.387210
# 458         458  ...    3.063528
# 459         459  ...  -76.938207
# 460         460  ...   -6.400888
# 461         461  ...  -77.412756
# 462         462  ...  -77.171091
# 463         463  ...  -84.036872
# 464         464  ...   12.002398
# 465         465  ...  -84.274733
# 466         466  ...  -79.872858
# 467         467  ...  -73.569806
# 468         468  ...   -5.930183
# 469         469  ...  -75.401331
# 470         470  ... -104.827718
# 471         471  ...         NaN
# 472         472  ...  -68.859020
# 473         473  ... -122.291455
# 474         474  ... -118.045577
# 475         475  ... -111.827433
# 476         476  ...  -76.241128
# 477         477  ... -117.840833
# 478         478  ... -103.338396
# 479         479  ...  -76.793625
# 480         480  ...  -97.619994
# 481         481  ...  -97.668884
# 482         482  ...  -97.619994
# 483         483  ...  -73.212906
# 484         484  ...  -89.216655
# 485         485  ... -106.704812
# 486         486  ... -106.695702
# 487         487  ... -121.655037
# 488         488  ...         NaN
# 489         489  ...   -3.129497
# 490         490  ...  -72.690855
# 491         491  ...  -81.537067
# 492         492  ...         NaN
# 493         493  ...   -2.890896
# 494         494  ...  -87.916700
# 495         495  ... -155.081580
# 496         496  ...         NaN
# 497         497  ...   87.301097
# 498         498  ... -156.569845
# 499         499  ...    4.420986
# 500         500  ... -122.562580
# 501         501  ...         NaN
# 502         502  ...   -2.002647
# 503         503  ...  -75.139364
# 504         504  ...  -82.353473
# 505         505  ...         NaN
# 506         506  ...         NaN
# 507         507  ... -115.563051
# 508         508  ...  -75.617647
# 509         509  ...  -75.680057
# 510         510  ... -161.755833
# 511         511  ...  -75.711700
# 512         512  ... -106.464634
# 513         513  ... -122.484974
# 514         514  ...   19.506094
# 515         515  ...  -14.452961
# 516         516  ...   14.520858
# 517         517  ...    8.231974
# 518         518  ...  127.696119
# 519         519  ... -106.532759
# 520         520  ...  -88.419768
# 521         521  ...   97.745306
# 522         522  ...   72.877393
# 523         523  ...   77.221939
# 524         524  ...   -1.017085
# 525         525  ...  -73.188724
# 526         526  ...  -73.105856
# 527         527  ...   -2.856360
# 528         528  ... -123.033121
# 529         529  ...  -74.422935
# 530         530  ...  -93.269357
# 531         531  ...  -58.162446
# 532         532  ... -118.247847
# 533         533  ...  -85.155141
# 534         534  ...  -69.972079
# 535         535  ...  -75.969619
# 536         536  ...   -4.023957
# 537         537  ...  -76.707404
# 538         538  ...  -82.162064
# 539         539  ...  -75.534368
# 540         540  ...  -88.903120
# 541         541  ...   21.006725
# 542         542  ...  -89.538421
# 543         543  ...  -74.325427
# 544         544  ...   -2.716044
# 545         545  ... -122.023015
# 546         546  ...   19.894567
# 547         547  ...  -84.968819
# 548         548  ...  -80.890851
# 549         549  ...  -89.118343
# 550         550  ...  -76.513650
# 551         551  ... -109.791975
# 552         552  ... -114.471884
# 553         553  ...         NaN
# 554         554  ...         NaN
# 555         555  ...  -85.952968
# 556         556  ...   -6.590942
# 557         557  ...  -85.667864
# 558         558  ... -120.739662
# 559         559  ...  -74.149605
# 560         560  ...  -73.894767
# 561         561  ...         NaN
# 562         562  ...    5.345596
# 563         563  ... -122.478836
# 564         564  ...  -94.969401
# 565         565  ...  -97.336627
# 566         566  ...  -97.335696
# 567         567  ...   -0.327471
# 568         568  ...   28.612982
# 569         569  ...  -77.009418
# 570         570  ...  -75.471279
# 571         571  ...  -81.130843
# 572         572  ...   76.517427
# 573         573  ...  -78.957897
# 574         574  ... -117.031417
# 575         575  ...  -94.048104
# 576         576  ...  145.639196
# 577         577  ... -120.510842
# 578         578  ... -120.730253
# 579         579  ...  -95.223175
# 580         580  ...  -80.498947
# 581         581  ...  -80.321275
# 582         582  ...    8.904113
# 583         583  ... -121.837478
# 584         584  ... -120.212613
# 585         585  ...   95.353979
# 586         586  ...  120.211169
# 587         587  ...         NaN
# 588         588  ...         NaN
# 589         589  ...  -94.379579
# 590         590  ...  -93.692982
# 591         591  ...  -91.143697
# 592         592  ... -119.546232
# 593         593  ...  -83.690021
# 594         594  ...   31.235726
# 595         595  ...  -94.740490
# 596         596  ...  -79.744144
# 597         597  ...  -89.383761
# 598         598  ...  -78.458076
# 599         599  ... -106.586847
# 600         600  ...         NaN
# 601         601  ...  -72.368905
# 602         602  ...  -82.181253
# 603         603  ... -122.328138
# 604         604  ... -122.473705
# 605         605  ...  -87.732439
# 606         606  ... -104.970990
# 607         607  ...  -71.811984
# 608         608  ...  -88.043054
# 609         609  ...  -90.184556
# 610         610  ...         NaN
# 611         611  ...  -91.925761
# 612         612  ...  103.819499
# 613         613  ...  102.265682
# 614         614  ...   80.713785
# 615         615  ...  -79.180299
# 616         616  ...  -83.892523
# 617         617  ... -115.834497
# 618         618  ... -122.619964
# 619         619  ...         NaN
# 620         620  ...  -72.857803
# 621         621  ...  -73.568906
# 622         622  ...         NaN
# 623         623  ...  -80.141184
# 624         624  ...  -99.587382
# 625         625  ...  -70.909213
# 626         626  ...   47.787251
# 627         627  ...  -64.241850
# 628         628  ...  -97.371465
# 629         629  ... -105.110058
# 630         630  ...  -73.996250
# 631         631  ...  -93.128288
# 632         632  ...  -95.506594
# 633         633  ...  -79.936204
# 634         634  ...         NaN
# 635         635  ...  -83.222153
# 636         636  ...   12.374733
# 637         637  ...  -72.290899
# 638         638  ...    4.321417
# 639         639  ...  -82.348806
# 640         640  ...  -95.286430
# 641         641  ...  -84.497039
# 642         642  ...  -71.003737
# 643         643  ... -120.730998
# 644         644  ... -120.653006
# 645         645  ...  -90.719535
# 646         646  ... -123.899773
# 647         647  ...         NaN
# 648         648  ... -120.737257
# 649         649  ...   18.839370
# 650         650  ... -117.810337
# 651         651  ... -100.477668
# 652         652  ...         NaN
# 653         653  ...         NaN
# 654         654  ...   -2.920241
# 655         655  ...  -83.844085
# 656         656  ... -106.761307
# 657         657  ...  -97.510864
# 658         658  ...         NaN
# 659         659  ...  -87.633102
# 660         660  ...         NaN
# 661         661  ... -114.315321
# 662         662  ... -111.044047
# 663         663  ... -111.291890
# 664         664  ...  -82.732931
# 665         665  ...   30.316229
# 666         666  ...  -78.901399
# 667         667  ...  -72.032366
# 668         668  ...         NaN
# 669         669  ... -118.226624
# 670         670  ... -118.419195
# 671         671  ...   -3.276575
# 672         672  ...   -1.869210
# 673         673  ...  -76.918238
# 674         674  ...   -0.145708
# 675         675  ...  -77.040825
# 676         676  ... -117.873221
# 677         677  ... -122.419906
# 678         678  ...  -83.380444
# 679         679  ...  -80.837346
# 680         680  ... -118.517434
# 681         681  ...  -76.792813
# 682         682  ...  -90.616841
# 683         683  ...  -74.172367
# 684         684  ...  -90.078213
# 685         685  ...  -97.605344
# 686         686  ...   18.123672
# 687         687  ...   29.666790
# 688         688  ...   95.999965
# 689         689  ...  -73.968085
# 690         690  ...  -73.968085
# 691         691  ... -111.910312
# 692         692  ...  -93.272139
# 693         693  ...    8.960439
# 694         694  ...         NaN
# 695         695  ...  -89.093966
# 696         696  ...   69.000000
# 697         697  ...  -77.040877
# 698         698  ...         NaN
# 699         699  ... -123.439680
# 700         700  ...   -1.133079
# 701         701  ... -119.551459
# 702         702  ...  -71.251387
# 703         703  ...   -1.706367
# 704         704  ... -121.298071
# 705         705  ...  172.834408
# 706         706  ...  176.917839
# 707         707  ... -157.855676
# 708         708  ... -157.917314
# 709         709  ... -106.931127
# 710         710  ...  -80.840842
# 711         711  ...  114.299935
# 712         712  ...  -95.552282
# 713         713  ...  -90.718934
# 714         714  ... -106.605463
# 715         715  ...  -94.846632
# 716         716  ...  -86.454189
# 717         717  ...  -86.075514
# 718         718  ...   35.546102
# 719         719  ...         NaN
# 720         720  ...   -7.101303
# 721         721  ...  -88.819661
# 722         722  ...   -7.101303
# 723         723  ...  -86.534288
# 724         724  ...         NaN
# 725         725  ...  -84.171314
# 726         726  ...         NaN
# 727         727  ...  -63.580136
# 728         728  ...   -0.902807
# 729         729  ...  -97.317910
# 730         730  ...   -1.973822
# 731         731  ...         NaN
# 732         732  ...         NaN
# 733         733  ...  -76.931677
# 734         734  ...  -76.851869
# 735         735  ...  -76.851869
# 736         736  ...   -2.970190
# 737         737  ...  -97.146670
# 738         738  ...  -82.681102
# 739         739  ... -121.277372
# 740         740  ...  -73.156594
# 741         741  ...  -79.039292
# 742         742  ...   -1.750000
# 743         743  ...    1.574504
# 744         744  ...  -81.339828
# 745         745  ... -105.756164
# 746         746  ...  -93.951050
# 747         747  ...         NaN
# 748         748  ...  -87.882005
# 749         749  ... -111.739231
# 750         750  ... -111.740337
# 751         751  ...  -76.886112
# 752         752  ...  -80.350071
# 753         753  ...  -80.286451
# 754         754  ...  -80.371000
# 755         755  ...  -80.267726
# 756         756  ... -122.410030
# 757         757  ...  -79.265445
# 758         758  ... -104.825349
# 759         759  ...  -75.750997
# 760         760  ...  103.378253
# 761         761  ...   11.575382
# 762         762  ...   -1.795413
# 763         763  ... -121.698419
# 764         764  ...  -84.576062
# 765         765  ...  122.731210
# 766         766  ... -121.592165
# 767         767  ...  120.416667
# 768         768  ...  127.696119
# 769         769  ... -100.348761
# 770         770  ...   -1.081536
# 771         771  ...  -78.873749
# 772         772  ...   -0.220759
# 773         773  ...  -99.747343
# 774         774  ...  -86.851123
# 775         775  ...  -80.141745
# 776         776  ...         NaN
# 777         777  ...  -90.435179
# 778         778  ...  -72.313829
# 779         779  ...  -73.898747
# 780         780  ...  153.093360
# 781         781  ...  -94.794588
# 782         782  ...         NaN
# 783         783  ...  -61.261305
# 784         784  ...  -90.244020
# 785         785  ...  -75.165775
# 786         786  ...         NaN
# 787         787  ...  -83.199040
# 788         788  ...  -95.677556
# 789         789  ...    9.099971
# 790         790  ...  -90.313170
# 791         791  ...  144.757551
# 792         792  ...   76.201220
# 793         793  ...  -78.000055
# 794         794  ...  -79.538929
# 795         795  ...  -71.514104
# 796         796  ...  -71.086995
# 797         797  ...   -0.273261
# 798         798  ...  -73.939569
# 799         799  ...  -74.044539
# 800         800  ...  151.210047
# 801         801  ...  -83.885479
# 802         802  ...  -95.223175
# 803         803  ...  -85.616530
# 804         804  ...    0.118255
# 805         805  ...   -4.700217
# 806         806  ...  -62.743717
# 807         807  ...         NaN
# 808         808  ...  -73.828313
# 809         809  ...  -79.764770
# 810         810  ...  -79.764770
# 811         811  ...  -86.174693
# 812         812  ...  -77.038682
#
# [813 rows x 6 columns]

# %%
ct_mapping
# Out:
#      Unnamed: 0  ...  Longtitude
# 0             0  ...  -93.265469
# 1             1  ...    5.979900
# 2             2  ...    9.009582
# 3             3  ...  -84.390264
# 4             4  ...  -97.988594
# 5             5  ...  -94.611329
# 6             6  ... -100.445882
# 7             7  ... -122.330062
# 8             8  ...  -99.683001
# 9             9  ...  -74.006015
# 10           10  ...  -95.367697
# 11           11  ... -118.755997
# 12           12  ...  -77.036543
# 13           13  ... -118.242766
# 14           14  ...  139.759455
# 15           15  ...  172.834408
# 16           16  ...  -76.938207
# 17           17  ...  139.239418
# 18           18  ...  -87.624421
# 19           19  ...    2.320041
# 20           20  ...    1.888333
# 21           21  ...  -78.492772
# 22           22  ...  -93.093103
# 23           23  ...  -77.036543
# 24           24  ... -115.148516
# 25           25  ...   -0.127647
# 26           26  ...  -73.949721
# 27           27  ...  -95.992911
# 28           28  ... -118.329523
# 29           29  ...  -75.163526
# 30           30  ...  -83.113737
# 31           31  ...  -96.796856
# 32           32  ...  -81.463983
# 33           33  ...  -77.434280
# 34           34  ... -122.271356
# 35           35  ...  -79.039292
# 36           36  ... -122.419906
# 37           37  ...  -84.682435
# 38           38  ...  -74.006015
# 39           39  ... -118.117111
# 40           40  ...  -71.058291
# 41           41  ...  134.755000
# 42           42  ...  -95.374125
# 43           43  ...  -79.990086
# 44           44  ... -112.074142
# 45           45  ...  -72.734216
# 46           46  ... -122.427866
# 47           47  ...         NaN
# 48           48  ...  -87.922497
# 49           49  ...   10.423447
# 50           50  ...  -85.759407
# 51           51  ... -118.755997
# 52           52  ...  -72.734216
# 53           53  ... -100.445882
# 54           54  ...  -81.693445
# 55           55  ...   -2.922520
# 56           56  ...  -98.495141
# 57           57  ...  -82.688140
# 58           58  ...  -90.051629
# 59           59  ...   13.388860
# 60           60  ... -100.445882
# 61           61  ...  -92.561787
# 62           62  ...  -94.611329
# 63           63  ...  -83.221873
# 64           64  ...  -74.006015
# 65           65  ...  -83.046640
# 66           66  ...  -94.157433
# 67           67  ... -111.763275
# 68           68  ...  -72.032366
# 69           69  ...  -76.938207
# 70           70  ...  -78.639099
# 71           71  ... -104.984862
# 72           72  ... -122.674195
# 73           73  ...         NaN
# 74           74  ...   -1.918023
# 75           75  ... -107.991707
# 76           76  ...  -77.036543
# 77           77  ...  -79.039292
# 78           78  ...  -82.458444
# 79           79  ...  -89.688464
# 80           80  ...   -3.276575
# 81           81  ...  -97.268406
# 82           82  ... -117.291156
# 83           83  ...  -89.734850
# 84           84  ...  -78.878392
# 85           85  ... -102.267516
# 86           86  ...  -86.829534
# 87           87  ... -121.493895
# 88           88  ...  102.288096
# 89           89  ...  -86.282008
# 90           90  ...  -74.404162
# 91           91  ...  -86.282008
# 92           92  ...  -79.940273
# 93           93  ... -109.638757
# 94           94  ...         NaN
# 95           95  ...  -90.199585
# 96           96  ...  -74.404162
# 97           97  ...  -73.204835
# 98           98  ...  -76.610759
# 99           99  ...  -97.988594
# 100         100  ...  -92.561787
# 101         101  ...    4.666714
# 102         102  ...  -83.000706
# 103         103  ...  -53.200000
# 104         104  ...   66.238514
# 105         105  ...   -4.837979
# 106         106  ...  -77.850765
# 107         107  ...  121.025875
# 108         108  ...   11.689970
# 109         109  ...  -97.517054
# 110         110  ...  -81.130843
# 111         111  ...         NaN
# 112         112  ...  -85.155141
# 113         113  ...  -80.843083
# 114         114  ...  -78.492772
# 115         115  ... -122.439875
# 116         116  ...   -3.703582
# 117         117  ...   39.049411
# 118         118  ...   10.333328
# 119         119  ...   19.134422
# 120         120  ...   -7.979460
# 121         121  ... -106.779808
# 122         122  ...  -83.323777
# 123         123  ... -119.019464
# 124         124  ...   34.866765
# 125         125  ...  -77.036543
# 126         126  ...   29.894378
# 127         127  ...  -79.039292
# 128         128  ...  -87.789743
# 129         129  ...  -75.765242
# 130         130  ...  -92.007126
# 131         131  ... -112.036277
# 132         132  ...  -89.433729
# 133         133  ...  -16.254088
# 134         134  ...  -84.512460
# 135         135  ...  -89.260060
# 136         136  ...  -77.727883
# 137         137  ...   23.728305
# 138         138  ...   21.987713
# 139         139  ...   -6.260273
# 140         140  ...   36.714575
# 141         141  ...  -99.133178
# 142         142  ...    4.893604
# 143         143  ...    4.351697
# 144         144  ...   12.570072
# 145         145  ...    2.177432
# 146         146  ...  174.763180
# 147         147  ...  -87.674740
# 148         148  ...   -4.555331
# 149         149  ...  -81.463983
# 150         150  ...  -80.436374
# 151         151  ...  -75.119891
# 152         152  ... -118.485635
# 153         153  ... -122.256637
# 154         154  ...  -85.608316
# 155         155  ...  -91.670405
# 156         156  ...  -81.818919
# 157         157  ...  -97.268406
# 158         158  ...  -88.929841
# 159         159  ...   -1.080027
# 160         160  ...  -93.486505
# 161         161  ...  -81.987349
# 162         162  ...  -97.332746
# 163         163  ... -121.990591
# 164         164  ...  -72.500261
# 165         165  ...  -87.580755
# 166         166  ...  -89.688464
# 167         167  ...  -93.589124
# 168         168  ...   11.689970
# 169         169  ...   -1.902691
# 170         170  ...   24.991639
# 171         171  ...  -99.683001
# 172         172  ... -105.993007
# 173         173  ... -111.714358
# 174         174  ...  -80.436374
# 175         175  ... -115.172797
# 176         176  ...  -77.036543
# 177         177  ...  -72.500261
# 178         178  ...  -72.575114
# 179         179  ...  -86.158350
# 180         180  ...   -2.135839
# 181         181  ... -155.428370
# 182         182  ... -117.162773
# 183         183  ...         NaN
# 184         184  ...   12.674297
# 185         185  ...   78.667743
# 186         186  ...  -75.844995
# 187         187  ...  -94.611329
# 188         188  ... -100.540737
# 189         189  ... -112.113055
# 190         190  ...   12.674297
# 191         191  ...  -79.791975
# 192         192  ...  -73.959894
# 193         193  ...   11.045785
# 194         194  ... -109.912162
# 195         195  ...   54.564352
# 196         196  ...   51.262730
# 197         197  ...   71.247499
# 198         198  ... -118.242766
# 199         199  ...  104.999927
# 200         200  ...  -97.997589
# 201         201  ...         NaN
# 202         202  ...  -74.404162
# 203         203  ...         NaN
# 204         204  ...  -92.172427
# 205         205  ...   -0.201238
# 206         206  ... -122.239634
# 207         207  ...  -91.187380
# 208         208  ... -122.391675
# 209         209  ...  -92.332964
# 210         210  ... -119.708861
# 211         211  ...  108.426511
# 212         212  ...  -72.032366
# 213         213  ...  -66.261522
# 214         214  ...  -85.155141
# 215         215  ...  -85.293691
# 216         216  ...         NaN
# 217         217  ... -105.607716
# 218         218  ...  -76.345206
# 219         219  ... -116.853723
# 220         220  ...  -87.676387
# 221         221  ...  -85.378280
# 222         222  ...  -82.161424
# 223         223  ...  -73.099426
# 224         224  ...  -77.615214
# 225         225  ...  -79.976040
# 226         226  ... -117.423511
# 227         227  ...  -93.278334
# 228         228  ...  -72.357097
# 229         229  ...  -92.447911
# 230         230  ...  -80.436374
# 231         231  ...  -97.268406
# 232         232  ...  -92.125122
# 233         233  ...  -74.975711
# 234         234  ...  -86.774298
# 235         235  ...  -94.344488
# 236         236  ...  -84.280933
# 237         237  ...   -4.114052
# 238         238  ...  -93.312270
# 239         239  ... -118.191604
# 240         240  ...  -95.094930
# 241         241  ... -100.217897
# 242         242  ...   -3.276575
# 243         243  ...  -73.878594
# 244         244  ...  -96.703412
# 245         245  ...  120.612966
# 246         246  ...  149.984444
# 247         247  ... -117.870493
# 248         248  ...   67.020706
# 249         249  ... -118.117111
# 250         250  ...  -80.284283
# 251         251  ...  -92.500000
# 252         252  ...  -97.743700
# 253         253  ...  -82.076402
# 254         254  ...         NaN
# 255         255  ...  -71.801888
# 256         256  ...  -90.037576
# 257         257  ...  114.162813
# 258         258  ...  -74.404162
# 259         259  ...  -74.159866
# 260         260  ...  -97.105624
# 261         261  ...  -77.009043
# 262         262  ...    1.046683
# 263         263  ...   34.573134
# 264         264  ...   35.225763
# 265         265  ... -119.613161
# 266         266  ...   38.431397
# 267         267  ...   31.271832
# 268         268  ...  -77.024037
# 269         269  ... -104.987964
# 270         270  ...   11.255576
# 271         271  ... -111.965413
# 272         272  ... -122.777656
# 273         273  ... -121.290780
# 274         274  ... -117.147366
# 275         275  ...  -78.476678
# 276         276  ...  -52.715149
# 277         277  ... -123.302049
# 278         278  ...  -87.216915
# 279         279  ...  -71.537476
# 280         280  ...    9.300651
# 281         281  ...  -72.908813
# 282         282  ... -124.263944
# 283         283  ...  -81.379030
# 284         284  ... -118.499820
# 285         285  ...  -88.914068
# 286         286  ... -118.491227
# 287         287  ...         NaN
# 288         288  ...   -2.754066
# 289         289  ...   -7.336248
# 290         290  ...  121.100360
# 291         291  ...   34.924965
# 292         292  ... -114.015407
# 293         293  ...  -70.975043
# 294         294  ...   15.575748
# 295         295  ...  -71.655399
# 296         296  ...  -80.449417
# 297         297  ...  -78.971078
# 298         298  ...         NaN
# 299         299  ...  151.210047
# 300         300  ...  -83.921026
# 301         301  ...  -88.952415
# 302         302  ...  -88.960238
# 303         303  ...    7.249473
# 304         304  ...  -87.649278
# 305         305  ...  100.532730
# 306         306  ... -119.795634
# 307         307  ...  -87.833269
# 308         308  ...   11.223458
# 309         309  ...  -87.020747
# 310         310  ...   19.999962
# 311         311  ... -118.209681
# 312         312  ...  -78.656398
# 313         313  ...   49.834791
# 314         314  ...   -2.597298
# 315         315  ...    4.399708
# 316         316  ...  -72.650906
# 317         317  ... -118.475953
# 318         318  ...   -7.889626
# 319         319  ...   -1.264906
# 320         320  ...  -75.546589
# 321         321  ...   46.717408
# 322         322  ... -120.737257
# 323         323  ...  -80.135301
# 324         324  ...  -80.193620
# 325         325  ...  -74.415984
# 326         326  ...  -78.998728
# 327         327  ... -110.974848
# 328         328  ...  -74.047455
# 329         329  ... -120.905723
# 330         330  ...  116.391276
# 331         331  ...  -82.398488
# 332         332  ...  -96.247134
# 333         333  ...  -87.358870
# 334         334  ...  -90.595365
# 335         335  ...         NaN
# 336         336  ...  -95.369691
# 337         337  ...  -96.995592
# 338         338  ...  -93.723406
# 339         339  ... -117.435048
# 340         340  ...  -99.813038
# 341         341  ... -116.770628
# 342         342  ...  -75.523423
# 343         343  ...  140.459214
# 344         344  ...  -87.821226
# 345         345  ...  -95.938376
# 346         346  ...  -90.122655
# 347         347  ...  -82.559429
# 348         348  ...  -89.589101
# 349         349  ...  -91.214790
# 350         350  ...  -72.925052
# 351         351  ...  -86.033877
# 352         352  ...  -84.191607
# 353         353  ... -117.911732
# 354         354  ...  -89.643957
# 355         355  ...         NaN
# 356         356  ...  -80.880559
# 357         357  ...  -77.036543
# 358         358  ... -118.242766
# 359         359  ... -111.714358
# 360         360  ...  -83.244371
# 361         361  ... -116.200886
# 362         362  ...  -75.977418
# 363         363  ...  -87.665474
# 364         364  ...  -80.352254
# 365         365  ...  -86.829534
# 366         366  ...  -96.753867
# 367         367  ...   10.523607
# 368         368  ...  -60.955858
# 369         369  ...  -72.758486
# 370         370  ...  -87.756525
# 371         371  ... -120.907089
# 372         372  ...  -81.655651
# 373         373  ...  -90.171799
# 374         374  ...         NaN
# 375         375  ...  -77.036540
# 376         376  ...   -2.002253
# 377         377  ...  -74.517722
# 378         378  ... -121.919747
# 379         379  ...   18.770272
# 380         380  ...    4.284453
# 381         381  ...   34.262717
# 382         382  ... -125.002441
# 383         383  ... -122.333057
# 384         384  ...  -96.731393
# 385         385  ... -100.348761
# 386         386  ...  -70.737736
# 387         387  ...         NaN
# 388         388  ...   29.267547
# 389         389  ... -122.141075
# 390         390  ...   18.871289
# 391         391  ...  -73.945415
# 392         392  ...  -71.064182
# 393         393  ... -122.855373
# 394         394  ...  -77.280393
# 395         395  ... -122.544354
# 396         396  ...  -70.973053
# 397         397  ...  121.090583
# 398         398  ... -117.188454
# 399         399  ...  -77.612135
# 400         400  ... -118.111975
# 401         401  ... -116.153277
# 402         402  ...  -87.940342
# 403         403  ...   29.746841
# 404         404  ...  -80.237270
# 405         405  ...  -74.055255
# 406         406  ...  -70.817310
# 407         407  ...  -78.602238
# 408         408  ...  -53.481842
# 409         409  ...   -1.080027
# 410         410  ...   -2.245115
# 411         411  ...  -73.817429
# 412         412  ...  -73.769721
# 413         413  ...  -93.765194
# 414         414  ...  -80.990371
# 415         415  ...         NaN
# 416         416  ...  -90.303897
# 417         417  ...  -85.654573
# 418         418  ... -106.325138
# 419         419  ...  -73.991228
# 420         420  ...  -47.897921
# 421         421  ... -112.730038
# 422         422  ...         NaN
# 423         423  ...  -84.073910
# 424         424  ...  -72.908813
# 425         425  ...  -81.130843
# 426         426  ...  -76.662665
# 427         427  ...   -1.396725
# 428         428  ...  -92.365186
# 429         429  ...  -86.305444
# 430         430  ...         NaN
# 431         431  ...  -90.184556
# 432         432  ...  -94.611329
# 433         433  ...  -72.536917
# 434         434  ... -122.376771
# 435         435  ...  -78.492772
# 436         436  ...  151.216454
# 437         437  ...  -81.315091
# 438         438  ...   44.174978
# 439         439  ...  -88.281099
# 440         440  ...   17.078078
# 441         441  ...  -74.095290
# 442         442  ...  -89.299846
# 443         443  ...  -72.500261
# 444         444  ... -117.395324
# 445         445  ...  -93.252012
# 446         446  ...  -79.383474
# 447         447  ...  -83.209524
# 448         448  ... -118.325855
# 449         449  ...  -84.379559
# 450         450  ...  -89.267641
# 451         451  ...  -98.908727
# 452         452  ... -104.228475
# 453         453  ...   12.871077
# 454         454  ...  -93.344358
# 455         455  ...  -93.094950
# 456         456  ...  -93.126110
# 457         457  ...    5.387210
# 458         458  ...    3.063528
# 459         459  ...  -76.938207
# 460         460  ...   -6.400888
# 461         461  ...  -77.412756
# 462         462  ...  -77.171091
# 463         463  ...  -84.036872
# 464         464  ...   12.002398
# 465         465  ...  -84.274733
# 466         466  ...  -79.872858
# 467         467  ...  -73.569806
# 468         468  ...   -5.930183
# 469         469  ...  -75.401331
# 470         470  ... -104.827718
# 471         471  ...         NaN
# 472         472  ...  -68.859020
# 473         473  ... -122.291455
# 474         474  ... -118.045577
# 475         475  ... -111.827433
# 476         476  ...  -76.241128
# 477         477  ... -117.840833
# 478         478  ... -103.338396
# 479         479  ...  -76.793625
# 480         480  ...  -97.619994
# 481         481  ...  -97.668884
# 482         482  ...  -97.619994
# 483         483  ...  -73.212906
# 484         484  ...  -89.216655
# 485         485  ... -106.704812
# 486         486  ... -106.695702
# 487         487  ... -121.655037
# 488         488  ...         NaN
# 489         489  ...   -3.129497
# 490         490  ...  -72.690855
# 491         491  ...  -81.537067
# 492         492  ...         NaN
# 493         493  ...   -2.890896
# 494         494  ...  -87.916700
# 495         495  ... -155.081580
# 496         496  ...         NaN
# 497         497  ...   87.301097
# 498         498  ... -156.569845
# 499         499  ...    4.420986
# 500         500  ... -122.562580
# 501         501  ...         NaN
# 502         502  ...   -2.002647
# 503         503  ...  -75.139364
# 504         504  ...  -82.353473
# 505         505  ...         NaN
# 506         506  ...         NaN
# 507         507  ... -115.563051
# 508         508  ...  -75.617647
# 509         509  ...  -75.680057
# 510         510  ... -161.755833
# 511         511  ...  -75.711700
# 512         512  ... -106.464634
# 513         513  ... -122.484974
# 514         514  ...   19.506094
# 515         515  ...  -14.452961
# 516         516  ...   14.520858
# 517         517  ...    8.231974
# 518         518  ...  127.696119
# 519         519  ... -106.532759
# 520         520  ...  -88.419768
# 521         521  ...   97.745306
# 522         522  ...   72.877393
# 523         523  ...   77.221939
# 524         524  ...   -1.017085
# 525         525  ...  -73.188724
# 526         526  ...  -73.105856
# 527         527  ...   -2.856360
# 528         528  ... -123.033121
# 529         529  ...  -74.422935
# 530         530  ...  -93.269357
# 531         531  ...  -58.162446
# 532         532  ... -118.247847
# 533         533  ...  -85.155141
# 534         534  ...  -69.972079
# 535         535  ...  -75.969619
# 536         536  ...   -4.023957
# 537         537  ...  -76.707404
# 538         538  ...  -82.162064
# 539         539  ...  -75.534368
# 540         540  ...  -88.903120
# 541         541  ...   21.006725
# 542         542  ...  -89.538421
# 543         543  ...  -74.325427
# 544         544  ...   -2.716044
# 545         545  ... -122.023015
# 546         546  ...   19.894567
# 547         547  ...  -84.968819
# 548         548  ...  -80.890851
# 549         549  ...  -89.118343
# 550         550  ...  -76.513650
# 551         551  ... -109.791975
# 552         552  ... -114.471884
# 553         553  ...         NaN
# 554         554  ...         NaN
# 555         555  ...  -85.952968
# 556         556  ...   -6.590942
# 557         557  ...  -85.667864
# 558         558  ... -120.739662
# 559         559  ...  -74.149605
# 560         560  ...  -73.894767
# 561         561  ...         NaN
# 562         562  ...    5.345596
# 563         563  ... -122.478836
# 564         564  ...  -94.969401
# 565         565  ...  -97.336627
# 566         566  ...  -97.335696
# 567         567  ...   -0.327471
# 568         568  ...   28.612982
# 569         569  ...  -77.009418
# 570         570  ...  -75.471279
# 571         571  ...  -81.130843
# 572         572  ...   76.517427
# 573         573  ...  -78.957897
# 574         574  ... -117.031417
# 575         575  ...  -94.048104
# 576         576  ...  145.639196
# 577         577  ... -120.510842
# 578         578  ... -120.730253
# 579         579  ...  -95.223175
# 580         580  ...  -80.498947
# 581         581  ...  -80.321275
# 582         582  ...    8.904113
# 583         583  ... -121.837478
# 584         584  ... -120.212613
# 585         585  ...   95.353979
# 586         586  ...  120.211169
# 587         587  ...         NaN
# 588         588  ...         NaN
# 589         589  ...  -94.379579
# 590         590  ...  -93.692982
# 591         591  ...  -91.143697
# 592         592  ... -119.546232
# 593         593  ...  -83.690021
# 594         594  ...   31.235726
# 595         595  ...  -94.740490
# 596         596  ...  -79.744144
# 597         597  ...  -89.383761
# 598         598  ...  -78.458076
# 599         599  ... -106.586847
# 600         600  ...         NaN
# 601         601  ...  -72.368905
# 602         602  ...  -82.181253
# 603         603  ... -122.328138
# 604         604  ... -122.473705
# 605         605  ...  -87.732439
# 606         606  ... -104.970990
# 607         607  ...  -71.811984
# 608         608  ...  -88.043054
# 609         609  ...  -90.184556
# 610         610  ...         NaN
# 611         611  ...  -91.925761
# 612         612  ...  103.819499
# 613         613  ...  102.265682
# 614         614  ...   80.713785
# 615         615  ...  -79.180299
# 616         616  ...  -83.892523
# 617         617  ... -115.834497
# 618         618  ... -122.619964
# 619         619  ...         NaN
# 620         620  ...  -72.857803
# 621         621  ...  -73.568906
# 622         622  ...         NaN
# 623         623  ...  -80.141184
# 624         624  ...  -99.587382
# 625         625  ...  -70.909213
# 626         626  ...   47.787251
# 627         627  ...  -64.241850
# 628         628  ...  -97.371465
# 629         629  ... -105.110058
# 630         630  ...  -73.996250
# 631         631  ...  -93.128288
# 632         632  ...  -95.506594
# 633         633  ...  -79.936204
# 634         634  ...         NaN
# 635         635  ...  -83.222153
# 636         636  ...   12.374733
# 637         637  ...  -72.290899
# 638         638  ...    4.321417
# 639         639  ...  -82.348806
# 640         640  ...  -95.286430
# 641         641  ...  -84.497039
# 642         642  ...  -71.003737
# 643         643  ... -120.730998
# 644         644  ... -120.653006
# 645         645  ...  -90.719535
# 646         646  ... -123.899773
# 647         647  ...         NaN
# 648         648  ... -120.737257
# 649         649  ...   18.839370
# 650         650  ... -117.810337
# 651         651  ... -100.477668
# 652         652  ...         NaN
# 653         653  ...         NaN
# 654         654  ...   -2.920241
# 655         655  ...  -83.844085
# 656         656  ... -106.761307
# 657         657  ...  -97.510864
# 658         658  ...         NaN
# 659         659  ...  -87.633102
# 660         660  ...         NaN
# 661         661  ... -114.315321
# 662         662  ... -111.044047
# 663         663  ... -111.291890
# 664         664  ...  -82.732931
# 665         665  ...   30.316229
# 666         666  ...  -78.901399
# 667         667  ...  -72.032366
# 668         668  ...         NaN
# 669         669  ... -118.226624
# 670         670  ... -118.419195
# 671         671  ...   -3.276575
# 672         672  ...   -1.869210
# 673         673  ...  -76.918238
# 674         674  ...   -0.145708
# 675         675  ...  -77.040825
# 676         676  ... -117.873221
# 677         677  ... -122.419906
# 678         678  ...  -83.380444
# 679         679  ...  -80.837346
# 680         680  ... -118.517434
# 681         681  ...  -76.792813
# 682         682  ...  -90.616841
# 683         683  ...  -74.172367
# 684         684  ...  -90.078213
# 685         685  ...  -97.605344
# 686         686  ...   18.123672
# 687         687  ...   29.666790
# 688         688  ...   95.999965
# 689         689  ...  -73.968085
# 690         690  ...  -73.968085
# 691         691  ... -111.910312
# 692         692  ...  -93.272139
# 693         693  ...    8.960439
# 694         694  ...         NaN
# 695         695  ...  -89.093966
# 696         696  ...   69.000000
# 697         697  ...  -77.040877
# 698         698  ...         NaN
# 699         699  ... -123.439680
# 700         700  ...   -1.133079
# 701         701  ... -119.551459
# 702         702  ...  -71.251387
# 703         703  ...   -1.706367
# 704         704  ... -121.298071
# 705         705  ...  172.834408
# 706         706  ...  176.917839
# 707         707  ... -157.855676
# 708         708  ... -157.917314
# 709         709  ... -106.931127
# 710         710  ...  -80.840842
# 711         711  ...  114.299935
# 712         712  ...  -95.552282
# 713         713  ...  -90.718934
# 714         714  ... -106.605463
# 715         715  ...  -94.846632
# 716         716  ...  -86.454189
# 717         717  ...  -86.075514
# 718         718  ...   35.546102
# 719         719  ...         NaN
# 720         720  ...   -7.101303
# 721         721  ...  -88.819661
# 722         722  ...   -7.101303
# 723         723  ...  -86.534288
# 724         724  ...         NaN
# 725         725  ...  -84.171314
# 726         726  ...         NaN
# 727         727  ...  -63.580136
# 728         728  ...   -0.902807
# 729         729  ...  -97.317910
# 730         730  ...   -1.973822
# 731         731  ...         NaN
# 732         732  ...         NaN
# 733         733  ...  -76.931677
# 734         734  ...  -76.851869
# 735         735  ...  -76.851869
# 736         736  ...   -2.970190
# 737         737  ...  -97.146670
# 738         738  ...  -82.681102
# 739         739  ... -121.277372
# 740         740  ...  -73.156594
# 741         741  ...  -79.039292
# 742         742  ...   -1.750000
# 743         743  ...    1.574504
# 744         744  ...  -81.339828
# 745         745  ... -105.756164
# 746         746  ...  -93.951050
# 747         747  ...         NaN
# 748         748  ...  -87.882005
# 749         749  ... -111.739231
# 750         750  ... -111.740337
# 751         751  ...  -76.886112
# 752         752  ...  -80.350071
# 753         753  ...  -80.286451
# 754         754  ...  -80.371000
# 755         755  ...  -80.267726
# 756         756  ... -122.410030
# 757         757  ...  -79.265445
# 758         758  ... -104.825349
# 759         759  ...  -75.750997
# 760         760  ...  103.378253
# 761         761  ...   11.575382
# 762         762  ...   -1.795413
# 763         763  ... -121.698419
# 764         764  ...  -84.576062
# 765         765  ...  122.731210
# 766         766  ... -121.592165
# 767         767  ...  120.416667
# 768         768  ...  127.696119
# 769         769  ... -100.348761
# 770         770  ...   -1.081536
# 771         771  ...  -78.873749
# 772         772  ...   -0.220759
# 773         773  ...  -99.747343
# 774         774  ...  -86.851123
# 775         775  ...  -80.141745
# 776         776  ...         NaN
# 777         777  ...  -90.435179
# 778         778  ...  -72.313829
# 779         779  ...  -73.898747
# 780         780  ...  153.093360
# 781         781  ...  -94.794588
# 782         782  ...         NaN
# 783         783  ...  -61.261305
# 784         784  ...  -90.244020
# 785         785  ...  -75.165775
# 786         786  ...         NaN
# 787         787  ...  -83.199040
# 788         788  ...  -95.677556
# 789         789  ...    9.099971
# 790         790  ...  -90.313170
# 791         791  ...  144.757551
# 792         792  ...   76.201220
# 793         793  ...  -78.000055
# 794         794  ...  -79.538929
# 795         795  ...  -71.514104
# 796         796  ...  -71.086995
# 797         797  ...   -0.273261
# 798         798  ...  -73.939569
# 799         799  ...  -74.044539
# 800         800  ...  151.210047
# 801         801  ...  -83.885479
# 802         802  ...  -95.223175
# 803         803  ...  -85.616530
# 804         804  ...    0.118255
# 805         805  ...   -4.700217
# 806         806  ...  -62.743717
# 807         807  ...         NaN
# 808         808  ...  -73.828313
# 809         809  ...  -79.764770
# 810         810  ...  -79.764770
# 811         811  ...  -86.174693
# 812         812  ...  -77.038682
#
# [813 rows x 6 columns]

# %%
ct_mapping.to_csv('dataframe_mapping_0614.csv')

# %%
#ct_mapping=pd.read_csv('dataframe_mapping_0530.csv',encoding='ISO-8859-1')

# %%
for k in range(len(ct_ner['NER-1'])):
  list=[]
  for i in ct_ner['NER-1'][k]:
    for j in range(len(ct_mapping['City'])):
      if(i==ct_mapping['City'][j]):
        list.append(ct_mapping['Mapping'][j])
  ct_ner['NER-1'][k]=list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
ct_ner[:100]
# Out:
#     Unnamed: 0  ...                                              NER-1
# 0            0  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 1            1  ...                                                 []
# 2            2  ...  [Dallas, Dallas County, Texas, 75242, United S...
# 3            3  ...  [Dallas, Dallas County, Texas, 75242, United S...
# 4            4  ...                                                 []
# 5            5  ...  [nan, nan, nan, Seattle, King County, Washingt...
# 6            6  ...                                                 []
# 7            7  ...  [nan, London, Greater London, England, SW1A 2D...
# 8            8  ...                                                 []
# 9            9  ...  [nan, Bakersfield, Kern County, California, Un...
# 10          10  ...  [Empire, Stanislaus County, California, 95319,...
# 11          11  ...  [Harris County, Texas, United States, Houston,...
# 12          12  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 13          13  ...  [nan, Chicago, Cook County, Illinois, United S...
# 14          14  ...                                                 []
# 15          15  ...  [nan, Nutley, Essex County, New Jersey, 07110,...
# 16          16  ...  [nan, Baltimore, Maryland, 21203, United State...
# 17          17  ...  [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 18          18  ...                      [æ±äº¬é½, æ¥æ¬, nan, nan]
# 19          19  ...                                              [nan]
# 20          20  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 21          21  ...                                                 []
# 22          22  ...  [Marshfield, Wood County, Wisconsin, 54449, Un...
# 23          23  ...                                                 []
# 24          24  ...                                         [nan, nan]
# 25          25  ...                                              [nan]
# 26          26  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 27          27  ...  [Arlington, Tarrant County, Texas, United States]
# 28          28  ...                                                 []
# 29          29  ...                                                 []
# 30          30  ...                                              [nan]
# 31          31  ...  [West Okc 178 Street, Canadian County, Oklahom...
# 32          32  ...  [Washington, District of Columbia, United Stat...
# 33          33  ...                                                 []
# 34          34  ...                                         [nan, nan]
# 35          35  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 36          36  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 37          37  ...  [Third Ward, Grand Rapids, Kent County, Michig...
# 38          38  ...                                                 []
# 39          39  ...                                         [nan, nan]
# 40          40  ...                                              [nan]
# 41          41  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 42          42  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 43          43  ...                                         [nan, nan]
# 44          44  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 45          45  ...                                                 []
# 46          46  ...                                              [nan]
# 47          47  ...                                                 []
# 48          48  ...                                                 []
# 49          49  ...  [nan, London, Greater London, England, SW1A 2D...
# 50          50  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 51          51  ...  [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 52          52  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 53          53  ...   [Cedar Rapids, Linn County, Iowa, United States]
# 54          54  ...  [Washington, District of Columbia, United Stat...
# 55          55  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 56          56  ...                                                 []
# 57          57  ...                                                 []
# 58          58  ...                                                 []
# 59          59  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 60          60  ...                                              [nan]
# 61          61  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 62          62  ...                                    [nan, nan, nan]
# 63          63  ...                                         [nan, nan]
# 64          64  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 65          65  ...                                         [nan, nan]
# 66          66  ...                                              [nan]
# 67          67  ...                                              [nan]
# 68          68  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 69          69  ...  [Houston, Harris County, Texas, 77002-5902, Un...
# 70          70  ...                                              [nan]
# 71          71  ...                                                 []
# 72          72  ...                                                 []
# 73          73  ...  [Bull Common, Romaldkirk, County Durham, North...
# 74          74  ...                                                 []
# 75          75  ...                                         [nan, nan]
# 76          76  ...  [nan, Suffolk, East of England, England, Unite...
# 77          77  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 78          78  ...                                          [PanamÃ¡]
# 79          79  ...                                              [nan]
# 80          80  ...                                              [nan]
# 81          81  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 82          82  ...                                                 []
# 83          83  ...  [Brooklyn, Kings County, New York, United States]
# 84          84  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 85          85  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 86          86  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 87          87  ...                                              [nan]
# 88          88  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 89          89  ...                                                 []
# 90          90  ...  [nan, Neverland, Carmel-by-the-Sea, Monterey C...
# 91          91  ...                                                 []
# 92          92  ...                                                 []
# 93          93  ...  [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 94          94  ...  [nan, Atlanta, Fulton County, Georgia, 30303-3...
# 95          95  ...                                              [nan]
# 96          96  ...                                                 []
# 97          97  ...  [nan, Great Britain, United Kingdom, nan, nan,...
# 98          98  ...                                                 []
# 99          99  ...                                              [nan]
#
# [100 rows x 53 columns]

# %%
ct_ner['NER-1'][:100]
# Out:
# 0     [Minneapolis, Hennepin County, Minnesota, 5548...
# 1                                                    []
# 2     [Dallas, Dallas County, Texas, 75242, United S...
# 3     [Dallas, Dallas County, Texas, 75242, United S...
# 4                                                    []
# 5     [nan, nan, nan, Seattle, King County, Washingt...
# 6                                                    []
# 7     [nan, London, Greater London, England, SW1A 2D...
# 8                                                    []
# 9     [nan, Bakersfield, Kern County, California, Un...
# 10    [Empire, Stanislaus County, California, 95319,...
# 11    [Harris County, Texas, United States, Houston,...
# 12    [Minneapolis, Hennepin County, Minnesota, 5548...
# 13    [nan, Chicago, Cook County, Illinois, United S...
# 14                                                   []
# 15    [nan, Nutley, Essex County, New Jersey, 07110,...
# 16    [nan, Baltimore, Maryland, 21203, United State...
# 17    [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 18                        [æ±äº¬é½, æ¥æ¬, nan, nan]
# 19                                                [nan]
# 20    [Minneapolis, Hennepin County, Minnesota, 5548...
# 21                                                   []
# 22    [Marshfield, Wood County, Wisconsin, 54449, Un...
# 23                                                   []
# 24                                           [nan, nan]
# 25                                                [nan]
# 26    [Minneapolis, Hennepin County, Minnesota, 5548...
# 27    [Arlington, Tarrant County, Texas, United States]
# 28                                                   []
# 29                                                   []
# 30                                                [nan]
# 31    [West Okc 178 Street, Canadian County, Oklahom...
# 32    [Washington, District of Columbia, United Stat...
# 33                                                   []
# 34                                           [nan, nan]
# 35    [Minneapolis, Hennepin County, Minnesota, 5548...
# 36    [Minneapolis, Hennepin County, Minnesota, 5548...
# 37    [Third Ward, Grand Rapids, Kent County, Michig...
# 38                                                   []
# 39                                           [nan, nan]
# 40                                                [nan]
# 41    [Minneapolis, Hennepin County, Minnesota, 5548...
# 42    [Minneapolis, Hennepin County, Minnesota, 5548...
# 43                                           [nan, nan]
# 44    [Minneapolis, Hennepin County, Minnesota, 5548...
# 45                                                   []
# 46                                                [nan]
# 47                                                   []
# 48                                                   []
# 49    [nan, London, Greater London, England, SW1A 2D...
# 50    [Minneapolis, Hennepin County, Minnesota, 5548...
# 51    [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 52    [Minneapolis, Hennepin County, Minnesota, 5548...
# 53     [Cedar Rapids, Linn County, Iowa, United States]
# 54    [Washington, District of Columbia, United Stat...
# 55    [Minneapolis, Hennepin County, Minnesota, 5548...
# 56                                                   []
# 57                                                   []
# 58                                                   []
# 59    [Minneapolis, Hennepin County, Minnesota, 5548...
# 60                                                [nan]
# 61    [Minneapolis, Hennepin County, Minnesota, 5548...
# 62                                      [nan, nan, nan]
# 63                                           [nan, nan]
# 64    [Minneapolis, Hennepin County, Minnesota, 5548...
# 65                                           [nan, nan]
# 66                                                [nan]
# 67                                                [nan]
# 68    [Minneapolis, Hennepin County, Minnesota, 5548...
# 69    [Houston, Harris County, Texas, 77002-5902, Un...
# 70                                                [nan]
# 71                                                   []
# 72                                                   []
# 73    [Bull Common, Romaldkirk, County Durham, North...
# 74                                                   []
# 75                                           [nan, nan]
# 76    [nan, Suffolk, East of England, England, Unite...
# 77    [Minneapolis, Hennepin County, Minnesota, 5548...
# 78                                            [PanamÃ¡]
# 79                                                [nan]
# 80                                                [nan]
# 81    [Minneapolis, Hennepin County, Minnesota, 5548...
# 82                                                   []
# 83    [Brooklyn, Kings County, New York, United States]
# 84    [Minneapolis, Hennepin County, Minnesota, 5548...
# 85    [Minneapolis, Hennepin County, Minnesota, 5548...
# 86    [nan, Minneapolis, Hennepin County, Minnesota,...
# 87                                                [nan]
# 88    [Minneapolis, Hennepin County, Minnesota, 5548...
# 89                                                   []
# 90    [nan, Neverland, Carmel-by-the-Sea, Monterey C...
# 91                                                   []
# 92                                                   []
# 93    [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 94    [nan, Atlanta, Fulton County, Georgia, 30303-3...
# 95                                                [nan]
# 96                                                   []
# 97    [nan, Great Britain, United Kingdom, nan, nan,...
# 98                                                   []
# 99                                                [nan]
# Name: NER-1, dtype: object

# %%
ct_ner.to_csv('dataframe0614_post_remove.csv')

# %%
# !ls
# Out:
#  Country.txt			 dataframe0611_post.csv
#  dataframe0529_post.csv		 dataframe0611_post_remove.csv
#  dataframe0529_post_remove.csv	 dataframe0614_post_remove.csv
#  dataframe0530_post.csv		 dataframe_mapping
#  dataframe0530_post_remove.csv	 dataframe_mapping_0529.csv
#  dataframe0531_post.csv		 dataframe_mapping_0530.csv
#  dataframe0531_post_remove.csv	 dataframe_mapping_0531.csv
#  dataframe0601_post.csv		 dataframe_mapping_0601.csv
#  dataframe0601_post_remove.csv	 dataframe_mapping_0602.csv
#  dataframe0602_post.csv		 dataframe_mapping_0603.csv
#  dataframe0602_post_remove.csv	 dataframe_mapping_0604.csv
#  dataframe0603_post.csv		 dataframe_mapping_0605.csv
#  dataframe0603_post_remove.csv	 dataframe_mapping_0606.csv
#  dataframe0604_post.csv		 dataframe_mapping_0607.csv
#  dataframe0604_post_remove.csv	 dataframe_mapping_0608.csv
#  dataframe0605_post.csv		 dataframe_mapping_0609.csv
#  dataframe0605_post_remove.csv	 dataframe_mapping_0610.csv
#  dataframe0606_post.csv		 dataframe_mapping_0611.csv
#  dataframe0606_post_remove.csv	 dataframe_mapping_0612.csv
#  dataframe0607_post.csv		 dataframe_mapping_0613.csv
#  dataframe0607_post_remove.csv	 dataframe_mapping_0614.csv
#  dataframe0608_post.csv		 datarframe_post
#  dataframe0608_post_remove.csv	'mapping_US_Cities_Only(1).zip'
#  dataframe0609_post.csv		 mapping_US_Cities_Only.zip
#  dataframe0609_post_remove.csv	 post_specific_mapping_US.zip
#  dataframe0610_post.csv		 states.csv
#  dataframe0610_post_remove.csv
