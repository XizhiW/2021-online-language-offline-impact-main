# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 4.6 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=f3d61579f3b40f20054da44f198bede7a19d2314d6bf8350950696aa20b94b9f
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.1 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK		       dataframe_result_530_UK.csv
#  a0529-a0611_US		       dataframe_result_531_UK.csv
#  a0529.csv		       dataframe_result_csv
#  a0530.csv		       dataframe_result_csv_EU
#  a0601.csv		       dataframe_result_csv_UK
#  a0602.csv		       Github
#  a0603.csv		       heatmap529_UK.ipynb
#  a0604.csv		       heatmap530.ipynb
#  a0607.csv		       Heat_Map_Online_language.ipynb
#  a0608.csv		       __MACOSX
#  ccc_compiled.csv	       mapping_UK
#  csv			       mapping_US
#  csv.zip		       non_violant1.csv
#  dataframe_csv		       non_violant2.csv
#  dataframe_csv_EU	       UK
#  dataframe_csv_UK	       violant.csv
#  dataframe_result_529_UK.csv  '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_601 = 'csv/US06_11.csv'

# %%
ct = pd.read_csv(ct_path_601)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                             platformId  ...                    post_id
# 0       129130583590_10157918601653591  ...   310278|10157918601653591
# 1     228241367217618_4042110949163955  ...   1573929|4042110949163955
# 2       168824166370_10156817898751371  ...    36857|10156817898751371
# 3         7040724713_10159357359084714  ...    25024|10159357359084714
# 4     297620307282279_1123866811324287  ...  11575762|1123866811324287
# ...                                ...  ...                        ...
# 8165    108536136665_10157069661606666  ...    20322|10157069661606666
# 8166     67576374925_10157722257779926  ...    18470|10157722257779926
# 8167    334421824439_10157834098984440  ...    47650|10157834098984440
# 8168     91093559934_10158553449869935  ...    88929|10158553449869935
# 8169     63564314363_10156562638244364  ...    16549|10156562638244364
#
# [8170 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#                                              NER-msg                      NER-desc
# 0                                 {'Minneapolis': 1}                            {}
# 1                                     {'Houston': 1}                {'Houston': 1}
# 2                                                 {}  {'Portland': 1, 'Oregon': 1}
# 3                                                 {}                            {}
# 4  {'Richmond': 3, 'Richmonder': 1, 'Virginia': 3...                            {}

# %%
ct.to_csv('a0611.csv')

# %%
ct=pd.read_csv('a0611.csv')

# %%
# !ls
# Out:
#  a0529-a0611_UK		       dataframe_result_530_UK.csv
#  a0529-a0611_US		       dataframe_result_531_UK.csv
#  a0529.csv		       dataframe_result_csv
#  a0530.csv		       dataframe_result_csv_EU
#  a0601.csv		       dataframe_result_csv_UK
#  a0602.csv		       Github
#  a0603.csv		       heatmap529_UK.ipynb
#  a0604.csv		       heatmap530.ipynb
#  a0607.csv		       Heat_Map_Online_language.ipynb
#  a0608.csv		       __MACOSX
#  a0611.csv		       mapping_UK
#  ccc_compiled.csv	       mapping_US
#  csv			       non_violant1.csv
#  csv.zip		       non_violant2.csv
#  dataframe_csv		       UK
#  dataframe_csv_EU	       violant.csv
#  dataframe_csv_UK	      '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_result_529_UK.csv

# %%
###
#ct=pd.read_csv('a0601.csv')

# %%
ct
# Out:
#       Unnamed: 0  ...           NER-title
# 0              0  ...                  {}
# 1              1  ...                  {}
# 2              2  ...  {'Minneapolis': 1}
# 3              3  ...                  {}
# 4              4  ...                  {}
# ...          ...  ...                 ...
# 8165        8165  ...                  {}
# 8166        8166  ...                  {}
# 8167        8167  ...                  {}
# 8168        8168  ...                  {}
# 8169        8169  ...                  {}
#
# [8170 rows x 51 columns]

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
#ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
###
ct_ner = ct

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                                              NER-msg  ...           NER-title
# 0                                 {'Minneapolis': 1}  ...                  {}
# 1                                     {'Houston': 1}  ...                  {}
# 2                                                 {}  ...  {'Minneapolis': 1}
# 3                                                 {}  ...                  {}
# 4  {'Richmond': 3, 'Richmonder': 1, 'Virginia': 3...  ...                  {}
#
# [5 rows x 3 columns]

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))

# %%
ct_ner['NER-msg']
# Out:
# 0                                           [Minneapolis]
# 1                                               [Houston]
# 2                                                      []
# 3                                                      []
# 4       [Virginia, Minneapolis, Richmond, Charlottesvi...
#                               ...
# 8165                                                   []
# 8166                                           [Richmond]
# 8167                                          [Manhattan]
# 8168                                                   []
# 8169                                                   []
# Name: NER-msg, Length: 8170, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']

# %%
ct_ner['NER']
# Out:
# 0                                           [Minneapolis]
# 1                                      [Houston, Houston]
# 2                         [Portland, Oregon, Minneapolis]
# 3                                                      []
# 4       [Virginia, Minneapolis, Richmond, Charlottesvi...
#                               ...
# 8165                                                   []
# 8166                                           [Richmond]
# 8167                               [Manhattan, Manhattan]
# 8168                [Minn., MINNEAPOLIS, Hennepin County]
# 8169                                            [CHICAGO]
# Name: NER, Length: 8170, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])

# %%
ct_ner
# Out:
#       Unnamed: 0  ...                                                NER
# 0              0  ...                                      [minneapolis]
# 1              1  ...                                          [houston]
# 2              2  ...                    [portland, minneapolis, oregon]
# 3              3  ...                                                 []
# 4              4  ...  [virginia, minneapolis, richmond, charlottesvi...
# ...          ...  ...                                                ...
# 8165        8165  ...                                                 []
# 8166        8166  ...                                         [richmond]
# 8167        8167  ...                                        [manhattan]
# 8168        8168  ...              [minn., minneapolis, hennepin county]
# 8169        8169  ...                                          [chicago]
#
# [8170 rows x 52 columns]

# %%
ct_ner['NER-1']=ct_ner['NER']

# %%
ct_ner['NER-1'][0]
# Out:
# ['minneapolis']

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_ner[:100]
# Out:
#     Unnamed: 0  ...                                              NER-1
# 0            0  ...                                      [minneapolis]
# 1            1  ...                                          [houston]
# 2            2  ...                    [portland, minneapolis, oregon]
# 3            3  ...                                                 []
# 4            4  ...  [virginia, minneapolis, richmond, charlottesvi...
# ..         ...  ...                                                ...
# 95          95  ...                          [zionsville, minneapolis]
# 96          96  ...                                         [columbus]
# 97          97  ...                                         [columbus]
# 98          98  ...                                                 []
# 99          99  ...                              [houston, washington]
#
# [100 rows x 53 columns]

# %%
# %cd mapping_US
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/mapping_US

# %%
# !ls
# Out:
#  Country.txt			 dataframe0610_post.csv
#  dataframe0529_post.csv		 dataframe0610_post_remove.csv
#  dataframe0529_post_remove.csv	 dataframe0611_post.csv
#  dataframe0530_post.csv		 dataframe0611_post_remove.csv
#  dataframe0530_post_remove.csv	 dataframe_mapping
#  dataframe0531_post.csv		 dataframe_mapping_0529.csv
#  dataframe0531_post_remove.csv	 dataframe_mapping_0530.csv
#  dataframe0601_post.csv		 dataframe_mapping_0531.csv
#  dataframe0601_post_remove.csv	 dataframe_mapping_0601.csv
#  dataframe0602_post.csv		 dataframe_mapping_0602.csv
#  dataframe0602_post_remove.csv	 dataframe_mapping_0603.csv
#  dataframe0603_post.csv		 dataframe_mapping_0604.csv
#  dataframe0603_post_remove.csv	 dataframe_mapping_0605.csv
#  dataframe0604_post.csv		 dataframe_mapping_0606.csv
#  dataframe0604_post_remove.csv	 dataframe_mapping_0607.csv
#  dataframe0605_post.csv		 dataframe_mapping_0608.csv
#  dataframe0605_post_remove.csv	 dataframe_mapping_0609.csv
#  dataframe0606_post.csv		 dataframe_mapping_0610.csv
#  dataframe0606_post_remove.csv	 dataframe_mapping_0611.csv
#  dataframe0607_post.csv		 datarframe_post
#  dataframe0607_post_remove.csv	'mapping_US_Cities_Only (1).zip'
#  dataframe0608_post.csv		 mapping_US_Cities_Only.zip
#  dataframe0608_post_remove.csv	 post_specific_mapping_US.zip
#  dataframe0609_post.csv		 states.csv
#  dataframe0609_post_remove.csv

# %%
ct_mapping=pd.read_csv('dataframe_mapping_0611.csv',encoding='ISO-8859-1')

# %%
ct_mapping
# Out:
#       Unnamed: 0                   City  ...   Latitude  Longtitude
# 0              0            minneapolis  ...  44.977300  -93.265469
# 1              1                america  ...  51.437148    5.979900
# 2              2                   u.s.  ...  48.684067    9.009582
# 3              3                houston  ...  29.758938  -95.367697
# 4              4                     us  ...  39.783730 -100.445882
# ...          ...                    ...  ...        ...         ...
# 1358        1358            richmond va  ... -32.865200  151.501200
# 1359        1359  the city of jerusalem  ...  52.949333   -1.152649
# 1360        1360      the city of peace  ...  51.513057   -0.056667
# 1361        1361              watertown  ...  42.370930  -71.182832
# 1362        1362                  bryan  ...  30.674364  -96.369963
#
# [1363 rows x 6 columns]

# %%
country_list=pd.read_csv('Country.txt')
country_list['Name']=country_list['Name'].str.lower()

# %%
country_list['Name']
# Out:
# 0            afghanistan
# 1          �land islands
# 2                albania
# 3                algeria
# 4         american samoa
#              ...
# 250                   us
# 251    the united states
# 252              america
# 253                  u.s
# 254        united states
# Name: Name, Length: 255, dtype: object

# %%
states_list=pd.read_csv('states.csv')
states_list['State']
# Out:
# 0                             Alabama, United States
# 1                              Alaska, United States
# 2                             Arizona, United States
# 3                            Arkansas, United States
# 4                          California, United States
#                            ...
# 165         Armagh, Northern Ireland, United Kingdom
# 166           Down, Northern Ireland, United Kingdom
# 167      Fermanagh, Northern Ireland, United Kingdom
# 168    Londonderry, Northern Ireland, United Kingdom
# 169         Tyrone, Northern Ireland, United Kingdom
# Name: State, Length: 170, dtype: object

# %%
from numpy.core.numeric import NaN
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['City'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(states_list['State'])):
    if ct_mapping['Mapping'][i]==states_list['State'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['Mapping'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN

# %%
pd.set_option('display.max_rows', None)

# %%
ct_mapping
# Out:
#       Unnamed: 0  ...  Longtitude
# 0              0  ...  -93.265469
# 1              1  ...    5.979900
# 2              2  ...    9.009582
# 3              3  ...  -95.367697
# 4              4  ... -100.445882
# 5              5  ...  -77.036543
# 6              6  ...  -97.988594
# 7              7  ...  -94.611329
# 8              8  ...  -99.683001
# 9              9  ... -118.242766
# 10            10  ...  -87.624421
# 11            11  ... -118.755997
# 12            12  ...  -74.006015
# 13            13  ... -122.330062
# 14            14  ...  -78.492772
# 15            15  ...  -68.859020
# 16            16  ...  -72.734216
# 17            17  ...  -77.036543
# 18            18  ...  -71.655399
# 19            19  ...  -77.434280
# 20            20  ...  -83.000706
# 21            21  ...  -94.611329
# 22            22  ...  -74.006015
# 23            23  ...  -72.032366
# 24            24  ...         NaN
# 25            25  ...  -74.404162
# 26            26  ...  -75.163526
# 27            27  ...  -96.796856
# 28            28  ...    4.346369
# 29            29  ...  -89.688464
# 30            30  ...  -81.463983
# 31            31  ...  -77.036543
# 32            32  ... -122.271356
# 33            33  ...  -79.039292
# 34            34  ...  -78.878392
# 35            35  ...  -86.829534
# 36            36  ... -111.714358
# 37            37  ...  -84.390264
# 38            38  ...  -71.058291
# 39            39  ...  -78.492772
# 40            40  ...  -93.486505
# 41            41  ...  -77.727883
# 42            42  ...  -73.972772
# 43            43  ...  -93.093103
# 44            44  ...  -87.922497
# 45            45  ...  -83.113737
# 46            46  ...  -74.006015
# 47            47  ...  -82.688140
# 48            48  ... -120.737257
# 49            49  ... -100.445882
# 50            50  ... -118.191604
# 51            51  ... -111.763275
# 52            52  ...  -97.743700
# 53            53  ...  -89.433729
# 54            54  ... -122.419906
# 55            55  ...   -1.902691
# 56            56  ...  -76.938207
# 57            57  ...  -73.959894
# 58            58  ...         NaN
# 59            59  ... -104.984862
# 60            60  ...  -85.759407
# 61            61  ... -122.674195
# 62            62  ...  -84.682435
# 63            63  ...  -76.610759
# 64            64  ...  -88.007927
# 65            65  ...  -90.241117
# 66            66  ...  -80.193620
# 67            67  ...    2.320041
# 68            68  ...  -94.611329
# 69            69  ... -107.991707
# 70            70  ... -117.870493
# 71            71  ...  -95.992911
# 72            72  ...  134.755000
# 73            73  ...  -83.046640
# 74            74  ...  -74.404162
# 75            75  ...  -93.312270
# 76            76  ... -116.853723
# 77            77  ... -109.638757
# 78            78  ...  -92.561787
# 79            79  ...   -1.080027
# 80            80  ...  104.999927
# 81            81  ...  -92.447911
# 82            82  ...  -92.007126
# 83            83  ...  -97.268406
# 84            84  ...    1.888333
# 85            85  ...  -53.200000
# 86            86  ...   23.728305
# 87            87  ...  -81.655651
# 88            88  ...   10.423447
# 89            89  ...  -98.495141
# 90            90  ...   34.866765
# 91            91  ...  -95.374125
# 92            92  ...  -79.039292
# 93            93  ...  -80.436374
# 94            94  ...  -85.155141
# 95            95  ... -100.445882
# 96            96  ...  -74.404162
# 97            97  ...   13.388860
# 98            98  ...  -94.157433
# 99            99  ...   -1.075614
# 100          100  ...  -78.639099
# 101          101  ...  -90.078213
# 102          102  ...  -95.506594
# 103          103  ...  -78.492772
# 104          104  ...  -76.411419
# 105          105  ...  172.834408
# 106          106  ... -102.267516
# 107          107  ...   -3.276575
# 108          108  ...  -99.683001
# 109          109  ...  -79.990086
# 110          110  ...  -75.844995
# 111          111  ...  -81.379030
# 112          112  ...   12.674297
# 113          113  ...  -97.988594
# 114          114  ...  -81.693445
# 115          115  ...  -86.282008
# 116          116  ...   -4.837979
# 117          117  ... -115.148516
# 118          118  ...         NaN
# 119          119  ...  -79.940273
# 120          120  ...   -1.264906
# 121          121  ...   21.987713
# 122          122  ...   -7.979460
# 123          123  ...  -97.105624
# 124          124  ...   39.049411
# 125          125  ... -100.348761
# 126          126  ...  -93.102220
# 127          127  ...   -6.260273
# 128          128  ...    4.351697
# 129          129  ...   -3.703582
# 130          130  ...   10.333328
# 131          131  ...  -77.040877
# 132          132  ...   54.659387
# 133          133  ...  -87.674740
# 134          134  ...    4.893604
# 135          135  ...   -2.716044
# 136          136  ...  -80.843083
# 137          137  ...   88.263350
# 138          138  ...   36.714575
# 139          139  ...   19.134422
# 140          140  ...    2.177432
# 141          141  ...   12.570072
# 142          142  ...   -0.127647
# 143          143  ... -105.607716
# 144          144  ...  -81.130843
# 145          145  ...  -75.190784
# 146          146  ... -118.242766
# 147          147  ... -118.755997
# 148          148  ...  -99.133178
# 149          149  ...  174.763180
# 150          150  ...  -88.217052
# 151          151  ... -106.464634
# 152          152  ...  -75.546589
# 153          153  ... -120.905723
# 154          154  ... -118.329523
# 155          155  ...  -89.734850
# 156          156  ...  -73.878594
# 157          157  ...   19.999962
# 158          158  ... -122.439875
# 159          159  ...   -1.918023
# 160          160  ...  -72.650906
# 161          161  ...  -77.615214
# 162          162  ...  -97.312770
# 163          163  ...  -85.309488
# 164          164  ...  -75.844995
# 165          165  ...  -77.036543
# 166          166  ...  -77.231787
# 167          167  ... -117.162773
# 168          168  ...  -97.517054
# 169          169  ... -119.812658
# 170          170  ...  150.618500
# 171          171  ...  -78.458076
# 172          172  ...  -73.949721
# 173          173  ...  -77.036543
# 174          174  ... -121.890583
# 175          175  ...  -82.458444
# 176          176  ...   12.452835
# 177          177  ...  -87.782524
# 178          178  ...         NaN
# 179          179  ... -100.217897
# 180          180  ...  -46.633382
# 181          181  ...    4.666714
# 182          182  ...   97.745306
# 183          183  ...  -94.398461
# 184          184  ... -112.074142
# 185          185  ...  -76.938207
# 186          186  ...  -95.938376
# 187          187  ...   24.991639
# 188          188  ...  -80.436374
# 189          189  ... -119.019464
# 190          190  ...  -71.599237
# 191          191  ...  -86.158350
# 192          192  ...  -95.286430
# 193          193  ...   -2.227736
# 194          194  ...   10.523607
# 195          195  ...  -86.774298
# 196          196  ...  -71.089764
# 197          197  ...  -97.332746
# 198          198  ...  -89.589101
# 199          199  ...  -84.191607
# 200          200  ...   26.238017
# 201          201  ... -121.371618
# 202          202  ... -105.993007
# 203          203  ...  -92.125122
# 204          204  ... -116.037247
# 205          205  ...  -74.877931
# 206          206  ...  -86.829534
# 207          207  ... -125.002441
# 208          208  ...  -90.577637
# 209          209  ...  -86.300648
# 210          210  ...   66.238514
# 211          211  ...  -74.172367
# 212          212  ...  -85.138602
# 213          213  ... -121.990591
# 214          214  ...  -84.555380
# 215          215  ...  -77.283685
# 216          216  ...  -79.039292
# 217          217  ... -121.290780
# 218          218  ...  -75.561297
# 219          219  ... -121.929710
# 220          220  ...  -75.844995
# 221          221  ... -116.495298
# 222          222  ...  -80.062998
# 223          223  ... -122.847339
# 224          224  ...  -84.539874
# 225          225  ...  -80.832875
# 226          226  ...  -66.110932
# 227          227  ...         NaN
# 228          228  ...  -87.796281
# 229          229  ...   18.123672
# 230          230  ...   -4.114052
# 231          231  ...  -86.585901
# 232          232  ...  -66.261522
# 233          233  ... -116.770628
# 234          234  ...         NaN
# 235          235  ...  -75.401331
# 236          236  ...    9.009582
# 237          237  ... -149.680909
# 238          238  ...   44.174978
# 239          239  ...  -88.531715
# 240          240  ...   -3.276575
# 241          241  ...  -84.512460
# 242          242  ... -122.256637
# 243          243  ... -117.423511
# 244          244  ...  -77.306373
# 245          245  ...   -0.131255
# 246          246  ...  -89.688464
# 247          247  ...    6.146601
# 248          248  ...  -48.468245
# 249          249  ...  -16.254088
# 250          250  ...  -82.554016
# 251          251  ...   -0.201238
# 252          252  ...  -81.130843
# 253          253  ...  -79.791975
# 254          254  ...  -90.051629
# 255          255  ...  -73.043836
# 256          256  ... -106.650985
# 257          257  ...  172.636646
# 258          258  ... -121.493401
# 259          259  ...  -93.999351
# 260          260  ...   -1.750000
# 261          261  ...         NaN
# 262          262  ... -121.493895
# 263          263  ...  -93.044911
# 264          264  ...  -86.250007
# 265          265  ... -100.348761
# 266          266  ...  -92.974562
# 267          267  ...  -76.938207
# 268          268  ... -110.697357
# 269          269  ...   -3.004175
# 270          270  ...  -85.293691
# 271          271  ...   29.746841
# 272          272  ...  -64.991229
# 273          273  ... -122.312918
# 274          274  ...         NaN
# 275          275  ... -120.737257
# 276          276  ... -121.730488
# 277          277  ...  -95.736666
# 278          278  ...   -2.597298
# 279          279  ...  -76.345206
# 280          280  ... -118.278813
# 281          281  ...  -86.174693
# 282          282  ...  -80.840842
# 283          283  ... -101.427109
# 284          284  ... -123.095051
# 285          285  ...  -82.161424
# 286          286  ... -122.606758
# 287          287  ...  -76.859136
# 288          288  ...  -81.556235
# 289          289  ...  114.162813
# 290          290  ...  -92.289627
# 291          291  ...  -85.155141
# 292          292  ...  -55.992541
# 293          293  ...  -89.383761
# 294          294  ...  -72.500261
# 295          295  ...  -70.975043
# 296          296  ...   -3.075387
# 297          297  ...  -72.690855
# 298          298  ...         NaN
# 299          299  ...  -94.611329
# 300          300  ...  -14.452961
# 301          301  ...  -77.009043
# 302          302  ...   -1.795413
# 303          303  ...  -72.734216
# 304          304  ...  -71.010051
# 305          305  ...  -90.184769
# 306          306  ...  -82.445154
# 307          307  ...  -76.492786
# 308          308  ... -123.113952
# 309          309  ...   -3.183782
# 310          310  ...   -0.197542
# 311          311  ... -123.033121
# 312          312  ...  -93.272139
# 313          313  ... -100.005684
# 314          314  ...  -77.024037
# 315          315  ... -116.434734
# 316          316  ...  -73.817681
# 317          317  ...  -81.987349
# 318          318  ... -117.911732
# 319          319  ...  -85.976667
# 320          320  ...  -73.942500
# 321          321  ...   34.360007
# 322          322  ...  -78.476678
# 323          323  ...         NaN
# 324          324  ... -120.212613
# 325          325  ...  -75.765242
# 326          326  ...  -80.684988
# 327          327  ...  -95.499337
# 328          328  ...  -77.036540
# 329          329  ... -122.159847
# 330          330  ...   29.894378
# 331          331  ...  -97.604165
# 332          332  ...  -77.963960
# 333          333  ...  -85.587229
# 334          334  ...  -79.462243
# 335          335  ...  -90.303897
# 336          336  ...         NaN
# 337          337  ...  -78.998728
# 338          338  ...  135.501389
# 339          339  ...  -86.174693
# 340          340  ...   24.662789
# 341          341  ...  120.814194
# 342          342  ...         NaN
# 343          343  ... -122.203691
# 344          344  ... -122.383893
# 345          345  ... -123.726679
# 346          346  ...    9.400138
# 347          347  ... -117.939535
# 348          348  ... -121.841756
# 349          349  ...  -77.151684
# 350          350  ...  -77.192921
# 351          351  ...  -80.498947
# 352          352  ...  -80.053294
# 353          353  ...  -90.518813
# 354          354  ...  -87.216915
# 355          355  ... -111.910312
# 356          356  ...   54.564352
# 357          357  ...  -79.492033
# 358          358  ... -121.913985
# 359          359  ...         NaN
# 360          360  ...   35.304816
# 361          361  ...  -77.057130
# 362          362  ...  -81.440113
# 363          363  ...  -80.385833
# 364          364  ...  -81.518485
# 365          365  ...  -81.917917
# 366          366  ...  -81.818919
# 367          367  ...  -97.146670
# 368          368  ...  -73.725044
# 369          369  ... -119.342518
# 370          370  ...  -84.280933
# 371          371  ...   78.667743
# 372          372  ...  -80.413677
# 373          373  ...         NaN
# 374          374  ...  -82.161424
# 375          375  ...   49.083416
# 376          376  ... -111.886798
# 377          377  ...  -99.587382
# 378          378  ...   -8.495022
# 379          379  ...  -81.463983
# 380          380  ...  -73.968085
# 381          381  ...  -63.162924
# 382          382  ...  -78.611831
# 383          383  ...  -72.332283
# 384          384  ...  -97.046522
# 385          385  ...  -73.569806
# 386          386  ... -118.242766
# 387          387  ... -122.419260
# 388          388  ... -122.706977
# 389          389  ...  -84.019386
# 390          390  ...  -94.578142
# 391          391  ...  -76.807734
# 392          392  ...   -1.288955
# 393          393  ...  -85.737160
# 394          394  ...  -89.734850
# 395          395  ...  -89.260060
# 396          396  ...  -81.463983
# 397          397  ... -116.853723
# 398          398  ...  -84.472168
# 399          399  ...  -84.494152
# 400          400  ...  -96.731393
# 401          401  ... -102.829096
# 402          402  ...  -96.060719
# 403          403  ...  -76.886112
# 404          404  ...  -76.559448
# 405          405  ...  -86.238946
# 406          406  ...  -86.026204
# 407          407  ...   -0.131175
# 408          408  ... -117.023084
# 409          409  ...  -80.449417
# 410          410  ...  -76.305669
# 411          411  ...  -89.643957
# 412          412  ...  -88.226452
# 413          413  ...  -73.728561
# 414          414  ...  -92.754213
# 415          415  ...  -80.846524
# 416          416  ...  -97.658083
# 417          417  ...  120.612966
# 418          418  ...  -89.250479
# 419          419  ...  -80.315331
# 420          420  ...  -89.688464
# 421          421  ...  -94.846426
# 422          422  ...  -82.076402
# 423          423  ...  -82.955475
# 424          424  ...  -82.902901
# 425          425  ...  -90.616841
# 426          426  ...  -79.930450
# 427          427  ...  -88.419768
# 428          428  ... -118.345355
# 429          429  ...   19.015617
# 430          430  ...  -93.740960
# 431          431  ...  -93.287788
# 432          432  ...   -4.023957
# 433          433  ... -100.784648
# 434          434  ...  -67.507864
# 435          435  ...   71.247499
# 436          436  ...   11.689970
# 437          437  ...  -84.457183
# 438          438  ... -121.995911
# 439          439  ...  -94.170450
# 440          440  ...  -96.247134
# 441          441  ...  -73.099426
# 442          442  ...  -75.273795
# 443          443  ...   78.751471
# 444          444  ...  -75.057950
# 445          445  ...  -73.559224
# 446          446  ...  -89.433729
# 447          447  ...  -88.243093
# 448          448  ...  139.239418
# 449          449  ...  151.210047
# 450          450  ... -120.212613
# 451          451  ...  -75.119891
# 452          452  ...  -70.880049
# 453          453  ...  -71.499599
# 454          454  ...  -86.534288
# 455          455  ...  -82.398488
# 456          456  ...  -82.460953
# 457          457  ...         NaN
# 458          458  ...  -83.613055
# 459          459  ...  -75.750997
# 460          460  ...   47.787251
# 461          461  ...  -77.520549
# 462          462  ...  -77.040877
# 463          463  ...  -74.149605
# 464          464  ...         NaN
# 465          465  ... -108.240386
# 466          466  ...   31.596949
# 467          467  ...         NaN
# 468          468  ...  -92.352621
# 469          469  ...  -84.380084
# 470          470  ...  -82.324985
# 471          471  ...  -82.732931
# 472          472  ...  -90.310344
# 473          473  ...  -95.235950
# 474          474  ...  -85.919524
# 475          475  ...   15.290720
# 476          476  ... -120.691246
# 477          477  ... -120.375716
# 478          478  ...  150.618500
# 479          479  ...  -84.497039
# 480          480  ...  -58.162446
# 481          481  ... -107.991707
# 482          482  ...  151.210047
# 483          483  ...  -95.637226
# 484          484  ...    7.999972
# 485          485  ...    4.469307
# 486          486  ... -155.108330
# 487          487  ...  -94.564563
# 488          488  ...  -89.420064
# 489          489  ...         NaN
# 490          490  ...   12.334590
# 491          491  ...   -1.869210
# 492          492  ... -101.276554
# 493          493  ... -118.421393
# 494          494  ...  -81.498455
# 495          495  ...  -95.671389
# 496          496  ...   35.206188
# 497          497  ...  -83.921026
# 498          498  ...  -91.366715
# 499          499  ...  -87.580755
# 500          500  ...  -98.582750
# 501          501  ...         NaN
# 502          502  ...  -64.729902
# 503          503  ...  -74.405378
# 504          504  ...    1.075095
# 505          505  ... -103.227448
# 506          506  ...  -87.555848
# 507          507  ...   -4.142566
# 508          508  ...  -85.667864
# 509          509  ...    4.526852
# 510          510  ...  -71.801888
# 511          511  ...  -76.509395
# 512          512  ...   -2.437123
# 513          513  ...  -95.552282
# 514          514  ...   -8.593516
# 515          515  ...  -90.440651
# 516          516  ...  -73.954971
# 517          517  ...  -82.515447
# 518          518  ... -116.083314
# 519          519  ...  -73.200669
# 520          520  ...  -73.274720
# 521          521  ...  -73.755133
# 522          522  ...  -73.828313
# 523          523  ...  -74.012082
# 524          524  ...  -91.187380
# 525          525  ...  -76.653188
# 526          526  ...         NaN
# 527          527  ...  -98.295300
# 528          528  ...  -86.851123
# 529          529  ... -122.427866
# 530          530  ...  -97.337545
# 531          531  ...  -99.117889
# 532          532  ...  -84.172164
# 533          533  ...  -84.512460
# 534          534  ...  -84.172164
# 535          535  ... -105.066808
# 536          536  ...   37.793600
# 537          537  ...    5.060290
# 538          538  ...   -2.245819
# 539          539  ...         NaN
# 540          540  ... -155.428370
# 541          541  ...  -94.846632
# 542          542  ...   19.936092
# 543          543  ...  -89.433729
# 544          544  ...         NaN
# 545          545  ...  -84.365168
# 546          546  ...  -81.245914
# 547          547  ...  -98.458984
# 548          548  ...    3.320786
# 549          549  ...   -8.295139
# 550          550  ...  -74.477699
# 551          551  ...  -73.911513
# 552          552  ... -104.825349
# 553          553  ...  -73.952913
# 554          554  ...  -76.792813
# 555          555  ... -116.037247
# 556          556  ...         NaN
# 557          557  ...  -73.681406
# 558          558  ... -111.237757
# 559          559  ...  -99.587382
# 560          560  ...  -80.799719
# 561          561  ...  -94.879901
# 562          562  ...  -83.717410
# 563          563  ...   -8.769902
# 564          564  ... -105.607716
# 565          565  ...  -99.683001
# 566          566  ...  -63.059939
# 567          567  ...   29.491769
# 568          568  ...  -78.394736
# 569          569  ...  -73.967357
# 570          570  ...  -90.150943
# 571          571  ...   -0.604096
# 572          572  ...  -92.414907
# 573          573  ... -120.996878
# 574          574  ...  -74.932140
# 575          575  ...  -52.715149
# 576          576  ...  -73.817429
# 577          577  ...  -93.045699
# 578          578  ...   -2.604220
# 579          579  ...   -2.092809
# 580          580  ... -100.540737
# 581          581  ...  -77.040828
# 582          582  ...   -2.632393
# 583          583  ...  -80.462364
# 584          584  ... -122.061870
# 585          585  ...  -80.344534
# 586          586  ...  -70.978877
# 587          587  ...   12.871077
# 588          588  ...         NaN
# 589          589  ...    2.593583
# 590          590  ...  -87.761417
# 591          591  ...  -69.107556
# 592          592  ...  -97.054434
# 593          593  ...  101.661771
# 594          594  ...  -73.976624
# 595          595  ...  -77.036543
# 596          596  ...  -82.348806
# 597          597  ... -118.247847
# 598          598  ...  -90.406918
# 599          599  ...         NaN
# 600          600  ...   -2.181261
# 601          601  ...  -86.261697
# 602          602  ... -120.345792
# 603          603  ...    2.577310
# 604          604  ...         NaN
# 605          605  ...   73.738398
# 606          606  ...   -4.837979
# 607          607  ... -118.144478
# 608          608  ... -117.751750
# 609          609  ... -117.865339
# 610          610  ... -121.684635
# 611          611  ...  -82.342918
# 612          612  ...         NaN
# 613          613  ...   14.417839
# 614          614  ...  -88.043054
# 615          615  ...  -77.460540
# 616          616  ...  -80.083098
# 617          617  ...  -87.862283
# 618          618  ...  -73.968085
# 619          619  ...  -75.232535
# 620          620  ...  -77.347954
# 621          621  ...  -94.398216
# 622          622  ...   33.145128
# 623          623  ...  -70.982827
# 624          624  ... -122.353534
# 625          625  ... -118.242849
# 626          626  ... -116.495298
# 627          627  ...         NaN
# 628          628  ...  -94.237746
# 629          629  ...  -75.635738
# 630          630  ...   34.054707
# 631          631  ... -111.886798
# 632          632  ...  -76.066613
# 633          633  ...  121.039159
# 634          634  ...  -74.030956
# 635          635  ...         NaN
# 636          636  ...    4.810711
# 637          637  ...         NaN
# 638          638  ...    1.470349
# 639          639  ...  -79.253304
# 640          640  ...  -72.242775
# 641          641  ...   67.020706
# 642          642  ...  -84.237500
# 643          643  ...  136.515328
# 644          644  ...  -73.892382
# 645          645  ...  -84.968819
# 646          646  ...  -81.176486
# 647          647  ... -122.546029
# 648          648  ... -123.844429
# 649          649  ...  -81.915680
# 650          650  ...   -2.620907
# 651          651  ...  -73.996250
# 652          652  ...    8.916885
# 653          653  ...         NaN
# 654          654  ...         NaN
# 655          655  ...  -96.606098
# 656          656  ...  -64.835418
# 657          657  ...  -64.759016
# 658          658  ...  -82.452270
# 659          659  ...  -88.094935
# 660          660  ... -119.119919
# 661          661  ...  -75.401331
# 662          662  ... -118.359259
# 663          663  ...         NaN
# 664          664  ...  -74.363205
# 665          665  ...  -64.755041
# 666          666  ...   12.614667
# 667          667  ...   -8.442790
# 668          668  ... -119.795634
# 669          669  ...         NaN
# 670          670  ...  -88.819661
# 671          671  ... -156.045442
# 672          672  ...  -72.043036
# 673          673  ... -104.871679
# 674          674  ...  120.587918
# 675          675  ...  104.869423
# 676          676  ...   -1.486007
# 677          677  ...   30.316229
# 678          678  ...  -82.988872
# 679          679  ...  -96.797175
# 680          680  ...         NaN
# 681          681  ...   80.738074
# 682          682  ...  -74.544506
# 683          683  ...   -3.210057
# 684          684  ...  -86.401776
# 685          685  ...  -79.744144
# 686          686  ...  -95.918010
# 687          687  ...  -75.977418
# 688          688  ...  -81.507896
# 689          689  ...  -70.299467
# 690          690  ...  -66.115700
# 691          691  ...   77.987712
# 692          692  ...  -73.897749
# 693          693  ...  -73.975694
# 694          694  ...         NaN
# 695          695  ...  -93.484065
# 696          696  ...  -80.081817
# 697          697  ...  -86.250540
# 698          698  ...  -86.033877
# 699          699  ... -105.591101
# 700          700  ...  121.100360
# 701          701  ...  -93.282763
# 702          702  ...  -71.911154
# 703          703  ...  -87.882005
# 704          704  ...  -77.878886
# 705          705  ... -109.087122
# 706          706  ...  -76.241128
# 707          707  ...  -87.734502
# 708          708  ...   14.367117
# 709          709  ...  -73.121221
# 710          710  ...   55.283213
# 711          711  ...  -74.178978
# 712          712  ...  -74.458165
# 713          713  ...  -74.801212
# 714          714  ...   11.597719
# 715          715  ...  -73.691751
# 716          716  ...         NaN
# 717          717  ...  -73.538734
# 718          718  ...  -85.746639
# 719          719  ...  -80.436374
# 720          720  ...  -76.607721
# 721          721  ...  -81.644247
# 722          722  ...         NaN
# 723          723  ...  -77.035210
# 724          724  ...  -94.812744
# 725          725  ...  -94.060140
# 726          726  ...  -94.130165
# 727          727  ...  -81.041473
# 728          728  ... -122.201400
# 729          729  ...         NaN
# 730          730  ... -122.777656
# 731          731  ...  -76.353300
# 732          732  ...  -95.094930
# 733          733  ...  -95.201045
# 734          734  ...  -93.928872
# 735          735  ...  -94.101846
# 736          736  ...  -89.621227
# 737          737  ...  -94.794588
# 738          738  ...  -95.431885
# 739          739  ...   19.205556
# 740          740  ...  -92.561787
# 741          741  ... -114.154018
# 742          742  ...  -95.353426
# 743          743  ... -117.924340
# 744          744  ...  -83.169595
# 745          745  ...  -71.077230
# 746          746  ... -119.278077
# 747          747  ... -118.910588
# 748          748  ...   -9.285937
# 749          749  ...  -76.262190
# 750          750  ...  -75.912526
# 751          751  ...  -88.634774
# 752          752  ...  -70.556125
# 753          753  ...         NaN
# 754          754  ...  -87.714930
# 755          755  ...  -71.412834
# 756          756  ...  -78.781208
# 757          757  ...  120.982018
# 758          758  ... -119.708861
# 759          759  ...         NaN
# 760          760  ...  -73.918748
# 761          761  ...   38.652120
# 762          762  ...    4.178629
# 763          763  ...    2.717444
# 764          764  ...   20.121457
# 765          765  ... -123.782617
# 766          766  ...   13.153581
# 767          767  ...   29.932395
# 768          768  ...   -7.336248
# 769          769  ...    7.489297
# 770          770  ... -105.472691
# 771          771  ... -121.497904
# 772          772  ...  -93.251032
# 773          773  ...    4.399708
# 774          774  ... -159.674138
# 775          775  ... -105.993007
# 776          776  ...  -93.302390
# 777          777  ... -117.566541
# 778          778  ...         NaN
# 779          779  ...  -87.039688
# 780          780  ...  -87.009752
# 781          781  ...  -87.345109
# 782          782  ...  -87.135098
# 783          783  ...  -79.657578
# 784          784  ... -121.387743
# 785          785  ...  -74.574600
# 786          786  ...  114.299935
# 787          787  ...  -80.432280
# 788          788  ...   15.641915
# 789          789  ...  -81.183879
# 790          790  ... -118.445022
# 791          791  ...  -93.268745
# 792          792  ...   73.738398
# 793          793  ...         NaN
# 794          794  ...         NaN
# 795          795  ...  -96.783763
# 796          796  ...  -69.972079
# 797          797  ...   84.091714
# 798          798  ...  -77.036543
# 799          799  ...  -80.065029
# 800          800  ...   34.262717
# 801          801  ...         NaN
# 802          802  ...  108.134501
# 803          803  ...  -92.125122
# 804          804  ...  -77.037559
# 805          805  ... -161.755833
# 806          806  ...  -71.537476
# 807          807  ...  151.584444
# 808          808  ...  -75.680057
# 809          809  ...         NaN
# 810          810  ...  -65.046342
# 811          811  ...         NaN
# 812          812  ...         NaN
# 813          813  ...  -55.910589
# 814          814  ...   -2.471770
# 815          815  ... -102.071297
# 816          816  ... -121.288006
# 817          817  ...  -88.823551
# 818          818  ...  -94.739220
# 819          819  ...  -93.961012
# 820          820  ...  144.954023
# 821          821  ...  -87.553605
# 822          822  ...  139.696662
# 823          823  ...  -75.822991
# 824          824  ...  -74.408208
# 825          825  ...         NaN
# 826          826  ... -116.340778
# 827          827  ...  -81.690556
# 828          828  ...  -96.160237
# 829          829  ...  -99.813038
# 830          830  ...   -1.520557
# 831          831  ... -121.213817
# 832          832  ... -121.235783
# 833          833  ...         NaN
# 834          834  ...  -74.261852
# 835          835  ...  -66.978551
# 836          836  ...  -77.040825
# 837          837  ... -123.782617
# 838          838  ...  -81.268022
# 839          839  ... -121.493895
# 840          840  ...  -95.990706
# 841          841  ...  -93.093103
# 842          842  ...  -79.940273
# 843          843  ...  -90.303897
# 844          844  ...  -89.250479
# 845          845  ...         NaN
# 846          846  ...  -87.970646
# 847          847  ... -122.736919
# 848          848  ...  -77.040825
# 849          849  ...  -73.828299
# 850          850  ...  -95.537722
# 851          851  ...  -77.084159
# 852          852  ...  -77.341883
# 853          853  ...   16.372504
# 854          854  ...         NaN
# 855          855  ...  -74.007257
# 856          856  ...    8.411977
# 857          857  ...  -95.864051
# 858          858  ...  -75.440175
# 859          859  ...  -81.022833
# 860          860  ... -117.939535
# 861          861  ...   -3.585323
# 862          862  ... -122.239634
# 863          863  ...    7.229355
# 864          864  ... -124.263944
# 865          865  ... -121.805789
# 866          866  ...  -95.950723
# 867          867  ...  -88.352571
# 868          868  ...  -76.548071
# 869          869  ...  -72.924818
# 870          870  ...  -80.135301
# 871          871  ...   -1.472801
# 872          872  ...   29.894378
# 873          873  ...   37.372580
# 874          874  ...  -75.732970
# 875          875  ... -122.855373
# 876          876  ... -122.670649
# 877          877  ... -122.803780
# 878          878  ... -122.497174
# 879          879  ... -122.641252
# 880          880  ... -122.430977
# 881          881  ... -122.766351
# 882          882  ... -122.612314
# 883          883  ... -122.989827
# 884          884  ... -122.771933
# 885          885  ...  -73.213607
# 886          886  ...         NaN
# 887          887  ...  139.522699
# 888          888  ...         NaN
# 889          889  ...  -74.252776
# 890          890  ...   -3.014385
# 891          891  ...    0.083333
# 892          892  ...  -93.604665
# 893          893  ... -155.081580
# 894          894  ...   -2.604837
# 895          895  ...  -86.118926
# 896          896  ... -113.484951
# 897          897  ... -117.201176
# 898          898  ...   31.235726
# 899          899  ...  -73.357895
# 900          900  ...  -73.407897
# 901          901  ...  -73.469287
# 902          902  ...   -2.977892
# 903          903  ...  -72.337448
# 904          904  ...  -73.494845
# 905          905  ...  -96.625605
# 906          906  ...   -3.276575
# 907          907  ...   -0.339476
# 908          908  ... -122.319169
# 909          909  ...   -2.922520
# 910          910  ...         NaN
# 911          911  ...  -87.821226
# 912          912  ...  -75.514913
# 913          913  ...   -1.771128
# 914          914  ...  120.963760
# 915          915  ...  -85.369960
# 916          916  ...  -84.822161
# 917          917  ...  -98.340667
# 918          918  ...  -72.332675
# 919          919  ...  -88.217052
# 920          920  ...  -66.750183
# 921          921  ...  -85.155141
# 922          922  ...   34.643359
# 923          923  ...  -82.235219
# 924          924  ...   11.255576
# 925          925  ...         NaN
# 926          926  ...  135.490357
# 927          927  ...  -98.582187
# 928          928  ...  -98.582187
# 929          929  ... -122.089965
# 930          930  ... -121.340938
# 931          931  ...  -86.075514
# 932          932  ...   -1.461170
# 933          933  ...  -93.951050
# 934          934  ...  -93.251289
# 935          935  ...         NaN
# 936          936  ...  -93.765194
# 937          937  ... -122.841709
# 938          938  ...  -79.237636
# 939          939  ... -102.780453
# 940          940  ...  -83.432684
# 941          941  ...  -83.733808
# 942          942  ...  -72.313829
# 943          943  ...  -72.734216
# 944          944  ...  -73.898747
# 945          945  ...  -88.197556
# 946          946  ...   30.903492
# 947          947  ...  -82.421261
# 948          948  ...  -82.355738
# 949          949  ...  -81.581111
# 950          950  ... -118.226624
# 951          951  ...         NaN
# 952          952  ... -123.330202
# 953          953  ...  -80.390081
# 954          954  ...  108.426511
# 955          955  ...  -84.573201
# 956          956  ...  -11.763687
# 957          957  ... -121.997919
# 958          958  ...  -85.299709
# 959          959  ...  -82.681486
# 960          960  ... -121.885323
# 961          961  ...  121.044016
# 962          962  ... -122.312903
# 963          963  ...  -76.831742
# 964          964  ...   -5.930183
# 965          965  ...         NaN
# 966          966  ...         NaN
# 967          967  ...  -58.214058
# 968          968  ...  -82.530855
# 969          969  ...   -0.145708
# 970          970  ...  -75.187843
# 971          971  ...         NaN
# 972          972  ...  -68.618322
# 973          973  ...  -90.241117
# 974          974  ...    6.095467
# 975          975  ...  -76.537764
# 976          976  ...   -1.055909
# 977          977  ...   35.288808
# 978          978  ...   38.431397
# 979          979  ...  -86.809046
# 980          980  ...  -93.255369
# 981          981  ...         NaN
# 982          982  ... -111.651823
# 983          983  ...  -96.964647
# 984          984  ...  -91.020142
# 985          985  ...  -75.769629
# 986          986  ...  -88.010228
# 987          987  ...  -72.908813
# 988          988  ...   -1.207798
# 989          989  ...   -1.133079
# 990          990  ...         NaN
# 991          991  ...   44.571638
# 992          992  ...   34.924965
# 993          993  ...  -99.832064
# 994          994  ...  -72.357097
# 995          995  ...         NaN
# 996          996  ...  125.005855
# 997          997  ...         NaN
# 998          998  ...  -63.229970
# 999          999  ...  121.074947
# 1000        1000  ... -121.277372
# 1001        1001  ... -121.277372
# 1002        1002  ...  -89.338799
# 1003        1003  ...  -93.251032
# 1004        1004  ...  -93.126110
# 1005        1005  ...  -93.344358
# 1006        1006  ... -121.899142
# 1007        1007  ...  -96.920241
# 1008        1008  ... -121.768053
# 1009        1009  ... -122.768160
# 1010        1010  ...         NaN
# 1011        1011  ...  -93.171219
# 1012        1012  ...  -73.970138
# 1013        1013  ...  -85.783935
# 1014        1014  ...  -77.907528
# 1015        1015  ...  -82.162064
# 1016        1016  ...  -85.005679
# 1017        1017  ...  -71.106164
# 1018        1018  ... -118.242899
# 1019        1019  ... -119.180382
# 1020        1020  ...  -70.711613
# 1021        1021  ... -117.435048
# 1022        1022  ...         NaN
# 1023        1023  ...  -95.233086
# 1024        1024  ...  -73.751798
# 1025        1025  ...  115.709162
# 1026        1026  ...  -75.750997
# 1027        1027  ...         NaN
# 1028        1028  ...  -88.202286
# 1029        1029  ...         NaN
# 1030        1030  ...  -87.976657
# 1031        1031  ...    1.313423
# 1032        1032  ...  -71.099358
# 1033        1033  ...  -77.152726
# 1034        1034  ...  -83.000835
# 1035        1035  ...  -98.101119
# 1036        1036  ...  -43.209373
# 1037        1037  ...  -81.501268
# 1038        1038  ...   14.667822
# 1039        1039  ...         NaN
# 1040        1040  ...  -97.335696
# 1041        1041  ...  -96.792023
# 1042        1042  ...  -94.164200
# 1043        1043  ...  -97.058572
# 1044        1044  ...         NaN
# 1045        1045  ...  -95.582343
# 1046        1046  ...  -85.665934
# 1047        1047  ...  -78.857231
# 1048        1048  ...  -78.872204
# 1049        1049  ...         NaN
# 1050        1050  ...         NaN
# 1051        1051  ... -122.192337
# 1052        1052  ...  -83.047556
# 1053        1053  ...   55.292491
# 1054        1054  ...   35.225763
# 1055        1055  ...  -89.771243
# 1056        1056  ...   -0.126540
# 1057        1057  ...  -71.655399
# 1058        1058  ...  -94.890787
# 1059        1059  ... -111.842298
# 1060        1060  ...  -76.009923
# 1061        1061  ...         NaN
# 1062        1062  ...  -84.168827
# 1063        1063  ...  -95.978530
# 1064        1064  ...         NaN
# 1065        1065  ...  -97.988594
# 1066        1066  ...         NaN
# 1067        1067  ... -101.535161
# 1068        1068  ...   21.630538
# 1069        1069  ...  114.160234
# 1070        1070  ...         NaN
# 1071        1071  ...  -72.082003
# 1072        1072  ...         NaN
# 1073        1073  ... -100.894698
# 1074        1074  ...  -82.452270
# 1075        1075  ...         NaN
# 1076        1076  ...  -74.269828
# 1077        1077  ...   19.999962
# 1078        1078  ...  -73.510773
# 1079        1079  ...  -79.874625
# 1080        1080  ...   49.588616
# 1081        1081  ... -122.158578
# 1082        1082  ...  -79.224200
# 1083        1083  ...         NaN
# 1084        1084  ... -117.690075
# 1085        1085  ...   14.248768
# 1086        1086  ...  125.837576
# 1087        1087  ...   29.491769
# 1088        1088  ...   37.999967
# 1089        1089  ...  -94.992736
# 1090        1090  ...  -86.250067
# 1091        1091  ...         NaN
# 1092        1092  ...         NaN
# 1093        1093  ...  -81.091177
# 1094        1094  ...   13.773192
# 1095        1095  ... -118.244663
# 1096        1096  ...   -0.177221
# 1097        1097  ...         NaN
# 1098        1098  ... -111.926018
# 1099        1099  ...  -74.002148
# 1100        1100  ...   34.792518
# 1101        1101  ...   29.267547
# 1102        1102  ...   15.322393
# 1103        1103  ...    6.128885
# 1104        1104  ...  -83.222153
# 1105        1105  ...   -2.245115
# 1106        1106  ...   14.421254
# 1107        1107  ...  -76.116618
# 1108        1108  ...   -3.179193
# 1109        1109  ...   -3.738930
# 1110        1110  ...         NaN
# 1111        1111  ...  -71.811984
# 1112        1112  ...   10.992412
# 1113        1113  ...   25.908847
# 1114        1114  ...   24.592874
# 1115        1115  ...   -0.116796
# 1116        1116  ...    0.529276
# 1117        1117  ... -117.870493
# 1118        1118  ...         NaN
# 1119        1119  ...         NaN
# 1120        1120  ...  -87.141732
# 1121        1121  ... -121.988571
# 1122        1122  ...  105.848779
# 1123        1123  ... -123.943147
# 1124        1124  ... -105.587619
# 1125        1125  ... -105.561361
# 1126        1126  ...   -0.467504
# 1127        1127  ...  -84.298393
# 1128        1128  ...  -36.618593
# 1129        1129  ...  -84.232688
# 1130        1130  ...  -96.042238
# 1131        1131  ... -122.391675
# 1132        1132  ...  -98.510478
# 1133        1133  ...  -86.282008
# 1134        1134  ...  -72.423747
# 1135        1135  ...  -91.701335
# 1136        1136  ... -117.147366
# 1137        1137  ...    1.000000
# 1138        1138  ...  -99.388484
# 1139        1139  ...  -88.952415
# 1140        1140  ... -117.873221
# 1141        1141  ...         NaN
# 1142        1142  ...  -89.629824
# 1143        1143  ...  -97.141342
# 1144        1144  ...         NaN
# 1145        1145  ...  -95.886751
# 1146        1146  ...  -92.014040
# 1147        1147  ...  -90.078213
# 1148        1148  ...   -1.133079
# 1149        1149  ...  -77.040337
# 1150        1150  ...  -91.670405
# 1151        1151  ...  -78.868883
# 1152        1152  ...  -70.877275
# 1153        1153  ...  -78.805186
# 1154        1154  ...  -85.290247
# 1155        1155  ...  -98.086678
# 1156        1156  ...  -81.314539
# 1157        1157  ...  -91.511510
# 1158        1158  ...  -97.141342
# 1159        1159  ...         NaN
# 1160        1160  ...         NaN
# 1161        1161  ...  -89.846107
# 1162        1162  ...  -75.880197
# 1163        1163  ...         NaN
# 1164        1164  ... -110.974848
# 1165        1165  ...         NaN
# 1166        1166  ... -122.134334
# 1167        1167  ...   18.386687
# 1168        1168  ...   -2.534849
# 1169        1169  ...   30.064436
# 1170        1170  ...   30.683651
# 1171        1171  ...  -91.529911
# 1172        1172  ...         NaN
# 1173        1173  ...  -74.155228
# 1174        1174  ...         NaN
# 1175        1175  ...  139.759455
# 1176        1176  ... -104.833333
# 1177        1177  ...  -78.501652
# 1178        1178  ...  -95.036958
# 1179        1179  ...  -96.425005
# 1180        1180  ...         NaN
# 1181        1181  ...  -79.537893
# 1182        1182  ...  -73.940221
# 1183        1183  ...   -7.889626
# 1184        1184  ...    0.731545
# 1185        1185  ...   14.520858
# 1186        1186  ...    5.387210
# 1187        1187  ...  -59.525031
# 1188        1188  ...  -81.379030
# 1189        1189  ...         NaN
# 1190        1190  ...  -73.790755
# 1191        1191  ...  -70.528122
# 1192        1192  ...  -83.956788
# 1193        1193  ...  -93.256375
# 1194        1194  ...  -75.339905
# 1195        1195  ...  -70.945322
# 1196        1196  ...  -85.937436
# 1197        1197  ...  -73.212906
# 1198        1198  ...  -90.515134
# 1199        1199  ...   13.057955
# 1200        1200  ...  -94.124427
# 1201        1201  ...    1.292270
# 1202        1202  ...   -7.952385
# 1203        1203  ...  -86.180703
# 1204        1204  ...  -10.708359
# 1205        1205  ...  -91.090239
# 1206        1206  ...  -77.026922
# 1207        1207  ...  -74.589590
# 1208        1208  ...  -75.150026
# 1209        1209  ... -109.428213
# 1210        1210  ... -124.057095
# 1211        1211  ...  -82.195918
# 1212        1212  ...  -90.389899
# 1213        1213  ... -100.653678
# 1214        1214  ... -105.084204
# 1215        1215  ...         NaN
# 1216        1216  ...  -82.348806
# 1217        1217  ...         NaN
# 1218        1218  ...         NaN
# 1219        1219  ...  145.024898
# 1220        1220  ...  -97.619994
# 1221        1221  ...  -98.269079
# 1222        1222  ...  -98.510478
# 1223        1223  ...  -51.108489
# 1224        1224  ...    4.311346
# 1225        1225  ...    5.387210
# 1226        1226  ... -122.039966
# 1227        1227  ...  -73.754204
# 1228        1228  ...  -79.490337
# 1229        1229  ...  -71.505161
# 1230        1230  ...    3.890227
# 1231        1231  ...  -78.339360
# 1232        1232  ...         NaN
# 1233        1233  ...  -95.058632
# 1234        1234  ... -122.404056
# 1235        1235  ...  -86.031947
# 1236        1236  ... -134.419734
# 1237        1237  ... -118.266192
# 1238        1238  ...  -73.204835
# 1239        1239  ...  -96.958859
# 1240        1240  ...  -97.988594
# 1241        1241  ...  -77.394769
# 1242        1242  ...         NaN
# 1243        1243  ...  -98.527046
# 1244        1244  ...  -74.167111
# 1245        1245  ...  -95.266518
# 1246        1246  ...         NaN
# 1247        1247  ...   -7.336248
# 1248        1248  ...   -2.593004
# 1249        1249  ...  -87.020747
# 1250        1250  ...         NaN
# 1251        1251  ...    6.959974
# 1252        1252  ...  -84.570234
# 1253        1253  ...  -87.765059
# 1254        1254  ...    4.971619
# 1255        1255  ...   12.482932
# 1256        1256  ...  -81.180211
# 1257        1257  ...  -11.191587
# 1258        1258  ...         NaN
# 1259        1259  ... -119.677442
# 1260        1260  ...  -81.995595
# 1261        1261  ...  -81.932016
# 1262        1262  ... -117.946372
# 1263        1263  ...  121.055278
# 1264        1264  ... -112.551597
# 1265        1265  ...  -82.990782
# 1266        1266  ...  -74.047455
# 1267        1267  ... -121.837478
# 1268        1268  ...    9.099971
# 1269        1269  ...  -80.241196
# 1270        1270  ... -105.993007
# 1271        1271  ... -106.779808
# 1272        1272  ... -109.912162
# 1273        1273  ...  -64.967282
# 1274        1274  ...  -76.496802
# 1275        1275  ...  -82.440466
# 1276        1276  ...  -88.147928
# 1277        1277  ...  -88.314754
# 1278        1278  ...  -86.829534
# 1279        1279  ...  -83.380444
# 1280        1280  ...         NaN
# 1281        1281  ...  -82.234238
# 1282        1282  ...  -87.693046
# 1283        1283  ...  -87.756525
# 1284        1284  ...  -90.607080
# 1285        1285  ...  -73.770954
# 1286        1286  ...  -73.939569
# 1287        1287  ...  151.948144
# 1288        1288  ... -120.591102
# 1289        1289  ...  -78.376802
# 1290        1290  ...  -73.034986
# 1291        1291  ...  135.506211
# 1292        1292  ...   -2.158385
# 1293        1293  ...         NaN
# 1294        1294  ...  -82.732931
# 1295        1295  ...  -77.566713
# 1296        1296  ...   15.160548
# 1297        1297  ...         NaN
# 1298        1298  ...  -88.875966
# 1299        1299  ...  121.005349
# 1300        1300  ...         NaN
# 1301        1301  ...  -58.459843
# 1302        1302  ...   18.619444
# 1303        1303  ...  -92.289627
# 1304        1304  ...  -89.118343
# 1305        1305  ...  -94.952522
# 1306        1306  ...         NaN
# 1307        1307  ...   -8.146170
# 1308        1308  ...  -80.990371
# 1309        1309  ...  -73.894102
# 1310        1310  ...  -78.718852
# 1311        1311  ...  -79.487320
# 1312        1312  ...  -61.261305
# 1313        1313  ...  -73.983470
# 1314        1314  ...  -81.379494
# 1315        1315  ...  -81.622507
# 1316        1316  ...   -0.139560
# 1317        1317  ...  -78.754147
# 1318        1318  ...  -81.385638
# 1319        1319  ...         NaN
# 1320        1320  ...  -72.857803
# 1321        1321  ...  -74.041087
# 1322        1322  ...  -77.046287
# 1323        1323  ... -122.453881
# 1324        1324  ...  -80.449417
# 1325        1325  ...         NaN
# 1326        1326  ...         NaN
# 1327        1327  ...  -92.136376
# 1328        1328  ...         NaN
# 1329        1329  ...  -69.865464
# 1330        1330  ...  -69.514714
# 1331        1331  ...  -69.814768
# 1332        1332  ...  -97.089726
# 1333        1333  ...         NaN
# 1334        1334  ...   19.260080
# 1335        1335  ...  -91.169485
# 1336        1336  ...         NaN
# 1337        1337  ...   10.000654
# 1338        1338  ...   11.575382
# 1339        1339  ...         NaN
# 1340        1340  ...   20.081720
# 1341        1341  ...  -72.801221
# 1342        1342  ...  -73.968085
# 1343        1343  ...         NaN
# 1344        1344  ...  -87.940342
# 1345        1345  ...  -80.462364
# 1346        1346  ...  -81.440667
# 1347        1347  ...  -74.055073
# 1348        1348  ... -111.240303
# 1349        1349  ... -118.443773
# 1350        1350  ...  -73.454011
# 1351        1351  ... -122.176821
# 1352        1352  ...  -87.627766
# 1353        1353  ...   -1.251665
# 1354        1354  ...   80.271246
# 1355        1355  ...   37.621566
# 1356        1356  ...  -90.184556
# 1357        1357  ...   -2.208799
# 1358        1358  ...  151.501200
# 1359        1359  ...   -1.152649
# 1360        1360  ...   -0.056667
# 1361        1361  ...  -71.182832
# 1362        1362  ...  -96.369963
#
# [1363 rows x 6 columns]

# %%
ct_mapping
# Out:
#       Unnamed: 0  ...  Longtitude
# 0              0  ...  -93.265469
# 1              1  ...    5.979900
# 2              2  ...    9.009582
# 3              3  ...  -95.367697
# 4              4  ... -100.445882
# 5              5  ...  -77.036543
# 6              6  ...  -97.988594
# 7              7  ...  -94.611329
# 8              8  ...  -99.683001
# 9              9  ... -118.242766
# 10            10  ...  -87.624421
# 11            11  ... -118.755997
# 12            12  ...  -74.006015
# 13            13  ... -122.330062
# 14            14  ...  -78.492772
# 15            15  ...  -68.859020
# 16            16  ...  -72.734216
# 17            17  ...  -77.036543
# 18            18  ...  -71.655399
# 19            19  ...  -77.434280
# 20            20  ...  -83.000706
# 21            21  ...  -94.611329
# 22            22  ...  -74.006015
# 23            23  ...  -72.032366
# 24            24  ...         NaN
# 25            25  ...  -74.404162
# 26            26  ...  -75.163526
# 27            27  ...  -96.796856
# 28            28  ...    4.346369
# 29            29  ...  -89.688464
# 30            30  ...  -81.463983
# 31            31  ...  -77.036543
# 32            32  ... -122.271356
# 33            33  ...  -79.039292
# 34            34  ...  -78.878392
# 35            35  ...  -86.829534
# 36            36  ... -111.714358
# 37            37  ...  -84.390264
# 38            38  ...  -71.058291
# 39            39  ...  -78.492772
# 40            40  ...  -93.486505
# 41            41  ...  -77.727883
# 42            42  ...  -73.972772
# 43            43  ...  -93.093103
# 44            44  ...  -87.922497
# 45            45  ...  -83.113737
# 46            46  ...  -74.006015
# 47            47  ...  -82.688140
# 48            48  ... -120.737257
# 49            49  ... -100.445882
# 50            50  ... -118.191604
# 51            51  ... -111.763275
# 52            52  ...  -97.743700
# 53            53  ...  -89.433729
# 54            54  ... -122.419906
# 55            55  ...   -1.902691
# 56            56  ...  -76.938207
# 57            57  ...  -73.959894
# 58            58  ...         NaN
# 59            59  ... -104.984862
# 60            60  ...  -85.759407
# 61            61  ... -122.674195
# 62            62  ...  -84.682435
# 63            63  ...  -76.610759
# 64            64  ...  -88.007927
# 65            65  ...  -90.241117
# 66            66  ...  -80.193620
# 67            67  ...    2.320041
# 68            68  ...  -94.611329
# 69            69  ... -107.991707
# 70            70  ... -117.870493
# 71            71  ...  -95.992911
# 72            72  ...  134.755000
# 73            73  ...  -83.046640
# 74            74  ...  -74.404162
# 75            75  ...  -93.312270
# 76            76  ... -116.853723
# 77            77  ... -109.638757
# 78            78  ...  -92.561787
# 79            79  ...   -1.080027
# 80            80  ...  104.999927
# 81            81  ...  -92.447911
# 82            82  ...  -92.007126
# 83            83  ...  -97.268406
# 84            84  ...    1.888333
# 85            85  ...  -53.200000
# 86            86  ...   23.728305
# 87            87  ...  -81.655651
# 88            88  ...   10.423447
# 89            89  ...  -98.495141
# 90            90  ...   34.866765
# 91            91  ...  -95.374125
# 92            92  ...  -79.039292
# 93            93  ...  -80.436374
# 94            94  ...  -85.155141
# 95            95  ... -100.445882
# 96            96  ...  -74.404162
# 97            97  ...   13.388860
# 98            98  ...  -94.157433
# 99            99  ...   -1.075614
# 100          100  ...  -78.639099
# 101          101  ...  -90.078213
# 102          102  ...  -95.506594
# 103          103  ...  -78.492772
# 104          104  ...  -76.411419
# 105          105  ...  172.834408
# 106          106  ... -102.267516
# 107          107  ...   -3.276575
# 108          108  ...  -99.683001
# 109          109  ...  -79.990086
# 110          110  ...  -75.844995
# 111          111  ...  -81.379030
# 112          112  ...   12.674297
# 113          113  ...  -97.988594
# 114          114  ...  -81.693445
# 115          115  ...  -86.282008
# 116          116  ...   -4.837979
# 117          117  ... -115.148516
# 118          118  ...         NaN
# 119          119  ...  -79.940273
# 120          120  ...   -1.264906
# 121          121  ...   21.987713
# 122          122  ...   -7.979460
# 123          123  ...  -97.105624
# 124          124  ...   39.049411
# 125          125  ... -100.348761
# 126          126  ...  -93.102220
# 127          127  ...   -6.260273
# 128          128  ...    4.351697
# 129          129  ...   -3.703582
# 130          130  ...   10.333328
# 131          131  ...  -77.040877
# 132          132  ...   54.659387
# 133          133  ...  -87.674740
# 134          134  ...    4.893604
# 135          135  ...   -2.716044
# 136          136  ...  -80.843083
# 137          137  ...   88.263350
# 138          138  ...   36.714575
# 139          139  ...   19.134422
# 140          140  ...    2.177432
# 141          141  ...   12.570072
# 142          142  ...   -0.127647
# 143          143  ... -105.607716
# 144          144  ...  -81.130843
# 145          145  ...  -75.190784
# 146          146  ... -118.242766
# 147          147  ... -118.755997
# 148          148  ...  -99.133178
# 149          149  ...  174.763180
# 150          150  ...  -88.217052
# 151          151  ... -106.464634
# 152          152  ...  -75.546589
# 153          153  ... -120.905723
# 154          154  ... -118.329523
# 155          155  ...  -89.734850
# 156          156  ...  -73.878594
# 157          157  ...   19.999962
# 158          158  ... -122.439875
# 159          159  ...   -1.918023
# 160          160  ...  -72.650906
# 161          161  ...  -77.615214
# 162          162  ...  -97.312770
# 163          163  ...  -85.309488
# 164          164  ...  -75.844995
# 165          165  ...  -77.036543
# 166          166  ...  -77.231787
# 167          167  ... -117.162773
# 168          168  ...  -97.517054
# 169          169  ... -119.812658
# 170          170  ...  150.618500
# 171          171  ...  -78.458076
# 172          172  ...  -73.949721
# 173          173  ...  -77.036543
# 174          174  ... -121.890583
# 175          175  ...  -82.458444
# 176          176  ...   12.452835
# 177          177  ...  -87.782524
# 178          178  ...         NaN
# 179          179  ... -100.217897
# 180          180  ...  -46.633382
# 181          181  ...    4.666714
# 182          182  ...   97.745306
# 183          183  ...  -94.398461
# 184          184  ... -112.074142
# 185          185  ...  -76.938207
# 186          186  ...  -95.938376
# 187          187  ...   24.991639
# 188          188  ...  -80.436374
# 189          189  ... -119.019464
# 190          190  ...  -71.599237
# 191          191  ...  -86.158350
# 192          192  ...  -95.286430
# 193          193  ...   -2.227736
# 194          194  ...   10.523607
# 195          195  ...  -86.774298
# 196          196  ...  -71.089764
# 197          197  ...  -97.332746
# 198          198  ...  -89.589101
# 199          199  ...  -84.191607
# 200          200  ...   26.238017
# 201          201  ... -121.371618
# 202          202  ... -105.993007
# 203          203  ...  -92.125122
# 204          204  ... -116.037247
# 205          205  ...  -74.877931
# 206          206  ...  -86.829534
# 207          207  ... -125.002441
# 208          208  ...  -90.577637
# 209          209  ...  -86.300648
# 210          210  ...   66.238514
# 211          211  ...  -74.172367
# 212          212  ...  -85.138602
# 213          213  ... -121.990591
# 214          214  ...  -84.555380
# 215          215  ...  -77.283685
# 216          216  ...  -79.039292
# 217          217  ... -121.290780
# 218          218  ...  -75.561297
# 219          219  ... -121.929710
# 220          220  ...  -75.844995
# 221          221  ... -116.495298
# 222          222  ...  -80.062998
# 223          223  ... -122.847339
# 224          224  ...  -84.539874
# 225          225  ...  -80.832875
# 226          226  ...  -66.110932
# 227          227  ...         NaN
# 228          228  ...  -87.796281
# 229          229  ...   18.123672
# 230          230  ...   -4.114052
# 231          231  ...  -86.585901
# 232          232  ...  -66.261522
# 233          233  ... -116.770628
# 234          234  ...         NaN
# 235          235  ...  -75.401331
# 236          236  ...    9.009582
# 237          237  ... -149.680909
# 238          238  ...   44.174978
# 239          239  ...  -88.531715
# 240          240  ...   -3.276575
# 241          241  ...  -84.512460
# 242          242  ... -122.256637
# 243          243  ... -117.423511
# 244          244  ...  -77.306373
# 245          245  ...   -0.131255
# 246          246  ...  -89.688464
# 247          247  ...    6.146601
# 248          248  ...  -48.468245
# 249          249  ...  -16.254088
# 250          250  ...  -82.554016
# 251          251  ...   -0.201238
# 252          252  ...  -81.130843
# 253          253  ...  -79.791975
# 254          254  ...  -90.051629
# 255          255  ...  -73.043836
# 256          256  ... -106.650985
# 257          257  ...  172.636646
# 258          258  ... -121.493401
# 259          259  ...  -93.999351
# 260          260  ...   -1.750000
# 261          261  ...         NaN
# 262          262  ... -121.493895
# 263          263  ...  -93.044911
# 264          264  ...  -86.250007
# 265          265  ... -100.348761
# 266          266  ...  -92.974562
# 267          267  ...  -76.938207
# 268          268  ... -110.697357
# 269          269  ...   -3.004175
# 270          270  ...  -85.293691
# 271          271  ...   29.746841
# 272          272  ...  -64.991229
# 273          273  ... -122.312918
# 274          274  ...         NaN
# 275          275  ... -120.737257
# 276          276  ... -121.730488
# 277          277  ...  -95.736666
# 278          278  ...   -2.597298
# 279          279  ...  -76.345206
# 280          280  ... -118.278813
# 281          281  ...  -86.174693
# 282          282  ...  -80.840842
# 283          283  ... -101.427109
# 284          284  ... -123.095051
# 285          285  ...  -82.161424
# 286          286  ... -122.606758
# 287          287  ...  -76.859136
# 288          288  ...  -81.556235
# 289          289  ...  114.162813
# 290          290  ...  -92.289627
# 291          291  ...  -85.155141
# 292          292  ...  -55.992541
# 293          293  ...  -89.383761
# 294          294  ...  -72.500261
# 295          295  ...  -70.975043
# 296          296  ...   -3.075387
# 297          297  ...  -72.690855
# 298          298  ...         NaN
# 299          299  ...  -94.611329
# 300          300  ...  -14.452961
# 301          301  ...  -77.009043
# 302          302  ...   -1.795413
# 303          303  ...  -72.734216
# 304          304  ...  -71.010051
# 305          305  ...  -90.184769
# 306          306  ...  -82.445154
# 307          307  ...  -76.492786
# 308          308  ... -123.113952
# 309          309  ...   -3.183782
# 310          310  ...   -0.197542
# 311          311  ... -123.033121
# 312          312  ...  -93.272139
# 313          313  ... -100.005684
# 314          314  ...  -77.024037
# 315          315  ... -116.434734
# 316          316  ...  -73.817681
# 317          317  ...  -81.987349
# 318          318  ... -117.911732
# 319          319  ...  -85.976667
# 320          320  ...  -73.942500
# 321          321  ...   34.360007
# 322          322  ...  -78.476678
# 323          323  ...         NaN
# 324          324  ... -120.212613
# 325          325  ...  -75.765242
# 326          326  ...  -80.684988
# 327          327  ...  -95.499337
# 328          328  ...  -77.036540
# 329          329  ... -122.159847
# 330          330  ...   29.894378
# 331          331  ...  -97.604165
# 332          332  ...  -77.963960
# 333          333  ...  -85.587229
# 334          334  ...  -79.462243
# 335          335  ...  -90.303897
# 336          336  ...         NaN
# 337          337  ...  -78.998728
# 338          338  ...  135.501389
# 339          339  ...  -86.174693
# 340          340  ...   24.662789
# 341          341  ...  120.814194
# 342          342  ...         NaN
# 343          343  ... -122.203691
# 344          344  ... -122.383893
# 345          345  ... -123.726679
# 346          346  ...    9.400138
# 347          347  ... -117.939535
# 348          348  ... -121.841756
# 349          349  ...  -77.151684
# 350          350  ...  -77.192921
# 351          351  ...  -80.498947
# 352          352  ...  -80.053294
# 353          353  ...  -90.518813
# 354          354  ...  -87.216915
# 355          355  ... -111.910312
# 356          356  ...   54.564352
# 357          357  ...  -79.492033
# 358          358  ... -121.913985
# 359          359  ...         NaN
# 360          360  ...   35.304816
# 361          361  ...  -77.057130
# 362          362  ...  -81.440113
# 363          363  ...  -80.385833
# 364          364  ...  -81.518485
# 365          365  ...  -81.917917
# 366          366  ...  -81.818919
# 367          367  ...  -97.146670
# 368          368  ...  -73.725044
# 369          369  ... -119.342518
# 370          370  ...  -84.280933
# 371          371  ...   78.667743
# 372          372  ...  -80.413677
# 373          373  ...         NaN
# 374          374  ...  -82.161424
# 375          375  ...   49.083416
# 376          376  ... -111.886798
# 377          377  ...  -99.587382
# 378          378  ...   -8.495022
# 379          379  ...  -81.463983
# 380          380  ...  -73.968085
# 381          381  ...  -63.162924
# 382          382  ...  -78.611831
# 383          383  ...  -72.332283
# 384          384  ...  -97.046522
# 385          385  ...  -73.569806
# 386          386  ... -118.242766
# 387          387  ... -122.419260
# 388          388  ... -122.706977
# 389          389  ...  -84.019386
# 390          390  ...  -94.578142
# 391          391  ...  -76.807734
# 392          392  ...   -1.288955
# 393          393  ...  -85.737160
# 394          394  ...  -89.734850
# 395          395  ...  -89.260060
# 396          396  ...  -81.463983
# 397          397  ... -116.853723
# 398          398  ...  -84.472168
# 399          399  ...  -84.494152
# 400          400  ...  -96.731393
# 401          401  ... -102.829096
# 402          402  ...  -96.060719
# 403          403  ...  -76.886112
# 404          404  ...  -76.559448
# 405          405  ...  -86.238946
# 406          406  ...  -86.026204
# 407          407  ...   -0.131175
# 408          408  ... -117.023084
# 409          409  ...  -80.449417
# 410          410  ...  -76.305669
# 411          411  ...  -89.643957
# 412          412  ...  -88.226452
# 413          413  ...  -73.728561
# 414          414  ...  -92.754213
# 415          415  ...  -80.846524
# 416          416  ...  -97.658083
# 417          417  ...  120.612966
# 418          418  ...  -89.250479
# 419          419  ...  -80.315331
# 420          420  ...  -89.688464
# 421          421  ...  -94.846426
# 422          422  ...  -82.076402
# 423          423  ...  -82.955475
# 424          424  ...  -82.902901
# 425          425  ...  -90.616841
# 426          426  ...  -79.930450
# 427          427  ...  -88.419768
# 428          428  ... -118.345355
# 429          429  ...   19.015617
# 430          430  ...  -93.740960
# 431          431  ...  -93.287788
# 432          432  ...   -4.023957
# 433          433  ... -100.784648
# 434          434  ...  -67.507864
# 435          435  ...   71.247499
# 436          436  ...   11.689970
# 437          437  ...  -84.457183
# 438          438  ... -121.995911
# 439          439  ...  -94.170450
# 440          440  ...  -96.247134
# 441          441  ...  -73.099426
# 442          442  ...  -75.273795
# 443          443  ...   78.751471
# 444          444  ...  -75.057950
# 445          445  ...  -73.559224
# 446          446  ...  -89.433729
# 447          447  ...  -88.243093
# 448          448  ...  139.239418
# 449          449  ...  151.210047
# 450          450  ... -120.212613
# 451          451  ...  -75.119891
# 452          452  ...  -70.880049
# 453          453  ...  -71.499599
# 454          454  ...  -86.534288
# 455          455  ...  -82.398488
# 456          456  ...  -82.460953
# 457          457  ...         NaN
# 458          458  ...  -83.613055
# 459          459  ...  -75.750997
# 460          460  ...   47.787251
# 461          461  ...  -77.520549
# 462          462  ...  -77.040877
# 463          463  ...  -74.149605
# 464          464  ...         NaN
# 465          465  ... -108.240386
# 466          466  ...   31.596949
# 467          467  ...         NaN
# 468          468  ...  -92.352621
# 469          469  ...  -84.380084
# 470          470  ...  -82.324985
# 471          471  ...  -82.732931
# 472          472  ...  -90.310344
# 473          473  ...  -95.235950
# 474          474  ...  -85.919524
# 475          475  ...   15.290720
# 476          476  ... -120.691246
# 477          477  ... -120.375716
# 478          478  ...  150.618500
# 479          479  ...  -84.497039
# 480          480  ...  -58.162446
# 481          481  ... -107.991707
# 482          482  ...  151.210047
# 483          483  ...  -95.637226
# 484          484  ...    7.999972
# 485          485  ...    4.469307
# 486          486  ... -155.108330
# 487          487  ...  -94.564563
# 488          488  ...  -89.420064
# 489          489  ...         NaN
# 490          490  ...   12.334590
# 491          491  ...   -1.869210
# 492          492  ... -101.276554
# 493          493  ... -118.421393
# 494          494  ...  -81.498455
# 495          495  ...  -95.671389
# 496          496  ...   35.206188
# 497          497  ...  -83.921026
# 498          498  ...  -91.366715
# 499          499  ...  -87.580755
# 500          500  ...  -98.582750
# 501          501  ...         NaN
# 502          502  ...  -64.729902
# 503          503  ...  -74.405378
# 504          504  ...    1.075095
# 505          505  ... -103.227448
# 506          506  ...  -87.555848
# 507          507  ...   -4.142566
# 508          508  ...  -85.667864
# 509          509  ...    4.526852
# 510          510  ...  -71.801888
# 511          511  ...  -76.509395
# 512          512  ...   -2.437123
# 513          513  ...  -95.552282
# 514          514  ...   -8.593516
# 515          515  ...  -90.440651
# 516          516  ...  -73.954971
# 517          517  ...  -82.515447
# 518          518  ... -116.083314
# 519          519  ...  -73.200669
# 520          520  ...  -73.274720
# 521          521  ...  -73.755133
# 522          522  ...  -73.828313
# 523          523  ...  -74.012082
# 524          524  ...  -91.187380
# 525          525  ...  -76.653188
# 526          526  ...         NaN
# 527          527  ...  -98.295300
# 528          528  ...  -86.851123
# 529          529  ... -122.427866
# 530          530  ...  -97.337545
# 531          531  ...  -99.117889
# 532          532  ...  -84.172164
# 533          533  ...  -84.512460
# 534          534  ...  -84.172164
# 535          535  ... -105.066808
# 536          536  ...   37.793600
# 537          537  ...    5.060290
# 538          538  ...   -2.245819
# 539          539  ...         NaN
# 540          540  ... -155.428370
# 541          541  ...  -94.846632
# 542          542  ...   19.936092
# 543          543  ...  -89.433729
# 544          544  ...         NaN
# 545          545  ...  -84.365168
# 546          546  ...  -81.245914
# 547          547  ...  -98.458984
# 548          548  ...    3.320786
# 549          549  ...   -8.295139
# 550          550  ...  -74.477699
# 551          551  ...  -73.911513
# 552          552  ... -104.825349
# 553          553  ...  -73.952913
# 554          554  ...  -76.792813
# 555          555  ... -116.037247
# 556          556  ...         NaN
# 557          557  ...  -73.681406
# 558          558  ... -111.237757
# 559          559  ...  -99.587382
# 560          560  ...  -80.799719
# 561          561  ...  -94.879901
# 562          562  ...  -83.717410
# 563          563  ...   -8.769902
# 564          564  ... -105.607716
# 565          565  ...  -99.683001
# 566          566  ...  -63.059939
# 567          567  ...   29.491769
# 568          568  ...  -78.394736
# 569          569  ...  -73.967357
# 570          570  ...  -90.150943
# 571          571  ...   -0.604096
# 572          572  ...  -92.414907
# 573          573  ... -120.996878
# 574          574  ...  -74.932140
# 575          575  ...  -52.715149
# 576          576  ...  -73.817429
# 577          577  ...  -93.045699
# 578          578  ...   -2.604220
# 579          579  ...   -2.092809
# 580          580  ... -100.540737
# 581          581  ...  -77.040828
# 582          582  ...   -2.632393
# 583          583  ...  -80.462364
# 584          584  ... -122.061870
# 585          585  ...  -80.344534
# 586          586  ...  -70.978877
# 587          587  ...   12.871077
# 588          588  ...         NaN
# 589          589  ...    2.593583
# 590          590  ...  -87.761417
# 591          591  ...  -69.107556
# 592          592  ...  -97.054434
# 593          593  ...  101.661771
# 594          594  ...  -73.976624
# 595          595  ...  -77.036543
# 596          596  ...  -82.348806
# 597          597  ... -118.247847
# 598          598  ...  -90.406918
# 599          599  ...         NaN
# 600          600  ...   -2.181261
# 601          601  ...  -86.261697
# 602          602  ... -120.345792
# 603          603  ...    2.577310
# 604          604  ...         NaN
# 605          605  ...   73.738398
# 606          606  ...   -4.837979
# 607          607  ... -118.144478
# 608          608  ... -117.751750
# 609          609  ... -117.865339
# 610          610  ... -121.684635
# 611          611  ...  -82.342918
# 612          612  ...         NaN
# 613          613  ...   14.417839
# 614          614  ...  -88.043054
# 615          615  ...  -77.460540
# 616          616  ...  -80.083098
# 617          617  ...  -87.862283
# 618          618  ...  -73.968085
# 619          619  ...  -75.232535
# 620          620  ...  -77.347954
# 621          621  ...  -94.398216
# 622          622  ...   33.145128
# 623          623  ...  -70.982827
# 624          624  ... -122.353534
# 625          625  ... -118.242849
# 626          626  ... -116.495298
# 627          627  ...         NaN
# 628          628  ...  -94.237746
# 629          629  ...  -75.635738
# 630          630  ...   34.054707
# 631          631  ... -111.886798
# 632          632  ...  -76.066613
# 633          633  ...  121.039159
# 634          634  ...  -74.030956
# 635          635  ...         NaN
# 636          636  ...    4.810711
# 637          637  ...         NaN
# 638          638  ...    1.470349
# 639          639  ...  -79.253304
# 640          640  ...  -72.242775
# 641          641  ...   67.020706
# 642          642  ...  -84.237500
# 643          643  ...  136.515328
# 644          644  ...  -73.892382
# 645          645  ...  -84.968819
# 646          646  ...  -81.176486
# 647          647  ... -122.546029
# 648          648  ... -123.844429
# 649          649  ...  -81.915680
# 650          650  ...   -2.620907
# 651          651  ...  -73.996250
# 652          652  ...    8.916885
# 653          653  ...         NaN
# 654          654  ...         NaN
# 655          655  ...  -96.606098
# 656          656  ...  -64.835418
# 657          657  ...  -64.759016
# 658          658  ...  -82.452270
# 659          659  ...  -88.094935
# 660          660  ... -119.119919
# 661          661  ...  -75.401331
# 662          662  ... -118.359259
# 663          663  ...         NaN
# 664          664  ...  -74.363205
# 665          665  ...  -64.755041
# 666          666  ...   12.614667
# 667          667  ...   -8.442790
# 668          668  ... -119.795634
# 669          669  ...         NaN
# 670          670  ...  -88.819661
# 671          671  ... -156.045442
# 672          672  ...  -72.043036
# 673          673  ... -104.871679
# 674          674  ...  120.587918
# 675          675  ...  104.869423
# 676          676  ...   -1.486007
# 677          677  ...   30.316229
# 678          678  ...  -82.988872
# 679          679  ...  -96.797175
# 680          680  ...         NaN
# 681          681  ...   80.738074
# 682          682  ...  -74.544506
# 683          683  ...   -3.210057
# 684          684  ...  -86.401776
# 685          685  ...  -79.744144
# 686          686  ...  -95.918010
# 687          687  ...  -75.977418
# 688          688  ...  -81.507896
# 689          689  ...  -70.299467
# 690          690  ...  -66.115700
# 691          691  ...   77.987712
# 692          692  ...  -73.897749
# 693          693  ...  -73.975694
# 694          694  ...         NaN
# 695          695  ...  -93.484065
# 696          696  ...  -80.081817
# 697          697  ...  -86.250540
# 698          698  ...  -86.033877
# 699          699  ... -105.591101
# 700          700  ...  121.100360
# 701          701  ...  -93.282763
# 702          702  ...  -71.911154
# 703          703  ...  -87.882005
# 704          704  ...  -77.878886
# 705          705  ... -109.087122
# 706          706  ...  -76.241128
# 707          707  ...  -87.734502
# 708          708  ...   14.367117
# 709          709  ...  -73.121221
# 710          710  ...   55.283213
# 711          711  ...  -74.178978
# 712          712  ...  -74.458165
# 713          713  ...  -74.801212
# 714          714  ...   11.597719
# 715          715  ...  -73.691751
# 716          716  ...         NaN
# 717          717  ...  -73.538734
# 718          718  ...  -85.746639
# 719          719  ...  -80.436374
# 720          720  ...  -76.607721
# 721          721  ...  -81.644247
# 722          722  ...         NaN
# 723          723  ...  -77.035210
# 724          724  ...  -94.812744
# 725          725  ...  -94.060140
# 726          726  ...  -94.130165
# 727          727  ...  -81.041473
# 728          728  ... -122.201400
# 729          729  ...         NaN
# 730          730  ... -122.777656
# 731          731  ...  -76.353300
# 732          732  ...  -95.094930
# 733          733  ...  -95.201045
# 734          734  ...  -93.928872
# 735          735  ...  -94.101846
# 736          736  ...  -89.621227
# 737          737  ...  -94.794588
# 738          738  ...  -95.431885
# 739          739  ...   19.205556
# 740          740  ...  -92.561787
# 741          741  ... -114.154018
# 742          742  ...  -95.353426
# 743          743  ... -117.924340
# 744          744  ...  -83.169595
# 745          745  ...  -71.077230
# 746          746  ... -119.278077
# 747          747  ... -118.910588
# 748          748  ...   -9.285937
# 749          749  ...  -76.262190
# 750          750  ...  -75.912526
# 751          751  ...  -88.634774
# 752          752  ...  -70.556125
# 753          753  ...         NaN
# 754          754  ...  -87.714930
# 755          755  ...  -71.412834
# 756          756  ...  -78.781208
# 757          757  ...  120.982018
# 758          758  ... -119.708861
# 759          759  ...         NaN
# 760          760  ...  -73.918748
# 761          761  ...   38.652120
# 762          762  ...    4.178629
# 763          763  ...    2.717444
# 764          764  ...   20.121457
# 765          765  ... -123.782617
# 766          766  ...   13.153581
# 767          767  ...   29.932395
# 768          768  ...   -7.336248
# 769          769  ...    7.489297
# 770          770  ... -105.472691
# 771          771  ... -121.497904
# 772          772  ...  -93.251032
# 773          773  ...    4.399708
# 774          774  ... -159.674138
# 775          775  ... -105.993007
# 776          776  ...  -93.302390
# 777          777  ... -117.566541
# 778          778  ...         NaN
# 779          779  ...  -87.039688
# 780          780  ...  -87.009752
# 781          781  ...  -87.345109
# 782          782  ...  -87.135098
# 783          783  ...  -79.657578
# 784          784  ... -121.387743
# 785          785  ...  -74.574600
# 786          786  ...  114.299935
# 787          787  ...  -80.432280
# 788          788  ...   15.641915
# 789          789  ...  -81.183879
# 790          790  ... -118.445022
# 791          791  ...  -93.268745
# 792          792  ...   73.738398
# 793          793  ...         NaN
# 794          794  ...         NaN
# 795          795  ...  -96.783763
# 796          796  ...  -69.972079
# 797          797  ...   84.091714
# 798          798  ...  -77.036543
# 799          799  ...  -80.065029
# 800          800  ...   34.262717
# 801          801  ...         NaN
# 802          802  ...  108.134501
# 803          803  ...  -92.125122
# 804          804  ...  -77.037559
# 805          805  ... -161.755833
# 806          806  ...  -71.537476
# 807          807  ...  151.584444
# 808          808  ...  -75.680057
# 809          809  ...         NaN
# 810          810  ...  -65.046342
# 811          811  ...         NaN
# 812          812  ...         NaN
# 813          813  ...  -55.910589
# 814          814  ...   -2.471770
# 815          815  ... -102.071297
# 816          816  ... -121.288006
# 817          817  ...  -88.823551
# 818          818  ...  -94.739220
# 819          819  ...  -93.961012
# 820          820  ...  144.954023
# 821          821  ...  -87.553605
# 822          822  ...  139.696662
# 823          823  ...  -75.822991
# 824          824  ...  -74.408208
# 825          825  ...         NaN
# 826          826  ... -116.340778
# 827          827  ...  -81.690556
# 828          828  ...  -96.160237
# 829          829  ...  -99.813038
# 830          830  ...   -1.520557
# 831          831  ... -121.213817
# 832          832  ... -121.235783
# 833          833  ...         NaN
# 834          834  ...  -74.261852
# 835          835  ...  -66.978551
# 836          836  ...  -77.040825
# 837          837  ... -123.782617
# 838          838  ...  -81.268022
# 839          839  ... -121.493895
# 840          840  ...  -95.990706
# 841          841  ...  -93.093103
# 842          842  ...  -79.940273
# 843          843  ...  -90.303897
# 844          844  ...  -89.250479
# 845          845  ...         NaN
# 846          846  ...  -87.970646
# 847          847  ... -122.736919
# 848          848  ...  -77.040825
# 849          849  ...  -73.828299
# 850          850  ...  -95.537722
# 851          851  ...  -77.084159
# 852          852  ...  -77.341883
# 853          853  ...   16.372504
# 854          854  ...         NaN
# 855          855  ...  -74.007257
# 856          856  ...    8.411977
# 857          857  ...  -95.864051
# 858          858  ...  -75.440175
# 859          859  ...  -81.022833
# 860          860  ... -117.939535
# 861          861  ...   -3.585323
# 862          862  ... -122.239634
# 863          863  ...    7.229355
# 864          864  ... -124.263944
# 865          865  ... -121.805789
# 866          866  ...  -95.950723
# 867          867  ...  -88.352571
# 868          868  ...  -76.548071
# 869          869  ...  -72.924818
# 870          870  ...  -80.135301
# 871          871  ...   -1.472801
# 872          872  ...   29.894378
# 873          873  ...   37.372580
# 874          874  ...  -75.732970
# 875          875  ... -122.855373
# 876          876  ... -122.670649
# 877          877  ... -122.803780
# 878          878  ... -122.497174
# 879          879  ... -122.641252
# 880          880  ... -122.430977
# 881          881  ... -122.766351
# 882          882  ... -122.612314
# 883          883  ... -122.989827
# 884          884  ... -122.771933
# 885          885  ...  -73.213607
# 886          886  ...         NaN
# 887          887  ...  139.522699
# 888          888  ...         NaN
# 889          889  ...  -74.252776
# 890          890  ...   -3.014385
# 891          891  ...    0.083333
# 892          892  ...  -93.604665
# 893          893  ... -155.081580
# 894          894  ...   -2.604837
# 895          895  ...  -86.118926
# 896          896  ... -113.484951
# 897          897  ... -117.201176
# 898          898  ...   31.235726
# 899          899  ...  -73.357895
# 900          900  ...  -73.407897
# 901          901  ...  -73.469287
# 902          902  ...   -2.977892
# 903          903  ...  -72.337448
# 904          904  ...  -73.494845
# 905          905  ...  -96.625605
# 906          906  ...   -3.276575
# 907          907  ...   -0.339476
# 908          908  ... -122.319169
# 909          909  ...   -2.922520
# 910          910  ...         NaN
# 911          911  ...  -87.821226
# 912          912  ...  -75.514913
# 913          913  ...   -1.771128
# 914          914  ...  120.963760
# 915          915  ...  -85.369960
# 916          916  ...  -84.822161
# 917          917  ...  -98.340667
# 918          918  ...  -72.332675
# 919          919  ...  -88.217052
# 920          920  ...  -66.750183
# 921          921  ...  -85.155141
# 922          922  ...   34.643359
# 923          923  ...  -82.235219
# 924          924  ...   11.255576
# 925          925  ...         NaN
# 926          926  ...  135.490357
# 927          927  ...  -98.582187
# 928          928  ...  -98.582187
# 929          929  ... -122.089965
# 930          930  ... -121.340938
# 931          931  ...  -86.075514
# 932          932  ...   -1.461170
# 933          933  ...  -93.951050
# 934          934  ...  -93.251289
# 935          935  ...         NaN
# 936          936  ...  -93.765194
# 937          937  ... -122.841709
# 938          938  ...  -79.237636
# 939          939  ... -102.780453
# 940          940  ...  -83.432684
# 941          941  ...  -83.733808
# 942          942  ...  -72.313829
# 943          943  ...  -72.734216
# 944          944  ...  -73.898747
# 945          945  ...  -88.197556
# 946          946  ...   30.903492
# 947          947  ...  -82.421261
# 948          948  ...  -82.355738
# 949          949  ...  -81.581111
# 950          950  ... -118.226624
# 951          951  ...         NaN
# 952          952  ... -123.330202
# 953          953  ...  -80.390081
# 954          954  ...  108.426511
# 955          955  ...  -84.573201
# 956          956  ...  -11.763687
# 957          957  ... -121.997919
# 958          958  ...  -85.299709
# 959          959  ...  -82.681486
# 960          960  ... -121.885323
# 961          961  ...  121.044016
# 962          962  ... -122.312903
# 963          963  ...  -76.831742
# 964          964  ...   -5.930183
# 965          965  ...         NaN
# 966          966  ...         NaN
# 967          967  ...  -58.214058
# 968          968  ...  -82.530855
# 969          969  ...   -0.145708
# 970          970  ...  -75.187843
# 971          971  ...         NaN
# 972          972  ...  -68.618322
# 973          973  ...  -90.241117
# 974          974  ...    6.095467
# 975          975  ...  -76.537764
# 976          976  ...   -1.055909
# 977          977  ...   35.288808
# 978          978  ...   38.431397
# 979          979  ...  -86.809046
# 980          980  ...  -93.255369
# 981          981  ...         NaN
# 982          982  ... -111.651823
# 983          983  ...  -96.964647
# 984          984  ...  -91.020142
# 985          985  ...  -75.769629
# 986          986  ...  -88.010228
# 987          987  ...  -72.908813
# 988          988  ...   -1.207798
# 989          989  ...   -1.133079
# 990          990  ...         NaN
# 991          991  ...   44.571638
# 992          992  ...   34.924965
# 993          993  ...  -99.832064
# 994          994  ...  -72.357097
# 995          995  ...         NaN
# 996          996  ...  125.005855
# 997          997  ...         NaN
# 998          998  ...  -63.229970
# 999          999  ...  121.074947
# 1000        1000  ... -121.277372
# 1001        1001  ... -121.277372
# 1002        1002  ...  -89.338799
# 1003        1003  ...  -93.251032
# 1004        1004  ...  -93.126110
# 1005        1005  ...  -93.344358
# 1006        1006  ... -121.899142
# 1007        1007  ...  -96.920241
# 1008        1008  ... -121.768053
# 1009        1009  ... -122.768160
# 1010        1010  ...         NaN
# 1011        1011  ...  -93.171219
# 1012        1012  ...  -73.970138
# 1013        1013  ...  -85.783935
# 1014        1014  ...  -77.907528
# 1015        1015  ...  -82.162064
# 1016        1016  ...  -85.005679
# 1017        1017  ...  -71.106164
# 1018        1018  ... -118.242899
# 1019        1019  ... -119.180382
# 1020        1020  ...  -70.711613
# 1021        1021  ... -117.435048
# 1022        1022  ...         NaN
# 1023        1023  ...  -95.233086
# 1024        1024  ...  -73.751798
# 1025        1025  ...  115.709162
# 1026        1026  ...  -75.750997
# 1027        1027  ...         NaN
# 1028        1028  ...  -88.202286
# 1029        1029  ...         NaN
# 1030        1030  ...  -87.976657
# 1031        1031  ...    1.313423
# 1032        1032  ...  -71.099358
# 1033        1033  ...  -77.152726
# 1034        1034  ...  -83.000835
# 1035        1035  ...  -98.101119
# 1036        1036  ...  -43.209373
# 1037        1037  ...  -81.501268
# 1038        1038  ...   14.667822
# 1039        1039  ...         NaN
# 1040        1040  ...  -97.335696
# 1041        1041  ...  -96.792023
# 1042        1042  ...  -94.164200
# 1043        1043  ...  -97.058572
# 1044        1044  ...         NaN
# 1045        1045  ...  -95.582343
# 1046        1046  ...  -85.665934
# 1047        1047  ...  -78.857231
# 1048        1048  ...  -78.872204
# 1049        1049  ...         NaN
# 1050        1050  ...         NaN
# 1051        1051  ... -122.192337
# 1052        1052  ...  -83.047556
# 1053        1053  ...   55.292491
# 1054        1054  ...   35.225763
# 1055        1055  ...  -89.771243
# 1056        1056  ...   -0.126540
# 1057        1057  ...  -71.655399
# 1058        1058  ...  -94.890787
# 1059        1059  ... -111.842298
# 1060        1060  ...  -76.009923
# 1061        1061  ...         NaN
# 1062        1062  ...  -84.168827
# 1063        1063  ...  -95.978530
# 1064        1064  ...         NaN
# 1065        1065  ...  -97.988594
# 1066        1066  ...         NaN
# 1067        1067  ... -101.535161
# 1068        1068  ...   21.630538
# 1069        1069  ...  114.160234
# 1070        1070  ...         NaN
# 1071        1071  ...  -72.082003
# 1072        1072  ...         NaN
# 1073        1073  ... -100.894698
# 1074        1074  ...  -82.452270
# 1075        1075  ...         NaN
# 1076        1076  ...  -74.269828
# 1077        1077  ...   19.999962
# 1078        1078  ...  -73.510773
# 1079        1079  ...  -79.874625
# 1080        1080  ...   49.588616
# 1081        1081  ... -122.158578
# 1082        1082  ...  -79.224200
# 1083        1083  ...         NaN
# 1084        1084  ... -117.690075
# 1085        1085  ...   14.248768
# 1086        1086  ...  125.837576
# 1087        1087  ...   29.491769
# 1088        1088  ...   37.999967
# 1089        1089  ...  -94.992736
# 1090        1090  ...  -86.250067
# 1091        1091  ...         NaN
# 1092        1092  ...         NaN
# 1093        1093  ...  -81.091177
# 1094        1094  ...   13.773192
# 1095        1095  ... -118.244663
# 1096        1096  ...   -0.177221
# 1097        1097  ...         NaN
# 1098        1098  ... -111.926018
# 1099        1099  ...  -74.002148
# 1100        1100  ...   34.792518
# 1101        1101  ...   29.267547
# 1102        1102  ...   15.322393
# 1103        1103  ...    6.128885
# 1104        1104  ...  -83.222153
# 1105        1105  ...   -2.245115
# 1106        1106  ...   14.421254
# 1107        1107  ...  -76.116618
# 1108        1108  ...   -3.179193
# 1109        1109  ...   -3.738930
# 1110        1110  ...         NaN
# 1111        1111  ...  -71.811984
# 1112        1112  ...   10.992412
# 1113        1113  ...   25.908847
# 1114        1114  ...   24.592874
# 1115        1115  ...   -0.116796
# 1116        1116  ...    0.529276
# 1117        1117  ... -117.870493
# 1118        1118  ...         NaN
# 1119        1119  ...         NaN
# 1120        1120  ...  -87.141732
# 1121        1121  ... -121.988571
# 1122        1122  ...  105.848779
# 1123        1123  ... -123.943147
# 1124        1124  ... -105.587619
# 1125        1125  ... -105.561361
# 1126        1126  ...   -0.467504
# 1127        1127  ...  -84.298393
# 1128        1128  ...  -36.618593
# 1129        1129  ...  -84.232688
# 1130        1130  ...  -96.042238
# 1131        1131  ... -122.391675
# 1132        1132  ...  -98.510478
# 1133        1133  ...  -86.282008
# 1134        1134  ...  -72.423747
# 1135        1135  ...  -91.701335
# 1136        1136  ... -117.147366
# 1137        1137  ...    1.000000
# 1138        1138  ...  -99.388484
# 1139        1139  ...  -88.952415
# 1140        1140  ... -117.873221
# 1141        1141  ...         NaN
# 1142        1142  ...  -89.629824
# 1143        1143  ...  -97.141342
# 1144        1144  ...         NaN
# 1145        1145  ...  -95.886751
# 1146        1146  ...  -92.014040
# 1147        1147  ...  -90.078213
# 1148        1148  ...   -1.133079
# 1149        1149  ...  -77.040337
# 1150        1150  ...  -91.670405
# 1151        1151  ...  -78.868883
# 1152        1152  ...  -70.877275
# 1153        1153  ...  -78.805186
# 1154        1154  ...  -85.290247
# 1155        1155  ...  -98.086678
# 1156        1156  ...  -81.314539
# 1157        1157  ...  -91.511510
# 1158        1158  ...  -97.141342
# 1159        1159  ...         NaN
# 1160        1160  ...         NaN
# 1161        1161  ...  -89.846107
# 1162        1162  ...  -75.880197
# 1163        1163  ...         NaN
# 1164        1164  ... -110.974848
# 1165        1165  ...         NaN
# 1166        1166  ... -122.134334
# 1167        1167  ...   18.386687
# 1168        1168  ...   -2.534849
# 1169        1169  ...   30.064436
# 1170        1170  ...   30.683651
# 1171        1171  ...  -91.529911
# 1172        1172  ...         NaN
# 1173        1173  ...  -74.155228
# 1174        1174  ...         NaN
# 1175        1175  ...  139.759455
# 1176        1176  ... -104.833333
# 1177        1177  ...  -78.501652
# 1178        1178  ...  -95.036958
# 1179        1179  ...  -96.425005
# 1180        1180  ...         NaN
# 1181        1181  ...  -79.537893
# 1182        1182  ...  -73.940221
# 1183        1183  ...   -7.889626
# 1184        1184  ...    0.731545
# 1185        1185  ...   14.520858
# 1186        1186  ...    5.387210
# 1187        1187  ...  -59.525031
# 1188        1188  ...  -81.379030
# 1189        1189  ...         NaN
# 1190        1190  ...  -73.790755
# 1191        1191  ...  -70.528122
# 1192        1192  ...  -83.956788
# 1193        1193  ...  -93.256375
# 1194        1194  ...  -75.339905
# 1195        1195  ...  -70.945322
# 1196        1196  ...  -85.937436
# 1197        1197  ...  -73.212906
# 1198        1198  ...  -90.515134
# 1199        1199  ...   13.057955
# 1200        1200  ...  -94.124427
# 1201        1201  ...    1.292270
# 1202        1202  ...   -7.952385
# 1203        1203  ...  -86.180703
# 1204        1204  ...  -10.708359
# 1205        1205  ...  -91.090239
# 1206        1206  ...  -77.026922
# 1207        1207  ...  -74.589590
# 1208        1208  ...  -75.150026
# 1209        1209  ... -109.428213
# 1210        1210  ... -124.057095
# 1211        1211  ...  -82.195918
# 1212        1212  ...  -90.389899
# 1213        1213  ... -100.653678
# 1214        1214  ... -105.084204
# 1215        1215  ...         NaN
# 1216        1216  ...  -82.348806
# 1217        1217  ...         NaN
# 1218        1218  ...         NaN
# 1219        1219  ...  145.024898
# 1220        1220  ...  -97.619994
# 1221        1221  ...  -98.269079
# 1222        1222  ...  -98.510478
# 1223        1223  ...  -51.108489
# 1224        1224  ...    4.311346
# 1225        1225  ...    5.387210
# 1226        1226  ... -122.039966
# 1227        1227  ...  -73.754204
# 1228        1228  ...  -79.490337
# 1229        1229  ...  -71.505161
# 1230        1230  ...    3.890227
# 1231        1231  ...  -78.339360
# 1232        1232  ...         NaN
# 1233        1233  ...  -95.058632
# 1234        1234  ... -122.404056
# 1235        1235  ...  -86.031947
# 1236        1236  ... -134.419734
# 1237        1237  ... -118.266192
# 1238        1238  ...  -73.204835
# 1239        1239  ...  -96.958859
# 1240        1240  ...  -97.988594
# 1241        1241  ...  -77.394769
# 1242        1242  ...         NaN
# 1243        1243  ...  -98.527046
# 1244        1244  ...  -74.167111
# 1245        1245  ...  -95.266518
# 1246        1246  ...         NaN
# 1247        1247  ...   -7.336248
# 1248        1248  ...   -2.593004
# 1249        1249  ...  -87.020747
# 1250        1250  ...         NaN
# 1251        1251  ...    6.959974
# 1252        1252  ...  -84.570234
# 1253        1253  ...  -87.765059
# 1254        1254  ...    4.971619
# 1255        1255  ...   12.482932
# 1256        1256  ...  -81.180211
# 1257        1257  ...  -11.191587
# 1258        1258  ...         NaN
# 1259        1259  ... -119.677442
# 1260        1260  ...  -81.995595
# 1261        1261  ...  -81.932016
# 1262        1262  ... -117.946372
# 1263        1263  ...  121.055278
# 1264        1264  ... -112.551597
# 1265        1265  ...  -82.990782
# 1266        1266  ...  -74.047455
# 1267        1267  ... -121.837478
# 1268        1268  ...    9.099971
# 1269        1269  ...  -80.241196
# 1270        1270  ... -105.993007
# 1271        1271  ... -106.779808
# 1272        1272  ... -109.912162
# 1273        1273  ...  -64.967282
# 1274        1274  ...  -76.496802
# 1275        1275  ...  -82.440466
# 1276        1276  ...  -88.147928
# 1277        1277  ...  -88.314754
# 1278        1278  ...  -86.829534
# 1279        1279  ...  -83.380444
# 1280        1280  ...         NaN
# 1281        1281  ...  -82.234238
# 1282        1282  ...  -87.693046
# 1283        1283  ...  -87.756525
# 1284        1284  ...  -90.607080
# 1285        1285  ...  -73.770954
# 1286        1286  ...  -73.939569
# 1287        1287  ...  151.948144
# 1288        1288  ... -120.591102
# 1289        1289  ...  -78.376802
# 1290        1290  ...  -73.034986
# 1291        1291  ...  135.506211
# 1292        1292  ...   -2.158385
# 1293        1293  ...         NaN
# 1294        1294  ...  -82.732931
# 1295        1295  ...  -77.566713
# 1296        1296  ...   15.160548
# 1297        1297  ...         NaN
# 1298        1298  ...  -88.875966
# 1299        1299  ...  121.005349
# 1300        1300  ...         NaN
# 1301        1301  ...  -58.459843
# 1302        1302  ...   18.619444
# 1303        1303  ...  -92.289627
# 1304        1304  ...  -89.118343
# 1305        1305  ...  -94.952522
# 1306        1306  ...         NaN
# 1307        1307  ...   -8.146170
# 1308        1308  ...  -80.990371
# 1309        1309  ...  -73.894102
# 1310        1310  ...  -78.718852
# 1311        1311  ...  -79.487320
# 1312        1312  ...  -61.261305
# 1313        1313  ...  -73.983470
# 1314        1314  ...  -81.379494
# 1315        1315  ...  -81.622507
# 1316        1316  ...   -0.139560
# 1317        1317  ...  -78.754147
# 1318        1318  ...  -81.385638
# 1319        1319  ...         NaN
# 1320        1320  ...  -72.857803
# 1321        1321  ...  -74.041087
# 1322        1322  ...  -77.046287
# 1323        1323  ... -122.453881
# 1324        1324  ...  -80.449417
# 1325        1325  ...         NaN
# 1326        1326  ...         NaN
# 1327        1327  ...  -92.136376
# 1328        1328  ...         NaN
# 1329        1329  ...  -69.865464
# 1330        1330  ...  -69.514714
# 1331        1331  ...  -69.814768
# 1332        1332  ...  -97.089726
# 1333        1333  ...         NaN
# 1334        1334  ...   19.260080
# 1335        1335  ...  -91.169485
# 1336        1336  ...         NaN
# 1337        1337  ...   10.000654
# 1338        1338  ...   11.575382
# 1339        1339  ...         NaN
# 1340        1340  ...   20.081720
# 1341        1341  ...  -72.801221
# 1342        1342  ...  -73.968085
# 1343        1343  ...         NaN
# 1344        1344  ...  -87.940342
# 1345        1345  ...  -80.462364
# 1346        1346  ...  -81.440667
# 1347        1347  ...  -74.055073
# 1348        1348  ... -111.240303
# 1349        1349  ... -118.443773
# 1350        1350  ...  -73.454011
# 1351        1351  ... -122.176821
# 1352        1352  ...  -87.627766
# 1353        1353  ...   -1.251665
# 1354        1354  ...   80.271246
# 1355        1355  ...   37.621566
# 1356        1356  ...  -90.184556
# 1357        1357  ...   -2.208799
# 1358        1358  ...  151.501200
# 1359        1359  ...   -1.152649
# 1360        1360  ...   -0.056667
# 1361        1361  ...  -71.182832
# 1362        1362  ...  -96.369963
#
# [1363 rows x 6 columns]

# %%
ct_mapping.to_csv('dataframe_mapping_0611.csv')

# %%
#ct_mapping=pd.read_csv('dataframe_mapping_0530.csv',encoding='ISO-8859-1')

# %%
for k in range(len(ct_ner['NER-1'])):
  list=[]
  for i in ct_ner['NER-1'][k]:
    for j in range(len(ct_mapping['City'])):
      if(i==ct_mapping['City'][j]):
        list.append(ct_mapping['Mapping'][j])
  ct_ner['NER-1'][k]=list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
ct_ner[:100]
# Out:
#     Unnamed: 0  ...                                              NER-1
# 0            0  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 1            1  ...  [Houston, Harris County, Texas, 77002-5902, Un...
# 2            2  ...  [Portland, Multnomah County, Oregon, United St...
# 3            3  ...                                                 []
# 4            4  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 5            5  ...                                                 []
# 6            6  ...                    [nan, nan, nan, United Kingdom]
# 7            7  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 8            8  ...                                              [nan]
# 9            9  ...                                                 []
# 10          10  ...  [Portland, Multnomah County, Oregon, United St...
# 11          11  ...                                                 []
# 12          12  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 13          13  ...                                                 []
# 14          14  ...                                                 []
# 15          15  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 16          16  ...  [nan, nan, Minneapolis, Hennepin County, Minne...
# 17          17  ...                                                 []
# 18          18  ...                                                 []
# 19          19  ...  [Dallas, Dallas County, Texas, 75242, United S...
# 20          20  ...  [nan, nan, Dallas, Dallas County, Texas, 75242...
# 21          21  ...                                                 []
# 22          22  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 23          23  ...                                                 []
# 24          24  ...  [Houston, Harris County, Texas, 77002-5902, Un...
# 25          25  ...                                              [nan]
# 26          26  ...  [Huntsville, Madison County, Alabama, 35804, U...
# 27          27  ...                                                 []
# 28          28  ...                                                 []
# 29          29  ...                                                 []
# 30          30  ...                                                 []
# 31          31  ...                                              [nan]
# 32          32  ...  [Los Angeles, Los Angeles County, California, ...
# 33          33  ...                                                 []
# 34          34  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 35          35  ...                                                 []
# 36          36  ...  [nan, nan, nan, Houston, Harris County, Texas,...
# 37          37  ...  [nan, Dallas, Dallas County, Texas, 75242, Uni...
# 38          38  ...  [Columbus, Franklin County, Ohio, United State...
# 39          39  ...  [City of Seattle Customer Service Center, 4534...
# 40          40  ...                                                 []
# 41          41  ...  [Houston, Harris County, Texas, 77002-5902, Un...
# 42          42  ...  [Columbus, Franklin County, Ohio, United State...
# 43          43  ...  [Franklinville, Cattaraugus County, New York, ...
# 44          44  ...  [Brooklyn, Kings County, New York, United States]
# 45          45  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 46          46  ...  [nan, Confederate States Navy Yard Marker, Cat...
# 47          47  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 48          48  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 49          49  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 50          50  ...  [Tulsa, Tulsa County, Oklahoma, United States,...
# 51          51  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 52          52  ...                                                 []
# 53          53  ...                                                 []
# 54          54  ...                                                 []
# 55          55  ...                                                 []
# 56          56  ...                                                 []
# 57          57  ...                                                 []
# 58          58  ...                                                 []
# 59          59  ...                                                 []
# 60          60  ...                                              [nan]
# 61          61  ...                                                 []
# 62          62  ...  [nan, San Francisco, City and County of San Fr...
# 63          63  ...  [Washington, District of Columbia, United Stat...
# 64          64  ...  [Washington, District of Columbia, United States]
# 65          65  ...                                                 []
# 66          66  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 67          67  ...                                                 []
# 68          68  ...                                                 []
# 69          69  ...  [Washington, District of Columbia, United Stat...
# 70          70  ...                                                 []
# 71          71  ...      [Hillsborough County, Florida, United States]
# 72          72  ...  [nan, nan, Washington, District of Columbia, U...
# 73          73  ...  [Washington, District of Columbia, United States]
# 74          74  ...  [San Diego, San Diego County, California, 9210...
# 75          75  ...      [Chester County, Pennsylvania, United States]
# 76          76  ...  [Fayetteville, Washington County, Arkansas, 72...
# 77          77  ...  [nan, Indianapolis, Marion County, Indiana, Un...
# 78          78  ...                                                 []
# 79          79  ...  [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 80          80  ...  [Washington, District of Columbia, United Stat...
# 81          81  ...  [Milwaukee, Milwaukee County, Wisconsin, Unite...
# 82          82  ...                                                 []
# 83          83  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 84          84  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 85          85  ...      [nan, Republic County, Kansas, United States]
# 86          86  ...                                              [nan]
# 87          87  ...                                              [nan]
# 88          88  ...                                                 []
# 89          89  ...                                                 []
# 90          90  ...                                                 []
# 91          91  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 92          92  ...                                              [nan]
# 93          93  ...      [nan, Republic County, Kansas, United States]
# 94          94  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 95          95  ...  [Zionsville, Boone County, Indiana, United Sta...
# 96          96  ...   [Columbus, Franklin County, Ohio, United States]
# 97          97  ...   [Columbus, Franklin County, Ohio, United States]
# 98          98  ...                                                 []
# 99          99  ...  [Houston, Harris County, Texas, 77002-5902, Un...
#
# [100 rows x 53 columns]

# %%
ct_ner['NER-1'][:100]
# Out:
# 0     [Minneapolis, Hennepin County, Minnesota, 5548...
# 1     [Houston, Harris County, Texas, 77002-5902, Un...
# 2     [Portland, Multnomah County, Oregon, United St...
# 3                                                    []
# 4     [nan, Minneapolis, Hennepin County, Minnesota,...
# 5                                                    []
# 6                       [nan, nan, nan, United Kingdom]
# 7     [nan, Minneapolis, Hennepin County, Minnesota,...
# 8                                                 [nan]
# 9                                                    []
# 10    [Portland, Multnomah County, Oregon, United St...
# 11                                                   []
# 12    [nan, Minneapolis, Hennepin County, Minnesota,...
# 13                                                   []
# 14                                                   []
# 15    [Minneapolis, Hennepin County, Minnesota, 5548...
# 16    [nan, nan, Minneapolis, Hennepin County, Minne...
# 17                                                   []
# 18                                                   []
# 19    [Dallas, Dallas County, Texas, 75242, United S...
# 20    [nan, nan, Dallas, Dallas County, Texas, 75242...
# 21                                                   []
# 22    [Minneapolis, Hennepin County, Minnesota, 5548...
# 23                                                   []
# 24    [Houston, Harris County, Texas, 77002-5902, Un...
# 25                                                [nan]
# 26    [Huntsville, Madison County, Alabama, 35804, U...
# 27                                                   []
# 28                                                   []
# 29                                                   []
# 30                                                   []
# 31                                                [nan]
# 32    [Los Angeles, Los Angeles County, California, ...
# 33                                                   []
# 34    [Minneapolis, Hennepin County, Minnesota, 5548...
# 35                                                   []
# 36    [nan, nan, nan, Houston, Harris County, Texas,...
# 37    [nan, Dallas, Dallas County, Texas, 75242, Uni...
# 38    [Columbus, Franklin County, Ohio, United State...
# 39    [City of Seattle Customer Service Center, 4534...
# 40                                                   []
# 41    [Houston, Harris County, Texas, 77002-5902, Un...
# 42    [Columbus, Franklin County, Ohio, United State...
# 43    [Franklinville, Cattaraugus County, New York, ...
# 44    [Brooklyn, Kings County, New York, United States]
# 45    [Minneapolis, Hennepin County, Minnesota, 5548...
# 46    [nan, Confederate States Navy Yard Marker, Cat...
# 47    [Minneapolis, Hennepin County, Minnesota, 5548...
# 48    [nan, Minneapolis, Hennepin County, Minnesota,...
# 49    [Minneapolis, Hennepin County, Minnesota, 5548...
# 50    [Tulsa, Tulsa County, Oklahoma, United States,...
# 51    [nan, Minneapolis, Hennepin County, Minnesota,...
# 52                                                   []
# 53                                                   []
# 54                                                   []
# 55                                                   []
# 56                                                   []
# 57                                                   []
# 58                                                   []
# 59                                                   []
# 60                                                [nan]
# 61                                                   []
# 62    [nan, San Francisco, City and County of San Fr...
# 63    [Washington, District of Columbia, United Stat...
# 64    [Washington, District of Columbia, United States]
# 65                                                   []
# 66    [Minneapolis, Hennepin County, Minnesota, 5548...
# 67                                                   []
# 68                                                   []
# 69    [Washington, District of Columbia, United Stat...
# 70                                                   []
# 71        [Hillsborough County, Florida, United States]
# 72    [nan, nan, Washington, District of Columbia, U...
# 73    [Washington, District of Columbia, United States]
# 74    [San Diego, San Diego County, California, 9210...
# 75        [Chester County, Pennsylvania, United States]
# 76    [Fayetteville, Washington County, Arkansas, 72...
# 77    [nan, Indianapolis, Marion County, Indiana, Un...
# 78                                                   []
# 79    [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 80    [Washington, District of Columbia, United Stat...
# 81    [Milwaukee, Milwaukee County, Wisconsin, Unite...
# 82                                                   []
# 83    [Minneapolis, Hennepin County, Minnesota, 5548...
# 84    [Minneapolis, Hennepin County, Minnesota, 5548...
# 85        [nan, Republic County, Kansas, United States]
# 86                                                [nan]
# 87                                                [nan]
# 88                                                   []
# 89                                                   []
# 90                                                   []
# 91    [Minneapolis, Hennepin County, Minnesota, 5548...
# 92                                                [nan]
# 93        [nan, Republic County, Kansas, United States]
# 94    [Minneapolis, Hennepin County, Minnesota, 5548...
# 95    [Zionsville, Boone County, Indiana, United Sta...
# 96     [Columbus, Franklin County, Ohio, United States]
# 97     [Columbus, Franklin County, Ohio, United States]
# 98                                                   []
# 99    [Houston, Harris County, Texas, 77002-5902, Un...
# Name: NER-1, dtype: object

# %%
ct_ner.to_csv('dataframe0611_post_remove.csv')

# %%
# !ls
# Out:
#  Country.txt			 dataframe0610_post.csv
#  dataframe0529_post.csv		 dataframe0610_post_remove.csv
#  dataframe0529_post_remove.csv	 dataframe0611_post.csv
#  dataframe0530_post.csv		 dataframe0611_post_remove.csv
#  dataframe0530_post_remove.csv	 dataframe_mapping
#  dataframe0531_post.csv		 dataframe_mapping_0529.csv
#  dataframe0531_post_remove.csv	 dataframe_mapping_0530.csv
#  dataframe0601_post.csv		 dataframe_mapping_0531.csv
#  dataframe0601_post_remove.csv	 dataframe_mapping_0601.csv
#  dataframe0602_post.csv		 dataframe_mapping_0602.csv
#  dataframe0602_post_remove.csv	 dataframe_mapping_0603.csv
#  dataframe0603_post.csv		 dataframe_mapping_0604.csv
#  dataframe0603_post_remove.csv	 dataframe_mapping_0605.csv
#  dataframe0604_post.csv		 dataframe_mapping_0606.csv
#  dataframe0604_post_remove.csv	 dataframe_mapping_0607.csv
#  dataframe0605_post.csv		 dataframe_mapping_0608.csv
#  dataframe0605_post_remove.csv	 dataframe_mapping_0609.csv
#  dataframe0606_post.csv		 dataframe_mapping_0610.csv
#  dataframe0606_post_remove.csv	 dataframe_mapping_0611.csv
#  dataframe0607_post.csv		 datarframe_post
#  dataframe0607_post_remove.csv	'mapping_US_Cities_Only (1).zip'
#  dataframe0608_post.csv		 mapping_US_Cities_Only.zip
#  dataframe0608_post_remove.csv	 post_specific_mapping_US.zip
#  dataframe0609_post.csv		 states.csv
#  dataframe0609_post_remove.csv
