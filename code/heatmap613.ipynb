# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 3.9 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=7afc2b28ca1041ff552ad9d3afbbaadcea8c3a87f714c8c873bdd8e06c0424eb
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.8 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_UK
#  a0529-a0611_US     dataframe_result_529_UK.csv
#  a0529.csv	    dataframe_result_530_UK.csv
#  a0530.csv	    dataframe_result_531_UK.csv
#  a0601.csv	    dataframe_result_csv
#  a0602.csv	    dataframe_result_csv_EU
#  a0603.csv	    dataframe_result_csv_UK
#  a0604.csv	    Github
#  a0605.csv	    heatmap529_UK.ipynb
#  a0606.csv	    heatmap530.ipynb
#  a0607.csv	    Heat_Map_Online_language.ipynb
#  a0608.csv	    __MACOSX
#  a0610.csv	    mapping_UK
#  a0611.csv	    mapping_US
#  ccc_compiled.csv   non_violant1.csv
#  csv		    non_violant2.csv
#  csv.zip	    UK
#  dataframe_csv	    violant.csv
#  dataframe_csv_EU  '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_611 = 'csv/US06_13.csv'

# %%
ct = pd.read_csv(ct_path_611)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                              platformId  ...                   post_id
# 0      285178921532058_3667946513255265  ...    17623|3667946513255265
# 1         58051322414_10157764689437415  ...   60485|10157764689437415
# 2     1683805235011654_3115348728523957  ...  5419563|3115348728523957
# 3     1554989191478272_2830671237243388  ...  1495950|2830671237243388
# 4      430530153726848_3035448403234997  ...  3707887|3035448403234997
# ...                                 ...  ...                       ...
# 4679  1603266863274691_2767463020188397  ...  7825270|2767463020188397
# 4680      56396141107_10158583885716108  ...  234875|10158583885716108
# 4681   115084491845666_3472748149412600  ...    25289|3472748149412600
# 4682     210277954204_10157644503304205  ...    6786|10157644503304205
# 4683       5863113009_10158805296188010  ...   10336|10158805296188010
#
# [4684 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#                             NER-msg                       NER-desc
# 0                                {}                             {}
# 1     {'U.S.': 2, 'Minneapolis': 1}  {'U.S.': 2, 'Minneapolis': 1}
# 2  {'Minneapolis': 1, 'Seattle': 1}                             {}
# 3                                {}                             {}
# 4                {'Minneapolis': 2}             {'Minneapolis': 1}

# %%
ct
# Out:
#                              platformId  ...                         NER-title
# 0      285178921532058_3667946513255265  ...                                {}
# 1         58051322414_10157764689437415  ...                       {'U.S.': 1}
# 2     1683805235011654_3115348728523957  ...                                {}
# 3     1554989191478272_2830671237243388  ...         {'Sacramento Unified': 1}
# 4      430530153726848_3035448403234997  ...                                {}
# ...                                 ...  ...                               ...
# 4679  1603266863274691_2767463020188397  ...  {'Tennessee': 1, 'Nashville': 1}
# 4680      56396141107_10158583885716108  ...                                {}
# 4681   115084491845666_3472748149412600  ...                                {}
# 4682     210277954204_10157644503304205  ...                                {}
# 4683       5863113009_10158805296188010  ...                                {}
#
# [4684 rows x 50 columns]

# %%
ct.to_csv('a0613.csv')

# %%
ct=pd.read_csv('a0613.csv',lineterminator='\n')

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                             NER-msg  ...                  NER-title
# 1     {'U.S.': 2, 'Minneapolis': 1}  ...                {'U.S.': 1}
# 2  {'Minneapolis': 1, 'Seattle': 1}  ...                         {}
# 3                                {}  ...  {'Sacramento Unified': 1}
# 4                {'Minneapolis': 2}  ...                         {}
# 5                                {}  ...                         {}
#
# [5 rows x 3 columns]

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ct_ner['NER-msg']
# Out:
# 1              [U.S., Minneapolis]
# 2           [Seattle, Minneapolis]
# 3                               []
# 4                    [Minneapolis]
# 5                               []
#                    ...
# 4679    [Tennessee, Seattle, U.S.]
# 4680                 [US, Oakland]
# 4681                            []
# 4682                            []
# 4683                         [L.A]
# Name: NER-msg, Length: 2653, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ct_ner['NER']
# Out:
# 1            [U.S., Minneapolis, U.S., Minneapolis, U.S.]
# 2                                  [Seattle, Minneapolis]
# 3                                    [Sacramento Unified]
# 4                              [Minneapolis, Minneapolis]
# 5                                           [Minneapolis]
#                               ...
# 4679    [Tennessee, Seattle, U.S., Tennessee, Tennesse...
# 4680                               [US, Oakland, Oakland]
# 4681                                  [America, NEW YORK]
# 4682                                  [America, NEW YORK]
# 4683                                                [L.A]
# Name: NER, Length: 2653, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ner_lst = ct_ner['NER'].values

# %%
ner_lst
# Out:
# array([list(['u.s.', 'minneapolis']), list(['seattle', 'minneapolis']),
#        list(['sacramento unified']), ..., list(['new york', 'america']),
#        list(['new york', 'america']), list(['l.a'])], dtype=object)

# %%
m=0
list=[]
for n in ner_lst:
  for i in range(len(n)):
    list.append(ner_lst[m][i])
  m+=1

# %%
list
# Out:
# ['u.s.',
#  'minneapolis',
#  'seattle',
#  'minneapolis',
#  'sacramento unified',
#  'minneapolis',
#  'minneapolis',
#  'canada',
#  'minneapolis',
#  'canada',
#  'sacramento unified',
#  'minneapolis',
#  'fl',
#  'minneapolis',
#  'u.s.',
#  'carmel',
#  'minnesota',
#  'minneapolis',
#  'vermont',
#  'colchester',
#  'roc',
#  'd.c.',
#  'mexico',
#  'america',
#  'jersey',
#  'binnish',
#  'new zealand',
#  'buffalo',
#  'athens',
#  'germany',
#  'lauderdale',
#  'boston',
#  'france',
#  'australia',
#  'madrid',
#  'ireland',
#  'colchester',
#  'alabama',
#  'us',
#  'spain',
#  'paris',
#  'amsterdam',
#  'greece',
#  'copenhagen',
#  'poland',
#  'barcelona',
#  'minneapolis',
#  'brussels',
#  'syria',
#  'virginia',
#  'denmark',
#  'canada',
#  'vermont',
#  'maryland',
#  'mexico city',
#  'dublin',
#  'berlin',
#  'auckland',
#  'roc',
#  'brazil',
#  'franklin township',
#  'new jersey',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'jackson',
#  'miss.',
#  'mississippi',
#  'minneapolis',
#  'brooklyn',
#  'new york city',
#  'brooklyn',
#  'new york city',
#  'washington',
#  'dallas',
#  'minneapolis',
#  "united states'",
#  'florida',
#  'texas',
#  'minnesota',
#  'tulsa',
#  'the united states',
#  'oklahoma',
#  'arizona',
#  'minneapolis',
#  'oklahoma city',
#  'oklahoma city',
#  'florida',
#  'phoenix',
#  'tulsa',
#  'the arizona republic',
#  'okla.',
#  'maricopa county',
#  'charlottesville',
#  'va.',
#  'minneapolis',
#  'fort bragg',
#  'lansing',
#  'richmond',
#  'birmingham',
#  'south carolina',
#  'appomattox',
#  'alabama',
#  'charleston',
#  'michigan',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'columbus',
#  'mauritania',
#  'us',
#  'america',
#  'the united states',
#  'new york',
#  'u.s.',
#  'charlotte',
#  'usa',
#  'the united states',
#  'seattle',
#  'washington',
#  'new york',
#  'america',
#  'new york',
#  'america',
#  'd.c.',
#  'd.c.',
#  'america',
#  'd.c.',
#  'america',
#  'massachusetts',
#  'minneapolis',
#  'ore.',
#  'salem',
#  'america',
#  'memphis',
#  'jacksonville',
#  'iowa',
#  'fort myers',
#  'nicaragua',
#  'puerto rico',
#  'colombia',
#  'costa rica',
#  'us',
#  'el salvador',
#  'brazil',
#  'panama',
#  'dayton',
#  'oakwood',
#  'georgia',
#  'us',
#  'u.s.',
#  'u.k.',
#  'minneapolis',
#  'belmont',
#  'the united states of america',
#  'iowa',
#  'minnesota',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'fl',
#  'minneapolis',
#  'minneapolis',
#  'fl',
#  'minneapolis',
#  'minneapolis',
#  'new york',
#  'minneapolis',
#  'ohio',
#  'san bernardino county',
#  'cleveland',
#  'denver',
#  'indianapolis',
#  'maryland',
#  'michigan',
#  'montgomery county',
#  'california',
#  'u.s.',
#  'minneapolis',
#  'pittsburgh',
#  'pennsylvania',
#  'pa.',
#  'minneapolis',
#  'pa.',
#  'gaza',
#  'minneapolis',
#  'gaza',
#  'paris',
#  'america',
#  'paris',
#  'sacramento',
#  'minneapolis',
#  'cape coral',
#  'fl',
#  'minnesota',
#  'minneapolis',
#  'seattle',
#  'washington',
#  'seattle',
#  'washington',
#  'minnesota',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'hollywood',
#  'hollywood',
#  'usa',
#  'amish',
#  'north/south dakota',
#  'minneapolis',
#  'hollywood',
#  'hawthorne',
#  'hollywood',
#  'minneapolis',
#  'minneapolis',
#  'amerikkka',
#  'minneapolis',
#  'stockton',
#  'minneapolis',
#  'stockton',
#  'minneapolis',
#  'los angeles',
#  'minnesota',
#  'minneapolis',
#  'charlotte county',
#  'minnesota',
#  'minneapolis',
#  'washington',
#  'us',
#  'washington',
#  'us',
#  'texas',
#  'texas',
#  'america',
#  'atlanta',
#  'atlanta',
#  'florida',
#  'atlanta',
#  'phoenix',
#  'tulsa',
#  'the arizona republic',
#  'okla.',
#  'maricopa county',
#  'charlottesville',
#  'va.',
#  'minneapolis',
#  'florida',
#  'atlanta',
#  'phoenix',
#  'tulsa',
#  'the arizona republic',
#  'okla.',
#  'maricopa county',
#  'charlottesville',
#  'va.',
#  'minneapolis',
#  'florida',
#  'atlanta',
#  'phoenix',
#  'tulsa',
#  'the arizona republic',
#  'okla.',
#  'maricopa county',
#  'charlottesville',
#  'va.',
#  'minneapolis',
#  'florida',
#  'atlanta',
#  'phoenix',
#  'tulsa',
#  'the arizona republic',
#  'okla.',
#  'maricopa county',
#  'charlottesville',
#  'va.',
#  'minneapolis',
#  'florida',
#  'atlanta',
#  'phoenix',
#  'tulsa',
#  'the arizona republic',
#  'okla.',
#  'maricopa county',
#  'charlottesville',
#  'va.',
#  'minneapolis',
#  'florida',
#  'atlanta',
#  'phoenix',
#  'tulsa',
#  'the arizona republic',
#  'okla.',
#  'maricopa county',
#  'charlottesville',
#  'va.',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'greenville',
#  'washington',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'paris',
#  'london',
#  'u.s.',
#  'us',
#  'britain',
#  'netherlands',
#  'london',
#  'uk',
#  'germany',
#  'france',
#  'minneapolis',
#  'new york',
#  'minneapolis',
#  'houston',
#  'texas',
#  'the united state',
#  'philadelphia',
#  'california',
#  'minneapolis',
#  'the united states of america',
#  'hollywood',
#  'the united states of america',
#  'hollywood',
#  'the united states of america',
#  'hollywood',
#  'the united states of america',
#  'hollywood',
#  'the united states of america',
#  'hollywood',
#  'the united states of america',
#  'hollywood',
#  'the united states of america',
#  'hollywood',
#  'the united states of america',
#  'hollywood',
#  'the united states of america',
#  'hollywood',
#  'las cruces',
#  'alexandria city',
#  'alexandria city',
#  'las cruces',
#  'alexandria',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'philadelphia',
#  'u.s.',
#  'pittsburgh',
#  'the united states',
#  'atlanta',
#  'minneapolis',
#  'u.s.',
#  'america',
#  'minneapolis',
#  'brooklyn',
#  'downtown portland',
#  'northeast portland',
#  'portland',
#  'philadelphia',
#  'denver',
#  'denver',
#  'acps',
#  'chester',
#  'chester',
#  'colorado',
#  'minneapolis',
#  'the united states',
#  'us',
#  'kentucky',
#  'minneapolis',
#  'little rock',
#  'arkansas',
#  'los angeles',
#  'minneapolis',
#  'us',
#  'yucaipa',
#  'the san bernardino county sheriff’s department',
#  'minneapolis',
#  'tulsa',
#  'okla.',
#  'america',
#  'louisville',
#  'minneapolis',
#  'd.c.',
#  'washington',
#  'st. john’s church',
#  'minneapolis',
#  'new york city',
#  'philadelphia',
#  'us',
#  'fl',
#  'minneapolis',
#  'novato',
#  'fl',
#  'minneapolis',
#  'tennessee',
#  'nashville',
#  'america',
#  'america',
#  'texas',
#  'minneapolis',
#  'minneapolis',
#  'f**king',
#  'portland',
#  'rose city park',
#  'detroit',
#  'minneapolis',
#  'texas',
#  'minneapolis',
#  'longmont',
#  'us',
#  'massachusetts',
#  'texas',
#  'america',
#  'bayview',
#  'san francisco’s',
#  'san francisco',
#  'minneapolis',
#  'oakland',
#  'new york',
#  'america',
#  'new york',
#  'america',
#  'texas',
#  'minneapolis',
#  'tulsa',
#  'okla.',
#  'america',
#  'minneapolis',
#  'new york city',
#  'philadelphia',
#  'us',
#  'new york',
#  'america',
#  'minneapolis',
#  'oakland',
#  'd.c.',
#  'u.s.',
#  'america',
#  'washington',
#  'washington',
#  'nyc',
#  'america',
#  'op-ed',
#  'u.s.',
#  'minneapolis',
#  'minneapolis',
#  'iowa city',
#  'minneapolis',
#  'wa state',
#  'portland',
#  'nyc',
#  'british columbia',
#  'seattle',
#  'greenwich village',
#  'washington',
#  'india',
#  'oregon',
#  'us',
#  'canada',
#  'minneapolis',
#  'california',
#  'minnesota',
#  'minneapolis',
#  'the united states’',
#  'oakland',
#  'minneapolis',
#  'naples',
#  'minneapolis',
#  'minneapolis',
#  'tulsa',
#  'okla.',
#  'minneapolis',
#  'naples',
#  'the united states',
#  'u.s.',
#  'minneapolis',
#  'bethesda',
#  'maryland',
#  'montgomery county',
#  'minneapolis',
#  'minnesota',
#  'wisconsin',
#  'america',
#  'wisconsin',
#  'america',
#  'wisconsin',
#  'hattiesburg',
#  'america',
#  'pflag',
#  'mt. horeb',
#  'america',
#  'minneapolis',
#  'texas',
#  'minneapolis',
#  'america',
#  'wausau',
#  'new york city',
#  'georgia',
#  'd.c.',
#  'mexico',
#  'america',
#  'jersey',
#  'binnish',
#  'new zealand',
#  'buffalo',
#  'athens',
#  'germany',
#  'lauderdale',
#  'boston',
#  'france',
#  'australia',
#  'madrid',
#  'ireland',
#  'alabama',
#  'us',
#  'spain',
#  'paris',
#  'amsterdam',
#  'greece',
#  'copenhagen',
#  'poland',
#  'barcelona',
#  'minneapolis',
#  'brussels',
#  'syria',
#  'virginia',
#  'denmark',
#  'canada',
#  'maryland',
#  'mexico city',
#  'dublin',
#  'berlin',
#  'auckland',
#  'brazil',
#  'durham',
#  'new york city',
#  'brooklyn',
#  'wheaton',
#  'illinois',
#  'brooklyn',
#  'china',
#  'u.s.',
#  'us',
#  'russia',
#  'lafayette park',
#  'minneapolis',
#  'ore.',
#  'salem',
#  'new york city',
#  'seattle',
#  'new york city',
#  'america',
#  'america',
#  'minnesota',
#  'georgia',
#  'creve coeur',
#  'georgia',
#  'st. louis',
#  'dc',
#  'minneapolis',
#  'belmont',
#  'wayne county',
#  'belmont',
#  'chicago',
#  'lakeview chicago',
#  'belmont',
#  'halsted',
#  'drag queens',
#  'kings',
#  'boystown',
#  'nassau county',
#  'america',
#  'long island',
#  'the united states',
#  'u.s.',
#  'tucson',
#  'houston',
#  "san francisco's",
#  'san francisco’s',
#  'america',
#  'minneapolis',
#  'new mexico',
#  'minneapolis',
#  'oviedo',
#  'seminole county',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'new york city',
#  'antifa',
#  'new york city',
#  'harris county',
#  'berlin',
#  'u.s.',
#  'us',
#  'paris',
#  'london',
#  'the united states',
#  'milwaukee',
#  'wisconsins',
#  'u.s.',
#  'wausau',
#  'wisconsin',
#  'minneapolis',
#  '🇸',
#  'huntington',
#  'minneapolis',
#  'huntington',
#  'st. pauls',
#  'minneapolis',
#  'chicago',
#  'minneapolis',
#  'texas',
#  'charlotte',
#  'u.s.',
#  'tulsa',
#  'oklahoma',
#  'north carolina',
#  'galveston',
#  'minneapolis',
#  'the united states',
#  'bushwick',
#  'mabou mines',
#  'nyc',
#  'new georges',
#  'ars nova',
#  'new york',
#  'u.s.',
#  'us',
#  'the united states',
#  'u.s.',
#  'united states',
#  "santa rosa's",
#  'santa rosa',
#  'u.s.',
#  'new',
#  'u.s.',
#  'd.c.',
#  'mexico',
#  'america',
#  'jersey',
#  'binnish',
#  'new zealand',
#  'buffalo',
#  'athens',
#  'germany',
#  'lauderdale',
#  'boston',
#  'france',
#  'australia',
#  'madrid',
#  'ireland',
#  'alabama',
#  'us',
#  'spain',
#  'paris',
#  'amsterdam',
#  'greece',
#  'copenhagen',
#  'poland',
#  'barcelona',
#  'minneapolis',
#  'brussels',
#  'syria',
#  'virginia',
#  'denmark',
#  'canada',
#  'maryland',
#  'mexico city',
#  'dublin',
#  'berlin',
#  'u.s.',
#  'auckland',
#  'brazil',
#  'minneapolis',
#  'new york',
#  'america',
#  'u.s.',
#  'us',
#  'n.j.',
#  'america',
#  'camden',
#  'the united states',
#  'minneapolis',
#  'warren',
#  'new york’s',
#  'minneapolis',
#  'florida',
#  'america',
#  'philadelphia',
#  'u.s.',
#  'us',
#  'arlington',
#  'va.',
#  'omaha',
#  'u.s.',
#  'berlin',
#  'minnesota',
#  'berlin',
#  'us',
#  'paris',
#  'london',
#  'the united states',
#  'u.s.',
#  'minneapolis',
#  'florida',
#  'minnesota',
#  'u.s.',
#  'louisville',
#  'kentucky',
#  'tallahassee',
#  'minneapolis',
#  'sunrise greensboro',
#  'danville',
#  'china',
#  'america',
#  'hollywood',
#  'minneapolis',
#  'columbus',
#  'mo.',
#  'd.c.',
#  'dorchester',
#  'ferguson',
#  'america',
#  'the north end',
#  'washington',
#  'boston',
#  'columbus avenue',
#  'minneapolis',
#  'portland',
#  'minneapolis',
#  'florida',
#  'chester',
#  'minnesota',
#  'south carolina',
#  'minneapolis',
#  'minneapolis',
#  'seattle',
#  'minneapolis',
#  'washington',
#  'st. john’s',
#  'dc',
#  'd.c.',
#  'los angeles',
#  'houston',
#  'bunna/shai',
#  'ethiopia',
#  'puerto rican parade',
#  'houston',
#  'us',
#  'minneapolis',
#  'the united kingdom',
#  'texas',
#  'usa',
#  'u.s.',
#  'paris',
#  'los angeles county',
#  'the united states',
#  'france',
#  'minneapolis',
#  'marion county',
#  'minneapolis',
#  'north minneapolis',
#  'minneapolis',
#  'north minneapolis',
#  'd.c.',
#  'tenn.',
#  'nashville',
#  'washington',
#  'tn',
#  'clarksville',
#  'tennessee',
#  'minneapolis',
#  'minneapolis',
#  'north minneapolis',
#  'wick park',
#  'wick park',
#  'america',
#  'america',
#  'detroit',
#  'new york',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'nevada',
#  'virginia',
#  'kansas city',
#  'missouri',
#  'u.s.',
#  'the boogaloo bois',
#  'the united states',
#  'las vegas',
#  'arkansas',
#  'america',
#  'u.s.',
#  'america',
#  'san clemente’s',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'springfield',
#  'minneapolis',
#  'florida',
#  'the united states',
#  'america',
#  'the united states',
#  'milwaukee',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'washington',
#  'pennsylvania',
#  'minneapolis',
#  'new york',
#  'new york',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  's.c.',
#  'minneapolis',
#  'south brunswick',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'seattle',
#  'minneapolis',
#  'seattle',
#  'seattle',
#  'minneapolis',
#  'missouri',
#  'seattle',
#  'minneapolis',
#  'west africa',
#  'hanover',
#  'rwanda',
#  'germany',
#  'wroc',
#  'america',
#  'baltimore',
#  'minneapolis',
#  'us',
#  'los angeles',
#  'newton',
#  'centennial park',
#  'brooklyn',
#  'murrieta',
#  'duck pond',
#  'ynez',
#  'u.s.',
#  'riverside county',
#  'temecula',
#  'minneapolis',
#  'minneapolis',
#  'fort worth',
#  'texas',
#  'east carolina',
#  'phoenix',
#  'arizona',
#  'd.c.',
#  'mexico',
#  'america',
#  'jersey',
#  'binnish',
#  'new zealand',
#  'buffalo',
#  'athens',
#  'germany',
#  'lauderdale',
#  'boston',
#  'france',
#  'australia',
#  'madrid',
#  'ireland',
#  'phoenix',
#  'alabama',
#  'us',
#  'spain',
#  'paris',
#  'amsterdam',
#  'greece',
#  'copenhagen',
#  'poland',
#  'barcelona',
#  'minneapolis',
#  'brussels',
#  'syria',
#  'virginia',
#  'denmark',
#  'canada',
#  'maryland',
#  'mexico city',
#  'dublin',
#  'berlin',
#  'auckland',
#  'brazil',
#  'arizona',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'us',
#  'minneapolis',
#  'burien',
#  'seattle',
#  'wash.',
#  'america',
#  'new york',
#  'albany',
#  'minneapolis',
#  'buffalo ny',
#  'buffalo',
#  'deyanna davis',
#  'minneapolis',
#  'minneapolis',
#  'us',
#  'u.s.',
#  'u.k.',
#  'minneapolis',
#  'new jersey',
#  'belgium',
#  'antwerp',
#  'america',
#  'new york',
#  'new york',
#  'florida',
#  'virginia',
#  'n.j.',
#  'america',
#  'camden',
#  'the united states',
#  'camden',
#  'minneapolis',
#  'minneapolis',
#  'charlotte',
#  'martinsburg',
#  'west virginia',
#  'west virginia',
#  'america',
#  'martinsburg',
#  'sacramento',
#  'houston',
#  'texas',
#  'harris county',
#  'houston',
#  'america',
#  'minnesota',
#  'detroit',
#  'new york city',
#  'philadelphia',
#  'us',
#  'minneapolis',
#  'new york city',
#  'philadelphia',
#  'us',
#  'minnesota',
#  'south dakota',
#  'sioux',
#  's.d.',
#  'minneapolis',
#  'minnesota',
#  'u.s.',
#  'us',
#  'sioux',
#  's.d.',
#  'u.k.',
#  'minneapolis',
#  'minneapolis',
#  'brooklyn',
#  'hartford',
#  'connecticut',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'us',
#  'philadelphia',
#  'philadelphia',
#  'new york city',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minneapolis',
#  'vegas',
#  'u.s.',
#  'las vegas',
#  ...]

# %%
c = collections.Counter()

# %%
dict_a=collections.Counter(list).most_common()

# %%
dict_a
# Out:
# [('minneapolis', 986),
#  ('america', 320),
#  ('u.s.', 222),
#  ('minnesota', 190),
#  ('the united states', 149),
#  ('us', 148),
#  ('new york', 144),
#  ('seattle', 102),
#  ('new york city', 77),
#  ('washington', 76),
#  ('philadelphia', 64),
#  ('texas', 63),
#  ('houston', 55),
#  ('tulsa', 46),
#  ('paris', 44),
#  ('atlanta', 44),
#  ('boston', 43),
#  ('florida', 42),
#  ('los angeles', 42),
#  ('california', 39),
#  ('michigan', 38),
#  ('london', 37),
#  ('virginia', 35),
#  ('georgia', 35),
#  ('brooklyn', 32),
#  ('detroit', 31),
#  ('d.c.', 29),
#  ('iowa', 29),
#  ('hollywood', 28),
#  ('dallas', 27),
#  ('denver', 27),
#  ('chicago', 26),
#  ('north carolina', 26),
#  ('albany', 26),
#  ('berlin', 25),
#  ('ohio', 25),
#  ('buffalo', 24),
#  ('richmond', 24),
#  ('south carolina', 24),
#  ('oklahoma', 23),
#  ('alabama', 22),
#  ('phoenix', 22),
#  ('louisville', 22),
#  ('new jersey', 21),
#  ('portland', 21),
#  ('wisconsin', 21),
#  ('china', 21),
#  ('germany', 20),
#  ('usa', 20),
#  ('okla.', 19),
#  ('fort bragg', 19),
#  ('arkansas', 19),
#  ('oakland', 19),
#  ('nassau', 19),
#  ('arizona', 18),
#  ('charlottesville', 18),
#  ('charleston', 18),
#  ('columbus', 18),
#  ('fl', 17),
#  ('france', 17),
#  ('san francisco', 17),
#  ('kentucky', 16),
#  ('nyc', 16),
#  ('australia', 15),
#  ('the united states of america', 15),
#  ('pittsburgh', 15),
#  ('milwaukee', 15),
#  ('new york’s', 14),
#  ('capitol hill autonomous zone', 14),
#  ('brazil', 13),
#  ('ore.', 13),
#  ('pennsylvania', 13),
#  ('nashville', 13),
#  ('st. louis', 13),
#  ('united states', 13),
#  ('las vegas', 13),
#  ('baltimore', 13),
#  ('tacoma', 13),
#  ('n.y.', 13),
#  ('san diego', 13),
#  ('canada', 12),
#  ('va.', 12),
#  ('birmingham', 12),
#  ('uk', 12),
#  ('camden', 12),
#  ('manhattan', 12),
#  ('ny', 12),
#  ('nj', 12),
#  ('tampa', 12),
#  ('athens', 11),
#  ('spain', 11),
#  ('maryland', 11),
#  ('massachusetts', 11),
#  ('st. john’s', 11),
#  ('st. paul', 11),
#  ('calif.', 11),
#  ('madrid', 10),
#  ('amsterdam', 10),
#  ('dublin', 10),
#  ('lansing', 10),
#  ('appomattox', 10),
#  ('charlotte', 10),
#  ('salem', 10),
#  ('tennessee', 10),
#  ('u.k.', 9),
#  ('illinois', 9),
#  ('harris county', 9),
#  ('springfield', 9),
#  ('connecticut', 9),
#  ('lafayette', 9),
#  ('iraq', 9),
#  ('hennepin county', 9),
#  ('new orleans', 9),
#  ('mexico', 8),
#  ('ireland', 8),
#  ('greece', 8),
#  ('barcelona', 8),
#  ('brussels', 8),
#  ('syria', 8),
#  ('the arizona republic', 8),
#  ('maricopa county', 8),
#  ('oregon', 8),
#  ('dc', 8),
#  ('tenn.', 8),
#  ('missouri', 8),
#  ('nc', 8),
#  ('jersey', 7),
#  ('new zealand', 7),
#  ('lauderdale', 7),
#  ('copenhagen', 7),
#  ('denmark', 7),
#  ('auckland', 7),
#  ("united states'", 7),
#  ('cleveland', 7),
#  ('indianapolis', 7),
#  ('🇸', 7),
#  ('north minneapolis', 7),
#  ('the park police', 7),
#  ('knoxville', 7),
#  ('spokane', 7),
#  ('bronx', 7),
#  ('nigeria', 7),
#  ('franklinville', 7),
#  ('miami', 7),
#  ('north carolina’s', 7),
#  ('vermont', 6),
#  ('binnish', 6),
#  ('poland', 6),
#  ('mexico city', 6),
#  ('mississippi', 6),
#  ('memphis', 6),
#  ('jacksonville', 6),
#  ('puerto rico', 6),
#  ('dayton', 6),
#  ('britain', 6),
#  ('colorado', 6),
#  ('carbondale', 6),
#  ('minn.', 6),
#  ('ghana', 6),
#  ('south africa', 6),
#  ('madison', 6),
#  ('raleigh', 6),
#  ('jackson', 5),
#  ('oklahoma city', 5),
#  ('el salvador', 5),
#  ('charlotte county', 5),
#  ('las cruces', 5),
#  ('riverside county', 5),
#  ('belgium', 5),
#  ('west point', 5),
#  ('yellow springs', 5),
#  ('county', 5),
#  ('accra', 5),
#  ('newark', 5),
#  ('putnam county', 5),
#  ('hong kong', 5),
#  ('watchung', 5),
#  ('new york city’s', 5),
#  ('asheville', 5),
#  ('u.s', 5),
#  ('kabul', 5),
#  ('nicaragua', 4),
#  ('colombia', 4),
#  ('costa rica', 4),
#  ('panama', 4),
#  ('belmont', 4),
#  ('montgomery county', 4),
#  ('sacramento', 4),
#  ('india', 4),
#  ('the united states’', 4),
#  ('russia', 4),
#  ('lafayette park', 4),
#  ('tucson', 4),
#  ('danville', 4),
#  ('ferguson', 4),
#  ('nevada', 4),
#  ('kansas city', 4),
#  ('fort worth', 4),
#  ('wash.', 4),
#  ('vegas', 4),
#  ('walmart', 4),
#  ('ashland', 4),
#  ('nairobi', 4),
#  ('kenya', 4),
#  ('new york state', 4),
#  ('washington dc', 4),
#  ('bridgeport', 4),
#  ('r.i.', 4),
#  ('mn', 4),
#  ('manheim', 4),
#  ('virginia beach', 4),
#  ('san antonio', 4),
#  ('the united states of serfs and lords', 4),
#  ('ky.', 4),
#  ('san jose', 4),
#  ('pakistan', 4),
#  ('cincinnati', 4),
#  ('idaho', 4),
#  ('wuhan', 4),
#  ('de hecho', 4),
#  ('el mundo', 4),
#  ('todo el país', 4),
#  ('afghanistan', 4),
#  ('bronzeville', 4),
#  ('israel', 4),
#  ('floyd county', 4),
#  ('barbès', 4),
#  ('the united\nstates', 4),
#  ('the montgomery county', 4),
#  ('brooklyn ny', 4),
#  ('olivebridge', 4),
#  ('radford city', 4),
#  ('terre haute', 4),
#  ('marshfield', 4),
#  ('montana', 4),
#  ('• city', 4),
#  ('vancouver', 4),
#  ('new bedford', 4),
#  ('pa.', 3),
#  ('north/south dakota', 3),
#  ('hawthorne', 3),
#  ('stockton', 3),
#  ('greenville', 3),
#  ('netherlands', 3),
#  ('alexandria', 3),
#  ('chester', 3),
#  ('naples', 3),
#  ('pflag', 3),
#  ('wausau', 3),
#  ('nassau county', 3),
#  ('new mexico', 3),
#  ('seminole county', 3),
#  ('galveston', 3),
#  ('santa rosa', 3),
#  ('n.j.', 3),
#  ('arlington', 3),
#  ('omaha', 3),
#  ('s.c.', 3),
#  ('centennial park', 3),
#  ('temecula', 3),
#  ('hartford', 3),
#  ('cook county', 3),
#  ('la', 3),
#  ('satellite beach', 3),
#  ('palm springs', 3),
#  ('rhode island', 3),
#  ('downtown knoxville', 3),
#  ('sarver', 3),
#  ('az', 3),
#  ('louisiana', 3),
#  ('savannah', 3),
#  ('the city of eastvale', 3),
#  ('eastvale', 3),
#  ('karbala', 3),
#  ('jersey city', 3),
#  ('hampton', 3),
#  ('ga.', 3),
#  ('bethlehem', 3),
#  ('saudi arabia', 3),
#  ('egypt', 3),
#  ('albuquerque', 3),
#  ('delaware', 3),
#  ('austin', 3),
#  ('brookfield', 3),
#  ('south phoenix', 3),
#  ('riverdale', 3),
#  ('the district of columbia', 3),
#  ('washington state', 3),
#  ('poulsbo', 3),
#  ('north kitsap county', 3),
#  ('north kitsap', 3),
#  ('kitsap county', 3),
#  ('topeka', 3),
#  ('n.c.', 3),
#  ('santa cruz', 3),
#  ('lancaster county', 3),
#  ('fayetteville', 3),
#  ('reno', 3),
#  ('hill autonomous zone', 3),
#  ('philando castile', 3),
#  ('indiana', 3),
#  ('niagara falls', 3),
#  ('antonio valenzuela', 3),
#  ('rochester', 3),
#  ('palo alto', 3),
#  ('baptist', 3),
#  ('franklin', 3),
#  ('westlake', 3),
#  ('sacramento unified', 2),
#  ('colchester', 2),
#  ('roc', 2),
#  ('miss.', 2),
#  ('gaza', 2),
#  ('alexandria city', 2),
#  ('northeast portland', 2),
#  ('little rock', 2),
#  ('st. john’s church', 2),
#  ('san francisco’s', 2),
#  ('op-ed', 2),
#  ('iowa city', 2),
#  ('mt. horeb', 2),
#  ('creve coeur', 2),
#  ('antifa', 2),
#  ('huntington', 2),
#  ('new', 2),
#  ('tallahassee', 2),
#  ('mo.', 2),
#  ('ethiopia', 2),
#  ('the united kingdom', 2),
#  ('clarksville', 2),
#  ('wick park', 2),
#  ('wroc', 2),
#  ('ynez', 2),
#  ('east carolina', 2),
#  ('burien', 2),
#  ('antwerp', 2),
#  ('martinsburg', 2),
#  ('west virginia', 2),
#  ('south dakota', 2),
#  ('sioux', 2),
#  ('s.d.', 2),
#  ("the state of california: rethinking ca's ban on affirmative action", 2),
#  ('diversey', 2),
#  ('lincoln park', 2),
#  ('brandon township', 2),
#  ('bellingham', 2),
#  ('the city of palm springs', 2),
#  ('sylva', 2),
#  ('prince ea', 2),
#  ('switzerland', 2),
#  ('manchester', 2),
#  ('coronavirus', 2),
#  ('catskill', 2),
#  ('l.a.', 2),
#  ('kingdom', 2),
#  ('brooklyn park', 2),
#  ('england', 2),
#  ('leicester', 2),
#  ('gloucester county', 2),
#  ('ocean beach', 2),
#  ('north beach', 2),
#  ('va', 2),
#  ("jersey city's", 2),
#  ('jersey city’s', 2),
#  ('md.', 2),
#  ('sonoma county', 2),
#  ('thailand', 2),
#  ('palmdale', 2),
#  ('lancaster', 2),
#  ('mass.', 2),
#  ('newport', 2),
#  ('south korea', 2),
#  ('syracuse', 2),
#  ('osage ave', 2),
#  ('anne arundel county', 2),
#  ('arundel county', 2),
#  ('gastonia', 2),
#  ('pinellas county', 2),
#  ('duluth', 2),
#  ('havre', 2),
#  ('englewood', 2),
#  ('orange', 2),
#  ('diamond bar', 2),
#  ('salt lake', 2),
#  ('mo', 2),
#  ('king county', 2),
#  ('utah', 2),
#  ('salt lake city', 2),
#  ('the city of philadelphia', 2),
#  ('columbia', 2),
#  ('la grange', 2),
#  ('waltham', 2),
#  ('shelby township', 2),
#  ('norwood park', 2),
#  ('edison park', 2),
#  ('jefferson park', 2),
#  ('palm beach county', 2),
#  ('south minneapolis', 2),
#  ('yolo county', 2),
#  ('the yolo county', 2),
#  ('bristol', 2),
#  ('the city of las vegas government', 2),
#  ('killeen', 2),
#  ('long beach', 2),
#  ('jamaica', 2),
#  ('norfolk', 2),
#  ('guam', 2),
#  ('monroe', 2),
#  ('montgomery county’s', 2),
#  ('kansas', 2),
#  ('loudoun county', 2),
#  ('holland', 2),
#  ('plymouth', 2),
#  ('grand junction', 2),
#  ('orlando', 2),
#  ('umcnext', 2),
#  ('the city of fayetteville', 2),
#  ('minn', 2),
#  ('elgin', 2),
#  ('rome', 2),
#  ('hamburg', 2),
#  ('fla.', 2),
#  ('fairborn', 2),
#  ('oregon district', 2),
#  ('downtown sanford', 2),
#  ('radical left democrats', 2),
#  ('https://youtu.be/dhmhlccmonc charlotte county', 2),
#  ('st. norbert', 2),
#  ('vallejo', 2),
#  ('bloomington', 2),
#  ('turkey', 2),
#  ('chattanooga', 2),
#  ('hamilton county', 2),
#  ('iran', 2),
#  ('strasburg', 2),
#  ('east petersburg', 2),
#  ('elizabethtown', 2),
#  ('ephrata', 2),
#  ('lititz', 2),
#  ('quarryville', 2),
#  ('bedminster', 2),
#  ('bosselman', 2),
#  ('mumbai', 2),
#  ('domingo', 2),
#  ('washington, dc', 2),
#  ('|', 2),
#  ('lower merion', 2),
#  ('columbia-willamette', 2),
#  ('ymca', 2),
#  ('ky', 2),
#  ('jesuit', 2),
#  ('washington city government', 2),
#  ('johnson city', 2),
#  ('pasadena', 2),
#  ('united brass', 2),
#  ('chicago ave', 2),
#  ('shanelle', 2),
#  ('lewis county', 2),
#  ('flushing, queens', 2),
#  ('sc', 2),
#  ('la crosse county', 2),
#  ('la crosse', 2),
#  ('hartbeespoort', 2),
#  ('reivilo', 2),
#  ('klerksdorp', 2),
#  ('kzn midlands', 2),
#  ('tulbach', 2),
#  ('balgowan', 2),
#  ('kobie', 2),
#  ('free state', 2),
#  ('oxnard', 2),
#  ('punxsutawney', 2),
#  ('ouray', 2),
#  ('brazoria county', 2),
#  ('bates park', 2),
#  ('angleton', 2),
#  ('carmel', 1),
#  ('franklin township', 1),
#  ('mauritania', 1),
#  ('fort myers', 1),
#  ('oakwood', 1),
#  ('san bernardino county', 1),
#  ('cape coral', 1),
#  ('amish', 1),
#  ('amerikkka', 1),
#  ('the united state', 1),
#  ('downtown portland', 1),
#  ('acps', 1),
#  ('yucaipa', 1),
#  ('the san bernardino county sheriff’s department', 1),
#  ('novato', 1),
#  ('f**king', 1),
#  ('rose city park', 1),
#  ('longmont', 1),
#  ('bayview', 1),
#  ('wa state', 1),
#  ('british columbia', 1),
#  ('greenwich village', 1),
#  ('bethesda', 1),
#  ('hattiesburg', 1),
#  ('durham', 1),
#  ('wheaton', 1),
#  ('wayne county', 1),
#  ('lakeview chicago', 1),
#  ('halsted', 1),
#  ('drag queens', 1),
#  ('kings', 1),
#  ('boystown', 1),
#  ('long island', 1),
#  ("san francisco's", 1),
#  ('oviedo', 1),
#  ('wisconsins', 1),
#  ('st. pauls', 1),
#  ('bushwick', 1),
#  ('mabou mines', 1),
#  ('new georges', 1),
#  ('ars nova', 1),
#  ("santa rosa's", 1),
#  ('warren', 1),
#  ('sunrise greensboro', 1),
#  ('dorchester', 1),
#  ('the north end', 1),
#  ('columbus avenue', 1),
#  ('bunna/shai', 1),
#  ('puerto rican parade', 1),
#  ('los angeles county', 1),
#  ('marion county', 1),
#  ('tn', 1),
#  ('the boogaloo bois', 1),
#  ('san clemente’s', 1),
#  ('south brunswick', 1),
#  ('west africa', 1),
#  ('hanover', 1),
#  ('rwanda', 1),
#  ('newton', 1),
#  ('murrieta', 1),
#  ('duck pond', 1),
#  ('buffalo ny', 1),
#  ('deyanna davis', 1),
#  ('van buren twp', 1),
#  ('bellville', 1),
#  ('lakeland', 1),
#  ('black roots', 1),
#  ('bomba', 1),
#  ('puerto rico’s', 1),
#  ('mathare', 1),
#  ('empire', 1),
#  ('maine', 1),
#  ('north carolina - wway', 1),
#  ('lycoming county', 1),
#  ('frisco', 1),
#  ('juneteenth', 1),
#  ('orem', 1),
#  ('boyle heights', 1),
#  ('patrisse cullors', 1),
#  ('jouelzy', 1),
#  ('west county', 1),
#  ('geneseo', 1),
#  ('northwest indiana', 1),
#  ('rockford', 1),
#  ('the queen city', 1),
#  ('des moines', 1),
#  ('st. paul?', 1),
#  ('haiti', 1),
#  ('ventura', 1),
#  ('rosemount', 1),
#  ('ramsey', 1),
#  ('downtown long beach', 1),
#  ('wales', 1),
#  ('the autonomous zone', 1),
#  ('md', 1),
#  ('the city of buffalo', 1),
#  ('kennewick', 1),
#  ('montgomery', 1),
#  ('ala.', 1),
#  ('baldwin', 1),
#  ('new york city silent', 1),
#  ('allentown', 1),
#  ('karachi', 1),
#  ('pleasant valley', 1),
#  ('his kingdom', 1),
#  ('bangladesh', 1),
#  ('indonesia', 1),
#  ('capital hill autonomous zone', 1),
#  ('ukraine', 1),
#  ('iceland', 1),
#  ('venezuela', 1),
#  ('croatia', 1),
#  ('argentina', 1),
#  ('chile', 1),
#  ('richmond bean', 1),
#  ('san antonio\n', 1),
#  ('centre county’s', 1),
#  ('malvern', 1),
#  ('west bt', 1),
#  ('judkins park', 1),
#  ('stoke', 1),
#  ('baltimore county', 1),
#  ('barbados', 1),
#  ('third ward', 1),
#  ('gazette medina county gazette', 1),
#  ('valley city', 1),
#  ('medina county’s', 1),
#  ('medina', 1),
#  ('gazette', 1),
#  ('everett', 1),
#  ('ludlow', 1),
#  ('hamilton', 1),
#  ('ri', 1),
#  ('the eastern shore', 1),
#  ('dover', 1),
#  ('wheatville', 1),
#  ('ut', 1),
#  ('u.s. park', 1),
#  ("south carolina's", 1),
#  ('black lives', 1),
#  ('auburn ave', 1),
#  ('cemetery field', 1),
#  ('sandy springs', 1),
#  ('district 8', 1),
#  ('yamhill county', 1),
#  ('san diego county', 1),
#  ('san diego\n', 1),
#  ('san diego \n', 1),
#  ("police—'no", 1),
#  ('south carolina church', 1),
#  ('garden city', 1),
#  ('the coastal empire', 1),
#  ('mpls', 1),
#  ('acadiana', 1),
#  ('north charleston', 1),
#  ('brix', 1),
#  ('tribune', 1),
#  ('taipei', 1),
#  ('taiwan', 1),
#  ('create autonomous zone', 1),
#  ('gaston county', 1),
#  ('greater philadelphia', 1),
#  ('berrien county', 1),
#  ('bchd', 1),
#  ('benton harbor', 1),
#  ('benton harbor farmer’s', 1),
#  ('swanigan', 1),
#  ('guyana', 1),
#  ('christi', 1),
#  ('@phillysocfem', 1),
#  ('ghana - blavity', 1),
#  ('south florida', 1),
#  ('chernobyl', 1),
#  ('washington d.c.', 1),
#  ('san fernando valley', 1),
#  ('inc', 1),
#  ('marion', 1),
#  ('mont.', 1),
#  ('vidor', 1),
#  ('triple oaks', 1),
#  ('chesterfield', 1),
#  ('culpeper', 1),
#  ('powhatan', 1),
#  ('anaheim', 1),
#  ('mi', 1),
#  ('bucks', 1),
#  ('doylestown', 1),
#  ('hummelstown', 1),
#  ('the u. s.', 1),
#  ('corvallis', 1),
#  ('brevard', 1),
#  ('beavercreek', 1),
#  ('𝐂𝐚𝐫𝐫𝐲 𝐖𝐢𝐭𝐡𝐢𝐧', 1),
#  ('northern idaho', 1),
#  ('queens', 1),
#  ('arverne', 1),
#  ('astoria', 1),
#  ('lakeview ave', 1),
#  ('kirksville', 1),
#  ('the city of kirksville', 1),
#  ('lawrenceburg', 1),
#  ("riverside county's", 1),
#  ('riverside county’s', 1),
#  ('wilson park', 1),
#  ('torrance', 1),
#  ('meditation.\u202c', 1),
#  ('brickell', 1),
#  ('west grove', 1),
#  ('miami-dade county', 1),
#  ('lake city', 1),
#  ('zala', 1),
#  ('mcdonough', 1),
#  ('henry county', 1),
#  ('nj protest', 1),
#  ('irvington', 1),
#  ('medford', 1),
#  ('philly dsa', 1),
#  ('toxic free philly', 1),
#  ('philadelphia jobs', 1),
#  ('phillysun', 1),
#  ('rohnert park', 1),
#  ('tx', 1),
#  ('west st. louis county', 1),
#  ('wildwood', 1),
#  ('the portland metropolitan region', 1),
#  ('the city of west linn', 1),
#  ('broward', 1),
#  ('pittsburg', 1),
#  ('•former', 1),
#  ('zephyr park', 1),
#  ('zephyrhills city', 1),
#  ('north carolina - tony wong', 1),
#  ('santa monica', 1),
#  ('sant', 1),
#  ('delray beach', 1),
#  ('boca', 1),
#  ('boca raton', 1),
#  ('delray', 1),
#  ('cass county', 1),
#  ('the cass county clerk’s', 1),
#  ('legrier', 1),
#  ('another soviet union', 1),
#  ('grovetown', 1),
#  ('leesville', 1),
#  ('dale county', 1),
#  ('blackstone', 1),
#  ('pineville', 1),
#  ('bowling green', 1),
#  ('prince george county', 1),
#  ('timpa', 1),
#  ('camden county', 1),
#  ('adventist', 1),
#  ('athens county', 1),
#  ('| athens', 1),
#  ('https://jocolibrary.bibliocommons.com/list/share/73908055/1657126159', 1),
#  ('irwin county', 1),
#  ('huntington beach', 1),
#  ('cambodia town', 1),
#  ('lee county', 1),
#  ('south seattle', 1),
#  ('rainier beach', 1),
#  ('downtown norfolk', 1),
#  ('-new york', 1),
#  ('laos', 1),
#  ('myanmar', 1),
#  ('sapahn', 1),
#  ('cambodia', 1),
#  ('university park', 1),
#  ('kan.', 1),
#  ('the city of', 1),
#  ('"united states of socialism', 1),
#  ('buffalo n.y.', 1),
#  ('d-ma', 1),
#  ('vt', 1),
#  ('tyre', 1),
#  ('nineveh', 1),
#  ('saint paul', 1),
#  ('the city of gonzales', 1),
#  ('cherry park', 1),
#  ('mesa', 1),
#  ('the city of mesa', 1),
#  ("san antonio's", 1),
#  ('the city of charlotte', 1),
#  ('great britain', 1),
#  ('florida state', 1),
#  ('loudoun', 1),
#  ('https://bluevirginia.us/2020/06/loudoun-county-young-republicans-launch-effort-to-recall-chair-phyllis-randall-use-darkened-photo-of-countys-first-ever-african-american-county-board-chair loudoun county',
#   1),
#  ('chicagoland', 1),
#  ('goshen', 1),
#  ('como', 1),
#  ('cuándo', 1),
#  ('hogar', 1),
#  ('que es', 1),
#  ('que se vayan', 1),
#  ('waukesha', 1),
#  ('delafield', 1),
#  ('greendale', 1),
#  ('lake mills', 1),
#  ('waupaca', 1),
#  ('ride, elkhorn', 1),
#  ('wi', 1),
#  ('humboldt park', 1),
#  ('genoa city', 1),
#  ('janesville', 1),
#  ('pulaski', 1),
#  ('layton blvd', 1),
#  ('south milwaukee', 1),
#  ('morgan park', 1),
#  ('wisconsin ave', 1),
#  ('burlington', 1),
#  ('erie', 1),
#  ('new haven', 1),
#  ('north jersey muslim', 1),
#  ('palm harbor', 1),
#  ('d-orlando', 1),
#  ("new york's", 1),
#  ('mesa county', 1),
#  ('dubois', 1),
#  ('wyoming', 1),
#  ('casper', 1),
#  ('black wyomingites', 1),
#  ('laramie', 1),
#  ('kowalewski ward', 1),
#  ('boulder creek', 1),
#  ('felton', 1),
#  ('orange county supervisors take formal stand against police brutality', 1),
#  ('orange county supervisors', 1),
#  ('mount vernon', 1),
#  ('traverse city’s', 1),
#  ('wexford county', 1),
#  ('cedarburg', 1),
#  ('ozaukee county', 1),
#  ('knox county', 1),
#  ('grand traverse county', 1),
#  ('grafton', 1),
#  ('o’fallon', 1),
#  ('scotland', 1),
#  ('\u2063 🖤', 1),
#  ('new london', 1),
#  ('kobe', 1),
#  ('moscow', 1),
#  ('st louis', 1),
#  ('grant park', 1),
#  ('greensburg', 1),
#  ('laundromat', 1),
#  ('aira', 1),
#  ('montpelier', 1),
#  ('sleepy lockhart today', 1),
#  ('hays county', 1),
#  ('caldwell co', 1),
#  ('bbg', 1),
#  ('toshira', 1),
#  ('prep southside', 1),
#  ('blue', 1),
#  ('my city', 1),
#  ('waterloo', 1),
#  ('west palm beach', 1),
#  ('the state of wisconsin', 1),
#  ('berwick', 1),
#  ('palmerton', 1),
#  ('seoul', 1),
#  ('afro-boricua ritmos', 1),
#  ('jamestown', 1),
#  ('wa', 1),
#  ('autonomous zone', 1),
#  ('twp.', 1),
#  ('long hill', 1),
#  ('fort', 1),
#  ('japan', 1),
#  ('hemming park', 1),
#  ('connected to', 1),
#  ('communities united against police', 1),
#  ('martinsville', 1),
#  ('sybrina', 1),
#  ('bethel', 1),
#  ('memorial park', 1),
#  ('palos heights', 1),
#  ('sgpd', 1),
#  ('seal beach', 1),
#  ('nafeez', 1),
#  ('caldwell county', 1),
#  ('lockhart', 1),
#  ('south jersey', 1),
#  ('nantes', 1),
#  ('calgary', 1),
#  ('rio de janeiro', 1),
#  ('sydney', 1),
#  ('tokyo', 1),
#  ('solon', 1),
#  ('anti-israel', 1),
#  ('ucc', 1),
#  ('fla', 1),
#  ('mobile', 1),
#  ('worcester', 1),
#  ('seacoast', 1),
#  ('tel aviv', 1),
#  ('chardon', 1),
#  ('potomac', 1),
#  ('greenway', 1),
#  ('the anne springs', 1),
#  ('centerton', 1),
#  ('laurel', 1),
#  ('mt.', 1),
#  ('the maasai warriors', 1),
#  ('cranston', 1),
#  ('rhode island pride', 1),
#  ('#ripride', 1),
#  ('downtown phoenix', 1),
#  ('taylors', 1),
#  ('grand rapids', 1),
#  ('los que', 1),
#  ('nijc', 1),
#  ('zeeshan', 1),
#  ('arna, shrayya', 1),
#  ('sauriya', 1),
#  ('nusrath sultana', 1),
#  ('rancho california', 1),
#  ('deutschland', 1),
#  ('travis county', 1),
#  ('waco', 1),
#  ('texas city', 1),
#  ('chino', 1),
#  ('west philly', 1),
#  ('https://www.youtube.com/watch?v=svkxj7ulvrc', 1),
#  ('the "autonomous zone"', 1),
#  ('oxford', 1),
#  ('island county', 1),
#  ('lutheran', 1),
#  ('providence', 1),
#  ('oregon city', 1),
#  ('claire county', 1),
#  ('the city of kingston', 1),
#  ('golden hill', 1),
#  ('uae', 1),
#  ('erdogan', 1),
#  ('qatar', 1),
#  ('norman', 1),
#  ('beijing', 1),
#  ('johnson county', 1),
#  ('shawnee mission', 1),
#  ('henrietta', 1),
#  ('the city of richmond police department', 1),
#  ('joining city', 1),
#  ("richmond commonwealth's", 1),
#  ('deuteronomy', 1),
#  ('the kingdom of heaven', 1),
#  ('norilsk', 1),
#  ('rockingham county', 1),
#  ('waltham city', 1),
#  ('sentinel', 1),
#  ('lititz springs park', 1),
#  ('north to south minneapolis', 1),
#  ('hoke county', 1),
#  ('mecklenburg county', 1),
#  ('somerset county', 1),
#  ('alexandire', 1),
#  ('seattle pd', 1),
#  ('fulton county', 1),
#  ('east passyunk', 1),
#  ('texarkana', 1),
#  ('stone coast', 1),
#  ('seattle autonomous', 1),
#  ('spokane county', 1),
#  ('middletown', 1),
#  ('glendale', 1),
#  ('lockwood', 1),
#  ('webster groves', 1),
#  ('lancaster city', 1),
#  ('millersville', 1),
#  ('wendover', 1),
#  ('greensboro', 1),
#  ('sábado', 1),
#  ('las', 1),
#  ('clark park', 1),
#  ('tulane', 1),
#  ('south philly', 1),
#  ('pensacola', 1),
#  ('yemen', 1),
#  ('the west bank', 1),
#  ('mali', 1),
#  ('calhoun', 1),
#  ('haverhill', 1),
#  ('selma', 1),
#  ('carlsbad', 1),
#  ('eddy county courthouse', 1),
#  ('eddy county', 1),
#  ('rv', 1),
#  ('melania', 1),
#  ('alaska', 1),
#  ('staten island', 1),
#  ('https://fal.cn/38bkt', 1),
#  ('the city of minneapolis', 1),
#  ('hertford', 1),
#  ('alton', 1),
#  ('san quentin', 1),
#  ('st. agnes', 1),
#  ('st. ignatius parish', 1),
#  ('st. ignatius', 1),
#  ('st. agnes parish', 1),
#  ('são paulo', 1),
#  ('north star', 1),
#  ('fordham manor', 1),
#  ('morris ave', 1),
#  ('champaign county', 1),
#  ('birmingham city', 1),
#  ('new york&#821', 1),
#  ('edgefield', 1),
#  ('carolina', 1),
#  ('evanston', 1),
#  ('mill creek', 1),
#  ('mount trashmore', 1),
#  ('the city of virginia beach police department', 1),
#  ('the city of virginia beach fire department', 1),
#  ('escondido', 1),
#  ('santa fe county', 1),
#  ('doral', 1),
#  ('northland', 1),
#  ('northwoods', 1),
#  ('baltimore city', 1),
#  ('https://www.nowtheendbegins.com/nteb-prophecy-news-podcast-they-all-lied-about-coronavirus-justify-global-lockdowns-here-what-will-likely-happen-next/',
#   1),
#  ('saint augustine', 1),
#  ('https://www.nowtheendbegins.com/mandatory-masks-social-conditioning-control-covid-19-new-world-order-trojan-horse/',
#   1),
#  ('st. paul city', 1),
#  ('muncie', 1),
#  ...]

# %%
dataframe611=pd.DataFrame(dict_a)

# %%
len(dict_a)
# Out:
# 1124

# %%
# %cd dataframe_csv
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/dataframe_csv

# %%
# !ls
# Out:
# dataframe0529.csv  dataframe0602.csv  dataframe0606.csv  dataframe0610.csv
# dataframe0530.csv  dataframe0603.csv  dataframe0607.csv  dataframe0611.csv
# dataframe0531.csv  dataframe0604.csv  dataframe0608.csv  heatmap.csv
# dataframe0601.csv  dataframe0605.csv  dataframe0609.csv

# %%
dataframe611.to_csv('dataframe0613.csv')
