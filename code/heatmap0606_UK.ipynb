# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 4.3 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=0223a954ba8dfa3c4162ded85643dd61346dea772a68ad0edf4f9e4c4a7cbf80
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_US         dataframe_csv
#  a0529.csv	        dataframe_csv_UK
#  a0530.csv	        dataframe_result_csv
#  a0531.csv	        dataframe_result_csv_UK
#  a0601.csv	        Github
#  a0602.csv	        heatmap529_UK.ipynb
#  a0603.csv	        heatmap530.ipynb
#  a0604.csv	        Heat_Map_Online_language.ipynb
#  a0605.csv	        __MACOSX
#  csv		        non_violant1.csv
#  csv.zip	        non_violant2.csv
#  dataframe0603_UK.csv   UK
#  dataframe0604_UK.csv   violant.csv
#  dataframe0605_UK.csv  '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_531 = 'UK/06_06.csv'

# %%
ct = pd.read_csv(ct_path_531)

# %%
ct.shape[1]
# Out:
# 47

# %%
#columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                               platformId  ...                    post_id
# 0      1204666772916238_3022436634472567  ...   4946904|3022436634472567
# 1       987673694762272_1437498816446422  ...  10909159|1437498816446422
# 2          56845382910_10158226273137911  ...    13844|10158226273137911
# 3       457604514282180_4110753105633951  ...  10054545|4110753105633951
# 4      1425803351055421_2372418579727222  ...  10933711|2372418579727222
# ...                                  ...  ...                        ...
# 23248  1675502322728328_2924501097828438  ...  12122250|2924501097828438
# 23249  1749814981940531_2702232190032134  ...   1427946|2702232190032134
# 23250   452385308168295_3857115024361956  ...   1414208|3857115024361956
# 23251    242005956573162_725343184906101  ...   10142781|725343184906101
# 23252   641343609302301_2456692387767405  ...   1306578|2456692387767405
#
# [23253 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#   NER-msg NER-desc
# 0      {}       {}
# 1      {}       {}
# 2      {}       {}
# 3      {}       {}
# 4      {}       {}

# %%
ct.to_csv('a0606.csv')

# %%
ct=pd.read_csv('a0606.csv',lineterminator="\n")

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#             NER-msg  ...        NER-title
# 6       {'U.S.': 1}  ...               {}
# 7                {}  ...               {}
# 8                {}  ...    {'Owosso': 1}
# 9   {'San Jose': 1}  ...  {'San Jose': 1}
# 10               {}  ...  {'San Jose': 1}
#
# [5 rows x 3 columns]

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ct_ner['NER-msg']
# Out:
# 6                                                   [U.S.]
# 7                                                       []
# 8                                                       []
# 9                                               [San Jose]
# 10                                                      []
#                                ...
# 23247    [Santa Clara, San Francisco, CT, Alameda, Cont...
# 23248    [minneapolis, Orange County, Minnesota, florid...
# 23249                                                   []
# 23250                                           [Cornwall]
# 23252                     [Minneapolis, the United States]
# Name: NER-msg, Length: 16581, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ct_ner['NER']
# Out:
# 6                                                   [U.S.]
# 7                [Hauraki-Waikato - Donna Pokere-Phillips]
# 8                          [Mich., OWOSSO, Owosso, Owosso]
# 9                                     [San Jose, San Jose]
# 10                              [the Deep State, San Jose]
#                                ...
# 23247    [Santa Clara, San Francisco, CT, Alameda, Cont...
# 23248    [minneapolis, Orange County, Minnesota, florid...
# 23249    [Minneapolis, Washington, D.C., Washington DC,...
# 23250                                 [Cornwall, Cornwall]
# 23252    [Minneapolis, the United States, Minneapolis, ...
# Name: NER, Length: 16581, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ner_lst = ct_ner['NER'].values

# %%
ner_lst
# Out:
# array([list(['u.s.']), list(['hauraki-waikato - donna pokere-phillips']),
#        list(['mich.', 'owosso', 'owosso']), ...,
#        list(['minneapolis', 'washington', 'd.c.', 'washington dc', 'dc', 'lafayette square', 'florida', 'iraq']),
#        list(['cornwall']), list(['minneapolis', 'the united states'])],
#       dtype=object)

# %%
m=0
list=[]
for n in ner_lst:
  for i in range(len(n)):
    list.append(ner_lst[m][i])
  m+=1

# %%
list
# Out:
# ['u.s.',
#  'hauraki-waikato - donna pokere-phillips',
#  'mich.',
#  'owosso',
#  'owosso',
#  'san jose',
#  'the deep state',
#  'san jose',
#  'the deep state',
#  'minneapolis',
#  'san jose',
#  'washington dc',
#  'dc',
#  'san jose',
#  'san jose',
#  'dc',
#  'minneapolis',
#  'dc',
#  'd.c',
#  'america',
#  'us',
#  'birmingham',
#  'uk',
#  'st louis, dc',
#  'chicago',
#  'baltimore',
#  'birmingham',
#  'atlanta',
#  'birmingham',
#  'birmingham',
#  'texas',
#  'america',
#  'minneapolis',
#  'dakota',
#  'chicago',
#  'broadway ave',
#  'franklin ave',
#  'sd',
#  'north minneapolis',
#  'u.s bank',
#  'mn 55411',
#  'america',
#  'minnesota',
#  'kentucky',
#  'massachusetts',
#  'china',
#  'the united states',
#  'salem',
#  'india',
#  'the united states',
#  'salem',
#  'america',
#  'bainbridge island',
#  'america',
#  'birmingham',
#  'alabama',
#  'laguna niguel',
#  'the laguna niguel ymca',
#  'myghanalinks',
#  'buffalo',
#  'minneapolis',
#  'u.s.',
#  'north carolina',
#  'minneapolis',
#  'dakota',
#  'chicago',
#  'broadway ave',
#  'franklin ave',
#  'sd',
#  'north minneapolis',
#  'u.s bank',
#  'mn 55411',
#  'new york city',
#  'n.y.c.',
#  'new york',
#  'the united states of america',
#  'resurrection city',
#  'boston',
#  'washington',
#  'd.c.',
#  'n.y.c.',
#  'the united states',
#  'north carolina',
#  'gulfport',
#  'minnesota',
#  'united states',
#  'us',
#  'washington',
#  'washington dc',
#  'dc',
#  'usa',
#  'arkansas',
#  'us',
#  'washington',
#  'canton',
#  'tulsa',
#  'america',
#  'chicago',
#  'okemah',
#  'oklahoma',
#  'detroit',
#  'united states',
#  'wisconsin',
#  'kenosha',
#  'wis.',
#  'new mexico',
#  'minneapolis',
#  'd.c.',
#  'washington',
#  'minneapolis',
#  'dakota',
#  'chicago',
#  'broadway ave',
#  'franklin ave',
#  'sd',
#  'north minneapolis',
#  'u.s bank',
#  'mn 55411',
#  'sacramento',
#  'san diego',
#  'los angeles',
#  'california',
#  'san francisco',
#  'san francisco',
#  'simi valley',
#  'milwaukee',
#  'maryland',
#  'milwaukee',
#  'potomac',
#  'minneapolis',
#  'seattle',
#  'washington',
#  'minneapolis',
#  'ny',
#  'ny',
#  'minneapolis',
#  'san diego',
#  'coronado',
#  'clackamas county',
#  'genesee county',
#  'clackamas county',
#  'us',
#  'minnesota',
#  'clackamas county',
#  'orange county',
#  'minneapolis',
#  'long beach',
#  'houston',
#  'los angeles',
#  'america',
#  'la',
#  'south los angeles',
#  'minnesota',
#  'orange county',
#  'texas',
#  'los angeles',
#  'los angeles\n',
#  'laguna beach\n',
#  'santa ana',
#  'us',
#  'smyrna',
#  'philadelphia',
#  'philadelphia',
#  'minneapolis',
#  'mn',
#  'minneapolis',
#  'mn',
#  'worcester',
#  'massachusetts',
#  'america',
#  'america',
#  'minneapolis',
#  'ghana',
#  'minneapolis',
#  'ghana',
#  'america',
#  'minneapolis',
#  'ghana',
#  'us',
#  'minnesota',
#  'minneapolis',
#  'ghana',
#  'connecticut',
#  'ventura county',
#  'simi valley',
#  'connecticut',
#  'brevard',
#  'florida',
#  'brevard county',
#  'hollywood',
#  'd.c.',
#  'dc',
#  'washington',
#  'melania',
#  'rv',
#  'sacramento',
#  'san diego',
#  'los angeles',
#  'california',
#  'san francisco',
#  'simi valley',
#  'kansas',
#  'd.c.',
#  'marriot',
#  'dc',
#  'washington',
#  'baton rouge',
#  'nashville',
#  'plymouth',
#  'michigan',
#  'minneapolis',
#  'minneapolis',
#  'the united kingdom',
#  'kingston',
#  'us',
#  'the united states embassy',
#  'jamaica',
#  'liguanea',
#  'oklahoma city',
#  'pretoria',
#  'london',
#  'the united states',
#  'sydney',
#  'clermont',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'vancouver',
#  'dc',
#  'us',
#  'vancouver',
#  'washington',
#  'usa',
#  'the united states',
#  'laguna niguel',
#  'the laguna niguel ymca',
#  'hilo',
#  'hawaii',
#  'ohio',
#  'madison park',
#  'texas',
#  'bakersfield',
#  'minneapolis',
#  'the kern county coroner’s office',
#  'texas',
#  'america',
#  'wisconsin',
#  'alberta',
#  'st. paul',
#  'us',
#  'minnesota',
#  'us',
#  '|',
#  'buffalo',
#  'los angeles',
#  'us',
#  'new york',
#  'washington',
#  'the united states',
#  'los angeles',
#  'us',
#  'new york',
#  'washington',
#  'the united states',
#  'minneapolis',
#  'us',
#  'washington',
#  'milwaukee',
#  'buffalo',
#  'the united states',
#  'america',
#  'antifa',
#  'america',
#  'antifa',
#  'sacramento',
#  'san diego',
#  'los angeles',
#  'california',
#  'san francisco',
#  'san francisco',
#  'simi valley',
#  'china',
#  'us',
#  'hongkong',
#  'china',
#  'us',
#  'minneapolis',
#  'minnesota',
#  'north carolina',
#  'raeford',
#  'north carolina',
#  'raeford',
#  'raeford',
#  'london',
#  'london',
#  'london',
#  'houston',
#  'minnesota',
#  'hennepin county',
#  'america',
#  'ethiopia',
#  'minnesota',
#  'hennepin county',
#  'minneapolis',
#  'syria',
#  'manchester',
#  'vermont',
#  'dc',
#  'washington',
#  'washington',
#  'minneapolis',
#  'minnesota',
#  'dc',
#  'washington',
#  'washington',
#  'minneapolis',
#  'minnesota',
#  'the united states',
#  'minneapolis',
#  'minnesota',
#  'augusta',
#  'minneapolis',
#  'richmond county',
#  'chillicothe',
#  'minnesota',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'concord',
#  'redding',
#  'minneapolis',
#  'america',
#  'u.s.',
#  'washington',
#  'washington',
#  'higher heights for',
#  "the district of columbia's",
#  'd.c.',
#  'washington',
#  'd.c.',
#  'u.s.',
#  'washington',
#  'america',
#  'kūpuna',
#  'minneapolis',
#  'center city',
#  'philadelphia',
#  'snohomish county',
#  'france',
#  'snohomish county',
#  'normandy',
#  'new york city',
#  'snohomish county',
#  'u.s.',
#  'gainesville',
#  'washington',
#  'd.c.',
#  'alleghany county',
#  'alleghany',
#  'covington',
#  '•',
#  'roanoke city',
#  'virginia',
#  'salem',
#  'health district',
#  'roanoke county',
#  'roanoke',
#  'china',
#  'tuscaloosa',
#  'alabama',
#  'the city of tuscaloosa',
#  'hollywood',
#  'charlevoix',
#  'america',
#  'texas',
#  'united states',
#  'minnesota',
#  'texas',
#  'united states',
#  'minnesota',
#  'cahokia',
#  'illinois',
#  'toronto',
#  'minneapolis',
#  'guangzhou',
#  'missouri',
#  'america',
#  'maryland',
#  'baltimore',
#  'new york',
#  'minnesota',
#  'louisville',
#  'kentucky',
#  'china',
#  'cleveland',
#  'ohio',
#  'sanford',
#  'ferguson',
#  'toronto',
#  'florida',
#  'the united states',
#  'toronto',
#  'sacramento',
#  'san diego',
#  'los angeles',
#  'california',
#  'san francisco',
#  'san francisco',
#  'simi valley',
#  'australia',
#  'us',
#  'holy trinity',
#  'australia',
#  'st. augustine’s',
#  'washington, dc',
#  'washington, dc',
#  'kingston',
#  'kingston',
#  'minneapolis',
#  'columbus',
#  'kingston',
#  'midtown',
#  'pekin',
#  'pekin',
#  'pekin',
#  'pekin',
#  'san antonio',
#  'minneapolis',
#  'us',
#  'yuendumu',
#  'omaha',
#  'pekin',
#  'pekin',
#  'florida',
#  'florida',
#  'florida',
#  'minneapolis',
#  'toronto',
#  'tehran',
#  'us',
#  'iran',
#  'minneapolis',
#  'minneapolis',
#  'iowa',
#  'minneapolis',
#  'des moines',
#  'des moines',
#  'minneapolis',
#  'toronto',
#  'new york city',
#  'los angeles',
#  'u.s.',
#  'chicago',
#  'us',
#  'san francisco',
#  'washington d.c.',
#  'ghana',
#  'u.s.',
#  'us',
#  'ghana',
#  'germany',
#  'minneapolis',
#  'artesia',
#  'sacramento',
#  'us',
#  'dallas',
#  'atlanta',
#  'texas',
#  'georgia',
#  'washington',
#  'maryland',
#  'montgomery county',
#  'minneapolis',
#  'paris',
#  'south africa',
#  'johannesburg',
#  'rome',
#  'north carolina',
#  'minneapolis',
#  'paris',
#  'south africa',
#  'johannesburg',
#  'rome',
#  'north carolina',
#  'minneapolis',
#  'paris',
#  'south africa',
#  'johannesburg',
#  'rome',
#  'minneapolis',
#  'paris',
#  'south africa',
#  'johannesburg',
#  'rome',
#  'north carolina',
#  'minneapolis',
#  'paris',
#  'south africa',
#  'johannesburg',
#  'rome',
#  'north carolina',
#  'us',
#  'us',
#  'richmond',
#  'london',
#  'us',
#  'uk',
#  'minneapolis',
#  'america',
#  'america',
#  'cleveland',
#  'america',
#  'providence',
#  'america',
#  'minnesota',
#  'philadelphia',
#  'florida',
#  'florida',
#  'america',
#  'minneapolis',
#  'us',
#  'd.c.',
#  'd.c.',
#  'america',
#  'new york city',
#  'antifa',
#  'america',
#  'minneapolis',
#  'rotary park',
#  'cape may',
#  'glasgow',
#  'fife',
#  'us',
#  'edinburgh',
#  'america',
#  'minneapolis',
#  'florida',
#  'pinellas county',
#  'minneapolis',
#  'u.s.',
#  'venezuela',
#  'miami',
#  'the united states',
#  'venezuela',
#  'moline',
#  'the united states',
#  'u.s.',
#  'the united states',
#  'u.s.',
#  'venezuela',
#  'miami',
#  'the united states',
#  'florida',
#  'pinellas county',
#  'minneapolis',
#  'pinellas county',
#  'florida',
#  'minneapolis',
#  'pinellas county',
#  'florida',
#  'minneapolis',
#  'louisville',
#  'washington d.c.',
#  'washington',
#  'u.s.',
#  'venezuela',
#  'miami',
#  'the united states',
#  'tunisia',
#  'germany',
#  'prague',
#  'canada',
#  'vancouver',
#  'buffalo',
#  'sr.',
#  'minneapolis',
#  'usa',
#  'minneapolis',
#  'nw',
#  'us',
#  'washington',
#  'the united states',
#  'canada',
#  'vancouver',
#  'usa',
#  'india',
#  'usa',
#  'america',
#  'washington dc',
#  'fort bragg',
#  'u.s.',
#  'venezuela',
#  'miami',
#  'the united states',
#  'venezuela',
#  'usa',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'texas',
#  'america',
#  'u.s.',
#  'venezuela',
#  'miami',
#  'the united states',
#  'uk',
#  'minneapolis',
#  'minneapolis',
#  'mayfair',
#  'allegheny',
#  'minneapolis',
#  'philadelphia',
#  'philadelphia',
#  'philadelphia',
#  'arizona',
#  'philadelphia',
#  'phoenix',
#  'philadelphia',
#  'philadelphia',
#  'minneapolis',
#  'buffalo',
#  'new york',
#  'buffalo',
#  'new york',
#  'minneapolis',
#  'encinitas',
#  'n.y.',
#  'buffalo',
#  'buffalo',
#  'minnesota',
#  'south africa’s',
#  'minneapolis',
#  'dc',
#  'dc',
#  'https://buff.ly/2xkukza',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'australia',
#  'mexico',
#  'minneapolis',
#  'australia',
#  'minneapolis',
#  'houston',
#  'houston ave',
#  'minneapolis',
#  'the united states',
#  'buffalo',
#  'buffalo',
#  'minnesota',
#  'my bio',
#  'usa',
#  'buffalo',
#  'n.y.',
#  'buffalo',
#  'buffalo',
#  'minnesota',
#  'u.s.',
#  'minneapolis',
#  'america',
#  'london',
#  'usa',
#  'britain',
#  'washington',
#  'd.c.',
#  'south carolina',
#  'u.s.',
#  'houston',
#  'houston ave',
#  'my bio',
#  'usa',
#  'north carolina',
#  'raeford',
#  'n.c.',
#  'u.s.',
#  'las vegas',
#  'east lee county',
#  'walmart',
#  'minnesota',
#  'dallas',
#  'n.y.',
#  'buffalo',
#  'buffalo',
#  'minnesota',
#  'raeford',
#  'minneapolis',
#  'baltimore',
#  'minnesota',
#  'vancouver',
#  'bc',
#  'dc',
#  'america',
#  'the united states',
#  'vietnam',
#  'fairfax county',
#  'virginia',
#  'alexandria',
#  'rochester hills',
#  'britain',
#  'the united states',
#  'd.c.',
#  'fort drum',
#  'washington',
#  'north carolina - daily',
#  'houston',
#  "north carolina floyd's",
#  'north carolina',
#  'raeford',
#  'us',
#  'us',
#  'bethlehem',
#  'us',
#  'allentown',
#  'us',
#  'us',
#  'america',
#  'us',
#  'america',
#  'buffalo',
#  'buffalo',
#  'buffalo',
#  'buffalo',
#  'buffalo',
#  'buffalo',
#  'buffalo',
#  'buffalo',
#  'buffalo',
#  'buffalo',
#  'leicester',
#  'westminster',
#  'uk',
#  'buffalo',
#  'sheffield',
#  'us',
#  'watford',
#  'piccadilly gardens - cardiff',
#  'north london',
#  'manchester',
#  'buffalo',
#  'flint',
#  'genesee county',
#  'buffalo',
#  'mi',
#  'minneapolis',
#  'new zealand',
#  'kingston',
#  'the united states embassy',
#  'syria',
#  'hope road',
#  'jamaica',
#  'usa',
#  'buffalo',
#  'minnesota',
#  'buffalo',
#  'u.s.',
#  'minneapolis',
#  'jerusalem',
#  'minneapolis',
#  'us',
#  'new york city',
#  'washington dc',
#  'philadelphia',
#  'los angeles',
#  'minneapolis',
#  'burbank',
#  'maryland',
#  'cambodia',
#  'long beach',
#  'cambodia',
#  'washington usa',
#  'cambodia',
#  'minneapolis',
#  'the united states',
#  'petrie',
#  'us',
#  'uk',
#  'washington, dc',
#  'dc',
#  'dc',
#  'buffalo',
#  'minnesota',
#  'texas',
#  'texas',
#  'buffalo',
#  'new york',
#  'buffalo',
#  'minnesota',
#  'calgary',
#  'usa',
#  'uk',
#  'bethlehem',
#  'allentown',
#  'bethlehem',
#  'allentown',
#  'toronto',
#  'america',
#  'new york city',
#  'new york',
#  'nyc',
#  'washington dc',
#  'us',
#  'washington dc',
#  'us',
#  'minneapolis',
#  'utah',
#  'america',
#  'us',
#  'washington',
#  'washington dc',
#  'st. louis',
#  'hong kong',
#  'chicago',
#  'minnesota',
#  'minneapolis',
#  'california',
#  'minneapolis',
#  'denver',
#  'minneapolis',
#  'utah',
#  'america',
#  'us',
#  'washington',
#  'st. louis',
#  'denver',
#  'hong kong',
#  'denver',
#  'chicago',
#  'minneapolis',
#  'utah',
#  'america',
#  'chicago',
#  'us',
#  'washington',
#  'st. louis',
#  'hong kong',
#  'michigan',
#  'washington dc',
#  'us',
#  'minneapolis',
#  'minneapolis',
#  'oregon',
#  'md.',
#  'kensington',
#  'maryland',
#  'maryland',
#  'houston',
#  'greenville',
#  'london',
#  'greenville',
#  'london',
#  'greenville',
#  'minneapolis',
#  'sterling heights',
#  'macomb county',
#  'washington dc',
#  'us',
#  'powhatan',
#  'us',
#  'washington dc',
#  'cheltenham',
#  'bristol',
#  'stroud',
#  'the united states',
#  'roc',
#  'long island',
#  'new york',
#  'nyc',
#  'minneapolis',
#  'minneapolis',
#  'manhattan',
#  'bronx',
#  'hamburg',
#  'germany',
#  'deutsch',
#  'california',
#  'california',
#  'america',
#  'park city',
#  'summit county',
#  'park city',
#  'summit county',
#  'houston',
#  'minneapolis',
#  'perth',
#  'new jersey',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'dane county',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'us',
#  'uk',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'chico',
#  'canaan ray-strong',
#  'aurum oro',
#  'ta-coumba aiken',
#  'dc',
#  'new york city',
#  'new york',
#  'chico',
#  'broadnax',
#  'minneapolis',
#  'dallas',
#  'broadnax',
#  'minneapolis',
#  'dallas',
#  'broadnax',
#  'minneapolis',
#  'dallas',
#  '1 minneapolis',
#  'bethlehem',
#  'broadnax',
#  'minneapolis',
#  'dallas',
#  'allentown',
#  'buffalo',
#  'erie county',
#  'florida',
#  'the united states of america',
#  'resurrection city',
#  'boston',
#  'washington',
#  'd.c.',
#  'florida',
#  'the united states',
#  'jordan',
#  'jordan',
#  'edwardsville',
#  'jordan',
#  'shenandoah ave',
#  'roanoke',
#  'dc',
#  'america',
#  'ghana',
#  'ghana',
#  'chicago',
#  'minnesota',
#  'chicago',
#  'minnesota',
#  'minneapolis',
#  '🇸',
#  'minneapolis',
#  '🇸',
#  'ohio',
#  'coronavirus',
#  'mph',
#  'ohio',
#  'america',
#  'america',
#  'oak brook',
#  'butterfield',
#  'minnesota',
#  'minneapolis',
#  'michigan',
#  'vancouver',
#  'minneapolis',
#  'los angeles',
#  'buffalo',
#  'missouri',
#  'mn',
#  'vancouver',
#  'ar',
#  'birmingham',
#  'philadelphia',
#  'atlanta',
#  'minn',
#  'denver',
#  'bentonville',
#  'fl',
#  'ga',
#  'alexandria',
#  'fort myers',
#  'ny',
#  'minneapolis',
#  'avon',
#  'vancouver',
#  'indiana',
#  'noblesville',
#  'minnesota indianapolis',
#  'carmel',
#  'department city',
#  'dc',
#  'minneapolis',
#  'los angeles',
#  'buffalo',
#  'missouri',
#  'mn',
#  'ar',
#  'birmingham',
#  'philadelphia',
#  'atlanta',
#  ...]

# %%
c = collections.Counter()

# %%
dict_a=collections.Counter(list).most_common()

# %%
dict_a
# Out:
# [('minneapolis', 4179),
#  ('america', 2041),
#  ('us', 1772),
#  ('u.s.', 1273),
#  ('the united states', 1125),
#  ('minnesota', 1083),
#  ('washington', 914),
#  ('north carolina', 710),
#  ('buffalo', 615),
#  ('london', 482),
#  ('d.c.', 460),
#  ('usa', 445),
#  ('chicago', 416),
#  ('uk', 406),
#  ('new york', 386),
#  ('texas', 345),
#  ('raeford', 337),
#  ('dc', 327),
#  ('california', 310),
#  ('houston', 287),
#  ('los angeles', 284),
#  ('philadelphia', 282),
#  ('maryland', 279),
#  ('australia', 269),
#  ('new york city', 262),
#  ('florida', 251),
#  ('atlanta', 215),
#  ('nj', 214),
#  ('canada', 198),
#  ('china', 185),
#  ('nyc', 182),
#  ('washington dc', 171),
#  ('michigan', 170),
#  ('paris', 165),
#  ('the united states of america', 153),
#  ('seattle', 149),
#  ('ghana', 147),
#  ('portland', 147),
#  ('sydney', 139),
#  ('pennsylvania', 127),
#  ('germany', 123),
#  ('denver', 122),
#  ('sacramento', 120),
#  ('new jersey', 118),
#  ('san francisco', 117),
#  ('louisville', 113),
#  ('nc', 109),
#  ('united states', 103),
#  ('fayetteville', 99),
#  ('🇸', 98),
#  ('washington d.c.', 93),
#  ('dallas', 91),
#  ('santa monica', 90),
#  ('britain', 89),
#  ('chicago heights', 89),
#  ('nashville', 88),
#  ('berlin', 88),
#  ('hoke county', 87),
#  ('ohio', 84),
#  ('georgia', 84),
#  ('hollywood', 83),
#  ('milwaukee', 82),
#  ('france', 80),
#  ('n.y.', 80),
#  ('newark', 80),
#  ('washington, dc', 79),
#  ('alabama', 77),
#  ('manchester', 75),
#  ('n.c.', 75),
#  ('ga', 74),
#  ('south africa', 73),
#  ('oakland', 73),
#  ('vancouver', 70),
#  ('india', 68),
#  ('detroit', 67),
#  ('ottawa', 67),
#  ('boston', 66),
#  ('virginia', 66),
#  ('hong kong', 66),
#  ('baltimore', 65),
#  ('ny', 65),
#  ('oregon', 65),
#  ('colorado', 65),
#  ('las vegas', 63),
#  ('wisconsin', 62),
#  ('new zealand', 62),
#  ('kentucky', 61),
#  ('antifa', 61),
#  ('israel', 61),
#  ('columbus', 59),
#  ('kensington', 59),
#  ('cincinnati', 58),
#  ('iowa', 56),
#  ('syria', 55),
#  ('phoenix', 55),
#  ('brooklyn', 55),
#  ('mn', 54),
#  ('toronto', 53),
#  ('pittsburgh', 53),
#  ('south carolina', 52),
#  ('el paso', 51),
#  ('new orleans', 50),
#  ('calif.', 50),
#  ('orange county', 49),
#  ('fairfax county', 49),
#  ('bethesda', 49),
#  ('vienna', 49),
#  ('iran', 48),
#  ('st. louis', 48),
#  ('manhattan', 48),
#  ('centreville', 48),
#  ('burke', 48),
#  ('san jose', 47),
#  ('melbourne', 47),
#  ('connecticut', 46),
#  ('|', 46),
#  ('miami', 46),
#  ('salem', 45),
#  ('athens', 45),
#  ('nigeria', 45),
#  ('massachusetts', 44),
#  ('illinois', 44),
#  ('tx', 43),
#  ('watford', 41),
#  ('fl', 41),
#  ('worcester', 40),
#  ('rome', 40),
#  ('ireland', 40),
#  ('maine', 40),
#  ('portugal', 40),
#  ('richmond', 38),
#  ('center city', 37),
#  ('missouri', 37),
#  ('newcastle', 37),
#  ('brazil', 37),
#  ('philando castile', 37),
#  ('arkansas', 36),
#  ('belfast', 36),
#  ('vallejo', 36),
#  ('sa', 36),
#  ('birmingham', 35),
#  ('new hampshire', 35),
#  ('england', 35),
#  ('vermont', 34),
#  ('leicester', 34),
#  ('kanye west donates', 34),
#  ('san antonio', 33),
#  ('casper', 33),
#  ('dublin', 33),
#  ('russia', 33),
#  ('long beach', 32),
#  ('st. paul', 32),
#  ('utah', 32),
#  ('bristol', 32),
#  ('ky', 32),
#  ('edmonton', 32),
#  ('san diego', 31),
#  ('indiana', 31),
#  ('covid', 31),
#  ('brisbane', 31),
#  ('kansas', 30),
#  ('arizona', 30),
#  ('madison', 30),
#  ('beijing', 30),
#  ('pinellas county', 29),
#  ('sheffield', 29),
#  ('minn.', 29),
#  ('wilmington', 29),
#  ('rose city', 29),
#  ('delaware', 29),
#  ('cleveland', 28),
#  ('tokyo', 28),
#  ('tennessee', 28),
#  ('the district of columbia', 28),
#  ('palestine', 27),
#  ('idaho', 27),
#  ('tampa', 27),
#  ('iraq', 27),
#  ('u.s.a.', 27),
#  ('la', 26),
#  ('alberta', 26),
#  ('montgomery county', 26),
#  ('nevada', 26),
#  ('md.', 25),
#  ('orlando', 25),
#  ('va.', 25),
#  ('memphis', 25),
#  ('l.a.', 25),
#  ('bloomfield', 25),
#  ('montana', 25),
#  ('jodhpur', 25),
#  ('adelaide', 25),
#  ('mexico', 24),
#  ('jackson', 24),
#  ('charleston', 24),
#  ('united states of america', 24),
#  ('kenya', 24),
#  ('taiwan', 24),
#  ('montreal', 23),
#  ('japan', 23),
#  ('tacoma', 23),
#  ('scotland', 23),
#  ('oklahoma', 22),
#  ('glasgow', 22),
#  ('long island', 22),
#  ('austin', 22),
#  ('puerto rico', 22),
#  ('mississippi', 22),
#  ('italy', 22),
#  ('charlotte', 22),
#  ('u.k.', 21),
#  ('wales', 21),
#  ('n.j.', 21),
#  ('pasadena', 21),
#  ('north korea', 21),
#  ('u.s', 21),
#  ('mo', 21),
#  ('hawaii', 20),
#  ('fredericksburg', 20),
#  ('chattanooga', 20),
#  ('zimbabwe', 20),
#  ('stockton', 20),
#  ('bollywood', 20),
#  ('greece', 20),
#  ('auckland', 20),
#  ('wisconsin ave', 20),
#  ('fort worth', 20),
#  ('north and south america', 20),
#  ('libya', 20),
#  ('wis.', 19),
#  ('tallahassee', 19),
#  ('nebraska', 19),
#  ('lagos', 19),
#  ('cbd', 19),
#  ('pa.', 19),
#  ('turkey', 19),
#  ('los angeles city hall', 19),
#  ('afghanistan', 19),
#  ('alexandria', 18),
#  ('bronx', 18),
#  ('minn', 18),
#  ('salt lake city', 18),
#  ('wi', 18),
#  ('kent', 18),
#  ('rochester', 18),
#  ('deerfield', 18),
#  ('hooksett', 18),
#  ('pleasanton', 18),
#  ('beverly hills', 18),
#  ('kan.', 18),
#  ('the deep state', 17),
#  ('jamaica', 17),
#  ('ferguson', 17),
#  ('jerusalem', 17),
#  ('jordan', 17),
#  ('queens', 17),
#  ('victoria', 17),
#  ('greensboro', 17),
#  ('stoke', 17),
#  ('asheville', 17),
#  ('trenton', 17),
#  ('georgetown', 17),
#  ('kansas city', 17),
#  ('st. petersburg', 17),
#  ('raleigh', 17),
#  ('south minneapolis', 17),
#  ('springfield', 17),
#  ('santee', 17),
#  ('west hollywood', 17),
#  ('new mexico', 16),
#  ('oklahoma city', 16),
#  ('hennepin county', 16),
#  ('johannesburg', 16),
#  ('westminster', 16),
#  ('greenville', 16),
#  ('indianapolis', 16),
#  ('rajasthan', 16),
#  ('accra', 16),
#  ('jacksonville', 16),
#  ('san quentin state prison', 16),
#  ('pittsburg', 16),
#  ('northridge', 16),
#  ('chico', 15),
#  ('bexar county', 15),
#  ('wausau', 15),
#  ('cardiff', 15),
#  ('south korea', 15),
#  ('spain', 15),
#  ('derry', 15),
#  ('mobile', 15),
#  ('fla.', 15),
#  ('yonkers', 15),
#  ('minneapo', 15),
#  ('san diego county', 15),
#  ('emporia', 15),
#  ('•', 14),
#  ('venezuela', 14),
#  ('district', 14),
#  ('arlington', 14),
#  ('alaska', 14),
#  ('northern ireland', 14),
#  ('md', 14),
#  ('hoboken', 14),
#  ('dayton', 14),
#  ('eugene', 14),
#  ('columbia', 14),
#  ('states', 14),
#  ('portland maine', 14),
#  ('tulsa', 13),
#  ('santa ana', 13),
#  ('omaha', 13),
#  ('bethlehem', 13),
#  ('exeter', 13),
#  ('pa', 13),
#  ('brunswick', 13),
#  ('ore.', 13),
#  ('dover', 13),
#  ('st. pete', 13),
#  ('va', 13),
#  ('mo.', 13),
#  ('southfield', 13),
#  ('montgomery', 13),
#  ('dortmund', 13),
#  ('wichita', 13),
#  ('west palm beach', 13),
#  ('boise', 13),
#  ('whitehall', 13),
#  ('san antonio spurs', 13),
#  ('simi valley', 12),
#  ('providence', 12),
#  ('copenhagen', 12),
#  ('harrison', 12),
#  ('seoul', 12),
#  ('englewood', 12),
#  ('sri lanka', 12),
#  ('turin', 12),
#  ('wash.', 12),
#  ('wa', 12),
#  ('verona', 12),
#  ('johnson city', 12),
#  ('lafayette square', 12),
#  ('essex county', 12),
#  ('lafayette park', 12),
#  ('may.', 12),
#  ('the city of chicago', 12),
#  ('mcallen', 12),
#  ('northampton', 12),
#  ('muammar', 12),
#  ('yemen', 12),
#  ('north minneapolis', 11),
#  ('erie county', 11),
#  ('liverpool', 11),
#  ('nsw', 11),
#  ('amsterdam', 11),
#  ('erie', 11),
#  ('spokane', 11),
#  ('tn', 11),
#  ('cambridge', 11),
#  ('little rock', 11),
#  ('ontario', 11),
#  ('rock', 11),
#  ('zulu', 11),
#  ('saudi arabia', 11),
#  ('mecca', 11),
#  ('los angeles county', 11),
#  ('west germany', 11),
#  ('clayton', 11),
#  ('pasco county', 11),
#  ('honeymoon island beach', 11),
#  ("pinellas county sheriff's", 11),
#  ('port richey police dept', 11),
#  ('thrasco county', 11),
#  ('honeymoon island', 11),
#  ('new port richey', 11),
#  ('oranges', 11),
#  ('caldwell', 11),
#  ('washingto', 11),
#  ('colorado springs', 11),
#  ('madera', 11),
#  ('charlottesville', 11),
#  ('san quentin', 11),
#  ('fort washington', 11),
#  ('kingston', 10),
#  ('gainesville', 10),
#  ('des moines', 10),
#  ('edinburgh', 10),
#  ('south africa’s', 10),
#  ('flint', 10),
#  ('botswana', 10),
#  ('comal', 10),
#  ('nueces', 10),
#  ('bexar', 10),
#  ('grand rapids', 10),
#  ('moscow', 10),
#  ('durham', 10),
#  ('ga.', 10),
#  ('iowa city', 10),
#  ('new york state', 10),
#  ('west belfast', 10),
#  ('louisiana', 10),
#  ('north charleston', 10),
#  ('bham', 10),
#  ('senegal', 10),
#  ('hyde park', 10),
#  ('ala.', 10),
#  ('third ward', 10),
#  ('the city-county building', 10),
#  ('mass.', 10),
#  ('suffolk county', 10),
#  ('ipswich', 10),
#  ('uganda', 10),
#  ('philly', 10),
#  ('malaysia', 10),
#  ('huntsville', 10),
#  ('the north carolina state conference of the naacp', 10),
#  ('south los angeles', 9),
#  ('pretoria', 9),
#  ('ar', 9),
#  ('rockville', 9),
#  ('haiti', 9),
#  ('troy', 9),
#  ('fort lauderdale', 9),
#  ('wyo.', 9),
#  ('kaduna', 9),
#  ('nairobi', 9),
#  ('sussex', 9),
#  ('albany', 9),
#  ('norway', 9),
#  ('west virginia', 9),
#  ('st. john’s', 9),
#  ("new york's", 9),
#  ('berkeley', 9),
#  ('fort bend county', 9),
#  ('pensacola', 9),
#  ('chauvin', 9),
#  ('cook county', 9),
#  ('honolulu', 9),
#  ('new south wales', 9),
#  ('north beach', 9),
#  ('minnea', 9),
#  ('chicago protest', 9),
#  ('new york city ballet', 9),
#  ('randolph', 9),
#  ('philippines', 9),
#  ('montrose', 9),
#  ('santa clarita', 9),
#  ('las cruces', 9),
#  ('https://refusefascism.org/2020/06/02/128603/', 9),
#  ('dakota', 8),
#  ('the united kingdom', 8),
#  ('the united states embassy', 8),
#  ('walmart', 8),
#  ('vietnam', 8),
#  ('cambodia', 8),
#  ('fort myers', 8),
#  ('palm beach', 8),
#  ('huber heights', 8),
#  ('laval', 8),
#  ('sweden', 8),
#  ('jersey city', 8),
#  ('knoxville', 8),
#  ('santa rosa', 8),
#  ('bradford', 8),
#  ('bridgeport', 8),
#  ('boulder', 8),
#  ('wauwatosa', 8),
#  ('italia', 8),
#  ('jamestown', 8),
#  ('san fernando valley', 8),
#  ('alabama city', 8),
#  ('the rock and nickelback', 8),
#  ('syracuse', 8),
#  ('sudan', 8),
#  ('staten island', 8),
#  ('lexington', 8),
#  ('brooksville', 8),
#  ('east germany', 8),
#  ('harrisburg', 8),
#  ('new haven', 8),
#  ('evansville', 8),
#  ('alameda', 8),
#  ('anchorage', 8),
#  ('new delhi', 8),
#  ('galveston', 8),
#  ('vegas', 8),
#  ('saint paul', 8),
#  ('el cajon', 8),
#  ('olango', 8),
#  ('hampton', 8),
#  ('mass', 8),
#  ('op-ed', 8),
#  ('chernobyl', 8),
#  ('miami valley', 8),
#  ('washinton', 8),
#  ('genesee county', 7),
#  ('plymouth', 7),
#  ('tunisia', 7),
#  ('my bio', 7),
#  ('north london', 7),
#  ('broadnax', 7),
#  ('bentonville', 7),
#  ('ma', 7),
#  ('victoria park', 7),
#  ('stockholm', 7),
#  ('hartford', 7),
#  ('barbados', 7),
#  ('vidor', 7),
#  ('bolivia', 7),
#  ("the united states'", 7),
#  ('easton', 7),
#  ('evanston', 7),
#  ('lafayette', 7),
#  ('del.', 7),
#  ('rhode island', 7),
#  ('davenport', 7),
#  ('ct', 7),
#  ('ky.', 7),
#  ('tam tak', 7),
#  ('ni ta hlauh mai si a. chu tak', 7),
#  ('australia te', 7),
#  ('chutih', 7),
#  ('lansing', 7),
#  ('san bernardino', 7),
#  ('winnipeg', 7),
#  ('toa baja', 7),
#  ('indonesia', 7),
#  ('aurora', 7),
#  ('ark.', 7),
#  ('south bend', 7),
#  ('gauteng', 7),
#  ('grant park', 7),
#  ('frankfurt', 7),
#  ('oslo', 7),
#  ('wuhan', 7),
#  ('north wales', 7),
#  ('queensland', 7),
#  ('olympia', 7),
#  ('cook county jail', 7),
#  ('the cook county', 7),
#  ('brussels', 7),
#  ('belgium', 7),
#  ('laos', 7),
#  ('las vegas strip', 7),
#  ('basel', 7),
#  ('guadalupe', 7),
#  ('mauritania', 7),
#  ('mardah', 7),
#  ('fresno', 7),
#  ('hermosa beach', 7),
#  ('angry united', 7),
#  ('yellow springs', 7),
#  ('n.c. memorial', 7),
#  ('san gabriel', 7),
#  ('north carolina memorial', 7),
#  ('canton', 6),
#  ('normandy', 6),
#  ('roanoke', 6),
#  ('pekin', 6),
#  ('fife', 6),
#  ('calgary', 6),
#  ('park city', 6),
#  ('summit county', 6),
#  ('perth', 6),
#  ('naugatuck', 6),
#  ('la jolla', 6),
#  ('fla', 6),
#  ('powderhorn', 6),
#  ('pakistan', 6),
#  ('tucson', 6),
#  ('new brunswick', 6),
#  ('thailand', 6),
#  ('netherlands', 6),
#  ('bedford', 6),
#  ('mansfield', 6),
#  ('hackensack', 6),
#  ('newton', 6),
#  ('sarasota', 6),
#  ('lake dr', 6),
#  ('shorewood', 6),
#  ('oconomowoc', 6),
#  ('north shore justice', 6),
#  ('burleigh', 6),
#  ('halifax', 6),
#  ('carbondale', 6),
#  ('guyana', 6),
#  ('westfield', 6),
#  ('colombia', 6),
#  ('temecula', 6),
#  ('empire', 6),
#  ('bawhchhia', 6),
#  ('pasala pawm', 6),
#  ('ni zel', 6),
#  ('hlun tak', 6),
#  ('hmun', 6),
#  ('inhawr khawmin', 6),
#  ('enthla', 6),
#  ('ni si', 6),
#  ('ni ta reng', 6),
#  ('ni si a. buaina', 6),
#  ('hlawh si lo', 6),
#  ('mihang', 6),
#  ('bellevue', 6),
#  ('denmark', 6),
#  ('delhi', 6),
#  ('kenosha county', 6),
#  ('naples', 6),
#  ('nh', 6),
#  ('ocean city', 6),
#  ('| city', 6),
#  ('hudson', 6),
#  ('nottingham', 6),
#  ('piccadilly gardens', 6),
#  ('saginaw', 6),
#  ('palm springs', 6),
#  ('topeka', 6),
#  ('egypt', 6),
#  ('rehoboth', 6),
#  ('tennesse', 6),
#  ('district of columbia', 6),
#  ('newham', 6),
#  ('joburg', 6),
#  ('bundjalung', 6),
#  ('yreka', 6),
#  ('cuba', 6),
#  ('gedenken', 6),
#  ('den usa', 6),
#  ('systematische', 6),
#  ('hawaiʻi', 6),
#  ('nassau', 6),
#  ('suffolk', 6),
#  ('akron', 6),
#  ('glynn county', 6),
#  ('christi', 6),
#  ('corpus', 6),
#  ('fort wayne', 6),
#  ('summerville', 6),
#  ("south africa's", 6),
#  ('alamo heights', 6),
#  ('humboldt park', 6),
#  ('pomona', 6),
#  ('bolsa chica state beach', 6),
#  ('richland', 6),
#  ('dubai', 6),
#  ('these united states', 6),
#  ("st. john's downtown", 6),
#  ('youtube.com/c/blackpressusatv', 6),
#  ('texarkana', 6),
#  ('hardcore', 6),
#  ('policia', 6),
#  ('mainz', 6),
#  ('sd', 5),
#  ('kenosha', 5),
#  ('baton rouge', 5),
#  ('kūpuna', 5),
#  ('holy trinity', 5),
#  ('fort drum', 5),
#  ('allentown', 5),
#  ('macomb county', 5),
#  ('desoto county', 5),
#  ('florida united methodists', 5),
#  ('northeast ohio', 5),
#  ('camden', 5),
#  ('herts', 5),
#  ('virginia beach', 5),
#  ('lebanon', 5),
#  ('windermere', 5),
#  ('hamptons', 5),
#  ('city', 5),
#  ('seattle city', 5),
#  ('franklin county', 5),
#  ('nueces county', 5),
#  ('marin', 5),
#  ('newport', 5),
#  ('north alabama', 5),
#  ('boulder county', 5),
#  ('lancaster', 5),
#  ('east grand rapids', 5),
#  ('kingdom', 5),
#  ('meck county', 5),
#  ('traverse city', 5),
#  ('redwood city', 5),
#  ('orange', 5),
#  ('ballsbridge', 5),
#  ('uruguay', 5),
#  ('r.i.', 5),
#  ('tunbridge wells', 5),
#  ('ind.', 5),
#  ('shoreline', 5),
#  ('renton', 5),
#  ('mill creek', 5),
#  ('lynnwood', 5),
#  ('ashland', 5),
#  ('south downs', 5),
#  ('congo', 5),
#  ('tenn.', 5),
#  ('florence', 5),
#  ('the united states’', 5),
#  ('shelby township', 5),
#  ('hobart', 5),
#  ('louisvill', 5),
#  ('black orlando', 5),
#  ('duluth', 5),
#  ('galesburg', 5),
#  ('marche et hommage à', 5),
#  ('oxford', 5),
#  ('occupied west bank', 5),
#  ('rehoboth beach', 5),
#  ('buffalo state', 5),
#  ('winston-salem', 5),
#  ('apopka', 5),
#  ('lakewood', 5),
#  ('birmingham city', 5),
#  ('kirkcaldy', 5),
#  ('alexanderplatz', 5),
#  ('miami-dade', 5),
#  ('canberra', 5),
#  ('kumasi', 5),
#  ('narberth', 5),
#  ('prc', 5),
#  ('brockton', 5),
#  ('dozzing', 5),
#  ('fargo', 5),
#  ('scottsdale', 5),
#  ('ossining', 5),
#  ('vicksburg', 5),
#  ('hoover', 5),
#  ('trinity county', 5),
#  ('sangamon county', 5),
#  ('greater sacramento', 5),
#  ('abilene christian', 5),
#  ('abilene', 5),
#  ('riverside county', 5),
#  ('istanbul', 5),
#  ('lisbon', 5),
#  ('la cultura', 5),
#  ('johnstown', 5),
#  ('the united sta', 5),
#  ('puerto', 5),
#  ('queen earth', 5),
#  ('earth nellys', 5),
#  ('san juan', 5),
#  ('roosevelt park', 5),
#  ('oly', 5),
#  ('christchurch park', 5),
#  ('nassau county', 5),
#  ('long island’s', 5),
#  ('middletown', 5),
#  ('falcon heights', 5),
#  ('savz', 5),
#  ('south florida', 5),
#  ('virgin islands', 5),
#  ('mich.', 4),
#  ('owosso', 4),
#  ('broadway ave', 4),
#  ('franklin ave', 4),
#  ('u.s bank', 4),
#  ('mn 55411', 4),
#  ('ethiopia', 4),
#  ('redding', 4),
#  ("the district of columbia's", 4),
#  ('snohomish county', 4),
#  ('guangzhou', 4),
#  ('sanford', 4),
#  ('encinitas', 4),
#  ('burbank', 4),
#  ('dane county', 4),
#  ('1 minneapolis', 4),
#  ('edwardsville', 4),
#  ('carlisle', 4),
#  ('belmont', 4),
#  ('beaumont', 4),
#  ('new york city’s', 4),
#  ('http://paypal', 4),
#  ('kingwood', 4),
#  ('greenwich', 4),
#  ('leesburg', 4),
#  ('teaneck', 4),
#  ('fort smith', 4),
#  ('soweto', 4),
#  ('namibia', 4),
#  ('pris', 4),
#  ('atlantic city', 4),
#  ('ucc', 4),
#  ('united kingdom', 4),
#  ('mumbai', 4),
#  ('la mesa', 4),
#  ('waterford', 4),
#  ('cedarburg', 4),
#  ('colo', 4),
#  ('vandalia', 4),
#  ('battle creek', 4),
#  ('tyler', 4),
#  ('»', 4),
#  ('selma', 4),
#  ('frederick', 4),
#  ('bremerton', 4),
#  ('seatac', 4),
#  ('bothell', 4),
#  ('redmond', 4),
#  ('everett', 4),
#  ('auburn', 4),
#  ('mercer island', 4),
#  ('windsor', 4),
#  ('conn.', 4),
#  ('https://spectrum360media.com/2020/06/02/a-radio-program-webcast-spectrum-360-20-21-20-jun-01-mon/',
#   4),
#  ('new jersey’s', 4),
#  ('burnsville', 4),
#  ('rogers', 4),
#  ('manchester city', 4),
#  ('green bay', 4),
#  ('jefferson', 4),
#  ('st. thomas', 4),
#  ('hastings', 4),
#  ('westchester', 4),
#  ('the village of hastings', 4),
#  ('hereford', 4),
#  ('standing rock', 4),
#  ('south dakota', 4),
#  ('saint lucia', 4),
#  ('lockerbie', 4),
#  ('cayman health city', 4),
#  ('sc', 4),
#  ('upstate', 4),
#  ('brooklyn borough', 4),
#  ('lyon', 4),
#  ('greeley', 4),
#  ('bute park', 4),
#  ('bucks county', 4),
#  ('fortuna', 4),
#  ('racism.\u2063', 4),
#  ('korea', 4),
#  ('haifa city', 4),
#  ('the city of minneapolis', 4),
#  ('the united states ever end', 4),
#  ('canterbury', 4),
#  ('cumbria', 4),
#  ('coeur', 4),
#  ('idaho city', 4),
#  ('harris county', 4),
#  ('katai', 4),
#  ('arundel', 4),
#  ('montpelier', 4),
#  ('ellsworth', 4),
#  ('barcelona', 4),
#  ('benue', 4),
#  ('taraba', 4),
#  ('kogi', 4),
#  ('greater manchester', 4),
#  ('nairobi city', 4),
#  ('de verenigde staten', 4),
#  ('morocco', 4),
#  ('bolivarian republic of venezuela', 4),
#  ('bemidji', 4),
#  ('de vynck', 4),
#  ('takoradi', 4),
#  ('zongo', 4),
#  ('kintampo', 4),
#  ('singapore', 4),
#  ('south brisbane', 4),
#  ('waco', 4),
#  ('turlock', 4),
#  ('chatham', 4),
#  ('cabo', 4),
#  ('santa cruz', 4),
#  ('brentwood', 4),
#  ('black puerto', 4),
#  ('walnut creek', 4),
#  ('shreveport', 4),
#  ('podcast', 4),
#  ('monticello', 4),
#  ('benicia', 4),
#  ('abuja mass transit', 4),
#  ('ndigbo', 4),
#  ('abuja-kaduna', 4),
#  ('minesota', 4),
#  ('calabar', 4),
#  ('clifton', 4),
#  ('warren county', 4),
#  ('mt', 4),
#  ('helena', 4),
#  ('belle isle', 4),
#  ('irvine', 4),
#  ('los altos', 4),
#  ('mass ave', 4),
#  ('boston ma', 4),
#  ('la, chicago', 4),
#  ('zambia', 4),
#  ('hermosa', 4),
#  ('bay village', 4),
#  ('marshfield', 4),
#  ('the sacramento bee', 4),
#  ('maple ave', 4),
#  ('east ave', 4),
#  ('ill.', 4),
#  ('st. louis streets', 4),
#  ('inglewood', 4),
#  ('piscataway', 4),
#  ('wy oil city news', 4),
#  ('albuquerque', 4),
#  ('longmont', 4),
#  ('las 11:30am', 4),
#  ('11:30am', 4),
#  ('stamford', 4),
#  ('northam', 4),
#  ('elizabethtown', 4),
#  ("new jersey's", 4),
#  ('manhattan beach', 4),
#  ('west midlands police', 4),
#  ('hawthorne', 4),
#  ('s.c.', 4),
#  ('the city of flint', 4),
#  ('anmah minneapolis', 4),
#  ('bridgewater', 4),
#  ('stoughton', 4),
#  ('ghana nana akufo-addo', 4),
#  ('union park', 4),
#  ('the northern wasco county aquatic center', 4),
#  ('thompson park', 4),
#  ('londonderry', 4),
#  ('york county', 4),
#  ('calif', 4),
#  ('secaucus', 4),
#  ('balch springs', 4),
#  ('tex', 4),
#  ('wis', 4),
#  ('beavercreek', 4),
#  ('palm beach gardens', 4),
#  ('donisha prendergast', 4),
#  ('fort worthreally', 4),
#  ('rialto', 4),
#  ('lewisburg', 4),
#  ('myghanalinks', 3),
#  ('gulfport', 3),
#  ('potomac', 3),
#  ('clackamas county', 3),
#  ('melania', 3),
#  ('rv', 3),
#  ('liguanea', 3),
#  ('concord', 3),
#  ('tuscaloosa', 3),
#  ('charlevoix', 3),
#  ('yuendumu', 3),
#  ('houston ave', 3),
#  ("north carolina floyd's", 3),
#  ('mi', 3),
#  ('washington usa', 3),
#  ('petrie', 3),
#  ('sterling heights', 3),
#  ('stroud', 3),
#  ('roc', 3),
#  ('hamburg', 3),
#  ('canaan ray-strong', 3),
#  ('aurum oro', 3),
#  ('ta-coumba aiken', 3),
#  ('gillespie county', 3),
#  ('inverness', 3),
#  ('oak', 3),
#  ('vlaanderen', 3),
#  ('verantwoordelijken', 3),
#  ('northern new york', 3),
#  ('inwood park', 3),
#  ('mpls', 3),
#  ('u.k', 3),
#  ('mill valley', 3),
#  ('mpa', 3),
#  ('judah', 3),
#  ('￼circumstance', 3),
#  ('schaumburg', 3),
#  ('trotwood', 3),
#  ('floyd', 3),
#  ('lincoln', 3),
#  ('monroe', 3),
#  ('danbury', 3),
#  ('new london', 3),
#  ('broward county', 3),
#  ('demonstr', 3),
#  ('hampton roads', 3),
#  ('lutheran', 3),
#  ('montauk', 3),
#  ('coraopolis', 3),
#  ('bowie', 3),
#  ('lake arthur', 3),
#  ('st. louis police', 3),
#  ('british columbia', 3),
#  ('cumberland', 3),
#  ('buffalo city court', 3),
#  ('kalamazoo', 3),
#  ('bozeman', 3),
#  ('los elementos de acción que salieron de las sesiones', 3),
#  ('cómo', 3),
#  ('the city of santa rosa', 3),
#  ('wellington', 3),
#  ('sandahpiah', 3),
#  ('the city and county of greenwood', 3),
#  ('palghar', 3),
#  ('memorial', 3),
#  ('washington, d.c', 3),
#  ('north carolinian ki', 3),
#  ('layton blvd', 3),
#  ('philando castile\n', 3),
#  ...]

# %%
dataframe531=pd.DataFrame(dict_a)

# %%
len(dict_a)
# Out:
# 3621

# %%
dataframe531.to_csv('dataframe0606_UK.csv')
