# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
#  Xizhi_Wu_UnderGrad_Transcript.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# %cd dataframe_csv/
# !ls
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/dataframe_csv
# dataframe0529.csv  dataframe0602.csv  dataframe0606.csv  dataframe0610.csv
# dataframe0530.csv  dataframe0603.csv  dataframe0607.csv  dataframe0611.csv
# dataframe0531.csv  dataframe0604.csv  dataframe0608.csv
# dataframe0601.csv  dataframe0605.csv  dataframe0609.csv

# %%
import pandas as pd

# %%
d529=pd.read_csv('dataframe0529.csv')

# %%
d529
# Out:
#       Unnamed: 0                        0      1
# 0              0              minneapolis  15956
# 1              1                minnesota   3860
# 2              2                  america   1102
# 3              3                 st. paul    945
# 4              4          hennepin county    737
# ...          ...                      ...    ...
# 1444        1444  suffolk county district      1
# 1445        1445                  bristol      1
# 1446        1446                    diego      1
# 1447        1447          san francisco's      1
# 1448        1448                     acab      1
#
# [1449 rows x 3 columns]

# %%
rownames=d529['0'].tolist()

# %%
rownames

# %%
d529=pd.read_csv('dataframe0529.csv')
rownumbers529=d529['1'].tolist()
index529=d529['0'].tolist()
d529new=pd.Series(rownumbers529,index=index529)
d529new_seq=d529new.reindex(rownames)
print(d529new_seq)

# %%
#d529=pd.read_csv('dataframe0529.csv')
#rownumbers529=d529['1'].tolist()
#index529=d529['0'].tolist()
#d529new=pd.DataFrame(index=index529,columns=rownumbers529)
#d529new_f=d529new.reindex(rownames)
#print(d529new_f)

# %%
#columns529=['city','5-29']
#d529new_seq.columns=columns529

# %%
#d529new_seq.columns
# Out:
# ['city', '5-29']

# %%
print(d529['0'])
# Out:
# 0                   minneapolis
# 1                     minnesota
# 2                       america
# 3                      st. paul
# 4               hennepin county
#                  ...
# 1444    suffolk county district
# 1445                    bristol
# 1446                      diego
# 1447            san francisco's
# 1448                       acab
# Name: 0, Length: 1449, dtype: object

# %%
d530=pd.read_csv('dataframe0530.csv')

# %%
d530
# Out:
#       Unnamed: 0              0     1
# 0              0    minneapolis  8686
# 1              1      minnesota  2261
# 2              2        atlanta  1546
# 3              3        america  1381
# 4              4           u.s.  1071
# ...          ...            ...   ...
# 1786        1786      southport     1
# 1787        1787       fishkill     1
# 1788        1788      otisville     1
# 1789        1789  kentucky stre     1
# 1790        1790        captiol     1
#
# [1791 rows x 3 columns]

# %%
d530=d530.drop(['Unnamed: 0'],axis=1)

# %%
rownumbers530=d530['1'].tolist()
index530=d530['0'].tolist()

# %%
d530new=pd.Series(rownumbers530,index=index530)

# %%
d530new
# Out:
# minneapolis      8686
# minnesota        2261
# atlanta          1546
# america          1381
# u.s.             1071
#                  ...
# southport           1
# fishkill            1
# otisville           1
# kentucky stre       1
# captiol             1
# Length: 1791, dtype: int64

# %%
d530new_seq=d530new.reindex(rownames)
print(d530new_seq)

# %%
pd.set_option('display.max_rows', None)

# %%
d531=pd.read_csv('dataframe0531.csv')
rownumbers531=d531['1'].tolist()
index531=d531['0'].tolist()
d531new=pd.Series(rownumbers531,index=index531)
d531new_seq=d531new.reindex(rownames)
print(d531new_seq)

# %%
d601=pd.read_csv('dataframe0601.csv')
rownumbers601=d601['1'].tolist()
index601=d601['0'].tolist()
d601new=pd.Series(rownumbers601,index=index601)
d601new_seq=d601new.reindex(rownames)
print(d601new_seq)

# %%
d602=pd.read_csv('dataframe0602.csv')
rownumbers602=d602['1'].tolist()
index602=d602['0'].tolist()
d602new=pd.Series(rownumbers602,index=index602)
d602new_seq=d602new.reindex(rownames)
print(d602new_seq)

# %%
d603=pd.read_csv('dataframe0603.csv')
rownumbers603=d603['1'].tolist()
index603=d603['0'].tolist()
d603new=pd.Series(rownumbers603,index=index603)
d603new_seq=d603new.reindex(rownames)
print(d603new_seq)

# %%
d604=pd.read_csv('dataframe0604.csv')
rownumbers604=d604['1'].tolist()
index604=d604['0'].tolist()
d604new=pd.Series(rownumbers604,index=index604)
d604new_seq=d604new.reindex(rownames)
print(d604new_seq)

# %%
d605=pd.read_csv('dataframe0605.csv')
rownumbers605=d605['1'].tolist()
index605=d605['0'].tolist()
d605new=pd.Series(rownumbers605,index=index605)
d605new_seq=d605new.reindex(rownames)
print(d605new_seq)

# %%
d606=pd.read_csv('dataframe0606.csv')
rownumbers606=d606['1'].tolist()
index606=d606['0'].tolist()
d606new=pd.Series(rownumbers606,index=index606)
d606new_seq=d606new.reindex(rownames)
print(d606new_seq)

# %%
d607=pd.read_csv('dataframe0607.csv')
rownumbers607=d607['1'].tolist()
index607=d607['0'].tolist()
d607new=pd.Series(rownumbers607,index=index607)
d607new_seq=d607new.reindex(rownames)
print(d607new_seq)

# %%
d608=pd.read_csv('dataframe0608.csv')
rownumbers608=d608['1'].tolist()
index608=d608['0'].tolist()
d608new=pd.Series(rownumbers608,index=index608)
d608new_seq=d608new.reindex(rownames)
print(d608new_seq)

# %%
d609=pd.read_csv('dataframe0609.csv')
rownumbers609=d609['1'].tolist()
index609=d609['0'].tolist()
d609new=pd.Series(rownumbers609,index=index609)
d609new_seq=d609new.reindex(rownames)
print(d609new_seq)

# %%
d610=pd.read_csv('dataframe0610.csv')
rownumbers610=d610['1'].tolist()
index610=d610['0'].tolist()
d610new=pd.Series(rownumbers610,index=index610)
d610new_seq=d610new.reindex(rownames)
print(d610new_seq)

# %%
d611=pd.read_csv('dataframe0611.csv')
rownumbers611=d611['1'].tolist()
index611=d611['0'].tolist()
d611new=pd.Series(rownumbers611,index=index611)
d611new_seq=d611new.reindex(rownames)
print(d611new_seq)

# %%
len(d530new_seq)
# Out:
# 1449

# %%
d530new_seqdict=d530new_seq.to_dict()

# %%
d530new_seqdict

# %%
datafame529=pd.DataFrame(d530new_seqdict,index=rownames)

# %%
datafame529=[]
for i in range(1449):
  datafame529.append(d529new_seq.iloc[i])

# %%
datafame529

# %%
import numpy as np

# %%
data = pd.DataFrame(np.array(datafame529),columns=['5-29'],index=rownames)

# %%
data

# %%
#data.insert(data.shape[1],'5-29',datafame529)

# %%
datafame530=[]
datafame531=[]
datafame601=[]
datafame602=[]
datafame603=[]
datafame604=[]
datafame605=[]
datafame606=[]
datafame607=[]
datafame608=[]
datafame609=[]
datafame610=[]
datafame611=[]
for i in range(1449):
  datafame530.append(d530new_seq.iloc[i])
data.insert(data.shape[1],'5-30',datafame530)

for i in range(1449):
  datafame531.append(d531new_seq.iloc[i])
data.insert(data.shape[1],'5-31',datafame531)

for i in range(1449):
  datafame601.append(d601new_seq.iloc[i])
data.insert(data.shape[1],'6-01',datafame601)

for i in range(1449):
  datafame602.append(d602new_seq.iloc[i])
data.insert(data.shape[1],'6-02',datafame602)

for i in range(1449):
  datafame603.append(d603new_seq.iloc[i])
data.insert(data.shape[1],'6-03',datafame603)

for i in range(1449):
  datafame604.append(d604new_seq.iloc[i])
data.insert(data.shape[1],'6-04',datafame604)

for i in range(1449):
  datafame605.append(d605new_seq.iloc[i])
data.insert(data.shape[1],'6-05',datafame605)

for i in range(1449):
  datafame606.append(d606new_seq.iloc[i])
data.insert(data.shape[1],'6-06',datafame606)

for i in range(1449):
  datafame607.append(d607new_seq.iloc[i])
data.insert(data.shape[1],'6-07',datafame607)

for i in range(1449):
  datafame608.append(d608new_seq.iloc[i])
data.insert(data.shape[1],'6-08',datafame608)

for i in range(1449):
  datafame609.append(d609new_seq.iloc[i])
data.insert(data.shape[1],'6-09',datafame609)

for i in range(1449):
  datafame610.append(d610new_seq.iloc[i])
data.insert(data.shape[1],'6-10',datafame610)

for i in range(1449):
  datafame611.append(d611new_seq.iloc[i])
data.insert(data.shape[1],'6-11',datafame611)

data
# Out:
#                                                      5-29    5-30    5-31  \
# minneapolis                                         15956  8686.0  7124.0
# minnesota                                            3860  2261.0  2089.0
# america                                              1102  1381.0  1324.0
# st. paul                                              945   194.0   114.0
# hennepin county                                       737   168.0    64.0
# the united states                                     533   609.0   793.0
# denver                                                490   235.0   222.0
# us                                                    477   863.0  1318.0
# u.s.                                                  476  1071.0  1009.0
# columbus                                              416   189.0   104.0
# houston                                               330   447.0   394.0
# mn                                                    299   132.0   152.0
# ...

# %%
data.to_csv('heatmap.csv')

# %%
# !ls
# Out:
# dataframe0529.csv  dataframe0602.csv  dataframe0606.csv  dataframe0610.csv
# dataframe0530.csv  dataframe0603.csv  dataframe0607.csv  dataframe0611.csv
# dataframe0531.csv  dataframe0604.csv  dataframe0608.csv  heatmap.csv
# dataframe0601.csv  dataframe0605.csv  dataframe0609.csv

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#sns.set(font_scale=1.5)

# %%
plt.subplots(figsize=(30,30))
sns.heatmap(data.iloc[0:60],cmap='YlGnBu',annot=True)

# %%
import requests
import re
import json

# %%
def get_get_location_m(name):
    url="https://restapi.amap.com/v3/place/text?s=rsv3" \
        "&children=&key=8325164e247e15eea68b59e89200988b&page=1" \
        "&offset=10&city=510100&language=zh_cn" \
        "&callback=jsonp_755735_" \
        "&platform=JS&logversion=2.0" \
        "&sdkversion=1.3" \
        "&appname=https%3A%2F%2Flbs.amap.com%2Fconsole%2Fshow%2Fpicker" \
        "&csid=F028E84F-6601-43AE-88A8-13425E3DE7C7" \
        "&keywords={}".format(name)
    res_text=requests.get(url).text
    if re.findall('"info":"OK"',res_text):
        res_data=json.loads(res_text.replace(re.findall("jsonp_\d+_\(",res_text)[0],"")[0:-1])["pois"][0]
        item = {}
        item["name"] = res_data["name"]
        item["type"] = res_data["type"]
        item["location"] = res_data["location"]
        item["pname"] = res_data["pname"]
        item["cityname"] = res_data["cityname"]
        item["adname"] = res_data["adname"]
        return item
    else:
        return None
    
print(get_get_location_m("minneapolis"))
# Out:
# None
