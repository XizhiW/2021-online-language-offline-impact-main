# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 4.5 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=b316c083ed2d3c8ba9ae87a3e56246d5034dc8cd7231a43419bb38e767d87e42
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.9 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_UK
#  a0529-a0611_US     dataframe_result_529_UK.csv
#  a0529.csv	    dataframe_result_530_UK.csv
#  a0530.csv	    dataframe_result_531_UK.csv
#  a0601.csv	    dataframe_result_csv
#  a0602.csv	    dataframe_result_csv_EU
#  a0603.csv	    dataframe_result_csv_UK
#  a0604.csv	    Github
#  a0605.csv	    heatmap529_UK.ipynb
#  a0606.csv	    heatmap530.ipynb
#  a0607.csv	    Heat_Map_Online_language.ipynb
#  a0608.csv	    __MACOSX
#  a0610.csv	    mapping_UK
#  a0611.csv	    mapping_US
#  ccc_compiled.csv   non_violant1.csv
#  csv		    non_violant2.csv
#  csv.zip	    UK
#  dataframe_csv	    violant.csv
#  dataframe_csv_EU  '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_601 = 'csv/US05_31.csv'

# %%
ct = pd.read_csv(ct_path_601)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                              platformId  ...                    post_id
# 0      863053903797785_2416081108495049  ...  14766958|2416081108495049
# 1        198522895242_10163567614455243  ...  5833864|10163567614455243
# 2       277079169583056_595742771050026  ...   13088064|595742771050026
# 3      111158588907265_3175736799116080  ...   2226324|3175736799116080
# 4      189456527907231_1364396433746562  ...     90949|1364396433746562
# ...                                 ...  ...                        ...
# 21294      9299179711_10158480136539712  ...     1520|10158480136539712
# 21295  1555489164769329_280338333371641  ...    2227833|280338333371641
# 21296     38843147901_10158303971257902  ...    24318|10158303971257902
# 21297  177014055831470_1359720020894195  ...  11563729|1359720020894195
# 21298    117410107174_10156991960632175  ...    23862|10156991960632175
#
# [21299 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#            NER-msg                           NER-desc
# 0               {}                 {'Minneapolis': 1}
# 1               {}                                 {}
# 2    {'Lawton': 1}                                 {}
# 3  {'Stamford': 1}  {'Stamford': 1, 'Minneapolis': 1}
# 4               {}                                 {}

# %%
ct.to_csv('a0531.csv')

# %%
ct=pd.read_csv('a0531.csv',encoding='ISO-8859-1', lineterminator='\n')

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_UK
#  a0529-a0611_US     dataframe_result_529_UK.csv
#  a0529.csv	    dataframe_result_530_UK.csv
#  a0530.csv	    dataframe_result_531_UK.csv
#  a0531.csv	    dataframe_result_csv
#  a0601.csv	    dataframe_result_csv_EU
#  a0602.csv	    dataframe_result_csv_UK
#  a0603.csv	    Github
#  a0604.csv	    heatmap529_UK.ipynb
#  a0605.csv	    heatmap530.ipynb
#  a0606.csv	    Heat_Map_Online_language.ipynb
#  a0607.csv	    __MACOSX
#  a0608.csv	    mapping_UK
#  a0610.csv	    mapping_US
#  a0611.csv	    non_violant1.csv
#  ccc_compiled.csv   non_violant2.csv
#  csv		    UK
#  csv.zip	    violant.csv
#  dataframe_csv	   '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_csv_EU

# %%
###
#ct=pd.read_csv('a0601.csv')

# %%
ct
# Out:
#        Unnamed: 0  ...                     NER-title
# 0               0  ...                            {}
# 1               1  ...                            {}
# 2               2  ...                            {}
# 3               3  ...                            {}
# 4               4  ...                            {}
# ...           ...  ...                           ...
# 21294       21294  ...                            {}
# 21295       21295  ...                            {}
# 21296       21296  ...  {'US': 1, 'Fayetteville': 1}
# 21297       21297  ...                            {}
# 21298       21298  ...                     {'DC': 1}
#
# [21299 rows x 51 columns]

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
#ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
###
ct_ner = ct

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#            NER-msg                           NER-desc NER-title
# 0               {}                 {'Minneapolis': 1}        {}
# 1               {}                                 {}        {}
# 2    {'Lawton': 1}                                 {}        {}
# 3  {'Stamford': 1}  {'Stamford': 1, 'Minneapolis': 1}        {}
# 4               {}                                 {}        {}

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))

# %%
ct_ner['NER-msg']
# Out:
# 0                                                       []
# 1                                                       []
# 2                                                 [Lawton]
# 3                                               [Stamford]
# 4                                                       []
#                                ...
# 21294                               [Minnesota, Baltimore]
# 21295                             [Charlotte, Minneapolis]
# 21296                                                   []
# 21297    [Louisville, Minnesota, Georgia, Brunswick, Ke...
# 21298                                                   []
# Name: NER-msg, Length: 21299, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']

# %%
ct_ner['NER']
# Out:
# 0                                            [Minneapolis]
# 1                                                       []
# 2                                                 [Lawton]
# 3                        [Stamford, Stamford, Minneapolis]
# 4                                                       []
#                                ...
# 21294         [Minnesota, Baltimore, Minnesota, Baltimore]
# 21295       [Charlotte, Minneapolis, Minnesota, Baltimore]
# 21296    [FAYETTEVILLE, Fayetteville, N.C., Fayettevill...
# 21297    [Louisville, Minnesota, Georgia, Brunswick, Ke...
# 21298                                    [Minneapolis, DC]
# Name: NER, Length: 21299, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])

# %%
ct_ner
# Out:
#        Unnamed: 0  ...                                                NER
# 0               0  ...                                      [minneapolis]
# 1               1  ...                                                 []
# 2               2  ...                                           [lawton]
# 3               3  ...                            [stamford, minneapolis]
# 4               4  ...                                                 []
# ...           ...  ...                                                ...
# 21294       21294  ...                             [minnesota, baltimore]
# 21295       21295  ...     [charlotte, minneapolis, minnesota, baltimore]
# 21296       21296  ...             [fayetteville, n.c., fayetteville, us]
# 21297       21297  ...  [louisville, minnesota, georgia, brunswick, ke...
# 21298       21298  ...                                  [minneapolis, dc]
#
# [21299 rows x 52 columns]

# %%
ct_ner['NER-1']=ct_ner['NER']

# %%
ct_ner['NER-1'][0]
# Out:
# ['minneapolis']

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_ner[:100]
# Out:
#     Unnamed: 0  ...                                              NER-1
# 0            0  ...                                      [minneapolis]
# 1            1  ...                                                 []
# 2            2  ...                                           [lawton]
# 3            3  ...                            [stamford, minneapolis]
# 4            4  ...                                                 []
# ..         ...  ...                                                ...
# 95          95  ...                [tulare county, san joaquin valley]
# 96          96  ...                                      [minneapolis]
# 97          97  ...  [north carolina, greenville, minneapolis, minn...
# 98          98  ...  [goldsboro, greenville, minnesota, north carol...
# 99          99  ...                                                 []
#
# [100 rows x 53 columns]

# %%
# %cd mapping_US
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/mapping_US

# %%
# !ls
# Out:
# Country.txt		       dataframe0609_post_remove.csv
# dataframe0529_post.csv	       dataframe0610_post.csv
# dataframe0529_post_remove.csv  dataframe0610_post_remove.csv
# dataframe0530_post.csv	       dataframe0611_post.csv
# dataframe0530_post_remove.csv  dataframe0611_post_remove.csv
# dataframe0531_post.csv	       dataframe_mapping
# dataframe0601_post.csv	       dataframe_mapping_0529.csv
# dataframe0601_post_remove.csv  dataframe_mapping_0530.csv
# dataframe0602_post.csv	       dataframe_mapping_0531.csv
# dataframe0602_post_remove.csv  dataframe_mapping_0601.csv
# dataframe0603_post.csv	       dataframe_mapping_0602.csv
# dataframe0603_post_remove.csv  dataframe_mapping_0603.csv
# dataframe0604_post.csv	       dataframe_mapping_0604.csv
# dataframe0604_post_remove.csv  dataframe_mapping_0605.csv
# dataframe0605_post.csv	       dataframe_mapping_0606.csv
# dataframe0605_post_remove.csv  dataframe_mapping_0607.csv
# dataframe0606_post.csv	       dataframe_mapping_0608.csv
# dataframe0606_post_remove.csv  dataframe_mapping_0609.csv
# dataframe0607_post.csv	       dataframe_mapping_0610.csv
# dataframe0607_post_remove.csv  dataframe_mapping_0611.csv
# dataframe0608_post.csv	       datarframe_post
# dataframe0608_post_remove.csv  post_specific_mapping_US.zip
# dataframe0609_post.csv	       states.csv

# %%
ct_mapping=pd.read_csv('dataframe_mapping_0531.csv',encoding='ISO-8859-1')

# %%
ct_mapping
# Out:
#       Unnamed: 0         City Number  ... Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0              0  minneapolis   7124  ...         NaN         NaN         NaN
# 1              1    minnesota   2089  ...         NaN         NaN         NaN
# 2              2      america   1324  ...         NaN         NaN         NaN
# 3              3           us   1318  ...         NaN         NaN         NaN
# 4              4  los angeles   1179  ...         NaN         NaN         NaN
# ...          ...          ...    ...  ...         ...         ...         ...
# 2344        2348      belmont      1  ...         NaN         NaN         NaN
# 2345        2349       avenal      1  ...         NaN         NaN         NaN
# 2346        2350         nola      1  ...         NaN         NaN         NaN
# 2347        2351      us park      1  ...         NaN         NaN         NaN
# 2348        2352          fam      1  ...         NaN         NaN         NaN
#
# [2349 rows x 14 columns]

# %%
country_list=pd.read_csv('Country.txt')
country_list['Name']=country_list['Name'].str.lower()

# %%
country_list['Name']
# Out:
# 0            afghanistan
# 1          �land islands
# 2                albania
# 3                algeria
# 4         american samoa
#              ...
# 244    wallis and futuna
# 245       western sahara
# 246                yemen
# 247               zambia
# 248             zimbabwe
# Name: Name, Length: 249, dtype: object

# %%
states_list=pd.read_csv('states.csv')
states_list['State']
# Out:
# 0            Alabama, United States
# 1             Alaska, United States
# 2            Arizona, United States
# 3           Arkansas, United States
# 4         California, United States
# 5           Colorado, United States
# 6        Connecticut, United States
# 7           Delaware, United States
# 8            Florida, United States
# 9            Georgia, United States
# 10            Hawaii, United States
# 11             Idaho, United States
# 12          Illinois, United States
# 13           Indiana, United States
# 14              Iowa, United States
# 15            Kansas, United States
# 16          Kentucky, United States
# 17         Louisiana, United States
# 18             Maine, United States
# 19           Montana, United States
# 20          Nebraska, United States
# 21            Nevada, United States
# 22     New Hampshire, United States
# 23        New Jersey, United States
# 24        New Mexico, United States
# 25    North Carolina, United States
# 26      North Dakota, United States
# 27              Ohio, United States
# 28          Oklahoma, United States
# 29            Oregon, United States
# 30          Maryland, United States
# 31     Massachusetts, United States
# 32          Michigan, United States
# 33         Minnesota, United States
# 34       Mississippi, United States
# 35          Missouri, United States
# 36      Pennsylvania, United States
# 37      Rhode Island, United States
# 38    South Carolina, United States
# 39      South Dakota, United States
# 40         Tennessee, United States
# 41             Texas, United States
# 42              Utah, United States
# 43           Vermont, United States
# 44          Virginia, United States
# 45        Washington, United States
# 46     West Virginia, United States
# 47         Wisconsin, United States
# 48           Wyoming, United States
# Name: State, dtype: object

# %%
from numpy.core.numeric import NaN
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['City'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(states_list['State'])):
    if ct_mapping['Mapping'][i]==states_list['State'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['Mapping'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN

# %%
pd.set_option('display.max_rows', None)

# %%
ct_mapping
# Out:
#       Unnamed: 0  ... Unnamed: 13
# 0              0  ...         NaN
# 1              1  ...         NaN
# 2              2  ...         NaN
# 3              3  ...         NaN
# 4              4  ...         NaN
# 5              5  ...         NaN
# 6              6  ...         NaN
# 7              7  ...         NaN
# 8              8  ...         NaN
# 9              9  ...         NaN
# 10            10  ...         NaN
# 11            11  ...         NaN
# 12            12  ...         NaN
# 13            13  ...         NaN
# 14            14  ...         NaN
# 15            15  ...         NaN
# 16            16  ...         NaN
# 17            17  ...         NaN
# 18            18  ...         NaN
# 19            19  ...         NaN
# 20            20  ...         NaN
# 21            21  ...         NaN
# 22            22  ...         NaN
# 23            23  ...         NaN
# 24            24  ...         NaN
# 25            25  ...         NaN
# 26            26  ...         NaN
# 27            27  ...         NaN
# 28            28  ...         NaN
# 29            29  ...         NaN
# 30            30  ...         NaN
# 31            31  ...         NaN
# 32            32  ...         NaN
# 33            33  ...         NaN
# 34            34  ...         NaN
# 35            35  ...         NaN
# 36            36  ...         NaN
# 37            37  ...         NaN
# 38            38  ...         NaN
# 39            39  ...         NaN
# 40            40  ...         NaN
# 41            41  ...         NaN
# 42            42  ...         NaN
# 43            43  ...         NaN
# 44            44  ...         NaN
# 45            45  ...         NaN
# 46            46  ...         NaN
# 47            47  ...         NaN
# 48            48  ...         NaN
# 49            49  ...         NaN
# 50            50  ...         NaN
# 51            51  ...         NaN
# 52            52  ...         NaN
# 53            53  ...         NaN
# 54            54  ...         NaN
# 55            55  ...         NaN
# 56            56  ...         NaN
# 57            57  ...         NaN
# 58            58  ...         NaN
# 59            59  ...         NaN
# 60            60  ...         NaN
# 61            61  ...         NaN
# 62            62  ...         NaN
# 63            63  ...         NaN
# 64            64  ...         NaN
# 65            65  ...         NaN
# 66            66  ...         NaN
# 67            67  ...         NaN
# 68            68  ...         NaN
# 69            69  ...         NaN
# 70            70  ...         NaN
# 71            71  ...         NaN
# 72            72  ...         NaN
# 73            73  ...         NaN
# 74            74  ...         NaN
# 75            75  ...         NaN
# 76            76  ...         NaN
# 77            77  ...         NaN
# 78            78  ...         NaN
# 79            79  ...         NaN
# 80            80  ...         NaN
# 81            81  ...         NaN
# 82            82  ...         NaN
# 83            83  ...         NaN
# 84            84  ...         NaN
# 85            85  ...         NaN
# 86            86  ...         NaN
# 87            87  ...         NaN
# 88            88  ...         NaN
# 89            89  ...         NaN
# 90            90  ...         NaN
# 91            91  ...         NaN
# 92            92  ...         NaN
# 93            93  ...         NaN
# 94            94  ...         NaN
# 95            95  ...         NaN
# 96            96  ...         NaN
# 97            97  ...         NaN
# 98            98  ...         NaN
# 99            99  ...         NaN
# 100          100  ...         NaN
# 101          101  ...         NaN
# 102          102  ...         NaN
# 103          103  ...         NaN
# 104          104  ...         NaN
# 105          105  ...         NaN
# 106          106  ...         NaN
# 107          107  ...         NaN
# 108          108  ...         NaN
# 109          109  ...         NaN
# 110          110  ...         NaN
# 111          111  ...         NaN
# 112          112  ...         NaN
# 113          113  ...         NaN
# 114          114  ...         NaN
# 115          115  ...         NaN
# 116          116  ...         NaN
# 117          117  ...         NaN
# 118          118  ...         NaN
# 119          119  ...         NaN
# 120          120  ...         NaN
# 121          121  ...         NaN
# 122          122  ...         NaN
# 123          123  ...         NaN
# 124          124  ...         NaN
# 125          125  ...         NaN
# 126          126  ...         NaN
# 127          127  ...         NaN
# 128          128  ...         NaN
# 129          129  ...         NaN
# 130          130  ...         NaN
# 131          131  ...         NaN
# 132          132  ...         NaN
# 133          133  ...         NaN
# 134          134  ...         NaN
# 135          135  ...         NaN
# 136          136  ...         NaN
# 137          137  ...         NaN
# 138          138  ...         NaN
# 139          139  ...         NaN
# 140          140  ...         NaN
# 141          141  ...         NaN
# 142          142  ...         NaN
# 143          143  ...         NaN
# 144          144  ...         NaN
# 145          145  ...         NaN
# 146          146  ...         NaN
# 147          147  ...         NaN
# 148          148  ...         NaN
# 149          149  ...         NaN
# 150          150  ...         NaN
# 151          151  ...         NaN
# 152          152  ...         NaN
# 153          153  ...         NaN
# 154          154  ...         NaN
# 155          155  ...         NaN
# 156          156  ...         NaN
# 157          157  ...         NaN
# 158          158  ...         NaN
# 159          159  ...         NaN
# 160          160  ...         NaN
# 161          161  ...         NaN
# 162          162  ...         NaN
# 163          163  ...         NaN
# 164          164  ...         NaN
# 165          165  ...         NaN
# 166          166  ...         NaN
# 167          167  ...         NaN
# 168          168  ...         NaN
# 169          169  ...         NaN
# 170          170  ...         NaN
# 171          171  ...         NaN
# 172          172  ...         NaN
# 173          173  ...         NaN
# 174          174  ...         NaN
# 175          175  ...         NaN
# 176          176  ...         NaN
# 177          177  ...         NaN
# 178          178  ...         NaN
# 179          179  ...         NaN
# 180          180  ...         NaN
# 181          181  ...         NaN
# 182          182  ...         NaN
# 183          183  ...         NaN
# 184          184  ...         NaN
# 185          185  ...         NaN
# 186          186  ...         NaN
# 187          187  ...         NaN
# 188          188  ...         NaN
# 189          189  ...         NaN
# 190          190  ...         NaN
# 191          191  ...         NaN
# 192          192  ...         NaN
# 193          193  ...         NaN
# 194          194  ...         NaN
# 195          195  ...         NaN
# 196          196  ...         NaN
# 197          197  ...         NaN
# 198          198  ...         NaN
# 199          199  ...         NaN
# 200          200  ...         NaN
# 201          201  ...         NaN
# 202          202  ...         NaN
# 203          203  ...         NaN
# 204          204  ...         NaN
# 205          205  ...         NaN
# 206          206  ...         NaN
# 207          207  ...         NaN
# 208          208  ...         NaN
# 209          209  ...         NaN
# 210          210  ...         NaN
# 211          211  ...         NaN
# 212          212  ...         NaN
# 213          213  ...         NaN
# 214          214  ...         NaN
# 215          215  ...         NaN
# 216          216  ...         NaN
# 217          217  ...         NaN
# 218          218  ...         NaN
# 219          219  ...         NaN
# 220          220  ...         NaN
# 221          221  ...         NaN
# 222          222  ...         NaN
# 223          223  ...         NaN
# 224          224  ...         NaN
# 225          225  ...         NaN
# 226          226  ...         NaN
# 227          227  ...         NaN
# 228          228  ...         NaN
# 229          229  ...         NaN
# 230          230  ...         NaN
# 231          231  ...         NaN
# 232          232  ...         NaN
# 233          233  ...         NaN
# 234          234  ...         NaN
# 235          235  ...         NaN
# 236          236  ...         NaN
# 237          237  ...         NaN
# 238          238  ...         NaN
# 239          239  ...         NaN
# 240          240  ...         NaN
# 241          241  ...         NaN
# 242          242  ...         NaN
# 243          243  ...         NaN
# 244          244  ...         NaN
# 245          245  ...         NaN
# 246          246  ...         NaN
# 247          247  ...         NaN
# 248          248  ...         NaN
# 249          249  ...         NaN
# 250          250  ...         NaN
# 251          251  ...         NaN
# 252          252  ...         NaN
# 253          253  ...         NaN
# 254          254  ...         NaN
# 255          255  ...         NaN
# 256          256  ...         NaN
# 257          257  ...         NaN
# 258          258  ...         NaN
# 259          259  ...         NaN
# 260          260  ...         NaN
# 261          261  ...         NaN
# 262          262  ...         NaN
# 263          263  ...         NaN
# 264          264  ...         NaN
# 265          265  ...         NaN
# 266          266  ...         NaN
# 267          267  ...         NaN
# 268          268  ...         NaN
# 269          269  ...         NaN
# 270          270  ...         NaN
# 271          271  ...         NaN
# 272          272  ...         NaN
# 273          273  ...         NaN
# 274          274  ...         NaN
# 275          275  ...         NaN
# 276          276  ...         NaN
# 277          277  ...         NaN
# 278          278  ...         NaN
# 279          279  ...         NaN
# 280          280  ...         NaN
# 281          281  ...         NaN
# 282          282  ...         NaN
# 283          283  ...         NaN
# 284          284  ...         NaN
# 285          285  ...         NaN
# 286          286  ...         NaN
# 287          287  ...         NaN
# 288          288  ...         NaN
# 289          289  ...         NaN
# 290          290  ...         NaN
# 291          291  ...         NaN
# 292          292  ...         NaN
# 293          293  ...         NaN
# 294          294  ...         NaN
# 295          295  ...         NaN
# 296          296  ...         NaN
# 297          297  ...         NaN
# 298          298  ...         NaN
# 299          299  ...         NaN
# 300          300  ...         NaN
# 301          301  ...         NaN
# 302          302  ...         NaN
# 303          303  ...         NaN
# 304          304  ...         NaN
# 305          305  ...         NaN
# 306          306  ...         NaN
# 307          307  ...         NaN
# 308          308  ...         NaN
# 309          309  ...         NaN
# 310          310  ...         NaN
# 311          311  ...         NaN
# 312          312  ...         NaN
# 313          313  ...         NaN
# 314          314  ...         NaN
# 315          315  ...         NaN
# 316          316  ...         NaN
# 317          317  ...         NaN
# 318          318  ...         NaN
# 319          319  ...         NaN
# 320          320  ...         NaN
# 321          321  ...         NaN
# 322          322  ...         NaN
# 323          323  ...         NaN
# 324          324  ...         NaN
# 325          325  ...         NaN
# 326          326  ...         NaN
# 327          327  ...         NaN
# 328          328  ...         NaN
# 329          329  ...         NaN
# 330          330  ...         NaN
# 331          331  ...         NaN
# 332          332  ...         NaN
# 333          333  ...         NaN
# 334          334  ...         NaN
# 335          335  ...         NaN
# 336          336  ...         NaN
# 337          337  ...         NaN
# 338          338  ...         NaN
# 339          339  ...         NaN
# 340          340  ...         NaN
# 341          341  ...         NaN
# 342          342  ...         NaN
# 343          343  ...         NaN
# 344          344  ...         NaN
# 345          345  ...         NaN
# 346          346  ...         NaN
# 347          347  ...         NaN
# 348          348  ...         NaN
# 349          349  ...         NaN
# 350          350  ...         NaN
# 351          351  ...         NaN
# 352          352  ...         NaN
# 353          353  ...         NaN
# 354          354  ...         NaN
# 355          355  ...         NaN
# 356          356  ...         NaN
# 357          357  ...         NaN
# 358          358  ...         NaN
# 359          359  ...         NaN
# 360          360  ...         NaN
# 361          361  ...         NaN
# 362          362  ...         NaN
# 363          363  ...         NaN
# 364          364  ...         NaN
# 365          365  ...         NaN
# 366          366  ...         NaN
# 367          367  ...         NaN
# 368          368  ...         NaN
# 369          369  ...         NaN
# 370          370  ...         NaN
# 371          371  ...         NaN
# 372          372  ...         NaN
# 373          373  ...         NaN
# 374          374  ...         NaN
# 375          375  ...         NaN
# 376          376  ...         NaN
# 377          377  ...         NaN
# 378          378  ...         NaN
# 379          379  ...         NaN
# 380          380  ...         NaN
# 381          381  ...         NaN
# 382          382  ...         NaN
# 383          383  ...         NaN
# 384          384  ...         NaN
# 385          385  ...         NaN
# 386          386  ...         NaN
# 387          387  ...         NaN
# 388          388  ...         NaN
# 389          389  ...         NaN
# 390          390  ...         NaN
# 391          391  ...         NaN
# 392          392  ...         NaN
# 393          393  ...         NaN
# 394          394  ...         NaN
# 395          395  ...         NaN
# 396          396  ...         NaN
# 397          397  ...         NaN
# 398          398  ...         NaN
# 399          399  ...         NaN
# 400          400  ...         NaN
# 401          401  ...         NaN
# 402          402  ...         NaN
# 403          403  ...         NaN
# 404          404  ...         NaN
# 405          405  ...         NaN
# 406          406  ...         NaN
# 407          407  ...         NaN
# 408          408  ...         NaN
# 409          409  ...         NaN
# 410          410  ...         NaN
# 411          411  ...         NaN
# 412          412  ...         NaN
# 413          413  ...         NaN
# 414          414  ...         NaN
# 415          415  ...         NaN
# 416          416  ...         NaN
# 417          417  ...         NaN
# 418          418  ...         NaN
# 419          419  ...         NaN
# 420          420  ...         NaN
# 421          421  ...         NaN
# 422          422  ...         NaN
# 423          423  ...         NaN
# 424          424  ...         NaN
# 425          425  ...         NaN
# 426          426  ...         NaN
# 427          427  ...         NaN
# 428          428  ...         NaN
# 429          429  ...         NaN
# 430          430  ...         NaN
# 431          431  ...         NaN
# 432          432  ...         NaN
# 433          433  ...         NaN
# 434          434  ...         NaN
# 435          435  ...         NaN
# 436          436  ...         NaN
# 437          437  ...         NaN
# 438          438  ...         NaN
# 439          439  ...         NaN
# 440          440  ...         NaN
# 441          441  ...         NaN
# 442          442  ...         NaN
# 443          443  ...         NaN
# 444          444  ...         NaN
# 445          445  ...         NaN
# 446          446  ...         NaN
# 447          447  ...         NaN
# 448          448  ...         NaN
# 449          449  ...         NaN
# 450          450  ...         NaN
# 451          451  ...         NaN
# 452          452  ...         NaN
# 453          453  ...         NaN
# 454          454  ...         NaN
# 455          455  ...         NaN
# 456          456  ...         NaN
# 457          457  ...         NaN
# 458          458  ...         NaN
# 459          459  ...         NaN
# 460          460  ...         NaN
# 461          461  ...         NaN
# 462          462  ...         NaN
# 463          463  ...         NaN
# 464          464  ...         NaN
# 465          465  ...         NaN
# 466          466  ...         NaN
# 467          467  ...         NaN
# 468          468  ...         NaN
# 469          469  ...         NaN
# 470          470  ...         NaN
# 471          471  ...         NaN
# 472          472  ...         NaN
# 473          473  ...         NaN
# 474          474  ...         NaN
# 475          475  ...         NaN
# 476          476  ...         NaN
# 477          477  ...         NaN
# 478          478  ...         NaN
# 479          479  ...         NaN
# 480          480  ...         NaN
# 481          481  ...         NaN
# 482          482  ...         NaN
# 483          483  ...         NaN
# 484          484  ...         NaN
# 485          485  ...         NaN
# 486          486  ...         NaN
# 487          487  ...         NaN
# 488          488  ...         NaN
# 489          489  ...         NaN
# 490          490  ...         NaN
# 491          491  ...         NaN
# 492          492  ...         NaN
# 493          493  ...         NaN
# 494          494  ...         NaN
# 495          495  ...         NaN
# 496          496  ...         NaN
# 497          497  ...         NaN
# 498          498  ...         NaN
# 499          499  ...         NaN
# 500          500  ...         NaN
# 501          501  ...         NaN
# 502          502  ...         NaN
# 503          503  ...         NaN
# 504          504  ...         NaN
# 505          505  ...         NaN
# 506          506  ...         NaN
# 507          507  ...         NaN
# 508          508  ...         NaN
# 509          509  ...         NaN
# 510          510  ...         NaN
# 511          511  ...         NaN
# 512          512  ...         NaN
# 513          513  ...         NaN
# 514          514  ...         NaN
# 515          515  ...         NaN
# 516          516  ...         NaN
# 517          517  ...         NaN
# 518          518  ...         NaN
# 519          519  ...         NaN
# 520          520  ...         NaN
# 521          521  ...         NaN
# 522          522  ...         NaN
# 523          523  ...         NaN
# 524          524  ...         NaN
# 525          525  ...         NaN
# 526          526  ...         NaN
# 527          527  ...         NaN
# 528          528  ...         NaN
# 529          529  ...         NaN
# 530          530  ...         NaN
# 531          531  ...         NaN
# 532          532  ...         NaN
# 533          533  ...         NaN
# 534          534  ...         NaN
# 535          535  ...         NaN
# 536          536  ...         NaN
# 537          537  ...         NaN
# 538          538  ...         NaN
# 539          539  ...         NaN
# 540          540  ...         NaN
# 541          541  ...         NaN
# 542          542  ...         NaN
# 543          543  ...         NaN
# 544          544  ...         NaN
# 545          545  ...         NaN
# 546          546  ...         NaN
# 547          547  ...         NaN
# 548          548  ...         NaN
# 549          549  ...         NaN
# 550          550  ...         NaN
# 551          551  ...         NaN
# 552          552  ...         NaN
# 553          553  ...         NaN
# 554          554  ...         NaN
# 555          555  ...         NaN
# 556          556  ...         NaN
# 557          557  ...         NaN
# 558          558  ...         NaN
# 559          559  ...         NaN
# 560          560  ...         NaN
# 561          561  ...         NaN
# 562          562  ...         NaN
# 563          563  ...         NaN
# 564          564  ...         NaN
# 565          565  ...         NaN
# 566          566  ...         NaN
# 567          567  ...         NaN
# 568          568  ...         NaN
# 569          569  ...         NaN
# 570          570  ...         NaN
# 571          571  ...         NaN
# 572          572  ...         NaN
# 573          573  ...         NaN
# 574          574  ...         NaN
# 575          575  ...         NaN
# 576          576  ...         NaN
# 577          577  ...         NaN
# 578          578  ...         NaN
# 579          579  ...         NaN
# 580          580  ...         NaN
# 581          581  ...         NaN
# 582          582  ...         NaN
# 583          583  ...         NaN
# 584          584  ...         NaN
# 585          585  ...         NaN
# 586          586  ...         NaN
# 587          587  ...         NaN
# 588          588  ...         NaN
# 589          589  ...         NaN
# 590          590  ...         NaN
# 591          591  ...         NaN
# 592          592  ...         NaN
# 593          593  ...         NaN
# 594          594  ...         NaN
# 595          595  ...         NaN
# 596          596  ...         NaN
# 597          597  ...         NaN
# 598          598  ...         NaN
# 599          599  ...         NaN
# 600          600  ...         NaN
# 601          601  ...         NaN
# 602          602  ...         NaN
# 603          603  ...         NaN
# 604          604  ...         NaN
# 605          605  ...         NaN
# 606          606  ...         NaN
# 607          607  ...         NaN
# 608          608  ...         NaN
# 609          609  ...         NaN
# 610          610  ...         NaN
# 611          611  ...         NaN
# 612          612  ...         NaN
# 613          613  ...         NaN
# 614          614  ...         NaN
# 615          615  ...         NaN
# 616          616  ...         NaN
# 617          617  ...         NaN
# 618          618  ...         NaN
# 619          619  ...         NaN
# 620          620  ...         NaN
# 621          621  ...         NaN
# 622          622  ...         NaN
# 623          623  ...         NaN
# 624          624  ...         NaN
# 625          625  ...         NaN
# 626          626  ...         NaN
# 627          627  ...         NaN
# 628          628  ...         NaN
# 629          629  ...         NaN
# 630          630  ...         NaN
# 631          631  ...         NaN
# 632          632  ...         NaN
# 633          633  ...         NaN
# 634          634  ...         NaN
# 635          635  ...         NaN
# 636          636  ...         NaN
# 637          637  ...         NaN
# 638          638  ...         NaN
# 639          639  ...         NaN
# 640          640  ...         NaN
# 641          641  ...         NaN
# 642          642  ...         NaN
# 643          643  ...         NaN
# 644          644  ...         NaN
# 645          645  ...         NaN
# 646          646  ...         NaN
# 647          647  ...         NaN
# 648          648  ...         NaN
# 649          649  ...         NaN
# 650          650  ...         NaN
# 651          651  ...         NaN
# 652          652  ...         NaN
# 653          653  ...         NaN
# 654          654  ...         NaN
# 655          655  ...         NaN
# 656          656  ...         NaN
# 657          657  ...         NaN
# 658          658  ...         NaN
# 659          659  ...         NaN
# 660          660  ...         NaN
# 661          661  ...         NaN
# 662          662  ...         NaN
# 663          663  ...         NaN
# 664          664  ...         NaN
# 665          665  ...         NaN
# 666          666  ...         NaN
# 667          667  ...         NaN
# 668          668  ...         NaN
# 669          669  ...         NaN
# 670          670  ...         NaN
# 671          671  ...         NaN
# 672          672  ...         NaN
# 673          673  ...         NaN
# 674          674  ...         NaN
# 675          675  ...         NaN
# 676          676  ...         NaN
# 677          677  ...         NaN
# 678          678  ...         NaN
# 679          679  ...         NaN
# 680          680  ...         NaN
# 681          681  ...         NaN
# 682          682  ...         NaN
# 683          683  ...         NaN
# 684          684  ...         NaN
# 685          685  ...         NaN
# 686          686  ...         NaN
# 687          687  ...         NaN
# 688          688  ...         NaN
# 689          689  ...         NaN
# 690          690  ...         NaN
# 691          691  ...         NaN
# 692          692  ...         NaN
# 693          693  ...         NaN
# 694          694  ...         NaN
# 695          695  ...         NaN
# 696          696  ...         NaN
# 697          697  ...         NaN
# 698          698  ...         NaN
# 699          699  ...         NaN
# 700          700  ...         NaN
# 701          701  ...         NaN
# 702          702  ...         NaN
# 703          703  ...         NaN
# 704          704  ...         NaN
# 705          705  ...         NaN
# 706          706  ...         NaN
# 707          707  ...         NaN
# 708          708  ...         NaN
# 709          709  ...         NaN
# 710          710  ...         NaN
# 711          711  ...         NaN
# 712          712  ...         NaN
# 713          713  ...         NaN
# 714          714  ...         NaN
# 715          715  ...         NaN
# 716          716  ...         NaN
# 717          717  ...         NaN
# 718          718  ...         NaN
# 719          719  ...         NaN
# 720          720  ...         NaN
# 721          721  ...         NaN
# 722          722  ...         NaN
# 723          723  ...         NaN
# 724          724  ...         NaN
# 725          725  ...         NaN
# 726          726  ...         NaN
# 727          727  ...         NaN
# 728          728  ...         NaN
# 729          729  ...         NaN
# 730          730  ...         NaN
# 731          731  ...         NaN
# 732          732  ...         NaN
# 733          733  ...         NaN
# 734          734  ...         NaN
# 735          735  ...         NaN
# 736          736  ...         NaN
# 737          737  ...         NaN
# 738          738  ...         NaN
# 739          739  ...         NaN
# 740          740  ...         NaN
# 741          741  ...         NaN
# 742          742  ...         NaN
# 743          743  ...         NaN
# 744          744  ...         NaN
# 745          745  ...         NaN
# 746          746  ...         NaN
# 747          747  ...         NaN
# 748          748  ...         NaN
# 749          749  ...         NaN
# 750          750  ...         NaN
# 751          751  ...         NaN
# 752          752  ...         NaN
# 753          753  ...         NaN
# 754          754  ...         NaN
# 755          755  ...         NaN
# 756          756  ...         NaN
# 757          757  ...         NaN
# 758          758  ...         NaN
# 759          759  ...         NaN
# 760          760  ...         NaN
# 761          761  ...         NaN
# 762          762  ...         NaN
# 763          763  ...         NaN
# 764          764  ...         NaN
# 765          765  ...         NaN
# 766          766  ...         NaN
# 767          767  ...         NaN
# 768          768  ...         NaN
# 769          769  ...         NaN
# 770          770  ...         NaN
# 771          771  ...         NaN
# 772          772  ...         NaN
# 773          773  ...         NaN
# 774          774  ...         NaN
# 775          775  ...         NaN
# 776          776  ...         NaN
# 777          777  ...         NaN
# 778          778  ...         NaN
# 779          779  ...         NaN
# 780          780  ...         NaN
# 781          781  ...         NaN
# 782          782  ...         NaN
# 783          783  ...         NaN
# 784          784  ...         NaN
# 785          785  ...         NaN
# 786          786  ...         NaN
# 787          787  ...         NaN
# 788          788  ...         NaN
# 789          789  ...         NaN
# 790          790  ...         NaN
# 791          791  ...         NaN
# 792          792  ...         NaN
# 793          793  ...         NaN
# 794          794  ...         NaN
# 795          795  ...         NaN
# 796          796  ...         NaN
# 797          797  ...         NaN
# 798          798  ...         NaN
# 799          799  ...         NaN
# 800          800  ...         NaN
# 801          801  ...         NaN
# 802          802  ...         NaN
# 803          803  ...         NaN
# 804          804  ...         NaN
# 805          805  ...         NaN
# 806          806  ...         NaN
# 807          807  ...         NaN
# 808          808  ...         NaN
# 809          809  ...         NaN
# 810          810  ...         NaN
# 811          811  ...         NaN
# 812          812  ...         NaN
# 813          813  ...         NaN
# 814          814  ...         NaN
# 815          815  ...         NaN
# 816          816  ...         NaN
# 817          817  ...         NaN
# 818          818  ...         NaN
# 819          819  ...         NaN
# 820          820  ...         NaN
# 821          821  ...         NaN
# 822          822  ...         NaN
# 823          823  ...         NaN
# 824          824  ...         NaN
# 825          825  ...         NaN
# 826          826  ...         NaN
# 827          827  ...         NaN
# 828          828  ...         NaN
# 829          829  ...         NaN
# 830          830  ...         NaN
# 831          831  ...         NaN
# 832          832  ...         NaN
# 833          833  ...         NaN
# 834          834  ...         NaN
# 835          835  ...         NaN
# 836          836  ...         NaN
# 837          837  ...         NaN
# 838          838  ...         NaN
# 839          839  ...         NaN
# 840          840  ...         NaN
# 841          841  ...         NaN
# 842          842  ...         NaN
# 843          843  ...         NaN
# 844          844  ...         NaN
# 845          845  ...         NaN
# 846          846  ...         NaN
# 847          847  ...         NaN
# 848          848  ...         NaN
# 849          849  ...         NaN
# 850          850  ...         NaN
# 851          851  ...         NaN
# 852          852  ...         NaN
# 853          853  ...         NaN
# 854          854  ...         NaN
# 855          855  ...         NaN
# 856          856  ...         NaN
# 857          857  ...         NaN
# 858          858  ...         NaN
# 859          859  ...         NaN
# 860          860  ...         NaN
# 861          861  ...         NaN
# 862          862  ...         NaN
# 863          863  ...         NaN
# 864          864  ...         NaN
# 865          865  ...         NaN
# 866          866  ...         NaN
# 867          867  ...         NaN
# 868          868  ...         NaN
# 869          869  ...         NaN
# 870          870  ...         NaN
# 871          871  ...         NaN
# 872          872  ...         NaN
# 873          873  ...         NaN
# 874          874  ...         NaN
# 875          875  ...         NaN
# 876          876  ...         NaN
# 877          877  ...         NaN
# 878          878  ...         NaN
# 879          879  ...         NaN
# 880          880  ...         NaN
# 881          881  ...         NaN
# 882          882  ...         NaN
# 883          883  ...         NaN
# 884          884  ...         NaN
# 885          885  ...         NaN
# 886          886  ...         NaN
# 887          887  ...         NaN
# 888          888  ...         NaN
# 889          889  ...         NaN
# 890          890  ...         NaN
# 891          891  ...         NaN
# 892          892  ...         NaN
# 893          893  ...         NaN
# 894          894  ...         NaN
# 895          895  ...         NaN
# 896          896  ...         NaN
# 897          897  ...         NaN
# 898          898  ...         NaN
# 899          899  ...         NaN
# 900          900  ...         NaN
# 901          901  ...         NaN
# 902          902  ...         NaN
# 903          903  ...         NaN
# 904          904  ...         NaN
# 905          905  ...         NaN
# 906          906  ...         NaN
# 907          907  ...         NaN
# 908          908  ...         NaN
# 909          909  ...         NaN
# 910          910  ...         NaN
# 911          911  ...         NaN
# 912          912  ...         NaN
# 913          913  ...         NaN
# 914          914  ...         NaN
# 915          915  ...         NaN
# 916          916  ...         NaN
# 917          917  ...         NaN
# 918          918  ...         NaN
# 919          919  ...         NaN
# 920          920  ...         NaN
# 921          921  ...         NaN
# 922          922  ...         NaN
# 923          923  ...         NaN
# 924          924  ...         NaN
# 925          925  ...         NaN
# 926          926  ...         NaN
# 927          927  ...         NaN
# 928          928  ...         NaN
# 929          929  ...         NaN
# 930          930  ...         NaN
# 931          931  ...         NaN
# 932          932  ...         NaN
# 933          933  ...         NaN
# 934          934  ...         NaN
# 935          935  ...         NaN
# 936          936  ...         NaN
# 937          937  ...         NaN
# 938          938  ...         NaN
# 939          939  ...         NaN
# 940          940  ...         NaN
# 941          941  ...         NaN
# 942          942  ...         NaN
# 943          943  ...         NaN
# 944          944  ...         NaN
# 945          945  ...         NaN
# 946          946  ...         NaN
# 947          947  ...         NaN
# 948          948  ...         NaN
# 949          949  ...         NaN
# 950          950  ...         NaN
# 951          951  ...         NaN
# 952          952  ...         NaN
# 953          953  ...         NaN
# 954          954  ...         NaN
# 955          955  ...         NaN
# 956          956  ...         NaN
# 957          957  ...         NaN
# 958          958  ...         NaN
# 959          959  ...         NaN
# 960          960  ...         NaN
# 961          961  ...         NaN
# 962          962  ...         NaN
# 963          963  ...         NaN
# 964          964  ...         NaN
# 965          965  ...         NaN
# 966          966  ...         NaN
# 967          967  ...         NaN
# 968          968  ...         NaN
# 969          969  ...         NaN
# 970          970  ...         NaN
# 971          971  ...         NaN
# 972          972  ...         NaN
# 973          973  ...         NaN
# 974          974  ...         NaN
# 975          975  ...         NaN
# 976          976  ...         NaN
# 977          977  ...         NaN
# 978          978  ...         NaN
# 979          979  ...         NaN
# 980          980  ...         NaN
# 981          981  ...         NaN
# 982          982  ...         NaN
# 983          983  ...         NaN
# 984          984  ...         NaN
# 985          985  ...         NaN
# 986          986  ...         NaN
# 987          987  ...         NaN
# 988          988  ...         NaN
# 989          989  ...         NaN
# 990          990  ...         NaN
# 991          991  ...         NaN
# 992          992  ...         NaN
# 993          993  ...         NaN
# 994          994  ...         NaN
# 995          995  ...         NaN
# 996          996  ...         NaN
# 997          997  ...         NaN
# 998          998  ...         NaN
# 999          999  ...         NaN
# 1000        1000  ...         NaN
# 1001        1001  ...         NaN
# 1002        1002  ...         NaN
# 1003        1003  ...         NaN
# 1004        1004  ...         NaN
# 1005        1005  ...         NaN
# 1006        1006  ...         NaN
# 1007        1007  ...         NaN
# 1008        1008  ...         NaN
# 1009        1009  ...         NaN
# 1010        1010  ...         NaN
# 1011        1011  ...         NaN
# 1012        1012  ...         NaN
# 1013        1013  ...         NaN
# 1014        1014  ...         NaN
# 1015        1015  ...         NaN
# 1016        1016  ...         NaN
# 1017        1017  ...         NaN
# 1018        1018  ...         NaN
# 1019        1019  ...         NaN
# 1020        1020  ...         NaN
# 1021        1021  ...         NaN
# 1022        1022  ...         NaN
# 1023        1023  ...         NaN
# 1024        1024  ...         NaN
# 1025        1025  ...         NaN
# 1026        1026  ...         NaN
# 1027        1027  ...         NaN
# 1028        1028  ...         NaN
# 1029        1029  ...         NaN
# 1030        1030  ...         NaN
# 1031        1031  ...         NaN
# 1032        1032  ...         NaN
# 1033        1033  ...         NaN
# 1034        1034  ...         NaN
# 1035        1035  ...         NaN
# 1036        1036  ...         NaN
# 1037        1037  ...         NaN
# 1038        1038  ...         NaN
# 1039        1039  ...         NaN
# 1040        1040  ...         NaN
# 1041        1041  ...         NaN
# 1042        1043  ...         NaN
# 1043        1044  ...         NaN
# 1044        1045  ...         NaN
# 1045        1046  ...         NaN
# 1046        1047  ...         NaN
# 1047        1048  ...         NaN
# 1048        1049  ...         NaN
# 1049        1050  ...         NaN
# 1050        1051  ...         NaN
# 1051        1052  ...         NaN
# 1052        1053  ...         NaN
# 1053        1054  ...         NaN
# 1054        1055  ...         NaN
# 1055        1056  ...         NaN
# 1056        1057  ...         NaN
# 1057        1058  ...         NaN
# 1058        1059  ...         NaN
# 1059        1060  ...         NaN
# 1060        1061  ...         NaN
# 1061        1062  ...         NaN
# 1062        1063  ...         NaN
# 1063        1064  ...         NaN
# 1064        1065  ...         NaN
# 1065        1066  ...         NaN
# 1066        1067  ...         NaN
# 1067        1068  ...         NaN
# 1068        1069  ...         NaN
# 1069        1070  ...         NaN
# 1070        1071  ...         NaN
# 1071        1072  ...         NaN
# 1072        1073  ...         NaN
# 1073        1074  ...         NaN
# 1074        1075  ...         NaN
# 1075        1076  ...         NaN
# 1076        1077  ...         NaN
# 1077        1078  ...         NaN
# 1078        1079  ...         NaN
# 1079        1080  ...         NaN
# 1080        1081  ...         NaN
# 1081        1082  ...         NaN
# 1082        1083  ...         NaN
# 1083        1084  ...         NaN
# 1084        1085  ...         NaN
# 1085        1086  ...         NaN
# 1086        1087  ...         NaN
# 1087        1088  ...         NaN
# 1088        1089  ...         NaN
# 1089        1090  ...         NaN
# 1090        1091  ...         NaN
# 1091        1092  ...         NaN
# 1092        1093  ...         NaN
# 1093        1094  ...         NaN
# 1094        1095  ...         NaN
# 1095        1096  ...         NaN
# 1096        1097  ...         NaN
# 1097        1098  ...         NaN
# 1098        1099  ...         NaN
# 1099        1100  ...         NaN
# 1100        1101  ...         NaN
# 1101        1102  ...         NaN
# 1102        1103  ...         NaN
# 1103        1104  ...         NaN
# 1104        1105  ...         NaN
# 1105        1106  ...         NaN
# 1106        1107  ...         NaN
# 1107        1108  ...         NaN
# 1108        1109  ...         NaN
# 1109        1110  ...         NaN
# 1110        1111  ...         NaN
# 1111        1112  ...         NaN
# 1112        1113  ...         NaN
# 1113        1114  ...         NaN
# 1114        1115  ...         NaN
# 1115        1116  ...         NaN
# 1116        1117  ...         NaN
# 1117        1118  ...         NaN
# 1118        1119  ...         NaN
# 1119        1120  ...         NaN
# 1120        1121  ...         NaN
# 1121        1122  ...         NaN
# 1122        1123  ...         NaN
# 1123        1124  ...         NaN
# 1124        1125  ...         NaN
# 1125        1126  ...         NaN
# 1126        1127  ...         NaN
# 1127        1128  ...         NaN
# 1128        1129  ...         NaN
# 1129        1130  ...         NaN
# 1130        1131  ...         NaN
# 1131        1132  ...         NaN
# 1132        1133  ...         NaN
# 1133        1134  ...         NaN
# 1134        1135  ...         NaN
# 1135        1136  ...         NaN
# 1136        1137  ...         NaN
# 1137        1138  ...         NaN
# 1138        1139  ...         NaN
# 1139        1140  ...         NaN
# 1140        1141  ...         NaN
# 1141        1142  ...         NaN
# 1142        1143  ...         NaN
# 1143        1144  ...         NaN
# 1144        1145  ...         NaN
# 1145        1146  ...         NaN
# 1146        1147  ...         NaN
# 1147        1148  ...         NaN
# 1148        1149  ...         NaN
# 1149        1150  ...         NaN
# 1150        1151  ...         NaN
# 1151        1152  ...         NaN
# 1152        1153  ...         NaN
# 1153        1154  ...         NaN
# 1154        1155  ...         NaN
# 1155        1156  ...         NaN
# 1156        1157  ...         NaN
# 1157        1158  ...         NaN
# 1158        1159  ...         NaN
# 1159        1160  ...         NaN
# 1160        1161  ...         NaN
# 1161        1162  ...         NaN
# 1162        1163  ...         NaN
# 1163        1164  ...         NaN
# 1164        1165  ...         NaN
# 1165        1166  ...         NaN
# 1166        1167  ...         NaN
# 1167        1168  ...         NaN
# 1168        1169  ...         NaN
# 1169        1170  ...         NaN
# 1170        1171  ...         NaN
# 1171        1172  ...         NaN
# 1172        1173  ...         NaN
# 1173        1174  ...         NaN
# 1174        1175  ...         NaN
# 1175        1176  ...         NaN
# 1176        1177  ...         NaN
# 1177        1178  ...         NaN
# 1178        1179  ...         NaN
# 1179        1180  ...         NaN
# 1180        1181  ...         NaN
# 1181        1182  ...         NaN
# 1182        1183  ...         NaN
# 1183        1184  ...         NaN
# 1184        1185  ...         NaN
# 1185        1186  ...         NaN
# 1186        1187  ...         NaN
# 1187        1188  ...         NaN
# 1188        1189  ...         NaN
# 1189        1190  ...         NaN
# 1190        1191  ...         NaN
# 1191        1192  ...         NaN
# 1192        1193  ...         NaN
# 1193        1194  ...         NaN
# 1194        1195  ...         NaN
# 1195        1196  ...         NaN
# 1196        1197  ...         NaN
# 1197        1198  ...         NaN
# 1198        1199  ...         NaN
# 1199        1200  ...         NaN
# 1200        1201  ...         NaN
# 1201        1202  ...         NaN
# 1202        1203  ...         NaN
# 1203        1204  ...         NaN
# 1204        1205  ...         NaN
# 1205        1207  ...         NaN
# 1206        1208  ...         NaN
# 1207        1209  ...         NaN
# 1208        1210  ...         NaN
# 1209        1211  ...         NaN
# 1210        1212  ...         NaN
# 1211        1213  ...         NaN
# 1212        1214  ...         NaN
# 1213        1215  ...         NaN
# 1214        1216  ...         NaN
# 1215        1217  ...         NaN
# 1216        1218  ...         NaN
# 1217        1219  ...         NaN
# 1218        1220  ...         NaN
# 1219        1221  ...         NaN
# 1220        1222  ...         NaN
# 1221        1223  ...         NaN
# 1222        1224  ...         NaN
# 1223        1225  ...         NaN
# 1224        1226  ...         NaN
# 1225        1227  ...         NaN
# 1226        1228  ...         NaN
# 1227        1229  ...         NaN
# 1228        1230  ...         NaN
# 1229        1231  ...         NaN
# 1230        1232  ...         NaN
# 1231        1233  ...         NaN
# 1232        1234  ...         NaN
# 1233        1235  ...         NaN
# 1234        1236  ...         NaN
# 1235        1237  ...         NaN
# 1236        1238  ...         NaN
# 1237        1239  ...         NaN
# 1238        1240  ...         NaN
# 1239        1241  ...         NaN
# 1240        1242  ...         NaN
# 1241        1243  ...         NaN
# 1242        1244  ...         NaN
# 1243        1245  ...         NaN
# 1244        1246  ...         NaN
# 1245        1247  ...         NaN
# 1246        1248  ...         NaN
# 1247        1249  ...         NaN
# 1248        1250  ...         NaN
# 1249        1251  ...         NaN
# 1250        1252  ...         NaN
# 1251        1253  ...         NaN
# 1252        1254  ...         NaN
# 1253        1255  ...         NaN
# 1254        1256  ...         NaN
# 1255        1257  ...   -0.084806
# 1256        1259  ...         NaN
# 1257        1260  ...         NaN
# 1258        1261  ...         NaN
# 1259        1262  ...         NaN
# 1260        1263  ...         NaN
# 1261        1264  ...         NaN
# 1262        1265  ...         NaN
# 1263        1266  ...         NaN
# 1264        1267  ...         NaN
# 1265        1268  ...         NaN
# 1266        1269  ...         NaN
# 1267        1270  ...         NaN
# 1268        1271  ...         NaN
# 1269        1272  ...         NaN
# 1270        1273  ...         NaN
# 1271        1274  ...         NaN
# 1272        1275  ...         NaN
# 1273        1276  ...         NaN
# 1274        1277  ...         NaN
# 1275        1278  ...         NaN
# 1276        1279  ...         NaN
# 1277        1280  ...         NaN
# 1278        1281  ...         NaN
# 1279        1282  ...         NaN
# 1280        1283  ...         NaN
# 1281        1284  ...         NaN
# 1282        1285  ...         NaN
# 1283        1286  ...         NaN
# 1284        1287  ...         NaN
# 1285        1288  ...         NaN
# 1286        1289  ...         NaN
# 1287        1290  ...         NaN
# 1288        1291  ...         NaN
# 1289        1292  ...         NaN
# 1290        1293  ...         NaN
# 1291        1294  ...         NaN
# 1292        1295  ...         NaN
# 1293        1296  ...         NaN
# 1294        1297  ...         NaN
# 1295        1298  ...         NaN
# 1296        1299  ...         NaN
# 1297        1300  ...         NaN
# 1298        1301  ...         NaN
# 1299        1302  ...         NaN
# 1300        1303  ...         NaN
# 1301        1304  ...         NaN
# 1302        1305  ...         NaN
# 1303        1306  ...         NaN
# 1304        1307  ...         NaN
# 1305        1308  ...         NaN
# 1306        1309  ...         NaN
# 1307        1310  ...         NaN
# 1308        1311  ...         NaN
# 1309        1312  ...         NaN
# 1310        1313  ...         NaN
# 1311        1314  ...         NaN
# 1312        1315  ...         NaN
# 1313        1316  ...         NaN
# 1314        1317  ...         NaN
# 1315        1318  ...         NaN
# 1316        1319  ...         NaN
# 1317        1320  ...         NaN
# 1318        1321  ...         NaN
# 1319        1322  ...         NaN
# 1320        1323  ...         NaN
# 1321        1324  ...         NaN
# 1322        1325  ...         NaN
# 1323        1326  ...         NaN
# 1324        1327  ...         NaN
# 1325        1328  ...         NaN
# 1326        1329  ...         NaN
# 1327        1330  ...         NaN
# 1328        1331  ...         NaN
# 1329        1332  ...         NaN
# 1330        1333  ...         NaN
# 1331        1334  ...         NaN
# 1332        1335  ...         NaN
# 1333        1336  ...         NaN
# 1334        1337  ...         NaN
# 1335        1338  ...         NaN
# 1336        1339  ...         NaN
# 1337        1340  ...         NaN
# 1338        1341  ...         NaN
# 1339        1342  ...         NaN
# 1340        1343  ...         NaN
# 1341        1344  ...         NaN
# 1342        1345  ...         NaN
# 1343        1346  ...         NaN
# 1344        1347  ...         NaN
# 1345        1348  ...         NaN
# 1346        1349  ...         NaN
# 1347        1350  ...         NaN
# 1348        1351  ...         NaN
# 1349        1352  ...         NaN
# 1350        1353  ...         NaN
# 1351        1354  ...         NaN
# 1352        1355  ...         NaN
# 1353        1356  ...         NaN
# 1354        1357  ...         NaN
# 1355        1358  ...         NaN
# 1356        1359  ...         NaN
# 1357        1360  ...         NaN
# 1358        1361  ...         NaN
# 1359        1362  ...         NaN
# 1360        1363  ...         NaN
# 1361        1364  ...         NaN
# 1362        1365  ...         NaN
# 1363        1366  ...         NaN
# 1364        1367  ...         NaN
# 1365        1368  ...         NaN
# 1366        1369  ...         NaN
# 1367        1370  ...         NaN
# 1368        1371  ...         NaN
# 1369        1372  ...         NaN
# 1370        1373  ...         NaN
# 1371        1374  ...         NaN
# 1372        1375  ...         NaN
# 1373        1376  ...         NaN
# 1374        1377  ...         NaN
# 1375        1378  ...         NaN
# 1376        1379  ...         NaN
# 1377        1380  ...         NaN
# 1378        1381  ...         NaN
# 1379        1382  ...         NaN
# 1380        1383  ...         NaN
# 1381        1384  ...         NaN
# 1382        1385  ...         NaN
# 1383        1386  ...         NaN
# 1384        1387  ...         NaN
# 1385        1388  ...         NaN
# 1386        1389  ...         NaN
# 1387        1390  ...         NaN
# 1388        1391  ...         NaN
# 1389        1392  ...         NaN
# 1390        1393  ...         NaN
# 1391        1394  ...         NaN
# 1392        1395  ...         NaN
# 1393        1396  ...         NaN
# 1394        1397  ...         NaN
# 1395        1398  ...         NaN
# 1396        1399  ...         NaN
# 1397        1400  ...         NaN
# 1398        1401  ...         NaN
# 1399        1402  ...         NaN
# 1400        1403  ...         NaN
# 1401        1404  ...         NaN
# 1402        1405  ...         NaN
# 1403        1406  ...         NaN
# 1404        1407  ...         NaN
# 1405        1408  ...         NaN
# 1406        1409  ...         NaN
# 1407        1410  ...         NaN
# 1408        1411  ...         NaN
# 1409        1412  ...         NaN
# ...
# 1880        1883  ...         NaN
# 1881        1884  ...         NaN
# 1882        1885  ...         NaN
# 1883        1886  ...         NaN
# 1884        1887  ...         NaN
# 1885        1888  ...         NaN
# 1886        1889  ...         NaN
# 1887        1890  ...         NaN
# 1888        1891  ...         NaN
# 1889        1892  ...         NaN
# 1890        1893  ...         NaN
# 1891        1894  ...         NaN
# 1892        1895  ...         NaN
# 1893        1896  ...         NaN
# 1894        1897  ...         NaN
# 1895        1898  ...         NaN
# 1896        1899  ...         NaN
# 1897        1900  ...         NaN
# 1898        1901  ...         NaN
# 1899        1902  ...         NaN
# 1900        1903  ...         NaN
# 1901        1904  ...         NaN
# 1902        1905  ...         NaN
# 1903        1906  ...         NaN
# 1904        1907  ...         NaN
# 1905        1908  ...         NaN
# 1906        1909  ...         NaN
# 1907        1910  ...         NaN
# 1908        1911  ...         NaN
# 1909        1912  ...         NaN
# 1910        1913  ...         NaN
# 1911        1914  ...         NaN
# 1912        1915  ...         NaN
# 1913        1916  ...         NaN
# 1914        1917  ...         NaN
# 1915        1918  ...         NaN
# 1916        1919  ...         NaN
# 1917        1920  ...         NaN
# 1918        1921  ...         NaN
# 1919        1922  ...         NaN
# 1920        1923  ...         NaN
# 1921        1924  ...         NaN
# 1922        1925  ...         NaN
# 1923        1926  ...         NaN
# 1924        1927  ...         NaN
# 1925        1928  ...         NaN
# 1926        1929  ...         NaN
# 1927        1930  ...         NaN
# 1928        1931  ...         NaN
# 1929        1932  ...         NaN
# 1930        1933  ...         NaN
# 1931        1934  ...         NaN
# 1932        1935  ...         NaN
# 1933        1936  ...         NaN
# 1934        1937  ...         NaN
# 1935        1938  ...         NaN
# 1936        1939  ...         NaN
# 1937        1940  ...         NaN
# 1938        1941  ...         NaN
# 1939        1942  ...         NaN
# 1940        1943  ...         NaN
# 1941        1944  ...         NaN
# 1942        1945  ...         NaN
# 1943        1946  ...         NaN
# 1944        1947  ...         NaN
# 1945        1948  ...         NaN
# 1946        1949  ...         NaN
# 1947        1950  ...         NaN
# 1948        1951  ...         NaN
# 1949        1952  ...         NaN
# 1950        1953  ...         NaN
# 1951        1954  ...         NaN
# 1952        1955  ...         NaN
# 1953        1956  ...         NaN
# 1954        1957  ...         NaN
# 1955        1958  ...         NaN
# 1956        1959  ...         NaN
# 1957        1960  ...         NaN
# 1958        1961  ...         NaN
# 1959        1962  ...         NaN
# 1960        1963  ...         NaN
# 1961        1964  ...         NaN
# 1962        1965  ...         NaN
# 1963        1966  ...         NaN
# 1964        1967  ...         NaN
# 1965        1968  ...         NaN
# 1966        1969  ...         NaN
# 1967        1970  ...         NaN
# 1968        1971  ...         NaN
# 1969        1972  ...         NaN
# 1970        1973  ...         NaN
# 1971        1974  ...         NaN
# 1972        1975  ...         NaN
# 1973        1976  ...         NaN
# 1974        1977  ...         NaN
# 1975        1978  ...         NaN
# 1976        1979  ...         NaN
# 1977        1980  ...         NaN
# 1978        1981  ...         NaN
# 1979        1982  ...         NaN
# 1980        1983  ...         NaN
# 1981        1984  ...         NaN
# 1982        1985  ...         NaN
# 1983        1986  ...         NaN
# 1984        1987  ...         NaN
# 1985        1988  ...         NaN
# 1986        1989  ...         NaN
# 1987        1990  ...         NaN
# 1988        1991  ...         NaN
# 1989        1992  ...         NaN
# 1990        1993  ...         NaN
# 1991        1994  ...         NaN
# 1992        1995  ...         NaN
# 1993        1996  ...         NaN
# 1994        1997  ...         NaN
# 1995        1998  ...         NaN
# 1996        1999  ...         NaN
# 1997        2000  ...         NaN
# 1998        2001  ...         NaN
# 1999        2002  ...         NaN
# 2000        2003  ...         NaN
# 2001        2004  ...         NaN
# 2002        2005  ...         NaN
# 2003        2006  ...         NaN
# 2004        2007  ...         NaN
# 2005        2008  ...         NaN
# 2006        2009  ...         NaN
# 2007        2010  ...         NaN
# 2008        2011  ...         NaN
# 2009        2012  ...         NaN
# 2010        2013  ...         NaN
# 2011        2014  ...         NaN
# 2012        2015  ...         NaN
# 2013        2016  ...         NaN
# 2014        2017  ...         NaN
# 2015        2018  ...         NaN
# 2016        2019  ...         NaN
# 2017        2020  ...         NaN
# 2018        2021  ...         NaN
# 2019        2022  ...         NaN
# 2020        2023  ...         NaN
# 2021        2024  ...         NaN
# 2022        2025  ...         NaN
# 2023        2026  ...         NaN
# 2024        2027  ...         NaN
# 2025        2028  ...         NaN
# 2026        2029  ...         NaN
# 2027        2030  ...         NaN
# 2028        2031  ...         NaN
# 2029        2032  ...         NaN
# 2030        2033  ...         NaN
# 2031        2034  ...         NaN
# 2032        2035  ...         NaN
# 2033        2036  ...         NaN
# 2034        2037  ...         NaN
# 2035        2038  ...         NaN
# 2036        2039  ...         NaN
# 2037        2040  ...         NaN
# 2038        2041  ...         NaN
# 2039        2042  ...         NaN
# 2040        2043  ...         NaN
# 2041        2044  ...         NaN
# 2042        2045  ...         NaN
# 2043        2046  ...         NaN
# 2044        2047  ...         NaN
# 2045        2048  ...         NaN
# 2046        2049  ...         NaN
# 2047        2050  ...         NaN
# 2048        2051  ...         NaN
# 2049        2052  ...         NaN
# 2050        2053  ...         NaN
# 2051        2054  ...         NaN
# 2052        2055  ...         NaN
# 2053        2056  ...         NaN
# 2054        2057  ...         NaN
# 2055        2058  ...         NaN
# 2056        2059  ...         NaN
# 2057        2060  ...         NaN
# 2058        2061  ...         NaN
# 2059        2062  ...         NaN
# 2060        2063  ...         NaN
# 2061        2064  ...         NaN
# 2062        2065  ...         NaN
# 2063        2066  ...         NaN
# 2064        2067  ...         NaN
# 2065        2068  ...         NaN
# 2066        2069  ...         NaN
# 2067        2070  ...         NaN
# 2068        2071  ...         NaN
# 2069        2072  ...         NaN
# 2070        2073  ...         NaN
# 2071        2074  ...         NaN
# 2072        2075  ...         NaN
# 2073        2076  ...         NaN
# 2074        2077  ...         NaN
# 2075        2078  ...         NaN
# 2076        2079  ...         NaN
# 2077        2080  ...         NaN
# 2078        2081  ...         NaN
# 2079        2082  ...         NaN
# 2080        2083  ...         NaN
# 2081        2084  ...         NaN
# 2082        2085  ...         NaN
# 2083        2086  ...         NaN
# 2084        2087  ...         NaN
# 2085        2088  ...         NaN
# 2086        2089  ...         NaN
# 2087        2090  ...         NaN
# 2088        2091  ...         NaN
# 2089        2092  ...         NaN
# 2090        2093  ...         NaN
# 2091        2094  ...         NaN
# 2092        2095  ...         NaN
# 2093        2096  ...         NaN
# 2094        2097  ...         NaN
# 2095        2098  ...         NaN
# 2096        2099  ...         NaN
# 2097        2100  ...         NaN
# 2098        2101  ...         NaN
# 2099        2102  ...         NaN
# 2100        2103  ...         NaN
# 2101        2104  ...         NaN
# 2102        2106  ...         NaN
# 2103        2107  ...         NaN
# 2104        2108  ...         NaN
# 2105        2109  ...         NaN
# 2106        2110  ...         NaN
# 2107        2111  ...         NaN
# 2108        2112  ...         NaN
# 2109        2113  ...         NaN
# 2110        2114  ...         NaN
# 2111        2115  ...         NaN
# 2112        2116  ...         NaN
# 2113        2117  ...         NaN
# 2114        2118  ...         NaN
# 2115        2119  ...         NaN
# 2116        2120  ...         NaN
# 2117        2121  ...         NaN
# 2118        2122  ...         NaN
# 2119        2123  ...         NaN
# 2120        2124  ...         NaN
# 2121        2125  ...         NaN
# 2122        2126  ...         NaN
# 2123        2127  ...         NaN
# 2124        2128  ...         NaN
# 2125        2129  ...         NaN
# 2126        2130  ...         NaN
# 2127        2131  ...         NaN
# 2128        2132  ...         NaN
# 2129        2133  ...         NaN
# 2130        2134  ...         NaN
# 2131        2135  ...         NaN
# 2132        2136  ...         NaN
# 2133        2137  ...         NaN
# 2134        2138  ...         NaN
# 2135        2139  ...         NaN
# 2136        2140  ...         NaN
# 2137        2141  ...         NaN
# 2138        2142  ...         NaN
# 2139        2143  ...         NaN
# 2140        2144  ...         NaN
# 2141        2145  ...         NaN
# 2142        2146  ...         NaN
# 2143        2147  ...         NaN
# 2144        2148  ...         NaN
# 2145        2149  ...         NaN
# 2146        2150  ...         NaN
# 2147        2151  ...         NaN
# 2148        2152  ...         NaN
# 2149        2153  ...         NaN
# 2150        2154  ...         NaN
# 2151        2155  ...         NaN
# 2152        2156  ...         NaN
# 2153        2157  ...         NaN
# 2154        2158  ...         NaN
# 2155        2159  ...         NaN
# 2156        2160  ...         NaN
# 2157        2161  ...         NaN
# 2158        2162  ...         NaN
# 2159        2163  ...         NaN
# 2160        2164  ...         NaN
# 2161        2165  ...         NaN
# 2162        2166  ...         NaN
# 2163        2167  ...         NaN
# 2164        2168  ...         NaN
# 2165        2169  ...         NaN
# 2166        2170  ...         NaN
# 2167        2171  ...         NaN
# 2168        2172  ...         NaN
# 2169        2173  ...         NaN
# 2170        2174  ...         NaN
# 2171        2175  ...         NaN
# 2172        2176  ...         NaN
# 2173        2177  ...         NaN
# 2174        2178  ...         NaN
# 2175        2179  ...         NaN
# 2176        2180  ...         NaN
# 2177        2181  ...         NaN
# 2178        2182  ...         NaN
# 2179        2183  ...         NaN
# 2180        2184  ...         NaN
# 2181        2185  ...         NaN
# 2182        2186  ...         NaN
# 2183        2187  ...         NaN
# 2184        2188  ...         NaN
# 2185        2189  ...         NaN
# 2186        2190  ...         NaN
# 2187        2191  ...         NaN
# 2188        2192  ...         NaN
# 2189        2193  ...         NaN
# 2190        2194  ...         NaN
# 2191        2195  ...         NaN
# 2192        2196  ...         NaN
# 2193        2197  ...         NaN
# 2194        2198  ...         NaN
# 2195        2199  ...         NaN
# 2196        2200  ...         NaN
# 2197        2201  ...         NaN
# 2198        2202  ...         NaN
# 2199        2203  ...         NaN
# 2200        2204  ...         NaN
# 2201        2205  ...         NaN
# 2202        2206  ...         NaN
# 2203        2207  ...         NaN
# 2204        2208  ...         NaN
# 2205        2209  ...         NaN
# 2206        2210  ...         NaN
# 2207        2211  ...         NaN
# 2208        2212  ...         NaN
# 2209        2213  ...         NaN
# 2210        2214  ...         NaN
# 2211        2215  ...         NaN
# 2212        2216  ...         NaN
# 2213        2217  ...         NaN
# 2214        2218  ...         NaN
# 2215        2219  ...         NaN
# 2216        2220  ...         NaN
# 2217        2221  ...         NaN
# 2218        2222  ...         NaN
# 2219        2223  ...         NaN
# 2220        2224  ...         NaN
# 2221        2225  ...         NaN
# 2222        2226  ...         NaN
# 2223        2227  ...         NaN
# 2224        2228  ...         NaN
# 2225        2229  ...         NaN
# 2226        2230  ...         NaN
# 2227        2231  ...         NaN
# 2228        2232  ...         NaN
# 2229        2233  ...         NaN
# 2230        2234  ...         NaN
# 2231        2235  ...         NaN
# 2232        2236  ...         NaN
# 2233        2237  ...         NaN
# 2234        2238  ...         NaN
# 2235        2239  ...         NaN
# 2236        2240  ...         NaN
# 2237        2241  ...         NaN
# 2238        2242  ...         NaN
# 2239        2243  ...         NaN
# 2240        2244  ...         NaN
# 2241        2245  ...         NaN
# 2242        2246  ...         NaN
# 2243        2247  ...         NaN
# 2244        2248  ...         NaN
# 2245        2249  ...         NaN
# 2246        2250  ...         NaN
# 2247        2251  ...         NaN
# 2248        2252  ...         NaN
# 2249        2253  ...         NaN
# 2250        2254  ...         NaN
# 2251        2255  ...         NaN
# 2252        2256  ...         NaN
# 2253        2257  ...         NaN
# 2254        2258  ...         NaN
# 2255        2259  ...         NaN
# 2256        2260  ...         NaN
# 2257        2261  ...         NaN
# 2258        2262  ...         NaN
# 2259        2263  ...         NaN
# 2260        2264  ...         NaN
# 2261        2265  ...         NaN
# 2262        2266  ...         NaN
# 2263        2267  ...         NaN
# 2264        2268  ...         NaN
# 2265        2269  ...         NaN
# 2266        2270  ...         NaN
# 2267        2271  ...         NaN
# 2268        2272  ...         NaN
# 2269        2273  ...         NaN
# 2270        2274  ...         NaN
# 2271        2275  ...         NaN
# 2272        2276  ...         NaN
# 2273        2277  ...         NaN
# 2274        2278  ...         NaN
# 2275        2279  ...         NaN
# 2276        2280  ...         NaN
# 2277        2281  ...         NaN
# 2278        2282  ...         NaN
# 2279        2283  ...         NaN
# 2280        2284  ...         NaN
# 2281        2285  ...         NaN
# 2282        2286  ...         NaN
# 2283        2287  ...         NaN
# 2284        2288  ...         NaN
# 2285        2289  ...         NaN
# 2286        2290  ...         NaN
# 2287        2291  ...         NaN
# 2288        2292  ...         NaN
# 2289        2293  ...         NaN
# 2290        2294  ...         NaN
# 2291        2295  ...         NaN
# 2292        2296  ...         NaN
# 2293        2297  ...         NaN
# 2294        2298  ...         NaN
# 2295        2299  ...         NaN
# 2296        2300  ...         NaN
# 2297        2301  ...         NaN
# 2298        2302  ...         NaN
# 2299        2303  ...         NaN
# 2300        2304  ...         NaN
# 2301        2305  ...         NaN
# 2302        2306  ...         NaN
# 2303        2307  ...         NaN
# 2304        2308  ...         NaN
# 2305        2309  ...         NaN
# 2306        2310  ...         NaN
# 2307        2311  ...         NaN
# 2308        2312  ...         NaN
# 2309        2313  ...         NaN
# 2310        2314  ...         NaN
# 2311        2315  ...         NaN
# 2312        2316  ...         NaN
# 2313        2317  ...         NaN
# 2314        2318  ...         NaN
# 2315        2319  ...         NaN
# 2316        2320  ...         NaN
# 2317        2321  ...         NaN
# 2318        2322  ...         NaN
# 2319        2323  ...         NaN
# 2320        2324  ...         NaN
# 2321        2325  ...         NaN
# 2322        2326  ...         NaN
# 2323        2327  ...         NaN
# 2324        2328  ...         NaN
# 2325        2329  ...         NaN
# 2326        2330  ...         NaN
# 2327        2331  ...         NaN
# 2328        2332  ...         NaN
# 2329        2333  ...         NaN
# 2330        2334  ...         NaN
# 2331        2335  ...         NaN
# 2332        2336  ...         NaN
# 2333        2337  ...         NaN
# 2334        2338  ...         NaN
# 2335        2339  ...         NaN
# 2336        2340  ...         NaN
# 2337        2341  ...         NaN
# 2338        2342  ...         NaN
# 2339        2343  ...         NaN
# 2340        2344  ...         NaN
# 2341        2345  ...         NaN
# 2342        2346  ...         NaN
# 2343        2347  ...         NaN
# 2344        2348  ...         NaN
# 2345        2349  ...         NaN
# 2346        2350  ...         NaN
# 2347        2351  ...         NaN
# 2348        2352  ...         NaN
#
# [2349 rows x 14 columns]

# %%
ct_mapping
# Out:
#       Unnamed: 0  ... Unnamed: 13
# 0              0  ...         NaN
# 1              1  ...         NaN
# 2              2  ...         NaN
# 3              3  ...         NaN
# 4              4  ...         NaN
# 5              5  ...         NaN
# 6              6  ...         NaN
# 7              7  ...         NaN
# 8              8  ...         NaN
# 9              9  ...         NaN
# 10            10  ...         NaN
# 11            11  ...         NaN
# 12            12  ...         NaN
# 13            13  ...         NaN
# 14            14  ...         NaN
# 15            15  ...         NaN
# 16            16  ...         NaN
# 17            17  ...         NaN
# 18            18  ...         NaN
# 19            19  ...         NaN
# 20            20  ...         NaN
# 21            21  ...         NaN
# 22            22  ...         NaN
# 23            23  ...         NaN
# 24            24  ...         NaN
# 25            25  ...         NaN
# 26            26  ...         NaN
# 27            27  ...         NaN
# 28            28  ...         NaN
# 29            29  ...         NaN
# 30            30  ...         NaN
# 31            31  ...         NaN
# 32            32  ...         NaN
# 33            33  ...         NaN
# 34            34  ...         NaN
# 35            35  ...         NaN
# 36            36  ...         NaN
# 37            37  ...         NaN
# 38            38  ...         NaN
# 39            39  ...         NaN
# 40            40  ...         NaN
# 41            41  ...         NaN
# 42            42  ...         NaN
# 43            43  ...         NaN
# 44            44  ...         NaN
# 45            45  ...         NaN
# 46            46  ...         NaN
# 47            47  ...         NaN
# 48            48  ...         NaN
# 49            49  ...         NaN
# 50            50  ...         NaN
# 51            51  ...         NaN
# 52            52  ...         NaN
# 53            53  ...         NaN
# 54            54  ...         NaN
# 55            55  ...         NaN
# 56            56  ...         NaN
# 57            57  ...         NaN
# 58            58  ...         NaN
# 59            59  ...         NaN
# 60            60  ...         NaN
# 61            61  ...         NaN
# 62            62  ...         NaN
# 63            63  ...         NaN
# 64            64  ...         NaN
# 65            65  ...         NaN
# 66            66  ...         NaN
# 67            67  ...         NaN
# 68            68  ...         NaN
# 69            69  ...         NaN
# 70            70  ...         NaN
# 71            71  ...         NaN
# 72            72  ...         NaN
# 73            73  ...         NaN
# 74            74  ...         NaN
# 75            75  ...         NaN
# 76            76  ...         NaN
# 77            77  ...         NaN
# 78            78  ...         NaN
# 79            79  ...         NaN
# 80            80  ...         NaN
# 81            81  ...         NaN
# 82            82  ...         NaN
# 83            83  ...         NaN
# 84            84  ...         NaN
# 85            85  ...         NaN
# 86            86  ...         NaN
# 87            87  ...         NaN
# 88            88  ...         NaN
# 89            89  ...         NaN
# 90            90  ...         NaN
# 91            91  ...         NaN
# 92            92  ...         NaN
# 93            93  ...         NaN
# 94            94  ...         NaN
# 95            95  ...         NaN
# 96            96  ...         NaN
# 97            97  ...         NaN
# 98            98  ...         NaN
# 99            99  ...         NaN
# 100          100  ...         NaN
# 101          101  ...         NaN
# 102          102  ...         NaN
# 103          103  ...         NaN
# 104          104  ...         NaN
# 105          105  ...         NaN
# 106          106  ...         NaN
# 107          107  ...         NaN
# 108          108  ...         NaN
# 109          109  ...         NaN
# 110          110  ...         NaN
# 111          111  ...         NaN
# 112          112  ...         NaN
# 113          113  ...         NaN
# 114          114  ...         NaN
# 115          115  ...         NaN
# 116          116  ...         NaN
# 117          117  ...         NaN
# 118          118  ...         NaN
# 119          119  ...         NaN
# 120          120  ...         NaN
# 121          121  ...         NaN
# 122          122  ...         NaN
# 123          123  ...         NaN
# 124          124  ...         NaN
# 125          125  ...         NaN
# 126          126  ...         NaN
# 127          127  ...         NaN
# 128          128  ...         NaN
# 129          129  ...         NaN
# 130          130  ...         NaN
# 131          131  ...         NaN
# 132          132  ...         NaN
# 133          133  ...         NaN
# 134          134  ...         NaN
# 135          135  ...         NaN
# 136          136  ...         NaN
# 137          137  ...         NaN
# 138          138  ...         NaN
# 139          139  ...         NaN
# 140          140  ...         NaN
# 141          141  ...         NaN
# 142          142  ...         NaN
# 143          143  ...         NaN
# 144          144  ...         NaN
# 145          145  ...         NaN
# 146          146  ...         NaN
# 147          147  ...         NaN
# 148          148  ...         NaN
# 149          149  ...         NaN
# 150          150  ...         NaN
# 151          151  ...         NaN
# 152          152  ...         NaN
# 153          153  ...         NaN
# 154          154  ...         NaN
# 155          155  ...         NaN
# 156          156  ...         NaN
# 157          157  ...         NaN
# 158          158  ...         NaN
# 159          159  ...         NaN
# 160          160  ...         NaN
# 161          161  ...         NaN
# 162          162  ...         NaN
# 163          163  ...         NaN
# 164          164  ...         NaN
# 165          165  ...         NaN
# 166          166  ...         NaN
# 167          167  ...         NaN
# 168          168  ...         NaN
# 169          169  ...         NaN
# 170          170  ...         NaN
# 171          171  ...         NaN
# 172          172  ...         NaN
# 173          173  ...         NaN
# 174          174  ...         NaN
# 175          175  ...         NaN
# 176          176  ...         NaN
# 177          177  ...         NaN
# 178          178  ...         NaN
# 179          179  ...         NaN
# 180          180  ...         NaN
# 181          181  ...         NaN
# 182          182  ...         NaN
# 183          183  ...         NaN
# 184          184  ...         NaN
# 185          185  ...         NaN
# 186          186  ...         NaN
# 187          187  ...         NaN
# 188          188  ...         NaN
# 189          189  ...         NaN
# 190          190  ...         NaN
# 191          191  ...         NaN
# 192          192  ...         NaN
# 193          193  ...         NaN
# 194          194  ...         NaN
# 195          195  ...         NaN
# 196          196  ...         NaN
# 197          197  ...         NaN
# 198          198  ...         NaN
# 199          199  ...         NaN
# 200          200  ...         NaN
# 201          201  ...         NaN
# 202          202  ...         NaN
# 203          203  ...         NaN
# 204          204  ...         NaN
# 205          205  ...         NaN
# 206          206  ...         NaN
# 207          207  ...         NaN
# 208          208  ...         NaN
# 209          209  ...         NaN
# 210          210  ...         NaN
# 211          211  ...         NaN
# 212          212  ...         NaN
# 213          213  ...         NaN
# 214          214  ...         NaN
# 215          215  ...         NaN
# 216          216  ...         NaN
# 217          217  ...         NaN
# 218          218  ...         NaN
# 219          219  ...         NaN
# 220          220  ...         NaN
# 221          221  ...         NaN
# 222          222  ...         NaN
# 223          223  ...         NaN
# 224          224  ...         NaN
# 225          225  ...         NaN
# 226          226  ...         NaN
# 227          227  ...         NaN
# 228          228  ...         NaN
# 229          229  ...         NaN
# 230          230  ...         NaN
# 231          231  ...         NaN
# 232          232  ...         NaN
# 233          233  ...         NaN
# 234          234  ...         NaN
# 235          235  ...         NaN
# 236          236  ...         NaN
# 237          237  ...         NaN
# 238          238  ...         NaN
# 239          239  ...         NaN
# 240          240  ...         NaN
# 241          241  ...         NaN
# 242          242  ...         NaN
# 243          243  ...         NaN
# 244          244  ...         NaN
# 245          245  ...         NaN
# 246          246  ...         NaN
# 247          247  ...         NaN
# 248          248  ...         NaN
# 249          249  ...         NaN
# 250          250  ...         NaN
# 251          251  ...         NaN
# 252          252  ...         NaN
# 253          253  ...         NaN
# 254          254  ...         NaN
# 255          255  ...         NaN
# 256          256  ...         NaN
# 257          257  ...         NaN
# 258          258  ...         NaN
# 259          259  ...         NaN
# 260          260  ...         NaN
# 261          261  ...         NaN
# 262          262  ...         NaN
# 263          263  ...         NaN
# 264          264  ...         NaN
# 265          265  ...         NaN
# 266          266  ...         NaN
# 267          267  ...         NaN
# 268          268  ...         NaN
# 269          269  ...         NaN
# 270          270  ...         NaN
# 271          271  ...         NaN
# 272          272  ...         NaN
# 273          273  ...         NaN
# 274          274  ...         NaN
# 275          275  ...         NaN
# 276          276  ...         NaN
# 277          277  ...         NaN
# 278          278  ...         NaN
# 279          279  ...         NaN
# 280          280  ...         NaN
# 281          281  ...         NaN
# 282          282  ...         NaN
# 283          283  ...         NaN
# 284          284  ...         NaN
# 285          285  ...         NaN
# 286          286  ...         NaN
# 287          287  ...         NaN
# 288          288  ...         NaN
# 289          289  ...         NaN
# 290          290  ...         NaN
# 291          291  ...         NaN
# 292          292  ...         NaN
# 293          293  ...         NaN
# 294          294  ...         NaN
# 295          295  ...         NaN
# 296          296  ...         NaN
# 297          297  ...         NaN
# 298          298  ...         NaN
# 299          299  ...         NaN
# 300          300  ...         NaN
# 301          301  ...         NaN
# 302          302  ...         NaN
# 303          303  ...         NaN
# 304          304  ...         NaN
# 305          305  ...         NaN
# 306          306  ...         NaN
# 307          307  ...         NaN
# 308          308  ...         NaN
# 309          309  ...         NaN
# 310          310  ...         NaN
# 311          311  ...         NaN
# 312          312  ...         NaN
# 313          313  ...         NaN
# 314          314  ...         NaN
# 315          315  ...         NaN
# 316          316  ...         NaN
# 317          317  ...         NaN
# 318          318  ...         NaN
# 319          319  ...         NaN
# 320          320  ...         NaN
# 321          321  ...         NaN
# 322          322  ...         NaN
# 323          323  ...         NaN
# 324          324  ...         NaN
# 325          325  ...         NaN
# 326          326  ...         NaN
# 327          327  ...         NaN
# 328          328  ...         NaN
# 329          329  ...         NaN
# 330          330  ...         NaN
# 331          331  ...         NaN
# 332          332  ...         NaN
# 333          333  ...         NaN
# 334          334  ...         NaN
# 335          335  ...         NaN
# 336          336  ...         NaN
# 337          337  ...         NaN
# 338          338  ...         NaN
# 339          339  ...         NaN
# 340          340  ...         NaN
# 341          341  ...         NaN
# 342          342  ...         NaN
# 343          343  ...         NaN
# 344          344  ...         NaN
# 345          345  ...         NaN
# 346          346  ...         NaN
# 347          347  ...         NaN
# 348          348  ...         NaN
# 349          349  ...         NaN
# 350          350  ...         NaN
# 351          351  ...         NaN
# 352          352  ...         NaN
# 353          353  ...         NaN
# 354          354  ...         NaN
# 355          355  ...         NaN
# 356          356  ...         NaN
# 357          357  ...         NaN
# 358          358  ...         NaN
# 359          359  ...         NaN
# 360          360  ...         NaN
# 361          361  ...         NaN
# 362          362  ...         NaN
# 363          363  ...         NaN
# 364          364  ...         NaN
# 365          365  ...         NaN
# 366          366  ...         NaN
# 367          367  ...         NaN
# 368          368  ...         NaN
# 369          369  ...         NaN
# 370          370  ...         NaN
# 371          371  ...         NaN
# 372          372  ...         NaN
# 373          373  ...         NaN
# 374          374  ...         NaN
# 375          375  ...         NaN
# 376          376  ...         NaN
# 377          377  ...         NaN
# 378          378  ...         NaN
# 379          379  ...         NaN
# 380          380  ...         NaN
# 381          381  ...         NaN
# 382          382  ...         NaN
# 383          383  ...         NaN
# 384          384  ...         NaN
# 385          385  ...         NaN
# 386          386  ...         NaN
# 387          387  ...         NaN
# 388          388  ...         NaN
# 389          389  ...         NaN
# 390          390  ...         NaN
# 391          391  ...         NaN
# 392          392  ...         NaN
# 393          393  ...         NaN
# 394          394  ...         NaN
# 395          395  ...         NaN
# 396          396  ...         NaN
# 397          397  ...         NaN
# 398          398  ...         NaN
# 399          399  ...         NaN
# 400          400  ...         NaN
# 401          401  ...         NaN
# 402          402  ...         NaN
# 403          403  ...         NaN
# 404          404  ...         NaN
# 405          405  ...         NaN
# 406          406  ...         NaN
# 407          407  ...         NaN
# 408          408  ...         NaN
# 409          409  ...         NaN
# 410          410  ...         NaN
# 411          411  ...         NaN
# 412          412  ...         NaN
# 413          413  ...         NaN
# 414          414  ...         NaN
# 415          415  ...         NaN
# 416          416  ...         NaN
# 417          417  ...         NaN
# 418          418  ...         NaN
# 419          419  ...         NaN
# 420          420  ...         NaN
# 421          421  ...         NaN
# 422          422  ...         NaN
# 423          423  ...         NaN
# 424          424  ...         NaN
# 425          425  ...         NaN
# 426          426  ...         NaN
# 427          427  ...         NaN
# 428          428  ...         NaN
# 429          429  ...         NaN
# 430          430  ...         NaN
# 431          431  ...         NaN
# 432          432  ...         NaN
# 433          433  ...         NaN
# 434          434  ...         NaN
# 435          435  ...         NaN
# 436          436  ...         NaN
# 437          437  ...         NaN
# 438          438  ...         NaN
# 439          439  ...         NaN
# 440          440  ...         NaN
# 441          441  ...         NaN
# 442          442  ...         NaN
# 443          443  ...         NaN
# 444          444  ...         NaN
# 445          445  ...         NaN
# 446          446  ...         NaN
# 447          447  ...         NaN
# 448          448  ...         NaN
# 449          449  ...         NaN
# 450          450  ...         NaN
# 451          451  ...         NaN
# 452          452  ...         NaN
# 453          453  ...         NaN
# 454          454  ...         NaN
# 455          455  ...         NaN
# 456          456  ...         NaN
# 457          457  ...         NaN
# 458          458  ...         NaN
# 459          459  ...         NaN
# 460          460  ...         NaN
# 461          461  ...         NaN
# 462          462  ...         NaN
# 463          463  ...         NaN
# 464          464  ...         NaN
# 465          465  ...         NaN
# 466          466  ...         NaN
# 467          467  ...         NaN
# 468          468  ...         NaN
# 469          469  ...         NaN
# 470          470  ...         NaN
# 471          471  ...         NaN
# 472          472  ...         NaN
# 473          473  ...         NaN
# 474          474  ...         NaN
# 475          475  ...         NaN
# 476          476  ...         NaN
# 477          477  ...         NaN
# 478          478  ...         NaN
# 479          479  ...         NaN
# 480          480  ...         NaN
# 481          481  ...         NaN
# 482          482  ...         NaN
# 483          483  ...         NaN
# 484          484  ...         NaN
# 485          485  ...         NaN
# 486          486  ...         NaN
# 487          487  ...         NaN
# 488          488  ...         NaN
# 489          489  ...         NaN
# 490          490  ...         NaN
# 491          491  ...         NaN
# 492          492  ...         NaN
# 493          493  ...         NaN
# 494          494  ...         NaN
# 495          495  ...         NaN
# 496          496  ...         NaN
# 497          497  ...         NaN
# 498          498  ...         NaN
# 499          499  ...         NaN
# 500          500  ...         NaN
# 501          501  ...         NaN
# 502          502  ...         NaN
# 503          503  ...         NaN
# 504          504  ...         NaN
# 505          505  ...         NaN
# 506          506  ...         NaN
# 507          507  ...         NaN
# 508          508  ...         NaN
# 509          509  ...         NaN
# 510          510  ...         NaN
# 511          511  ...         NaN
# 512          512  ...         NaN
# 513          513  ...         NaN
# 514          514  ...         NaN
# 515          515  ...         NaN
# 516          516  ...         NaN
# 517          517  ...         NaN
# 518          518  ...         NaN
# 519          519  ...         NaN
# 520          520  ...         NaN
# 521          521  ...         NaN
# 522          522  ...         NaN
# 523          523  ...         NaN
# 524          524  ...         NaN
# 525          525  ...         NaN
# 526          526  ...         NaN
# 527          527  ...         NaN
# 528          528  ...         NaN
# 529          529  ...         NaN
# 530          530  ...         NaN
# 531          531  ...         NaN
# 532          532  ...         NaN
# 533          533  ...         NaN
# 534          534  ...         NaN
# 535          535  ...         NaN
# 536          536  ...         NaN
# 537          537  ...         NaN
# 538          538  ...         NaN
# 539          539  ...         NaN
# 540          540  ...         NaN
# 541          541  ...         NaN
# 542          542  ...         NaN
# 543          543  ...         NaN
# 544          544  ...         NaN
# 545          545  ...         NaN
# 546          546  ...         NaN
# 547          547  ...         NaN
# 548          548  ...         NaN
# 549          549  ...         NaN
# 550          550  ...         NaN
# 551          551  ...         NaN
# 552          552  ...         NaN
# 553          553  ...         NaN
# 554          554  ...         NaN
# 555          555  ...         NaN
# 556          556  ...         NaN
# 557          557  ...         NaN
# 558          558  ...         NaN
# 559          559  ...         NaN
# 560          560  ...         NaN
# 561          561  ...         NaN
# 562          562  ...         NaN
# 563          563  ...         NaN
# 564          564  ...         NaN
# 565          565  ...         NaN
# 566          566  ...         NaN
# 567          567  ...         NaN
# 568          568  ...         NaN
# 569          569  ...         NaN
# 570          570  ...         NaN
# 571          571  ...         NaN
# 572          572  ...         NaN
# 573          573  ...         NaN
# 574          574  ...         NaN
# 575          575  ...         NaN
# 576          576  ...         NaN
# 577          577  ...         NaN
# 578          578  ...         NaN
# 579          579  ...         NaN
# 580          580  ...         NaN
# 581          581  ...         NaN
# 582          582  ...         NaN
# 583          583  ...         NaN
# 584          584  ...         NaN
# 585          585  ...         NaN
# 586          586  ...         NaN
# 587          587  ...         NaN
# 588          588  ...         NaN
# 589          589  ...         NaN
# 590          590  ...         NaN
# 591          591  ...         NaN
# 592          592  ...         NaN
# 593          593  ...         NaN
# 594          594  ...         NaN
# 595          595  ...         NaN
# 596          596  ...         NaN
# 597          597  ...         NaN
# 598          598  ...         NaN
# 599          599  ...         NaN
# 600          600  ...         NaN
# 601          601  ...         NaN
# 602          602  ...         NaN
# 603          603  ...         NaN
# 604          604  ...         NaN
# 605          605  ...         NaN
# 606          606  ...         NaN
# 607          607  ...         NaN
# 608          608  ...         NaN
# 609          609  ...         NaN
# 610          610  ...         NaN
# 611          611  ...         NaN
# 612          612  ...         NaN
# 613          613  ...         NaN
# 614          614  ...         NaN
# 615          615  ...         NaN
# 616          616  ...         NaN
# 617          617  ...         NaN
# 618          618  ...         NaN
# 619          619  ...         NaN
# 620          620  ...         NaN
# 621          621  ...         NaN
# 622          622  ...         NaN
# 623          623  ...         NaN
# 624          624  ...         NaN
# 625          625  ...         NaN
# 626          626  ...         NaN
# 627          627  ...         NaN
# 628          628  ...         NaN
# 629          629  ...         NaN
# 630          630  ...         NaN
# 631          631  ...         NaN
# 632          632  ...         NaN
# 633          633  ...         NaN
# 634          634  ...         NaN
# 635          635  ...         NaN
# 636          636  ...         NaN
# 637          637  ...         NaN
# 638          638  ...         NaN
# 639          639  ...         NaN
# 640          640  ...         NaN
# 641          641  ...         NaN
# 642          642  ...         NaN
# 643          643  ...         NaN
# 644          644  ...         NaN
# 645          645  ...         NaN
# 646          646  ...         NaN
# 647          647  ...         NaN
# 648          648  ...         NaN
# 649          649  ...         NaN
# 650          650  ...         NaN
# 651          651  ...         NaN
# 652          652  ...         NaN
# 653          653  ...         NaN
# 654          654  ...         NaN
# 655          655  ...         NaN
# 656          656  ...         NaN
# 657          657  ...         NaN
# 658          658  ...         NaN
# 659          659  ...         NaN
# 660          660  ...         NaN
# 661          661  ...         NaN
# 662          662  ...         NaN
# 663          663  ...         NaN
# 664          664  ...         NaN
# 665          665  ...         NaN
# 666          666  ...         NaN
# 667          667  ...         NaN
# 668          668  ...         NaN
# 669          669  ...         NaN
# 670          670  ...         NaN
# 671          671  ...         NaN
# 672          672  ...         NaN
# 673          673  ...         NaN
# 674          674  ...         NaN
# 675          675  ...         NaN
# 676          676  ...         NaN
# 677          677  ...         NaN
# 678          678  ...         NaN
# 679          679  ...         NaN
# 680          680  ...         NaN
# 681          681  ...         NaN
# 682          682  ...         NaN
# 683          683  ...         NaN
# 684          684  ...         NaN
# 685          685  ...         NaN
# 686          686  ...         NaN
# 687          687  ...         NaN
# 688          688  ...         NaN
# 689          689  ...         NaN
# 690          690  ...         NaN
# 691          691  ...         NaN
# 692          692  ...         NaN
# 693          693  ...         NaN
# 694          694  ...         NaN
# 695          695  ...         NaN
# 696          696  ...         NaN
# 697          697  ...         NaN
# 698          698  ...         NaN
# 699          699  ...         NaN
# 700          700  ...         NaN
# 701          701  ...         NaN
# 702          702  ...         NaN
# 703          703  ...         NaN
# 704          704  ...         NaN
# 705          705  ...         NaN
# 706          706  ...         NaN
# 707          707  ...         NaN
# 708          708  ...         NaN
# 709          709  ...         NaN
# 710          710  ...         NaN
# 711          711  ...         NaN
# 712          712  ...         NaN
# 713          713  ...         NaN
# 714          714  ...         NaN
# 715          715  ...         NaN
# 716          716  ...         NaN
# 717          717  ...         NaN
# 718          718  ...         NaN
# 719          719  ...         NaN
# 720          720  ...         NaN
# 721          721  ...         NaN
# 722          722  ...         NaN
# 723          723  ...         NaN
# 724          724  ...         NaN
# 725          725  ...         NaN
# 726          726  ...         NaN
# 727          727  ...         NaN
# 728          728  ...         NaN
# 729          729  ...         NaN
# 730          730  ...         NaN
# 731          731  ...         NaN
# 732          732  ...         NaN
# 733          733  ...         NaN
# 734          734  ...         NaN
# 735          735  ...         NaN
# 736          736  ...         NaN
# 737          737  ...         NaN
# 738          738  ...         NaN
# 739          739  ...         NaN
# 740          740  ...         NaN
# 741          741  ...         NaN
# 742          742  ...         NaN
# 743          743  ...         NaN
# 744          744  ...         NaN
# 745          745  ...         NaN
# 746          746  ...         NaN
# 747          747  ...         NaN
# 748          748  ...         NaN
# 749          749  ...         NaN
# 750          750  ...         NaN
# 751          751  ...         NaN
# 752          752  ...         NaN
# 753          753  ...         NaN
# 754          754  ...         NaN
# 755          755  ...         NaN
# 756          756  ...         NaN
# 757          757  ...         NaN
# 758          758  ...         NaN
# 759          759  ...         NaN
# 760          760  ...         NaN
# 761          761  ...         NaN
# 762          762  ...         NaN
# 763          763  ...         NaN
# 764          764  ...         NaN
# 765          765  ...         NaN
# 766          766  ...         NaN
# 767          767  ...         NaN
# 768          768  ...         NaN
# 769          769  ...         NaN
# 770          770  ...         NaN
# 771          771  ...         NaN
# 772          772  ...         NaN
# 773          773  ...         NaN
# 774          774  ...         NaN
# 775          775  ...         NaN
# 776          776  ...         NaN
# 777          777  ...         NaN
# 778          778  ...         NaN
# 779          779  ...         NaN
# 780          780  ...         NaN
# 781          781  ...         NaN
# 782          782  ...         NaN
# 783          783  ...         NaN
# 784          784  ...         NaN
# 785          785  ...         NaN
# 786          786  ...         NaN
# 787          787  ...         NaN
# 788          788  ...         NaN
# 789          789  ...         NaN
# 790          790  ...         NaN
# 791          791  ...         NaN
# 792          792  ...         NaN
# 793          793  ...         NaN
# 794          794  ...         NaN
# 795          795  ...         NaN
# 796          796  ...         NaN
# 797          797  ...         NaN
# 798          798  ...         NaN
# 799          799  ...         NaN
# 800          800  ...         NaN
# 801          801  ...         NaN
# 802          802  ...         NaN
# 803          803  ...         NaN
# 804          804  ...         NaN
# 805          805  ...         NaN
# 806          806  ...         NaN
# 807          807  ...         NaN
# 808          808  ...         NaN
# 809          809  ...         NaN
# 810          810  ...         NaN
# 811          811  ...         NaN
# 812          812  ...         NaN
# 813          813  ...         NaN
# 814          814  ...         NaN
# 815          815  ...         NaN
# 816          816  ...         NaN
# 817          817  ...         NaN
# 818          818  ...         NaN
# 819          819  ...         NaN
# 820          820  ...         NaN
# 821          821  ...         NaN
# 822          822  ...         NaN
# 823          823  ...         NaN
# 824          824  ...         NaN
# 825          825  ...         NaN
# 826          826  ...         NaN
# 827          827  ...         NaN
# 828          828  ...         NaN
# 829          829  ...         NaN
# 830          830  ...         NaN
# 831          831  ...         NaN
# 832          832  ...         NaN
# 833          833  ...         NaN
# 834          834  ...         NaN
# 835          835  ...         NaN
# 836          836  ...         NaN
# 837          837  ...         NaN
# 838          838  ...         NaN
# 839          839  ...         NaN
# 840          840  ...         NaN
# 841          841  ...         NaN
# 842          842  ...         NaN
# 843          843  ...         NaN
# 844          844  ...         NaN
# 845          845  ...         NaN
# 846          846  ...         NaN
# 847          847  ...         NaN
# 848          848  ...         NaN
# 849          849  ...         NaN
# 850          850  ...         NaN
# 851          851  ...         NaN
# 852          852  ...         NaN
# 853          853  ...         NaN
# 854          854  ...         NaN
# 855          855  ...         NaN
# 856          856  ...         NaN
# 857          857  ...         NaN
# 858          858  ...         NaN
# 859          859  ...         NaN
# 860          860  ...         NaN
# 861          861  ...         NaN
# 862          862  ...         NaN
# 863          863  ...         NaN
# 864          864  ...         NaN
# 865          865  ...         NaN
# 866          866  ...         NaN
# 867          867  ...         NaN
# 868          868  ...         NaN
# 869          869  ...         NaN
# 870          870  ...         NaN
# 871          871  ...         NaN
# 872          872  ...         NaN
# 873          873  ...         NaN
# 874          874  ...         NaN
# 875          875  ...         NaN
# 876          876  ...         NaN
# 877          877  ...         NaN
# 878          878  ...         NaN
# 879          879  ...         NaN
# 880          880  ...         NaN
# 881          881  ...         NaN
# 882          882  ...         NaN
# 883          883  ...         NaN
# 884          884  ...         NaN
# 885          885  ...         NaN
# 886          886  ...         NaN
# 887          887  ...         NaN
# 888          888  ...         NaN
# 889          889  ...         NaN
# 890          890  ...         NaN
# 891          891  ...         NaN
# 892          892  ...         NaN
# 893          893  ...         NaN
# 894          894  ...         NaN
# 895          895  ...         NaN
# 896          896  ...         NaN
# 897          897  ...         NaN
# 898          898  ...         NaN
# 899          899  ...         NaN
# 900          900  ...         NaN
# 901          901  ...         NaN
# 902          902  ...         NaN
# 903          903  ...         NaN
# 904          904  ...         NaN
# 905          905  ...         NaN
# 906          906  ...         NaN
# 907          907  ...         NaN
# 908          908  ...         NaN
# 909          909  ...         NaN
# 910          910  ...         NaN
# 911          911  ...         NaN
# 912          912  ...         NaN
# 913          913  ...         NaN
# 914          914  ...         NaN
# 915          915  ...         NaN
# 916          916  ...         NaN
# 917          917  ...         NaN
# 918          918  ...         NaN
# 919          919  ...         NaN
# 920          920  ...         NaN
# 921          921  ...         NaN
# 922          922  ...         NaN
# 923          923  ...         NaN
# 924          924  ...         NaN
# 925          925  ...         NaN
# 926          926  ...         NaN
# 927          927  ...         NaN
# 928          928  ...         NaN
# 929          929  ...         NaN
# 930          930  ...         NaN
# 931          931  ...         NaN
# 932          932  ...         NaN
# 933          933  ...         NaN
# 934          934  ...         NaN
# 935          935  ...         NaN
# 936          936  ...         NaN
# 937          937  ...         NaN
# 938          938  ...         NaN
# 939          939  ...         NaN
# 940          940  ...         NaN
# 941          941  ...         NaN
# 942          942  ...         NaN
# 943          943  ...         NaN
# 944          944  ...         NaN
# 945          945  ...         NaN
# 946          946  ...         NaN
# 947          947  ...         NaN
# 948          948  ...         NaN
# 949          949  ...         NaN
# 950          950  ...         NaN
# 951          951  ...         NaN
# 952          952  ...         NaN
# 953          953  ...         NaN
# 954          954  ...         NaN
# 955          955  ...         NaN
# 956          956  ...         NaN
# 957          957  ...         NaN
# 958          958  ...         NaN
# 959          959  ...         NaN
# 960          960  ...         NaN
# 961          961  ...         NaN
# 962          962  ...         NaN
# 963          963  ...         NaN
# 964          964  ...         NaN
# 965          965  ...         NaN
# 966          966  ...         NaN
# 967          967  ...         NaN
# 968          968  ...         NaN
# 969          969  ...         NaN
# 970          970  ...         NaN
# 971          971  ...         NaN
# 972          972  ...         NaN
# 973          973  ...         NaN
# 974          974  ...         NaN
# 975          975  ...         NaN
# 976          976  ...         NaN
# 977          977  ...         NaN
# 978          978  ...         NaN
# 979          979  ...         NaN
# 980          980  ...         NaN
# 981          981  ...         NaN
# 982          982  ...         NaN
# 983          983  ...         NaN
# 984          984  ...         NaN
# 985          985  ...         NaN
# 986          986  ...         NaN
# 987          987  ...         NaN
# 988          988  ...         NaN
# 989          989  ...         NaN
# 990          990  ...         NaN
# 991          991  ...         NaN
# 992          992  ...         NaN
# 993          993  ...         NaN
# 994          994  ...         NaN
# 995          995  ...         NaN
# 996          996  ...         NaN
# 997          997  ...         NaN
# 998          998  ...         NaN
# 999          999  ...         NaN
# 1000        1000  ...         NaN
# 1001        1001  ...         NaN
# 1002        1002  ...         NaN
# 1003        1003  ...         NaN
# 1004        1004  ...         NaN
# 1005        1005  ...         NaN
# 1006        1006  ...         NaN
# 1007        1007  ...         NaN
# 1008        1008  ...         NaN
# 1009        1009  ...         NaN
# 1010        1010  ...         NaN
# 1011        1011  ...         NaN
# 1012        1012  ...         NaN
# 1013        1013  ...         NaN
# 1014        1014  ...         NaN
# 1015        1015  ...         NaN
# 1016        1016  ...         NaN
# 1017        1017  ...         NaN
# 1018        1018  ...         NaN
# 1019        1019  ...         NaN
# 1020        1020  ...         NaN
# 1021        1021  ...         NaN
# 1022        1022  ...         NaN
# 1023        1023  ...         NaN
# 1024        1024  ...         NaN
# 1025        1025  ...         NaN
# 1026        1026  ...         NaN
# 1027        1027  ...         NaN
# 1028        1028  ...         NaN
# 1029        1029  ...         NaN
# 1030        1030  ...         NaN
# 1031        1031  ...         NaN
# 1032        1032  ...         NaN
# 1033        1033  ...         NaN
# 1034        1034  ...         NaN
# 1035        1035  ...         NaN
# 1036        1036  ...         NaN
# 1037        1037  ...         NaN
# 1038        1038  ...         NaN
# 1039        1039  ...         NaN
# 1040        1040  ...         NaN
# 1041        1041  ...         NaN
# 1042        1043  ...         NaN
# 1043        1044  ...         NaN
# 1044        1045  ...         NaN
# 1045        1046  ...         NaN
# 1046        1047  ...         NaN
# 1047        1048  ...         NaN
# 1048        1049  ...         NaN
# 1049        1050  ...         NaN
# 1050        1051  ...         NaN
# 1051        1052  ...         NaN
# 1052        1053  ...         NaN
# 1053        1054  ...         NaN
# 1054        1055  ...         NaN
# 1055        1056  ...         NaN
# 1056        1057  ...         NaN
# 1057        1058  ...         NaN
# 1058        1059  ...         NaN
# 1059        1060  ...         NaN
# 1060        1061  ...         NaN
# 1061        1062  ...         NaN
# 1062        1063  ...         NaN
# 1063        1064  ...         NaN
# 1064        1065  ...         NaN
# 1065        1066  ...         NaN
# 1066        1067  ...         NaN
# 1067        1068  ...         NaN
# 1068        1069  ...         NaN
# 1069        1070  ...         NaN
# 1070        1071  ...         NaN
# 1071        1072  ...         NaN
# 1072        1073  ...         NaN
# 1073        1074  ...         NaN
# 1074        1075  ...         NaN
# 1075        1076  ...         NaN
# 1076        1077  ...         NaN
# 1077        1078  ...         NaN
# 1078        1079  ...         NaN
# 1079        1080  ...         NaN
# 1080        1081  ...         NaN
# 1081        1082  ...         NaN
# 1082        1083  ...         NaN
# 1083        1084  ...         NaN
# 1084        1085  ...         NaN
# 1085        1086  ...         NaN
# 1086        1087  ...         NaN
# 1087        1088  ...         NaN
# 1088        1089  ...         NaN
# 1089        1090  ...         NaN
# 1090        1091  ...         NaN
# 1091        1092  ...         NaN
# 1092        1093  ...         NaN
# 1093        1094  ...         NaN
# 1094        1095  ...         NaN
# 1095        1096  ...         NaN
# 1096        1097  ...         NaN
# 1097        1098  ...         NaN
# 1098        1099  ...         NaN
# 1099        1100  ...         NaN
# 1100        1101  ...         NaN
# 1101        1102  ...         NaN
# 1102        1103  ...         NaN
# 1103        1104  ...         NaN
# 1104        1105  ...         NaN
# 1105        1106  ...         NaN
# 1106        1107  ...         NaN
# 1107        1108  ...         NaN
# 1108        1109  ...         NaN
# 1109        1110  ...         NaN
# 1110        1111  ...         NaN
# 1111        1112  ...         NaN
# 1112        1113  ...         NaN
# 1113        1114  ...         NaN
# 1114        1115  ...         NaN
# 1115        1116  ...         NaN
# 1116        1117  ...         NaN
# 1117        1118  ...         NaN
# 1118        1119  ...         NaN
# 1119        1120  ...         NaN
# 1120        1121  ...         NaN
# 1121        1122  ...         NaN
# 1122        1123  ...         NaN
# 1123        1124  ...         NaN
# 1124        1125  ...         NaN
# 1125        1126  ...         NaN
# 1126        1127  ...         NaN
# 1127        1128  ...         NaN
# 1128        1129  ...         NaN
# 1129        1130  ...         NaN
# 1130        1131  ...         NaN
# 1131        1132  ...         NaN
# 1132        1133  ...         NaN
# 1133        1134  ...         NaN
# 1134        1135  ...         NaN
# 1135        1136  ...         NaN
# 1136        1137  ...         NaN
# 1137        1138  ...         NaN
# 1138        1139  ...         NaN
# 1139        1140  ...         NaN
# 1140        1141  ...         NaN
# 1141        1142  ...         NaN
# 1142        1143  ...         NaN
# 1143        1144  ...         NaN
# 1144        1145  ...         NaN
# 1145        1146  ...         NaN
# 1146        1147  ...         NaN
# 1147        1148  ...         NaN
# 1148        1149  ...         NaN
# 1149        1150  ...         NaN
# 1150        1151  ...         NaN
# 1151        1152  ...         NaN
# 1152        1153  ...         NaN
# 1153        1154  ...         NaN
# 1154        1155  ...         NaN
# 1155        1156  ...         NaN
# 1156        1157  ...         NaN
# 1157        1158  ...         NaN
# 1158        1159  ...         NaN
# 1159        1160  ...         NaN
# 1160        1161  ...         NaN
# 1161        1162  ...         NaN
# 1162        1163  ...         NaN
# 1163        1164  ...         NaN
# 1164        1165  ...         NaN
# 1165        1166  ...         NaN
# 1166        1167  ...         NaN
# 1167        1168  ...         NaN
# 1168        1169  ...         NaN
# 1169        1170  ...         NaN
# 1170        1171  ...         NaN
# 1171        1172  ...         NaN
# 1172        1173  ...         NaN
# 1173        1174  ...         NaN
# 1174        1175  ...         NaN
# 1175        1176  ...         NaN
# 1176        1177  ...         NaN
# 1177        1178  ...         NaN
# 1178        1179  ...         NaN
# 1179        1180  ...         NaN
# 1180        1181  ...         NaN
# 1181        1182  ...         NaN
# 1182        1183  ...         NaN
# 1183        1184  ...         NaN
# 1184        1185  ...         NaN
# 1185        1186  ...         NaN
# 1186        1187  ...         NaN
# 1187        1188  ...         NaN
# 1188        1189  ...         NaN
# 1189        1190  ...         NaN
# 1190        1191  ...         NaN
# 1191        1192  ...         NaN
# 1192        1193  ...         NaN
# 1193        1194  ...         NaN
# 1194        1195  ...         NaN
# 1195        1196  ...         NaN
# 1196        1197  ...         NaN
# 1197        1198  ...         NaN
# 1198        1199  ...         NaN
# 1199        1200  ...         NaN
# 1200        1201  ...         NaN
# 1201        1202  ...         NaN
# 1202        1203  ...         NaN
# 1203        1204  ...         NaN
# 1204        1205  ...         NaN
# 1205        1207  ...         NaN
# 1206        1208  ...         NaN
# 1207        1209  ...         NaN
# 1208        1210  ...         NaN
# 1209        1211  ...         NaN
# 1210        1212  ...         NaN
# 1211        1213  ...         NaN
# 1212        1214  ...         NaN
# 1213        1215  ...         NaN
# 1214        1216  ...         NaN
# 1215        1217  ...         NaN
# 1216        1218  ...         NaN
# 1217        1219  ...         NaN
# 1218        1220  ...         NaN
# 1219        1221  ...         NaN
# 1220        1222  ...         NaN
# 1221        1223  ...         NaN
# 1222        1224  ...         NaN
# 1223        1225  ...         NaN
# 1224        1226  ...         NaN
# 1225        1227  ...         NaN
# 1226        1228  ...         NaN
# 1227        1229  ...         NaN
# 1228        1230  ...         NaN
# 1229        1231  ...         NaN
# 1230        1232  ...         NaN
# 1231        1233  ...         NaN
# 1232        1234  ...         NaN
# 1233        1235  ...         NaN
# 1234        1236  ...         NaN
# 1235        1237  ...         NaN
# 1236        1238  ...         NaN
# 1237        1239  ...         NaN
# 1238        1240  ...         NaN
# 1239        1241  ...         NaN
# 1240        1242  ...         NaN
# 1241        1243  ...         NaN
# 1242        1244  ...         NaN
# 1243        1245  ...         NaN
# 1244        1246  ...         NaN
# 1245        1247  ...         NaN
# 1246        1248  ...         NaN
# 1247        1249  ...         NaN
# 1248        1250  ...         NaN
# 1249        1251  ...         NaN
# 1250        1252  ...         NaN
# 1251        1253  ...         NaN
# 1252        1254  ...         NaN
# 1253        1255  ...         NaN
# 1254        1256  ...         NaN
# 1255        1257  ...   -0.084806
# 1256        1259  ...         NaN
# 1257        1260  ...         NaN
# 1258        1261  ...         NaN
# 1259        1262  ...         NaN
# 1260        1263  ...         NaN
# 1261        1264  ...         NaN
# 1262        1265  ...         NaN
# 1263        1266  ...         NaN
# 1264        1267  ...         NaN
# 1265        1268  ...         NaN
# 1266        1269  ...         NaN
# 1267        1270  ...         NaN
# 1268        1271  ...         NaN
# 1269        1272  ...         NaN
# 1270        1273  ...         NaN
# 1271        1274  ...         NaN
# 1272        1275  ...         NaN
# 1273        1276  ...         NaN
# 1274        1277  ...         NaN
# 1275        1278  ...         NaN
# 1276        1279  ...         NaN
# 1277        1280  ...         NaN
# 1278        1281  ...         NaN
# 1279        1282  ...         NaN
# 1280        1283  ...         NaN
# 1281        1284  ...         NaN
# 1282        1285  ...         NaN
# 1283        1286  ...         NaN
# 1284        1287  ...         NaN
# 1285        1288  ...         NaN
# 1286        1289  ...         NaN
# 1287        1290  ...         NaN
# 1288        1291  ...         NaN
# 1289        1292  ...         NaN
# 1290        1293  ...         NaN
# 1291        1294  ...         NaN
# 1292        1295  ...         NaN
# 1293        1296  ...         NaN
# 1294        1297  ...         NaN
# 1295        1298  ...         NaN
# 1296        1299  ...         NaN
# 1297        1300  ...         NaN
# 1298        1301  ...         NaN
# 1299        1302  ...         NaN
# 1300        1303  ...         NaN
# 1301        1304  ...         NaN
# 1302        1305  ...         NaN
# 1303        1306  ...         NaN
# 1304        1307  ...         NaN
# 1305        1308  ...         NaN
# 1306        1309  ...         NaN
# 1307        1310  ...         NaN
# 1308        1311  ...         NaN
# 1309        1312  ...         NaN
# 1310        1313  ...         NaN
# 1311        1314  ...         NaN
# 1312        1315  ...         NaN
# 1313        1316  ...         NaN
# 1314        1317  ...         NaN
# 1315        1318  ...         NaN
# 1316        1319  ...         NaN
# 1317        1320  ...         NaN
# 1318        1321  ...         NaN
# 1319        1322  ...         NaN
# 1320        1323  ...         NaN
# 1321        1324  ...         NaN
# 1322        1325  ...         NaN
# 1323        1326  ...         NaN
# 1324        1327  ...         NaN
# 1325        1328  ...         NaN
# 1326        1329  ...         NaN
# 1327        1330  ...         NaN
# 1328        1331  ...         NaN
# 1329        1332  ...         NaN
# 1330        1333  ...         NaN
# 1331        1334  ...         NaN
# 1332        1335  ...         NaN
# 1333        1336  ...         NaN
# 1334        1337  ...         NaN
# 1335        1338  ...         NaN
# 1336        1339  ...         NaN
# 1337        1340  ...         NaN
# 1338        1341  ...         NaN
# 1339        1342  ...         NaN
# 1340        1343  ...         NaN
# 1341        1344  ...         NaN
# 1342        1345  ...         NaN
# 1343        1346  ...         NaN
# 1344        1347  ...         NaN
# 1345        1348  ...         NaN
# 1346        1349  ...         NaN
# 1347        1350  ...         NaN
# 1348        1351  ...         NaN
# 1349        1352  ...         NaN
# 1350        1353  ...         NaN
# 1351        1354  ...         NaN
# 1352        1355  ...         NaN
# 1353        1356  ...         NaN
# 1354        1357  ...         NaN
# 1355        1358  ...         NaN
# 1356        1359  ...         NaN
# 1357        1360  ...         NaN
# 1358        1361  ...         NaN
# 1359        1362  ...         NaN
# 1360        1363  ...         NaN
# 1361        1364  ...         NaN
# 1362        1365  ...         NaN
# 1363        1366  ...         NaN
# 1364        1367  ...         NaN
# 1365        1368  ...         NaN
# 1366        1369  ...         NaN
# 1367        1370  ...         NaN
# 1368        1371  ...         NaN
# 1369        1372  ...         NaN
# 1370        1373  ...         NaN
# 1371        1374  ...         NaN
# 1372        1375  ...         NaN
# 1373        1376  ...         NaN
# 1374        1377  ...         NaN
# 1375        1378  ...         NaN
# 1376        1379  ...         NaN
# 1377        1380  ...         NaN
# 1378        1381  ...         NaN
# 1379        1382  ...         NaN
# 1380        1383  ...         NaN
# 1381        1384  ...         NaN
# 1382        1385  ...         NaN
# 1383        1386  ...         NaN
# 1384        1387  ...         NaN
# 1385        1388  ...         NaN
# 1386        1389  ...         NaN
# 1387        1390  ...         NaN
# 1388        1391  ...         NaN
# 1389        1392  ...         NaN
# 1390        1393  ...         NaN
# 1391        1394  ...         NaN
# 1392        1395  ...         NaN
# 1393        1396  ...         NaN
# 1394        1397  ...         NaN
# 1395        1398  ...         NaN
# 1396        1399  ...         NaN
# 1397        1400  ...         NaN
# 1398        1401  ...         NaN
# 1399        1402  ...         NaN
# 1400        1403  ...         NaN
# 1401        1404  ...         NaN
# 1402        1405  ...         NaN
# 1403        1406  ...         NaN
# 1404        1407  ...         NaN
# 1405        1408  ...         NaN
# 1406        1409  ...         NaN
# 1407        1410  ...         NaN
# 1408        1411  ...         NaN
# 1409        1412  ...         NaN
# ...
# 1880        1883  ...         NaN
# 1881        1884  ...         NaN
# 1882        1885  ...         NaN
# 1883        1886  ...         NaN
# 1884        1887  ...         NaN
# 1885        1888  ...         NaN
# 1886        1889  ...         NaN
# 1887        1890  ...         NaN
# 1888        1891  ...         NaN
# 1889        1892  ...         NaN
# 1890        1893  ...         NaN
# 1891        1894  ...         NaN
# 1892        1895  ...         NaN
# 1893        1896  ...         NaN
# 1894        1897  ...         NaN
# 1895        1898  ...         NaN
# 1896        1899  ...         NaN
# 1897        1900  ...         NaN
# 1898        1901  ...         NaN
# 1899        1902  ...         NaN
# 1900        1903  ...         NaN
# 1901        1904  ...         NaN
# 1902        1905  ...         NaN
# 1903        1906  ...         NaN
# 1904        1907  ...         NaN
# 1905        1908  ...         NaN
# 1906        1909  ...         NaN
# 1907        1910  ...         NaN
# 1908        1911  ...         NaN
# 1909        1912  ...         NaN
# 1910        1913  ...         NaN
# 1911        1914  ...         NaN
# 1912        1915  ...         NaN
# 1913        1916  ...         NaN
# 1914        1917  ...         NaN
# 1915        1918  ...         NaN
# 1916        1919  ...         NaN
# 1917        1920  ...         NaN
# 1918        1921  ...         NaN
# 1919        1922  ...         NaN
# 1920        1923  ...         NaN
# 1921        1924  ...         NaN
# 1922        1925  ...         NaN
# 1923        1926  ...         NaN
# 1924        1927  ...         NaN
# 1925        1928  ...         NaN
# 1926        1929  ...         NaN
# 1927        1930  ...         NaN
# 1928        1931  ...         NaN
# 1929        1932  ...         NaN
# 1930        1933  ...         NaN
# 1931        1934  ...         NaN
# 1932        1935  ...         NaN
# 1933        1936  ...         NaN
# 1934        1937  ...         NaN
# 1935        1938  ...         NaN
# 1936        1939  ...         NaN
# 1937        1940  ...         NaN
# 1938        1941  ...         NaN
# 1939        1942  ...         NaN
# 1940        1943  ...         NaN
# 1941        1944  ...         NaN
# 1942        1945  ...         NaN
# 1943        1946  ...         NaN
# 1944        1947  ...         NaN
# 1945        1948  ...         NaN
# 1946        1949  ...         NaN
# 1947        1950  ...         NaN
# 1948        1951  ...         NaN
# 1949        1952  ...         NaN
# 1950        1953  ...         NaN
# 1951        1954  ...         NaN
# 1952        1955  ...         NaN
# 1953        1956  ...         NaN
# 1954        1957  ...         NaN
# 1955        1958  ...         NaN
# 1956        1959  ...         NaN
# 1957        1960  ...         NaN
# 1958        1961  ...         NaN
# 1959        1962  ...         NaN
# 1960        1963  ...         NaN
# 1961        1964  ...         NaN
# 1962        1965  ...         NaN
# 1963        1966  ...         NaN
# 1964        1967  ...         NaN
# 1965        1968  ...         NaN
# 1966        1969  ...         NaN
# 1967        1970  ...         NaN
# 1968        1971  ...         NaN
# 1969        1972  ...         NaN
# 1970        1973  ...         NaN
# 1971        1974  ...         NaN
# 1972        1975  ...         NaN
# 1973        1976  ...         NaN
# 1974        1977  ...         NaN
# 1975        1978  ...         NaN
# 1976        1979  ...         NaN
# 1977        1980  ...         NaN
# 1978        1981  ...         NaN
# 1979        1982  ...         NaN
# 1980        1983  ...         NaN
# 1981        1984  ...         NaN
# 1982        1985  ...         NaN
# 1983        1986  ...         NaN
# 1984        1987  ...         NaN
# 1985        1988  ...         NaN
# 1986        1989  ...         NaN
# 1987        1990  ...         NaN
# 1988        1991  ...         NaN
# 1989        1992  ...         NaN
# 1990        1993  ...         NaN
# 1991        1994  ...         NaN
# 1992        1995  ...         NaN
# 1993        1996  ...         NaN
# 1994        1997  ...         NaN
# 1995        1998  ...         NaN
# 1996        1999  ...         NaN
# 1997        2000  ...         NaN
# 1998        2001  ...         NaN
# 1999        2002  ...         NaN
# 2000        2003  ...         NaN
# 2001        2004  ...         NaN
# 2002        2005  ...         NaN
# 2003        2006  ...         NaN
# 2004        2007  ...         NaN
# 2005        2008  ...         NaN
# 2006        2009  ...         NaN
# 2007        2010  ...         NaN
# 2008        2011  ...         NaN
# 2009        2012  ...         NaN
# 2010        2013  ...         NaN
# 2011        2014  ...         NaN
# 2012        2015  ...         NaN
# 2013        2016  ...         NaN
# 2014        2017  ...         NaN
# 2015        2018  ...         NaN
# 2016        2019  ...         NaN
# 2017        2020  ...         NaN
# 2018        2021  ...         NaN
# 2019        2022  ...         NaN
# 2020        2023  ...         NaN
# 2021        2024  ...         NaN
# 2022        2025  ...         NaN
# 2023        2026  ...         NaN
# 2024        2027  ...         NaN
# 2025        2028  ...         NaN
# 2026        2029  ...         NaN
# 2027        2030  ...         NaN
# 2028        2031  ...         NaN
# 2029        2032  ...         NaN
# 2030        2033  ...         NaN
# 2031        2034  ...         NaN
# 2032        2035  ...         NaN
# 2033        2036  ...         NaN
# 2034        2037  ...         NaN
# 2035        2038  ...         NaN
# 2036        2039  ...         NaN
# 2037        2040  ...         NaN
# 2038        2041  ...         NaN
# 2039        2042  ...         NaN
# 2040        2043  ...         NaN
# 2041        2044  ...         NaN
# 2042        2045  ...         NaN
# 2043        2046  ...         NaN
# 2044        2047  ...         NaN
# 2045        2048  ...         NaN
# 2046        2049  ...         NaN
# 2047        2050  ...         NaN
# 2048        2051  ...         NaN
# 2049        2052  ...         NaN
# 2050        2053  ...         NaN
# 2051        2054  ...         NaN
# 2052        2055  ...         NaN
# 2053        2056  ...         NaN
# 2054        2057  ...         NaN
# 2055        2058  ...         NaN
# 2056        2059  ...         NaN
# 2057        2060  ...         NaN
# 2058        2061  ...         NaN
# 2059        2062  ...         NaN
# 2060        2063  ...         NaN
# 2061        2064  ...         NaN
# 2062        2065  ...         NaN
# 2063        2066  ...         NaN
# 2064        2067  ...         NaN
# 2065        2068  ...         NaN
# 2066        2069  ...         NaN
# 2067        2070  ...         NaN
# 2068        2071  ...         NaN
# 2069        2072  ...         NaN
# 2070        2073  ...         NaN
# 2071        2074  ...         NaN
# 2072        2075  ...         NaN
# 2073        2076  ...         NaN
# 2074        2077  ...         NaN
# 2075        2078  ...         NaN
# 2076        2079  ...         NaN
# 2077        2080  ...         NaN
# 2078        2081  ...         NaN
# 2079        2082  ...         NaN
# 2080        2083  ...         NaN
# 2081        2084  ...         NaN
# 2082        2085  ...         NaN
# 2083        2086  ...         NaN
# 2084        2087  ...         NaN
# 2085        2088  ...         NaN
# 2086        2089  ...         NaN
# 2087        2090  ...         NaN
# 2088        2091  ...         NaN
# 2089        2092  ...         NaN
# 2090        2093  ...         NaN
# 2091        2094  ...         NaN
# 2092        2095  ...         NaN
# 2093        2096  ...         NaN
# 2094        2097  ...         NaN
# 2095        2098  ...         NaN
# 2096        2099  ...         NaN
# 2097        2100  ...         NaN
# 2098        2101  ...         NaN
# 2099        2102  ...         NaN
# 2100        2103  ...         NaN
# 2101        2104  ...         NaN
# 2102        2106  ...         NaN
# 2103        2107  ...         NaN
# 2104        2108  ...         NaN
# 2105        2109  ...         NaN
# 2106        2110  ...         NaN
# 2107        2111  ...         NaN
# 2108        2112  ...         NaN
# 2109        2113  ...         NaN
# 2110        2114  ...         NaN
# 2111        2115  ...         NaN
# 2112        2116  ...         NaN
# 2113        2117  ...         NaN
# 2114        2118  ...         NaN
# 2115        2119  ...         NaN
# 2116        2120  ...         NaN
# 2117        2121  ...         NaN
# 2118        2122  ...         NaN
# 2119        2123  ...         NaN
# 2120        2124  ...         NaN
# 2121        2125  ...         NaN
# 2122        2126  ...         NaN
# 2123        2127  ...         NaN
# 2124        2128  ...         NaN
# 2125        2129  ...         NaN
# 2126        2130  ...         NaN
# 2127        2131  ...         NaN
# 2128        2132  ...         NaN
# 2129        2133  ...         NaN
# 2130        2134  ...         NaN
# 2131        2135  ...         NaN
# 2132        2136  ...         NaN
# 2133        2137  ...         NaN
# 2134        2138  ...         NaN
# 2135        2139  ...         NaN
# 2136        2140  ...         NaN
# 2137        2141  ...         NaN
# 2138        2142  ...         NaN
# 2139        2143  ...         NaN
# 2140        2144  ...         NaN
# 2141        2145  ...         NaN
# 2142        2146  ...         NaN
# 2143        2147  ...         NaN
# 2144        2148  ...         NaN
# 2145        2149  ...         NaN
# 2146        2150  ...         NaN
# 2147        2151  ...         NaN
# 2148        2152  ...         NaN
# 2149        2153  ...         NaN
# 2150        2154  ...         NaN
# 2151        2155  ...         NaN
# 2152        2156  ...         NaN
# 2153        2157  ...         NaN
# 2154        2158  ...         NaN
# 2155        2159  ...         NaN
# 2156        2160  ...         NaN
# 2157        2161  ...         NaN
# 2158        2162  ...         NaN
# 2159        2163  ...         NaN
# 2160        2164  ...         NaN
# 2161        2165  ...         NaN
# 2162        2166  ...         NaN
# 2163        2167  ...         NaN
# 2164        2168  ...         NaN
# 2165        2169  ...         NaN
# 2166        2170  ...         NaN
# 2167        2171  ...         NaN
# 2168        2172  ...         NaN
# 2169        2173  ...         NaN
# 2170        2174  ...         NaN
# 2171        2175  ...         NaN
# 2172        2176  ...         NaN
# 2173        2177  ...         NaN
# 2174        2178  ...         NaN
# 2175        2179  ...         NaN
# 2176        2180  ...         NaN
# 2177        2181  ...         NaN
# 2178        2182  ...         NaN
# 2179        2183  ...         NaN
# 2180        2184  ...         NaN
# 2181        2185  ...         NaN
# 2182        2186  ...         NaN
# 2183        2187  ...         NaN
# 2184        2188  ...         NaN
# 2185        2189  ...         NaN
# 2186        2190  ...         NaN
# 2187        2191  ...         NaN
# 2188        2192  ...         NaN
# 2189        2193  ...         NaN
# 2190        2194  ...         NaN
# 2191        2195  ...         NaN
# 2192        2196  ...         NaN
# 2193        2197  ...         NaN
# 2194        2198  ...         NaN
# 2195        2199  ...         NaN
# 2196        2200  ...         NaN
# 2197        2201  ...         NaN
# 2198        2202  ...         NaN
# 2199        2203  ...         NaN
# 2200        2204  ...         NaN
# 2201        2205  ...         NaN
# 2202        2206  ...         NaN
# 2203        2207  ...         NaN
# 2204        2208  ...         NaN
# 2205        2209  ...         NaN
# 2206        2210  ...         NaN
# 2207        2211  ...         NaN
# 2208        2212  ...         NaN
# 2209        2213  ...         NaN
# 2210        2214  ...         NaN
# 2211        2215  ...         NaN
# 2212        2216  ...         NaN
# 2213        2217  ...         NaN
# 2214        2218  ...         NaN
# 2215        2219  ...         NaN
# 2216        2220  ...         NaN
# 2217        2221  ...         NaN
# 2218        2222  ...         NaN
# 2219        2223  ...         NaN
# 2220        2224  ...         NaN
# 2221        2225  ...         NaN
# 2222        2226  ...         NaN
# 2223        2227  ...         NaN
# 2224        2228  ...         NaN
# 2225        2229  ...         NaN
# 2226        2230  ...         NaN
# 2227        2231  ...         NaN
# 2228        2232  ...         NaN
# 2229        2233  ...         NaN
# 2230        2234  ...         NaN
# 2231        2235  ...         NaN
# 2232        2236  ...         NaN
# 2233        2237  ...         NaN
# 2234        2238  ...         NaN
# 2235        2239  ...         NaN
# 2236        2240  ...         NaN
# 2237        2241  ...         NaN
# 2238        2242  ...         NaN
# 2239        2243  ...         NaN
# 2240        2244  ...         NaN
# 2241        2245  ...         NaN
# 2242        2246  ...         NaN
# 2243        2247  ...         NaN
# 2244        2248  ...         NaN
# 2245        2249  ...         NaN
# 2246        2250  ...         NaN
# 2247        2251  ...         NaN
# 2248        2252  ...         NaN
# 2249        2253  ...         NaN
# 2250        2254  ...         NaN
# 2251        2255  ...         NaN
# 2252        2256  ...         NaN
# 2253        2257  ...         NaN
# 2254        2258  ...         NaN
# 2255        2259  ...         NaN
# 2256        2260  ...         NaN
# 2257        2261  ...         NaN
# 2258        2262  ...         NaN
# 2259        2263  ...         NaN
# 2260        2264  ...         NaN
# 2261        2265  ...         NaN
# 2262        2266  ...         NaN
# 2263        2267  ...         NaN
# 2264        2268  ...         NaN
# 2265        2269  ...         NaN
# 2266        2270  ...         NaN
# 2267        2271  ...         NaN
# 2268        2272  ...         NaN
# 2269        2273  ...         NaN
# 2270        2274  ...         NaN
# 2271        2275  ...         NaN
# 2272        2276  ...         NaN
# 2273        2277  ...         NaN
# 2274        2278  ...         NaN
# 2275        2279  ...         NaN
# 2276        2280  ...         NaN
# 2277        2281  ...         NaN
# 2278        2282  ...         NaN
# 2279        2283  ...         NaN
# 2280        2284  ...         NaN
# 2281        2285  ...         NaN
# 2282        2286  ...         NaN
# 2283        2287  ...         NaN
# 2284        2288  ...         NaN
# 2285        2289  ...         NaN
# 2286        2290  ...         NaN
# 2287        2291  ...         NaN
# 2288        2292  ...         NaN
# 2289        2293  ...         NaN
# 2290        2294  ...         NaN
# 2291        2295  ...         NaN
# 2292        2296  ...         NaN
# 2293        2297  ...         NaN
# 2294        2298  ...         NaN
# 2295        2299  ...         NaN
# 2296        2300  ...         NaN
# 2297        2301  ...         NaN
# 2298        2302  ...         NaN
# 2299        2303  ...         NaN
# 2300        2304  ...         NaN
# 2301        2305  ...         NaN
# 2302        2306  ...         NaN
# 2303        2307  ...         NaN
# 2304        2308  ...         NaN
# 2305        2309  ...         NaN
# 2306        2310  ...         NaN
# 2307        2311  ...         NaN
# 2308        2312  ...         NaN
# 2309        2313  ...         NaN
# 2310        2314  ...         NaN
# 2311        2315  ...         NaN
# 2312        2316  ...         NaN
# 2313        2317  ...         NaN
# 2314        2318  ...         NaN
# 2315        2319  ...         NaN
# 2316        2320  ...         NaN
# 2317        2321  ...         NaN
# 2318        2322  ...         NaN
# 2319        2323  ...         NaN
# 2320        2324  ...         NaN
# 2321        2325  ...         NaN
# 2322        2326  ...         NaN
# 2323        2327  ...         NaN
# 2324        2328  ...         NaN
# 2325        2329  ...         NaN
# 2326        2330  ...         NaN
# 2327        2331  ...         NaN
# 2328        2332  ...         NaN
# 2329        2333  ...         NaN
# 2330        2334  ...         NaN
# 2331        2335  ...         NaN
# 2332        2336  ...         NaN
# 2333        2337  ...         NaN
# 2334        2338  ...         NaN
# 2335        2339  ...         NaN
# 2336        2340  ...         NaN
# 2337        2341  ...         NaN
# 2338        2342  ...         NaN
# 2339        2343  ...         NaN
# 2340        2344  ...         NaN
# 2341        2345  ...         NaN
# 2342        2346  ...         NaN
# 2343        2347  ...         NaN
# 2344        2348  ...         NaN
# 2345        2349  ...         NaN
# 2346        2350  ...         NaN
# 2347        2351  ...         NaN
# 2348        2352  ...         NaN
#
# [2349 rows x 14 columns]

# %%
ct_mapping.to_csv('dataframe_mapping_0531.csv')

# %%
#ct_mapping=pd.read_csv('dataframe_mapping_0530.csv',encoding='ISO-8859-1')

# %%
for k in range(len(ct_ner['NER-1'])):
  list=[]
  for i in ct_ner['NER-1'][k]:
    for j in range(len(ct_mapping['City'])):
      if(i==ct_mapping['City'][j]):
        list.append(ct_mapping['Mapping'][j])
  ct_ner['NER-1'][k]=list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
ct_ner[:100]
# Out:
#     Unnamed: 0  ...                                              NER-1
# 0            0  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 1            1  ...                                                 []
# 2            2  ...  [Lawton, Comanche County, Oklahoma, 73501, Uni...
# 3            3  ...  [Stamford, Fairfield County, Connecticut, Unit...
# 4            4  ...                                                 []
# 5            5  ...                                              [nan]
# 6            6  ...                                                 []
# 7            7  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 8            8  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 9            9  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 10          10  ...                                                 []
# 11          11  ...                                                 []
# 12          12  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 13          13  ...                                              [nan]
# 14          14  ...  [Goldsboro, Wayne County, North Carolina, Unit...
# 15          15  ...   [America, Horst aan de Maas, Limburg, Nederland]
# 16          16  ...  [New Bedford, Bristol County, Massachusetts, 0...
# 17          17  ...                                                 []
# 18          18  ...  [Omaha, Douglas County, Nebraska, 68183, Unite...
# 19          19  ...  [Philadelphia, Philadelphia County, Pennsylvan...
# 20          20  ...  [America, Horst aan de Maas, Limburg, Nederlan...
# 21          21  ...  [Lawton, Comanche County, Oklahoma, 73501, Uni...
# 22          22  ...                                                 []
# 23          23  ...  [Kingston, Surrey County, KINGSTON, Jamaica, N...
# 24          24  ...  [nan, nan, Minneapolis, Hennepin County, Minne...
# 25          25  ...  [Cincinnati, Hamilton County, Ohio, United Sta...
# 26          26  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 27          27  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 28          28  ...  [Greenville, Greenville County, South Carolina...
# 29          29  ...                                                 []
# 30          30  ...  [Seattle, King County, Washington, United Stat...
# 31          31  ...                                                 []
# 32          32  ...  [Santa Monica, Los Angeles County, California,...
# 33          33  ...  [Santa Monica, Los Angeles County, California,...
# 34          34  ...   [Queens, Queens County, New York, United States]
# 35          35  ...   [Queens, Queens County, New York, United States]
# 36          36  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 37          37  ...  [Oakland, Alameda County, California, United S...
# 38          38  ...  [Oakland, Alameda County, California, United S...
# 39          39  ...  [Oakland, Alameda County, California, United S...
# 40          40  ...  [London, Greater London, England, SW1A 2DX, Un...
# 41          41  ...  [Omaha, Douglas County, Nebraska, 68183, Unite...
# 42          42  ...                                              [nan]
# 43          43  ...                                                 []
# 44          44  ...  [Flint, Genesee County, Michigan, United State...
# 45          45  ...  [Flint, Genesee County, Michigan, United State...
# 46          46  ...  [Flint, Genesee County, Michigan, United State...
# 47          47  ...                                                 []
# 48          48  ...  [America, Horst aan de Maas, Limburg, Nederlan...
# 49          49  ...  [San Angelo, Tom Green County, Texas, 76903, U...
# 50          50  ...     [Houston, Harris County, Texas, United States]
# 51          51  ...     [nan, Genesee County, Michigan, United States]
# 52          52  ...  [New York, United States, nan, nan, nan, nan, ...
# 53          53  ...  [Cleveland, Cuyahoga County, Ohio, 44114, Unit...
# 54          54  ...  [Cleveland, Cuyahoga County, Ohio, 44114, Unit...
# 55          55  ...  [Cleveland, Cuyahoga County, Ohio, 44114, Unit...
# 56          56  ...  [Cleveland, Cuyahoga County, Ohio, 44114, Unit...
# 57          57  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 58          58  ...                                              [nan]
# 59          59  ...                                              [nan]
# 60          60  ...                                              [nan]
# 61          61  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 62          62  ...  [nan, Fayetteville, Washington County, Arkansa...
# 63          63  ...  [Denver, Denver County, Colorado, United State...
# 64          64  ...  [nan, Dayton, Montgomery County, Ohio, 45423, ...
# 65          65  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 66          66  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 67          67  ...  [L.A., Mamburao, Occidental Mindoro, Mimaropa,...
# 68          68  ...                                                 []
# 69          69  ...   [nan, Baltimore, Maryland, 21203, United States]
# 70          70  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 71          71  ...  [nan, Rangeline, Town of Green Valley, Maratho...
# 72          72  ...  [nan, Rangeline, Town of Green Valley, Maratho...
# 73          73  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 74          74  ...  [Sioux Falls, Minnehaha County, South Dakota, ...
# 75          75  ...  [San Diego, San Diego County, California, 9210...
# 76          76  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 77          77  ...  [Kitsap County, Washington, United States, Kit...
# 78          78  ...  [nan, Columbus, Franklin County, Ohio, United ...
# 79          79  ...  [Lake Worth Beach, Palm Beach County, Florida,...
# 80          80  ...  [nan, Wilmington, New Castle County, Delaware,...
# 81          81  ...  [nan, Orlando, Orange County, Florida, United ...
# 82          82  ...                                              [nan]
# 83          83  ...  [Sacramento, Sacramento County, California, 95...
# 84          84  ...   [America, Horst aan de Maas, Limburg, Nederland]
# 85          85  ...                                                 []
# 86          86  ...                                                 []
# 87          87  ...  [nan, Chicago, Cook County, Illinois, United S...
# 88          88  ...  [Chicago, Cook County, Illinois, United States...
# 89          89  ...   [nan, Baltimore, Maryland, 21203, United States]
# 90          90  ...                                                 []
# 91          91  ...  [Kalamazoo, Kalamazoo County, Michigan, United...
# 92          92  ...  [nan, Chicago, Cook County, Illinois, United S...
# 93          93  ...  [nan, America, Horst aan de Maas, Limburg, Ned...
# 94          94  ...  [Willingboro, Willingboro Township, Burlington...
# 95          95  ...  [San Joaquin, Basco, Batanes, Cagayan Valley, ...
# 96          96  ...  [Minneapolis, Hennepin County, Minnesota, Unit...
# 97          97  ...  [nan, Greenville, Greenville County, South Car...
# 98          98  ...  [Goldsboro, Wayne County, North Carolina, Unit...
# 99          99  ...                                                 []
#
# [100 rows x 53 columns]

# %%
ct_ner['NER-1'][:100]
# Out:
# 0     [Minneapolis, Hennepin County, Minnesota, Unit...
# 1                                                    []
# 2     [Lawton, Comanche County, Oklahoma, 73501, Uni...
# 3     [Stamford, Fairfield County, Connecticut, Unit...
# 4                                                    []
# 5                                                 [nan]
# 6                                                    []
# 7     [Minneapolis, Hennepin County, Minnesota, Unit...
# 8     [Minneapolis, Hennepin County, Minnesota, Unit...
# 9     [Minneapolis, Hennepin County, Minnesota, Unit...
# 10                                                   []
# 11                                                   []
# 12    [Minneapolis, Hennepin County, Minnesota, Unit...
# 13                                                [nan]
# 14    [Goldsboro, Wayne County, North Carolina, Unit...
# 15     [America, Horst aan de Maas, Limburg, Nederland]
# 16    [New Bedford, Bristol County, Massachusetts, 0...
# 17                                                   []
# 18    [Omaha, Douglas County, Nebraska, 68183, Unite...
# 19    [Philadelphia, Philadelphia County, Pennsylvan...
# 20    [America, Horst aan de Maas, Limburg, Nederlan...
# 21    [Lawton, Comanche County, Oklahoma, 73501, Uni...
# 22                                                   []
# 23    [Kingston, Surrey County, KINGSTON, Jamaica, N...
# 24    [nan, nan, Minneapolis, Hennepin County, Minne...
# 25    [Cincinnati, Hamilton County, Ohio, United Sta...
# 26    [Minneapolis, Hennepin County, Minnesota, Unit...
# 27    [Minneapolis, Hennepin County, Minnesota, Unit...
# 28    [Greenville, Greenville County, South Carolina...
# 29                                                   []
# 30    [Seattle, King County, Washington, United Stat...
# 31                                                   []
# 32    [Santa Monica, Los Angeles County, California,...
# 33    [Santa Monica, Los Angeles County, California,...
# 34     [Queens, Queens County, New York, United States]
# 35     [Queens, Queens County, New York, United States]
# 36    [Minneapolis, Hennepin County, Minnesota, Unit...
# 37    [Oakland, Alameda County, California, United S...
# 38    [Oakland, Alameda County, California, United S...
# 39    [Oakland, Alameda County, California, United S...
# 40    [London, Greater London, England, SW1A 2DX, Un...
# 41    [Omaha, Douglas County, Nebraska, 68183, Unite...
# 42                                                [nan]
# 43                                                   []
# 44    [Flint, Genesee County, Michigan, United State...
# 45    [Flint, Genesee County, Michigan, United State...
# 46    [Flint, Genesee County, Michigan, United State...
# 47                                                   []
# 48    [America, Horst aan de Maas, Limburg, Nederlan...
# 49    [San Angelo, Tom Green County, Texas, 76903, U...
# 50       [Houston, Harris County, Texas, United States]
# 51       [nan, Genesee County, Michigan, United States]
# 52    [New York, United States, nan, nan, nan, nan, ...
# 53    [Cleveland, Cuyahoga County, Ohio, 44114, Unit...
# 54    [Cleveland, Cuyahoga County, Ohio, 44114, Unit...
# 55    [Cleveland, Cuyahoga County, Ohio, 44114, Unit...
# 56    [Cleveland, Cuyahoga County, Ohio, 44114, Unit...
# 57    [Minneapolis, Hennepin County, Minnesota, Unit...
# 58                                                [nan]
# 59                                                [nan]
# 60                                                [nan]
# 61    [Minneapolis, Hennepin County, Minnesota, Unit...
# 62    [nan, Fayetteville, Washington County, Arkansa...
# 63    [Denver, Denver County, Colorado, United State...
# 64    [nan, Dayton, Montgomery County, Ohio, 45423, ...
# 65    [Minneapolis, Hennepin County, Minnesota, Unit...
# 66    [Minneapolis, Hennepin County, Minnesota, Unit...
# 67    [L.A., Mamburao, Occidental Mindoro, Mimaropa,...
# 68                                                   []
# 69     [nan, Baltimore, Maryland, 21203, United States]
# 70    [nan, Minneapolis, Hennepin County, Minnesota,...
# 71    [nan, Rangeline, Town of Green Valley, Maratho...
# 72    [nan, Rangeline, Town of Green Valley, Maratho...
# 73    [Minneapolis, Hennepin County, Minnesota, Unit...
# 74    [Sioux Falls, Minnehaha County, South Dakota, ...
# 75    [San Diego, San Diego County, California, 9210...
# 76    [Minneapolis, Hennepin County, Minnesota, Unit...
# 77    [Kitsap County, Washington, United States, Kit...
# 78    [nan, Columbus, Franklin County, Ohio, United ...
# 79    [Lake Worth Beach, Palm Beach County, Florida,...
# 80    [nan, Wilmington, New Castle County, Delaware,...
# 81    [nan, Orlando, Orange County, Florida, United ...
# 82                                                [nan]
# 83    [Sacramento, Sacramento County, California, 95...
# 84     [America, Horst aan de Maas, Limburg, Nederland]
# 85                                                   []
# 86                                                   []
# 87    [nan, Chicago, Cook County, Illinois, United S...
# 88    [Chicago, Cook County, Illinois, United States...
# 89     [nan, Baltimore, Maryland, 21203, United States]
# 90                                                   []
# 91    [Kalamazoo, Kalamazoo County, Michigan, United...
# 92    [nan, Chicago, Cook County, Illinois, United S...
# 93    [nan, America, Horst aan de Maas, Limburg, Ned...
# 94    [Willingboro, Willingboro Township, Burlington...
# 95    [San Joaquin, Basco, Batanes, Cagayan Valley, ...
# 96    [Minneapolis, Hennepin County, Minnesota, Unit...
# 97    [nan, Greenville, Greenville County, South Car...
# 98    [Goldsboro, Wayne County, North Carolina, Unit...
# 99                                                   []
# Name: NER-1, dtype: object

# %%
ct_ner.to_csv('dataframe0531_post_remove.csv')

# %%
# !ls
# Out:
# Country.txt		       dataframe0609_post_remove.csv
# dataframe0529_post.csv	       dataframe0610_post.csv
# dataframe0529_post_remove.csv  dataframe0610_post_remove.csv
# dataframe0530_post.csv	       dataframe0611_post.csv
# dataframe0530_post_remove.csv  dataframe0611_post_remove.csv
# dataframe0531_post.csv	       dataframe_mapping
# dataframe0531_post_remove.csv  dataframe_mapping_0529.csv
# dataframe0601_post.csv	       dataframe_mapping_0530.csv
# dataframe0601_post_remove.csv  dataframe_mapping_0531.csv
# dataframe0602_post.csv	       dataframe_mapping_0601.csv
# dataframe0602_post_remove.csv  dataframe_mapping_0602.csv
# dataframe0603_post.csv	       dataframe_mapping_0603.csv
# dataframe0603_post_remove.csv  dataframe_mapping_0604.csv
# dataframe0604_post.csv	       dataframe_mapping_0605.csv
# dataframe0604_post_remove.csv  dataframe_mapping_0606.csv
# dataframe0605_post.csv	       dataframe_mapping_0607.csv
# dataframe0605_post_remove.csv  dataframe_mapping_0608.csv
# dataframe0606_post.csv	       dataframe_mapping_0609.csv
# dataframe0606_post_remove.csv  dataframe_mapping_0610.csv
# dataframe0607_post.csv	       dataframe_mapping_0611.csv
# dataframe0607_post_remove.csv  datarframe_post
# dataframe0608_post.csv	       post_specific_mapping_US.zip
# dataframe0608_post_remove.csv  states.csv
# dataframe0609_post.csv
