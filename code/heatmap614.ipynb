# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 5.4 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=40ac95530b3cd6175a2fba51d9a4a94aea03cdfdfff09b5aeb2be73fb7114c70
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.0 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_UK
#  a0529-a0611_US     dataframe_result_529_UK.csv
#  a0529.csv	    dataframe_result_530_UK.csv
#  a0530.csv	    dataframe_result_531_UK.csv
#  a0601.csv	    dataframe_result_csv
#  a0602.csv	    dataframe_result_csv_EU
#  a0603.csv	    dataframe_result_csv_UK
#  a0604.csv	    Github
#  a0605.csv	    heatmap529_UK.ipynb
#  a0606.csv	    heatmap530.ipynb
#  a0607.csv	    Heat_Map_Online_language.ipynb
#  a0608.csv	    __MACOSX
#  a0610.csv	    mapping_UK
#  a0611.csv	    mapping_US
#  ccc_compiled.csv   non_violant1.csv
#  csv		    non_violant2.csv
#  csv.zip	    UK
#  dataframe_csv	    violant.csv
#  dataframe_csv_EU  '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_611 = 'csv/US06_14.csv'

# %%
ct = pd.read_csv(ct_path_611)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                             platformId  ...                    post_id
# 0        18982436812_10157083355091813  ...     8015|10157083355091813
# 1     115049898514565_3320488604637329  ...     10268|3320488604637329
# 2      212643102652626_651586795424919  ...    3892292|651586795424919
# 3     389462407756241_3044759782226477  ...    465971|3044759782226477
# 4     191314347566158_3285176251513270  ...   8605125|3285176251513270
# ...                                ...  ...                        ...
# 3281  837955106354138_1617784385037869  ...   2146395|1617784385037869
# 3282  519305544814653_3366661223412390  ...     48733|3366661223412390
# 3283    158094820767_10158441052675768  ...    13653|10158441052675768
# 3284    275678631915_10156988934511916  ...   349912|10156988934511916
# 3285  310182299373875_1236259733432789  ...  12924282|1236259733432789
#
# [3286 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#                          NER-msg                          NER-desc
# 0             {'Minneapolis': 1}  {'Minneapolis': 1, 'America': 1}
# 1                             {}                                {}
# 2                  {'Dallas': 1}                     {'Dallas': 1}
# 3  {'Abita Springs': 1, 'LA': 1}                     {'Dallas': 1}
# 4                             {}                                {}

# %%
ct
# Out:
#                             platformId  ...      NER-title
# 0        18982436812_10157083355091813  ...             {}
# 1     115049898514565_3320488604637329  ...             {}
# 2      212643102652626_651586795424919  ...  {'Dallas': 1}
# 3     389462407756241_3044759782226477  ...  {'Dallas': 1}
# 4     191314347566158_3285176251513270  ...             {}
# ...                                ...  ...            ...
# 3281  837955106354138_1617784385037869  ...             {}
# 3282  519305544814653_3366661223412390  ...             {}
# 3283    158094820767_10158441052675768  ...             {}
# 3284    275678631915_10156988934511916  ...             {}
# 3285  310182299373875_1236259733432789  ...    {'U.S.': 1}
#
# [3286 rows x 50 columns]

# %%
ct.to_csv('a0614.csv')

# %%
ct=pd.read_csv('a0614.csv',lineterminator='\n')

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                                              NER-msg  ...       NER-title
# 0                                 {'Minneapolis': 1}  ...              {}
# 2                                      {'Dallas': 1}  ...   {'Dallas': 1}
# 3                      {'Abita Springs': 1, 'LA': 1}  ...   {'Dallas': 1}
# 5  {'Seattle': 9, 'Capitol Hill Autonomous Zone':...  ...  {'Seattle': 1}
# 7  {'Berlin': 1, 'London': 1, 'Paris': 1, 'the Un...  ...     {'U.S.': 1}
#
# [5 rows x 3 columns]

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ct_ner['NER-msg']
# Out:
# 0                                           [Minneapolis]
# 2                                                [Dallas]
# 3                                     [LA, Abita Springs]
# 5       [Capitol Hill Autonomous Zone, America, the Un...
# 7       [London, Minnesota, Paris, Berlin, the United ...
#                               ...
# 3278                                                   []
# 3279                               [Minneapolis, Chicago]
# 3280                                            [Indiana]
# 3281                                                   []
# 3285                                     [U.S., New York]
# Name: NER-msg, Length: 2368, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ct_ner['NER']
# Out:
# 0                     [Minneapolis, America, Minneapolis]
# 2                                [Dallas, Dallas, Dallas]
# 3                     [LA, Abita Springs, Dallas, Dallas]
# 5       [Capitol Hill Autonomous Zone, America, the Un...
# 7       [London, Minnesota, Paris, Berlin, the United ...
#                               ...
# 3278                                        [Minneapolis]
# 3279                               [Minneapolis, Chicago]
# 3280              [Indiana, Indiana, State, INDIANAPOLIS]
# 3281                                        [Minneapolis]
# 3285                               [U.S., New York, U.S.]
# Name: NER, Length: 2368, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ner_lst = ct_ner['NER'].values

# %%
ner_lst
# Out:
# array([list(['america', 'minneapolis']), list(['dallas']),
#        list(['dallas', 'la', 'abita springs']), ...,
#        list(['indiana', 'state', 'indianapolis']), list(['minneapolis']),
#        list(['u.s.', 'new york'])], dtype=object)

# %%
m=0
list=[]
for n in ner_lst:
  for i in range(len(n)):
    list.append(ner_lst[m][i])
  m+=1

# %%
list
# Out:
# ['america',
#  'minneapolis',
#  'dallas',
#  'dallas',
#  'la',
#  'abita springs',
#  'capitol hill autonomous zone',
#  'america',
#  'the united states',
#  'seattle',
#  'washington',
#  'u.s.',
#  'london',
#  'minnesota',
#  'berlin',
#  'paris',
#  'the united states',
#  'bakersfield',
#  'california',
#  'minneapolis',
#  'cook county',
#  'empire',
#  'harris county',
#  'texas',
#  'houston',
#  'minneapolis',
#  'us',
#  'minneapolis',
#  'chicago',
#  'china',
#  'florida',
#  'north carolina',
#  'fayetteville',
#  'seattle',
#  'jacksonville',
#  'hong kong',
#  'nj -',
#  'nutley',
#  'baltimore',
#  'nj -',
#  'nutley',
#  'atlanta',
#  'japan',
#  'tokyo',
#  'new zealand',
#  'the united states',
#  'minneapolis',
#  'atlanta',
#  'atlanta',
#  'marshfield',
#  'america',
#  'us',
#  'america',
#  'minneapolis',
#  'atlanta',
#  'arlington',
#  'america',
#  'downtown okc',
#  'oklahoma city',
#  'the district of columbia',
#  'u.s.',
#  'washington',
#  'u.s.',
#  'us',
#  'minneapolis',
#  'atlanta',
#  'minneapolis',
#  'https://www.ghostcultmag.com/rage-against-the-machines-debut-album-returns-to-the-billboard-200-charts-on-the-strength-of-global-protests/',
#  'third ward',
#  'u.s.',
#  'us',
#  'u.s.',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'us',
#  'minneapolis',
#  'us',
#  'the united states',
#  'israel',
#  'london',
#  'minneapolis',
#  'paris',
#  'california',
#  'us',
#  'the united states',
#  'atlanta',
#  'minneapolis',
#  'atlanta',
#  'atlanta',
#  'minneapolis',
#  'atlanta',
#  'cedar rapids',
#  'lafayette square',
#  'd.c.',
#  'washington',
#  'minneapolis',
#  'atlanta',
#  'minneapolis',
#  'atlanta',
#  'america',
#  'minneapolis',
#  'u.s.',
#  'japan',
#  'u.s.',
#  'new zealand',
#  'u.s.',
#  'us',
#  'minneapolis',
#  'united states',
#  'u.s.',
#  'america',
#  'the lucas county courthouse',
#  'minneapolis',
#  'tokyo',
#  'the lucas county courthouse',
#  'the lucas county courthouse',
#  'houston',
#  'us',
#  'bull durham',
#  'america',
#  'us',
#  'the united states',
#  'suffolk',
#  'minneapolis',
#  'pa.',
#  'the united states',
#  'america',
#  'america',
#  'minneapolis',
#  'brooklyn',
#  'minneapolis',
#  'minneapolis',
#  'cranbury',
#  'minneapolis',
#  'the united states of america',
#  'the united states',
#  'minneapolis',
#  'arizona',
#  'neverland',
#  'florida',
#  'atlanta',
#  'minneapolis',
#  'atlanta',
#  'londo',
#  'us',
#  'the united states',
#  'us',
#  'britain',
#  'west',
#  'the state of israel',
#  'minneapolis',
#  'israel',
#  'america',
#  'us',
#  'palestine',
#  'israel',
#  'britain',
#  'jerusalem',
#  'massachusetts',
#  'japan',
#  'tokyo',
#  'new zealand',
#  'atlanta',
#  'minneapolis',
#  'usa',
#  'canada',
#  'us',
#  'bc',
#  'vegas',
#  'las vegas',
#  'u.s.',
#  'minneapolis',
#  'washoe county',
#  'las vegas',
#  'vegas',
#  'california',
#  'the united states',
#  'houston',
#  'california',
#  'washington d.c.',
#  'united states',
#  'd.c.',
#  'lafayette park',
#  'washington',
#  'lafayette park',
#  'minneapolis',
#  'okla',
#  'california',
#  'richmond',
#  'richmond',
#  'minneapolis',
#  'san mateo',
#  'california',
#  'california',
#  'california',
#  'california',
#  'chicago',
#  'chicago',
#  'chicago',
#  'chicago',
#  'chicago',
#  'chicago',
#  'sioux falls',
#  's.d.',
#  'n.j.',
#  'minessota',
#  'west tennessee',
#  'west tennessee',
#  'tenn.',
#  'minneapolis',
#  'the maasai warriors',
#  'minneapolis',
#  'kenya',
#  'egypt',
#  'ghana',
#  'seattle',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'texas',
#  'houston',
#  'rayshard brooks',
#  'atlanta',
#  'chicago',
#  'america',
#  'mo.',
#  'jefferson city',
#  'missouri',
#  'accra',
#  'ukraine',
#  'us',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'boston',
#  'boston',
#  'maryland',
#  'east palo alto',
#  'silver spring',
#  'minneapolis',
#  'minneapolis',
#  'london',
#  'englewood',
#  'englewood',
#  'n.j.',
#  'new york',
#  'tar beach',
#  'harlem',
#  'japan',
#  'tokyo',
#  'new zealand',
#  'america',
#  'minneapolis',
#  'minnesota',
#  'america',
#  'minneapolis',
#  'minnesota',
#  'chicago',
#  'u.s.',
#  'u.s.',
#  'lafayette park',
#  'alexandria',
#  'dc',
#  'virginia',
#  'the united states',
#  'hollywood',
#  'melrose',
#  'california',
#  'u.s.',
#  'u.s.',
#  'u.s.',
#  'u.s.',
#  'raleigh',
#  'london',
#  'minneapolis',
#  'paris',
#  'us',
#  'the united states',
#  'minneapolis',
#  'u.s.',
#  'minnesota',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'michigan',
#  'berkeley',
#  'minneapolis',
#  'atlanta',
#  'atlanta',
#  'u.s.',
#  'japan',
#  'u.s.',
#  'belgium',
#  'new zealand',
#  'britain',
#  'germany',
#  'tokyo',
#  'australia',
#  'america',
#  'america',
#  'france',
#  'new zealand',
#  'minneapolis',
#  'seattle',
#  'capitol hill autonomous zone',
#  'us',
#  'columbus',
#  'georgia',
#  'minneapolis',
#  'louisville',
#  'woodburn',
#  'minneapolis',
#  'minneapolis',
#  'houston',
#  'minneapolis',
#  'atlanta',
#  'florence',
#  'nc',
#  'fayetteville',
#  'n.c.',
#  'fayetteville',
#  'tampa',
#  'minneapolis',
#  'atlanta',
#  'atlanta',
#  'minneapolis',
#  'us',
#  'u.s.',
#  'minneapolis',
#  'america',
#  'us',
#  'baltimore',
#  'cumberland county',
#  'fayetteville',
#  'paris',
#  'atlanta',
#  'london',
#  'california',
#  'minneapolis',
#  'atlanta',
#  'atlanta',
#  'minneapolis',
#  'baton rouge',
#  'cleveland',
#  'cleveland',
#  'cleveland',
#  'cleveland',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'redding',
#  'north state',
#  'siskiyou county',
#  'redding',
#  'texas',
#  'houston',
#  'lake county',
#  'gilead',
#  'stockton',
#  'stockton',
#  'minneapolis',
#  'minneapolis',
#  'texas',
#  'houston',
#  'temecula',
#  'minneapolis',
#  'ynez',
#  'murrieta',
#  'duck pond',
#  'montebello',
#  'temecula',
#  'coachella',
#  'america',
#  'elmhurst',
#  'minneapolis',
#  'mn',
#  'minnesota',
#  'minneapolis',
#  'hennepin county',
#  'minneapolis',
#  'zimbabwe',
#  'the united states',
#  'rayshard brooks',
#  'minneapolis',
#  'atlanta',
#  'rayshard brooks',
#  'atlanta',
#  'london',
#  'waterloo',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'walmart',
#  'walmart',
#  'walmart',
#  'st. paul',
#  'minneapolis',
#  'fresno',
#  'parkland',
#  'the state of new jersey',
#  'florida',
#  'virginia',
#  'fresno',
#  'pittsburgh',
#  'nj',
#  'charlottesville',
#  'minneapolis',
#  'america',
#  'patagonia',
#  'vietnam',
#  'st. john’s',
#  'washington',
#  'minneapolis',
#  'cleveland',
#  'minneapolis',
#  'atlanta',
#  'the united states',
#  'seattle',
#  'seattle',
#  'seattle',
#  'washington',
#  'minnesota',
#  'minneapolis',
#  'tri-city',
#  'minneapolis',
#  'seattle',
#  'washington',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'us',
#  'minneapolis',
#  'minneapolis',
#  'pensacola',
#  'the autonomous zone',
#  'minnesota',
#  'capitol hill autonomous zone',
#  'st. paul',
#  'san antonio',
#  'seattle',
#  'capitol hill autonomous zone’',
#  'seatle',
#  'minneapolis',
#  'us',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'hennepin county',
#  'sacramento unified',
#  'sacramento unified',
#  'sacramento unified',
#  'sacramento unified',
#  'sacramento unified',
#  'sacramento unified',
#  'minneapolis',
#  'minneapolis',
#  'riverhead',
#  '#ghana',
#  'ghana',
#  'america',
#  'minneapolis',
#  'north minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'houston',
#  'minneapolis',
#  'the united states',
#  'america',
#  'america',
#  'minneapolis',
#  'fort worth',
#  'michigan',
#  'minneapolis',
#  'us',
#  'the united states',
#  'the united states',
#  'america',
#  'the united states',
#  'chicago',
#  'minneapolis',
#  'concord',
#  'manchester',
#  'boston',
#  'mass.',
#  'minnesota',
#  'st. paul',
#  'chester county',
#  'minneapolis',
#  'minneapolis',
#  'santa cruz county',
#  'oakland',
#  'minneapolis',
#  'atlanta',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'america',
#  'ghana',
#  'america',
#  'minnesota',
#  'minneapolis',
#  'the united states',
#  'california',
#  'flushing.ny',
#  'vermont',
#  'washington',
#  'd-n.y.',
#  'kentucky',
#  'us',
#  'chester county',
#  'minneapolis',
#  'shreveport',
#  'louisiana',
#  'houston',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'milwaukee',
#  'new york',
#  'los angeles',
#  'southfield',
#  'the united states',
#  'benning',
#  'minneapolis',
#  'the united states',
#  'bragg',
#  'minneapolis',
#  'atlanta',
#  'atlanta',
#  'america',
#  'wisconsin',
#  'milwaukee county',
#  'wi',
#  'shorewood',
#  'tennessee',
#  'seattle',
#  'autonomous zone threat',
#  'u.s.',
#  'us',
#  'minneapolis',
#  'atlanta',
#  'minneapolis',
#  'atlanta',
#  'chicago',
#  'minneapolis',
#  'd.c.',
#  'ferguson',
#  'missouri',
#  'washington',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'the united states',
#  'u.s.',
#  'puerto rico',
#  'the united states',
#  'the united states',
#  'columbia',
#  'america',
#  'uk',
#  'uk',
#  'southfield',
#  'baltimore',
#  'phoenix',
#  'the united states',
#  'phoenix',
#  'the united states',
#  'milwaukee',
#  'philadelphia',
#  'the autonomous zone',
#  'minnesota',
#  'st. paul',
#  'san antonio',
#  'the united states',
#  'seattle',
#  'capitol hill autonomous zone’',
#  'minneapolis',
#  'atlanta',
#  'america',
#  'new york',
#  'los angeles',
#  'ferndale',
#  'minneapolis',
#  'michigan',
#  'michigan',
#  'dallas',
#  'minneapolis',
#  'texas',
#  'houston',
#  'hollywood',
#  'minneapolis',
#  'minneapolis',
#  'orlando',
#  'panama city',
#  'seattle',
#  'minneapolis',
#  'louisville',
#  'ky.',
#  'u.s.',
#  'st. john’s',
#  'san francisco',
#  'charleston',
#  'america',
#  'san fernando valley',
#  'san fernando valley',
#  'minneapolis',
#  'casper',
#  'new york city planned parenthood',
#  'u.s.',
#  'london',
#  'minneapolis',
#  'paris',
#  'us',
#  'the united states',
#  'montana',
#  'american west',
#  'deer lodge',
#  'ghost hunt',
#  'puerto rico',
#  'costa rica',
#  'colombia',
#  'brazil',
#  'nicaragua',
#  'panama',
#  'us',
#  'el salvador',
#  'cauca',
#  'chaz(capital hill autonomous zone',
#  'minneapolis',
#  'chaz(capital hill autonomous zone',
#  'minneapolis',
#  'chaz(capital hill autonomous zone',
#  'philadelphia',
#  'us',
#  "st. mary's general",
#  'minneapolis',
#  'santa monica',
#  'colorado',
#  'denver',
#  'minnesota',
#  'minneapolis',
#  '|',
#  'sue city',
#  'oakland',
#  'tulsa',
#  'okla.',
#  'minnesota',
#  'minneapolis',
#  'minneapolis',
#  'atlanta',
#  'ga.',
#  'hampton',
#  'texas',
#  'montgomery county public libraries',
#  'minneapolis',
#  'minneapolis',
#  'dallas',
#  'minneapolis',
#  'minneapolis',
#  'dallas',
#  'minneapolis',
#  'minneapolis',
#  'france',
#  'paris',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'nc',
#  'minneapolis',
#  'charlotte',
#  'minneapolis',
#  'u.s.',
#  'new york city',
#  'us',
#  'congressmember',
#  'america',
#  'minneapolis',
#  'atlanta',
#  'minnesota',
#  'u.s.',
#  'france',
#  'paris',
#  'america',
#  'us',
#  'minneapolis',
#  'germany',
#  'new zealand',
#  'berkeley',
#  'minneapolis',
#  'us',
#  'us',
#  'milwaukee',
#  'us',
#  'dc',
#  'minnesota',
#  'capitol hill autonomous zone',
#  'st. paul',
#  'the autonomous zone',
#  'seattle',
#  'capitol hill autonomous zone’',
#  'minneapolis',
#  'helena',
#  'seattle',
#  'capitol hill autonomous zone',
#  'america',
#  'america',
#  'u.s.',
#  'france',
#  'u.s.',
#  'france',
#  'u.s.',
#  'france',
#  'shrewsbury',
#  'ma',
#  'shrewsbury',
#  'richmond',
#  'd.c.',
#  'denver',
#  'ma',
#  'tulsa',
#  'birmingham',
#  'fulton county',
#  'portland',
#  'louisville',
#  'seattle',
#  'minn',
#  'alexandire',
#  'seattle pd',
#  'atlanta',
#  'va',
#  'u.s.',
#  'london',
#  'nyc',
#  'u.s.',
#  'london',
#  'nyc',
#  'minneapolis',
#  'sydney',
#  'paris',
#  'the united states',
#  'france',
#  'south africa',
#  'st. augustine’s',
#  'minneapolis',
#  'minneapolis',
#  'metro detroit',
#  'southfield',
#  'the autonomous zone',
#  'minnesota',
#  'https://www.washingtonpost.com/politics/2020/06/13/fox-news-removes-manipulated-images-coverage-seattle-protests/',
#  'st. paul',
#  'san antonio',
#  'seattle',
#  'capitol hill autonomous zone’',
#  'southfield',
#  'the autonomous zone',
#  'minnesota',
#  'https://www.washingtonpost.com/politics/2020/06/13/fox-news-removes-manipulated-images-coverage-seattle-protests/',
#  'st. paul',
#  'san antonio',
#  'seattle',
#  'capitol hill autonomous zone’',
#  'southfield',
#  'the autonomous zone',
#  'minnesota',
#  'https://www.washingtonpost.com/politics/2020/06/13/fox-news-removes-manipulated-images-coverage-seattle-protests/',
#  'st. paul',
#  'san antonio',
#  'seattle',
#  'capitol hill autonomous zone’',
#  'southfield',
#  'america',
#  'afghanistan',
#  'iraq',
#  'israel',
#  'mass.',
#  'america',
#  'san francisco',
#  'us',
#  'texas',
#  'houston',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'illinois',
#  'elgin',
#  'seattle',
#  'capitol hill autonomous zone',
#  'seattle',
#  'poly heights',
#  'minnesota',
#  'tx',
#  'fort worth',
#  'poly',
#  'seattle',
#  'america',
#  'california',
#  'florida',
#  'new york',
#  'marshall',
#  'missouri',
#  'minneapolis',
#  'louisville',
#  'houston',
#  'u.s.',
#  'nevada',
#  'las vegas',
#  'calif.',
#  'santa cruz',
#  'santa cruz',
#  'massachusetts',
#  'new mexico',
#  'florida',
#  'california',
#  'america',
#  'atlanta',
#  'minneapolis',
#  'los angeles',
#  'vt',
#  'los angeles',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'cincinnati',
#  'mn',
#  'bloomington ave',
#  'minneapolis',
#  'el colegio bancroft 4137',
#  'chicago ave',
#  'sheraton',
#  'oakland ave.',
#  'america',
#  'burbank',
#  'bakersfield',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'atlanta',
#  'buckhead',
#  'atlanta',
#  'minneapolis',
#  'atlanta',
#  'georgia',
#  'america',
#  'minneapolis',
#  'atlanta',
#  'atlanta',
#  'southfield',
#  'putnam county',
#  'southfield',
#  'minneapolis',
#  'washington d.c.',
#  'minneapolis',
#  'eddy county',
#  'eddy county courthouse',
#  'carlsbad',
#  'minnesota',
#  'minneapolis',
#  'utah',
#  'd.c.',
#  'america',
#  'st. paul',
#  'america',
#  'texas',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'brooklyn park',
#  'united states',
#  'minneapolis',
#  'st. paul',
#  'ramsey',
#  'rosemount',
#  'minneapolis',
#  'st. paul',
#  'france',
#  'netherlands',
#  'uk',
#  'lille',
#  'america',
#  'america',
#  'america',
#  'minneapolis',
#  'japan',
#  'tokyo',
#  'new zealand',
#  'seattle',
#  'seattle',
#  'minneapolis',
#  'minneapolis',
#  'columbus',
#  'massachusetts',
#  'brooklyn',
#  'us',
#  'massachusetts',
#  'north carolina',
#  'massachusetts',
#  'turkey',
#  'idaho',
#  'minneapolis',
#  '|',
#  'opelika',
#  'opelika',
#  'opelika',
#  'md.',
#  'minneapolis',
#  'd.c.',
#  'dundalk',
#  'america',
#  'the united states',
#  'frederick',
#  'va.',
#  'falls church',
#  'minneapolis',
#  'charleston',
#  'mount olivet',
#  'south carolina',
#  'america',
#  'st. paul',
#  'us',
#  'lutheran',
#  'alpharetta',
#  'utah',
#  'minneapolis',
#  'hong kong',
#  'china',
#  'belgium',
#  'the united states',
#  'new zealand',
#  'britain',
#  'hamilton',
#  'north carolina',
#  'minneapolis',
#  'raleigh',
#  'the united states',
#  "south carolina's",
#  'minneapolis',
#  'chicago',
#  'california',
#  'berkeley',
#  'calif.',
#  'minneapolis',
#  'long island',
#  'japan',
#  'tokyo',
#  'new zealand',
#  'minneapolis',
#  'milwaukee county',
#  'shorewood',
#  'wi',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'montreal',
#  'belfast',
#  'berlin',
#  'the united states',
#  'minneapolis',
#  'america',
#  'georgia',
#  'minneapolis',
#  'maryland',
#  'silver spring',
#  'rochester',
#  'delaware',
#  'us',
#  'texas',
#  'texas',
#  'allegheny county',
#  'allegheny county',
#  'allegheny county',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'us',
#  'new york',
#  'platteville',
#  'peaceful plates',
#  'the united states',
#  'atlanta',
#  'the united states',
#  'the united states',
#  'us',
#  ...]

# %%
c = collections.Counter()

# %%
dict_a=collections.Counter(list).most_common()

# %%
dict_a
# Out:
# [('minneapolis', 976),
#  ('america', 274),
#  ('u.s.', 235),
#  ('atlanta', 230),
#  ('the united states', 208),
#  ('minnesota', 147),
#  ('us', 131),
#  ('seattle', 84),
#  ('texas', 67),
#  ('new york', 65),
#  ('houston', 58),
#  ('california', 52),
#  ('washington', 51),
#  ('los angeles', 47),
#  ('tokyo', 45),
#  ('new zealand', 43),
#  ('md', 39),
#  ('japan', 38),
#  ('chicago', 36),
#  ('paris', 34),
#  ('france', 33),
#  ('virginia', 27),
#  ('st. paul', 27),
#  ('d.c.', 26),
#  ('las vegas', 26),
#  ('london', 25),
#  ('brooklyn', 24),
#  ('tulsa', 24),
#  ('hollywood', 23),
#  ('philadelphia', 22),
#  ('georgia', 21),
#  ('dallas', 20),
#  ('florida', 20),
#  ('richmond', 20),
#  ('oakland', 20),
#  ('north carolina', 19),
#  ('san francisco', 19),
#  ('michigan', 18),
#  ('new york city', 18),
#  ('palmdale', 18),
#  ('boston', 17),
#  ('australia', 17),
#  ('harris county', 16),
#  ('pittsburgh', 16),
#  ('phoenix', 15),
#  ('connecticut', 15),
#  ('lafayette park', 14),
#  ('capitol hill autonomous zone’', 14),
#  ('milwaukee', 14),
#  ('germany', 13),
#  ('louisville', 13),
#  ('calif.', 13),
#  ('ct', 13),
#  ('usa', 12),
#  ('cleveland', 12),
#  ('the autonomous zone', 12),
#  ('san antonio', 12),
#  ('ohio', 12),
#  ('memphis', 12),
#  ('berlin', 11),
#  ('united states', 11),
#  ('missouri', 11),
#  ('mn', 11),
#  ('southfield', 11),
#  ('nyc', 11),
#  ('detroit', 11),
#  ('fayetteville', 10),
#  ('arizona', 10),
#  ('massachusetts', 10),
#  ('maryland', 10),
#  ('raleigh', 10),
#  ('denver', 10),
#  ('portland', 10),
#  ('capitol hill autonomous zone', 9),
#  ('britain', 9),
#  ('canada', 9),
#  ('dc', 9),
#  ('n.c.', 9),
#  ('tampa', 9),
#  ('wisconsin', 9),
#  ('uk', 9),
#  ('okla.', 9),
#  ('victorville', 9),
#  ('mississippi', 9),
#  ('buffalo', 9),
#  ('mexico', 9),
#  ('alabama', 9),
#  ('sacramento', 9),
#  ('mlk', 9),
#  ('tenn.', 8),
#  ('nj', 8),
#  ('tennessee', 8),
#  ('charleston', 8),
#  ('montana', 8),
#  ('https://www.washingtonpost.com/politics/2020/06/13/fox-news-removes-manipulated-images-coverage-seattle-protests/',
#   8),
#  ('st. louis', 8),
#  ('new jersey', 8),
#  ('bridgeport', 8),
#  ('baltimore', 7),
#  ('the united states of america', 7),
#  ('mo.', 7),
#  ('belgium', 7),
#  ('columbus', 7),
#  ('brazil', 7),
#  ('afghanistan', 7),
#  ('spain', 7),
#  ('baptist', 7),
#  ('jesuit', 7),
#  ('ga', 7),
#  ('oklahoma city', 6),
#  ('pa.', 6),
#  ('sacramento unified', 6),
#  ('kentucky', 6),
#  ('charlotte', 6),
#  ('va.', 6),
#  ('tacoma', 6),
#  ('madrid', 6),
#  ('syria', 6),
#  ('denmark', 6),
#  ('poland', 6),
#  ('ireland', 6),
#  ('las cruces', 6),
#  ('u.s. park', 6),
#  ('bakersfield', 5),
#  ('israel', 5),
#  ('washington d.c.', 5),
#  ('alexandria', 5),
#  ('nc', 5),
#  ('walmart', 5),
#  ('chester county', 5),
#  ('louisiana', 5),
#  ('helena', 5),
#  ('illinois', 5),
#  ('santa cruz', 5),
#  ('cincinnati', 5),
#  ('petal', 5),
#  ('pennsylvania', 5),
#  ('athens', 5),
#  ('greece', 5),
#  ('dublin', 5),
#  ('binnish', 5),
#  ('mexico city', 5),
#  ('amsterdam', 5),
#  ('brussels', 5),
#  ('copenhagen', 5),
#  ('barcelona', 5),
#  ('auckland', 5),
#  ('lauderdale', 5),
#  ('dui', 5),
#  ('fl', 5),
#  ('s.c.', 5),
#  ('camden', 5),
#  ('los angeles sentinel', 5),
#  ('vallejo', 5),
#  ('third ward', 4),
#  ('cedar rapids', 4),
#  ('vegas', 4),
#  ('okla', 4),
#  ('west tennessee', 4),
#  ('ghana', 4),
#  ('hennepin county', 4),
#  ('north minneapolis', 4),
#  ('fort worth', 4),
#  ('santa cruz county', 4),
#  ('vermont', 4),
#  ('milwaukee county', 4),
#  ('wi', 4),
#  ('shorewood', 4),
#  ('ga.', 4),
#  ('birmingham', 4),
#  ('south africa', 4),
#  ('tx', 4),
#  ('new mexico', 4),
#  ('utah', 4),
#  ('south carolina', 4),
#  ('las vegas strip', 4),
#  ('washington dc', 4),
#  ('vt.', 4),
#  ('montpelier', 4),
#  ('indianapolis', 4),
#  ('jersey', 4),
#  ('hawaii', 4),
#  ('san diego', 4),
#  ('🇸', 4),
#  ('italy', 4),
#  ('india', 4),
#  ('ny', 4),
#  ('minn.', 4),
#  ('north dakota', 4),
#  ('capital hill', 4),
#  ('y’', 4),
#  ('greensboro', 4),
#  ('manhattan', 4),
#  ('antifa', 4),
#  ('antonio valenzuela', 4),
#  ('iran', 4),
#  ('ava park', 4),
#  ('pakistan', 4),
#  ('la', 3),
#  ('china', 3),
#  ('downtown okc', 3),
#  ('the lucas county courthouse', 3),
#  ('n.j.', 3),
#  ('rayshard brooks', 3),
#  ('jefferson city', 3),
#  ('accra', 3),
#  ('berkeley', 3),
#  ('baton rouge', 3),
#  ('redding', 3),
#  ('waterloo', 3),
#  ('fresno', 3),
#  ('vietnam', 3),
#  ('mass.', 3),
#  ('puerto rico', 3),
#  ('ky.', 3),
#  ('nicaragua', 3),
#  ('chaz(capital hill autonomous zone', 3),
#  ('colorado', 3),
#  ('hampton', 3),
#  ('nevada', 3),
#  ('chicago ave', 3),
#  ('opelika', 3),
#  ("south carolina's", 3),
#  ('long island', 3),
#  ('rochester', 3),
#  ('allegheny county', 3),
#  ('spokane', 3),
#  ('1 minneapolis', 3),
#  ('haiti', 3),
#  ('arkansas', 3),
#  ('sc', 3),
#  ('oklahoma', 3),
#  ('duluth', 3),
#  ('kingdom', 3),
#  ('nashville', 3),
#  ('marion', 3),
#  ('tallahassee', 3),
#  ('scotland', 3),
#  ('iowa', 3),
#  ('long beach', 3),
#  ('league city', 3),
#  ('king county', 3),
#  ('u.k.', 3),
#  ('bronx', 3),
#  ('dilworth', 3),
#  ('l.a.', 3),
#  ('portland city', 3),
#  ('orange county', 3),
#  ('karachi', 3),
#  ('palmdale ca', 3),
#  ('east oakland', 3),
#  ('chp', 3),
#  ('austin', 3),
#  ('sumter', 3),
#  ('los angeles sentinel executive', 3),
#  ('worcester', 3),
#  ('abita springs', 2),
#  ('hong kong', 2),
#  ('nj -', 2),
#  ('nutley', 2),
#  ('arlington', 2),
#  ('the district of columbia', 2),
#  ('suffolk', 2),
#  ('west', 2),
#  ('jerusalem', 2),
#  ('washoe county', 2),
#  ('kenya', 2),
#  ('ukraine', 2),
#  ('silver spring', 2),
#  ('englewood', 2),
#  ('florence', 2),
#  ('north state', 2),
#  ('lake county', 2),
#  ('stockton', 2),
#  ('temecula', 2),
#  ('charlottesville', 2),
#  ('st. john’s', 2),
#  ('tri-city', 2),
#  ('pensacola', 2),
#  ('concord', 2),
#  ('benning', 2),
#  ('columbia', 2),
#  ('ferndale', 2),
#  ('orlando', 2),
#  ('san fernando valley', 2),
#  ('el salvador', 2),
#  ('santa monica', 2),
#  ('|', 2),
#  ('shrewsbury', 2),
#  ('ma', 2),
#  ('metro detroit', 2),
#  ('turkey', 2),
#  ('idaho', 2),
#  ('bridgewater', 2),
#  ('christi', 2),
#  ('new hampshire', 2),
#  ('palm beach', 2),
#  ('punxsutawney', 2),
#  ('philando castile', 2),
#  ('| city', 2),
#  ('knoxville', 2),
#  ('decatur', 2),
#  ('macon county', 2),
#  ('belmont', 2),
#  ('boystown', 2),
#  ('drag queens', 2),
#  ('kings', 2),
#  ('lakeview chicago', 2),
#  ('halsted', 2),
#  ('selma', 2),
#  ('albany', 2),
#  ('los angeles county', 2),
#  ('the city of fayetteville', 2),
#  ('inner city', 2),
#  ('bristol', 2),
#  ('antwerp', 2),
#  ('middletown', 2),
#  ('santa monica boulevard', 2),
#  ('portugal', 2),
#  ('england', 2),
#  ('wilmington', 2),
#  ('district', 2),
#  ('ore.', 2),
#  ('miami beach', 2),
#  ('miami', 2),
#  ('east brunswick', 2),
#  ('fort bragg', 2),
#  ('tucson', 2),
#  ('jersey city', 2),
#  ('county', 2),
#  ('beijing', 2),
#  ('greenville', 2),
#  ('greenwood', 2),
#  ('clarksville', 2),
#  ('chauvin', 2),
#  ('rayshard brook', 2),
#  ('muskogee', 2),
#  ('winfield', 2),
#  ('ark city', 2),
#  ('fontana', 2),
#  ('hawley', 2),
#  ('san diego county', 2),
#  ('san onofre', 2),
#  ('fukushima', 2),
#  ('kenosha', 2),
#  ('omaha', 2),
#  ('guatemala', 2),
#  ('kingsport', 2),
#  ('peoria', 2),
#  ('west kentucky', 2),
#  ('new haven', 2),
#  ('scottsboro', 2),
#  ('dayton', 2),
#  ('anaheim', 2),
#  ('springfield', 2),
#  ('preplanned', 2),
#  ('iredell county', 2),
#  ('washington, dc', 2),
#  ('la.', 2),
#  ('ut', 2),
#  ('berrien county', 2),
#  ('boise', 2),
#  ('virginia beach', 2),
#  ('homewood', 2),
#  ('sunset', 2),
#  ('ala.', 2),
#  ('moorhead', 2),
#  ('brunswick', 2),
#  ('the kingdom of god', 2),
#  ('westfield', 2),
#  ('cook county', 1),
#  ('empire', 1),
#  ('jacksonville', 1),
#  ('marshfield', 1),
#  ('https://www.ghostcultmag.com/rage-against-the-machines-debut-album-returns-to-the-billboard-200-charts-on-the-strength-of-global-protests/',
#   1),
#  ('lafayette square', 1),
#  ('bull durham', 1),
#  ('cranbury', 1),
#  ('neverland', 1),
#  ('londo', 1),
#  ('the state of israel', 1),
#  ('palestine', 1),
#  ('bc', 1),
#  ('san mateo', 1),
#  ('sioux falls', 1),
#  ('s.d.', 1),
#  ('minessota', 1),
#  ('the maasai warriors', 1),
#  ('egypt', 1),
#  ('east palo alto', 1),
#  ('tar beach', 1),
#  ('harlem', 1),
#  ('melrose', 1),
#  ('woodburn', 1),
#  ('cumberland county', 1),
#  ('siskiyou county', 1),
#  ('gilead', 1),
#  ('ynez', 1),
#  ('murrieta', 1),
#  ('duck pond', 1),
#  ('montebello', 1),
#  ('coachella', 1),
#  ('elmhurst', 1),
#  ('zimbabwe', 1),
#  ('parkland', 1),
#  ('the state of new jersey', 1),
#  ('patagonia', 1),
#  ('seatle', 1),
#  ('riverhead', 1),
#  ('#ghana', 1),
#  ('manchester', 1),
#  ('flushing.ny', 1),
#  ('d-n.y.', 1),
#  ('shreveport', 1),
#  ('bragg', 1),
#  ('autonomous zone threat', 1),
#  ('ferguson', 1),
#  ('panama city', 1),
#  ('casper', 1),
#  ('new york city planned parenthood', 1),
#  ('american west', 1),
#  ('deer lodge', 1),
#  ('ghost hunt', 1),
#  ('costa rica', 1),
#  ('colombia', 1),
#  ('panama', 1),
#  ('cauca', 1),
#  ("st. mary's general", 1),
#  ('sue city', 1),
#  ('montgomery county public libraries', 1),
#  ('congressmember', 1),
#  ('fulton county', 1),
#  ('minn', 1),
#  ('alexandire', 1),
#  ('seattle pd', 1),
#  ('va', 1),
#  ('sydney', 1),
#  ('st. augustine’s', 1),
#  ('iraq', 1),
#  ('elgin', 1),
#  ('poly heights', 1),
#  ('poly', 1),
#  ('marshall', 1),
#  ('vt', 1),
#  ('bloomington ave', 1),
#  ('el colegio bancroft 4137', 1),
#  ('sheraton', 1),
#  ('oakland ave.', 1),
#  ('burbank', 1),
#  ('buckhead', 1),
#  ('putnam county', 1),
#  ('eddy county', 1),
#  ('eddy county courthouse', 1),
#  ('carlsbad', 1),
#  ('brooklyn park', 1),
#  ('ramsey', 1),
#  ('rosemount', 1),
#  ('netherlands', 1),
#  ('lille', 1),
#  ('md.', 1),
#  ('dundalk', 1),
#  ('frederick', 1),
#  ('falls church', 1),
#  ('mount olivet', 1),
#  ('lutheran', 1),
#  ('alpharetta', 1),
#  ('hamilton', 1),
#  ('montreal', 1),
#  ('belfast', 1),
#  ('delaware', 1),
#  ('platteville', 1),
#  ('peaceful plates', 1),
#  ('maine', 1),
#  ("king county's", 1),
#  ('los angeles county sheriff', 1),
#  ('shalamar', 1),
#  ('lancaster county', 1),
#  ('san dimas', 1),
#  ('guadalajara', 1),
#  ('sunbury', 1),
#  ('nueces county', 1),
#  ('robstown', 1),
#  ('nueces', 1),
#  ('burlington', 1),
#  ('carbondale', 1),
#  ("northern new mexico's", 1),
#  ('northern new mexico', 1),
#  ('salinas', 1),
#  ('bronsan', 1),
#  ('the city of southfield', 1),
#  ('hartford', 1),
#  ('shaker heights', 1),
#  ('states', 1),
#  ('chester', 1),
#  ('bronzeville', 1),
#  ('hilo', 1),
#  ('mauna kea, kahuku', 1),
#  ('kōkua', 1),
#  ('free hawaii', 1),
#  ('ekeren', 1),
#  ('southeast portland', 1),
#  ('the divided states of america', 1),
#  ('berwick', 1),
#  ('philly', 1),
#  ('johnson city', 1),
#  ('san diego orgs', 1),
#  ('juso schweiz', 1),
#  ('el centro', 1),
#  ('pennsbury', 1),
#  ('kennett township', 1),
#  ('bethel', 1),
#  ('kennett square', 1),
#  ('el paso', 1),
#  ('san quentin', 1),
#  ('hungary', 1),
#  ('senegal', 1),
#  ('sweden', 1),
#  ('switzerland', 1),
#  ('south korea', 1),
#  ('parkside', 1),
#  ('wayne county', 1),
#  ('russia', 1),
#  ('mumbai', 1),
#  ('delhi', 1),
#  ('stowe', 1),
#  ('litchfield', 1),
#  ('east setauket', 1),
#  ('village inn', 1),
#  ('salem', 1),
#  ('atlantic city', 1),
#  ('pleasantville', 1),
#  ('georgetown', 1),
#  ('glendale', 1),
#  ('ky', 1),
#  ('bowdoin', 1),
#  ('tamaqua', 1),
#  ('toledo', 1),
#  ('williamsburg', 1),
#  ('fort gordon', 1),
#  ('brandywine', 1),
#  ('mount vernon', 1),
#  ('warsaw', 1),
#  ('germantown', 1),
#  ('short hills', 1),
#  ('monmouth', 1),
#  ('saratoga', 1),
#  ('fort kościuszko', 1),
#  ('fort benning', 1),
#  ('fort pulaski', 1),
#  ('pulaski', 1),
#  ('yorktown', 1),
#  ('fort pitt', 1),
#  ('breton', 1),
#  ('@daniellebelardomd', 1),
#  ('protesting—@jessicashepherdmd', 1),
#  ('allendale', 1),
#  ('pine ave.', 1),
#  ('grand rapids', 1),
#  ('graniteville', 1),
#  ('staten island', 1),
#  ('pennsylvania ave', 1),
#  ('loyalness', 1),
#  ('dorn', 1),
#  ('bellingham', 1),
#  ('mount pleasant', 1),
#  ('tarrant county jail', 1),
#  ('tarrant county', 1),
#  ('haddon', 1),
#  ('haddon ave', 1),
#  ('capitol hill', 1),
#  ('allentown', 1),
#  ('pa', 1),
#  ('bham', 1),
#  ('horry county', 1),
#  ('lemon grove', 1),
#  ('benton', 1),
#  ('carolinas', 1),
#  ('yakima', 1),
#  ('yakima county', 1),
#  ('franklin', 1),
#  ('miami-dade', 1),
#  ('miami lakes', 1),
#  ('usc', 1),
#  ('chico', 1),
#  ('wa', 1),
#  ('autonomous zone', 1),
#  ('south tampa', 1),
#  ('https://naacpldf.org', 1),
#  ('bettysoo', 1),
#  ('waller county pd', 1),
#  ('hempstead', 1),
#  ('kiwanis', 1),
#  ('district of kiwanis', 1),
#  ('flint', 1),
#  ('cairo', 1),
#  ('longview', 1),
#  ('rockingham county', 1),
#  ('madison', 1),
#  ('franklinville', 1),
#  ('el paso walmart', 1),
#  ('backed soviet union', 1),
#  ('cornish', 1),
#  ('zephyrhills', 1),
#  ('king county/metro', 1),
#  ('vashon', 1),
#  ('baldwin', 1),
#  ('roosevelt', 1),
#  ('fitchburg', 1),
#  ('mobile', 1),
#  ('fulton', 1),
#  ('the city of auxvasse', 1),
#  ('callaway county', 1),
#  ('singapore', 1),
#  ('malaysia', 1),
#  ('srilanka', 1),
#  ('sanford', 1),
#  ('yellow springs', 1),
#  ('idaho city', 1),
#  ('marin', 1),
#  ('marin county’s', 1),
#  ('suffolk county', 1),
#  ('nassau county', 1),
#  ('the black diaspora', 1),
#  ('hallandale beach', 1),
#  ('neb.', 1),
#  ('squirrel hill', 1),
#  ('az', 1),
#  ('jacobi', 1),
#  ('minto', 1),
#  ('lakewood', 1),
#  ('chinatown', 1),
#  ('shoreview', 1),
#  ('montgomery county', 1),
#  ('the city of greensboro', 1),
#  ('yyyuuugggeeeeeeeeeeee', 1),
#  ('lafayette', 1),
#  ('le', 1),
#  ('au guatemala', 1),
#  ('chimay', 1),
#  ('hillsborough', 1),
#  ('pearland', 1),
#  ('lexington', 1),
#  ('quincy', 1),
#  ('lassen county', 1),
#  ('susanville', 1),
#  ('houma', 1),
#  ('humboldt county', 1),
#  ('minnea', 1),
#  ('oregon', 1),
#  ('george park', 1),
#  ('diamond bar', 1),
#  ('la county', 1),
#  ('capital hill autonomous zone', 1),
#  ('hill autonomous zone', 1),
#  ('brittany', 1),
#  ('washtenaw', 1),
#  ('los lunas', 1),
#  ('gonzales', 1),
#  ('https://www.ajc.com/news/opinion/opinion-equality-still-remains-elusive-goal/dprtz2csjof7pcfvlr2stk/',
#   1),
#  ('riverdale', 1),
#  ('🥰', 1),
#  ('kalispell', 1),
#  ('bozeman', 1),
#  ('great falls', 1),
#  ('pinellas county', 1),
#  ('st. petersburg', 1),
#  ('south boston', 1),
#  ('mass', 1),
#  ('@docandcompany', 1),
#  ('compton', 1),
#  ('churchill', 1),
#  ('united kingdom', 1),
#  ('the united kingdom', 1),
#  ('daytona', 1),
#  ('the city of portland', 1),
#  ('north carolina’s', 1),
#  ('santa ana', 1),
#  ('sf', 1),
#  ('oakland county', 1),
#  ("the district attorney's", 1),
#  ('granada hills', 1),
#  ('kingston', 1),
#  ('warren', 1),
#  ('newark', 1),
#  ('new orleans', 1),
#  ('okc', 1),
#  ('libya', 1),
#  ('south sudan', 1),
#  ('myanmar', 1),
#  ("new york city's", 1),
#  ('new york city’s', 1),
#  ('salt lake', 1),
#  ('south minneapolis', 1),
#  ('monticello', 1),
#  ('cristal staten', 1),
#  ('rockford', 1),
#  ('sindh', 1),
#  ('🏼new jersey’s', 1),
#  ('yasharahla', 1),
#  ('the british empire', 1),
#  ('leicester', 1),
#  ('downtown fresno', 1),
#  ('chaz', 1),
#  ('stratford', 1),
#  ('sacramento county', 1),
#  ('new zealand / aotearoa', 1),
#  ('napier', 1),
#  ('honolulu', 1),
#  ('hnl', 1),
#  ('mineral county', 1),
#  ('west virginia', 1),
#  ('wuhan', 1),
#  ('walker', 1),
#  ('livingston parish', 1),
#  ('northeas', 1),
#  ('st. joseph', 1),
#  ('benton harbor', 1),
#  ('honduras', 1),
#  ('kibera', 1),
#  ('http://nbcct.co/stgdk0r', 1),
#  ('hosp.', 1),
#  ('mclean county', 1),
#  ('hosp', 1),
#  ('bloomington', 1),
#  ('https://theshaderoom.com/barbra-streisand-gifts-george-floyds-daughter-gianna-floyd-with-stock-in-disney/',
#   1),
#  ('disney', 1),
#  ('fort ulysses s. grant', 1),
#  ('fort george', 1),
#  ('northampton', 1),
#  ('juneteenth', 1),
#  ('s.f.', 1),
#  ('rust belt ohio', 1),
#  ('battleground states', 1),
#  ('edmonston', 1),
#  ('prince george’s county', 1),
#  ("prince george's county", 1),
#  ('dundee', 1),
#  ('waco', 1),
#  ('st. pete', 1),
#  ('san joaquin county', 1),
#  ('ocean beach', 1),
#  ('north carolina\n', 1),
#  ('durham', 1),
#  ('catalonia', 1),
#  ('kent state', 1),
#  ('park county', 1),
#  ('faribault', 1),
#  ('paypal.me/decarceratemn', 1),
#  ('westchester', 1),
#  ("north omaha's", 1),
#  ('north omaha', 1),
#  ('harrisburg', 1),
#  ('lawrence county', 1),
#  ('ellwood city', 1),
#  ('beaver county', 1),
#  ('aliquippa', 1),
#  ('the city of mason', 1),
#  ('warren county', 1),
#  ('colorado springs', 1),
#  ("new york's", 1),
#  ('las', 1),
#  ('munich', 1),
#  ('salisbury', 1),
#  ('california chiles', 1),
#  ('wheatville', 1),
#  ('philippines', 1),
#  ('rucker', 1),
#  ('bataan', 1),
#  ('korea', 1),
#  ('south dakota', 1),
#  ('york', 1),
#  ('the buffalo soldiers', 1),
#  ('queens borough', 1),
#  ('may.', 1),
#  ("san antonio's", 1),
#  ('pleasant valley', 1),
#  ('new wentzvillian', 1),
#  ('st. louis county executive', 1),
#  ('north haven', 1),
#  ('yonkers', 1),
#  ("david shire's", 1),
#  ('galveston', 1),
#  ('•', 1),
#  ('trinidad', 1),
#  ('durant park', 1),
#  ('love park', 1),
#  ('new jersey mock george floyd killing', 1),
#  ('western north carolina', 1),
#  ('topeka', 1),
#  ('norway', 1),
#  ('greendale', 1),
#  ('guam', 1),
#  ('district superintendent', 1),
#  ('bahamas', 1),
#  ('greensburg', 1),
#  ('boxborough', 1),
#  ('mattapan', 1),
#  ('acton', 1),
#  ('schenectady', 1),
#  ('schenectady county', 1),
#  ('city', 1),
#  ('wilberforce', 1),
#  ('franklin county', 1),
#  ('traverse city', 1),
#  ('corpus', 1),
#  ('avila', 1),
#  ('st. teresa', 1),
#  ('http://nypost.com/2020/06/12/derek-chauvin-ex-cop-charged-in-george-floyd-death-could-get-1-5m-in-benefits/',
#   1),
#  ('queens', 1),
#  ('new kensington’s', 1),
#  ('new kensington', 1),
#  ('indiana', 1),
#  ('state', 1)]

# %%
dataframe611=pd.DataFrame(dict_a)

# %%
len(dict_a)
# Out:
# 813

# %%
# %cd dataframe_csv
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/dataframe_csv

# %%
# !ls
# Out:
# dataframe0529.csv  dataframe0602.csv  dataframe0606.csv  dataframe0610.csv
# dataframe0530.csv  dataframe0603.csv  dataframe0607.csv  dataframe0611.csv
# dataframe0531.csv  dataframe0604.csv  dataframe0608.csv  heatmap.csv
# dataframe0601.csv  dataframe0605.csv  dataframe0609.csv

# %%
dataframe611.to_csv('dataframe0614.csv')
