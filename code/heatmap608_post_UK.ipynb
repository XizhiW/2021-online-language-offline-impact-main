# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 948 kB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK		       dataframe_result_csv_EU
#  a0529-a0611_US		       dataframe_result_csv_UK
#  a0605.csv		       Github
#  a0608.csv		       heatmap529_UK.ipynb
#  a0609.csv		       heatmap530.ipynb
#  ccc_compiled.csv	       Heat_Map_Online_language.ipynb
#  csv			       __MACOSX
#  csv.zip		       mapping_UK
#  dataframe_csv		       mapping_US
#  dataframe_csv_EU	       non_violant1.csv
#  dataframe_csv_UK	       non_violant2.csv
#  dataframe_result_529_UK.csv   UK
#  dataframe_result_530_UK.csv   violant.csv
#  dataframe_result_531_UK.csv  '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_result_csv

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct=pd.read_csv('a0529-a0611_UK/a0608.csv',encoding='ISO-8859-1')

# %%
# !ls
# Out:
#  a0529-a0611_UK		       dataframe_result_csv_EU
#  a0529-a0611_US		       dataframe_result_csv_UK
#  a0605.csv		       Github
#  a0608.csv		       heatmap529_UK.ipynb
#  a0609.csv		       heatmap530.ipynb
#  ccc_compiled.csv	       Heat_Map_Online_language.ipynb
#  csv			       __MACOSX
#  csv.zip		       mapping_UK
#  dataframe_csv		       mapping_US
#  dataframe_csv_EU	       non_violant1.csv
#  dataframe_csv_UK	       non_violant2.csv
#  dataframe_result_529_UK.csv   UK
#  dataframe_result_530_UK.csv   violant.csv
#  dataframe_result_531_UK.csv  '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_result_csv

# %%
###
#ct=pd.read_csv('a0601.csv')

# %%
ct
# Out:
#        Unnamed: 0  ...    NER-title
# 0               0  ...           {}
# 1               1  ...           {}
# 2               2  ...    {'US': 1}
# 3               3  ...           {}
# 4               4  ...           {}
# ...           ...  ...          ...
# 25298       25298  ...           {}
# 25299       25299  ...           {}
# 25300       25300  ...  {'Ohio': 1}
# 25301       25301  ...  {'Ohio': 1}
# 25302       25302  ...  {'Ohio': 1}
#
# [25303 rows x 51 columns]

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
#ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
###
ct_ner = ct

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                       NER-msg            NER-desc  NER-title
# 0                          {}  {'Minneapolis': 1}         {}
# 1                   {'US': 1}    {'Minnesota': 1}         {}
# 2  {'Washington': 1, 'US': 1}           {'US': 1}  {'US': 1}
# 3                          {}           {'US': 1}         {}
# 4              {'America': 1}                  {}         {}

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))

# %%
ct_ner['NER-msg']
# Out:
# 0                           []
# 1                         [US]
# 2             [US, Washington]
# 3                           []
# 4                    [America]
#                  ...
# 25298            [Houston, TX]
# 25299    [New York City, U.S.]
# 25300                   [Ohio]
# 25301      [America, Brooklyn]
# 25302                       []
# Name: NER-msg, Length: 25303, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']

# %%
ct_ner['NER']
# Out:
# 0                               [Minneapolis]
# 1                             [US, Minnesota]
# 2                    [US, Washington, US, US]
# 3                                        [US]
# 4                                   [America]
#                          ...
# 25298              [Houston, TX, Minneapolis]
# 25299    [New York City, U.S., New York City]
# 25300                      [Ohio, Ohio, Ohio]
# 25301         [America, Brooklyn, Ohio, Ohio]
# 25302                            [Ohio, Ohio]
# Name: NER, Length: 25303, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])

# %%
ct_ner
# Out:
#        Unnamed: 0  ...                         NER
# 0               0  ...               [minneapolis]
# 1               1  ...             [minnesota, us]
# 2               2  ...            [us, washington]
# 3               3  ...                        [us]
# 4               4  ...                   [america]
# ...           ...  ...                         ...
# 25298       25298  ...  [houston, tx, minneapolis]
# 25299       25299  ...       [new york city, u.s.]
# 25300       25300  ...                      [ohio]
# 25301       25301  ...   [brooklyn, america, ohio]
# 25302       25302  ...                      [ohio]
#
# [25303 rows x 52 columns]

# %%
ct_ner['NER-1']=ct_ner['NER']

# %%
ct_ner['NER-1'][1]
# Out:
# ['minnesota', 'us']

# %%
# !pip install -q geopy
# !pip install -q pyproj

# basic utilities
import json
import requests
import pandas as pd
import pprint
import time

# reverse geocoding utilities
from geopy.geocoders import Nominatim

# geography projection utilities
import pyproj
from shapely.ops import transform
from shapely.geometry import Point
from functools import partial
# Out:
#      |████████████████████████████████| 6.3 MB 5.2 MB/s

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_ner
# Out:
#        Unnamed: 0  ...                       NER-1
# 0               0  ...               [minneapolis]
# 1               1  ...             [minnesota, us]
# 2               2  ...            [us, washington]
# 3               3  ...                        [us]
# 4               4  ...                   [america]
# ...           ...  ...                         ...
# 25298       25298  ...  [houston, tx, minneapolis]
# 25299       25299  ...       [new york city, u.s.]
# 25300       25300  ...                      [ohio]
# 25301       25301  ...   [brooklyn, america, ohio]
# 25302       25302  ...                      [ohio]
#
# [25303 rows x 53 columns]

# %%
# %cd mapping_UK
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/mapping_UK

# %%
# !ls
# Out:
# dataframe0529_post.csv	dataframe0606_post.csv	    dataframe_mapping_0605.csv
# dataframe0530_post.csv	dataframe_mapping_0529.csv  dataframe_mapping_0606.csv
# dataframe0531_post.csv	dataframe_mapping_0530.csv  dataframe_mapping_0607.csv
# dataframe0601_post.csv	dataframe_mapping_0531.csv  dataframe_mapping_0608.csv
# dataframe0602_post.csv	dataframe_mapping_0601.csv  dataframe_mapping_0609.csv
# dataframe0603_post.csv	dataframe_mapping_0602.csv  dataframe_mapping_0610.csv
# dataframe0604_post.csv	dataframe_mapping_0603.csv  dataframe_mapping_0611.csv
# dataframe0605_post.csv	dataframe_mapping_0604.csv

# %%
ct_mapping=pd.read_csv('dataframe_mapping_0608.csv',encoding='ISO-8859-1')

# %%
len(ct_mapping['City'])
# Out:
# 3332

# %%
len(ct_ner['NER-1'])
# Out:
# 25303

# %%
for k in range(len(ct_ner['NER-1'])):
  list=[]
  for i in ct_ner['NER-1'][k]:
    for j in range(len(ct_mapping['City'])):
      if(i==ct_mapping['City'][j]):
        list.append(ct_mapping['Mapping'][j])
  ct_ner['NER-1'][k]=list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
ct_ner
# Out:
#        Unnamed: 0  ...                                              NER-1
# 0               0  ...  [Minneapolis, Hennepin County, Minnesota, 5541...
# 1               1  ...          [Minnesota, United States, United States]
# 2               2  ...  [United States, Washington, District of Columb...
# 3               3  ...                                    [United States]
# 4               4  ...   [America, Horst aan de Maas, Limburg, Nederland]
# ...           ...  ...                                                ...
# 25298       25298  ...  [Houston, Harris County, Texas, United States,...
# 25299       25299  ...  [New York, United States, Unterer See, Kirchhe...
# 25300       25300  ...                              [Ohio, United States]
# 25301       25301  ...  [Brooklyn, Kings County, New York, United Stat...
# 25302       25302  ...                              [Ohio, United States]
#
# [25303 rows x 53 columns]

# %%
ct_ner['NER-1'][12]
# Out:
# ['The Summit, Guadalupe County, Texas, United States']

# %%
ct_ner.to_csv('dataframe0608_post.csv')
