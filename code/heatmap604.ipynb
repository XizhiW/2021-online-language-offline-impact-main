# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.0/en_core_web_lg-2.2.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.0/en_core_web_lg-2.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.0/en_core_web_lg-2.2.0.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 4.4 kB/s
# Requirement already satisfied: spacy>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.0) (2.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (2.23.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (4.62.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (3.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (57.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.19.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (7.4.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.0->en-core-web-lg==2.2.0) (4.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.0->en-core-web-lg==2.2.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.0->en-core-web-lg==2.2.0) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-lg==2.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-lg==2.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-lg==2.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-lg==2.2.0) (2021.5.30)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.0-py3-none-any.whl size=829187827 sha256=03399b2582b356af6c7e562617ae3a00020be87bcc2667544f5ce0ccd5194b2d
#   Stored in directory: /root/.cache/pip/wheels/4b/6e/87/8b129988ba4d66c064415e09db36d5945b638aabcaf8f41765
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.0

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.9 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
#  Xizhi_Wu_UnderGrad_Transcript.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529.csv   csv	        Heat_Map_Online_language.ipynb
#  a0530.csv   csv.zip	        __MACOSX
#  a0531.csv   dataframe_csv      non_violant1.csv
#  a0601.csv   Github	        non_violant2.csv
#  a0602.csv   heatmap530.ipynb   violant.csv
#  a0603.csv   heatmap531.ipynb  '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_604 = 'csv/US06_04.csv'

# %%
ct = pd.read_csv(ct_path_604)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                               platformId  ...                    post_id
# 0       494739473885296_4400310719994799  ...   2054267|4400310719994799
# 1       121306027893052_3238007812889509  ...   3208429|3238007812889509
# 2      1453936424864551_2678215189103329  ...  12994430|2678215189103329
# 3         201170940075_10163668330810076  ...    12200|10163668330810076
# 4       463428970501884_1585191744992262  ...    446429|1585191744992262
# ...                                  ...  ...                        ...
# 24857      48010180735_10157191451090736  ...    20348|10157191451090736
# 24858      57237502362_10158537137187363  ...    23843|10158537137187363
# 24859      29223626655_10157744615491656  ...   306159|10157744615491656
# 24860     215199900044_10163927750645045  ...    18477|10163927750645045
# 24861      16780999098_10158401361969099  ...    51136|10158401361969099
#
# [24862 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#                 NER-msg            NER-desc
# 0  {'Nevada County': 1}                  {}
# 1                    {}                  {}
# 2    {'Minneapolis': 1}  {'Minneapolis': 1}
# 3                    {}                  {}
# 4                    {}                  {}

# %%
ct.to_csv('a0604.csv')

# %%
ct=pd.read_csv('a0604.csv')

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                 NER-msg            NER-desc           NER-title
# 0  {'Nevada County': 1}                  {}  {'Minneapolis': 1}
# 1                    {}                  {}  {'Minneapolis': 1}
# 2    {'Minneapolis': 1}  {'Minneapolis': 1}  {'Minneapolis': 1}
# 5                    {}  {'MINNEAPOLIS': 1}  {'Minneapolis': 1}
# 6          {'Floyd': 1}        {'Floyd': 1}                  {}

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ct_ner['NER-msg']
# Out:
# 0        [Nevada County]
# 1                     []
# 2          [Minneapolis]
# 5                     []
# 6                [Floyd]
#               ...
# 24853      [Mississippi]
# 24854                 []
# 24855          [Oakland]
# 24856                 []
# 24857                 []
# Name: NER-msg, Length: 16666, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ct_ner['NER']
# Out:
# 0                   [Nevada County, Minneapolis]
# 1                                  [Minneapolis]
# 2        [Minneapolis, Minneapolis, Minneapolis]
# 5                     [MINNEAPOLIS, Minneapolis]
# 6                                 [Floyd, Floyd]
#                           ...
# 24853    [Mississippi, Mississippi, Mississippi]
# 24854         [Washington, Minneapolis, Seattle]
# 24855                [Oakland, Oakland, Oakland]
# 24856                       [Missoula, Missoula]
# 24857                       [Hartford, Hartford]
# Name: NER, Length: 16666, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ner_lst = ct_ner['NER'].values

# %%
ner_lst
# Out:
# array([list(['minneapolis', 'nevada county']), list(['minneapolis']),
#        list(['minneapolis']), ..., list(['oakland']), list(['missoula']),
#        list(['hartford'])], dtype=object)

# %%
m=0
list=[]
for n in ner_lst:
  for i in range(len(n)):
    list.append(ner_lst[m][i])
  m+=1

# %%
list
# Out:
# ['minneapolis',
#  'nevada county',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'floyd',
#  'new york',
#  'syracuse',
#  'america',
#  'minneapolis',
#  'oakland',
#  'contra costa county',
#  'alameda county',
#  'bay county',
#  'bay county',
#  'chicago',
#  'minneapolis',
#  'illinois',
#  'washington',
#  'winston-salem',
#  'america',
#  'u.s.',
#  'alaska',
#  'ketchikan',
#  'kotzebue',
#  'alaska',
#  'ketchikan',
#  'kotzebue',
#  'us',
#  'alaska',
#  'kennis@iastate.edu',
#  'ahmaud arbery',
#  'ketchikan',
#  'kotzebue',
#  'america',
#  'america',
#  'america',
#  'somerville',
#  'america',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'minn.',
#  'minnesota',
#  'mn',
#  'florida',
#  'arizona',
#  'minneapolis',
#  'philando castile',
#  'miami',
#  'south florida',
#  'minneapolis',
#  'miami',
#  'south florida',
#  'minneapolis',
#  'america',
#  'texas',
#  'texas',
#  'minneapolis',
#  'america',
#  'america',
#  'florida',
#  'minneapolis',
#  'dubuque',
#  'iowa',
#  'columbus',
#  'ohio',
#  '@alimofun',
#  'texas',
#  'texas',
#  'texas',
#  'texas',
#  'suffolk',
#  'washington',
#  'california',
#  'usa',
#  'houston',
#  'minneapolis',
#  'north carolina',
#  'raeford',
#  'houston',
#  'ny',
#  'minneapolis',
#  'usa',
#  'minneapolis',
#  'u.s.',
#  'minnesota',
#  'tx',
#  'america',
#  'america',
#  'america',
#  'minneapolis',
#  'texas',
#  'america',
#  'america',
#  'america',
#  'america',
#  'america',
#  'minnesota',
#  'america',
#  'hyattsville',
#  'america',
#  'cedar rapids',
#  'iowa',
#  'cedar rapids - around 40',
#  'fayetteville',
#  'minnesota',
#  'minneapolis',
#  'washington',
#  'manitowoc',
#  'san francisco',
#  'saybrook township',
#  'ohio',
#  'minneapolis',
#  'alabama',
#  'minnesota',
#  'troy',
#  'troy',
#  'ala.',
#  'alabama',
#  'paris',
#  'minnesota',
#  'oklahoma',
#  'paris',
#  'america',
#  'troy',
#  'troy',
#  'ala.',
#  'minneapolis',
#  'texas',
#  'us',
#  'north carolina',
#  'dallas',
#  'north carolina',
#  'north carolina',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'america',
#  'new orleans',
#  "the united states'",
#  'minneapolis',
#  'the united states',
#  "the united states'",
#  'minneapolis',
#  'brown',
#  'arzadon',
#  'lawrence county',
#  'bexar county',
#  'minneapolis',
#  'bexar county',
#  'minneapolis',
#  'mass.',
#  'somerville',
#  'jamaica plain',
#  'wisconsin',
#  'milwaukee',
#  'minneapolis',
#  'king county',
#  'seattle',
#  'minneapolis',
#  'king county',
#  'seattle',
#  'new york',
#  'brooklyn',
#  'minneapolis',
#  'las vegas',
#  'minnesota',
#  'philadelphia',
#  'texas',
#  'minneapolis',
#  'us',
#  'united states',
#  'saint paul',
#  'guadalupe',
#  'minneapolis',
#  'the united states',
#  'us',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'salem',
#  'minnesota',
#  'seattle',
#  'ore.',
#  'eugene',
#  'minneapolis',
#  'portland',
#  'oregon',
#  'houston',
#  'north carolina',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'north dakota',
#  'los angeles',
#  'america',
#  'woodbury hts',
#  'woodbury heights',
#  'south jersey',
#  'u.s.',
#  'london',
#  'l.a.',
#  'china',
#  'hungary',
#  'u.s.',
#  'america',
#  'libya',
#  'yemen',
#  'the united states',
#  'bahrain',
#  'cuba',
#  'russia',
#  'the soviet union',
#  'turkey',
#  'the soviet union',
#  'havana',
#  'the united states',
#  'washington',
#  'ohio',
#  'columbus',
#  'u.s.',
#  'columbus',
#  'congo',
#  'belgium',
#  'america',
#  'minneapolis',
#  'niagara county',
#  'niagara',
#  'the united states',
#  'the united states',
#  'springfield',
#  'nj',
#  'brooklyn',
#  'minneapolis',
#  'the united states of america',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'portland',
#  'minneapolis',
#  'minneapolis',
#  'us',
#  'minnesota',
#  'modesto',
#  'modesto city',
#  'south georgia',
#  'georgia',
#  'us',
#  'america',
#  'washington',
#  'los angeles',
#  'new york',
#  'minneapolis',
#  'america',
#  'kimberly york',
#  'las cruces',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'taos',
#  'minneapolis',
#  'minneapolis',
#  'franklin',
#  'keene',
#  'nh',
#  'new hampshire',
#  'hennepin county district court',
#  'minneapolis',
#  'hennepin county district court',
#  'minneapolis',
#  'solidaridad',
#  'bondad',
#  'nosotros',
#  'maldad',
#  'coatesville',
#  'america',
#  'oakland',
#  'alameda county',
#  'alameda county',
#  'alameda county',
#  'michigan',
#  'minneapolis',
#  'champaign county casa',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'us',
#  'd.c.',
#  'lafayette park',
#  'los angeles',
#  'minneapolis',
#  'd.c.',
#  'lafayette park',
#  'minneapolis',
#  'los angeles',
#  'cleveland',
#  'new york',
#  'd.c.',
#  'lafayette park',
#  'los angeles',
#  'minnesota',
#  'tacoma',
#  'tacoma',
#  'wash.',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'new york',
#  'washington',
#  'washington',
#  'd.c.',
#  'lafayette park',
#  'los angeles',
#  'new york',
#  'minneapolis',
#  'new york',
#  'new york',
#  'san jose',
#  'new york',
#  'las vegas',
#  'd.c.',
#  'lafayette park',
#  'los angeles',
#  'new york',
#  'new york',
#  'new york',
#  'ahmaud arbery',
#  'minneapolis',
#  'minneapolis',
#  'new york',
#  'minneapolis',
#  'u.s.',
#  'u.s.',
#  'new york',
#  'brooklyn',
#  'minneapolis',
#  'ny',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'windsor',
#  'ywca',
#  'connecticut',
#  'hartford',
#  'ct',
#  'minneapolis',
#  'minneapolis',
#  'brooklyn',
#  'minneapolis',
#  'minneapolis',
#  'north carolina',
#  'minneapolis',
#  'raeford',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'mn',
#  'minneapolis',
#  'america',
#  'bel air',
#  'minneapolis',
#  'minneapolis',
#  'denver',
#  'america',
#  'minneapolis',
#  'ame',
#  'texas',
#  'texas',
#  'minneapolis',
#  'virginia',
#  'us',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'nc',
#  'hickory',
#  'nc',
#  'hickory',
#  'minneapolis',
#  'houston',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'ahmaud arbery',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'the united states',
#  'las vegas',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'philando castile',
#  'mn',
#  'minneapolis',
#  'new york',
#  'minneapolis',
#  'new york',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'los angeles',
#  'u.s.',
#  'minneapolis',
#  'minneapolis',
#  'louisville',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'nyc',
#  'minneapolis',
#  'nyc',
#  'minneapolis',
#  'nyc',
#  'minneapolis',
#  'nyc',
#  'minneapolis',
#  'brooklyn',
#  'nyc',
#  'minneapolis',
#  'montana state',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'washington',
#  'u.s.',
#  'washington',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'chanticleer',
#  'minneapolis',
#  'minneapolis',
#  'moonlight beach',
#  'minneapolis',
#  'california',
#  'encinitas',
#  'u.s.',
#  'minneapolis',
#  'syria',
#  'minnesota',
#  'minnesota',
#  'minnesota',
#  'minnesota',
#  'minneapolis',
#  'minneapolis',
#  'washington',
#  'ohio',
#  'washington',
#  'lafayette park',
#  'atlanta',
#  'minneapolis',
#  'washington',
#  'washington',
#  'washington',
#  'washington',
#  'minneapolis',
#  'america',
#  'america',
#  'america',
#  'america',
#  'bethel',
#  'yakima',
#  'minneapolis',
#  'navarre',
#  'u.s.',
#  'minneapolis',
#  'st. louis',
#  'the city of whitewater police department',
#  'wisconsin',
#  'a city of whitewater',
#  'whitewater',
#  'minneapolis',
#  'the united states',
#  'america',
#  'minneapolis',
#  'texas',
#  'texas',
#  'texas',
#  'london',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  "kansas city's",
#  'texas',
#  'youtube.com/hopecollege',
#  'minneapolis',
#  'minneapolis',
#  'washington',
#  'washington',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'brussels',
#  'minneapolis',
#  'minneapolis',
#  'nyc',
#  'nyc',
#  'nyc',
#  'los angeles',
#  'nyc',
#  'greensboro',
#  'n.c.',
#  'greensboro',
#  'virginia',
#  'richmond',
#  'lansdale',
#  'los angeles',
#  'lansdale',
#  'ferguson',
#  'missouri',
#  'los angeles',
#  'los angeles',
#  'los angeles',
#  'america',
#  'portland',
#  'america',
#  'michigan',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'new york',
#  'minneapolis',
#  'minneapolis',
#  'iowa',
#  'des moines',
#  'minneapolis',
#  'iowa',
#  'des moines',
#  'orlando',
#  'the city of sumter',
#  'sumter',
#  'u.s.',
#  'l.a.',
#  'minneapolis',
#  'los angeles county',
#  'minneapolis',
#  'birmingham',
#  'nashville',
#  'alabama',
#  'minneapolis',
#  'the united states',
#  'los angeles',
#  'washington',
#  'minneapolis',
#  'marshfield',
#  'marshfield',
#  'the united states',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'evanston',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'washington',
#  'minneapolis',
#  'america',
#  'rose city',
#  'oregon',
#  'us',
#  'green bay',
#  'wis.',
#  'green bay',
#  'wis.',
#  'green bay',
#  'wis.',
#  'bethesda',
#  'maryland',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'the city of minneapolis',
#  'denver',
#  'houston',
#  'minneapolis',
#  'minneapolis',
#  'chattanooga',
#  'minneapolis',
#  'minneapolis',
#  'orleans',
#  'orleans parish',
#  'america',
#  'minneapolis',
#  'orleans',
#  'orleans parish',
#  'minneapolis',
#  'orleans',
#  'orleans parish',
#  'the united states',
#  'tenn.',
#  'johnson city',
#  'johnson city',
#  'houston',
#  'mankato',
#  'tenn.',
#  'johnson city',
#  'johnson city',
#  'seattle',
#  'seattle',
#  'rhode island',
#  'texas',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'manhattan',
#  'minneapolis',
#  'california',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minnesota',
#  'mi',
#  'minneapolis',
#  'grand rapids',
#  'wilmington',
#  'las vegas',
#  'socal',
#  'la',
#  'minneapolis',
#  'minneapolis minnesota',
#  'minneapolis',
#  'u.s.',
#  'u.s.',
#  'u.s.',
#  'nashville',
#  'nashville',
#  'minneapolis',
#  'america',
#  'minneapolis minnesota',
#  'minneapolis',
#  'minneapolis minnesota',
#  'america',
#  'america',
#  'charlotte',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'colorado',
#  'denver',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'towson',
#  'minneapolis',
#  'bexar county',
#  'towson',
#  'minneapolis',
#  'towson',
#  'dallas',
#  'minnesota',
#  'louisiana',
#  'minneapolis minnesota',
#  'minneapolis minnesota',
#  'ohio',
#  'minneapolis minnesota',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'london',
#  'england',
#  'america',
#  'germany',
#  'minneapolis',
#  'nebraska',
#  'america',
#  'nebraska',
#  'colorado',
#  'denver',
#  'colorado',
#  'los angeles',
#  'latinx',
#  'sr.',
#  'new york city',
#  'minneapolis',
#  'bend',
#  'minneapolis',
#  'minneapolis',
#  'bend',
#  'virginia',
#  'richmond',
#  'virginia',
#  'richmond',
#  'virginia',
#  'richmond',
#  'virginia',
#  'richmond',
#  'colorado',
#  'denver',
#  'virginia',
#  'richmond',
#  'beverly hills',
#  'los angeles county',
#  'beverly hills - government',
#  'west hollywood',
#  'los angeles',
#  'chicago',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'florida',
#  'tallahassee',
#  'connecticut',
#  'mn',
#  'minneapolis',
#  'ct',
#  'pittsburgh',
#  'connecticut',
#  'pittsburgh',
#  'pittsburgh',
#  'colorado',
#  'denver',
#  'minnesota',
#  'minneapolis',
#  'hollywood',
#  'minneapolis',
#  'minneapolis',
#  'ahmaud arbery',
#  'ahmaud arbery',
#  'sandiego',
#  'california',
#  'moonlight beach',
#  'encinitas',
#  'minneapolis',
#  'america',
#  'colorado',
#  'denver',
#  'u.s.',
#  'arbery',
#  'plandemic',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'new york',
#  'boston',
#  'minneapolis',
#  'miami springs',
#  'minneapolis',
#  'valencia',
#  'valencia',
#  'colorado',
#  'denver',
#  'valencia',
#  'minnesota',
#  'nyc',
#  'u.s.',
#  'new york',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'the city of alton',
#  'madison county',
#  'illinois',
#  'abilene',
#  'abilene',
#  'texas',
#  'abilene',
#  'abilene',
#  'texas',
#  'abilene',
#  'minneapolis',
#  'denver',
#  'america',
#  'newnan',
#  'denver',
#  'jefferson',
#  'new orleans',
#  'modesto reyes',
#  'denver',
#  'atlanta',
#  'denver',
#  'columbus',
#  'ohio',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'sacramento',
#  'minneapolis',
#  'america',
#  'new york',
#  'dallas',
#  'us',
#  'america',
#  'flint',
#  'los angeles',
#  'new york',
#  'michigan',
#  'philadelphia',
#  'minneapolis',
#  'houston',
#  'us',
#  'america',
#  'ahmaud arbery',
#  'delaware',
#  'london',
#  'us',
#  'u.s.',
#  'the united states',
#  'minneapolis',
#  'south minneapolis',
#  'minneapolis',
#  'us',
#  'u.s.',
#  'paterson',
#  'the paterson diocese',
#  'us',
#  'las vegas',
#  'oregon',
#  'virginia',
#  'richmond',
#  'minneapolis',
#  'maryland',
#  'baltimore',
#  'minneapolis',
#  'pittsburgh',
#  'minneapolis',
#  'small city in western kansas',
#  'garden city',
#  'small city in western kansas',
#  'garden city',
#  'arkansas',
#  'jacksonville',
#  'america',
#  'l.a.',
#  'highland',
#  'melrose',
#  'minneapolis',
#  'houston',
#  'bexar county',
#  'syracuse',
#  'us',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'minneapolis',
#  'houston',
#  'minneapolis',
#  'minneapolis',
#  'san francisco’s',
#  'oakland',
#  'minneapolis',
#  'minneapolis',
#  'georgia',
#  'charlotte',
#  'georgia',
#  'colorado',
#  'los angeles',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'los angeles',
#  'america',
#  'zoom',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'albany',
#  'minnesota',
#  'new york’s',
#  'new york state',
#  'america',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'princeton',
#  'japan',
#  'osaka',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'new york',
#  'nyc',
#  'kueng',
#  'minnesota',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'hollywood',
#  'america',
#  'richmond',
#  'minneapolis',
#  'brooklyn',
#  'brooklyn',
#  'gwinnett',
#  'gwinnett',
#  'oakland',
#  '@blklivesmatter',
#  '@innocenceproject',
#  '@feedthemass',
#  'portland',
#  'minneapolis',
#  'chicago',
#  'illinois',
#  'chicago',
#  'grand rapids',
#  'birmingham',
#  'birmingham',
#  'minneapolis',
#  'tokyo',
#  'japan',
#  'amsterdam',
#  'minneapolis',
#  'america',
#  'minnesota',
#  'manhattan',
#  'houston',
#  'nc',
#  'raeford',
#  'minneapolis',
#  'minneapolis',
#  'louisiana',
#  'minneapolis',
#  'arizona',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  ...]

# %%
c = collections.Counter()

# %%
dict_a=collections.Counter(list).most_common()

# %%
dict_a
# Out:
# [('minneapolis', 7746),
#  ('america', 1515),
#  ('minnesota', 1317),
#  ('u.s.', 959),
#  ('us', 703),
#  ('the united states', 678),
#  ('washington', 550),
#  ('houston', 478),
#  ('los angeles', 396),
#  ('new york', 353),
#  ('chicago', 304),
#  ('texas', 257),
#  ('brooklyn', 217),
#  ('new york city', 203),
#  ('lincoln', 193),
#  ('florida', 182),
#  ('north carolina', 164),
#  ('denver', 160),
#  ('dallas', 157),
#  ('nyc', 152),
#  ('portland', 149),
#  ('california', 147),
#  ('d.c.', 145),
#  ('atlanta', 138),
#  ('virginia', 137),
#  ('philadelphia', 136),
#  ('seattle', 134),
#  ('ohio', 129),
#  ('georgia', 129),
#  ('santa monica', 126),
#  ('richmond', 125),
#  ('las vegas', 119),
#  ('hollywood', 114),
#  ('london', 111),
#  ('oregon', 110),
#  ('boston', 105),
#  ('milwaukee', 104),
#  ('alabama', 103),
#  ('louisville', 95),
#  ('michigan', 92),
#  ('dc', 92),
#  ('l.a.', 91),
#  ('mn', 88),
#  ('pittsburgh', 85),
#  ('bexar county', 84),
#  ('columbus', 83),
#  ('orange county', 80),
#  ('new jersey', 80),
#  ('wisconsin', 78),
#  ('ny', 77),
#  ('new orleans', 75),
#  ('detroit', 75),
#  ('usa', 74),
#  ('ahmaud arbery', 73),
#  ('philando castile', 73),
#  ('san francisco', 73),
#  ('illinois', 72),
#  ('baltimore', 72),
#  ('iowa', 70),
#  ('kentucky', 69),
#  ('nj', 68),
#  ('pennsylvania', 68),
#  ('oakland', 64),
#  ('paris', 63),
#  ('nc', 63),
#  ('massachusetts', 63),
#  ('hennepin county district court', 62),
#  ('tacoma', 62),
#  ('colorado', 62),
#  ('arizona', 61),
#  ('connecticut', 60),
#  ('missouri', 60),
#  ('raeford', 59),
#  ('harrisburg', 56),
#  ('the united states of america', 53),
#  ('huntsville', 53),
#  ('hennepin county', 53),
#  ('maryland', 52),
#  ('sacramento', 51),
#  ('san antonio', 51),
#  ('birmingham', 50),
#  ('floyd', 46),
#  ('china', 46),
#  ('cleveland', 46),
#  ('manhattan', 46),
#  ('vegas', 45),
#  ('mississippi', 45),
#  ('minn.', 43),
#  ('st. louis', 43),
#  ('phoenix', 43),
#  ('united states', 42),
#  ('nebraska', 41),
#  ('maine', 41),
#  ('springfield', 40),
#  ('athens', 40),
#  ('indiana', 40),
#  ('jacksonville', 39),
#  ('madison', 39),
#  ('brunswick', 39),
#  ('nevada', 38),
#  ('tennessee', 37),
#  ('park slope', 36),
#  ('miami', 35),
#  ('county', 35),
#  ('qb', 34),
#  ('salem', 33),
#  ('fl', 33),
#  ('montgomery', 33),
#  ('lansing', 33),
#  ('wilmington', 31),
#  ('zoom', 31),
#  ('kueng', 31),
#  ('st. paul', 31),
#  ('indianapolis', 31),
#  ('s.c.', 30),
#  ('el paso', 30),
#  ('va.', 29),
#  ('lafayette park', 28),
#  ('hartford', 28),
#  ('ct', 28),
#  ('charlotte', 28),
#  ('new mexico', 28),
#  ('south carolina', 28),
#  ('n.c.', 27),
#  ('des moines', 27),
#  ('orlando', 27),
#  ('nashville', 27),
#  ('calif.', 27),
#  ('alaska', 26),
#  ('troy', 26),
#  ('nh', 26),
#  ('philly', 26),
#  ('fayetteville', 25),
#  ('la', 25),
#  ('colorado springs', 25),
#  ('sarasota', 25),
#  ('russia', 24),
#  ('syria', 24),
#  ('wis.', 24),
#  ('south minneapolis', 24),
#  ('arkansas', 24),
#  ('canada', 24),
#  ('israel', 24),
#  ('san diego', 24),
#  ('washington d.c.', 24),
#  ('washington dc', 23),
#  ('cincinnati', 23),
#  ('ore.', 22),
#  ('germany', 22),
#  ('kansas city', 22),
#  ('melbourne', 22),
#  ('normandy', 22),
#  ('fresno', 21),
#  ('wi', 21),
#  ('ala.', 20),
#  ('guadalupe', 20),
#  ('greensboro', 20),
#  ('minneapolis minnesota', 20),
#  ('new york state', 20),
#  ('anaheim', 20),
#  ('rochester', 20),
#  ('bethel', 19),
#  ('austin', 19),
#  ('montgomery county', 19),
#  ('york city', 19),
#  ('syracuse', 18),
#  ('tx', 18),
#  ('new hampshire', 18),
#  ('san jose', 18),
#  ('rhode island', 18),
#  ('latinx', 18),
#  ('flint', 18),
#  ('irvine', 18),
#  ('omaha', 18),
#  ('arlington', 18),
#  ('tulsa', 18),
#  ('charleston', 18),
#  ('rockford', 18),
#  ('saint paul', 17),
#  ('bel air', 17),
#  ('johnson city', 17),
#  ('newport beach', 17),
#  ('georgetown', 17),
#  ('asheville', 17),
#  ('france', 17),
#  ('pa.', 17),
#  ('casper', 17),
#  ('ywca', 16),
#  ('arbery', 16),
#  ('albany', 16),
#  ('midland', 16),
#  ('sioux city', 16),
#  ('davenport', 16),
#  ('kingston', 16),
#  ('albuquerque', 16),
#  ('kan.', 16),
#  ('fort worth', 16),
#  ('new zealand', 16),
#  ('iran', 16),
#  ('greenville', 16),
#  ('newark', 16),
#  ('mo.', 16),
#  ('alexandria', 16),
#  ('joliet', 16),
#  ('pa', 16),
#  ('tenn.', 15),
#  ('tallahassee', 15),
#  ('garden city', 15),
#  ('new york’s', 15),
#  ('brentwood', 15),
#  ('md', 15),
#  ('minneapoli', 15),
#  ('salt lake city', 15),
#  ('bakersfield', 15),
#  ('memphis', 15),
#  ('utah', 15),
#  ('stockton', 15),
#  ('camden', 15),
#  ('puerto rico', 15),
#  ('rome', 15),
#  ('queens', 15),
#  ('lubbock', 15),
#  ('decatur', 15),
#  ('chattanooga', 14),
#  ('sioux', 14),
#  ('tampa', 14),
#  ('afghanistan', 14),
#  ('florence', 14),
#  ('hong kong', 14),
#  ('mich.', 14),
#  ('fargo', 14),
#  ('columbia', 14),
#  ('portsmouth', 14),
#  ('toms', 14),
#  ('los angeles county', 13),
#  ('green bay', 13),
#  ('italia', 13),
#  ('wyoming', 13),
#  ('shreveport', 13),
#  ('iowa city', 13),
#  ('la mesa', 13),
#  ('pensacola', 13),
#  ('montana', 13),
#  ('idaho', 13),
#  ('blm', 13),
#  ('selma', 13),
#  ('u.s', 13),
#  ('northampton', 13),
#  ('vermont', 13),
#  ('santa ana', 13),
#  ('u.k.', 13),
#  ('vestavia hills', 13),
#  ('sussex', 13),
#  ('albany park', 13),
#  ('stamford', 13),
#  ('winston-salem', 12),
#  ('mass.', 12),
#  ('eugene', 12),
#  ('wash.', 12),
#  ("kansas city's", 12),
#  ('grand rapids', 12),
#  ('west hollywood', 12),
#  ('bethlehem', 12),
#  ('australia', 12),
#  ('britain', 12),
#  ('lancaster', 12),
#  ('berlin', 12),
#  ('san marco', 12),
#  ('va', 12),
#  ('norfolk', 12),
#  ('long beach', 12),
#  ('santa rosa', 12),
#  ('newton', 12),
#  ('berkeley', 12),
#  ('peoria', 12),
#  ('st. john’s', 12),
#  ('keene', 11),
#  ('ferguson', 11),
#  ('amsterdam', 11),
#  ('buffalo', 11),
#  ('minn', 11),
#  ('waterloo', 11),
#  ('bloomington', 11),
#  ('evansville', 11),
#  ('his city', 11),
#  ('providence', 11),
#  ('fairfield', 11),
#  ('medford', 11),
#  ('sf', 11),
#  ('durham', 11),
#  ('palestine', 11),
#  ('ga', 11),
#  ('allegheny county', 11),
#  ('del.', 11),
#  ('harford county', 11),
#  ('windsor', 10),
#  ('bethesda', 10),
#  ('abilene', 10),
#  ('boise', 10),
#  ('broward county', 10),
#  ('jamestown', 10),
#  ('duluth', 10),
#  ('atlantic city', 10),
#  ('ga.', 10),
#  ('ashland', 10),
#  ('the district of columbia', 10),
#  ('these united states', 10),
#  ('rapid city', 10),
#  ('racine', 10),
#  ('vallejo', 10),
#  ('mexico', 10),
#  ('tuscaloosa', 10),
#  ('huntington', 10),
#  ("san francisco's", 10),
#  ('oklahoma city', 10),
#  ('sunnyside', 10),
#  ('augusta', 10),
#  ('oklahoma', 9),
#  ('towson', 9),
#  ('louisiana', 9),
#  ('sr.', 9),
#  ('delaware', 9),
#  ('lebanon', 9),
#  ('worcester', 9),
#  ('monterey county', 9),
#  ('muncie', 9),
#  ('uk', 9),
#  ('bronx', 9),
#  ('kansas', 9),
#  ('greece', 9),
#  ('conn.', 9),
#  ('d-ga', 9),
#  ('hawaii', 9),
#  ('belmont', 9),
#  ('truckee', 9),
#  ('burlington', 9),
#  ('carmel', 9),
#  ('iraq', 9),
#  ('cambridge', 9),
#  ('chico', 9),
#  ('christ', 9),
#  ('polk county', 9),
#  ('warsaw', 9),
#  ('taunton', 9),
#  ('shelby township', 9),
#  ('santa cruz', 9),
#  ('cape', 9),
#  ('hoboken', 9),
#  ('dayton', 9),
#  ('gettysburg', 9),
#  ('venice', 9),
#  ('sc', 9),
#  ('fla.', 9),
#  ('saginaw', 9),
#  ('the united s', 9),
#  ('rockingham county', 9),
#  ('alameda county', 8),
#  ('south florida', 8),
#  ('san francisco’s', 8),
#  ('fremont', 8),
#  ('south dakota', 8),
#  ('fox carolina', 8),
#  ('toledo', 8),
#  ('clark county', 8),
#  ('ma', 8),
#  ('l.a. county', 8),
#  ('stillwater', 8),
#  ('san diego county', 8),
#  ('breonna taylor', 8),
#  ('baton rouge', 8),
#  ('little rock', 8),
#  ('lafayette', 8),
#  ('la county', 8),
#  ('suffolk county district', 8),
#  ('the deep state', 8),
#  ('shelby township’s', 8),
#  ("philando castile's", 8),
#  ('lexington', 8),
#  ('amerikkka', 8),
#  ('d-la', 8),
#  ('jackson', 8),
#  ('riots', 8),
#  ('wv', 8),
#  ('pittsburg', 8),
#  ('montclair', 8),
#  ('city', 8),
#  ('cairo', 8),
#  ('raleigh', 8),
#  ("the united states'", 7),
#  ('cuba', 7),
#  ('turkey', 7),
#  ('south georgia', 7),
#  ('las cruces', 7),
#  ('encinitas', 7),
#  ('england', 7),
#  ('bend', 7),
#  ('beverly hills', 7),
#  ('comunidad', 7),
#  ('san bernardino', 7),
#  ('phoenixville', 7),
#  ('wy', 7),
#  ('bristol', 7),
#  ('escondido', 7),
#  ('gallatin county', 7),
#  ('moscow', 7),
#  ('ky.', 7),
#  ('charlottesville', 7),
#  ('poughkeepsie', 7),
#  ('waco', 7),
#  ('the united states constitution', 7),
#  ('the town of truckee', 7),
#  ('s.d.', 7),
#  ('n.d.', 7),
#  ('monroe', 7),
#  ('west philadelphia', 7),
#  ('missoula', 7),
#  ('brazil', 7),
#  ('helena', 7),
#  ('toms river', 7),
#  ('harris county', 7),
#  ('fitchburg', 7),
#  ('sonora', 7),
#  ('n.j.', 7),
#  ('castile', 7),
#  ('manchester', 7),
#  ('miss.', 7),
#  ('pittsford', 7),
#  ('san mateo', 7),
#  ('hoke county', 7),
#  ('st', 7),
#  ('jericho', 7),
#  ('whitefish', 7),
#  ('sandy springs', 7),
#  ('south dallas', 7),
#  ('hyde park', 7),
#  ('westchester', 7),
#  ('malaysia', 7),
#  ('dothan', 7),
#  ('dutchess county', 7),
#  ('scottsdale', 7),
#  ('ithaca', 7),
#  ('trenton', 7),
#  ('chatham', 7),
#  ('brookland', 7),
#  ('univ', 7),
#  ('bay county', 6),
#  ('kotzebue', 6),
#  ('king county', 6),
#  ('the city of minneapolis', 6),
#  ('ball state', 6),
#  ('warren county’s', 6),
#  ("san diego's", 6),
#  ('statesville', 6),
#  ('d-va', 6),
#  ('claremont', 6),
#  ('novato', 6),
#  ('westfield', 6),
#  ('houston ave', 6),
#  ('york', 6),
#  ('colo.', 6),
#  ('hampton', 6),
#  ('hennepin county’s', 6),
#  ('costa mesa', 6),
#  ('walnut', 6),
#  ('the city of fremont', 6),
#  ('lakewood', 6),
#  ('douglas county', 6),
#  ('ghana', 6),
#  ('minot', 6),
#  ('sonoma county', 6),
#  ('vero beach', 6),
#  ('the city of helena commission administrative meeting', 6),
#  ('lake county', 6),
#  ('beaumont', 6),
#  ('spokane', 6),
#  ('richland', 6),
#  ('n.y.', 6),
#  ('hennepin county jail', 6),
#  ('monmouth', 6),
#  ('dallas county', 6),
#  ('north', 6),
#  ('north dakota’s', 6),
#  ('oxnard', 6),
#  ('brockton', 6),
#  ('nassau county', 6),
#  ('mount vernon', 6),
#  ('camden county', 6),
#  ('mill creek', 6),
#  ('monroe county', 6),
#  ('monroe county area', 6),
#  ('monroe county branch', 6),
#  ('bloomington\n\n\n', 6),
#  ('brookhaven', 6),
#  ('ill.', 6),
#  ('reno', 6),
#  ('guilford', 6),
#  ('saagar', 6),
#  ('marco island', 6),
#  ('salinas', 6),
#  ('littleton', 6),
#  ('plainfield', 6),
#  ('alabama birmingham', 6),
#  ('ketchikan', 5),
#  ('dubuque', 5),
#  ('cedar rapids', 5),
#  ('manitowoc', 5),
#  ('moonlight beach', 5),
#  ('marshfield', 5),
#  ('mi', 5),
#  ('south los angeles', 5),
#  ('washington, dc', 5),
#  ('chabad', 5),
#  ('palm beach county', 5),
#  ('cheyenne', 5),
#  ('wyo.', 5),
#  ('fort wayne', 5),
#  ('topeka', 5),
#  ('uptown new orleans', 5),
#  ('olympia', 5),
#  ('baltimore county', 5),
#  ('bergen county', 5),
#  ('nw', 5),
#  ('fairfax', 5),
#  ('fort myers', 5),
#  ('centre county', 5),
#  ('district', 5),
#  ('nassau', 5),
#  ('ky', 5),
#  ("new york's", 5),
#  ('denison', 5),
#  ('north minneapolis', 5),
#  ('lafayette square', 5),
#  ('morgantown', 5),
#  ('tyler', 5),
#  ('macon', 5),
#  ('tucson', 5),
#  ('stanislaus county', 5),
#  ('kettering', 5),
#  ('alameda', 5),
#  ('huoston', 5),
#  ('kenosha', 5),
#  ('linden', 5),
#  ('denton', 5),
#  ('beijing', 5),
#  ('st. louis county', 5),
#  ('new bedford', 5),
#  ('freeport', 5),
#  ('d-milwaukee', 5),
#  ('quincey', 5),
#  ('jamaica', 5),
#  ('livonia', 5),
#  ('auburn', 5),
#  ('gulfport', 5),
#  ('milford', 5),
#  ('r-s.c.', 5),
#  ('sanford', 5),
#  ('whitley county', 5),
#  ('sandpoint', 5),
#  ('pocatello', 5),
#  ('the city and county of denver', 5),
#  ('oak park', 5),
#  ('holton', 5),
#  ('jefferson city', 5),
#  ('hennepin county district', 5),
#  ('waynesboro', 5),
#  ('venmo', 5),
#  ('philando', 5),
#  ('shorewood', 5),
#  ('baltimore city', 5),
#  ('slidell', 5),
#  ('west virginia', 5),
#  ('d-n.j.', 5),
#  ('nairobi', 5),
#  ('washington county', 5),
#  ('lynchburg', 5),
#  ('soci', 5),
#  ('district \n', 5),
#  ('the city of dallas', 5),
#  ('marlborough', 5),
#  ('hancock', 5),
#  ('aggies', 5),
#  ('hanover', 5),
#  ('park rapids', 5),
#  ('saratoga springs', 5),
#  ('broadway', 5),
#  ('n.m.', 5),
#  ('gainesville', 5),
#  ('allentown', 5),
#  ('champaign', 5),
#  ('bucks county', 5),
#  ('revd', 5),
#  ('contra costa county', 4),
#  ('somerville', 4),
#  ('suffolk', 4),
#  ('south jersey', 4),
#  ('libya', 4),
#  ('sumter', 4),
#  ('evanston', 4),
#  ('orleans', 4),
#  ('orleans parish', 4),
#  ('socal', 4),
#  ('small city in western kansas', 4),
#  ('the rock', 4),
#  ('bremerton', 4),
#  ('new haven', 4),
#  ('maplewood', 4),
#  ('kankakee', 4),
#  ('elba', 4),
#  ('the hennepin county', 4),
#  ('erie', 4),
#  ('w.va.', 4),
#  ('chicagoland', 4),
#  ('clayton', 4),
#  ('hawthorne', 4),
#  ('new jersey’s', 4),
#  ('midtown', 4),
#  ('uptown', 4),
#  ('wa', 4),
#  ('longview', 4),
#  ('genesee county', 4),
#  ('lilburn', 4),
#  ('kingdom', 4),
#  ('knox county', 4),
#  ("new jersey's", 4),
#  ('club', 4),
#  ('port arthur', 4),
#  ('mill valley', 4),
#  ('fairfield county', 4),
#  ('the town of fairfield', 4),
#  ('clarksburg', 4),
#  ('ann arbor', 4),
#  ('minnea', 4),
#  ('downey', 4),
#  ('jersey city', 4),
#  ('minnesota united', 4),
#  ('puerto rico’s', 4),
#  ('nm', 4),
#  ('alexandria ave.', 4),
#  ('braddock', 4),
#  ('il', 4),
#  ('spartanburg', 4),
#  ('beat columbia', 4),
#  ('mendocino', 4),
#  ('palo alto', 4),
#  ('college', 4),
#  ('italy', 4),
#  ('emantic', 4),
#  ('hialeah', 4),
#  ('south l.a.', 4),
#  ('the city of sanford', 4),
#  ('north carolina’s', 4),
#  ('tn', 4),
#  ('edina', 4),
#  ('columbia city', 4),
#  ('henderson', 4),
#  ('lynam', 4),
#  ('norway', 4),
#  ('new rochelle', 4),
#  ('the united states\n', 4),
#  ('burlingame', 4),
#  ('carlisle', 4),
#  ('falmouth', 4),
#  ('cumberland', 4),
#  ('roc', 4),
#  ('the allegheny county jail', 4),
#  ('the city of newark', 4),
#  ('shamokin', 4),
#  ('toa baja', 4),
#  ('okla', 4),
#  ('florida state', 4),
#  ('plymouth', 4),
#  ('washington park', 4),
#  ('mo', 4),
#  ('delray beach', 4),
#  ('ballwin', 4),
#  ('skokie', 4),
#  ('main st', 4),
#  ('jefferson county', 4),
#  ('nantucket', 4),
#  ('breonna', 4),
#  ('vt.', 4),
#  ('chambers county', 4),
#  ('franklin county', 4),
#  ('merrick', 4),
#  ('billings', 4),
#  ('west palm beach', 4),
#  ('weirton', 4),
#  ('royal oak', 4),
#  ('bellevue', 4),
#  ('auckland', 4),
#  ('kenya', 4),
#  ('palmyra', 4),
#  ('annville', 4),
#  ('lebanon york', 4),
#  ('new oxford', 4),
#  ('jonestown', 4),
#  ('hummelstown', 4),
#  ('east berlin', 4),
#  ('allison park', 4),
#  ('derby', 4),
#  ('salt lake city\n', 4),
#  ('middletown', 4),
#  ('moorhead', 4),
#  ('york county', 4),
#  ('texas county', 4),
#  ('netherlands', 4),
#  ('south bend', 4),
#  ('glynn county', 4),
#  ('warren', 4),
#  ('san francisco mission', 4),
#  ('south africa', 4),
#  ('corvallis', 4),
#  ('dtla', 4),
#  ("st. john's", 4),
#  ('grove city', 4),
#  ('hollis', 4),
#  ('lewisburg', 4),
#  ('atmore', 4),
#  ("west michigan's", 4),
#  ('boone county', 4),
#  ('framingham', 4),
#  ('st. charles', 4),
#  ('stoughton', 4),
#  ('albany ny', 4),
#  ('new britain', 4),
#  ('thurston county', 4),
#  ('clarksdale', 4),
#  ('petaluma', 4),
#  ('west alabama', 4),
#  ('canton', 4),
#  ('roanoke', 4),
#  ('northeast louisiana', 4),
#  ('suffolk county', 4),
#  ('rhinelander', 4),
#  ('la.', 4),
#  ('atlantic county', 4),
#  ('the city of marlborough', 4),
#  ('harrison', 4),
#  ('east haven', 4),
#  ('nevada county', 3),
#  ('north dakota', 3),
#  ('modesto', 3),
#  ('sandiego', 3),
#  ('valencia', 3),
#  ('japan', 3),
#  ('gwinnett', 3),
#  ('the city of bremerton', 3),
#  ('️ the city of bremerton', 3),
#  ('t.i.', 3),
#  ('leimert park', 3),
#  ('the ball state', 3),
#  ('la mesa city', 3),
#  ("their city's", 3),
#  ('binnish', 3),
#  ('santa clarita', 3),
#  ('alamo', 3),
#  ('waukegan', 3),
#  ('luray', 3),
#  ('emporia', 3),
#  ('riley county', 3),
#  ('santa fe', 3),
#  ('morganton', 3),
#  ('bedford', 3),
#  ('beverly', 3),
#  ('sherman oaks', 3),
#  ('featuing', 3),
#  ('elmira', 3),
#  ('sweden', 3),
#  ('east texas', 3),
#  ('east texas city', 3),
#  ('indybay', 3),
#  ('linn park', 3),
#  ('rockland county', 3),
#  ('annapolis', 3),
#  ('snohomish', 3),
#  ('tiananmen', 3),
#  ('ind.', 3),
#  ('smith county', 3),
#  ('the city of tyler', 3),
#  ('belvidere', 3),
#  ('warren county', 3),
#  ('mansfield', 3),
#  ('phillipsburg', 3),
#  ('greenwich', 3),
#  ('washington township', 3),
#  ('georgetown county', 3),
#  ('the diocese of metuchen', 3),
#  ('mn legislature', 3),
#  ('williamsburg', 3),
#  ('pilsen', 3),
#  ('travis park', 3),
#  ('tehran', 3),
#  ('the city of columbus', 3),
#  ('the city of portland', 3),
#  ('greater portland', 3),
#  ('ansonia', 3),
#  ('clermont', 3),
#  ('uhg.co/drivechange2', 3),
#  ('the city of seattle', 3),
#  ('newington', 3),
#  ('the city of richmond', 3),
#  ('samaritan', 3),
#  ('methodist', 3),
#  ('santa maria', 3),
#  ('redding', 3),
#  ('vietnam', 3),
#  ('bibb county', 3),
#  ('denmark', 3),
#  ('northam', 3),
#  ('spring valley’s', 3),
#  ('metro phoenix', 3),
#  ('grand junction', 3),
#  ('wicomico county', 3),
#  ('cameron county', 3),
#  ('the city of salem', 3),
#  ('los musulmanes', 3),
#  ("el paso's", 3),
#  ('sydney', 3),
#  ('covington', 3),
#  ('jerusalem', 3),
#  ('silver lake', 3),
#  ('moore county', 3),
#  ('pinehurst', 3),
#  ('vancouver', 3),
#  ('n.h.', 3),
#  ('tripoli', 3),
#  ('lancaster county', 3),
#  ('port huron', 3),
#  ('chamblee', 3),
#  ('miramar', 3),
#  ('hallandale beach', 3),
#  ('fort mill', 3),
#  ('the rhode island state police', 3),
#  ('south portland', 3),
#  ('gorham', 3),
#  ('cumberland county', 3),
#  ('knoxville', 3),
#  ('marysville', 3),
#  ('contra costa', 3),
#  ('ventura', 3),
#  ('glasgow', 3),
#  ('forsyth county', 3),
#  ('bozeman', 3),
#  ('bronzeville', 3),
#  ('travis', 3),
#  ('gaithersburg', 3),
#  ('youngstown', 3),
#  ('pasco county sheriff’s', 3),
#  ('mn 55436', 3),
#  ('somalia', 3),
#  ('whitestone', 3),
#  ('barnstable county human rights advisory commission', 3),
#  ('cape cod', 3),
#  ('mashpee', 3),
#  ('aberdeen', 3),
#  ('india', 3),
#  ('republic', 3),
#  ('wolfeboro', 3),
#  ('| city of iowa city', 3),
#  ('burleson', 3),
#  ('little village', 3),
#  ('unsplash', 3),
#  ('boulder county', 3),
#  ('berkshire', 3),
#  ('mecca', 3),
#  ('kalamazoo', 3),
#  ('gresham', 3),
#  ('floyds', 3),
#  ('norwalk', 3),
#  ('san antonio - black', 3),
#  ('ymca', 3),
#  ('the city of enid', 3),
#  ('westchester county', 3),
#  ('jefferson county district', 3),
#  ('lenoir', 3),
#  ('tenn', 3),
#  ('houston texas', 3),
#  ('tracy', 3),
#  ('castle rock', 3),
#  ('cannes', 3),
#  ('san leandro', 3),
#  ('west fargo', 3),
#  ('cass county', 3),
#  ('grayslake', 3),
#  ('az', 3),
#  ('los angeles looking at', 3),
#  ('the city of chicago', 3),
#  ('cleveland county', 3),
#  ('mt', 3),
#  ('copenhagen', 3),
#  ('center city', 3),
#  ('riverside', 3),
#  ('the inland empire', 3),
#  ('johnstown', 3),
#  ('el salvador', 3),
#  ('crestline', 3),
#  ('⚡', 3),
#  ('wakefield', 3),
#  ('thousand oaks', 3),
#  ('meridian', 3),
#  ('| salem', 3),
#  ('socorro', 3),
#  ('easley', 3),
#  ('champaign county', 3),
#  ('mckinney', 3),
#  ('collin county', 3),
#  ('houghton', 3),
#  ('atwater park', 3),
#  ('oconomowoc', 3),
#  ('wi\n', 3),
#  ('greenfield park - 2028 s.', 3),
#  ('lucas county', 3),
#  ('north charleston', 3),
#  ('the city of philadelphia', 3),
#  ('dfw', 3),
#  ('el caribe', 3),
#  ('movimiento', 3),
#  ('eutaw', 3),
#  ('the states of america', 3),
#  ('boulder', 3),
#  ('west sacramento', 3),
#  ('oneida county', 3),
#  ('md.', 3),
#  ('chesterfield county', 3),
#  ('union park', 3),
#  ("blm chicago's", 3),
#  ('boulder city', 3),
#  ('hennepin county district cour', 3),
#  ('brown', 2),
#  ('yemen', 2),
#  ('the soviet union', 2),
#  ('belgium', 2),
#  ('kimberly york', 2),
#  ('hickory', 2),
#  ('yakima', 2),
#  ('navarre', 2),
#  ('the city of whitewater police department', 2),
#  ('a city of whitewater', 2),
#  ('whitewater', 2),
#  ('brussels', 2),
#  ('lansdale', 2),
#  ('mankato', 2),
#  ('beverly hills - government', 2),
#  ('plandemic', 2),
#  ('madison county', 2),
#  ('modesto reyes', 2),
#  ('highland', 2),
#  ('el sereno', 2),
#  ('chaminade', 2),
#  ('bbq', 2),
#  ('chesterfield', 2),
#  ('kitsap', 2),
#  ('beth israel', 2),
#  ('ucc', 2),
#  ('willamette', 2),
#  ('homewood', 2),
#  ('pompey park', 2),
#  ("delray beach's", 2),
#  ('centennial park', 2),
#  ('hillsborough county', 2),
#  ('ybor city', 2),
#  ('lakeland', 2),
#  ('hampstead', 2),
#  ('aiken', 2),
#  ('congregation', 2),
#  ('appleton', 2),
#  ('pinellas county', 2),
#  ('peabody', 2),
#  ('pasco', 2),
#  ('states', 2),
#  ('council', 2),
#  ('san francisco district office', 2),
#  ('stoney', 2),
#  ('| delhi', 2),
#  ('south philadelphia', 2),
#  ('wheeling', 2),
#  ('spain', 2),
#  ('the united states air force', 2),
#  ("morris township's", 2),
#  ('san angelo', 2),
#  ('pomona', 2),
#  ('pasadena', 2),
#  ('glen cove', 2),
#  ('los padres', 2),
#  ('the city of los angeles', 2),
#  ('wichita', 2),
#  ('hayward', 2),
#  ('castle county', 2),
#  ("centre county's", 2),
#  ('clarksville', 2),
#  ('the city of simi valley', 2),
#  ('the county of ventura', 2),
#  ('greater cincinnati', 2),
#  ('losangeles', 2),
#  ('wetherby park', 2),
#  ('mercer park', 2),
#  ('moreno valley', 2),
#  ('the kingdom of god', 2),
#  ('utica', 2),
#  ('grayson', 2),
#  ...]

# %%
dataframe604=pd.DataFrame(dict_a)

# %%
len(dict_a)
# Out:
# 2839

# %%
dataframe604.to_csv('dataframe0604.csv')
