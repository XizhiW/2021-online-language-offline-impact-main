# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 798 kB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_UK
#  a0529-a0611_US     dataframe_result_529_UK.csv
#  a0529.csv	    dataframe_result_530_UK.csv
#  a0530.csv	    dataframe_result_531_UK.csv
#  a0531.csv	    dataframe_result_csv
#  a0601.csv	    dataframe_result_csv_EU
#  a0602.csv	    dataframe_result_csv_UK
#  a0603.csv	    Github
#  a0604.csv	    heatmap529_UK.ipynb
#  a0605.csv	    heatmap530.ipynb
#  a0606.csv	    Heat_Map_Online_language.ipynb
#  a0607.csv	    __MACOSX
#  a0608.csv	    mapping_UK
#  a0610.csv	    mapping_US
#  a0611.csv	    non_violant1.csv
#  ccc_compiled.csv   non_violant2.csv
#  csv		    UK
#  csv.zip	    violant.csv
#  dataframe_csv	   '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_csv_EU

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct=pd.read_csv('a0529-a0611_UK/a0529.csv',encoding='ISO-8859-1')

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_UK
#  a0529-a0611_US     dataframe_result_529_UK.csv
#  a0529.csv	    dataframe_result_530_UK.csv
#  a0530.csv	    dataframe_result_531_UK.csv
#  a0531.csv	    dataframe_result_csv
#  a0601.csv	    dataframe_result_csv_EU
#  a0602.csv	    dataframe_result_csv_UK
#  a0603.csv	    Github
#  a0604.csv	    heatmap529_UK.ipynb
#  a0605.csv	    heatmap530.ipynb
#  a0606.csv	    Heat_Map_Online_language.ipynb
#  a0607.csv	    __MACOSX
#  a0608.csv	    mapping_UK
#  a0610.csv	    mapping_US
#  a0611.csv	    non_violant1.csv
#  ccc_compiled.csv   non_violant2.csv
#  csv		    UK
#  csv.zip	    violant.csv
#  dataframe_csv	   '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_csv_EU

# %%
###
#ct=pd.read_csv('a0601.csv')

# %%
ct
# Out:
#        Unnamed: 0  ...  NER-title
# 0               0  ...         {}
# 1               1  ...         {}
# 2               2  ...         {}
# 3               3  ...         {}
# 4               4  ...         {}
# ...           ...  ...        ...
# 39755       39755  ...         {}
# 39756       39756  ...         {}
# 39757       39757  ...  {'US': 1}
# 39758       39758  ...  {'US': 1}
# 39759       39759  ...  {'US': 1}
#
# [39760 rows x 51 columns]

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
#ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
###
ct_ner = ct

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                              NER-msg NER-desc NER-title
# 0                                 {}       {}        {}
# 1  {'Minneapolis': 1, 'St. Paul': 1}       {}        {}
# 2                                 {}       {}        {}
# 3                                 {}       {}        {}
# 4                 {'Minneapolis': 1}       {}        {}

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))

# %%
ct_ner['NER-msg']
# Out:
# 0                             []
# 1        [St. Paul, Minneapolis]
# 2                             []
# 3                             []
# 4                  [Minneapolis]
#                   ...
# 39755                         []
# 39756              [Minneapolis]
# 39757                [Minnesota]
# 39758                         []
# 39759                         []
# Name: NER-msg, Length: 39760, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']

# %%
ct_ner['NER']
# Out:
# 0                                                       []
# 1                                  [St. Paul, Minneapolis]
# 2                                                       []
# 3                                                       []
# 4                                            [Minneapolis]
#                                ...
# 39755                                        [Minneapolis]
# 39756                                        [Minneapolis]
# 39757    [Minnesota, America, Minnesota, the United Sta...
# 39758          [America, Minnesota, the United States, US]
# 39759          [America, Minnesota, the United States, US]
# Name: NER, Length: 39760, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])

# %%
ct_ner
# Out:
#        Unnamed: 0  ...                                          NER
# 0               0  ...                                           []
# 1               1  ...                      [minneapolis, st. paul]
# 2               2  ...                                           []
# 3               3  ...                                           []
# 4               4  ...                                [minneapolis]
# ...           ...  ...                                          ...
# 39755       39755  ...                                [minneapolis]
# 39756       39756  ...                                [minneapolis]
# 39757       39757  ...  [america, minnesota, the united states, us]
# 39758       39758  ...  [america, minnesota, the united states, us]
# 39759       39759  ...  [america, minnesota, the united states, us]
#
# [39760 rows x 52 columns]

# %%
ct_ner['NER-1']=ct_ner['NER']

# %%
ct_ner['NER-1'][1]
# Out:
# ['minneapolis', 'st. paul']

# %%
# !pip install -q geopy
# !pip install -q pyproj

# basic utilities
import json
import requests
import pandas as pd
import pprint
import time

# reverse geocoding utilities
from geopy.geocoders import Nominatim

# geography projection utilities
import pyproj
from shapely.ops import transform
from shapely.geometry import Point
from functools import partial
# Out:
#      |████████████████████████████████| 6.3 MB 5.1 MB/s

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_ner
# Out:
#        Unnamed: 0  ...                                        NER-1
# 0               0  ...                                           []
# 1               1  ...                      [minneapolis, st. paul]
# 2               2  ...                                           []
# 3               3  ...                                           []
# 4               4  ...                                [minneapolis]
# ...           ...  ...                                          ...
# 39755       39755  ...                                [minneapolis]
# 39756       39756  ...                                [minneapolis]
# 39757       39757  ...  [america, minnesota, the united states, us]
# 39758       39758  ...  [america, minnesota, the united states, us]
# 39759       39759  ...  [america, minnesota, the united states, us]
#
# [39760 rows x 53 columns]

# %%
# %cd mapping_UK
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/mapping_UK

# %%
# !ls
# Out:
# Counties_UK1.txt	    dataframe_mapping_0605.csv
# Counties_UK.txt		    dataframe_mapping_0606.csv
# Country.txt		    dataframe_mapping_0607.csv
# dataframe_mapping	    dataframe_mapping_0608.csv
# dataframe_mapping_0529.csv  dataframe_mapping_0609.csv
# dataframe_mapping_0530.csv  dataframe_mapping_0610.csv
# dataframe_mapping_0531.csv  dataframe_mapping_0611.csv
# dataframe_mapping_0601.csv  dataframe_mapping_remove_0606.csv
# dataframe_mapping_0602.csv  dataframe_post
# dataframe_mapping_0603.csv  Post-specific_UK.zip
# dataframe_mapping_0604.csv  states.csv

# %%
ct_mapping=pd.read_csv('dataframe_mapping_0529.csv',encoding='ISO-8859-1')

# %%
len(ct_mapping['City'])
# Out:
# 2342

# %%
country_list=pd.read_csv('Country.txt')
country_list['Name']=country_list['Name'].str.lower()

# %%
country_list['Name']
# Out:
# 0            afghanistan
# 1          �land islands
# 2                albania
# 3                algeria
# 4         american samoa
#              ...
# 250                   us
# 251    the united states
# 252              america
# 253                  u.s
# 254        united states
# Name: Name, Length: 255, dtype: object

# %%
states_list=pd.read_csv('states.csv')
states_list['State']
# Out:
# 0                             Alabama, United States
# 1                              Alaska, United States
# 2                             Arizona, United States
# 3                            Arkansas, United States
# 4                          California, United States
#                            ...
# 165         Armagh, Northern Ireland, United Kingdom
# 166           Down, Northern Ireland, United Kingdom
# 167      Fermanagh, Northern Ireland, United Kingdom
# 168    Londonderry, Northern Ireland, United Kingdom
# 169         Tyrone, Northern Ireland, United Kingdom
# Name: State, Length: 170, dtype: object

# %%
from numpy.core.numeric import NaN
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['City'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(states_list['State'])):
    if ct_mapping['Mapping'][i]==states_list['State'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['Mapping'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN

# %%
ct_mapping.to_csv('dataframe_mapping_remove_0529.csv')

# %%
len(ct_ner['NER-1'])
# Out:
# 39760

# %%
for k in range(len(ct_ner['NER-1'])):
  list=[]
  for i in ct_ner['NER-1'][k]:
    for j in range(len(ct_mapping['City'])):
      if(i==ct_mapping['City'][j]):
        list.append(ct_mapping['Mapping'][j])
  ct_ner['NER-1'][k]=list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
ct_ner
# Out:
#        Unnamed: 0  ...                                              NER-1
# 0               0  ...                                                 []
# 1               1  ...  [Minneapolis, Hennepin County, Minnesota, 5541...
# 2               2  ...                                                 []
# 3               3  ...                                                 []
# 4               4  ...  [Minneapolis, Hennepin County, Minnesota, 5541...
# ...           ...  ...                                                ...
# 39755       39755  ...  [Minneapolis, Hennepin County, Minnesota, 5541...
# 39756       39756  ...  [Minneapolis, Hennepin County, Minnesota, 5541...
# 39757       39757  ...                               [nan, nan, nan, nan]
# 39758       39758  ...                               [nan, nan, nan, nan]
# 39759       39759  ...                               [nan, nan, nan, nan]
#
# [39760 rows x 53 columns]

# %%
ct_ner['NER-1'][12]
# Out:
# ['San Jose, Santa Clara County, California, United States']

# %%
ct_ner.to_csv('dataframe0529_post_remove.csv')
