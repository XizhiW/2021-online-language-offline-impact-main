# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.0/en_core_web_lg-2.2.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.0/en_core_web_lg-2.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.0/en_core_web_lg-2.2.0.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 3.7 kB/s
# Requirement already satisfied: spacy>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.0) (2.2.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (3.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (7.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (4.62.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (0.8.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.0->en-core-web-lg==2.2.0) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.0->en-core-web-lg==2.2.0) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.0->en-core-web-lg==2.2.0) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.0->en-core-web-lg==2.2.0) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-lg==2.2.0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-lg==2.2.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-lg==2.2.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-lg==2.2.0) (1.24.3)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.0-py3-none-any.whl size=829187827 sha256=d435a9de10103f821d8dcc8e947c51658e369b1938b8942e0785d4782879162a
#   Stored in directory: /root/.cache/pip/wheels/4b/6e/87/8b129988ba4d66c064415e09db36d5945b638aabcaf8f41765
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.0

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK   dataframe_csv_EU
#  a0529-a0611_US   dataframe_csv_UK
#  a0529.csv	  dataframe_result_529_UK.csv
#  a0530.csv	  dataframe_result_530_UK.csv
#  a0531.csv	  dataframe_result_531_UK.csv
#  a0601.csv	  dataframe_result_csv
#  a0602.csv	  dataframe_result_csv_EU
#  a0603.csv	  dataframe_result_csv_UK
#  a0604.csv	  Github
#  a0605.csv	  heatmap529_UK.ipynb
#  a0606.csv	  heatmap530.ipynb
#  a0607.csv	  Heat_Map_Online_language.ipynb
#  a0608.csv	  __MACOSX
#  a0609.csv	  non_violant1.csv
#  a0610.csv	  non_violant2.csv
#  a0611.csv	  UK
#  csv		  violant.csv
#  csv.zip	 '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_csv

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_601 = 'csv/US06_01.csv'

# %%
ct = pd.read_csv(ct_path_601)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                               platformId  ...                    post_id
# 0          96623207231_10158378197842232  ...     3535|10158378197842232
# 1      1265297223574474_2731921486912033  ...   5972645|2731921486912033
# 2        100395078149910_161877328668351  ...   12642648|161877328668351
# 3       762995300426539_3094901393902573  ...   2186839|3094901393902573
# 4          33957807912_10157309663472913  ...  8050974|10157309663472913
# ...                                  ...  ...                        ...
# 32484     166280891785_10157007368411786  ...  2051958|10157007368411786
# 32485      36113587166_10156950268932167  ...    27873|10156950268932167
# 32486   224680844232189_3409426459090929  ...   5957234|3409426459090929
# 32487   569800796519238_1687110871454886  ...    760286|1687110871454886
# 32488   687156898054966_2719090881528214  ...    349130|2719090881528214
#
# [32489 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#   NER-msg NER-desc
# 0      {}       {}
# 1      {}       {}
# 2      {}       {}
# 3      {}       {}
# 4      {}       {}

# %%
ct.to_csv('a0601.csv')

# %%
ct=pd.read_csv('a0601.csv')

# %%
# !ls
# Out:
#  a0529-a0611_UK		       dataframe_result_csv_EU
#  a0529-a0611_US		       dataframe_result_csv_UK
#  a0601.csv		       Github
#  csv			       heatmap529_UK.ipynb
#  csv.zip		       heatmap530.ipynb
#  dataframe_csv		       Heat_Map_Online_language.ipynb
#  dataframe_csv_EU	       __MACOSX
#  dataframe_csv_UK	       non_violant1.csv
#  dataframe_result_529_UK.csv   non_violant2.csv
#  dataframe_result_530_UK.csv   UK
#  dataframe_result_531_UK.csv   violant.csv
#  dataframe_result_csv	      '新建 Microsoft PowerPoint 演示文稿.pptx'

# %%
###
ct=pd.read_csv('a0601.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 265-266: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-33-2ae8dd7765db> in <module>()
#       1 ###
# ----> 2 ct=pd.read_csv('a0601.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 265-266: invalid continuation byte

# %%
ct
# Out:
#       Unnamed: 0                         platformId  ... Unnamed: 122 Unnamed: 123
# 0              0      96623207231_10158378197842232  ...          NaN          NaN
# 1              1  1265297223574474_2731921486912033  ...          NaN          NaN
# 2              2    100395078149910_161877328668351  ...          NaN          NaN
# 3              3   762995300426539_3094901393902573  ...          NaN          NaN
# 4              4      33957807912_10157309663472913  ...          NaN          NaN
# ...          ...                                ...  ...          ...          ...
# 32861      32484     166280891785_10157007368411786  ...          NaN          NaN
# 32862      32485      36113587166_10156950268932167  ...          NaN          NaN
# 32863      32486   224680844232189_3409426459090929  ...          NaN          NaN
# 32864      32487   569800796519238_1687110871454886  ...          NaN          NaN
# 32865      32488   687156898054966_2719090881528214  ...          NaN          NaN
#
# [32866 rows x 124 columns]

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
###
ct_ner = ct

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#                                        NER-msg NER-desc NER-title
# 0                                           {}       {}        {}
# 1                                           {}       {}        {}
# 2                                           {}       {}        {}
# 3                                           {}       {}        {}
# 4  {'Liverpool': 1, 'Minneapolis': 1, 'US': 1}       {}        {}

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3d37af6961e4> in <module>()
# ----> 1 ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
#       2 ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
#       3 ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))
#
# NameError: name 'ct_ner' is not defined

# %%
ct_ner['NER-msg']
# Out:
# 6        [the City of New Orleans, New Orleans]
# 7              [Mississippi, the United States]
# 8              [Mississippi, the United States]
# 9                                            []
# 10                                           []
#                           ...
# 32481                             [Minneapolis]
# 32482          [Minneapolis, the United States]
# 32484                             [Minneapolis]
# 32485                            [New Mexico’s]
# 32486                                        []
# Name: NER-msg, Length: 22661, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ct_ner['NER']
# Out:
# 6        [the City of New Orleans, New Orleans, the Cit...
# 7        [Mississippi, the United States, Mississippi, ...
# 8        [Mississippi, the United States, Mississippi, ...
# 9         [Mississippi, the United States, Miss., JACKSON]
# 10                                           [Minneapolis]
#                                ...
# 32481        [Minneapolis, New York, Rochester, Rochester]
# 32482    [Minneapolis, the United States, Minneapolis, ...
# 32484                                        [Minneapolis]
# 32485    [New Mexico’s, ALBUQUERQUE, Albuquerque, New M...
# 32486    [Oakland, West Bloomfield, Minneapolis, Oaklan...
# Name: NER, Length: 22661, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ner_lst = ct_ner['NER'].values

# %%
ner_lst
# Out:
# array([list(['the city of new orleans', 'new orleans']),
#        list(['mississippi', 'the united states', 'jackson', 'miss.']),
#        list(['mississippi', 'the united states', 'jackson', 'miss.']),
#        ..., list(['minneapolis']),
#        list(['new mexico', 'albuquerque', 'albuquerque', 'new mexico’s']),
#        list(['new mexico', 'oakland county', 'minneapolis', 'oakland', 'west bloomfield'])],
#       dtype=object)

# %%
m=0
list=[]
for n in ner_lst:
  for i in range(len(n)):
    list.append(ner_lst[m][i])
  m+=1

# %%
list
# Out:
# ['the city of new orleans',
#  'new orleans',
#  'mississippi',
#  'the united states',
#  'jackson',
#  'miss.',
#  'mississippi',
#  'the united states',
#  'jackson',
#  'miss.',
#  'mississippi',
#  'the united states',
#  'jackson',
#  'miss.',
#  'minneapolis',
#  'memphis',
#  'minneapolis',
#  'the united states',
#  'the village of bath police department',
#  'bath new york',
#  'bath n.y.',
#  'ny',
#  'bath new york',
#  'ny',
#  'sacramento',
#  'the village of bath police department',
#  'sacramento county',
#  'harrisonburg',
#  'bath new york',
#  'harrisonburg',
#  'bath new york',
#  'spartanburg',
#  'minneapolis',
#  'bath new york',
#  'the city of riverside',
#  'minnesota',
#  'riverside',
#  'minnesota',
#  'minnesota',
#  'minnesota',
#  'dekalb',
#  'washington',
#  'd.c.',
#  'minneapolis',
#  'illinois',
#  'u.s.',
#  'michigan',
#  'michigan',
#  'washington',
#  'd.c.',
#  'america',
#  'minneapolis',
#  'washington',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'santa rosa',
#  'alameda county',
#  'philadelphia',
#  'pennsylvania',
#  'rockaways',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'decatur',
#  'america',
#  'these united states',
#  'decatur',
#  'atlanta',
#  'america',
#  'these united states',
#  'decatur',
#  'atlanta',
#  'minneapolis',
#  'america',
#  'decatur',
#  'santa teresa',
#  'these united states',
#  'krose@gavilan.edu',
#  'gilroy',
#  'atlanta',
#  'decatur',
#  'washington',
#  'minnesota',
#  'minneapolis',
#  'washington',
#  'us',
#  'us',
#  'washington',
#  'washington',
#  'memphis',
#  'washington',
#  'cedar rapids',
#  'minneapolis',
#  'iowa',
#  'cedar rapids',
#  'auckland',
#  'new zealand',
#  'u.s.',
#  'iran',
#  'washington',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'washington',
#  'the hennepin county jail',
#  'washington',
#  'brooklyn',
#  'brooklyn',
#  'u.s.',
#  'u.s.',
#  'dc',
#  'the city of sacramento',
#  'sacramento',
#  'the city of sacramento',
#  'the city of sacramento',
#  'harrisonburg',
#  'the city of sacramento',
#  'the city of sacramento',
#  'the city of sacramento',
#  'minneapolis',
#  'santa cruz',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'somerset',
#  'somerset',
#  'minneapolis',
#  'somerset',
#  'los angeles',
#  'philando',
#  'pa',
#  'philadelphia',
#  'pennsylvania',
#  'minneapolis',
#  'florida',
#  'miami',
#  'minnesota',
#  'fort lauderdale',
#  'florida',
#  'mashhad',
#  'tehran',
#  'santa monica',
#  'santa monica',
#  'santa monica',
#  'atlantic city',
#  'new jersey',
#  'jersey city',
#  'hamilton township',
#  'trenton',
#  'asbury park',
#  'atlantic city',
#  'madden',
#  'new jersey',
#  'hamilton township',
#  'trenton',
#  'pittsburgh',
#  'minneapolis',
#  'huntsville',
#  'huntsville',
#  'ala.',
#  'minneapolis',
#  'u.s.',
#  'dc',
#  'santa monica',
#  'georgia',
#  'huntsville',
#  'minnesota',
#  'atlanta',
#  'charlotte',
#  'minneapolis',
#  'sarasota county',
#  'oklahoma',
#  'minneapolis',
#  'america',
#  'america',
#  'minneapolis',
#  'america',
#  'chicago',
#  'boston',
#  'oklahoma',
#  'minneapolis',
#  'america',
#  'birmingham',
#  'alabama',
#  'tulsa',
#  'saratoga springs - photos',
#  'saratoga springs',
#  'columbus',
#  'fulton',
#  'minneapolis',
#  'ohio',
#  'atlantic city',
#  'new jersey',
#  'jersey city',
#  'hamilton township',
#  'trenton',
#  'asbury park',
#  'michigan',
#  'indianapolis',
#  'minneapolis',
#  'new york',
#  'queens',
#  'uconn',
#  'us',
#  'u.s.',
#  'russia',
#  'mississippi',
#  'virginia',
#  'carolinas',
#  'minneapolis',
#  'us',
#  'the united states',
#  'minneapolis',
#  'minneapolis',
#  'washington',
#  'd.c.',
#  'minneapolis',
#  'minneapolis',
#  'phoenix',
#  'washington',
#  'd.c.',
#  'minneapolis',
#  'minneapolis',
#  'phoenix',
#  'minneapolis',
#  'u.s.',
#  'portland',
#  'minneapolis',
#  'u.s.',
#  'minneapolis',
#  'u.s.',
#  'minnesota',
#  'east dallas',
#  'wisconsin',
#  'america',
#  'america',
#  'riverside',
#  'r-s.c.',
#  'florida',
#  'minneapolis',
#  'washington',
#  'china',
#  'us',
#  'new zealand',
#  'auckland',
#  'nazareth',
#  'minneapolis',
#  'america',
#  'minnesota',
#  'buffalo',
#  'nazareth',
#  'minneapolis',
#  'america',
#  'minnesota',
#  'buffalo',
#  'us',
#  'new zealand',
#  'auckland',
#  'richmond',
#  'richmond',
#  'minneapolis',
#  'america',
#  'minnesota',
#  'oregon',
#  'memphis',
#  'memphis',
#  'minneapolis',
#  'baltimore',
#  'minneapolis',
#  'pennsylvania',
#  'minneapolis',
#  'pennsylvania',
#  'us',
#  'minneapolis',
#  'pennsylvania',
#  'minneapolis',
#  'new york city',
#  'pennsylvania',
#  'minneapolis',
#  'pennsylvania',
#  'rapid city',
#  'rapid city',
#  's.d.',
#  'the united states',
#  'the united states',
#  'u.s.',
#  'philippines',
#  'los angeles',
#  'los angeles',
#  'minneapolis',
#  'mn',
#  'mi',
#  'flint',
#  'miami',
#  'the city of corona - city government',
#  'fl',
#  'los angeles',
#  'birmingham',
#  'boston',
#  'america',
#  'u.s.',
#  'minneapolis',
#  'minnesota',
#  'dc',
#  'israel',
#  'la',
#  'episcopal church',
#  'nyc',
#  'south carolina',
#  'america',
#  'boston',
#  'us',
#  'the united states',
#  'virginia',
#  'minneapolis',
#  'plainview',
#  'commack',
#  'minneapolis',
#  'plainview',
#  'commack',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'gloucester county',
#  'county',
#  'portsmouth',
#  'minneapolis',
#  'ohio',
#  'us',
#  'us',
#  'san luis obispo',
#  'us',
#  'america',
#  'us',
#  'minneapolis',
#  'u.s.',
#  'usa',
#  'minnesota',
#  'usa',
#  'los angeles',
#  'los angeles',
#  'los angeles',
#  'd.c.',
#  'buffalo n.y.',
#  'houston',
#  'los angeles',
#  'detroit',
#  "san francisco's",
#  'texas',
#  'minneapolis',
#  'us',
#  'miami',
#  'philadelphia',
#  'chicago',
#  'the united states',
#  'virginia',
#  'los angeles',
#  'detroit',
#  'us',
#  'miami',
#  'chicago',
#  'the united states',
#  'baltimore',
#  'minnesota',
#  'baltimore',
#  'minnesota',
#  'cleveland',
#  'minneapolis',
#  'sacramento',
#  'santa cruz',
#  'california',
#  'delaware',
#  'delaware',
#  'cambodia',
#  'delaware',
#  'modesto',
#  'minnesota',
#  'jamestown',
#  'oklahoma city',
#  'the city of cleveland',
#  'cleveland',
#  'spokane',
#  'wash.',
#  'spokane',
#  'santa monica',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minnesota',
#  'minneapolis',
#  'pinellas county sheriff',
#  'pinellas',
#  'pinellas county',
#  'delaware',
#  'oakland',
#  'u.s.',
#  'california',
#  'boston',
#  'oakland',
#  'u.s.',
#  'california',
#  'boston',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  'phoenix',
#  'murfreesboro',
#  'nashville',
#  'phoenix',
#  'liverpool',
#  'u.s.',
#  'liverpool',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'irvine',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'spokane',
#  'stevens county',
#  'minnesota',
#  'washington',
#  'minneapolis',
#  'america',
#  'minnesota',
#  'the united states of america',
#  'hennepin county',
#  'nashville',
#  'u.s.',
#  'hennepin county',
#  'minneapolis',
#  'seattle',
#  'seattle',
#  'minneapolis',
#  'minneapolis',
#  'russellville',
#  'goldsboro',
#  'russellville',
#  'the united states',
#  'usa',
#  'the united states',
#  'portland',
#  'the united states',
#  'the united states',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'the united states',
#  'rome',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'pittsburgh',
#  'pittsburgh',
#  'minneapolis',
#  'hennepin county',
#  'minneapolis',
#  'alabama',
#  'minneapolis',
#  'alabama',
#  'wisconsin',
#  'the united states',
#  'u.s.',
#  'albany',
#  'new york city',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  "cook county state's",
#  'minneapolis',
#  'king county',
#  'the city of kirkland',
#  'redmond',
#  'the city of kirkland',
#  'kirkland',
#  'bellevue',
#  'seattle',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'houston',
#  'boston',
#  'minneapolis',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'ahmaud arbery',
#  'georgia',
#  'minneapolis',
#  'kentucky',
#  'minneapolis',
#  'the united states of america',
#  'calvary',
#  'hennepin county',
#  'minneapolis',
#  'the united states',
#  'us',
#  'miami',
#  'minnesota',
#  'miami',
#  'minnesota',
#  'london',
#  'ky',
#  'minneapolis',
#  'douglas county',
#  'alexandria',
#  'madison',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'hunterdon county',
#  'hunterdon county',
#  'minneapolis',
#  'northshore',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'america',
#  'minneapolis',
#  'u.s.',
#  'america',
#  'michigan',
#  'orlando',
#  'orlando',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'st. louis',
#  'minneapolis',
#  'st. louis',
#  'minneapolis',
#  'u.s.',
#  'michigan',
#  'buffalo',
#  "oak park's",
#  'minnesota',
#  'oak park',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'st. lucie county',
#  'america',
#  'martin county',
#  'america',
#  'america',
#  'america',
#  'us',
#  'america',
#  'minneapolis',
#  'america',
#  'america',
#  'minneapolis',
#  'u.s.',
#  'america',
#  'america',
#  'minneapolis',
#  'america',
#  'us',
#  'america',
#  'america',
#  'us',
#  'america',
#  'america',
#  'the city of coralville',
#  'america',
#  'america',
#  'us',
#  'coralville',
#  'minneapolis',
#  'pittsburgh',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'arlington',
#  'syria',
#  'minneapolis',
#  'waukesha',
#  'ymca',
#  'san francisco',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'topeka',
#  'minneapolis',
#  'minneapolis',
#  'the city of racine',
#  'racine',
#  'minneapolis',
#  'minneapolis',
#  'west michigan',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'minnesota',
#  "new york city's",
#  'boca raton',
#  'boca',
#  'minneapolis',
#  'fl',
#  'minneapolis',
#  'worcester county',
#  'boca',
#  'boca raton',
#  'fl',
#  'worcester',
#  'ardmore',
#  'minnesota',
#  'ardmore',
#  'minnesota',
#  'tivnu',
#  'berkeley',
#  'charleston',
#  'berkeley county',
#  'summerville',
#  'north charleston',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'u.s.',
#  'detroit',
#  'los angeles',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'baltimore',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'montgomery',
#  'selma',
#  'minneapolis',
#  'minneapolis',
#  'nyc',
#  '@attorneycrump',
#  'america',
#  'america',
#  'santa cruz',
#  'charter city',
#  'santa cruz county',
#  'minnesota',
#  'the city of santa cruz',
#  'nyc',
#  'prince george’s county',
#  'minneapolis',
#  'georgia',
#  'kentucky',
#  'prince george’s',
#  'minneapolis',
#  'vermont',
#  'minneapolis',
#  'new jersey',
#  'new jersey',
#  'madison',
#  'kenosha',
#  'america',
#  'milwaukee',
#  'greenville',
#  'minnesota',
#  'minneapolis',
#  'america',
#  'oklahoma city',
#  'oklahoma city',
#  'oklahoma city',
#  'oklahoma city',
#  'philando castile',
#  'utica',
#  'america',
#  'america',
#  'america',
#  'hong kong',
#  'u.s.',
#  'ywca york',
#  'america',
#  'hong kong',
#  'u.s.',
#  'minneapolis',
#  'minneapolis',
#  'dc',
#  'florida',
#  'jacksonville',
#  'pittsburgh',
#  'maine',
#  'bangor city',
#  'maine',
#  'maine',
#  'maine',
#  'sioux city',
#  'minneapolis',
#  'minneapolis',
#  'marin',
#  'minnesota',
#  'minneapolis',
#  'san diego',
#  'minneapolis',
#  'san diego',
#  'minneapolis',
#  'cleveland',
#  'minnesota',
#  'st. louis',
#  '@thepascalshow',
#  'hollywood',
#  'minnesota',
#  'minnesota',
#  'minnesota',
#  'wisconsin',
#  'minneapolis',
#  'milwaukee',
#  'minnesota',
#  'minneapolis',
#  'arizona',
#  'az',
#  'minneapolis',
#  'arizona',
#  'foxboro',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'minneapolis',
#  'minnesota',
#  'scottsdale',
#  'arizona',
#  'scottsdale',
#  'arizona',
#  'america',
#  'us',
#  'greenville',
#  'missouri',
#  'missouri',
#  'usa',
#  'milwaukee',
#  'wisconsin',
#  'milwaukee',
#  'calif.',
#  'santa monica',
#  'santa monica',
#  'south dakota',
#  'america',
#  'minneapolis',
#  'minneapolis',
#  'minneapolis',
#  'san diego',
#  'san diego',
#  'minneapolis',
#  'san diego',
#  'san diego',
#  'san jose',
#  'san jose city',
#  'san jose',
#  'calif.',
#  'houston',
#  'minneapolis',
#  'houston',
#  'minnesota',
#  'houston',
#  'minneapolis',
#  'houston',
#  'minnesota',
#  'jackson',
#  'tenn.',
#  'orange county district',
#  'minnesota',
#  'calif.',
#  'santa monica',
#  'santa monica',
#  'calif.',
#  'santa monica',
#  'santa monica',
#  'sacramento',
#  'sacramento',
#  'minneapolis',
#  'texas',
#  'minneapolis',
#  'texas',
#  'scottsdale',
#  'arizona',
#  'las vegas',
#  'las vegas',
#  'minneapolis',
#  'minnesota',
#  'las vegas strip',
#  'us',
#  'usa',
#  'texas',
#  'austin',
#  'la county',
#  'minneapolis',
#  'los angeles county',
#  'calif.',
#  'santa monica',
#  'santa monica',
#  'minneapolis',
#  'minneapolis',
#  'the inland empire',
#  'los angeles',
#  'san bernardino',
#  'minneapolis',
#  'minnesota',
#  'waukesha',
#  'milwaukee',
#  'waukesha',
#  'wis.',
#  'waukesha',
#  'minneapolis',
#  'milwaukee',
#  'wis.',
#  'new jersey',
#  'waukesha',
#  'union county',
#  'appleton',
#  'wis.',
#  'minneapolis',
#  'westgate',
#  'calif.',
#  'santa monica',
#  'santa monica',
#  'la county',
#  'minneapolis',
#  'los angeles county',
#  'jonesboro',
#  'jonesboro',
#  'minneapolis',
#  'u.s',
#  'st. paul',
#  'oakland',
#  'minneapolis',
#  'tyler',
#  'texas',
#  'la county',
#  'minneapolis',
#  'los angeles county',
#  'la county',
#  'minneapolis',
#  'los angeles county',
#  'philando castile',
#  'minneapolis',
#  'america',
#  'los angeles county',
#  'virginia - india beaty',
#  'minneapolis',
#  'los angeles county',
#  '3:00pm',
#  'montgomery county',
#  'maryland',
#  'montgomery county',
#  'america',
#  'washington d.c.',
#  "new york's",
#  'maryland',
#  'minneapolis',
#  'united states',
#  'hennepin county me',
#  'minneapolis',
#  'hennepin county',
#  'minneapolis',
#  'hennepin county',
#  'minneapolis',
#  'hennepin county',
#  'america',
#  'michigan',
#  'minneapolis',
#  'minneapolis',
#  'philando castile',
#  'minneapolis',
#  'milwaukee',
#  'wisconsin',
#  'the united states of america',
#  'america',
#  'america',
#  'america',
#  'minnesota',
#  'new york',
#  'portland',
#  'oregon',
#  'minneapolis',
#  'minnesota',
#  'us',
#  'washington',
#  'us',
#  'washington',
#  'us',
#  'washington',
#  'us',
#  'us',
#  'thunberg',
#  'america',
#  'minnesota',
#  'minnesota',
#  'usa',
#  'minnesota',
#  'san diego',
#  'minneapolis',
#  'somerset',
#  'somerset',
#  'minneapolis',
#  'somerset',
#  'somerset',
#  'minneapolis',
#  'somerset',
#  'somerset',
#  'episcopal church',
#  'minneapolis',
#  'louisville',
#  'georgia',
#  'kentucky',
#  'brunswick',
#  'west michigan',
#  'grand rapids',
#  'michigan',
#  'minneapolis',
#  'minnesota',
#  'america',
#  'minnesota',
#  'wisconsin',
#  'minnesota',
#  'hong kong',
#  'china',
#  'minneapolis',
#  'the united states',
#  'minneapolis',
#  'america',
#  'minneapolis',
#  'u.s.',
#  'plant city',
#  'minneapolis',
#  'baltimore',
#  'minneapolis',
#  'baltimore',
#  'minnesota',
#  'minneapolis',
#  'baltimore',
#  'the city of st. louis',
#  'kobe',
#  'https://to.pbs.org/2mjbben',
#  'united states',
#  'philando castile',
#  'minneapolis',
#  'milwaukee',
#  'wisconsin',
#  'the united states of america',
#  'flagler beach',
#  'flagler county',
#  'minneapolis',
#  'america',
#  'bunnell',
#  'the city of newark',
#  'alameda county imposes a countywide curfew',
#  'flagler beach',
#  'flagler county',
#  'minneapolis',
#  'america',
#  'newark',
#  'the city and county',
#  ...]

# %%
c = collections.Counter()

# %%
dict_a=collections.Counter(list).most_common()

# %%
dict_a
# Out:
# [('minneapolis', 8856),
#  ('minnesota', 2579),
#  ('america', 2183),
#  ('u.s.', 1792),
#  ('the united states', 1658),
#  ('us', 1291),
#  ('washington', 639),
#  ('chicago', 551),
#  ('california', 439),
#  ('atlanta', 438),
#  ('los angeles', 438),
#  ('texas', 396),
#  ('new york', 368),
#  ('d.c.', 362),
#  ('flint', 353),
#  ('houston', 352),
#  ('boston', 337),
#  ('michigan', 332),
#  ('seattle', 319),
#  ('new york city', 313),
#  ('dc', 304),
#  ('london', 263),
#  ('florida', 261),
#  ('philadelphia', 252),
#  ('portland', 237),
#  ('nyc', 232),
#  ('georgia', 229),
#  ('camden', 227),
#  ('oakland', 224),
#  ('nj', 186),
#  ('hennepin county', 183),
#  ('sacramento', 179),
#  ('denver', 170),
#  ('los angeles county', 169),
#  ('louisville', 167),
#  ('connecticut', 163),
#  ('st. paul', 157),
#  ('dallas', 157),
#  ('mn', 150),
#  ('brooklyn', 143),
#  ('baltimore', 143),
#  ('kentucky', 143),
#  ('la county', 139),
#  ('maine', 138),
#  ('milwaukee', 135),
#  ('manhattan', 135),
#  ('san francisco', 134),
#  ('wisconsin', 131),
#  ('detroit', 129),
#  ('santa monica', 126),
#  ('charlotte', 123),
#  ('asbury', 123),
#  ('miami', 122),
#  ('ohio', 120),
#  ('new jersey', 116),
#  ('asbury park', 116),
#  ('germany', 114),
#  ('massachusetts', 112),
#  ('iowa', 110),
#  ('tennessee', 108),
#  ('berlin', 103),
#  ('north carolina', 102),
#  ('des moines', 102),
#  ('nashville', 101),
#  ('canada', 98),
#  ('mississippi', 96),
#  ('richmond', 96),
#  ('newark', 96),
#  ('new hampshire', 96),
#  ('pittsburgh', 94),
#  ('philando castile', 94),
#  ('virginia', 93),
#  ('cleveland', 93),
#  ('albuquerque', 90),
#  ('arizona', 88),
#  ('illinois', 86),
#  ('russia', 86),
#  ('columbus', 85),
#  ('ahmaud arbery', 85),
#  ('bryan', 83),
#  ('delaware', 82),
#  ('orlando', 82),
#  ('nc', 82),
#  ('usa', 79),
#  ('san diego', 79),
#  ('uptown', 79),
#  ('minn.', 77),
#  ('indianapolis', 76),
#  ('genesee county', 75),
#  ('wilmington', 75),
#  ('oregon', 73),
#  ('san jose', 73),
#  ('colorado', 73),
#  ('austin', 70),
#  ('rhode', 69),
#  ('san bernardino', 68),
#  ('united states', 68),
#  ('birmingham', 67),
#  ('china', 66),
#  ('south carolina', 65),
#  ('columbia', 64),
#  ('nebraska', 64),
#  ('indiana', 63),
#  ('| atlanta', 63),
#  ('ny', 62),
#  ('raleigh', 62),
#  ('alabama', 61),
#  ('the united states of america', 61),
#  ('wi', 61),
#  ('pennsylvania', 60),
#  ('new zealand', 60),
#  ('casper', 60),
#  ('madison', 59),
#  ('tampa', 59),
#  ('kansas city', 59),
#  ('spokane', 58),
#  ('charleston', 58),
#  ('vermont', 58),
#  ('sioux falls', 58),
#  ('omaha', 58),
#  ('tulsa', 56),
#  ('fort lauderdale', 55),
#  ('long beach', 55),
#  ('oklahoma city', 54),
#  ('washington d.c.', 53),
#  ('albany', 52),
#  ('missouri', 52),
#  ('las vegas', 52),
#  ('new curfew', 52),
#  ('phoenix', 51),
#  ('uk', 50),
#  ('scottsdale', 49),
#  ('calif.', 49),
#  ('washington dc', 49),
#  ('el paso', 49),
#  ('racine', 48),
#  ('l.a.', 48),
#  ('la', 47),
#  ('santa cruz', 46),
#  ('springfield', 46),
#  ('philly', 46),
#  ('arkansas', 45),
#  ('the district of columbia', 45),
#  ('montgomery county', 44),
#  ('maryland', 43),
#  ('queens', 42),
#  ('county', 42),
#  ('atlantic city', 41),
#  ('trenton', 41),
#  ('fl', 41),
#  ('bellevue', 41),
#  ('greenville', 41),
#  ('hollywood', 41),
#  ('tallahassee', 41),
#  ('u.k.', 41),
#  ('st. louis', 40),
#  ('toronto', 40),
#  ('savannah', 40),
#  ('cincinnati', 39),
#  ('flint twp', 39),
#  ('dayton', 39),
#  ('racine county', 39),
#  ('ga', 39),
#  ('brunswick', 38),
#  ('wv', 37),
#  ('nevada', 37),
#  ('salt lake city', 37),
#  ("new jersey's", 37),
#  ('iran', 35),
#  ('oklahoma', 35),
#  ('waukesha', 35),
#  ('sc', 35),
#  ('england', 35),
#  ('polk county', 35),
#  ('new orleans', 34),
#  ('riverside', 34),
#  ('alexandria', 34),
#  ('worcester', 34),
#  ('grand rapids', 34),
#  ('tx', 34),
#  ('mo.', 34),
#  ('jackson', 33),
#  ('hong kong', 33),
#  ('sioux', 33),
#  ('s.c.', 33),
#  ('decatur', 32),
#  ('colorado springs', 32),
#  ('san antonio', 32),
#  ('santa maria', 32),
#  ('asheville', 32),
#  ('lafayette', 31),
#  ('flint township', 31),
#  ('salem', 31),
#  ('n.c.', 31),
#  ('fresno', 31),
#  ('staten island', 31),
#  ('memphis', 30),
#  ('tenn.', 30),
#  ('lafayette park', 30),
#  ('new york’s', 30),
#  ('auckland', 29),
#  ('jacksonville', 29),
#  ('bangkok', 29),
#  ('fayetteville', 29),
#  ('joplin', 29),
#  ('louisiana', 29),
#  ('rochester', 29),
#  ('the city of riverside', 28),
#  ('buffalo', 28),
#  ('utah', 28),
#  ('virginia beach', 28),
#  ('schenectady', 28),
#  ('wash.', 27),
#  ('burlington county', 27),
#  ('orange county', 27),
#  ('the city of minneapolis', 27),
#  ('knoxville', 26),
#  ('naperville', 26),
#  ('manchester', 26),
#  ('greensboro', 26),
#  ('binghamton', 26),
#  ('wyo.', 26),
#  ('chattanooga', 26),
#  ('west palm beach', 26),
#  ('bakersfield', 26),
#  ('coral gables', 26),
#  ('willingboro', 25),
#  ('walnut creek', 25),
#  ('utica', 24),
#  ('beavercreek', 24),
#  ('va.', 24),
#  ('baton rouge', 24),
#  ('florence', 24),
#  ('davenport', 24),
#  ('wy', 24),
#  ('south minneapolis', 24),
#  ('san luis obispo', 23),
#  ('boca raton', 23),
#  ('wis.', 23),
#  ('delray beach', 23),
#  ('minn', 23),
#  ('morristown', 23),
#  ('amarillo', 23),
#  ('riverside county', 23),
#  ('ore.', 23),
#  ('santa rosa', 22),
#  ('ala.', 22),
#  ('israel', 22),
#  ('liverpool', 22),
#  ("new york's", 22),
#  ('cambridge', 22),
#  ('lancaster', 22),
#  ('hartford', 22),
#  ('bloomington', 22),
#  ('macon', 22),
#  ('kansas', 22),
#  ('carmel', 22),
#  ('huntington beach', 22),
#  ('fla.', 22),
#  ('huntsville', 21),
#  ('syria', 21),
#  ('south dakota', 21),
#  ('cheyenne', 21),
#  ('genesee county sheriff', 21),
#  ('mich.', 21),
#  ('zoom', 21),
#  ('milan', 21),
#  ('new haven', 21),
#  ('fort wayne', 21),
#  ('harrisburg', 21),
#  ('new jersey’s', 21),
#  ('hennepin', 21),
#  ('tuscaloosa', 21),
#  ('u.s', 20),
#  ('italy', 20),
#  ('okc', 20),
#  ('york', 20),
#  ('mobile', 20),
#  ('lansing', 20),
#  ('morocco', 20),
#  ('bozeman', 20),
#  ('clarksburg', 19),
#  ('stoke', 19),
#  ('chicagoland', 19),
#  ('little rock', 19),
#  ('wyoming', 19),
#  ('charlottesville', 19),
#  ('windermere', 19),
#  ('jersey city', 18),
#  ('myrtle beach', 18),
#  ('new zealand’s', 18),
#  ('new mexico', 18),
#  ('ywca', 18),
#  ('la playa', 18),
#  ('toledo', 18),
#  ('pa', 17),
#  ('murfreesboro', 17),
#  ('n.j.', 17),
#  ('dover', 17),
#  ('n.m.', 17),
#  ('san angelo', 17),
#  ('syracuse', 17),
#  ('n.y.', 17),
#  ('boise', 17),
#  ('monmouth county', 17),
#  ('englewood', 17),
#  ('pawleys island', 17),
#  ('duluth', 17),
#  ("new zealand's", 16),
#  ('tokyo', 16),
#  ('the united kingdom', 16),
#  ('pensacola', 16),
#  ('ferguson', 16),
#  ('shreveport', 16),
#  ('ga.', 16),
#  ('fort myers', 16),
#  ('center city', 16),
#  ('va', 16),
#  ('auburn', 16),
#  ('city', 16),
#  ('fort worth', 16),
#  ('bristol', 16),
#  ('detroit lakes', 16),
#  ('fairfax', 16),
#  ('iowa city', 15),
#  ('lufkin', 15),
#  ('stockton', 15),
#  ('all city of riverside', 15),
#  ('monroe county', 15),
#  ('copenhagen', 15),
#  ('pasco', 15),
#  ('cedar city', 15),
#  ('these united states', 14),
#  ('episcopal church', 14),
#  ('jamestown', 14),
#  ('montgomery', 14),
#  ('la mesa', 14),
#  ('germantown', 14),
#  ('streator', 14),
#  ('north minneapolis', 14),
#  ('wichita', 14),
#  ('denmark', 14),
#  ('west chester', 14),
#  ('paris', 14),
#  ('toms river', 14),
#  ('west islip', 14),
#  ('lubbock', 14),
#  ('w.va.', 14),
#  ('ardmore', 13),
#  ('sioux city', 13),
#  ('rhode island', 13),
#  ('palestine', 13),
#  ('hampton', 13),
#  ('india', 13),
#  ('soho', 13),
#  ('lexington', 13),
#  ('italia', 13),
#  ('somerville', 13),
#  ('coral springs', 13),
#  ('triblive', 13),
#  ('josephine county', 13),
#  ('gwinnett county', 13),
#  ('nassau county', 13),
#  ('kenosha', 12),
#  ('abilene', 12),
#  ('bangor', 12),
#  ('tacoma', 12),
#  ('reno', 12),
#  ('nixle', 12),
#  ('lake county', 12),
#  ('ind.', 12),
#  ('ky.', 12),
#  ('denton', 12),
#  ('minne', 12),
#  ('las cruces', 12),
#  ('idaho', 12),
#  ('mineola', 12),
#  ('fort bragg', 12),
#  ('san leandro', 12),
#  ('palm beach lakes boulevard', 12),
#  ('stroudsburg', 12),
#  ('athens', 12),
#  ('morgantown', 12),
#  ('yonkers', 12),
#  ('ameri', 12),
#  ('alameda county', 11),
#  ('the city of sacramento', 11),
#  ('somerset', 11),
#  ('carolinas', 11),
#  ('rapid city', 11),
#  ('modesto', 11),
#  ('arlington', 11),
#  ('west michigan', 11),
#  ('tx fayetteville', 11),
#  ('fremont', 11),
#  ('temple israel', 11),
#  ('la.', 11),
#  ('il', 11),
#  ('tucson', 11),
#  ('doylestown', 11),
#  ('ct', 11),
#  ('redding', 11),
#  ('beloit', 11),
#  ('troy', 11),
#  ('muskegon', 11),
#  ('west virginia', 11),
#  ('east moline', 11),
#  ('britain', 11),
#  ('canton', 11),
#  ('kalamazoo', 11),
#  ('lawrenceville', 11),
#  ('miami-dade county', 11),
#  ('poughkeepsie', 11),
#  ('carbondale', 11),
#  ('west virginia university', 11),
#  ('beckley', 11),
#  ('md', 11),
#  ('sandusky', 11),
#  ('santa ana', 11),
#  ('washington state', 11),
#  ('longview', 11),
#  ('livingston', 11),
#  ('uptown charlotte', 11),
#  ('exeter', 11),
#  ('miss.', 10),
#  ('fulton', 10),
#  ('philippines', 10),
#  ('topeka', 10),
#  ('selma', 10),
#  ('rockford', 10),
#  ('haiti', 10),
#  ('north hills', 10),
#  ('beverly hills', 10),
#  ('gainesville', 10),
#  ('kinston', 10),
#  ('hamilton county', 10),
#  ('kissimmee', 10),
#  ('mass.', 10),
#  ('beaumont', 10),
#  ('jefferson', 10),
#  ('st. petersburg', 10),
#  ('broward county', 10),
#  ('wa', 10),
#  ('williams-sonoma', 10),
#  ('manassas', 10),
#  ('kearney', 10),
#  ('westfield', 10),
#  ('the county of riverside', 10),
#  ('marietta', 10),
#  ('freeport', 10),
#  ('somerset county', 10),
#  ('glynn county', 10),
#  ('ohio city curfews in effect', 10),
#  ('martinsburg', 10),
#  ('towson', 10),
#  ('north dakota', 10),
#  ('akron', 10),
#  ('bloomfield', 10),
#  ('killeen', 10),
#  ('jerusalem', 10),
#  ('queens borough', 10),
#  ('the nassau county legislature', 10),
#  ('long island', 10),
#  ('hs dems suffolk', 10),
#  ('visalia', 10),
#  ('socal', 10),
#  ('harrisonburg', 9),
#  ('r-s.c.', 9),
#  ('s.d.', 9),
#  ('portsmouth', 9),
#  ('king county', 9),
#  ('ky', 9),
#  ('douglas county', 9),
#  ("new york city's", 9),
#  ('@attorneycrump', 9),
#  ('kobe', 9),
#  ('l.a. county', 9),
#  ('latinx', 9),
#  ('houma', 9),
#  ('myers park united methodist church', 9),
#  ('umc', 9),
#  ('st. stephen united', 9),
#  ('baptist church', 9),
#  ('roanoke', 9),
#  ('santa barbara', 9),
#  ('medford', 9),
#  ('providence', 9),
#  ('quincy', 9),
#  ('muncie', 9),
#  ('kingdom', 9),
#  ('washington, dc', 9),
#  ('napa', 9),
#  ('conway', 9),
#  ('the kingdom of god', 9),
#  ('hampton roads', 9),
#  ('montana', 9),
#  ('rockland', 9),
#  ('fairmont', 9),
#  ('hamilton', 9),
#  ('conroe', 9),
#  ('ill.', 9),
#  ('champaign', 9),
#  ('hampton beach', 9),
#  ('beijing', 9),
#  ('humboldt county', 9),
#  ('east stroudsburg', 9),
#  ('sf', 9),
#  ('fort smith', 9),
#  ('geneva', 9),
#  ('tinashe', 9),
#  ('riverdale', 9),
#  ('curfew', 9),
#  ('palm beach', 9),
#  ('capital city', 9),
#  ('arenal', 9),
#  ('churches aroun', 9),
#  ('| jersey shore', 9),
#  ('chambersburg', 9),
#  ('astoria', 9),
#  ('east elmhurst', 9),
#  ('the hennepin county jail', 8),
#  ('hamilton township', 8),
#  ('rome', 8),
#  ('coralville', 8),
#  ('bangor city', 8),
#  ('tyler', 8),
#  ('the city of newark', 8),
#  ('clark county', 8),
#  ('cincy', 8),
#  ('missoula', 8),
#  ('bremerton', 8),
#  ('waterbury', 8),
#  ('jordan', 8),
#  ('sarasota', 8),
#  ('danville', 8),
#  ('allentown', 8),
#  ('brentwood', 8),
#  ('clinton', 8),
#  ('oxford', 8),
#  ('genesee', 8),
#  ('castile', 8),
#  ('augusta', 8),
#  ('middletown', 8),
#  ("hennepin county's", 8),
#  ('anaheim', 8),
#  ('fredericksburg', 8),
#  ('twin cities', 8),
#  ('richland', 8),
#  ('westminster', 8),
#  ('washington county', 8),
#  ('new bedford', 8),
#  ('olympia', 8),
#  ('pa.', 8),
#  ('holland', 8),
#  ('north texas', 8),
#  ('pasadena', 8),
#  ('morrisville', 8),
#  ('| suny', 8),
#  ('montauk', 8),
#  ('dekalb', 7),
#  ('cedar rapids', 7),
#  ('mashhad', 7),
#  ('tehran', 7),
#  ('sarasota county', 7),
#  ('saratoga springs', 7),
#  ('az', 7),
#  ('jonesboro', 7),
#  ('el centro', 7),
#  ('eugene', 7),
#  ('the city of cambridge', 7),
#  ('santa rosa city', 7),
#  ('santa rosa mayor', 7),
#  ('santa rosans', 7),
#  ('the city of santa rosa', 7),
#  ('gaithersburg', 7),
#  ('thibodaux', 7),
#  ('otsego', 7),
#  ('benicia', 7),
#  ('huntington', 7),
#  ('annapolis', 7),
#  ('kan.', 7),
#  ('suffolk', 7),
#  ('los angeles city hall', 7),
#  ('edwardsville', 7),
#  ('the city of houston', 7),
#  ('lakewood', 7),
#  ('marysville', 7),
#  ('dublin', 7),
#  ('bellingham', 7),
#  ('lorain', 7),
#  ('nassau', 7),
#  ('the united states constitution', 7),
#  ('vancouver', 7),
#  ('bluffton', 7),
#  ('mankato', 7),
#  ('cape girardeau', 7),
#  ('bengals', 7),
#  ('broward', 7),
#  ('durham', 7),
#  ('md.', 7),
#  ("san antonio's", 7),
#  ('melbourne', 7),
#  ('baptist', 7),
#  ('stillwater', 7),
#  ('north canton', 7),
#  ('the george floyd riots', 7),
#  ('erie', 7),
#  ('odessa', 7),
#  ('temecula', 7),
#  ('peoria', 7),
#  ('cumberland', 7),
#  ('bessemer', 7),
#  ('jefferson city', 7),
#  ('blacksburg', 7),
#  ('petersburg', 7),
#  ('columbia county', 7),
#  ('taheshah', 7),
#  ('the city of carmel', 7),
#  ('highland park', 7),
#  ('kingsport', 7),
#  ('the city of hoover', 7),
#  ('parkersburg', 7),
#  ('hilton', 7),
#  ('williamsburg', 7),
#  ('philando', 6),
#  ('the city of kirkland', 6),
#  ('oak park', 6),
#  ('berkeley county', 6),
#  ('jamaica', 6),
#  ('centerville', 6),
#  ('broome county', 6),
#  ('ashland', 6),
#  ('israel-palestine', 6),
#  ('st. louis county', 6),
#  ('the city of boston', 6),
#  ('southwest minneapolis', 6),
#  ('saint paul', 6),
#  ('northampton', 6),
#  ('midland', 6),
#  ('hayward', 6),
#  ('australia', 6),
#  ('france', 6),
#  ('bend', 6),
#  ('indio', 6),
#  ('the county of los angeles', 6),
#  ('ywca minneapolis', 6),
#  ('peru', 6),
#  ('hillels', 6),
#  ('south florida', 6),
#  ('concord', 6),
#  ("madison county's", 6),
#  ('new orleans remain mostly', 6),
#  ('darlington', 6),
#  ('f.c.', 6),
#  ('bengal', 6),
#  ('idaho state', 6),
#  ('spokane county', 6),
#  ('monmouth', 6),
#  ('bronx', 6),
#  ('the city of clermont', 6),
#  ('urbana', 6),
#  ('i-95', 6),
#  ('michigan city', 6),
#  ('benton harbor', 6),
#  ('fargo', 6),
#  ('helena', 6),
#  ('san diego county', 6),
#  ('santa clara', 6),
#  ('gaylord', 6),
#  ('anoka', 6),
#  ('los angles', 6),
#  ('spain', 6),
#  ('new york regions', 6),
#  ('carlsbad', 6),
#  ('paducah', 6),
#  ('pueblo', 6),
#  ('cape canaveral', 6),
#  ('lakeland', 6),
#  ('little rock city hall', 6),
#  ('mount vernon', 6),
#  ('the city of fremont', 6),
#  ('burlington', 6),
#  ('third ward', 6),
#  ('bedford', 6),
#  ('the city of dekalb', 6),
#  ('wuhan', 6),
#  ('dakotas', 6),
#  ('vatican city', 6),
#  ('arcata', 6),
#  ('sac state', 6),
#  ('hoboken', 6),
#  ('bath new york', 5),
#  ('mi', 5),
#  ('the city of coralville', 5),
#  ('summerville', 5),
#  ('https://to.pbs.org/2mjbben', 5),
#  ('flagler beach', 5),
#  ('flagler county', 5),
#  ('bunnell', 5),
#  ('blm', 5),
#  ('jersey', 5),
#  ('gaza', 5),
#  ('mid-michigan', 5),
#  ('new britain', 5),
#  ('hamilton county courthouse', 5),
#  ('allegheny county', 5),
#  ('norfolk', 5),
#  ('palm beach county', 5),
#  ('egypt', 5),
#  ('west caldwell', 5),
#  ('qb', 5),
#  ('ocala', 5),
#  ('erie county', 5),
#  ('bend county', 5),
#  ('beverly', 5),
#  ('south georgia', 5),
#  ('vegas', 5),
#  ('uganda', 5),
#  ('miami-dade', 5),
#  ('montreal', 5),
#  ('s---', 5),
#  ('adams', 5),
#  ('mercer county', 5),
#  ('venice', 5),
#  ('monroe', 5),
#  ('green bay', 5),
#  ('puerto rico', 5),
#  ('the city of clinton', 5),
#  ('the city of riverside’s', 5),
#  ('bethlehem', 5),
#  ('beat columbia', 5),
#  ('baltimore city', 5),
#  ('district', 5),
#  ('ventura county', 5),
#  ("the palm beach county sheriff's office", 5),
#  ('moreno valley', 5),
#  ('oroville', 5),
#  ("kansas city's", 5),
#  ('minnea', 5),
#  ('alpharetta', 5),
#  ('tn', 5),
#  ('the city of covington', 5),
#  ('janesville', 5),
#  ('tukwila', 5),
#  ('the city of bend police department', 5),
#  ('goshen', 5),
#  ('san clemente', 5),
#  ('billings', 5),
#  ('colo.', 5),
#  ('san josé', 5),
#  ('lancaster county', 5),
#  ('new york city’s', 5),
#  ('north korea', 5),
#  ('roxbury', 5),
#  ('mo', 5),
#  ('little rock’s', 5),
#  ('boylston', 5),
#  ('newbury', 5),
#  ('westchester', 5),
#  ('paso', 5),
#  ('suffolk county district', 5),
#  ('falmouth', 5),
#  ('brazil', 5),
#  ('cook county', 5),
#  ('nw ohio', 5),
#  ('south sacramento', 5),
#  ('west palm', 5),
#  ('milwaukee county', 5),
#  ('wheeling', 5),
#  ('mariposa county', 5),
#  ('olean', 5),
#  ('bullhead city - lake havasu city', 5),
#  ('los angeles county district', 5),
#  ('twitter]los angeles', 5),
#  ('nazareth', 4),
#  ('berkeley', 4),
#  ('appleton', 4),
#  ('buckhead', 4),
#  ('st pete', 4),
#  ('orphanage', 4),
#  ('essex county', 4),
#  ('the highlands', 4),
#  ('blandford', 4),
#  ('sheinelle', 4),
#  ('dauphin county', 4),
#  ('mansfield', 4),
#  ('evansville', 4),
#  ('henderson', 4),
#  ('spring valley', 4),
#  ('salt lake', 4),
#  ('gazette', 4),
#  ('sam houston', 4),
#  ('ithaca', 4),
#  ('fort walton beach', 4),
#  ('iraq', 4),
#  ('scottsbluff', 4),
#  ('venmo', 4),
#  ('okla.', 4),
#  ('chad', 4),
#  ('camden county', 4),
#  ("st. john's", 4),
#  ('amerikkka', 4),
#  ('york county', 4),
#  ('d.c', 4),
#  ('kenya', 4),
#  ('howard county', 4),
#  ('ark.', 4),
#  ('nm', 4),
#  ('plainfield', 4),
#  ('the village of plainfield', 4),
#  ('newport', 4),
#  ('tri-county', 4),
#  ('turkey', 4),
#  ('ywca usa', 4),
#  ('the city county building', 4),
#  ('vietnam', 4),
#  ('nyack', 4),
#  ('leesburg', 4),
#  ('greenwood', 4),
#  ('winston-salem', 4),
#  ('baden', 4),
#  ('nh', 4),
#  ('jackson michigan', 4),
#  ('jr.', 4),
#  ('mt. vernon', 4),
#  ('williamson county', 4),
#  ('timberwolves', 4),
#  ('fort greene', 4),
#  ('anne arundel county', 4),
#  ('joliet', 4),
#  ('pomona', 4),
#  ('palmyra', 4),
#  ('monterey', 4),
#  ('brockton', 4),
#  ('greenacres', 4),
#  ('hemet', 4),
#  ('the city of asbury park', 4),
#  ('clermont', 4),
#  ('the city and county of denver', 4),
#  ('millburn', 4),
#  ('amherst', 4),
#  ('5:30pm', 4),
#  ('alameda county\n\n', 4),
#  ('butte county', 4),
#  ('neb.', 4),
#  ('birmingham jail', 4),
#  ('edgewood', 4),
#  ('harford county', 4),
#  ('new mexico’s', 4),
#  ('beaufort county', 4),
#  ('breonna', 4),
#  ('westport', 4),
#  ('poway', 4),
#  ('the city of wichita', 4),
#  ('elgin', 4),
#  ('beaufort', 4),
#  ('sonoma county', 4),
#  ('delano', 4),
#  ('hawaii', 4),
#  ('watsonville', 4),
#  ('humboldt', 4),
#  ('samaritan', 4),
#  ('coconino county', 4),
#  ('pres', 4),
#  ('somalia', 4),
#  ('guilford', 4),
#  ('petoskey', 4),
#  ('warminster', 4),
#  ('zimbabwe', 4),
#  ('mclean county', 4),
#  ('comunidad', 4),
#  ('este desafío', 4),
#  ('nuestra comunidad', 4),
#  ('ut', 4),
#  ('flagstaff', 4),
#  ('christ', 4),
#  ('stark county', 4),
#  ('hagerstown', 4),
#  ('laredo', 4),
#  ('ma', 4),
#  ('grayson county', 4),
#  ('hennepin county district', 4),
#  ('united states of america', 4),
#  ('conn.', 4),
#  ('calaveras county', 4),
#  ('the city of fulton', 4),
#  ('the city of raleigh', 4),
#  ('washington d.c', 4),
#  ('paso robles', 4),
#  ('yuba streets', 4),
#  ('his city', 4),
#  ('statesville', 4),
#  ('maple valley', 4),
#  ('pierre', 4),
#  ('the holy metropolis of chicago', 4),
#  ('johnson county', 4),
#  ('lower manhattan', 4),
#  ('provincetown', 4),
#  ('san francisco city hall', 4),
#  ('okla', 4),
#  ('beachwood', 4),
#  ('east texas', 4),
#  ('lewiston', 4),
#  ('east hanover', 4),
#  ('berkshire county', 4),
#  ('yadkin', 4),
#  ('morgan county', 4),
#  ('covington', 4),
#  ('american city', 4),
#  ('dupage county', 4),
#  ('hollidaysburg', 4),
#  ('caldwell', 4),
#  ('the city of fort wayne', 4),
#  ('the city of newburyport', 4),
#  ('bogert park', 4),
#  ('flemington', 4),
#  ('danbury', 4),
#  ('san antonio spurs', 4),
#  ('las olas boulvard', 4),
#  ('madden', 3),
#  ('saratoga springs - photos', 3),
#  ('east dallas', 3),
#  ('plainview', 3),
#  ('commack', 3),
#  ("san francisco's", 3),
#  ('pinellas county', 3),
#  ('irvine', 3),
#  ('kirkland', 3),
#  ('hunterdon county', 3),
#  ('ymca', 3),
#  ('boca', 3),
#  ('marin', 3),
#  ('orange county district', 3),
#  ('las vegas strip', 3),
#  ('the city and county', 3),
#  ('chatham county', 3),
#  ('the hennepin county’s', 3),
#  ('the jewish federation', 3),
#  ('smithfield', 3),
#  ('south korea', 3),
#  ('walnut st.', 3),
#  ('fla', 3),
#  ('ohio montgomery county', 3),
#  ('the city of poughkeepsie', 3),
#  ('minnesota state', 3),
#  ('rancho cucamonga', 3),
#  ('chauvin', 3),
#  ('riverhead', 3),
#  ('minot', 3),
#  ('lawton', 3),
#  ('hattiesburg', 3),
#  ('lawrence', 3),
#  ('va. sheriff', 3),
#  ('stafford', 3),
#  ('dewey beach police', 3),
#  ('dortmund', 3),
#  ('alaska', 3),
#  ('belgium', 3),
#  ('wrig', 3),
#  ('lowcountry', 3),
#  ('johnstown', 3),
#  ('fulton county', 3),
#  ('oakley', 3),
#  ('niagara', 3),
#  ('district attorneys', 3),
#  ('sr.', 3),
#  ('montclair', 3),
#  ('sydney', 3),
#  ('methuen', 3),
#  ('the fairfax district', 3),
#  ('stuart', 3),
#  ('alamance county', 3),
#  ('vt', 3),
#  ('ireland', 3),
#  ('scarborough', 3),
#  ('south florida’s', 3),
#  ('quincy enunwa', 3),
#  ('west roxbury', 3),
#  ('south jersey', 3),
#  ('the city of birmingham', 3),
#  ('mt', 3),
#  ('champaign county', 3),
#  ('st. helena', 3),
#  ('trump', 3),
#  ('ocean county', 3),
#  ('arbery', 3),
#  ('multnomah county', 3),
#  ('delaware county', 3),
#  ('lebanon york', 3),
#  ('hummelstown', 3),
#  ('new oxford', 3),
#  ('east berlin', 3),
#  ('jonestown', 3),
#  ('gettysburg', 3),
#  ('annville', 3),
#  ("san luis obispo county sheriff's", 3),
#  ('𝐣𝐨𝐢𝐧', 3),
#  ('salinas', 3),
#  ('the city of madison', 3),
#  ('breckenridge', 3),
#  ...]

# %%
dataframe601=pd.DataFrame(dict_a)

# %%
len(dict_a)
# Out:
# 3063

# %%
dataframe601.to_csv('dataframe0601.csv')
