# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 4.4 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==2.2.5) (2.2.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.8.2)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en-core-web-lg==2.2.5) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en-core-web-lg==2.2.5) (3.0.4)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=712b054ac995f3ab1777219609bd3357d7a12713e01421cf15224b3ee7183341
#   Stored in directory: /root/.cache/pip/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5

# %%
# !pip install bert-tensorflow
# Out:
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4

# %%
#%cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ln -s /content/gdrive/MyDrive/ /mydrive
# !ls /mydrive
# Out:
# ln: failed to create symbolic link '/mydrive/MyDrive': File exists
# '2020 slides'
#  2021-online-language-offline-impact-main
#  An_Xception_Based_Convolutional_Neural_Network_for_Scene_Image_Classification_with_Transfer_Learning.pdf
# 'API key'
# 'Application for Lease- Form for Email (Applicant) (1).gdoc'
# 'Application for Lease- Form for Email (Applicant).gdoc'
# 'Application for Lease- Form for Email (Applicant).pdf'
# 'Colab Notebooks'
# 'CV -Xizhi Wu.pdf'
# 'FOW Documents'
#  MyDrive
# 'NT15 LEASE 2021.gdoc'
# 'NT15 LEASE 2021.pdf'
# 'Review Group 9.gdoc'
#  Xizhi_Wu_UnderGrad_Transcript.pdf
#  教授资格证身份证.pdf

# %%
# %cd gdrive/MyDrive/2021-online-language-offline-impact-main
# Out:
# /content/gdrive/MyDrive/2021-online-language-offline-impact-main

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_EU
#  a0529-a0611_US     dataframe_csv_UK
#  a0529.csv	    dataframe_result_529_UK.csv
#  a0530.csv	    dataframe_result_530_UK.csv
#  a0601.csv	    dataframe_result_531_UK.csv
#  a0602.csv	    dataframe_result_csv
#  a0603.csv	    dataframe_result_csv_EU
#  a0604.csv	    dataframe_result_csv_UK
#  a0605.csv	    Github
#  a0606.csv	    heatmap529_UK.ipynb
#  a0607.csv	    heatmap530.ipynb
#  a0608.csv	    Heat_Map_Online_language.ipynb
#  a0610.csv	    __MACOSX
#  a0611.csv	    mapping_UK
#  a0612.csv	    mapping_US
#  a0613.csv	    non_violant1.csv
#  a0614.csv	    non_violant2.csv
#  ccc_compiled.csv   UK
#  csv		    violant.csv
#  csv.zip	   '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_csv

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_path_601 = 'csv/US06_12.csv'

# %%
ct = pd.read_csv(ct_path_601)

# %%
ct.shape[1]
# Out:
# 47

# %%
columns1=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message','expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media_type', 'media_numl', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']
columns2=['platformId', 'platform', 'date', 'updated', 'type1', 'title', 'caption', 'description', 'message', 'expandedLinks', 'link', 'postUrl', 'subscriberCount', 'score', 'media', 'actual_likeCount', 'actual_shareCount', 'actual_commentCount', 'actual_loveCount', 'actual_wowCount', 'actual_hahaCount', 'actual_sadCount', 'actual_angryCount', 'actual_thankfulCount', 'actual_careCount', 'expected_likeCount', 'expected_shareCount', 'expected_commentCount', 'expected_loveCount', 'expected_wowCount', 'expected_hahaCount', 'expected_sadCount', 'expected_angryCount', 'expected_thankfulCount', 'expected_careCount', 'account_id', 'account_name', 'account_handle', 'account_profileImage', 'account_accountType', 'account_pageAdminTopCountry', 'account_pageDescription', 'account_verified', 'account_pageCreatedDate', 'languageCode', 'legacyId', 'post_id']

# %%
#len(columns1)
len(columns2)
# Out:
# 47

# %%
ct.columns=columns2

# %%
ct
# Out:
#                              platformId  ...                    post_id
# 0     1791654857736614_2699985123570245  ...   8096587|2699985123570245
# 1     1481073582140028_2787886488125391  ...     68123|2787886488125391
# 2     2457084541029255_3911218202282541  ...   5775977|3911218202282541
# 3      104914626218275_3165074630202244  ...   1821675|3165074630202244
# 4      481275305234454_3775044389190846  ...   5799320|3775044389190846
# ...                                 ...  ...                        ...
# 6238   341833139168802_3359091014109651  ...     69527|3359091014109651
# 6239   674764996035495_1534516946726958  ...   1534289|1534516946726958
# 6240      28807649968_10151403362734969  ...  9868876|10151403362734969
# 6241   889555808073667_1168735133489065  ...  11386916|1168735133489065
# 6242    391196808388510_679376802903841  ...   13099713|679376802903841
#
# [6243 rows x 47 columns]

# %%
ct['message'] = ct['message'].fillna('')
ct['description'] = ct['description'].fillna('')
ct['title'] = ct['title'].fillna('')

# %%
nlp = spacy.load('en_core_web_lg', disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
def ner(txt):
    ner = dict()

    doc = nlp(txt)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_inline(doc):
    ner = dict()

    for ent in doc.ents:
        if ent.label_ == 'GPE':
            if ent.text not in ner:
                ner[ent.text] = 1
            else:
                ner[ent.text] += 1
    return ner

# %%
def ner_pipe(texts):
    batch = []
    for doc in nlp.pipe(texts, batch_size=200, n_threads=16):
        batch.append(ner_inline(doc))
    return batch

# %%
ct['NER-msg'] = ner_pipe(ct['message'])

# %%
ct['NER-msg'] = ct['message'].apply(ner)

# %%
ct['NER-desc'] = ct['description'].apply(ner)

# %%
ct['NER-title'] = ct['title'].apply(ner)

# %%
ct[['NER-msg', 'NER-desc']].head()
# Out:
#             NER-msg            NER-desc
# 0                {}                  {}
# 1                {}  {'Minneapolis': 1}
# 2  {'Minnesota': 1}  {'Minneapolis': 1}
# 3                {}  {'Minneapolis': 1}
# 4                {}  {'Minneapolis': 1}

# %%
ct.to_csv('a0612.csv')

# %%
ct=pd.read_csv('a0612.csv')

# %%
# !ls
# Out:
#  a0529-a0611_UK     dataframe_csv_EU
#  a0529-a0611_US     dataframe_csv_UK
#  a0529.csv	    dataframe_result_529_UK.csv
#  a0530.csv	    dataframe_result_530_UK.csv
#  a0601.csv	    dataframe_result_531_UK.csv
#  a0602.csv	    dataframe_result_csv
#  a0603.csv	    dataframe_result_csv_EU
#  a0604.csv	    dataframe_result_csv_UK
#  a0605.csv	    Github
#  a0606.csv	    heatmap529_UK.ipynb
#  a0607.csv	    heatmap530.ipynb
#  a0608.csv	    Heat_Map_Online_language.ipynb
#  a0610.csv	    __MACOSX
#  a0611.csv	    mapping_UK
#  a0612.csv	    mapping_US
#  a0613.csv	    non_violant1.csv
#  a0614.csv	    non_violant2.csv
#  ccc_compiled.csv   UK
#  csv		    violant.csv
#  csv.zip	   '新建 Microsoft PowerPoint 演示文稿.pptx'
#  dataframe_csv

# %%
###
#ct=pd.read_csv('a0601.csv')

# %%
ct
# Out:
#       Unnamed: 0  ...                     NER-title
# 0              0  ...                            {}
# 1              1  ...                            {}
# 2              2  ...                            {}
# 3              3  ...                            {}
# 4              4  ...                            {}
# ...          ...  ...                           ...
# 6238        6238  ...                            {}
# 6239        6239  ...                            {}
# 6240        6240  ...                    {'NYC': 1}
# 6241        6241  ...                    {'NYC': 1}
# 6242        6242  ...  {'D.C.': 1, 'Washington': 1}
#
# [6243 rows x 51 columns]

# %%
ct['NER-msg'] = ct['NER-msg'].apply(ast.literal_eval)
ct['NER-desc'] = ct['NER-desc'].apply(ast.literal_eval)
ct['NER-title'] = ct['NER-title'].apply(ast.literal_eval)

# %%
#ct_ner = ct[((ct['NER-msg'] != {}) | (ct['NER-desc'] != {}) | (ct['NER-title'] != {}))]

# %%
###
ct_ner = ct

# %%
ct_ner[['NER-msg', 'NER-desc', 'NER-title']].head()
# Out:
#             NER-msg            NER-desc NER-title
# 0                {}                  {}        {}
# 1                {}  {'Minneapolis': 1}        {}
# 2  {'Minnesota': 1}  {'Minneapolis': 1}        {}
# 3                {}  {'Minneapolis': 1}        {}
# 4                {}  {'Minneapolis': 1}        {}

# %%
ct_ner['NER-msg'] = ct_ner['NER-msg'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-desc'] = ct_ner['NER-desc'].apply(lambda x: list(set(x.keys())))
ct_ner['NER-title'] = ct_ner['NER-title'].apply(lambda x: list(set(x.keys())))

# %%
ct_ner['NER-msg']
# Out:
# 0                                          []
# 1                                          []
# 2                                 [Minnesota]
# 3                                          []
# 4                                          []
#                         ...
# 6238                                       []
# 6239                                       []
# 6240                                       []
# 6241    [Zelle, Socorro, Bayonne, St. Joseph]
# 6242                                       []
# Name: NER-msg, Length: 6243, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER-msg'] + ct_ner['NER-desc'] + ct_ner['NER-title']

# %%
ct_ner['NER']
# Out:
# 0                                               []
# 1                                    [Minneapolis]
# 2                         [Minnesota, Minneapolis]
# 3                                    [Minneapolis]
# 4                                    [Minneapolis]
#                            ...
# 6238                                            []
# 6239                                            []
# 6240                                         [NYC]
# 6241    [Zelle, Socorro, Bayonne, St. Joseph, NYC]
# 6242                            [Washington, D.C.]
# Name: NER, Length: 6243, dtype: object

# %%
ct_ner['NER'] = ct_ner['NER'].apply(set)
ct_ner['NER'] = ct_ner['NER'].apply(list)

# %%
ct_ner['NER'] = ct_ner['NER'].apply(lambda x: [s.lower() for s in x])

# %%
ct_ner
# Out:
#       Unnamed: 0  ...                                         NER
# 0              0  ...                                          []
# 1              1  ...                               [minneapolis]
# 2              2  ...                    [minnesota, minneapolis]
# 3              3  ...                               [minneapolis]
# 4              4  ...                               [minneapolis]
# ...          ...  ...                                         ...
# 6238        6238  ...                                          []
# 6239        6239  ...                                          []
# 6240        6240  ...                                       [nyc]
# 6241        6241  ...  [zelle, socorro, st. joseph, nyc, bayonne]
# 6242        6242  ...                          [washington, d.c.]
#
# [6243 rows x 52 columns]

# %%
ct_ner['NER-1']=ct_ner['NER']

# %%
ct_ner['NER-1'][0]
# Out:
# []

# %%
import os
import collections
import ast
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
import spacy
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
#from bert import tokenization
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# %%
ct_ner[:100]
# Out:
#     Unnamed: 0  ...                                              NER-1
# 0            0  ...                                                 []
# 1            1  ...                                      [minneapolis]
# 2            2  ...                           [minnesota, minneapolis]
# 3            3  ...                                      [minneapolis]
# 4            4  ...                                      [minneapolis]
# ..         ...  ...                                                ...
# 95          95  ...                       [minneapolis, orange county]
# 96          96  ...                        [california, new york city]
# 97          97  ...  [providence, the state of rhode island, r.i., ...
# 98          98  ...                                      [minneapolis]
# 99          99  ...                                                 []
#
# [100 rows x 53 columns]

# %%
# %cd mapping_US
# Out:
# /content/gdrive/My Drive/2021-online-language-offline-impact-main/mapping_US

# %%
# !ls
# Out:
#  Country.txt			 dataframe0610_post_remove.csv
#  dataframe0529_post.csv		 dataframe0611_post.csv
#  dataframe0529_post_remove.csv	 dataframe0611_post_remove.csv
#  dataframe0530_post.csv		 dataframe_mapping
#  dataframe0530_post_remove.csv	 dataframe_mapping_0529.csv
#  dataframe0531_post.csv		 dataframe_mapping_0530.csv
#  dataframe0531_post_remove.csv	 dataframe_mapping_0531.csv
#  dataframe0601_post.csv		 dataframe_mapping_0601.csv
#  dataframe0601_post_remove.csv	 dataframe_mapping_0602.csv
#  dataframe0602_post.csv		 dataframe_mapping_0603.csv
#  dataframe0602_post_remove.csv	 dataframe_mapping_0604.csv
#  dataframe0603_post.csv		 dataframe_mapping_0605.csv
#  dataframe0603_post_remove.csv	 dataframe_mapping_0606.csv
#  dataframe0604_post.csv		 dataframe_mapping_0607.csv
#  dataframe0604_post_remove.csv	 dataframe_mapping_0608.csv
#  dataframe0605_post.csv		 dataframe_mapping_0609.csv
#  dataframe0605_post_remove.csv	 dataframe_mapping_0610.csv
#  dataframe0606_post.csv		 dataframe_mapping_0611.csv
#  dataframe0606_post_remove.csv	 dataframe_mapping_0612.csv
#  dataframe0607_post.csv		 dataframe_mapping_0613.csv
#  dataframe0607_post_remove.csv	 dataframe_mapping_0614.csv
#  dataframe0608_post.csv		 datarframe_post
#  dataframe0608_post_remove.csv	'mapping_US_Cities_Only(1).zip'
#  dataframe0609_post.csv		 mapping_US_Cities_Only.zip
#  dataframe0609_post_remove.csv	 post_specific_mapping_US.zip
#  dataframe0610_post.csv		 states.csv

# %%
ct_mapping=pd.read_csv('dataframe_mapping_0612.csv',encoding='ISO-8859-1')

# %%
ct_mapping
# Out:
#       Unnamed: 0               City  ...   Latitude  Longtitude
# 0              0        minneapolis  ...  44.977300  -93.265469
# 1              1            america  ...  51.437148    5.979900
# 2              2          minnesota  ...  45.989659  -94.611329
# 3              3               u.s.  ...  48.630579    9.417545
# 4              4  the united states  ...  29.633008  -97.988594
# ...          ...                ...  ...        ...         ...
# 1371        1371         black amer  ...        NaN         NaN
# 1372        1372              zelle  ...  52.178548   13.215199
# 1373        1373            socorro  ...  34.057286 -106.893080
# 1374        1374         st. joseph  ...  39.768605  -94.846632
# 1375        1375            bayonne  ...  43.493338   -1.475099
#
# [1376 rows x 6 columns]

# %%
country_list=pd.read_csv('Country.txt')
country_list['Name']=country_list['Name'].str.lower()

# %%
country_list['Name']
# Out:
# 0            afghanistan
# 1          �land islands
# 2                albania
# 3                algeria
# 4         american samoa
#              ...
# 250                   us
# 251    the united states
# 252              america
# 253                  u.s
# 254        united states
# Name: Name, Length: 255, dtype: object

# %%
states_list=pd.read_csv('states.csv')
states_list['State']
# Out:
# 0                             Alabama, United States
# 1                              Alaska, United States
# 2                             Arizona, United States
# 3                            Arkansas, United States
# 4                          California, United States
#                            ...
# 165         Armagh, Northern Ireland, United Kingdom
# 166           Down, Northern Ireland, United Kingdom
# 167      Fermanagh, Northern Ireland, United Kingdom
# 168    Londonderry, Northern Ireland, United Kingdom
# 169         Tyrone, Northern Ireland, United Kingdom
# Name: State, Length: 170, dtype: object

# %%
from numpy.core.numeric import NaN
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['City'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(states_list['State'])):
    if ct_mapping['Mapping'][i]==states_list['State'][k]:
      ct_mapping['Mapping'][i]=NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for i in range(len(ct_mapping['City'])):
  for k in range(len(country_list['Name'])):
    if ct_mapping['Mapping'][i]==country_list['Name'][k]:
      ct_mapping['Mapping'][i]=NaN

# %%
pd.set_option('display.max_rows', None)

# %%
ct_mapping
# Out:
#       Unnamed: 0  ...  Longtitude
# 0              0  ...  -93.265469
# 1              1  ...    5.979900
# 2              2  ...  -94.611329
# 3              3  ...    9.417545
# 4              4  ...  -97.988594
# 5              5  ... -100.445882
# 6              6  ...  -74.006015
# 7              7  ...  -77.036543
# 8              8  ... -122.330062
# 9              9  ...  -99.683001
# 10            10  ...  -95.367697
# 11            11  ...  -82.688140
# 12            12  ... -118.755997
# 13            13  ...  -87.624421
# 14            14  ...  -75.163526
# 15            15  ... -104.984862
# 16            16  ...  -85.759407
# 17            17  ...    4.666714
# 18            18  ...  -74.006015
# 19            19  ... -118.242766
# 20            20  ...  -96.796856
# 21            21  ...  -83.113737
# 22            22  ...  -79.990086
# 23            23  ...  -81.463983
# 24            24  ...  -71.058291
# 25            25  ...   11.045785
# 26            26  ...  -84.390264
# 27            27  ...  -89.433729
# 28            28  ...  -74.404162
# 29            29  ...  -77.036543
# 30            30  ...  -78.492772
# 31            31  ...  -93.312270
# 32            32  ...  -95.992911
# 33            33  ... -122.419906
# 34            34  ... -122.271356
# 35            35  ...  -89.688464
# 36            36  ... -122.674195
# 37            37  ...  -87.922497
# 38            38  ...  -79.039292
# 39            39  ...         NaN
# 40            40  ...  -83.000706
# 41            41  ...  -97.268406
# 42            42  ...  -77.434280
# 43            43  ...   -3.276575
# 44            44  ...  -94.611329
# 45            45  ... -118.755997
# 46            46  ...  -77.036543
# 47            47  ...  -86.829534
# 48            48  ...  -80.843083
# 49            49  ...  -74.006015
# 50            50  ...  172.834408
# 51            51  ... -115.148516
# 52            52  ...   19.999962
# 53            53  ...  -80.193620
# 54            54  ...  -93.093103
# 55            55  ...  -73.959894
# 56            56  ...    1.888333
# 57            57  ...  -80.436374
# 58            58  ... -105.607716
# 59            59  ...  -77.727883
# 60            60  ...  -76.610759
# 61            61  ...  -78.878392
# 62            62  ...  -85.155141
# 63            63  ... -122.439875
# 64            64  ...  -79.039292
# 65            65  ... -117.162773
# 66            66  ...  -81.379030
# 67            67  ...  -83.892523
# 68            68  ...  -83.046640
# 69            69  ...  -76.938207
# 70            70  ...   -1.264906
# 71            71  ...  -78.492772
# 72            72  ... -111.714358
# 73            73  ...  -86.282008
# 74            74  ...  -84.682435
# 75            75  ...  -81.693445
# 76            76  ...  -77.036543
# 77            77  ...  -97.332746
# 78            78  ... -111.763275
# 79            79  ...  -84.063269
# 80            80  ... -118.329523
# 81            81  ...  -73.949721
# 82            82  ...         NaN
# 83            83  ...  -97.105624
# 84            84  ...   -1.902691
# 85            85  ...    2.320041
# 86            86  ...  -94.611329
# 87            87  ...         NaN
# 88            88  ...  -90.051629
# 89            89  ... -121.493895
# 90            90  ...  -89.433729
# 91            91  ...  -93.604665
# 92            92  ...   13.388860
# 93            93  ...    4.351697
# 94            94  ...  -75.844995
# 95            95  ...  -85.155141
# 96            96  ...  -72.032366
# 97            97  ...  -74.404162
# 98            98  ...   -0.127647
# 99            99  ...  -75.844995
# 100          100  ...  -89.734850
# 101          101  ...  -75.401331
# 102          102  ...         NaN
# 103          103  ... -118.191604
# 104          104  ...  -90.370584
# 105          105  ... -100.445882
# 106          106  ...   10.423447
# 107          107  ...  -86.774298
# 108          108  ...  104.999927
# 109          109  ...  -90.184769
# 110          110  ...  -71.599237
# 111          111  ...  -90.199585
# 112          112  ...  -73.878594
# 113          113  ... -120.737257
# 114          114  ...  -90.078213
# 115          115  ... -112.074142
# 116          116  ...  -84.280933
# 117          117  ... -106.464634
# 118          118  ...  -53.200000
# 119          119  ... -102.267516
# 120          120  ...  -93.486505
# 121          121  ...  -72.734216
# 122          122  ...  -80.449417
# 123          123  ...  -76.648348
# 124          124  ...  -92.561787
# 125          125  ...  -96.779007
# 126          126  ...  -81.176486
# 127          127  ...  -94.578142
# 128          128  ...   24.991639
# 129          129  ...   36.941628
# 130          130  ...  -81.463983
# 131          131  ...   10.992412
# 132          132  ... -105.993007
# 133          133  ... -100.445882
# 134          134  ...  -97.743700
# 135          135  ...  -72.734216
# 136          136  ...  -92.447911
# 137          137  ... -118.242766
# 138          138  ... -116.853723
# 139          139  ...  -89.267641
# 140          140  ...  -72.500261
# 141          141  ...   97.745306
# 142          142  ...  -86.534288
# 143          143  ... -122.706977
# 144          144  ...   -1.869210
# 145          145  ...  -86.300648
# 146          146  ...  -84.512460
# 147          147  ...  -91.187380
# 148          148  ... -120.212613
# 149          149  ...  -76.345206
# 150          150  ... -106.650985
# 151          151  ...  -74.742946
# 152          152  ...   29.894378
# 153          153  ...  -89.383761
# 154          154  ...  -75.977418
# 155          155  ...   -6.131967
# 156          156  ...   23.728305
# 157          157  ...  134.755000
# 158          158  ... -107.991707
# 159          159  ...  -75.119891
# 160          160  ...  -75.844995
# 161          161  ...  -87.216915
# 162          162  ...  -80.143379
# 163          163  ...  -75.546589
# 164          164  ...   -1.257850
# 165          165  ...  -86.282008
# 166          166  ...  -89.643957
# 167          167  ...  139.239418
# 168          168  ...  -79.940273
# 169          169  ...  -94.157433
# 170          170  ...  121.140422
# 171          171  ...  121.140422
# 172          172  ...  -94.846426
# 173          173  ...  -91.670405
# 174          174  ...  174.763180
# 175          175  ...  -80.085269
# 176          176  ... -122.348527
# 177          177  ... -117.870493
# 178          178  ...  -71.412834
# 179          179  ...  -82.458444
# 180          180  ...   -7.979460
# 181          181  ...   21.987713
# 182          182  ...    4.893604
# 183          183  ...   10.333328
# 184          184  ...  -87.674740
# 185          185  ...   -2.135839
# 186          186  ...   -4.837979
# 187          187  ...  -85.155141
# 188          188  ...  -87.789743
# 189          189  ... -100.217897
# 190          190  ...  -92.447911
# 191          191  ... -100.348761
# 192          192  ... -118.209681
# 193          193  ...   34.866765
# 194          194  ...         NaN
# 195          195  ... -104.987964
# 196          196  ...    9.417545
# 197          197  ...  -78.476678
# 198          198  ... -110.974848
# 199          199  ...  -88.007927
# 200          200  ... -118.485635
# 201          201  ...  -97.268406
# 202          202  ...  -72.690855
# 203          203  ...    2.177432
# 204          204  ...   -3.703582
# 205          205  ...   12.570072
# 206          206  ...   -6.260273
# 207          207  ... -104.825349
# 208          208  ...  -77.615214
# 209          209  ...  -73.043836
# 210          210  ...  -92.125122
# 211          211  ...  -78.492772
# 212          212  ...   -2.245115
# 213          213  ...  -71.316172
# 214          214  ...   -0.201238
# 215          215  ...   -1.080027
# 216          216  ...   66.238514
# 217          217  ...   44.174978
# 218          218  ...  -93.272139
# 219          219  ...  -93.044911
# 220          220  ...  -91.374322
# 221          221  ...  -80.241196
# 222          222  ... -149.680909
# 223          223  ...  -66.261522
# 224          224  ...   34.262717
# 225          225  ...  -89.629824
# 226          226  ...  -75.172039
# 227          227  ...  -72.612035
# 228          228  ...   36.714575
# 229          229  ...   19.134422
# 230          230  ...  -97.988594
# 231          231  ... -116.356044
# 232          232  ...  -95.864051
# 233          233  ...   11.689970
# 234          234  ...   34.924965
# 235          235  ...  -81.655651
# 236          236  ...  -71.599237
# 237          237  ...  -86.829534
# 238          238  ...  -86.158350
# 239          239  ...  -95.938376
# 240          240  ...  -80.436374
# 241          241  ...  -97.005825
# 242          242  ...  -96.247134
# 243          243  ...  -82.398488
# 244          244  ...   -0.169439
# 245          245  ...         NaN
# 246          246  ...  114.162813
# 247          247  ... -106.325138
# 248          248  ...  -79.039292
# 249          249  ...   -2.597298
# 250          250  ...  -90.179248
# 251          251  ...  -81.463983
# 252          252  ...  -84.191607
# 253          253  ... -119.019464
# 254          254  ...  -94.130165
# 255          255  ... -118.242766
# 256          256  ...  -82.889224
# 257          257  ...  139.718491
# 258          258  ...  -84.850737
# 259          259  ...  -27.223876
# 260          260  ...         NaN
# 261          261  ...         NaN
# 262          262  ...  -73.771287
# 263          263  ...         NaN
# 264          264  ...         NaN
# 265          265  ...  -61.883254
# 266          266  ...  -84.365168
# 267          267  ...         NaN
# 268          268  ...  -75.119891
# 269          269  ...   -3.474926
# 270          270  ...  -77.036543
# 271          271  ... -122.714105
# 272          272  ...  -68.859020
# 273          273  ...  -77.044114
# 274          274  ...  -81.022833
# 275          275  ...  -94.794588
# 276          276  ...  -94.611329
# 277          277  ...   18.277262
# 278          278  ...  139.922450
# 279          279  ... -106.650985
# 280          280  ...  -85.608316
# 281          281  ... -114.338285
# 282          282  ...         NaN
# 283          283  ...   46.717408
# 284          284  ...  -97.317910
# 285          285  ...         NaN
# 286          286  ...  -62.874624
# 287          287  ...  -92.007126
# 288          288  ...  -99.133178
# 289          289  ...   39.049411
# 290          290  ...  -75.004920
# 291          291  ... -112.491230
# 292          292  ...   78.667743
# 293          293  ... -118.491227
# 294          294  ...  -77.963960
# 295          295  ...  -77.341883
# 296          296  ... -105.110058
# 297          297  ...  -73.845312
# 298          298  ...  -99.683001
# 299          299  ... -108.550732
# 300          300  ...  -71.313771
# 301          301  ...  -95.286430
# 302          302  ...   38.431397
# 303          303  ...  151.216454
# 304          304  ...         NaN
# 305          305  ... -119.812658
# 306          306  ...  -73.469287
# 307          307  ... -111.940009
# 308          308  ...  -85.667864
# 309          309  ... -100.246720
# 310          310  ...   -1.918023
# 311          311  ... -106.319478
# 312          312  ...  -89.688464
# 313          313  ...  -81.818919
# 314          314  ... -120.737257
# 315          315  ... -122.828587
# 316          316  ...   12.482932
# 317          317  ...  108.426511
# 318          318  ...  -97.517054
# 319          319  ...  -97.390121
# 320          320  ...    2.420739
# 321          321  ...  151.210047
# 322          322  ...  -77.786572
# 323          323  ... -116.200886
# 324          324  ... -114.015407
# 325          325  ...         NaN
# 326          326  ...  -85.976667
# 327          327  ...   73.738398
# 328          328  ...  -78.705914
# 329          329  ...   -8.593516
# 330          330  ... -102.010377
# 331          331  ...  -74.118249
# 332          332  ...  -72.908813
# 333          333  ... -123.033121
# 334          334  ...   -0.169439
# 335          335  ... -112.036277
# 336          336  ... -122.427866
# 337          337  ...  -93.287788
# 338          338  ...  -93.765194
# 339          339  ...  -80.840842
# 340          340  ...   -1.075614
# 341          341  ...  120.612966
# 342          342  ...  -74.047455
# 343          343  ...  -88.247364
# 344          344  ...  -52.715149
# 345          345  ...   84.091714
# 346          346  ...    9.400138
# 347          347  ... -117.423511
# 348          348  ...  -93.198107
# 349          349  ... -116.037247
# 350          350  ...  -82.889096
# 351          351  ...  -97.683921
# 352          352  ...  -74.404162
# 353          353  ...  -93.256375
# 354          354  ...  -75.750997
# 355          355  ...   -3.738930
# 356          356  ...  -93.740504
# 357          357  ...  -80.840842
# 358          358  ... -117.792610
# 359          359  ...  -72.500261
# 360          360  ...  -76.537764
# 361          361  ...  -83.380444
# 362          362  ...  -95.374125
# 363          363  ...  -85.309488
# 364          364  ... -112.124655
# 365          365  ...  -73.407897
# 366          366  ...  -72.621371
# 367          367  ...  -72.032366
# 368          368  ...  -81.872308
# 369          369  ...  -71.010051
# 370          370  ...  -66.110932
# 371          371  ...   29.267547
# 372          372  ... -120.905723
# 373          373  ...  -94.344488
# 374          374  ...   13.413637
# 375          375  ...  -82.161424
# 376          376  ...  100.832730
# 377          377  ...         NaN
# 378          378  ... -116.495298
# 379          379  ...   12.674297
# 380          380  ...  -84.421311
# 381          381  ...   18.417396
# 382          382  ...  -75.156397
# 383          383  ... -111.237757
# 384          384  ...   10.423447
# 385          385  ...  -88.094935
# 386          386  ...         NaN
# 387          387  ...   47.787251
# 388          388  ...   -0.126540
# 389          389  ...   71.247499
# 390          390  ...  -92.352621
# 391          391  ...   54.564352
# 392          392  ...  -74.431408
# 393          393  ...  -98.495141
# 394          394  ... -106.097247
# 395          395  ... -121.890583
# 396          396  ... -122.840114
# 397          397  ...  104.999927
# 398          398  ...  -72.925052
# 399          399  ...  -80.498947
# 400          400  ...   -1.688031
# 401          401  ...  -92.289627
# 402          402  ...   -4.023957
# 403          403  ... -106.761307
# 404          404  ... -106.850392
# 405          405  ...  -74.879361
# 406          406  ...         NaN
# 407          407  ...  -77.659862
# 408          408  ...  -87.676387
# 409          409  ...  -97.388776
# 410          410  ...  151.210047
# 411          411  ...    6.095467
# 412          412  ...  -98.725884
# 413          413  ... -123.095051
# 414          414  ...  -87.772847
# 415          415  ...  -80.053294
# 416          416  ...   -0.131255
# 417          417  ...  -85.227733
# 418          418  ...         NaN
# 419          419  ...  -89.940719
# 420          420  ... -117.690075
# 421          421  ...  -82.445154
# 422          422  ...         NaN
# 423          423  ...  -82.574819
# 424          424  ...   35.225763
# 425          425  ... -121.978835
# 426          426  ...  -86.250007
# 427          427  ...   10.523607
# 428          428  ...  -84.573201
# 429          429  ...  -80.843083
# 430          430  ...  -63.048307
# 431          431  ...  -81.622507
# 432          432  ...  -71.801888
# 433          433  ...  -90.680259
# 434          434  ...         NaN
# 435          435  ...   12.002398
# 436          436  ...  -98.230082
# 437          437  ...  -98.216445
# 438          438  ... -117.291156
# 439          439  ... -113.995267
# 440          440  ...         NaN
# 441          441  ...   29.491769
# 442          442  ...  -77.231787
# 443          443  ... -103.227448
# 444          444  ...  -73.968085
# 445          445  ...  -81.690556
# 446          446  ...  122.731210
# 447          447  ...         NaN
# 448          448  ... -122.312918
# 449          449  ...  -84.555380
# 450          450  ...  -88.217052
# 451          451  ...  -80.371000
# 452          452  ...  -72.835420
# 453          453  ...   -3.188375
# 454          454  ...  -76.973794
# 455          455  ...  -90.575003
# 456          456  ...   -2.718901
# 457          457  ...    8.411977
# 458          458  ...  -53.542724
# 459          459  ...  -53.510267
# 460          460  ...  -77.066644
# 461          461  ...  -77.035951
# 462          462  ...  -77.036543
# 463          463  ...  -82.669508
# 464          464  ...  144.977682
# 465          465  ...  -88.531715
# 466          466  ...  -74.975711
# 467          467  ...  -86.392110
# 468          468  ...  -80.843083
# 469          469  ...  -72.500261
# 470          470  ...  -73.212906
# 471          471  ...  121.100360
# 472          472  ...         NaN
# 473          473  ...  -96.890282
# 474          474  ...   -1.055909
# 475          475  ...  -76.938207
# 476          476  ...  -87.840603
# 477          477  ...  -88.314754
# 478          478  ...    7.314956
# 479          479  ...  -87.848085
# 480          480  ...   -1.795413
# 481          481  ... -118.176742
# 482          482  ...  -93.210589
# 483          483  ...  -81.478898
# 484          484  ...  -89.250479
# 485          485  ...   26.550098
# 486          486  ...  -59.525031
# 487          487  ...  -97.988594
# 488          488  ...  -87.982297
# 489          489  ...   11.223458
# 490          490  ...    7.249473
# 491          491  ...  100.532730
# 492          492  ...  -87.833269
# 493          493  ...  -87.649278
# 494          494  ... -119.795634
# 495          495  ...  -66.254565
# 496          496  ...  151.192128
# 497          497  ...   31.271832
# 498          498  ...  -80.062998
# 499          499  ...  -85.650553
# 500          500  ...         NaN
# 501          501  ...  -96.160237
# 502          502  ...         NaN
# 503          503  ...    5.387210
# 504          504  ...         NaN
# 505          505  ...  -73.882428
# 506          506  ... -122.201400
# 507          507  ...  114.299935
# 508          508  ...         NaN
# 509          509  ... -111.886798
# 510          510  ...   35.206188
# 511          511  ...   12.674297
# 512          512  ... -119.180382
# 513          513  ...  -79.955944
# 514          514  ...  -80.840842
# 515          515  ...  -92.813498
# 516          516  ...  -74.149605
# 517          517  ...  -74.172367
# 518          518  ...  -88.059999
# 519          519  ...  -89.688464
# 520          520  ...  -99.112683
# 521          521  ...  -71.066163
# 522          522  ...  -78.998728
# 523          523  ...  -77.672693
# 524          524  ...    0.899465
# 525          525  ...  -83.221873
# 526          526  ...  -85.315553
# 527          527  ...  -96.789821
# 528          528  ...  -76.305669
# 529          529  ... -118.977322
# 530          530  ... -111.957708
# 531          531  ...  -80.072820
# 532          532  ...  -71.319290
# 533          533  ...  -90.832082
# 534          534  ... -102.135330
# 535          535  ...  -81.987349
# 536          536  ... -122.239634
# 537          537  ...         NaN
# 538          538  ... -123.117362
# 539          539  ...  -78.864042
# 540          540  ...    4.399708
# 541          541  ...  -80.832875
# 542          542  ...  -88.094935
# 543          543  ... -118.262509
# 544          544  ...   18.123672
# 545          545  ...    0.461789
# 546          546  ...  -99.747343
# 547          547  ...  -81.130843
# 548          548  ... -118.448135
# 549          549  ... -118.437869
# 550          550  ... -118.499820
# 551          551  ...  -90.584168
# 552          552  ...         NaN
# 553          553  ... -118.561271
# 554          554  ...   22.052782
# 555          555  ...  -55.910589
# 556          556  ... -118.242766
# 557          557  ... -117.596352
# 558          558  ...  -72.032366
# 559          559  ...  -95.677556
# 560          560  ... -100.440509
# 561          561  ...  -81.376774
# 562          562  ...  -70.494468
# 563          563  ...  -71.036166
# 564          564  ...   -9.585438
# 565          565  ...  -80.052129
# 566          566  ... -108.565996
# 567          567  ...  -84.810504
# 568          568  ...  -77.394769
# 569          569  ...  -72.453884
# 570          570  ...  -80.244052
# 571          571  ...  -88.043054
# 572          572  ...  -58.515028
# 573          573  ...         NaN
# 574          574  ... -105.472691
# 575          575  ... -105.756164
# 576          576  ...  -97.082849
# 577          577  ...   -3.276575
# 578          578  ...   -4.114052
# 579          579  ...  -95.552282
# 580          580  ...  -76.886112
# 581          581  ...   34.781806
# 582          582  ...  -76.411419
# 583          583  ...   34.846724
# 584          584  ...  131.018371
# 585          585  ...         NaN
# 586          586  ...  -97.749512
# 587          587  ...  -87.782524
# 588          588  ...  -90.616841
# 589          589  ...  -76.607917
# 590          590  ...  -96.968958
# 591          591  ...         NaN
# 592          592  ...         NaN
# 593          593  ...  121.026932
# 594          594  ...   39.826869
# 595          595  ...   -9.365852
# 596          596  ... -121.684635
# 597          597  ...  -75.401331
# 598          598  ...  -85.138602
# 599          599  ...  -87.020747
# 600          600  ...  -79.926240
# 601          601  ...  -74.988225
# 602          602  ...    0.198693
# 603          603  ...    3.169028
# 604          604  ...    7.206390
# 605          605  ...    6.094377
# 606          606  ...    5.747746
# 607          607  ...   -0.234834
# 608          608  ...         NaN
# 609          609  ...         NaN
# 610          610  ...         NaN
# 611          611  ...   -0.007059
# 612          612  ...         NaN
# 613          613  ...    5.387210
# 614          614  ...         NaN
# 615          615  ... -116.037247
# 616          616  ...         NaN
# 617          617  ...  -80.799719
# 618          618  ... -121.768053
# 619          619  ...    9.099971
# 620          620  ...  -79.039292
# 621          621  ...         NaN
# 622          622  ...   21.630538
# 623          623  ...         NaN
# 624          624  ... -119.784831
# 625          625  ... -117.176695
# 626          626  ...  -84.017690
# 627          627  ...  -86.459724
# 628          628  ... -122.777656
# 629          629  ...  -81.351026
# 630          630  ...  -73.219341
# 631          631  ...  -71.474693
# 632          632  ...   28.965165
# 633          633  ...         NaN
# 634          634  ...  -87.633102
# 635          635  ...  -71.398383
# 636          636  ...  -93.378341
# 637          637  ...   37.617494
# 638          638  ...   16.372504
# 639          639  ...  -73.665683
# 640          640  ...   49.083416
# 641          641  ...         NaN
# 642          642  ...  -72.667178
# 643          643  ...  132.910257
# 644          644  ...  -89.538421
# 645          645  ...  -85.759407
# 646          646  ...         NaN
# 647          647  ...  -80.143929
# 648          648  ...  -95.853308
# 649          649  ...  -71.085655
# 650          650  ... -118.248787
# 651          651  ...  -73.847829
# 652          652  ...  -71.296373
# 653          653  ...  -71.268947
# 654          654  ...   44.487797
# 655          655  ... -113.484951
# 656          656  ...   74.758023
# 657          657  ...         NaN
# 658          658  ...  -74.961978
# 659          659  ...         NaN
# 660          660  ...  -87.883673
# 661          661  ...  -88.058763
# 662          662  ...         NaN
# 663          663  ... -100.445882
# 664          664  ...  -79.996741
# 665          665  ...  -70.133616
# 666          666  ...  -73.993015
# 667          667  ...  -74.248480
# 668          668  ...  120.070268
# 669          669  ...   29.477011
# 670          670  ...         NaN
# 671          671  ...         NaN
# 672          672  ...  -49.061779
# 673          673  ...  151.345887
# 674          674  ... -118.353132
# 675          675  ...  -97.308600
# 676          676  ...  -97.388776
# 677          677  ...    8.904113
# 678          678  ... -147.669917
# 679          679  ...         NaN
# 680          680  ...  -89.738415
# 681          681  ...   -1.579648
# 682          682  ...  139.763005
# 683          683  ...         NaN
# 684          684  ...   -0.604096
# 685          685  ...  -85.744377
# 686          686  ...  -87.756525
# 687          687  ...  -87.693046
# 688          688  ...         NaN
# 689          689  ... -113.196639
# 690          690  ... -111.973843
# 691          691  ...  -82.572319
# 692          692  ...         NaN
# 693          693  ...  -84.285482
# 694          694  ...  -84.168827
# 695          695  ...   -0.131255
# 696          696  ...  -73.538734
# 697          697  ...         NaN
# 698          698  ...  -73.989898
# 699          699  ...         NaN
# 700          700  ...  -98.983102
# 701          701  ...  -79.941431
# 702          702  ...  -77.043182
# 703          703  ...  -90.303897
# 704          704  ...  -90.910455
# 705          705  ...         NaN
# 706          706  ... -118.242766
# 707          707  ...  -81.581111
# 708          708  ...    8.169460
# 709          709  ...  120.982018
# 710          710  ...  -90.674737
# 711          711  ...  -92.138770
# 712          712  ...  -75.232664
# 713          713  ...  120.883305
# 714          714  ...  -82.364011
# 715          715  ...  -72.666892
# 716          716  ... -103.353163
# 717          717  ...  -73.204835
# 718          718  ...  -87.806266
# 719          719  ... -117.192246
# 720          720  ...         NaN
# 721          721  ...   -2.784359
# 722          722  ...   -9.013548
# 723          723  ...  -80.135301
# 724          724  ...  -83.433157
# 725          725  ...         NaN
# 726          726  ...         NaN
# 727          727  ... -118.360370
# 728          728  ... -114.097039
# 729          729  ...  -87.733397
# 730          730  ...  -75.113465
# 731          731  ...  -96.845634
# 732          732  ...   -0.198283
# 733          733  ...  -82.966687
# 734          734  ...  -82.879136
# 735          735  ...   -0.230443
# 736          736  ...  -94.969401
# 737          737  ...  -89.250479
# 738          738  ...  -81.655651
# 739          739  ...   76.044418
# 740          740  ...    6.537702
# 741          741  ...   18.619444
# 742          742  ... -122.770452
# 743          743  ... -122.779038
# 744          744  ...  -94.170450
# 745          745  ... -120.212613
# 746          746  ...    7.447920
# 747          747  ...         NaN
# 748          748  ...         NaN
# 749          749  ... -118.226624
# 750          750  ...  -80.449417
# 751          751  ...  152.908847
# 752          752  ...  -71.067897
# 753          753  ...  -81.812912
# 754          754  ...  -81.668812
# 755          755  ...  138.728963
# 756          756  ...  -97.194370
# 757          757  ... -122.256637
# 758          758  ... -122.230950
# 759          759  ...   -4.727897
# 760          760  ...  172.636646
# 761          761  ...  -78.890041
# 762          762  ...  -83.632402
# 763          763  ...  -82.324985
# 764          764  ...  -87.556711
# 765          765  ... -118.202415
# 766          766  ...   -0.181979
# 767          767  ...  -87.529584
# 768          768  ...  -79.817981
# 769          769  ...  -86.052331
# 770          770  ...  153.461672
# 771          771  ...  -90.733326
# 772          772  ...         NaN
# 773          773  ...  -90.122655
# 774          774  ...  -92.332964
# 775          775  ...    1.336252
# 776          776  ...  -77.036543
# 777          777  ...  -89.478704
# 778          778  ...   -2.805778
# 779          779  ...  -96.976930
# 780          780  ...  -95.431885
# 781          781  ...  -73.782636
# 782          782  ...         NaN
# 783          783  ...  -79.658366
# 784          784  ...  -79.745884
# 785          785  ... -118.865045
# 786          786  ...    8.541042
# 787          787  ...  -82.335646
# 788          788  ...  101.448088
# 789          789  ...  -82.398488
# 790          790  ...  144.359496
# 791          791  ...  -76.497005
# 792          792  ...  -81.091177
# 793          793  ...  -89.553438
# 794          794  ...  -77.036526
# 795          795  ...  -73.789546
# 796          796  ...   14.446200
# 797          797  ...         NaN
# 798          798  ...  -91.603793
# 799          799  ...  -78.878392
# 800          800  ... -101.388495
# 801          801  ... -110.354945
# 802          802  ... -122.613786
# 803          803  ... -100.889704
# 804          804  ...   14.217167
# 805          805  ... -100.458920
# 806          806  ...  -88.074239
# 807          807  ...  -94.093848
# 808          808  ... -111.241833
# 809          809  ...  -88.445803
# 810          810  ...   -1.243409
# 811          811  ...  -72.721834
# 812          812  ...  -95.989395
# 813          813  ...  -92.964579
# 814          814  ...  -73.063399
# 815          815  ...  -89.774810
# 816          816  ...   -2.872472
# 817          817  ...  -92.688894
# 818          818  ...  -87.765573
# 819          819  ... -101.279976
# 820          820  ...  -80.837346
# 821          821  ...         NaN
# 822          822  ...   -1.706367
# 823          823  ...  -74.502344
# 824          824  ...   76.201220
# 825          825  ...  144.757551
# 826          826  ...  -60.955858
# 827          827  ...  -78.000055
# 828          828  ... -122.253413
# 829          829  ...  -92.414907
# 830          830  ...         NaN
# 831          831  ...   90.511927
# 832          832  ...   84.091714
# 833          833  ... -115.167207
# 834          834  ...         NaN
# 835          835  ...  -71.655399
# 836          836  ...  -60.010701
# 837          837  ...  -68.714564
# 838          838  ...  -87.882005
# 839          839  ...         NaN
# 840          840  ...  -76.614815
# 841          841  ... -124.086486
# 842          842  ...  104.999927
# 843          843  ...         NaN
# 844          844  ...  -85.198845
# 845          845  ...  -73.067367
# 846          846  ...  -87.666120
# 847          847  ...   76.174415
# 848          848  ...  -83.049644
# 849          849  ...  -73.739713
# 850          850  ...         NaN
# 851          851  ...   -2.589017
# 852          852  ...  -93.928872
# 853          853  ...  -95.388563
# 854          854  ...  -97.078875
# 855          855  ...  -96.944218
# 856          856  ... -122.647442
# 857          857  ... -122.647442
# 858          858  ...  -97.371465
# 859          859  ...  -64.241850
# 860          860  ...  -76.851869
# 861          861  ...  -89.433729
# 862          862  ...  168.390180
# 863          863  ...  -92.943822
# 864          864  ...         NaN
# 865          865  ...  -88.328149
# 866          866  ...         NaN
# 867          867  ...  -88.542423
# 868          868  ...  -87.860637
# 869          869  ...  -87.723959
# 870          870  ...  -87.666716
# 871          871  ...  -91.257501
# 872          872  ...  -87.821226
# 873          873  ...  -87.503152
# 874          874  ...  -83.653772
# 875          875  ...  -89.085946
# 876          876  ...  -89.022679
# 877          877  ...  -88.404069
# 878          878  ...  -93.533268
# 879          879  ...  -90.313170
# 880          880  ...  -89.118343
# 881          881  ...  -88.281404
# 882          882  ...  -81.440626
# 883          883  ...  -93.344358
# 884          884  ...         NaN
# 885          885  ...   15.160548
# 886          886  ...  -81.463983
# 887          887  ...         NaN
# 888          888  ...  -80.517175
# 889          889  ... -122.619964
# 890          890  ... -121.899142
# 891          891  ...         NaN
# 892          892  ...  113.980393
# 893          893  ...  151.271244
# 894          894  ... -121.387743
# 895          895  ... -122.847339
# 896          896  ... -122.544976
# 897          897  ... -121.714173
# 898          898  ... -122.619964
# 899          899  ...  -77.306373
# 900          900  ...   19.790462
# 901          901  ... -120.907089
# 902          902  ... -104.821987
# 903          903  ...  -75.000000
# 904          904  ... -118.753822
# 905          905  ...  -74.012082
# 906          906  ...         NaN
# 907          907  ...  -79.253304
# 908          908  ...  -87.703187
# 909          909  ...   55.993696
# 910          910  ...  -81.055792
# 911          911  ... -117.569696
# 912          912  ... -117.566541
# 913          913  ...  -51.197218
# 914          914  ...  -87.357655
# 915          915  ... -122.007541
# 916          916  ... -120.212613
# 917          917  ...   -2.290024
# 918          918  ...   47.891527
# 919          919  ...  -77.850765
# 920          920  ...  -72.824936
# 921          921  ...  -78.878392
# 922          922  ...   11.471795
# 923          923  ...  -89.290339
# 924          924  ...  -81.419565
# 925          925  ...  -89.211518
# 926          926  ...  -90.240112
# 927          927  ...  151.192128
# 928          928  ...   23.728305
# 929          929  ...  -82.061040
# 930          930  ...   11.077298
# 931          931  ...  -90.389899
# 932          932  ...  -93.435922
# 933          933  ...  -95.094930
# 934          934  ...  -82.826826
# 935          935  ...  -94.969401
# 936          936  ...         NaN
# 937          937  ... -120.872434
# 938          938  ...  121.107211
# 939          939  ...    9.167307
# 940          940  ...         NaN
# 941          941  ... -118.305304
# 942          942  ...         NaN
# 943          943  ... -118.242766
# 944          944  ...  -78.639099
# 945          945  ... -111.044047
# 946          946  ... -108.496070
# 947          947  ... -109.638757
# 948          948  ...   -5.995340
# 949          949  ... -109.638757
# 950          950  ... -105.993007
# 951          951  ...  -71.655399
# 952          952  ... -112.983061
# 953          953  ... -102.404371
# 954          954  ...   -0.000279
# 955          955  ... -118.424344
# 956          956  ... -121.387743
# 957          957  ...  -70.308153
# 958          958  ...         NaN
# 959          959  ...         NaN
# 960          960  ...  -92.303023
# 961          961  ...  -80.450934
# 962          962  ...  -80.445630
# 963          963  ...  -77.040337
# 964          964  ...  -97.268406
# 965          965  ...  -74.124282
# 966          966  ...         NaN
# 967          967  ...         NaN
# 968          968  ...  -80.083098
# 969          969  ...  -80.475991
# 970          970  ...  -99.747591
# 971          971  ...    6.131764
# 972          972  ...  -85.474159
# 973          973  ...   -1.521461
# 974          974  ...         NaN
# 975          975  ...  -93.093103
# 976          976  ...  -73.124313
# 977          977  ...    5.341775
# 978          978  ... -101.818501
# 979          979  ...  -72.359278
# 980          980  ...   -0.218069
# 981          981  ...  -73.754204
# 982          982  ...         NaN
# 983          983  ... -122.775707
# 984          984  ... -122.847339
# 985          985  ...  -81.949804
# 986          986  ...  -81.812575
# 987          987  ...  -76.653188
# 988          988  ... -101.427109
# 989          989  ...  -85.811992
# 990          990  ...  -89.268791
# 991          991  ...  -94.740490
# 992          992  ...  -89.130612
# 993          993  ...  -93.220367
# 994          994  ...  -83.152013
# 995          995  ...  -93.226108
# 996          996  ...  -96.673655
# 997          997  ...    0.748959
# 998          998  ...    3.553813
# 999          999  ...         NaN
# 1000        1000  ...         NaN
# 1001        1001  ...         NaN
# 1002        1002  ...   -0.263407
# 1003        1003  ...  -86.829534
# 1004        1004  ...         NaN
# 1005        1005  ...  -95.762754
# 1006        1006  ...         NaN
# 1007        1007  ...  -90.184556
# 1008        1008  ... -120.905723
# 1009        1009  ...   22.088340
# 1010        1010  ...   -1.251665
# 1011        1011  ...         NaN
# 1012        1012  ... -122.766351
# 1013        1013  ...   47.497948
# 1014        1014  ... -122.915829
# 1015        1015  ...  115.709162
# 1016        1016  ...  144.728816
# 1017        1017  ...  -96.807457
# 1018        1018  ...         NaN
# 1019        1019  ...   36.571091
# 1020        1020  ... -112.052354
# 1021        1021  ...  151.210047
# 1022        1022  ... -123.113952
# 1023        1023  ... -161.755833
# 1024        1024  ...  -84.156634
# 1025        1025  ...  -74.859252
# 1026        1026  ...  -74.353685
# 1027        1027  ...  -96.823612
# 1028        1028  ... -122.419906
# 1029        1029  ...  135.194376
# 1030        1030  ...         NaN
# 1031        1031  ... -122.061870
# 1032        1032  ...  -77.047023
# 1033        1033  ...         NaN
# 1034        1034  ...   -2.922520
# 1035        1035  ...         NaN
# 1036        1036  ...  -79.492033
# 1037        1037  ... -149.894852
# 1038        1038  ...  -81.518485
# 1039        1039  ...  -74.514323
# 1040        1040  ...  -77.373221
# 1041        1041  ...   70.053510
# 1042        1042  ... -121.288006
# 1043        1043  ...         NaN
# 1044        1044  ...  -90.171799
# 1045        1045  ...  -62.569152
# 1046        1046  ...         NaN
# 1047        1047  ...         NaN
# 1048        1048  ...  -73.683849
# 1049        1049  ...  -91.089922
# 1050        1050  ...         NaN
# 1051        1051  ...         NaN
# 1052        1052  ...  -84.445485
# 1053        1053  ... -122.272823
# 1054        1054  ...   -7.336248
# 1055        1055  ...  -79.075288
# 1056        1056  ...         NaN
# 1057        1057  ...    4.559740
# 1058        1058  ...  -77.035092
# 1059        1059  ...   36.152787
# 1060        1060  ...   17.323111
# 1061        1061  ...   17.323111
# 1062        1062  ...   11.689970
# 1063        1063  ...    9.454001
# 1064        1064  ...   25.418896
# 1065        1065  ...   -2.584493
# 1066        1066  ...         NaN
# 1067        1067  ...  103.832104
# 1068        1068  ...   12.452835
# 1069        1069  ...   15.641915
# 1070        1070  ...  109.515577
# 1071        1071  ...  127.087042
# 1072        1072  ...  -61.751805
# 1073        1073  ...  -74.299592
# 1074        1074  ...  -74.314037
# 1075        1075  ...   -0.453784
# 1076        1076  ...  -78.957897
# 1077        1077  ...  -70.959210
# 1078        1078  ...  -76.511702
# 1079        1079  ...         NaN
# 1080        1080  ...  -82.150284
# 1081        1081  ...  -90.088332
# 1082        1082  ... -116.083314
# 1083        1083  ... -116.083314
# 1084        1084  ...         NaN
# 1085        1085  ...  -93.655276
# 1086        1086  ...  -77.009043
# 1087        1087  ...  -75.004920
# 1088        1088  ...   38.739256
# 1089        1089  ...   -2.727498
# 1090        1090  ...  -94.118537
# 1091        1091  ...  -89.216298
# 1092        1092  ...   -1.404189
# 1093        1093  ...  -90.199585
# 1094        1094  ...  -89.734850
# 1095        1095  ... -105.591101
# 1096        1096  ...  121.044016
# 1097        1097  ...   14.447691
# 1098        1098  ...   35.843409
# 1099        1099  ... -103.240073
# 1100        1100  ...   14.447691
# 1101        1101  ... -121.733278
# 1102        1102  ...  -97.345592
# 1103        1103  ... -113.484951
# 1104        1104  ...  -58.162446
# 1105        1105  ...         NaN
# 1106        1106  ... -122.328565
# 1107        1107  ...   30.683651
# 1108        1108  ...  -90.595365
# 1109        1109  ... -101.285574
# 1110        1110  ... -121.277372
# 1111        1111  ... -118.341260
# 1112        1112  ...  -92.561787
# 1113        1113  ...   -0.091998
# 1114        1114  ...  -92.583394
# 1115        1115  ...    3.415006
# 1116        1116  ...  -73.817429
# 1117        1117  ...  -87.039688
# 1118        1118  ...   -0.199123
# 1119        1119  ...  -74.444455
# 1120        1120  ...  -75.189975
# 1121        1121  ...    4.284453
# 1122        1122  ...  -82.736372
# 1123        1123  ...  -77.459553
# 1124        1124  ...  -84.505619
# 1125        1125  ...  -83.222153
# 1126        1126  ...  -95.223175
# 1127        1127  ...  153.196146
# 1128        1128  ...    6.997757
# 1129        1129  ...  -46.633382
# 1130        1130  ...  -75.014270
# 1131        1131  ...  -98.111429
# 1132        1132  ...  -75.030726
# 1133        1133  ...  -94.621903
# 1134        1134  ...  -80.166725
# 1135        1135  ... -121.988571
# 1136        1136  ...  -71.880224
# 1137        1137  ...  -81.379494
# 1138        1138  ...   -1.288483
# 1139        1139  ...   -2.437123
# 1140        1140  ...  -75.155345
# 1141        1141  ...  -75.157743
# 1142        1142  ...   -4.142566
# 1143        1143  ...         NaN
# 1144        1144  ...  -70.986418
# 1145        1145  ...  137.737850
# 1146        1146  ... -122.434693
# 1147        1147  ... -122.434693
# 1148        1148  ...         NaN
# 1149        1149  ...   12.480494
# 1150        1150  ... -105.081157
# 1151        1151  ...  -78.039552
# 1152        1152  ...  -71.493400
# 1153        1153  ...   36.941628
# 1154        1154  ...         NaN
# 1155        1155  ... -121.730488
# 1156        1156  ...  -96.958859
# 1157        1157  ...  -87.826509
# 1158        1158  ...  121.603630
# 1159        1159  ...    1.313423
# 1160        1160  ... -134.419734
# 1161        1161  ... -121.916355
# 1162        1162  ... -122.256637
# 1163        1163  ...  -88.460571
# 1164        1164  ... -118.190283
# 1165        1165  ...   95.999965
# 1166        1166  ...  -90.150543
# 1167        1167  ...         NaN
# 1168        1168  ...   -0.091998
# 1169        1169  ...  -98.156119
# 1170        1170  ...  -98.125146
# 1171        1171  ... -120.653006
# 1172        1172  ...  -84.274733
# 1173        1173  ...  -93.328891
# 1174        1174  ...   -7.101303
# 1175        1175  ...   -7.101303
# 1176        1176  ...  -88.819661
# 1177        1177  ...  -88.993485
# 1178        1178  ...         NaN
# 1179        1179  ...  -77.268039
# 1180        1180  ...         NaN
# 1181        1181  ...  -90.877734
# 1182        1182  ...         NaN
# 1183        1183  ...  -80.301441
# 1184        1184  ...         NaN
# 1185        1185  ...  121.829571
# 1186        1186  ...  -16.254088
# 1187        1187  ... -121.990591
# 1188        1188  ...         NaN
# 1189        1189  ...   -0.665572
# 1190        1190  ...    1.000000
# 1191        1191  ...  -13.122608
# 1192        1192  ...         NaN
# 1193        1193  ...  -81.263674
# 1194        1194  ...  -73.961495
# 1195        1195  ...  -76.708303
# 1196        1196  ...    9.738553
# 1197        1197  ...  -99.683001
# 1198        1198  ...  -77.043998
# 1199        1199  ...  -53.481842
# 1200        1200  ... -123.001828
# 1201        1201  ...         NaN
# 1202        1202  ...         NaN
# 1203        1203  ...   31.586178
# 1204        1204  ...  -73.922915
# 1205        1205  ...  -90.435999
# 1206        1206  ...   81.113108
# 1207        1207  ...  -79.180299
# 1208        1208  ...         NaN
# 1209        1209  ...  -86.174693
# 1210        1210  ...  -94.076381
# 1211        1211  ...  -86.075514
# 1212        1212  ...  -91.366715
# 1213        1213  ...   -2.877938
# 1214        1214  ...  -98.582187
# 1215        1215  ... -100.540737
# 1216        1216  ...  -81.291742
# 1217        1217  ...  -81.131076
# 1218        1218  ...    6.031111
# 1219        1219  ...         NaN
# 1220        1220  ...  -89.016184
# 1221        1221  ...  -71.406808
# 1222        1222  ...   -2.922520
# 1223        1223  ...  -99.813038
# 1224        1224  ...  -97.940583
# 1225        1225  ... -102.365715
# 1226        1226  ...  -93.255369
# 1227        1227  ...  -95.925051
# 1228        1228  ...         NaN
# 1229        1229  ... -118.430635
# 1230        1230  ...  -93.302390
# 1231        1231  ...  -72.099780
# 1232        1232  ...  -88.197556
# 1233        1233  ...  -88.243093
# 1234        1234  ...   28.058809
# 1235        1235  ... -101.222989
# 1236        1236  ...         NaN
# 1237        1237  ...  -87.040994
# 1238        1238  ...    6.567620
# 1239        1239  ...         NaN
# 1240        1240  ...         NaN
# 1241        1241  ...   -1.751919
# 1242        1242  ...  -85.730751
# 1243        1243  ...  138.674997
# 1244        1244  ...   -1.211271
# 1245        1245  ...  -75.013940
# 1246        1246  ...  -93.647987
# 1247        1247  ...         NaN
# 1248        1248  ...  -79.196510
# 1249        1249  ...  -87.580755
# 1250        1250  ...  -87.972722
# 1251        1251  ...  -72.996376
# 1252        1252  ...  -85.599311
# 1253        1253  ... -117.749779
# 1254        1254  ...   -0.646136
# 1255        1255  ...  -88.563113
# 1256        1256  ...  -80.498947
# 1257        1257  ...  -94.992736
# 1258        1258  ...   37.617309
# 1259        1259  ...         NaN
# 1260        1260  ...  -94.626918
# 1261        1261  ... -111.651823
# 1262        1262  ...  -74.875443
# 1263        1263  ...  -71.106164
# 1264        1264  ...  -94.910653
# 1265        1265  ...         NaN
# 1266        1266  ...  -97.058572
# 1267        1267  ...   28.187944
# 1268        1268  ... -121.684635
# 1269        1269  ... -122.133554
# 1270        1270  ...   22.449459
# 1271        1271  ...  -77.295330
# 1272        1272  ...  -92.031282
# 1273        1273  ...    5.939427
# 1274        1274  ...   24.685923
# 1275        1275  ... -107.568534
# 1276        1276  ...  -86.011244
# 1277        1277  ...  -89.591166
# 1278        1278  ... -100.005746
# 1279        1279  ...         NaN
# 1280        1280  ...  -83.507491
# 1281        1281  ...  -95.506594
# 1282        1282  ...  -74.119440
# 1283        1283  ...  176.329726
# 1284        1284  ...  -66.116666
# 1285        1285  ... -155.428370
# 1286        1286  ...         NaN
# 1287        1287  ...  -87.923841
# 1288        1288  ...  -64.803325
# 1289        1289  ...   80.221460
# 1290        1290  ...  -72.908813
# 1291        1291  ...  -88.914068
# 1292        1292  ...  -81.130843
# 1293        1293  ...  -84.073910
# 1294        1294  ...  -85.293691
# 1295        1295  ...  -71.441310
# 1296        1296  ...  -81.291742
# 1297        1297  ...    8.231974
# 1298        1298  ... -119.702919
# 1299        1299  ...  -81.025078
# 1300        1300  ...  -77.473849
# 1301        1301  ...  -80.859001
# 1302        1302  ...  -86.299938
# 1303        1303  ...  -80.813948
# 1304        1304  ...  -73.114251
# 1305        1305  ...   18.109900
# 1306        1306  ...         NaN
# 1307        1307  ...  -77.089309
# 1308        1308  ...    2.603033
# 1309        1309  ...  -74.002817
# 1310        1310  ...  -81.206272
# 1311        1311  ...  -79.039292
# 1312        1312  ...   -1.750000
# 1313        1313  ...  -82.732931
# 1314        1314  ...         NaN
# 1315        1315  ...  -83.119420
# 1316        1316  ... -105.578670
# 1317        1317  ... -119.702667
# 1318        1318  ...  -72.240557
# 1319        1319  ...   -7.111908
# 1320        1320  ...   -1.440035
# 1321        1321  ...  -79.838439
# 1322        1322  ...   -2.795584
# 1323        1323  ...         NaN
# 1324        1324  ...  -81.575682
# 1325        1325  ... -121.235783
# 1326        1326  ...  139.759455
# 1327        1327  ...   -3.276575
# 1328        1328  ...   57.009593
# 1329        1329  ...  -76.773893
# 1330        1330  ...  -58.437089
# 1331        1331  ...  -78.826505
# 1332        1332  ...  106.593172
# 1333        1333  ... -100.445882
# 1334        1334  ...   51.389600
# 1335        1335  ...  -56.077119
# 1336        1336  ... -106.717284
# 1337        1337  ...   11.137331
# 1338        1338  ...  -35.032098
# 1339        1339  ...  -76.241128
# 1340        1340  ...   -1.031873
# 1341        1341  ...  -75.943331
# 1342        1342  ...  127.696119
# 1343        1343  ...  149.984444
# 1344        1344  ... -121.530234
# 1345        1345  ...  -74.083652
# 1346        1346  ...   18.071093
# 1347        1347  ...  -89.085272
# 1348        1348  ...  -94.045346
# 1349        1349  ...   -1.705392
# 1350        1350  ...  -58.376228
# 1351        1351  ...  -97.971597
# 1352        1352  ...  -78.458076
# 1353        1353  ...   14.843984
# 1354        1354  ...   -4.259867
# 1355        1355  ...  -96.673655
# 1356        1356  ...  -71.282272
# 1357        1357  ... -122.192337
# 1358        1358  ...  -74.314871
# 1359        1359  ...  -74.480987
# 1360        1360  ...  -72.357097
# 1361        1361  ...  -74.269828
# 1362        1362  ...   63.952810
# 1363        1363  ...   23.822264
# 1364        1364  ...         NaN
# 1365        1365  ...         NaN
# 1366        1366  ... -115.139374
# 1367        1367  ...  -73.958150
# 1368        1368  ...   -0.162237
# 1369        1369  ...    2.449811
# 1370        1370  ...  125.495853
# 1371        1371  ...         NaN
# 1372        1372  ...   13.215199
# 1373        1373  ... -106.893080
# 1374        1374  ...  -94.846632
# 1375        1375  ...   -1.475099
#
# [1376 rows x 6 columns]

# %%
ct_mapping
# Out:
#       Unnamed: 0  ...  Longtitude
# 0              0  ...  -93.265469
# 1              1  ...    5.979900
# 2              2  ...  -94.611329
# 3              3  ...    9.417545
# 4              4  ...  -97.988594
# 5              5  ... -100.445882
# 6              6  ...  -74.006015
# 7              7  ...  -77.036543
# 8              8  ... -122.330062
# 9              9  ...  -99.683001
# 10            10  ...  -95.367697
# 11            11  ...  -82.688140
# 12            12  ... -118.755997
# 13            13  ...  -87.624421
# 14            14  ...  -75.163526
# 15            15  ... -104.984862
# 16            16  ...  -85.759407
# 17            17  ...    4.666714
# 18            18  ...  -74.006015
# 19            19  ... -118.242766
# 20            20  ...  -96.796856
# 21            21  ...  -83.113737
# 22            22  ...  -79.990086
# 23            23  ...  -81.463983
# 24            24  ...  -71.058291
# 25            25  ...   11.045785
# 26            26  ...  -84.390264
# 27            27  ...  -89.433729
# 28            28  ...  -74.404162
# 29            29  ...  -77.036543
# 30            30  ...  -78.492772
# 31            31  ...  -93.312270
# 32            32  ...  -95.992911
# 33            33  ... -122.419906
# 34            34  ... -122.271356
# 35            35  ...  -89.688464
# 36            36  ... -122.674195
# 37            37  ...  -87.922497
# 38            38  ...  -79.039292
# 39            39  ...         NaN
# 40            40  ...  -83.000706
# 41            41  ...  -97.268406
# 42            42  ...  -77.434280
# 43            43  ...   -3.276575
# 44            44  ...  -94.611329
# 45            45  ... -118.755997
# 46            46  ...  -77.036543
# 47            47  ...  -86.829534
# 48            48  ...  -80.843083
# 49            49  ...  -74.006015
# 50            50  ...  172.834408
# 51            51  ... -115.148516
# 52            52  ...   19.999962
# 53            53  ...  -80.193620
# 54            54  ...  -93.093103
# 55            55  ...  -73.959894
# 56            56  ...    1.888333
# 57            57  ...  -80.436374
# 58            58  ... -105.607716
# 59            59  ...  -77.727883
# 60            60  ...  -76.610759
# 61            61  ...  -78.878392
# 62            62  ...  -85.155141
# 63            63  ... -122.439875
# 64            64  ...  -79.039292
# 65            65  ... -117.162773
# 66            66  ...  -81.379030
# 67            67  ...  -83.892523
# 68            68  ...  -83.046640
# 69            69  ...  -76.938207
# 70            70  ...   -1.264906
# 71            71  ...  -78.492772
# 72            72  ... -111.714358
# 73            73  ...  -86.282008
# 74            74  ...  -84.682435
# 75            75  ...  -81.693445
# 76            76  ...  -77.036543
# 77            77  ...  -97.332746
# 78            78  ... -111.763275
# 79            79  ...  -84.063269
# 80            80  ... -118.329523
# 81            81  ...  -73.949721
# 82            82  ...         NaN
# 83            83  ...  -97.105624
# 84            84  ...   -1.902691
# 85            85  ...    2.320041
# 86            86  ...  -94.611329
# 87            87  ...         NaN
# 88            88  ...  -90.051629
# 89            89  ... -121.493895
# 90            90  ...  -89.433729
# 91            91  ...  -93.604665
# 92            92  ...   13.388860
# 93            93  ...    4.351697
# 94            94  ...  -75.844995
# 95            95  ...  -85.155141
# 96            96  ...  -72.032366
# 97            97  ...  -74.404162
# 98            98  ...   -0.127647
# 99            99  ...  -75.844995
# 100          100  ...  -89.734850
# 101          101  ...  -75.401331
# 102          102  ...         NaN
# 103          103  ... -118.191604
# 104          104  ...  -90.370584
# 105          105  ... -100.445882
# 106          106  ...   10.423447
# 107          107  ...  -86.774298
# 108          108  ...  104.999927
# 109          109  ...  -90.184769
# 110          110  ...  -71.599237
# 111          111  ...  -90.199585
# 112          112  ...  -73.878594
# 113          113  ... -120.737257
# 114          114  ...  -90.078213
# 115          115  ... -112.074142
# 116          116  ...  -84.280933
# 117          117  ... -106.464634
# 118          118  ...  -53.200000
# 119          119  ... -102.267516
# 120          120  ...  -93.486505
# 121          121  ...  -72.734216
# 122          122  ...  -80.449417
# 123          123  ...  -76.648348
# 124          124  ...  -92.561787
# 125          125  ...  -96.779007
# 126          126  ...  -81.176486
# 127          127  ...  -94.578142
# 128          128  ...   24.991639
# 129          129  ...   36.941628
# 130          130  ...  -81.463983
# 131          131  ...   10.992412
# 132          132  ... -105.993007
# 133          133  ... -100.445882
# 134          134  ...  -97.743700
# 135          135  ...  -72.734216
# 136          136  ...  -92.447911
# 137          137  ... -118.242766
# 138          138  ... -116.853723
# 139          139  ...  -89.267641
# 140          140  ...  -72.500261
# 141          141  ...   97.745306
# 142          142  ...  -86.534288
# 143          143  ... -122.706977
# 144          144  ...   -1.869210
# 145          145  ...  -86.300648
# 146          146  ...  -84.512460
# 147          147  ...  -91.187380
# 148          148  ... -120.212613
# 149          149  ...  -76.345206
# 150          150  ... -106.650985
# 151          151  ...  -74.742946
# 152          152  ...   29.894378
# 153          153  ...  -89.383761
# 154          154  ...  -75.977418
# 155          155  ...   -6.131967
# 156          156  ...   23.728305
# 157          157  ...  134.755000
# 158          158  ... -107.991707
# 159          159  ...  -75.119891
# 160          160  ...  -75.844995
# 161          161  ...  -87.216915
# 162          162  ...  -80.143379
# 163          163  ...  -75.546589
# 164          164  ...   -1.257850
# 165          165  ...  -86.282008
# 166          166  ...  -89.643957
# 167          167  ...  139.239418
# 168          168  ...  -79.940273
# 169          169  ...  -94.157433
# 170          170  ...  121.140422
# 171          171  ...  121.140422
# 172          172  ...  -94.846426
# 173          173  ...  -91.670405
# 174          174  ...  174.763180
# 175          175  ...  -80.085269
# 176          176  ... -122.348527
# 177          177  ... -117.870493
# 178          178  ...  -71.412834
# 179          179  ...  -82.458444
# 180          180  ...   -7.979460
# 181          181  ...   21.987713
# 182          182  ...    4.893604
# 183          183  ...   10.333328
# 184          184  ...  -87.674740
# 185          185  ...   -2.135839
# 186          186  ...   -4.837979
# 187          187  ...  -85.155141
# 188          188  ...  -87.789743
# 189          189  ... -100.217897
# 190          190  ...  -92.447911
# 191          191  ... -100.348761
# 192          192  ... -118.209681
# 193          193  ...   34.866765
# 194          194  ...         NaN
# 195          195  ... -104.987964
# 196          196  ...    9.417545
# 197          197  ...  -78.476678
# 198          198  ... -110.974848
# 199          199  ...  -88.007927
# 200          200  ... -118.485635
# 201          201  ...  -97.268406
# 202          202  ...  -72.690855
# 203          203  ...    2.177432
# 204          204  ...   -3.703582
# 205          205  ...   12.570072
# 206          206  ...   -6.260273
# 207          207  ... -104.825349
# 208          208  ...  -77.615214
# 209          209  ...  -73.043836
# 210          210  ...  -92.125122
# 211          211  ...  -78.492772
# 212          212  ...   -2.245115
# 213          213  ...  -71.316172
# 214          214  ...   -0.201238
# 215          215  ...   -1.080027
# 216          216  ...   66.238514
# 217          217  ...   44.174978
# 218          218  ...  -93.272139
# 219          219  ...  -93.044911
# 220          220  ...  -91.374322
# 221          221  ...  -80.241196
# 222          222  ... -149.680909
# 223          223  ...  -66.261522
# 224          224  ...   34.262717
# 225          225  ...  -89.629824
# 226          226  ...  -75.172039
# 227          227  ...  -72.612035
# 228          228  ...   36.714575
# 229          229  ...   19.134422
# 230          230  ...  -97.988594
# 231          231  ... -116.356044
# 232          232  ...  -95.864051
# 233          233  ...   11.689970
# 234          234  ...   34.924965
# 235          235  ...  -81.655651
# 236          236  ...  -71.599237
# 237          237  ...  -86.829534
# 238          238  ...  -86.158350
# 239          239  ...  -95.938376
# 240          240  ...  -80.436374
# 241          241  ...  -97.005825
# 242          242  ...  -96.247134
# 243          243  ...  -82.398488
# 244          244  ...   -0.169439
# 245          245  ...         NaN
# 246          246  ...  114.162813
# 247          247  ... -106.325138
# 248          248  ...  -79.039292
# 249          249  ...   -2.597298
# 250          250  ...  -90.179248
# 251          251  ...  -81.463983
# 252          252  ...  -84.191607
# 253          253  ... -119.019464
# 254          254  ...  -94.130165
# 255          255  ... -118.242766
# 256          256  ...  -82.889224
# 257          257  ...  139.718491
# 258          258  ...  -84.850737
# 259          259  ...  -27.223876
# 260          260  ...         NaN
# 261          261  ...         NaN
# 262          262  ...  -73.771287
# 263          263  ...         NaN
# 264          264  ...         NaN
# 265          265  ...  -61.883254
# 266          266  ...  -84.365168
# 267          267  ...         NaN
# 268          268  ...  -75.119891
# 269          269  ...   -3.474926
# 270          270  ...  -77.036543
# 271          271  ... -122.714105
# 272          272  ...  -68.859020
# 273          273  ...  -77.044114
# 274          274  ...  -81.022833
# 275          275  ...  -94.794588
# 276          276  ...  -94.611329
# 277          277  ...   18.277262
# 278          278  ...  139.922450
# 279          279  ... -106.650985
# 280          280  ...  -85.608316
# 281          281  ... -114.338285
# 282          282  ...         NaN
# 283          283  ...   46.717408
# 284          284  ...  -97.317910
# 285          285  ...         NaN
# 286          286  ...  -62.874624
# 287          287  ...  -92.007126
# 288          288  ...  -99.133178
# 289          289  ...   39.049411
# 290          290  ...  -75.004920
# 291          291  ... -112.491230
# 292          292  ...   78.667743
# 293          293  ... -118.491227
# 294          294  ...  -77.963960
# 295          295  ...  -77.341883
# 296          296  ... -105.110058
# 297          297  ...  -73.845312
# 298          298  ...  -99.683001
# 299          299  ... -108.550732
# 300          300  ...  -71.313771
# 301          301  ...  -95.286430
# 302          302  ...   38.431397
# 303          303  ...  151.216454
# 304          304  ...         NaN
# 305          305  ... -119.812658
# 306          306  ...  -73.469287
# 307          307  ... -111.940009
# 308          308  ...  -85.667864
# 309          309  ... -100.246720
# 310          310  ...   -1.918023
# 311          311  ... -106.319478
# 312          312  ...  -89.688464
# 313          313  ...  -81.818919
# 314          314  ... -120.737257
# 315          315  ... -122.828587
# 316          316  ...   12.482932
# 317          317  ...  108.426511
# 318          318  ...  -97.517054
# 319          319  ...  -97.390121
# 320          320  ...    2.420739
# 321          321  ...  151.210047
# 322          322  ...  -77.786572
# 323          323  ... -116.200886
# 324          324  ... -114.015407
# 325          325  ...         NaN
# 326          326  ...  -85.976667
# 327          327  ...   73.738398
# 328          328  ...  -78.705914
# 329          329  ...   -8.593516
# 330          330  ... -102.010377
# 331          331  ...  -74.118249
# 332          332  ...  -72.908813
# 333          333  ... -123.033121
# 334          334  ...   -0.169439
# 335          335  ... -112.036277
# 336          336  ... -122.427866
# 337          337  ...  -93.287788
# 338          338  ...  -93.765194
# 339          339  ...  -80.840842
# 340          340  ...   -1.075614
# 341          341  ...  120.612966
# 342          342  ...  -74.047455
# 343          343  ...  -88.247364
# 344          344  ...  -52.715149
# 345          345  ...   84.091714
# 346          346  ...    9.400138
# 347          347  ... -117.423511
# 348          348  ...  -93.198107
# 349          349  ... -116.037247
# 350          350  ...  -82.889096
# 351          351  ...  -97.683921
# 352          352  ...  -74.404162
# 353          353  ...  -93.256375
# 354          354  ...  -75.750997
# 355          355  ...   -3.738930
# 356          356  ...  -93.740504
# 357          357  ...  -80.840842
# 358          358  ... -117.792610
# 359          359  ...  -72.500261
# 360          360  ...  -76.537764
# 361          361  ...  -83.380444
# 362          362  ...  -95.374125
# 363          363  ...  -85.309488
# 364          364  ... -112.124655
# 365          365  ...  -73.407897
# 366          366  ...  -72.621371
# 367          367  ...  -72.032366
# 368          368  ...  -81.872308
# 369          369  ...  -71.010051
# 370          370  ...  -66.110932
# 371          371  ...   29.267547
# 372          372  ... -120.905723
# 373          373  ...  -94.344488
# 374          374  ...   13.413637
# 375          375  ...  -82.161424
# 376          376  ...  100.832730
# 377          377  ...         NaN
# 378          378  ... -116.495298
# 379          379  ...   12.674297
# 380          380  ...  -84.421311
# 381          381  ...   18.417396
# 382          382  ...  -75.156397
# 383          383  ... -111.237757
# 384          384  ...   10.423447
# 385          385  ...  -88.094935
# 386          386  ...         NaN
# 387          387  ...   47.787251
# 388          388  ...   -0.126540
# 389          389  ...   71.247499
# 390          390  ...  -92.352621
# 391          391  ...   54.564352
# 392          392  ...  -74.431408
# 393          393  ...  -98.495141
# 394          394  ... -106.097247
# 395          395  ... -121.890583
# 396          396  ... -122.840114
# 397          397  ...  104.999927
# 398          398  ...  -72.925052
# 399          399  ...  -80.498947
# 400          400  ...   -1.688031
# 401          401  ...  -92.289627
# 402          402  ...   -4.023957
# 403          403  ... -106.761307
# 404          404  ... -106.850392
# 405          405  ...  -74.879361
# 406          406  ...         NaN
# 407          407  ...  -77.659862
# 408          408  ...  -87.676387
# 409          409  ...  -97.388776
# 410          410  ...  151.210047
# 411          411  ...    6.095467
# 412          412  ...  -98.725884
# 413          413  ... -123.095051
# 414          414  ...  -87.772847
# 415          415  ...  -80.053294
# 416          416  ...   -0.131255
# 417          417  ...  -85.227733
# 418          418  ...         NaN
# 419          419  ...  -89.940719
# 420          420  ... -117.690075
# 421          421  ...  -82.445154
# 422          422  ...         NaN
# 423          423  ...  -82.574819
# 424          424  ...   35.225763
# 425          425  ... -121.978835
# 426          426  ...  -86.250007
# 427          427  ...   10.523607
# 428          428  ...  -84.573201
# 429          429  ...  -80.843083
# 430          430  ...  -63.048307
# 431          431  ...  -81.622507
# 432          432  ...  -71.801888
# 433          433  ...  -90.680259
# 434          434  ...         NaN
# 435          435  ...   12.002398
# 436          436  ...  -98.230082
# 437          437  ...  -98.216445
# 438          438  ... -117.291156
# 439          439  ... -113.995267
# 440          440  ...         NaN
# 441          441  ...   29.491769
# 442          442  ...  -77.231787
# 443          443  ... -103.227448
# 444          444  ...  -73.968085
# 445          445  ...  -81.690556
# 446          446  ...  122.731210
# 447          447  ...         NaN
# 448          448  ... -122.312918
# 449          449  ...  -84.555380
# 450          450  ...  -88.217052
# 451          451  ...  -80.371000
# 452          452  ...  -72.835420
# 453          453  ...   -3.188375
# 454          454  ...  -76.973794
# 455          455  ...  -90.575003
# 456          456  ...   -2.718901
# 457          457  ...    8.411977
# 458          458  ...  -53.542724
# 459          459  ...  -53.510267
# 460          460  ...  -77.066644
# 461          461  ...  -77.035951
# 462          462  ...  -77.036543
# 463          463  ...  -82.669508
# 464          464  ...  144.977682
# 465          465  ...  -88.531715
# 466          466  ...  -74.975711
# 467          467  ...  -86.392110
# 468          468  ...  -80.843083
# 469          469  ...  -72.500261
# 470          470  ...  -73.212906
# 471          471  ...  121.100360
# 472          472  ...         NaN
# 473          473  ...  -96.890282
# 474          474  ...   -1.055909
# 475          475  ...  -76.938207
# 476          476  ...  -87.840603
# 477          477  ...  -88.314754
# 478          478  ...    7.314956
# 479          479  ...  -87.848085
# 480          480  ...   -1.795413
# 481          481  ... -118.176742
# 482          482  ...  -93.210589
# 483          483  ...  -81.478898
# 484          484  ...  -89.250479
# 485          485  ...   26.550098
# 486          486  ...  -59.525031
# 487          487  ...  -97.988594
# 488          488  ...  -87.982297
# 489          489  ...   11.223458
# 490          490  ...    7.249473
# 491          491  ...  100.532730
# 492          492  ...  -87.833269
# 493          493  ...  -87.649278
# 494          494  ... -119.795634
# 495          495  ...  -66.254565
# 496          496  ...  151.192128
# 497          497  ...   31.271832
# 498          498  ...  -80.062998
# 499          499  ...  -85.650553
# 500          500  ...         NaN
# 501          501  ...  -96.160237
# 502          502  ...         NaN
# 503          503  ...    5.387210
# 504          504  ...         NaN
# 505          505  ...  -73.882428
# 506          506  ... -122.201400
# 507          507  ...  114.299935
# 508          508  ...         NaN
# 509          509  ... -111.886798
# 510          510  ...   35.206188
# 511          511  ...   12.674297
# 512          512  ... -119.180382
# 513          513  ...  -79.955944
# 514          514  ...  -80.840842
# 515          515  ...  -92.813498
# 516          516  ...  -74.149605
# 517          517  ...  -74.172367
# 518          518  ...  -88.059999
# 519          519  ...  -89.688464
# 520          520  ...  -99.112683
# 521          521  ...  -71.066163
# 522          522  ...  -78.998728
# 523          523  ...  -77.672693
# 524          524  ...    0.899465
# 525          525  ...  -83.221873
# 526          526  ...  -85.315553
# 527          527  ...  -96.789821
# 528          528  ...  -76.305669
# 529          529  ... -118.977322
# 530          530  ... -111.957708
# 531          531  ...  -80.072820
# 532          532  ...  -71.319290
# 533          533  ...  -90.832082
# 534          534  ... -102.135330
# 535          535  ...  -81.987349
# 536          536  ... -122.239634
# 537          537  ...         NaN
# 538          538  ... -123.117362
# 539          539  ...  -78.864042
# 540          540  ...    4.399708
# 541          541  ...  -80.832875
# 542          542  ...  -88.094935
# 543          543  ... -118.262509
# 544          544  ...   18.123672
# 545          545  ...    0.461789
# 546          546  ...  -99.747343
# 547          547  ...  -81.130843
# 548          548  ... -118.448135
# 549          549  ... -118.437869
# 550          550  ... -118.499820
# 551          551  ...  -90.584168
# 552          552  ...         NaN
# 553          553  ... -118.561271
# 554          554  ...   22.052782
# 555          555  ...  -55.910589
# 556          556  ... -118.242766
# 557          557  ... -117.596352
# 558          558  ...  -72.032366
# 559          559  ...  -95.677556
# 560          560  ... -100.440509
# 561          561  ...  -81.376774
# 562          562  ...  -70.494468
# 563          563  ...  -71.036166
# 564          564  ...   -9.585438
# 565          565  ...  -80.052129
# 566          566  ... -108.565996
# 567          567  ...  -84.810504
# 568          568  ...  -77.394769
# 569          569  ...  -72.453884
# 570          570  ...  -80.244052
# 571          571  ...  -88.043054
# 572          572  ...  -58.515028
# 573          573  ...         NaN
# 574          574  ... -105.472691
# 575          575  ... -105.756164
# 576          576  ...  -97.082849
# 577          577  ...   -3.276575
# 578          578  ...   -4.114052
# 579          579  ...  -95.552282
# 580          580  ...  -76.886112
# 581          581  ...   34.781806
# 582          582  ...  -76.411419
# 583          583  ...   34.846724
# 584          584  ...  131.018371
# 585          585  ...         NaN
# 586          586  ...  -97.749512
# 587          587  ...  -87.782524
# 588          588  ...  -90.616841
# 589          589  ...  -76.607917
# 590          590  ...  -96.968958
# 591          591  ...         NaN
# 592          592  ...         NaN
# 593          593  ...  121.026932
# 594          594  ...   39.826869
# 595          595  ...   -9.365852
# 596          596  ... -121.684635
# 597          597  ...  -75.401331
# 598          598  ...  -85.138602
# 599          599  ...  -87.020747
# 600          600  ...  -79.926240
# 601          601  ...  -74.988225
# 602          602  ...    0.198693
# 603          603  ...    3.169028
# 604          604  ...    7.206390
# 605          605  ...    6.094377
# 606          606  ...    5.747746
# 607          607  ...   -0.234834
# 608          608  ...         NaN
# 609          609  ...         NaN
# 610          610  ...         NaN
# 611          611  ...   -0.007059
# 612          612  ...         NaN
# 613          613  ...    5.387210
# 614          614  ...         NaN
# 615          615  ... -116.037247
# 616          616  ...         NaN
# 617          617  ...  -80.799719
# 618          618  ... -121.768053
# 619          619  ...    9.099971
# 620          620  ...  -79.039292
# 621          621  ...         NaN
# 622          622  ...   21.630538
# 623          623  ...         NaN
# 624          624  ... -119.784831
# 625          625  ... -117.176695
# 626          626  ...  -84.017690
# 627          627  ...  -86.459724
# 628          628  ... -122.777656
# 629          629  ...  -81.351026
# 630          630  ...  -73.219341
# 631          631  ...  -71.474693
# 632          632  ...   28.965165
# 633          633  ...         NaN
# 634          634  ...  -87.633102
# 635          635  ...  -71.398383
# 636          636  ...  -93.378341
# 637          637  ...   37.617494
# 638          638  ...   16.372504
# 639          639  ...  -73.665683
# 640          640  ...   49.083416
# 641          641  ...         NaN
# 642          642  ...  -72.667178
# 643          643  ...  132.910257
# 644          644  ...  -89.538421
# 645          645  ...  -85.759407
# 646          646  ...         NaN
# 647          647  ...  -80.143929
# 648          648  ...  -95.853308
# 649          649  ...  -71.085655
# 650          650  ... -118.248787
# 651          651  ...  -73.847829
# 652          652  ...  -71.296373
# 653          653  ...  -71.268947
# 654          654  ...   44.487797
# 655          655  ... -113.484951
# 656          656  ...   74.758023
# 657          657  ...         NaN
# 658          658  ...  -74.961978
# 659          659  ...         NaN
# 660          660  ...  -87.883673
# 661          661  ...  -88.058763
# 662          662  ...         NaN
# 663          663  ... -100.445882
# 664          664  ...  -79.996741
# 665          665  ...  -70.133616
# 666          666  ...  -73.993015
# 667          667  ...  -74.248480
# 668          668  ...  120.070268
# 669          669  ...   29.477011
# 670          670  ...         NaN
# 671          671  ...         NaN
# 672          672  ...  -49.061779
# 673          673  ...  151.345887
# 674          674  ... -118.353132
# 675          675  ...  -97.308600
# 676          676  ...  -97.388776
# 677          677  ...    8.904113
# 678          678  ... -147.669917
# 679          679  ...         NaN
# 680          680  ...  -89.738415
# 681          681  ...   -1.579648
# 682          682  ...  139.763005
# 683          683  ...         NaN
# 684          684  ...   -0.604096
# 685          685  ...  -85.744377
# 686          686  ...  -87.756525
# 687          687  ...  -87.693046
# 688          688  ...         NaN
# 689          689  ... -113.196639
# 690          690  ... -111.973843
# 691          691  ...  -82.572319
# 692          692  ...         NaN
# 693          693  ...  -84.285482
# 694          694  ...  -84.168827
# 695          695  ...   -0.131255
# 696          696  ...  -73.538734
# 697          697  ...         NaN
# 698          698  ...  -73.989898
# 699          699  ...         NaN
# 700          700  ...  -98.983102
# 701          701  ...  -79.941431
# 702          702  ...  -77.043182
# 703          703  ...  -90.303897
# 704          704  ...  -90.910455
# 705          705  ...         NaN
# 706          706  ... -118.242766
# 707          707  ...  -81.581111
# 708          708  ...    8.169460
# 709          709  ...  120.982018
# 710          710  ...  -90.674737
# 711          711  ...  -92.138770
# 712          712  ...  -75.232664
# 713          713  ...  120.883305
# 714          714  ...  -82.364011
# 715          715  ...  -72.666892
# 716          716  ... -103.353163
# 717          717  ...  -73.204835
# 718          718  ...  -87.806266
# 719          719  ... -117.192246
# 720          720  ...         NaN
# 721          721  ...   -2.784359
# 722          722  ...   -9.013548
# 723          723  ...  -80.135301
# 724          724  ...  -83.433157
# 725          725  ...         NaN
# 726          726  ...         NaN
# 727          727  ... -118.360370
# 728          728  ... -114.097039
# 729          729  ...  -87.733397
# 730          730  ...  -75.113465
# 731          731  ...  -96.845634
# 732          732  ...   -0.198283
# 733          733  ...  -82.966687
# 734          734  ...  -82.879136
# 735          735  ...   -0.230443
# 736          736  ...  -94.969401
# 737          737  ...  -89.250479
# 738          738  ...  -81.655651
# 739          739  ...   76.044418
# 740          740  ...    6.537702
# 741          741  ...   18.619444
# 742          742  ... -122.770452
# 743          743  ... -122.779038
# 744          744  ...  -94.170450
# 745          745  ... -120.212613
# 746          746  ...    7.447920
# 747          747  ...         NaN
# 748          748  ...         NaN
# 749          749  ... -118.226624
# 750          750  ...  -80.449417
# 751          751  ...  152.908847
# 752          752  ...  -71.067897
# 753          753  ...  -81.812912
# 754          754  ...  -81.668812
# 755          755  ...  138.728963
# 756          756  ...  -97.194370
# 757          757  ... -122.256637
# 758          758  ... -122.230950
# 759          759  ...   -4.727897
# 760          760  ...  172.636646
# 761          761  ...  -78.890041
# 762          762  ...  -83.632402
# 763          763  ...  -82.324985
# 764          764  ...  -87.556711
# 765          765  ... -118.202415
# 766          766  ...   -0.181979
# 767          767  ...  -87.529584
# 768          768  ...  -79.817981
# 769          769  ...  -86.052331
# 770          770  ...  153.461672
# 771          771  ...  -90.733326
# 772          772  ...         NaN
# 773          773  ...  -90.122655
# 774          774  ...  -92.332964
# 775          775  ...    1.336252
# 776          776  ...  -77.036543
# 777          777  ...  -89.478704
# 778          778  ...   -2.805778
# 779          779  ...  -96.976930
# 780          780  ...  -95.431885
# 781          781  ...  -73.782636
# 782          782  ...         NaN
# 783          783  ...  -79.658366
# 784          784  ...  -79.745884
# 785          785  ... -118.865045
# 786          786  ...    8.541042
# 787          787  ...  -82.335646
# 788          788  ...  101.448088
# 789          789  ...  -82.398488
# 790          790  ...  144.359496
# 791          791  ...  -76.497005
# 792          792  ...  -81.091177
# 793          793  ...  -89.553438
# 794          794  ...  -77.036526
# 795          795  ...  -73.789546
# 796          796  ...   14.446200
# 797          797  ...         NaN
# 798          798  ...  -91.603793
# 799          799  ...  -78.878392
# 800          800  ... -101.388495
# 801          801  ... -110.354945
# 802          802  ... -122.613786
# 803          803  ... -100.889704
# 804          804  ...   14.217167
# 805          805  ... -100.458920
# 806          806  ...  -88.074239
# 807          807  ...  -94.093848
# 808          808  ... -111.241833
# 809          809  ...  -88.445803
# 810          810  ...   -1.243409
# 811          811  ...  -72.721834
# 812          812  ...  -95.989395
# 813          813  ...  -92.964579
# 814          814  ...  -73.063399
# 815          815  ...  -89.774810
# 816          816  ...   -2.872472
# 817          817  ...  -92.688894
# 818          818  ...  -87.765573
# 819          819  ... -101.279976
# 820          820  ...  -80.837346
# 821          821  ...         NaN
# 822          822  ...   -1.706367
# 823          823  ...  -74.502344
# 824          824  ...   76.201220
# 825          825  ...  144.757551
# 826          826  ...  -60.955858
# 827          827  ...  -78.000055
# 828          828  ... -122.253413
# 829          829  ...  -92.414907
# 830          830  ...         NaN
# 831          831  ...   90.511927
# 832          832  ...   84.091714
# 833          833  ... -115.167207
# 834          834  ...         NaN
# 835          835  ...  -71.655399
# 836          836  ...  -60.010701
# 837          837  ...  -68.714564
# 838          838  ...  -87.882005
# 839          839  ...         NaN
# 840          840  ...  -76.614815
# 841          841  ... -124.086486
# 842          842  ...  104.999927
# 843          843  ...         NaN
# 844          844  ...  -85.198845
# 845          845  ...  -73.067367
# 846          846  ...  -87.666120
# 847          847  ...   76.174415
# 848          848  ...  -83.049644
# 849          849  ...  -73.739713
# 850          850  ...         NaN
# 851          851  ...   -2.589017
# 852          852  ...  -93.928872
# 853          853  ...  -95.388563
# 854          854  ...  -97.078875
# 855          855  ...  -96.944218
# 856          856  ... -122.647442
# 857          857  ... -122.647442
# 858          858  ...  -97.371465
# 859          859  ...  -64.241850
# 860          860  ...  -76.851869
# 861          861  ...  -89.433729
# 862          862  ...  168.390180
# 863          863  ...  -92.943822
# 864          864  ...         NaN
# 865          865  ...  -88.328149
# 866          866  ...         NaN
# 867          867  ...  -88.542423
# 868          868  ...  -87.860637
# 869          869  ...  -87.723959
# 870          870  ...  -87.666716
# 871          871  ...  -91.257501
# 872          872  ...  -87.821226
# 873          873  ...  -87.503152
# 874          874  ...  -83.653772
# 875          875  ...  -89.085946
# 876          876  ...  -89.022679
# 877          877  ...  -88.404069
# 878          878  ...  -93.533268
# 879          879  ...  -90.313170
# 880          880  ...  -89.118343
# 881          881  ...  -88.281404
# 882          882  ...  -81.440626
# 883          883  ...  -93.344358
# 884          884  ...         NaN
# 885          885  ...   15.160548
# 886          886  ...  -81.463983
# 887          887  ...         NaN
# 888          888  ...  -80.517175
# 889          889  ... -122.619964
# 890          890  ... -121.899142
# 891          891  ...         NaN
# 892          892  ...  113.980393
# 893          893  ...  151.271244
# 894          894  ... -121.387743
# 895          895  ... -122.847339
# 896          896  ... -122.544976
# 897          897  ... -121.714173
# 898          898  ... -122.619964
# 899          899  ...  -77.306373
# 900          900  ...   19.790462
# 901          901  ... -120.907089
# 902          902  ... -104.821987
# 903          903  ...  -75.000000
# 904          904  ... -118.753822
# 905          905  ...  -74.012082
# 906          906  ...         NaN
# 907          907  ...  -79.253304
# 908          908  ...  -87.703187
# 909          909  ...   55.993696
# 910          910  ...  -81.055792
# 911          911  ... -117.569696
# 912          912  ... -117.566541
# 913          913  ...  -51.197218
# 914          914  ...  -87.357655
# 915          915  ... -122.007541
# 916          916  ... -120.212613
# 917          917  ...   -2.290024
# 918          918  ...   47.891527
# 919          919  ...  -77.850765
# 920          920  ...  -72.824936
# 921          921  ...  -78.878392
# 922          922  ...   11.471795
# 923          923  ...  -89.290339
# 924          924  ...  -81.419565
# 925          925  ...  -89.211518
# 926          926  ...  -90.240112
# 927          927  ...  151.192128
# 928          928  ...   23.728305
# 929          929  ...  -82.061040
# 930          930  ...   11.077298
# 931          931  ...  -90.389899
# 932          932  ...  -93.435922
# 933          933  ...  -95.094930
# 934          934  ...  -82.826826
# 935          935  ...  -94.969401
# 936          936  ...         NaN
# 937          937  ... -120.872434
# 938          938  ...  121.107211
# 939          939  ...    9.167307
# 940          940  ...         NaN
# 941          941  ... -118.305304
# 942          942  ...         NaN
# 943          943  ... -118.242766
# 944          944  ...  -78.639099
# 945          945  ... -111.044047
# 946          946  ... -108.496070
# 947          947  ... -109.638757
# 948          948  ...   -5.995340
# 949          949  ... -109.638757
# 950          950  ... -105.993007
# 951          951  ...  -71.655399
# 952          952  ... -112.983061
# 953          953  ... -102.404371
# 954          954  ...   -0.000279
# 955          955  ... -118.424344
# 956          956  ... -121.387743
# 957          957  ...  -70.308153
# 958          958  ...         NaN
# 959          959  ...         NaN
# 960          960  ...  -92.303023
# 961          961  ...  -80.450934
# 962          962  ...  -80.445630
# 963          963  ...  -77.040337
# 964          964  ...  -97.268406
# 965          965  ...  -74.124282
# 966          966  ...         NaN
# 967          967  ...         NaN
# 968          968  ...  -80.083098
# 969          969  ...  -80.475991
# 970          970  ...  -99.747591
# 971          971  ...    6.131764
# 972          972  ...  -85.474159
# 973          973  ...   -1.521461
# 974          974  ...         NaN
# 975          975  ...  -93.093103
# 976          976  ...  -73.124313
# 977          977  ...    5.341775
# 978          978  ... -101.818501
# 979          979  ...  -72.359278
# 980          980  ...   -0.218069
# 981          981  ...  -73.754204
# 982          982  ...         NaN
# 983          983  ... -122.775707
# 984          984  ... -122.847339
# 985          985  ...  -81.949804
# 986          986  ...  -81.812575
# 987          987  ...  -76.653188
# 988          988  ... -101.427109
# 989          989  ...  -85.811992
# 990          990  ...  -89.268791
# 991          991  ...  -94.740490
# 992          992  ...  -89.130612
# 993          993  ...  -93.220367
# 994          994  ...  -83.152013
# 995          995  ...  -93.226108
# 996          996  ...  -96.673655
# 997          997  ...    0.748959
# 998          998  ...    3.553813
# 999          999  ...         NaN
# 1000        1000  ...         NaN
# 1001        1001  ...         NaN
# 1002        1002  ...   -0.263407
# 1003        1003  ...  -86.829534
# 1004        1004  ...         NaN
# 1005        1005  ...  -95.762754
# 1006        1006  ...         NaN
# 1007        1007  ...  -90.184556
# 1008        1008  ... -120.905723
# 1009        1009  ...   22.088340
# 1010        1010  ...   -1.251665
# 1011        1011  ...         NaN
# 1012        1012  ... -122.766351
# 1013        1013  ...   47.497948
# 1014        1014  ... -122.915829
# 1015        1015  ...  115.709162
# 1016        1016  ...  144.728816
# 1017        1017  ...  -96.807457
# 1018        1018  ...         NaN
# 1019        1019  ...   36.571091
# 1020        1020  ... -112.052354
# 1021        1021  ...  151.210047
# 1022        1022  ... -123.113952
# 1023        1023  ... -161.755833
# 1024        1024  ...  -84.156634
# 1025        1025  ...  -74.859252
# 1026        1026  ...  -74.353685
# 1027        1027  ...  -96.823612
# 1028        1028  ... -122.419906
# 1029        1029  ...  135.194376
# 1030        1030  ...         NaN
# 1031        1031  ... -122.061870
# 1032        1032  ...  -77.047023
# 1033        1033  ...         NaN
# 1034        1034  ...   -2.922520
# 1035        1035  ...         NaN
# 1036        1036  ...  -79.492033
# 1037        1037  ... -149.894852
# 1038        1038  ...  -81.518485
# 1039        1039  ...  -74.514323
# 1040        1040  ...  -77.373221
# 1041        1041  ...   70.053510
# 1042        1042  ... -121.288006
# 1043        1043  ...         NaN
# 1044        1044  ...  -90.171799
# 1045        1045  ...  -62.569152
# 1046        1046  ...         NaN
# 1047        1047  ...         NaN
# 1048        1048  ...  -73.683849
# 1049        1049  ...  -91.089922
# 1050        1050  ...         NaN
# 1051        1051  ...         NaN
# 1052        1052  ...  -84.445485
# 1053        1053  ... -122.272823
# 1054        1054  ...   -7.336248
# 1055        1055  ...  -79.075288
# 1056        1056  ...         NaN
# 1057        1057  ...    4.559740
# 1058        1058  ...  -77.035092
# 1059        1059  ...   36.152787
# 1060        1060  ...   17.323111
# 1061        1061  ...   17.323111
# 1062        1062  ...   11.689970
# 1063        1063  ...    9.454001
# 1064        1064  ...   25.418896
# 1065        1065  ...   -2.584493
# 1066        1066  ...         NaN
# 1067        1067  ...  103.832104
# 1068        1068  ...   12.452835
# 1069        1069  ...   15.641915
# 1070        1070  ...  109.515577
# 1071        1071  ...  127.087042
# 1072        1072  ...  -61.751805
# 1073        1073  ...  -74.299592
# 1074        1074  ...  -74.314037
# 1075        1075  ...   -0.453784
# 1076        1076  ...  -78.957897
# 1077        1077  ...  -70.959210
# 1078        1078  ...  -76.511702
# 1079        1079  ...         NaN
# 1080        1080  ...  -82.150284
# 1081        1081  ...  -90.088332
# 1082        1082  ... -116.083314
# 1083        1083  ... -116.083314
# 1084        1084  ...         NaN
# 1085        1085  ...  -93.655276
# 1086        1086  ...  -77.009043
# 1087        1087  ...  -75.004920
# 1088        1088  ...   38.739256
# 1089        1089  ...   -2.727498
# 1090        1090  ...  -94.118537
# 1091        1091  ...  -89.216298
# 1092        1092  ...   -1.404189
# 1093        1093  ...  -90.199585
# 1094        1094  ...  -89.734850
# 1095        1095  ... -105.591101
# 1096        1096  ...  121.044016
# 1097        1097  ...   14.447691
# 1098        1098  ...   35.843409
# 1099        1099  ... -103.240073
# 1100        1100  ...   14.447691
# 1101        1101  ... -121.733278
# 1102        1102  ...  -97.345592
# 1103        1103  ... -113.484951
# 1104        1104  ...  -58.162446
# 1105        1105  ...         NaN
# 1106        1106  ... -122.328565
# 1107        1107  ...   30.683651
# 1108        1108  ...  -90.595365
# 1109        1109  ... -101.285574
# 1110        1110  ... -121.277372
# 1111        1111  ... -118.341260
# 1112        1112  ...  -92.561787
# 1113        1113  ...   -0.091998
# 1114        1114  ...  -92.583394
# 1115        1115  ...    3.415006
# 1116        1116  ...  -73.817429
# 1117        1117  ...  -87.039688
# 1118        1118  ...   -0.199123
# 1119        1119  ...  -74.444455
# 1120        1120  ...  -75.189975
# 1121        1121  ...    4.284453
# 1122        1122  ...  -82.736372
# 1123        1123  ...  -77.459553
# 1124        1124  ...  -84.505619
# 1125        1125  ...  -83.222153
# 1126        1126  ...  -95.223175
# 1127        1127  ...  153.196146
# 1128        1128  ...    6.997757
# 1129        1129  ...  -46.633382
# 1130        1130  ...  -75.014270
# 1131        1131  ...  -98.111429
# 1132        1132  ...  -75.030726
# 1133        1133  ...  -94.621903
# 1134        1134  ...  -80.166725
# 1135        1135  ... -121.988571
# 1136        1136  ...  -71.880224
# 1137        1137  ...  -81.379494
# 1138        1138  ...   -1.288483
# 1139        1139  ...   -2.437123
# 1140        1140  ...  -75.155345
# 1141        1141  ...  -75.157743
# 1142        1142  ...   -4.142566
# 1143        1143  ...         NaN
# 1144        1144  ...  -70.986418
# 1145        1145  ...  137.737850
# 1146        1146  ... -122.434693
# 1147        1147  ... -122.434693
# 1148        1148  ...         NaN
# 1149        1149  ...   12.480494
# 1150        1150  ... -105.081157
# 1151        1151  ...  -78.039552
# 1152        1152  ...  -71.493400
# 1153        1153  ...   36.941628
# 1154        1154  ...         NaN
# 1155        1155  ... -121.730488
# 1156        1156  ...  -96.958859
# 1157        1157  ...  -87.826509
# 1158        1158  ...  121.603630
# 1159        1159  ...    1.313423
# 1160        1160  ... -134.419734
# 1161        1161  ... -121.916355
# 1162        1162  ... -122.256637
# 1163        1163  ...  -88.460571
# 1164        1164  ... -118.190283
# 1165        1165  ...   95.999965
# 1166        1166  ...  -90.150543
# 1167        1167  ...         NaN
# 1168        1168  ...   -0.091998
# 1169        1169  ...  -98.156119
# 1170        1170  ...  -98.125146
# 1171        1171  ... -120.653006
# 1172        1172  ...  -84.274733
# 1173        1173  ...  -93.328891
# 1174        1174  ...   -7.101303
# 1175        1175  ...   -7.101303
# 1176        1176  ...  -88.819661
# 1177        1177  ...  -88.993485
# 1178        1178  ...         NaN
# 1179        1179  ...  -77.268039
# 1180        1180  ...         NaN
# 1181        1181  ...  -90.877734
# 1182        1182  ...         NaN
# 1183        1183  ...  -80.301441
# 1184        1184  ...         NaN
# 1185        1185  ...  121.829571
# 1186        1186  ...  -16.254088
# 1187        1187  ... -121.990591
# 1188        1188  ...         NaN
# 1189        1189  ...   -0.665572
# 1190        1190  ...    1.000000
# 1191        1191  ...  -13.122608
# 1192        1192  ...         NaN
# 1193        1193  ...  -81.263674
# 1194        1194  ...  -73.961495
# 1195        1195  ...  -76.708303
# 1196        1196  ...    9.738553
# 1197        1197  ...  -99.683001
# 1198        1198  ...  -77.043998
# 1199        1199  ...  -53.481842
# 1200        1200  ... -123.001828
# 1201        1201  ...         NaN
# 1202        1202  ...         NaN
# 1203        1203  ...   31.586178
# 1204        1204  ...  -73.922915
# 1205        1205  ...  -90.435999
# 1206        1206  ...   81.113108
# 1207        1207  ...  -79.180299
# 1208        1208  ...         NaN
# 1209        1209  ...  -86.174693
# 1210        1210  ...  -94.076381
# 1211        1211  ...  -86.075514
# 1212        1212  ...  -91.366715
# 1213        1213  ...   -2.877938
# 1214        1214  ...  -98.582187
# 1215        1215  ... -100.540737
# 1216        1216  ...  -81.291742
# 1217        1217  ...  -81.131076
# 1218        1218  ...    6.031111
# 1219        1219  ...         NaN
# 1220        1220  ...  -89.016184
# 1221        1221  ...  -71.406808
# 1222        1222  ...   -2.922520
# 1223        1223  ...  -99.813038
# 1224        1224  ...  -97.940583
# 1225        1225  ... -102.365715
# 1226        1226  ...  -93.255369
# 1227        1227  ...  -95.925051
# 1228        1228  ...         NaN
# 1229        1229  ... -118.430635
# 1230        1230  ...  -93.302390
# 1231        1231  ...  -72.099780
# 1232        1232  ...  -88.197556
# 1233        1233  ...  -88.243093
# 1234        1234  ...   28.058809
# 1235        1235  ... -101.222989
# 1236        1236  ...         NaN
# 1237        1237  ...  -87.040994
# 1238        1238  ...    6.567620
# 1239        1239  ...         NaN
# 1240        1240  ...         NaN
# 1241        1241  ...   -1.751919
# 1242        1242  ...  -85.730751
# 1243        1243  ...  138.674997
# 1244        1244  ...   -1.211271
# 1245        1245  ...  -75.013940
# 1246        1246  ...  -93.647987
# 1247        1247  ...         NaN
# 1248        1248  ...  -79.196510
# 1249        1249  ...  -87.580755
# 1250        1250  ...  -87.972722
# 1251        1251  ...  -72.996376
# 1252        1252  ...  -85.599311
# 1253        1253  ... -117.749779
# 1254        1254  ...   -0.646136
# 1255        1255  ...  -88.563113
# 1256        1256  ...  -80.498947
# 1257        1257  ...  -94.992736
# 1258        1258  ...   37.617309
# 1259        1259  ...         NaN
# 1260        1260  ...  -94.626918
# 1261        1261  ... -111.651823
# 1262        1262  ...  -74.875443
# 1263        1263  ...  -71.106164
# 1264        1264  ...  -94.910653
# 1265        1265  ...         NaN
# 1266        1266  ...  -97.058572
# 1267        1267  ...   28.187944
# 1268        1268  ... -121.684635
# 1269        1269  ... -122.133554
# 1270        1270  ...   22.449459
# 1271        1271  ...  -77.295330
# 1272        1272  ...  -92.031282
# 1273        1273  ...    5.939427
# 1274        1274  ...   24.685923
# 1275        1275  ... -107.568534
# 1276        1276  ...  -86.011244
# 1277        1277  ...  -89.591166
# 1278        1278  ... -100.005746
# 1279        1279  ...         NaN
# 1280        1280  ...  -83.507491
# 1281        1281  ...  -95.506594
# 1282        1282  ...  -74.119440
# 1283        1283  ...  176.329726
# 1284        1284  ...  -66.116666
# 1285        1285  ... -155.428370
# 1286        1286  ...         NaN
# 1287        1287  ...  -87.923841
# 1288        1288  ...  -64.803325
# 1289        1289  ...   80.221460
# 1290        1290  ...  -72.908813
# 1291        1291  ...  -88.914068
# 1292        1292  ...  -81.130843
# 1293        1293  ...  -84.073910
# 1294        1294  ...  -85.293691
# 1295        1295  ...  -71.441310
# 1296        1296  ...  -81.291742
# 1297        1297  ...    8.231974
# 1298        1298  ... -119.702919
# 1299        1299  ...  -81.025078
# 1300        1300  ...  -77.473849
# 1301        1301  ...  -80.859001
# 1302        1302  ...  -86.299938
# 1303        1303  ...  -80.813948
# 1304        1304  ...  -73.114251
# 1305        1305  ...   18.109900
# 1306        1306  ...         NaN
# 1307        1307  ...  -77.089309
# 1308        1308  ...    2.603033
# 1309        1309  ...  -74.002817
# 1310        1310  ...  -81.206272
# 1311        1311  ...  -79.039292
# 1312        1312  ...   -1.750000
# 1313        1313  ...  -82.732931
# 1314        1314  ...         NaN
# 1315        1315  ...  -83.119420
# 1316        1316  ... -105.578670
# 1317        1317  ... -119.702667
# 1318        1318  ...  -72.240557
# 1319        1319  ...   -7.111908
# 1320        1320  ...   -1.440035
# 1321        1321  ...  -79.838439
# 1322        1322  ...   -2.795584
# 1323        1323  ...         NaN
# 1324        1324  ...  -81.575682
# 1325        1325  ... -121.235783
# 1326        1326  ...  139.759455
# 1327        1327  ...   -3.276575
# 1328        1328  ...   57.009593
# 1329        1329  ...  -76.773893
# 1330        1330  ...  -58.437089
# 1331        1331  ...  -78.826505
# 1332        1332  ...  106.593172
# 1333        1333  ... -100.445882
# 1334        1334  ...   51.389600
# 1335        1335  ...  -56.077119
# 1336        1336  ... -106.717284
# 1337        1337  ...   11.137331
# 1338        1338  ...  -35.032098
# 1339        1339  ...  -76.241128
# 1340        1340  ...   -1.031873
# 1341        1341  ...  -75.943331
# 1342        1342  ...  127.696119
# 1343        1343  ...  149.984444
# 1344        1344  ... -121.530234
# 1345        1345  ...  -74.083652
# 1346        1346  ...   18.071093
# 1347        1347  ...  -89.085272
# 1348        1348  ...  -94.045346
# 1349        1349  ...   -1.705392
# 1350        1350  ...  -58.376228
# 1351        1351  ...  -97.971597
# 1352        1352  ...  -78.458076
# 1353        1353  ...   14.843984
# 1354        1354  ...   -4.259867
# 1355        1355  ...  -96.673655
# 1356        1356  ...  -71.282272
# 1357        1357  ... -122.192337
# 1358        1358  ...  -74.314871
# 1359        1359  ...  -74.480987
# 1360        1360  ...  -72.357097
# 1361        1361  ...  -74.269828
# 1362        1362  ...   63.952810
# 1363        1363  ...   23.822264
# 1364        1364  ...         NaN
# 1365        1365  ...         NaN
# 1366        1366  ... -115.139374
# 1367        1367  ...  -73.958150
# 1368        1368  ...   -0.162237
# 1369        1369  ...    2.449811
# 1370        1370  ...  125.495853
# 1371        1371  ...         NaN
# 1372        1372  ...   13.215199
# 1373        1373  ... -106.893080
# 1374        1374  ...  -94.846632
# 1375        1375  ...   -1.475099
#
# [1376 rows x 6 columns]

# %%
ct_mapping.to_csv('dataframe_mapping_0612.csv')

# %%
#ct_mapping=pd.read_csv('dataframe_mapping_0530.csv',encoding='ISO-8859-1')

# %%
for k in range(len(ct_ner['NER-1'])):
  list=[]
  for i in ct_ner['NER-1'][k]:
    for j in range(len(ct_mapping['City'])):
      if(i==ct_mapping['City'][j]):
        list.append(ct_mapping['Mapping'][j])
  ct_ner['NER-1'][k]=list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
ct_ner[:100]
# Out:
#     Unnamed: 0  ...                                              NER-1
# 0            0  ...                                                 []
# 1            1  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 2            2  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 3            3  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 4            4  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 5            5  ...  [Hampton, Virginia, 23669-4019, United States,...
# 6            6  ...  [Hampton, Virginia, 23669-4019, United States,...
# 7            7  ...                                                 []
# 8            8  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 9            9  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 10          10  ...                                                 []
# 11          11  ...                                                 []
# 12          12  ...  [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 13          13  ...                                                 []
# 14          14  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 15          15  ...  [Albuquerque, Bernalillo County, New Mexico, 8...
# 16          16  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 17          17  ...           [Lake County, California, United States]
# 18          18  ...  [Winter Park, Orange County, Florida, United S...
# 19          19  ...                                                 []
# 20          20  ...                                                 []
# 21          21  ...                                                 []
# 22          22  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 23          23  ...  [Washington, District of Columbia, United Stat...
# 24          24  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 25          25  ...  [Trenton, Mercer County, New Jersey, United St...
# 26          26  ...  [Trenton, Mercer County, New Jersey, United St...
# 27          27  ...  [Trenton, Mercer County, New Jersey, United St...
# 28          28  ...  [Trenton, Mercer County, New Jersey, United St...
# 29          29  ...  [Trenton, Mercer County, New Jersey, United St...
# 30          30  ...                                                 []
# 31          31  ...  [Trenton, Mercer County, New Jersey, United St...
# 32          32  ...  [Trenton, Mercer County, New Jersey, United St...
# 33          33  ...  [Cecil Street, Johnston, Providence County, Rh...
# 34          34  ...  [Ä°stanbul, Fatih, Ä°stanbul, Marmara BÃ¶lgesi...
# 35          35  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 36          36  ...                                              [nan]
# 37          37  ...                                                 []
# 38          38  ...                                                 []
# 39          39  ...                                              [nan]
# 40          40  ...  [Oakland, Alameda County, California, United S...
# 41          41  ...  [Oakland, Alameda County, California, United S...
# 42          42  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 43          43  ...                       [nan, AzÉrbaycan, nan, nan]
# 44          44  ...  [Beavercreek, Greene County, Ohio, 45430, Unit...
# 45          45  ...  [Beavercreek, Greene County, Ohio, 45430, Unit...
# 46          46  ...                                                 []
# 47          47  ...                                                 []
# 48          48  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 49          49  ...                                                 []
# 50          50  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 51          51  ...                                              [nan]
# 52          52  ...                                                 []
# 53          53  ...                                                 []
# 54          54  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 55          55  ...                                                 []
# 56          56  ...  [Jacksonville, Duval County, Florida, United S...
# 57          57  ...                                                 []
# 58          58  ...                                                 []
# 59          59  ...                                                 []
# 60          60  ...                                                 []
# 61          61  ...  [Westminster, Millbank, City of Westminster, L...
# 62          62  ...  [Louisville, Jefferson County, Kentucky, 40202...
# 63          63  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 64          64  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 65          65  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 66          66  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 67          67  ...                                                 []
# 68          68  ...                                                 []
# 69          69  ...                                         [nan, nan]
# 70          70  ...                                         [nan, nan]
# 71          71  ...                                         [nan, nan]
# 72          72  ...                                    [nan, nan, nan]
# 73          73  ...                                                 []
# 74          74  ...                                                 []
# 75          75  ...                                                 []
# 76          76  ...  [Riverdale, Thornton Township, Cook County, Il...
# 77          77  ...                                                 []
# 78          78  ...  [nan, Minneapolis, Hennepin County, Minnesota,...
# 79          79  ...                                              [nan]
# 80          80  ...                                         [nan, nan]
# 81          81  ...                                              [nan]
# 82          82  ...                                         [nan, nan]
# 83          83  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 84          84  ...                                                 []
# 85          85  ...  [Washington, District of Columbia, United States]
# 86          86  ...  [Denver, City and County of Denver, Colorado, ...
# 87          87  ...                                                 []
# 88          88  ...                                                 []
# 89          89  ...  [Denver, City and County of Denver, Colorado, ...
# 90          90  ...                                                 []
# 91          91  ...                                                 []
# 92          92  ...                                                 []
# 93          93  ...  [Portland, Multnomah County, Oregon, United St...
# 94          94  ...  [Hollywood, Los Angeles, Los Angeles County, C...
# 95          95  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 96          96  ...                     [nan, New York, United States]
# 97          97  ...  [Providence, Providence County, Rhode Island, ...
# 98          98  ...  [Minneapolis, Hennepin County, Minnesota, 5548...
# 99          99  ...                                                 []
#
# [100 rows x 53 columns]

# %%
ct_ner['NER-1'][:100]
# Out:
# 0                                                    []
# 1     [Minneapolis, Hennepin County, Minnesota, 5548...
# 2     [nan, Minneapolis, Hennepin County, Minnesota,...
# 3     [Minneapolis, Hennepin County, Minnesota, 5548...
# 4     [Minneapolis, Hennepin County, Minnesota, 5548...
# 5     [Hampton, Virginia, 23669-4019, United States,...
# 6     [Hampton, Virginia, 23669-4019, United States,...
# 7                                                    []
# 8     [Minneapolis, Hennepin County, Minnesota, 5548...
# 9     [Minneapolis, Hennepin County, Minnesota, 5548...
# 10                                                   []
# 11                                                   []
# 12    [Atlanta, Fulton County, Georgia, 30303-3506, ...
# 13                                                   []
# 14    [Minneapolis, Hennepin County, Minnesota, 5548...
# 15    [Albuquerque, Bernalillo County, New Mexico, 8...
# 16    [Minneapolis, Hennepin County, Minnesota, 5548...
# 17             [Lake County, California, United States]
# 18    [Winter Park, Orange County, Florida, United S...
# 19                                                   []
# 20                                                   []
# 21                                                   []
# 22    [Minneapolis, Hennepin County, Minnesota, 5548...
# 23    [Washington, District of Columbia, United Stat...
# 24    [Minneapolis, Hennepin County, Minnesota, 5548...
# 25    [Trenton, Mercer County, New Jersey, United St...
# 26    [Trenton, Mercer County, New Jersey, United St...
# 27    [Trenton, Mercer County, New Jersey, United St...
# 28    [Trenton, Mercer County, New Jersey, United St...
# 29    [Trenton, Mercer County, New Jersey, United St...
# 30                                                   []
# 31    [Trenton, Mercer County, New Jersey, United St...
# 32    [Trenton, Mercer County, New Jersey, United St...
# 33    [Cecil Street, Johnston, Providence County, Rh...
# 34    [Ä°stanbul, Fatih, Ä°stanbul, Marmara BÃ¶lgesi...
# 35    [Minneapolis, Hennepin County, Minnesota, 5548...
# 36                                                [nan]
# 37                                                   []
# 38                                                   []
# 39                                                [nan]
# 40    [Oakland, Alameda County, California, United S...
# 41    [Oakland, Alameda County, California, United S...
# 42    [nan, Minneapolis, Hennepin County, Minnesota,...
# 43                         [nan, AzÉrbaycan, nan, nan]
# 44    [Beavercreek, Greene County, Ohio, 45430, Unit...
# 45    [Beavercreek, Greene County, Ohio, 45430, Unit...
# 46                                                   []
# 47                                                   []
# 48    [Minneapolis, Hennepin County, Minnesota, 5548...
# 49                                                   []
# 50    [Minneapolis, Hennepin County, Minnesota, 5548...
# 51                                                [nan]
# 52                                                   []
# 53                                                   []
# 54    [Minneapolis, Hennepin County, Minnesota, 5548...
# 55                                                   []
# 56    [Jacksonville, Duval County, Florida, United S...
# 57                                                   []
# 58                                                   []
# 59                                                   []
# 60                                                   []
# 61    [Westminster, Millbank, City of Westminster, L...
# 62    [Louisville, Jefferson County, Kentucky, 40202...
# 63    [Minneapolis, Hennepin County, Minnesota, 5548...
# 64    [nan, Minneapolis, Hennepin County, Minnesota,...
# 65    [Minneapolis, Hennepin County, Minnesota, 5548...
# 66    [Minneapolis, Hennepin County, Minnesota, 5548...
# 67                                                   []
# 68                                                   []
# 69                                           [nan, nan]
# 70                                           [nan, nan]
# 71                                           [nan, nan]
# 72                                      [nan, nan, nan]
# 73                                                   []
# 74                                                   []
# 75                                                   []
# 76    [Riverdale, Thornton Township, Cook County, Il...
# 77                                                   []
# 78    [nan, Minneapolis, Hennepin County, Minnesota,...
# 79                                                [nan]
# 80                                           [nan, nan]
# 81                                                [nan]
# 82                                           [nan, nan]
# 83    [Minneapolis, Hennepin County, Minnesota, 5548...
# 84                                                   []
# 85    [Washington, District of Columbia, United States]
# 86    [Denver, City and County of Denver, Colorado, ...
# 87                                                   []
# 88                                                   []
# 89    [Denver, City and County of Denver, Colorado, ...
# 90                                                   []
# 91                                                   []
# 92                                                   []
# 93    [Portland, Multnomah County, Oregon, United St...
# 94    [Hollywood, Los Angeles, Los Angeles County, C...
# 95    [Minneapolis, Hennepin County, Minnesota, 5548...
# 96                       [nan, New York, United States]
# 97    [Providence, Providence County, Rhode Island, ...
# 98    [Minneapolis, Hennepin County, Minnesota, 5548...
# 99                                                   []
# Name: NER-1, dtype: object

# %%
ct_ner.to_csv('dataframe0612_post_remove.csv')

# %%
# !ls
# Out:
#  Country.txt			 dataframe0611_post_remove.csv
#  dataframe0529_post.csv		 dataframe0612_post_remove.csv
#  dataframe0529_post_remove.csv	 dataframe0613_post_remove.csv
#  dataframe0530_post.csv		 dataframe0614_post_remove.csv
#  dataframe0530_post_remove.csv	 dataframe_mapping
#  dataframe0531_post.csv		 dataframe_mapping_0529.csv
#  dataframe0531_post_remove.csv	 dataframe_mapping_0530.csv
#  dataframe0601_post.csv		 dataframe_mapping_0531.csv
#  dataframe0601_post_remove.csv	 dataframe_mapping_0601.csv
#  dataframe0602_post.csv		 dataframe_mapping_0602.csv
#  dataframe0602_post_remove.csv	 dataframe_mapping_0603.csv
#  dataframe0603_post.csv		 dataframe_mapping_0604.csv
#  dataframe0603_post_remove.csv	 dataframe_mapping_0605.csv
#  dataframe0604_post.csv		 dataframe_mapping_0606.csv
#  dataframe0604_post_remove.csv	 dataframe_mapping_0607.csv
#  dataframe0605_post.csv		 dataframe_mapping_0608.csv
#  dataframe0605_post_remove.csv	 dataframe_mapping_0609.csv
#  dataframe0606_post.csv		 dataframe_mapping_0610.csv
#  dataframe0606_post_remove.csv	 dataframe_mapping_0611.csv
#  dataframe0607_post.csv		 dataframe_mapping_0612.csv
#  dataframe0607_post_remove.csv	 dataframe_mapping_0613.csv
#  dataframe0608_post.csv		 dataframe_mapping_0614.csv
#  dataframe0608_post_remove.csv	 datarframe_post
#  dataframe0609_post.csv		'mapping_US_Cities_Only(1).zip'
#  dataframe0609_post_remove.csv	 mapping_US_Cities_Only.zip
#  dataframe0610_post.csv		 post_specific_mapping_US.zip
#  dataframe0610_post_remove.csv	 states.csv
#  dataframe0611_post.csv
